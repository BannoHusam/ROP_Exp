# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, InputLayer
from keras.regularizers import L1L2, l2, l1
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from custom_pooling import RMSPooling2D
from keras.optimizers import SGD, Adam
from keras.layers import LeakyReLU
#from data import BALANCE_WEIGHTS
from keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
#import os
from datetime import datetime as dt
from custom_loss import WeightedCategoricalCrossEntropy
from VCM import VCM
from QWK import QWK
import keras.backend as K
from Fractional_MAXPOOL import FractionalPooling2D
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
def get_experiment_id():
    time_str = dt.now().strftime('%Y-%m-%d-%H-%M-%S')
    experiment_id = 'base_{}'.format(time_str)
    return experiment_id
p_ratio=[1.0, 1.44, 1.73, 1.0]

model = Sequential()


model.add(Conv2D(16, (5, 5), activation='relu', input_shape=(300, 300, 3)))
model.add(Conv2D(16, (5, 5), activation='relu'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(16, (3, 3), activation='relu'))
model.add(Conv2D(16, (3, 3), activation='relu'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))

#model.add(LeakyReLU(alpha=0.01))


model.add(Conv2D(16, (5, 5), activation='relu'))
model.add(Conv2D(16, (5, 5), activation='relu'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))



model.add(Conv2D(16, (5, 5), activation='relu'))
model.add(Conv2D(16, (5, 5), activation='relu'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(Conv2D(32, (3, 3), activation='relu'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))          
model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(Conv2D(32, (3, 3), activation='relu'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(Conv2D(32, (3, 3), activation='relu'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))

model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(Conv2D(32, (3, 3), activation='relu'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(Conv2D(64, (3, 3), activation='relu'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(Conv2D(64, (3, 3), activation='relu'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(Conv2D(64, (3, 3), activation='relu'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))
#model.add(MaxPooling2D(pool_size=1))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(Conv2D(64, (3, 3), activation='relu'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(Conv2D(64, (3, 3), activation='relu'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Flatten())


#chnaged from 10 to 5 because an error 
model.add(Dense(2, activation='softmax'))

sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.count_params()
#adam = Adam(lr=0.0005, decay=1e-6)
#rmsprop
#Mloss = WeightedCategoricalCrossEntropy({0: 0.4125861396437394, 1: 1.4918664786083686, 2: 0.690426457789382, 3: 3.9541433021806855, 4: 4.885604311008468})
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['mae','acc'])
model.summary()
loss_no_weight_decay = model.total_loss - sum(model.losses)
model.metrics_tensors.append(loss_no_weight_decay)
model.metrics_names.append('loss_no_weight_decay')
#############################################################################################
#############################################################################################
#############################################################################################
#############################################################################################
#Preparing Data Augmentation Configuration 
train_datagen = ImageDataGenerator(
        
#        featurewise_center=True,
 #       samplewise_center=True,
        shear_range=0,
        zoom_range=0.0,#[1 / 1.15, 1.15],
        horizontal_flip=False,#True,
        rotation_range=0)#90,
#        validation_split=0.2)
"""
For the test set only rescale should be made 
"""
test_datagen = ImageDataGenerator()
valid_datagen = ImageDataGenerator()


train_generator = train_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas_grah/train",
    target_size=(300, 300),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="training")
#    save_to_dir="D:/Separating Images into subfolders/train_augmented")


#print(train_generator.class_indices)

valid_generator = valid_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas_grah/vald",
    target_size=(300, 300),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="validation")
#    save_to_dir="D:/Separating Images into subfolders/val_augmented"


test_generator = test_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas_grah/test",
    target_size=(300, 300),
    color_mode="rgb",
    batch_size=1,
    class_mode="categorical",
    shuffle=False,
    seed=42)
#    save_to_dir="D:/Separating Images into subfolders/test_augmented")


# Fitting/Training the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
experiment_id = get_experiment_id()
callbacks = [
    QWK(valid_generator, STEP_SIZE_VALID),
    EarlyStopping(monitor='val_acc', patience=50, min_delta=0.001, verbose=1),
    ModelCheckpoint(experiment_id + "-val_acc_checkpoint.hdf5", monitor='val_kappa', verbose=1, save_best_only=True, mode='max'),
    ReduceLROnPlateau(monitor='val_acc', factor=0.5, patience=7, verbose=1, mode='auto', min_delta=0.001, cooldown=0, min_lr=1e-7),
    VCM(valid_generator,STEP_SIZE_VALID)
    
]

class_weight_list = class_weight.compute_class_weight('balanced', np.unique(train_generator.classes), train_generator.classes)
class_weights = dict(zip(np.unique(train_generator.classes), class_weight_list))

history=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    #class_weight=class_weights,
                    callbacks=callbacks,
                    epochs=35  
)


# Evaluating the model 
#predicting output
#reseting the test generator before calling predict_generator, in order not to get weird output
test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 296, 296, 16)      1216
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 292, 292, 16)      6416
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 290, 290, 16)      2320
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 288, 288, 16)      2320
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 284, 284, 16)      6416
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 280, 280, 16)      6416
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 276, 276, 16)      6416
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 272, 272, 16)      6416
# _________________________________________________________________
# fractional_pooling2d_1 (Frac (None, 151, 151, 16)      0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 149, 149, 32)      4640
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 147, 147, 32)      9248
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 145, 145, 32)      9248
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 143, 143, 32)      9248
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 141, 141, 32)      9248
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 139, 139, 32)      9248
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 137, 137, 32)      9248
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 135, 135, 32)      9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 67, 67, 32)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 65, 65, 64)        18496
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 63, 63, 64)        36928
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 61, 61, 64)        36928
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 59, 59, 64)        36928
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 57, 57, 64)        36928
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 55, 55, 64)        36928
# _________________________________________________________________
# fractional_pooling2d_2 (Frac (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 28, 28, 64)        36928
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 26, 26, 64)        36928
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 24, 24, 64)        36928
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 22, 22, 64)        36928
# _________________________________________________________________
# fractional_pooling2d_3 (Frac (None, 12, 12, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 9216)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 18434
# =================================================================
# Total params: 476,594
# Trainable params: 476,594
# Non-trainable params: 0
# _________________________________________________________________
# Found 588 images belonging to 2 classes.
# Found 116 images belonging to 2 classes.
# Found 176 images belonging to 2 classes.
# Epoch 1/35
# 9/9 [==============================] - 35s 4s/step - loss: 0.6929 - mean_absolute_error: 0.4999 - acc: 0.5065 - loss_no_weight_decay: 0.6929 - val_loss: 0.6918 - val_mean_absolute_error: 0.4993 - val_acc: 0.5781 - val_loss_no_weight_decay: 0.6918
# — val_kappa: 0.0
#
# Epoch 00001: val_kappa improved from -inf to 0.00000, saving model to base_2020-05-10-14-40-06-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[26  0]
#  [26  0]]
# Epoch 2/35
# 9/9 [==============================] - 25s 3s/step - loss: 0.6930 - mean_absolute_error: 0.4999 - acc: 0.4965 - loss_no_weight_decay: 0.6930 - val_loss: 0.6942 - val_mean_absolute_error: 0.5005 - val_acc: 0.4038 - val_loss_no_weight_decay: 0.6942
# — val_kappa: -0.125
#
# Epoch 00002: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[30  0]
#  [22  0]]
# Epoch 3/35
# 9/9 [==============================] - 19s 2s/step - loss: 0.6928 - mean_absolute_error: 0.4998 - acc: 0.5110 - loss_no_weight_decay: 0.6928 - val_loss: 0.6926 - val_mean_absolute_error: 0.4997 - val_acc: 0.5000 - val_loss_no_weight_decay: 0.6926
# — val_kappa: 0.125
#
# Epoch 00003: val_kappa improved from 0.00000 to 0.12500, saving model to base_2020-05-10-14-40-06-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[22  0]
#  [30  0]]
# Epoch 4/35
# 9/9 [==============================] - 22s 2s/step - loss: 0.6934 - mean_absolute_error: 0.5001 - acc: 0.4722 - loss_no_weight_decay: 0.6934 - val_loss: 0.6926 - val_mean_absolute_error: 0.4997 - val_acc: 0.5000 - val_loss_no_weight_decay: 0.6926
# — val_kappa: -0.15625
#
# Epoch 00004: val_kappa did not improve from 0.12500
# Confusion matrix:
#  [[31  0]
#  [21  0]]
# Epoch 5/35
# 9/9 [==============================] - 19s 2s/step - loss: 0.6929 - mean_absolute_error: 0.4999 - acc: 0.4844 - loss_no_weight_decay: 0.6929 - val_loss: 0.6927 - val_mean_absolute_error: 0.4998 - val_acc: 0.5312 - val_loss_no_weight_decay: 0.6927
# — val_kappa: -0.03125
#
# Epoch 00005: val_kappa did not improve from 0.12500
# Confusion matrix:
#  [[27  1]
#  [23  1]]
# Epoch 6/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.6924 - mean_absolute_error: 0.4996 - acc: 0.5573 - loss_no_weight_decay: 0.6924 - val_loss: 0.6925 - val_mean_absolute_error: 0.4997 - val_acc: 0.4808 - val_loss_no_weight_decay: 0.6925
# — val_kappa: -0.03125
#
# Epoch 00006: val_kappa did not improve from 0.12500
# Confusion matrix:
#  [[27  0]
#  [25  0]]
# Epoch 7/35
# 9/9 [==============================] - 19s 2s/step - loss: 0.6924 - mean_absolute_error: 0.4996 - acc: 0.5164 - loss_no_weight_decay: 0.6924 - val_loss: 0.6918 - val_mean_absolute_error: 0.4993 - val_acc: 0.5469 - val_loss_no_weight_decay: 0.6918
# — val_kappa: -0.09375
#
# Epoch 00007: val_kappa did not improve from 0.12500
# Confusion matrix:
#  [[29  0]
#  [23  0]]
# Epoch 8/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.6929 - mean_absolute_error: 0.4998 - acc: 0.4861 - loss_no_weight_decay: 0.6929 - val_loss: 0.6929 - val_mean_absolute_error: 0.4998 - val_acc: 0.4423 - val_loss_no_weight_decay: 0.6929
# — val_kappa: 0.03125
#
# Epoch 00008: val_kappa did not improve from 0.12500
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Confusion matrix:
#  [[25  0]
#  [27  0]]
# Epoch 9/35
# 9/9 [==============================] - 21s 2s/step - loss: 0.6918 - mean_absolute_error: 0.4993 - acc: 0.5316 - loss_no_weight_decay: 0.6918 - val_loss: 0.6939 - val_mean_absolute_error: 0.5004 - val_acc: 0.4062 - val_loss_no_weight_decay: 0.6939
# — val_kappa: 0.0
#
# Epoch 00009: val_kappa did not improve from 0.12500
# Confusion matrix:
#  [[26  0]
#  [26  0]]
# Epoch 10/35
# 9/9 [==============================] - 21s 2s/step - loss: 0.6930 - mean_absolute_error: 0.4999 - acc: 0.4604 - loss_no_weight_decay: 0.6930 - val_loss: 0.6904 - val_mean_absolute_error: 0.4986 - val_acc: 0.6154 - val_loss_no_weight_decay: 0.6904
# — val_kappa: -0.15625
#
# Epoch 00010: val_kappa did not improve from 0.12500
# Confusion matrix:
#  [[31  0]
#  [21  0]]
# Epoch 11/35
# 9/9 [==============================] - 21s 2s/step - loss: 0.6922 - mean_absolute_error: 0.4995 - acc: 0.5033 - loss_no_weight_decay: 0.6922 - val_loss: 0.6920 - val_mean_absolute_error: 0.4994 - val_acc: 0.4688 - val_loss_no_weight_decay: 0.6920
# — val_kappa: 0.0
#
# Epoch 00011: val_kappa did not improve from 0.12500
# Confusion matrix:
#  [[26  0]
#  [26  0]]
# Epoch 12/35
# 9/9 [==============================] - 21s 2s/step - loss: 0.6923 - mean_absolute_error: 0.4996 - acc: 0.4882 - loss_no_weight_decay: 0.6923 - val_loss: 0.6918 - val_mean_absolute_error: 0.4993 - val_acc: 0.5577 - val_loss_no_weight_decay: 0.6918
# — val_kappa: 0.15625
#
# Epoch 00012: val_kappa improved from 0.12500 to 0.15625, saving model to base_2020-05-10-14-40-06-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[23  0]
#  [29  0]]
# Epoch 13/35
# 9/9 [==============================] - 21s 2s/step - loss: 0.6925 - mean_absolute_error: 0.4997 - acc: 0.5040 - loss_no_weight_decay: 0.6925 - val_loss: 0.6925 - val_mean_absolute_error: 0.4996 - val_acc: 0.4375 - val_loss_no_weight_decay: 0.6925
# — val_kappa: 0.0
#
# Epoch 00013: val_kappa did not improve from 0.15625
# Confusion matrix:
#  [[28  0]
#  [23  1]]
# Epoch 14/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.6918 - mean_absolute_error: 0.4993 - acc: 0.5590 - loss_no_weight_decay: 0.6918 - val_loss: 0.6913 - val_mean_absolute_error: 0.4991 - val_acc: 0.6346 - val_loss_no_weight_decay: 0.6913
# — val_kappa: 0.1875
#
# Epoch 00014: val_kappa improved from 0.15625 to 0.18750, saving model to base_2020-05-10-14-40-06-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[26  1]
#  [19  6]]
# Epoch 15/35
# 9/9 [==============================] - 21s 2s/step - loss: 0.6922 - mean_absolute_error: 0.4995 - acc: 0.5243 - loss_no_weight_decay: 0.6922 - val_loss: 0.6918 - val_mean_absolute_error: 0.4993 - val_acc: 0.5312 - val_loss_no_weight_decay: 0.6918
# — val_kappa: -0.125
#
# Epoch 00015: val_kappa did not improve from 0.18750
# Confusion matrix:
#  [[31  0]
#  [21  0]]
# Epoch 16/35
# 9/9 [==============================] - 21s 2s/step - loss: 0.6917 - mean_absolute_error: 0.4993 - acc: 0.5178 - loss_no_weight_decay: 0.6917 - val_loss: 0.6911 - val_mean_absolute_error: 0.4990 - val_acc: 0.5000 - val_loss_no_weight_decay: 0.6911
# — val_kappa: 0.0
#
# Epoch 00016: val_kappa did not improve from 0.18750
# Confusion matrix:
#  [[27  0]
#  [23  2]]
# Epoch 17/35
# 9/9 [==============================] - 21s 2s/step - loss: 0.6916 - mean_absolute_error: 0.4992 - acc: 0.5328 - loss_no_weight_decay: 0.6916 - val_loss: 0.6915 - val_mean_absolute_error: 0.4992 - val_acc: 0.5000 - val_loss_no_weight_decay: 0.6915
# — val_kappa: 0.0625
#
# Epoch 00017: val_kappa did not improve from 0.18750
# Confusion matrix:
#  [[24  0]
#  [28  0]]
# Epoch 18/35
# 9/9 [==============================] - 19s 2s/step - loss: 0.6915 - mean_absolute_error: 0.4991 - acc: 0.5014 - loss_no_weight_decay: 0.6915 - val_loss: 0.6914 - val_mean_absolute_error: 0.4991 - val_acc: 0.5000 - val_loss_no_weight_decay: 0.6914
# — val_kappa: 0.09375
#
# Epoch 00018: val_kappa did not improve from 0.18750
# Confusion matrix:
#  [[23  0]
#  [29  0]]
# Epoch 19/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.6918 - mean_absolute_error: 0.4993 - acc: 0.5000 - loss_no_weight_decay: 0.6918 - val_loss: 0.6898 - val_mean_absolute_error: 0.4983 - val_acc: 0.5625 - val_loss_no_weight_decay: 0.6898
# — val_kappa: 0.0625
#
# Epoch 00019: val_kappa did not improve from 0.18750
# Confusion matrix:
#  [[24  0]
#  [28  0]]
# Epoch 20/35
# 9/9 [==============================] - 21s 2s/step - loss: 0.6909 - mean_absolute_error: 0.4988 - acc: 0.5118 - loss_no_weight_decay: 0.6909 - val_loss: 0.6931 - val_mean_absolute_error: 0.4999 - val_acc: 0.4231 - val_loss_no_weight_decay: 0.6931
# — val_kappa: 0.0
#
# Epoch 00020: val_kappa did not improve from 0.18750
# Confusion matrix:
#  [[26  0]
#  [26  0]]
# Epoch 21/35
# 9/9 [==============================] - 21s 2s/step - loss: 0.6912 - mean_absolute_error: 0.4989 - acc: 0.5068 - loss_no_weight_decay: 0.6912 - val_loss: 0.6923 - val_mean_absolute_error: 0.4995 - val_acc: 0.4688 - val_loss_no_weight_decay: 0.6923
# — val_kappa: 0.15625
#
# Epoch 00021: val_kappa did not improve from 0.18750
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Confusion matrix:
#  [[21  0]
#  [31  0]]
# Epoch 22/35
# 9/9 [==============================] - 21s 2s/step - loss: 0.6914 - mean_absolute_error: 0.4991 - acc: 0.4930 - loss_no_weight_decay: 0.6914 - val_loss: 0.6887 - val_mean_absolute_error: 0.4977 - val_acc: 0.5385 - val_loss_no_weight_decay: 0.6887
# — val_kappa: 0.09375
#
# Epoch 00022: val_kappa did not improve from 0.18750
# Confusion matrix:
#  [[23  0]
#  [29  0]]
# Epoch 23/35
# 9/9 [==============================] - 21s 2s/step - loss: 0.6898 - mean_absolute_error: 0.4982 - acc: 0.5343 - loss_no_weight_decay: 0.6898 - val_loss: 0.6893 - val_mean_absolute_error: 0.4980 - val_acc: 0.5156 - val_loss_no_weight_decay: 0.6893
# — val_kappa: 0.0
#
# Epoch 00023: val_kappa did not improve from 0.18750
# Confusion matrix:
#  [[26  0]
#  [26  0]]
# Epoch 24/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.6912 - mean_absolute_error: 0.4989 - acc: 0.4931 - loss_no_weight_decay: 0.6912 - val_loss: 0.6918 - val_mean_absolute_error: 0.4992 - val_acc: 0.4808 - val_loss_no_weight_decay: 0.6918
# — val_kappa: 0.03125
#
# Epoch 00024: val_kappa did not improve from 0.18750
# Confusion matrix:
#  [[25  0]
#  [27  0]]
# Epoch 25/35
# 9/9 [==============================] - 21s 2s/step - loss: 0.6913 - mean_absolute_error: 0.4989 - acc: 0.4912 - loss_no_weight_decay: 0.6913 - val_loss: 0.6868 - val_mean_absolute_error: 0.4967 - val_acc: 0.5625 - val_loss_no_weight_decay: 0.6868
# — val_kappa: 0.03125
#
# Epoch 00025: val_kappa did not improve from 0.18750
# Confusion matrix:
#  [[25  0]
#  [27  0]]
# Epoch 26/35
# 9/9 [==============================] - 19s 2s/step - loss: 0.6891 - mean_absolute_error: 0.4978 - acc: 0.5402 - loss_no_weight_decay: 0.6891 - val_loss: 0.6940 - val_mean_absolute_error: 0.5003 - val_acc: 0.4231 - val_loss_no_weight_decay: 0.6940
# — val_kappa: -0.125
#
# Epoch 00026: val_kappa did not improve from 0.18750
# Confusion matrix:
#  [[30  0]
#  [22  0]]
# Epoch 27/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.6912 - mean_absolute_error: 0.4989 - acc: 0.4826 - loss_no_weight_decay: 0.6912 - val_loss: 0.6912 - val_mean_absolute_error: 0.4989 - val_acc: 0.4531 - val_loss_no_weight_decay: 0.6912
# — val_kappa: -0.03125
#
# Epoch 00027: val_kappa did not improve from 0.18750
# Confusion matrix:
#  [[27  0]
#  [25  0]]
# Epoch 28/35
# 9/9 [==============================] - 21s 2s/step - loss: 0.6914 - mean_absolute_error: 0.4990 - acc: 0.4917 - loss_no_weight_decay: 0.6914 - val_loss: 0.6885 - val_mean_absolute_error: 0.4976 - val_acc: 0.5577 - val_loss_no_weight_decay: 0.6885
# — val_kappa: 0.09375
#
# Epoch 00028: val_kappa did not improve from 0.18750
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Confusion matrix:
#  [[23  0]
#  [29  0]]
# Epoch 29/35
# 9/9 [==============================] - 21s 2s/step - loss: 0.6909 - mean_absolute_error: 0.4988 - acc: 0.4812 - loss_no_weight_decay: 0.6909 - val_loss: 0.6885 - val_mean_absolute_error: 0.4976 - val_acc: 0.5312 - val_loss_no_weight_decay: 0.6885
# — val_kappa: -0.03125
#
# Epoch 00029: val_kappa did not improve from 0.18750
# Confusion matrix:
#  [[27  0]
#  [25  0]]
# Epoch 30/35
# 9/9 [==============================] - 21s 2s/step - loss: 0.6908 - mean_absolute_error: 0.4987 - acc: 0.4779 - loss_no_weight_decay: 0.6908 - val_loss: 0.6907 - val_mean_absolute_error: 0.4987 - val_acc: 0.4615 - val_loss_no_weight_decay: 0.6907
# — val_kappa: 0.0625
#
# Epoch 00030: val_kappa did not improve from 0.18750
# Confusion matrix:
#  [[25  0]
#  [27  0]]
# Epoch 31/35
# 9/9 [==============================] - 21s 2s/step - loss: 0.6900 - mean_absolute_error: 0.4983 - acc: 0.4965 - loss_no_weight_decay: 0.6900 - val_loss: 0.6871 - val_mean_absolute_error: 0.4969 - val_acc: 0.5938 - val_loss_no_weight_decay: 0.6871
# — val_kappa: 0.0
#
# Epoch 00031: val_kappa did not improve from 0.18750
# Confusion matrix:
#  [[27  0]
#  [25  0]]
# Epoch 32/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.6896 - mean_absolute_error: 0.4982 - acc: 0.5191 - loss_no_weight_decay: 0.6896 - val_loss: 0.6926 - val_mean_absolute_error: 0.4996 - val_acc: 0.4038 - val_loss_no_weight_decay: 0.6926
# — val_kappa: 0.15625
#
# Epoch 00032: val_kappa did not improve from 0.18750
# Confusion matrix:
#  [[22  0]
#  [30  0]]
# Epoch 33/35
# 9/9 [==============================] - 19s 2s/step - loss: 0.6902 - mean_absolute_error: 0.4984 - acc: 0.4840 - loss_no_weight_decay: 0.6902 - val_loss: 0.6885 - val_mean_absolute_error: 0.4976 - val_acc: 0.5312 - val_loss_no_weight_decay: 0.6885
# — val_kappa: -0.03125
#
# Epoch 00033: val_kappa did not improve from 0.18750
# Confusion matrix:
#  [[27  0]
#  [24  1]]
# Epoch 34/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.6904 - mean_absolute_error: 0.4985 - acc: 0.5104 - loss_no_weight_decay: 0.6904 - val_loss: 0.6902 - val_mean_absolute_error: 0.4984 - val_acc: 0.4615 - val_loss_no_weight_decay: 0.6902
# — val_kappa: -0.0625
#
# Epoch 00034: val_kappa did not improve from 0.18750
# Confusion matrix:
#  [[28  0]
#  [24  0]]
# Epoch 35/35
# 9/9 [==============================] - 21s 2s/step - loss: 0.6891 - mean_absolute_error: 0.4978 - acc: 0.5105 - loss_no_weight_decay: 0.6891 - val_loss: 0.6896 - val_mean_absolute_error: 0.4981 - val_acc: 0.4844 - val_loss_no_weight_decay: 0.6896
# — val_kappa: -0.15625
#
# Epoch 00035: val_kappa did not improve from 0.18750
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Confusion matrix:
#  [[31  0]
#  [21  0]]
# 176/176 [==============================] - 3s 17ms/step
# 176/176 [==============================] - 2s 14ms/step
# Test loss: 0.6906502033499154
# Test accuracy: 0.4986428791149096
# Confusion Matrix
# [[87  1]
#  [88  0]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.50      0.99      0.66        88
#            1       0.00      0.00      0.00        88
#
#     accuracy                           0.49       176
#    macro avg       0.25      0.49      0.33       176
# weighted avg       0.25      0.49      0.33       176

# %%
from Kappa_Skl import kappa
def kappa2(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    if len(y_true.shape) > 1 and y_true.shape[1] > 1:
        y_true = y_true.dot(range(y_true.shape[1]))
    if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
        y_pred = y_pred.dot(range(y_pred.shape[1]))
    try:
        return kappa(y_true, y_pred, weights='quadratic')
    except IndexError:
        return np.nan
    
print('Quadratic_wieghted_kappa')
print(kappa2(y_true, y_pred))
# Out:
# Quadratic_wieghted_kappa
# -0.011363636363636465

# %%
import numpy as np 
import matplotlib.pyplot as plt
import os
import wandb
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model loss.png')

# summarize history for val_kappa
plt.plot(history.history['val_kappa'])
plt.title('Validation_Kappa')
plt.ylabel('val_kappa')
plt.xlabel('epoch')
plt.legend([ 'validation'], loc='upper left')
plt.show()
#plt.savefig('model validation_kappa.png')

# summarize history for mean_absolute _error
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model mean_absolute_error')
plt.ylabel('mean_absolute_error')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model maey.png'
# Out:
# dict_keys(['val_loss', 'val_mean_absolute_error', 'val_acc', 'val_loss_no_weight_decay', 'loss', 'mean_absolute_error', 'acc', 'loss_no_weight_decay', 'val_kappa', 'lr'])
