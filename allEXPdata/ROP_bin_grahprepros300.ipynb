# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, InputLayer
from keras.regularizers import L1L2, l2, l1
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from custom_pooling import RMSPooling2D
from keras.optimizers import SGD, Adam
from keras.layers import LeakyReLU
#from data import BALANCE_WEIGHTS
from keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
#import os
from datetime import datetime as dt
from custom_loss import WeightedCategoricalCrossEntropy
from VCM import VCM
from QWK import QWK
import keras.backend as K
from Fractional_MAXPOOL import FractionalPooling2D
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
def get_experiment_id():
    time_str = dt.now().strftime('%Y-%m-%d-%H-%M-%S')
    experiment_id = 'base_{}'.format(time_str)
    return experiment_id
p_ratio=[1.0, 1.44, 1.73, 1.0]

model = Sequential()


model.add(Conv2D(16, (5, 5), activation='tanh', input_shape=(300, 300, 3)))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(16, (3, 3), activation='tanh'))
model.add(Conv2D(16, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))

#model.add(LeakyReLU(alpha=0.01))


model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))



model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))          
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))
#model.add(MaxPooling2D(pool_size=1))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Flatten())


#chnaged from 10 to 5 because an error 
model.add(Dense(2, activation='softmax'))

sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.count_params()
#adam = Adam(lr=0.0005, decay=1e-6)
#rmsprop
#Mloss = WeightedCategoricalCrossEntropy({0: 0.4125861396437394, 1: 1.4918664786083686, 2: 0.690426457789382, 3: 3.9541433021806855, 4: 4.885604311008468})
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['mae','acc'])
model.summary()
loss_no_weight_decay = model.total_loss - sum(model.losses)
model.metrics_tensors.append(loss_no_weight_decay)
model.metrics_names.append('loss_no_weight_decay')
#############################################################################################
#############################################################################################
#############################################################################################
#############################################################################################
#Preparing Data Augmentation Configuration 
train_datagen = ImageDataGenerator(
        rescale=1./255,
#        featurewise_center=True,
 #       samplewise_center=True,
        shear_range=0,
        zoom_range=0.0,#[1 / 1.15, 1.15],
        horizontal_flip=False,#True,
        rotation_range=0)#90,
#        validation_split=0.2)
"""
For the test set only rescale should be made 
"""
test_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas_grah/train",
    target_size=(300, 300),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="training")
#    save_to_dir="D:/Separating Images into subfolders/train_augmented")


#print(train_generator.class_indices)

valid_generator = valid_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas_grah/vald",
    target_size=(300, 300),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="validation")
#    save_to_dir="D:/Separating Images into subfolders/val_augmented"


test_generator = test_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas_grah/test",
    target_size=(300, 300),
    color_mode="rgb",
    batch_size=1,
    class_mode="categorical",
    shuffle=False,
    seed=42)
#    save_to_dir="D:/Separating Images into subfolders/test_augmented")


# Fitting/Training the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
experiment_id = get_experiment_id()
callbacks = [
    QWK(valid_generator, STEP_SIZE_VALID),
    EarlyStopping(monitor='val_acc', patience=50, min_delta=0.001, verbose=1),
    ModelCheckpoint(experiment_id + "-val_acc_checkpoint.hdf5", monitor='val_kappa', verbose=1, save_best_only=True, mode='max'),
    ReduceLROnPlateau(monitor='val_acc', factor=0.5, patience=7, verbose=1, mode='auto', min_delta=0.001, cooldown=0, min_lr=1e-7),
    VCM(valid_generator,STEP_SIZE_VALID)
    
]

class_weight_list = class_weight.compute_class_weight('balanced', np.unique(train_generator.classes), train_generator.classes)
class_weights = dict(zip(np.unique(train_generator.classes), class_weight_list))

history=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    #class_weight=class_weights,
                    callbacks=callbacks,
                    epochs=35  
)


# Evaluating the model 
#predicting output
#reseting the test generator before calling predict_generator, in order not to get weird output
test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 296, 296, 16)      1216
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 292, 292, 16)      6416
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 290, 290, 16)      2320
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 288, 288, 16)      2320
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 284, 284, 16)      6416
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 280, 280, 16)      6416
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 276, 276, 16)      6416
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 272, 272, 16)      6416
# _________________________________________________________________
# fractional_pooling2d_1 (Frac (None, 151, 151, 16)      0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 149, 149, 32)      4640
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 147, 147, 32)      9248
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 145, 145, 32)      9248
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 143, 143, 32)      9248
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 141, 141, 32)      9248
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 139, 139, 32)      9248
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 137, 137, 32)      9248
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 135, 135, 32)      9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 67, 67, 32)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 65, 65, 64)        18496
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 63, 63, 64)        36928
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 61, 61, 64)        36928
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 59, 59, 64)        36928
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 57, 57, 64)        36928
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 55, 55, 64)        36928
# _________________________________________________________________
# fractional_pooling2d_2 (Frac (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 28, 28, 64)        36928
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 26, 26, 64)        36928
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 24, 24, 64)        36928
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 22, 22, 64)        36928
# _________________________________________________________________
# fractional_pooling2d_3 (Frac (None, 12, 12, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 9216)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 18434
# =================================================================
# Total params: 476,594
# Trainable params: 476,594
# Non-trainable params: 0
# _________________________________________________________________
# Found 588 images belonging to 2 classes.
# Found 116 images belonging to 2 classes.
# Found 176 images belonging to 2 classes.
# Epoch 1/35
# 9/9 [==============================] - 38s 4s/step - loss: 0.6948 - mean_absolute_error: 0.5000 - acc: 0.4935 - loss_no_weight_decay: 0.6948 - val_loss: 0.6914 - val_mean_absolute_error: 0.4991 - val_acc: 0.6250 - val_loss_no_weight_decay: 0.6914
# — val_kappa: 0.3125
#
# Epoch 00001: val_kappa improved from -inf to 0.31250, saving model to base_2020-05-10-13-21-58-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[ 9 17]
#  [ 4 22]]
# Epoch 2/35
# 9/9 [==============================] - 28s 3s/step - loss: 0.6914 - mean_absolute_error: 0.4988 - acc: 0.5122 - loss_no_weight_decay: 0.6914 - val_loss: 0.6889 - val_mean_absolute_error: 0.4978 - val_acc: 0.5385 - val_loss_no_weight_decay: 0.6889
# — val_kappa: 0.15625
#
# Epoch 00002: val_kappa did not improve from 0.31250
# Confusion matrix:
#  [[29  1]
#  [18  4]]
# Epoch 3/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.6911 - mean_absolute_error: 0.4982 - acc: 0.5166 - loss_no_weight_decay: 0.6911 - val_loss: 0.6838 - val_mean_absolute_error: 0.4951 - val_acc: 0.5469 - val_loss_no_weight_decay: 0.6838
# — val_kappa: -0.0625
#
# Epoch 00003: val_kappa did not improve from 0.31250
# Confusion matrix:
#  [[ 1 21]
#  [ 0 30]]
# Epoch 4/35
# 9/9 [==============================] - 21s 2s/step - loss: 0.6947 - mean_absolute_error: 0.4995 - acc: 0.5058 - loss_no_weight_decay: 0.6947 - val_loss: 0.6859 - val_mean_absolute_error: 0.4960 - val_acc: 0.5192 - val_loss_no_weight_decay: 0.6859
# — val_kappa: 0.15625
#
# Epoch 00004: val_kappa did not improve from 0.31250
# Confusion matrix:
#  [[ 2 29]
#  [ 0 21]]
# Epoch 5/35
# 9/9 [==============================] - 25s 3s/step - loss: 0.6882 - mean_absolute_error: 0.4972 - acc: 0.5573 - loss_no_weight_decay: 0.6882 - val_loss: 0.6826 - val_mean_absolute_error: 0.4946 - val_acc: 0.8281 - val_loss_no_weight_decay: 0.6826
# — val_kappa: 0.65625
#
# Epoch 00005: val_kappa improved from 0.31250 to 0.65625, saving model to base_2020-05-10-13-21-58-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[21  7]
#  [ 4 20]]
# Epoch 6/35
# 9/9 [==============================] - 21s 2s/step - loss: 0.6839 - mean_absolute_error: 0.4953 - acc: 0.7153 - loss_no_weight_decay: 0.6839 - val_loss: 0.6780 - val_mean_absolute_error: 0.4921 - val_acc: 0.6346 - val_loss_no_weight_decay: 0.6780
# — val_kappa: 0.25
#
# Epoch 00006: val_kappa did not improve from 0.65625
# Confusion matrix:
#  [[27  0]
#  [18  7]]
# Epoch 7/35
# 9/9 [==============================] - 25s 3s/step - loss: 0.6837 - mean_absolute_error: 0.4949 - acc: 0.5868 - loss_no_weight_decay: 0.6837 - val_loss: 0.6731 - val_mean_absolute_error: 0.4896 - val_acc: 0.6719 - val_loss_no_weight_decay: 0.6731
# — val_kappa: 0.5625
#
# Epoch 00007: val_kappa did not improve from 0.65625
# Confusion matrix:
#  [[ 9 20]
#  [ 1 22]]
# Epoch 8/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.6776 - mean_absolute_error: 0.4916 - acc: 0.6593 - loss_no_weight_decay: 0.6776 - val_loss: 0.6582 - val_mean_absolute_error: 0.4813 - val_acc: 0.6923 - val_loss_no_weight_decay: 0.6582
# — val_kappa: 0.34375
#
# Epoch 00008: val_kappa did not improve from 0.65625
# Confusion matrix:
#  [[ 7 18]
#  [ 1 26]]
# Epoch 9/35
# 9/9 [==============================] - 21s 2s/step - loss: 0.6680 - mean_absolute_error: 0.4853 - acc: 0.5955 - loss_no_weight_decay: 0.6680 - val_loss: 0.6389 - val_mean_absolute_error: 0.4447 - val_acc: 0.5938 - val_loss_no_weight_decay: 0.6389
# — val_kappa: 0.0
#
# Epoch 00009: val_kappa did not improve from 0.65625
# Confusion matrix:
#  [[ 0 26]
#  [ 0 26]]
# Epoch 10/35
# 9/9 [==============================] - 25s 3s/step - loss: 0.6689 - mean_absolute_error: 0.4818 - acc: 0.6458 - loss_no_weight_decay: 0.6689 - val_loss: 0.6478 - val_mean_absolute_error: 0.4724 - val_acc: 0.5769 - val_loss_no_weight_decay: 0.6478
# — val_kappa: 0.40625
#
# Epoch 00010: val_kappa did not improve from 0.65625
# Confusion matrix:
#  [[10 21]
#  [ 0 21]]
# Epoch 11/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.6244 - mean_absolute_error: 0.4515 - acc: 0.6608 - loss_no_weight_decay: 0.6244 - val_loss: 0.5301 - val_mean_absolute_error: 0.4023 - val_acc: 0.7969 - val_loss_no_weight_decay: 0.5301
# — val_kappa: 0.53125
#
# Epoch 00011: val_kappa did not improve from 0.65625
# Confusion matrix:
#  [[25  1]
#  [ 7 19]]
# Epoch 12/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.6125 - mean_absolute_error: 0.4154 - acc: 0.6899 - loss_no_weight_decay: 0.6125 - val_loss: 0.5509 - val_mean_absolute_error: 0.4159 - val_acc: 0.7692 - val_loss_no_weight_decay: 0.5509
# — val_kappa: 0.71875
#
# Epoch 00012: val_kappa improved from 0.65625 to 0.71875, saving model to base_2020-05-10-13-21-58-val_acc_checkpoint.hdf5
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Confusion matrix:
#  [[13 10]
#  [ 5 24]]
# Epoch 13/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.5367 - mean_absolute_error: 0.3980 - acc: 0.7550 - loss_no_weight_decay: 0.5367 - val_loss: 0.4725 - val_mean_absolute_error: 0.3261 - val_acc: 0.7188 - val_loss_no_weight_decay: 0.4725
# — val_kappa: 0.28125
#
# Epoch 00013: val_kappa did not improve from 0.71875
# Confusion matrix:
#  [[10 18]
#  [ 0 24]]
# Epoch 14/35
# 9/9 [==============================] - 26s 3s/step - loss: 0.4320 - mean_absolute_error: 0.2976 - acc: 0.8021 - loss_no_weight_decay: 0.4320 - val_loss: 0.3202 - val_mean_absolute_error: 0.2157 - val_acc: 0.8654 - val_loss_no_weight_decay: 0.3202
# — val_kappa: 0.78125
#
# Epoch 00014: val_kappa improved from 0.71875 to 0.78125, saving model to base_2020-05-10-13-21-58-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[25  2]
#  [ 5 20]]
# Epoch 15/35
# 9/9 [==============================] - 21s 2s/step - loss: 0.3873 - mean_absolute_error: 0.2302 - acc: 0.8306 - loss_no_weight_decay: 0.3873 - val_loss: 0.3449 - val_mean_absolute_error: 0.2358 - val_acc: 0.8594 - val_loss_no_weight_decay: 0.3449
# — val_kappa: 0.875
#
# Epoch 00015: val_kappa improved from 0.78125 to 0.87500, saving model to base_2020-05-10-13-21-58-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[25  6]
#  [ 2 19]]
# Epoch 16/35
# 9/9 [==============================] - 25s 3s/step - loss: 0.3271 - mean_absolute_error: 0.2095 - acc: 0.8646 - loss_no_weight_decay: 0.3271 - val_loss: 0.1560 - val_mean_absolute_error: 0.1325 - val_acc: 0.9615 - val_loss_no_weight_decay: 0.1560
# — val_kappa: 0.875
#
# Epoch 00016: val_kappa did not improve from 0.87500
# Confusion matrix:
#  [[25  2]
#  [ 2 23]]
# Epoch 17/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.2708 - mean_absolute_error: 0.1733 - acc: 0.8865 - loss_no_weight_decay: 0.2708 - val_loss: 0.1517 - val_mean_absolute_error: 0.1153 - val_acc: 0.9688 - val_loss_no_weight_decay: 0.1517
# — val_kappa: 0.96875
#
# Epoch 00017: val_kappa improved from 0.87500 to 0.96875, saving model to base_2020-05-10-13-21-58-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[22  2]
#  [ 0 28]]
# Epoch 18/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.1864 - mean_absolute_error: 0.1189 - acc: 0.9229 - loss_no_weight_decay: 0.1864 - val_loss: 0.1438 - val_mean_absolute_error: 0.0976 - val_acc: 0.9423 - val_loss_no_weight_decay: 0.1438
# — val_kappa: 0.9375
#
# Epoch 00018: val_kappa did not improve from 0.96875
# Confusion matrix:
#  [[22  1]
#  [ 4 25]]
# Epoch 19/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.2156 - mean_absolute_error: 0.1111 - acc: 0.9231 - loss_no_weight_decay: 0.2156 - val_loss: 0.1148 - val_mean_absolute_error: 0.0834 - val_acc: 0.9688 - val_loss_no_weight_decay: 0.1148
# — val_kappa: 1.0
#
# Epoch 00019: val_kappa improved from 0.96875 to 1.00000, saving model to base_2020-05-10-13-21-58-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[23  1]
#  [ 1 27]]
# Epoch 20/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.1679 - mean_absolute_error: 0.0999 - acc: 0.9386 - loss_no_weight_decay: 0.1679 - val_loss: 0.0686 - val_mean_absolute_error: 0.0627 - val_acc: 1.0000 - val_loss_no_weight_decay: 0.0686
# — val_kappa: 1.0
#
# Epoch 00020: val_kappa did not improve from 1.00000
# Confusion matrix:
#  [[25  1]
#  [ 1 25]]
# Epoch 21/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.1667 - mean_absolute_error: 0.0971 - acc: 0.9389 - loss_no_weight_decay: 0.1667 - val_loss: 0.1081 - val_mean_absolute_error: 0.0857 - val_acc: 0.9688 - val_loss_no_weight_decay: 0.1081
# — val_kappa: 0.9375
#
# Epoch 00021: val_kappa did not improve from 1.00000
# Confusion matrix:
#  [[21  0]
#  [ 0 31]]
# Epoch 22/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.1648 - mean_absolute_error: 0.0899 - acc: 0.9441 - loss_no_weight_decay: 0.1648 - val_loss: 0.0629 - val_mean_absolute_error: 0.0581 - val_acc: 1.0000 - val_loss_no_weight_decay: 0.0629
# — val_kappa: 0.96875
#
# Epoch 00022: val_kappa did not improve from 1.00000
# Confusion matrix:
#  [[23  0]
#  [ 1 28]]
# Epoch 23/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.1421 - mean_absolute_error: 0.0906 - acc: 0.9474 - loss_no_weight_decay: 0.1421 - val_loss: 0.0613 - val_mean_absolute_error: 0.0536 - val_acc: 0.9844 - val_loss_no_weight_decay: 0.0613
# — val_kappa: 0.96875
#
# Epoch 00023: val_kappa did not improve from 1.00000
# Confusion matrix:
#  [[25  1]
#  [ 0 26]]
# Epoch 24/35
# 9/9 [==============================] - 25s 3s/step - loss: 0.1373 - mean_absolute_error: 0.0776 - acc: 0.9531 - loss_no_weight_decay: 0.1373 - val_loss: 0.0938 - val_mean_absolute_error: 0.0740 - val_acc: 0.9808 - val_loss_no_weight_decay: 0.0938
# — val_kappa: 0.96875
#
# Epoch 00024: val_kappa did not improve from 1.00000
# Confusion matrix:
#  [[25  0]
#  [ 1 26]]
# Epoch 25/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.1239 - mean_absolute_error: 0.0666 - acc: 0.9614 - loss_no_weight_decay: 0.1239 - val_loss: 0.0594 - val_mean_absolute_error: 0.0497 - val_acc: 1.0000 - val_loss_no_weight_decay: 0.0594
# — val_kappa: 0.96875
#
# Epoch 00025: val_kappa did not improve from 1.00000
# Confusion matrix:
#  [[25  0]
#  [ 1 26]]
# Epoch 26/35
# 9/9 [==============================] - 21s 2s/step - loss: 0.1017 - mean_absolute_error: 0.0594 - acc: 0.9645 - loss_no_weight_decay: 0.1017 - val_loss: 0.0672 - val_mean_absolute_error: 0.0552 - val_acc: 0.9808 - val_loss_no_weight_decay: 0.0672
# — val_kappa: 0.96875
#
# Epoch 00026: val_kappa did not improve from 1.00000
# Confusion matrix:
#  [[30  0]
#  [ 1 21]]
# Epoch 27/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.1739 - mean_absolute_error: 0.0885 - acc: 0.9461 - loss_no_weight_decay: 0.1739 - val_loss: 0.0922 - val_mean_absolute_error: 0.0828 - val_acc: 1.0000 - val_loss_no_weight_decay: 0.0922
# — val_kappa: 0.96875
#
# Epoch 00027: val_kappa did not improve from 1.00000
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Confusion matrix:
#  [[27  0]
#  [ 0 25]]
# Epoch 28/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.1165 - mean_absolute_error: 0.0760 - acc: 0.9649 - loss_no_weight_decay: 0.1165 - val_loss: 0.0709 - val_mean_absolute_error: 0.0604 - val_acc: 1.0000 - val_loss_no_weight_decay: 0.0709
# — val_kappa: 0.9375
#
# Epoch 00028: val_kappa did not improve from 1.00000
# Confusion matrix:
#  [[23  0]
#  [ 1 28]]
# Epoch 29/35
# 9/9 [==============================] - 25s 3s/step - loss: 0.1110 - mean_absolute_error: 0.0650 - acc: 0.9601 - loss_no_weight_decay: 0.1110 - val_loss: 0.0721 - val_mean_absolute_error: 0.0588 - val_acc: 0.9844 - val_loss_no_weight_decay: 0.0721
# — val_kappa: 0.96875
#
# Epoch 00029: val_kappa did not improve from 1.00000
# Confusion matrix:
#  [[27  0]
#  [ 1 24]]
# Epoch 30/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.1155 - mean_absolute_error: 0.0622 - acc: 0.9614 - loss_no_weight_decay: 0.1155 - val_loss: 0.0394 - val_mean_absolute_error: 0.0341 - val_acc: 0.9808 - val_loss_no_weight_decay: 0.0394
# — val_kappa: 0.9375
#
# Epoch 00030: val_kappa did not improve from 1.00000
# Confusion matrix:
#  [[25  0]
#  [ 0 27]]
# Epoch 31/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.1043 - mean_absolute_error: 0.0604 - acc: 0.9614 - loss_no_weight_decay: 0.1043 - val_loss: 0.0708 - val_mean_absolute_error: 0.0605 - val_acc: 0.9844 - val_loss_no_weight_decay: 0.0708
# — val_kappa: 0.96875
#
# Epoch 00031: val_kappa did not improve from 1.00000
# Confusion matrix:
#  [[26  1]
#  [ 0 25]]
# Epoch 32/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.1080 - mean_absolute_error: 0.0657 - acc: 0.9617 - loss_no_weight_decay: 0.1080 - val_loss: 0.0430 - val_mean_absolute_error: 0.0340 - val_acc: 0.9808 - val_loss_no_weight_decay: 0.0430
# — val_kappa: 1.0
#
# Epoch 00032: val_kappa did not improve from 1.00000
# Confusion matrix:
#  [[22  0]
#  [ 1 29]]
# Epoch 33/35
# 9/9 [==============================] - 25s 3s/step - loss: 0.0979 - mean_absolute_error: 0.0540 - acc: 0.9635 - loss_no_weight_decay: 0.0979 - val_loss: 0.0447 - val_mean_absolute_error: 0.0383 - val_acc: 1.0000 - val_loss_no_weight_decay: 0.0447
# — val_kappa: 1.0
#
# Epoch 00033: val_kappa did not improve from 1.00000
# Confusion matrix:
#  [[27  0]
#  [ 1 24]]
# Epoch 34/35
# 9/9 [==============================] - 21s 2s/step - loss: 0.1069 - mean_absolute_error: 0.0570 - acc: 0.9510 - loss_no_weight_decay: 0.1069 - val_loss: 0.0649 - val_mean_absolute_error: 0.0524 - val_acc: 0.9808 - val_loss_no_weight_decay: 0.0649
# — val_kappa: 1.0
#
# Epoch 00034: val_kappa did not improve from 1.00000
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Confusion matrix:
#  [[28  0]
#  [ 1 23]]
# Epoch 35/35
# 9/9 [==============================] - 25s 3s/step - loss: 0.1223 - mean_absolute_error: 0.0688 - acc: 0.9653 - loss_no_weight_decay: 0.1223 - val_loss: 0.0438 - val_mean_absolute_error: 0.0379 - val_acc: 1.0000 - val_loss_no_weight_decay: 0.0438
# — val_kappa: 0.96875
#
# Epoch 00035: val_kappa did not improve from 1.00000
# Confusion matrix:
#  [[31  0]
#  [ 0 21]]
# 176/176 [==============================] - 3s 15ms/step
# 176/176 [==============================] - 2s 14ms/step
# Test loss: 0.5011423738357156
# Test accuracy: 0.2333807013247596
# Confusion Matrix
# [[86  2]
#  [38 50]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.69      0.98      0.81        88
#            1       0.96      0.57      0.71        88
#
#     accuracy                           0.77       176
#    macro avg       0.83      0.77      0.76       176
# weighted avg       0.83      0.77      0.76       176

# %%
from Kappa_Skl import kappa
def kappa2(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    if len(y_true.shape) > 1 and y_true.shape[1] > 1:
        y_true = y_true.dot(range(y_true.shape[1]))
    if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
        y_pred = y_pred.dot(range(y_pred.shape[1]))
    try:
        return kappa(y_true, y_pred, weights='quadratic')
    except IndexError:
        return np.nan
    
print('Quadratic_wieghted_kappa')
print(kappa2(y_true, y_pred))
# Out:
# Quadratic_wieghted_kappa
# 0.5454545454545454

# %%
import numpy as np 
import matplotlib.pyplot as plt
import os
import wandb
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model loss.png')

# summarize history for val_kappa
plt.plot(history.history['val_kappa'])
plt.title('Validation_Kappa')
plt.ylabel('val_kappa')
plt.xlabel('epoch')
plt.legend([ 'validation'], loc='upper left')
plt.show()
#plt.savefig('model validation_kappa.png')

# summarize history for mean_absolute _error
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model mean_absolute_error')
plt.ylabel('mean_absolute_error')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model maey.png'
# Out:
# dict_keys(['val_loss', 'val_mean_absolute_error', 'val_acc', 'val_loss_no_weight_decay', 'loss', 'mean_absolute_error', 'acc', 'loss_no_weight_decay', 'val_kappa', 'lr'])
