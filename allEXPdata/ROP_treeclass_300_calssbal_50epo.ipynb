# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, InputLayer
from keras.regularizers import L1L2, l2, l1
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from custom_pooling import RMSPooling2D
from keras.optimizers import SGD, Adam
from keras.layers import LeakyReLU
#from data import BALANCE_WEIGHTS
from keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
#import os
from datetime import datetime as dt
from custom_loss import WeightedCategoricalCrossEntropy
from VCM import VCM
from QWK import QWK
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
def get_experiment_id():
    time_str = dt.now().strftime('%Y-%m-%d-%H-%M-%S')
    experiment_id = 'base_{}'.format(time_str)
    return experiment_id
p_ratio=[1.0, 1.44, 1.73, 1.0]

model = Sequential()


model.add(Conv2D(16, (5, 5), activation='tanh', input_shape=(300, 300, 3)))
model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(16, (3, 3), activation='tanh'))
model.add(Conv2D(16, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))

#model.add(LeakyReLU(alpha=0.01))


model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))



model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))          
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(MaxPooling2D(pool_size=2))
#model.add(MaxPooling2D(pool_size=1))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
model.add(MaxPooling2D(pool_size=2))

model.add(Flatten())


#chnaged from 10 to 5 because an error 
model.add(Dense(3, activation='softmax'))

sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.count_params()
#adam = Adam(lr=0.0005, decay=1e-6)
#rmsprop
#Mloss = WeightedCategoricalCrossEntropy({0: 0.4125861396437394, 1: 1.4918664786083686, 2: 0.690426457789382, 3: 3.9541433021806855, 4: 4.885604311008468})
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['acc','binary_accuracy','mae'])
model.summary()
loss_no_weight_decay = model.total_loss - sum(model.losses)
model.metrics_tensors.append(loss_no_weight_decay)
model.metrics_names.append('loss_no_weight_decay')
#############################################################################################
#############################################################################################
#############################################################################################
#############################################################################################
#Preparing Data Augmentation Configuration 
train_datagen = ImageDataGenerator(
        rescale=1./255,
#        featurewise_center=True,
 #       samplewise_center=True,
        shear_range=0,
        zoom_range=0.0,#[1 / 1.15, 1.15],
        horizontal_flip=False,#True,
        rotation_range=0)#90,
#        validation_split=0.2)
"""
For the test set only rescale should be made 
"""
test_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/three_class/train",
    target_size=(300, 300),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="training")
#    save_to_dir="D:/Separating Images into subfolders/train_augmented")


#print(train_generator.class_indices)

valid_generator = valid_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/three_class/vald",
    target_size=(300, 300),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="validation")
#    save_to_dir="D:/Separating Images into subfolders/val_augmented"


test_generator = test_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/three_class/test",
    target_size=(300, 300),
    color_mode="rgb",
    batch_size=1,
    class_mode="categorical",
    shuffle=False,
    seed=42)
#    save_to_dir="D:/Separating Images into subfolders/test_augmented")


# Fitting/Training the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
experiment_id = get_experiment_id()
callbacks = [
    QWK(valid_generator, STEP_SIZE_VALID),
    EarlyStopping(monitor='val_acc', patience=50, min_delta=0.001, verbose=1),
    ModelCheckpoint(experiment_id + "-val_kapa_checkpoint.hdf5", monitor='val_kappa', verbose=1, save_best_only=True, mode='max'),
    ReduceLROnPlateau(monitor='val_acc', factor=0.5, patience=7, verbose=1, mode='auto', min_delta=0.001, cooldown=0, min_lr=1e-7),
    VCM(valid_generator,STEP_SIZE_VALID)
    
]

class_weight_list = class_weight.compute_class_weight('balanced', np.unique(train_generator.classes), train_generator.classes)
class_weights = dict(zip(np.unique(train_generator.classes), class_weight_list))

history=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    class_weight=class_weights,
                    callbacks=callbacks,
                    epochs=50  
)


# Evaluating the model 
#predicting output
#reseting the test generator before calling predict_generator, in order not to get weird output
test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1', '2']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 296, 296, 16)      1216
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 292, 292, 16)      6416
# _________________________________________________________________
# input_1 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 290, 290, 16)      2320
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 288, 288, 16)      2320
# _________________________________________________________________
# input_2 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 284, 284, 16)      6416
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 280, 280, 16)      6416
# _________________________________________________________________
# input_3 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 276, 276, 16)      6416
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 272, 272, 16)      6416
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 136, 136, 16)      0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 134, 134, 32)      4640
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 132, 132, 32)      9248
# _________________________________________________________________
# input_4 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 130, 130, 32)      9248
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 128, 128, 32)      9248
# _________________________________________________________________
# input_5 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 126, 126, 32)      9248
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 124, 124, 32)      9248
# _________________________________________________________________
# input_6 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 122, 122, 32)      9248
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 120, 120, 32)      9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 60, 60, 32)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 58, 58, 64)        18496
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 56, 56, 64)        36928
# _________________________________________________________________
# input_7 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 54, 54, 64)        36928
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 52, 52, 64)        36928
# _________________________________________________________________
# input_8 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 50, 50, 64)        36928
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 48, 48, 64)        36928
# _________________________________________________________________
# input_9 (InputLayer)         multiple                  0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 22, 22, 64)        36928
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 20, 20, 64)        36928
# _________________________________________________________________
# input_10 (InputLayer)        multiple                  0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 18, 18, 64)        36928
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# input_11 (InputLayer)        multiple                  0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 12291
# =================================================================
# Total params: 470,451
# Trainable params: 470,451
# Non-trainable params: 0
# _________________________________________________________________
# Found 588 images belonging to 3 classes.
# Found 116 images belonging to 3 classes.
# Found 176 images belonging to 3 classes.
# Epoch 1/50
# 9/9 [==============================] - 28s 3s/step - loss: 1.0889 - acc: 0.3640 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4438 - loss_no_weight_decay: 1.0889 - val_loss: 1.0926 - val_acc: 0.5625 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4430 - val_loss_no_weight_decay: 1.0926
# — val_kappa: 0.0
#
# Epoch 00001: val_kappa improved from -inf to 0.00000, saving model to base_2020-05-09-13-30-56-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[26  0  0]
#  [ 5  0  0]
#  [21  0  0]]
# Epoch 2/50
# 9/9 [==============================] - 15s 2s/step - loss: 1.0938 - acc: 0.4522 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4439 - loss_no_weight_decay: 1.0938 - val_loss: 1.1034 - val_acc: 0.4038 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4453 - val_loss_no_weight_decay: 1.1034
# — val_kappa: 0.0
#
# Epoch 00002: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[30  0  0]
#  [ 7  0  0]
#  [15  0  0]]
# Epoch 3/50
# 9/9 [==============================] - 13s 1s/step - loss: 1.1150 - acc: 0.3973 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4450 - loss_no_weight_decay: 1.1150 - val_loss: 1.1055 - val_acc: 0.4062 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4437 - val_loss_no_weight_decay: 1.1055
# — val_kappa: 0.0
#
# Epoch 00003: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[22  0  0]
#  [ 6  0  0]
#  [24  0  0]]
# Epoch 4/50
# 9/9 [==============================] - 13s 1s/step - loss: 1.0837 - acc: 0.3865 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4459 - loss_no_weight_decay: 1.0837 - val_loss: 1.0792 - val_acc: 0.5192 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4397 - val_loss_no_weight_decay: 1.0792
# — val_kappa: 0.0
#
# Epoch 00004: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[23  0  0]
#  [ 6  0  0]
#  [23  0  0]]
# Epoch 5/50
# 9/9 [==============================] - 15s 2s/step - loss: 1.0790 - acc: 0.4965 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4382 - loss_no_weight_decay: 1.0790 - val_loss: 1.0873 - val_acc: 0.3906 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4417 - val_loss_no_weight_decay: 1.0873
# — val_kappa: 0.0
#
# Epoch 00005: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[28  0  0]
#  [ 5  0  0]
#  [19  0  0]]
# Epoch 6/50
# 9/9 [==============================] - 12s 1s/step - loss: 1.1130 - acc: 0.3000 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4455 - loss_no_weight_decay: 1.1130 - val_loss: 1.0658 - val_acc: 0.4231 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4355 - val_loss_no_weight_decay: 1.0658
# — val_kappa: 0.0
#
# Epoch 00006: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[29  0  0]
#  [ 5  0  0]
#  [18  0  0]]
# Epoch 7/50
# 9/9 [==============================] - 13s 1s/step - loss: 1.0750 - acc: 0.3837 - binary_accuracy: 0.6760 - mean_absolute_error: 0.4339 - loss_no_weight_decay: 1.0750 - val_loss: 1.1225 - val_acc: 0.3281 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4436 - val_loss_no_weight_decay: 1.1225
# — val_kappa: 0.0
#
# Epoch 00007: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[29  0  0]
#  [ 4  0  0]
#  [19  0  0]]
# Epoch 8/50
# 9/9 [==============================] - 14s 2s/step - loss: 1.0552 - acc: 0.5521 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4324 - loss_no_weight_decay: 1.0552 - val_loss: 1.0046 - val_acc: 0.6346 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4206 - val_loss_no_weight_decay: 1.0046
# — val_kappa: 0.0
#
# Epoch 00008: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[28  0  0]
#  [ 7  0  0]
#  [17  0  0]]
# Epoch 9/50
# 9/9 [==============================] - 13s 1s/step - loss: 1.0098 - acc: 0.5877 - binary_accuracy: 0.6754 - mean_absolute_error: 0.4183 - loss_no_weight_decay: 1.0098 - val_loss: 0.9930 - val_acc: 0.5000 - val_binary_accuracy: 0.7188 - val_mean_absolute_error: 0.4064 - val_loss_no_weight_decay: 0.9930
# — val_kappa: 0.21052631578947367
#
# Epoch 00009: val_kappa improved from 0.00000 to 0.21053, saving model to base_2020-05-09-13-30-56-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[26  0  0]
#  [ 5  1  0]
#  [20  0  0]]
# Epoch 10/50
# 9/9 [==============================] - 13s 1s/step - loss: 1.0222 - acc: 0.4785 - binary_accuracy: 0.6733 - mean_absolute_error: 0.4100 - loss_no_weight_decay: 1.0222 - val_loss: 0.8804 - val_acc: 0.6538 - val_binary_accuracy: 0.7436 - val_mean_absolute_error: 0.3810 - val_loss_no_weight_decay: 0.8804
# — val_kappa: 0.33333333333333326
#
# Epoch 00010: val_kappa improved from 0.21053 to 0.33333, saving model to base_2020-05-09-13-30-56-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[29  0  0]
#  [ 4  0  0]
#  [19  0  0]]
# Epoch 11/50
# 9/9 [==============================] - 14s 2s/step - loss: 0.9607 - acc: 0.5608 - binary_accuracy: 0.7378 - mean_absolute_error: 0.3810 - loss_no_weight_decay: 0.9607 - val_loss: 1.0341 - val_acc: 0.5781 - val_binary_accuracy: 0.7031 - val_mean_absolute_error: 0.4128 - val_loss_no_weight_decay: 1.0341
# — val_kappa: 0.07920792079207928
#
# Epoch 00011: val_kappa did not improve from 0.33333
# Confusion matrix:
#  [[25  1  0]
#  [ 4  0  0]
#  [19  0  3]]
# Epoch 12/50
# 9/9 [==============================] - 13s 1s/step - loss: 0.9916 - acc: 0.5329 - binary_accuracy: 0.7056 - mean_absolute_error: 0.4050 - loss_no_weight_decay: 0.9916 - val_loss: 0.9709 - val_acc: 0.4231 - val_binary_accuracy: 0.6795 - val_mean_absolute_error: 0.3973 - val_loss_no_weight_decay: 0.9709
# — val_kappa: 0.19909502262443446
#
# Epoch 00012: val_kappa did not improve from 0.33333
# Confusion matrix:
#  [[29  2  0]
#  [ 2  2  0]
#  [11  6  0]]
# Epoch 13/50
# 9/9 [==============================] - 13s 1s/step - loss: 0.9919 - acc: 0.5326 - binary_accuracy: 0.7040 - mean_absolute_error: 0.3724 - loss_no_weight_decay: 0.9919 - val_loss: 1.0893 - val_acc: 0.4844 - val_binary_accuracy: 0.6615 - val_mean_absolute_error: 0.4280 - val_loss_no_weight_decay: 1.0893
# — val_kappa: 0.019512195121951015
#
# Epoch 00013: val_kappa did not improve from 0.33333
# Confusion matrix:
#  [[28  0  0]
#  [ 5  0  0]
#  [19  0  0]]
# Epoch 14/50
# 9/9 [==============================] - 13s 1s/step - loss: 1.0059 - acc: 0.4880 - binary_accuracy: 0.7032 - mean_absolute_error: 0.4074 - loss_no_weight_decay: 1.0059 - val_loss: 1.0147 - val_acc: 0.5962 - val_binary_accuracy: 0.6731 - val_mean_absolute_error: 0.4149 - val_loss_no_weight_decay: 1.0147
# — val_kappa: 0.05797101449275344
#
# Epoch 00014: val_kappa did not improve from 0.33333
# Confusion matrix:
#  [[27  0  0]
#  [ 6  0  0]
#  [19  0  0]]
# Epoch 15/50
# 9/9 [==============================] - 13s 1s/step - loss: 0.9530 - acc: 0.5732 - binary_accuracy: 0.7248 - mean_absolute_error: 0.3825 - loss_no_weight_decay: 0.9530 - val_loss: 1.0556 - val_acc: 0.4219 - val_binary_accuracy: 0.6458 - val_mean_absolute_error: 0.4061 - val_loss_no_weight_decay: 1.0556
# — val_kappa: -0.025974025974025983
#
# Epoch 00015: val_kappa did not improve from 0.33333
# Confusion matrix:
#  [[25  6  0]
#  [ 3  2  0]
#  [ 6 10  0]]
# Epoch 16/50
# 9/9 [==============================] - 14s 2s/step - loss: 0.8879 - acc: 0.5885 - binary_accuracy: 0.7321 - mean_absolute_error: 0.3655 - loss_no_weight_decay: 0.8879 - val_loss: 0.9229 - val_acc: 0.6346 - val_binary_accuracy: 0.7436 - val_mean_absolute_error: 0.3825 - val_loss_no_weight_decay: 0.9229
# — val_kappa: 0.2180094786729856
#
# Epoch 00016: val_kappa did not improve from 0.33333
# Confusion matrix:
#  [[22  2  0]
#  [ 5  4  0]
#  [13  5  1]]
# Epoch 17/50
# 9/9 [==============================] - 13s 1s/step - loss: 0.8022 - acc: 0.6365 - binary_accuracy: 0.7814 - mean_absolute_error: 0.3414 - loss_no_weight_decay: 0.8022 - val_loss: 0.7840 - val_acc: 0.7188 - val_binary_accuracy: 0.8021 - val_mean_absolute_error: 0.3389 - val_loss_no_weight_decay: 0.7840
# — val_kappa: 0.5128205128205128
#
# Epoch 00017: val_kappa improved from 0.33333 to 0.51282, saving model to base_2020-05-09-13-30-56-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[21  1  2]
#  [ 5  0  1]
#  [ 8  4 10]]
# Epoch 18/50
# 9/9 [==============================] - 13s 1s/step - loss: 0.8252 - acc: 0.6608 - binary_accuracy: 0.7618 - mean_absolute_error: 0.3316 - loss_no_weight_decay: 0.8252 - val_loss: 0.7673 - val_acc: 0.6538 - val_binary_accuracy: 0.7821 - val_mean_absolute_error: 0.3174 - val_loss_no_weight_decay: 0.7673
# — val_kappa: 0.35242290748898686
#
# Epoch 00018: val_kappa did not improve from 0.51282
# Confusion matrix:
#  [[31  0  1]
#  [ 2  1  0]
#  [ 9  4  4]]
# Epoch 19/50
# 9/9 [==============================] - 13s 1s/step - loss: 0.7662 - acc: 0.7044 - binary_accuracy: 0.8042 - mean_absolute_error: 0.3030 - loss_no_weight_decay: 0.7662 - val_loss: 0.7461 - val_acc: 0.6406 - val_binary_accuracy: 0.7865 - val_mean_absolute_error: 0.3071 - val_loss_no_weight_decay: 0.7461
# — val_kappa: 0.34024896265560156
#
# Epoch 00019: val_kappa did not improve from 0.51282
# Confusion matrix:
#  [[22  0  2]
#  [ 3  2  1]
#  [11  1 10]]
# Epoch 20/50
# 9/9 [==============================] - 13s 1s/step - loss: 0.7141 - acc: 0.7119 - binary_accuracy: 0.8135 - mean_absolute_error: 0.2997 - loss_no_weight_decay: 0.7141 - val_loss: 0.7245 - val_acc: 0.6923 - val_binary_accuracy: 0.7821 - val_mean_absolute_error: 0.2748 - val_loss_no_weight_decay: 0.7245
# — val_kappa: 0.3510204081632654
#
# Epoch 00020: val_kappa did not improve from 0.51282
# Confusion matrix:
#  [[23  0  1]
#  [ 1  4  1]
#  [11  1 10]]
# Epoch 21/50
# 9/9 [==============================] - 13s 1s/step - loss: 0.6971 - acc: 0.7119 - binary_accuracy: 0.8125 - mean_absolute_error: 0.2856 - loss_no_weight_decay: 0.6971 - val_loss: 0.7126 - val_acc: 0.6875 - val_binary_accuracy: 0.7969 - val_mean_absolute_error: 0.2884 - val_loss_no_weight_decay: 0.7126
# — val_kappa: 0.49382716049382713
#
# Epoch 00021: val_kappa did not improve from 0.51282
# Confusion matrix:
#  [[18  1  2]
#  [ 5  2  2]
#  [14  1  7]]
# Epoch 22/50
# 9/9 [==============================] - 16s 2s/step - loss: 0.7782 - acc: 0.6784 - binary_accuracy: 0.7950 - mean_absolute_error: 0.2973 - loss_no_weight_decay: 0.7782 - val_loss: 0.7532 - val_acc: 0.6154 - val_binary_accuracy: 0.7372 - val_mean_absolute_error: 0.3135 - val_loss_no_weight_decay: 0.7532
# — val_kappa: 0.26890756302521013
#
# Epoch 00022: val_kappa did not improve from 0.51282
# Confusion matrix:
#  [[23  3  1]
#  [ 3  5  1]
#  [ 7  3  6]]
# Epoch 23/50
# 9/9 [==============================] - 14s 2s/step - loss: 0.6672 - acc: 0.7447 - binary_accuracy: 0.8363 - mean_absolute_error: 0.2696 - loss_no_weight_decay: 0.6672 - val_loss: 0.7323 - val_acc: 0.6719 - val_binary_accuracy: 0.7917 - val_mean_absolute_error: 0.2911 - val_loss_no_weight_decay: 0.7323
# — val_kappa: 0.39495798319327724
#
# Epoch 00023: val_kappa did not improve from 0.51282
# Confusion matrix:
#  [[22  2  2]
#  [ 1  4  1]
#  [ 7  3 10]]
# Epoch 24/50
# 9/9 [==============================] - 13s 1s/step - loss: 0.6861 - acc: 0.7327 - binary_accuracy: 0.8212 - mean_absolute_error: 0.2731 - loss_no_weight_decay: 0.6861 - val_loss: 0.6663 - val_acc: 0.6923 - val_binary_accuracy: 0.8077 - val_mean_absolute_error: 0.2687 - val_loss_no_weight_decay: 0.6663
# — val_kappa: 0.44999999999999996
#
# Epoch 00024: val_kappa did not improve from 0.51282
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Confusion matrix:
#  [[19  2  2]
#  [ 2  3  2]
#  [ 8  3 11]]
# Epoch 25/50
# 9/9 [==============================] - 13s 1s/step - loss: 0.6133 - acc: 0.7690 - binary_accuracy: 0.8449 - mean_absolute_error: 0.2546 - loss_no_weight_decay: 0.6133 - val_loss: 0.7236 - val_acc: 0.6719 - val_binary_accuracy: 0.7708 - val_mean_absolute_error: 0.2960 - val_loss_no_weight_decay: 0.7236
# — val_kappa: 0.5469387755102041
#
# Epoch 00025: val_kappa improved from 0.51282 to 0.54694, saving model to base_2020-05-09-13-30-56-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[18  3  4]
#  [ 1  1  4]
#  [ 8  3 10]]
# Epoch 26/50
# 9/9 [==============================] - 15s 2s/step - loss: 0.5785 - acc: 0.7639 - binary_accuracy: 0.8478 - mean_absolute_error: 0.2452 - loss_no_weight_decay: 0.5785 - val_loss: 0.7399 - val_acc: 0.6346 - val_binary_accuracy: 0.7885 - val_mean_absolute_error: 0.2824 - val_loss_no_weight_decay: 0.7399
# — val_kappa: 0.42914979757085014
#
# Epoch 00026: val_kappa did not improve from 0.54694
# Confusion matrix:
#  [[22  1  3]
#  [ 1  3  2]
#  [ 5  4 11]]
# Epoch 27/50
# 9/9 [==============================] - 13s 1s/step - loss: 0.6272 - acc: 0.7322 - binary_accuracy: 0.8210 - mean_absolute_error: 0.2537 - loss_no_weight_decay: 0.6272 - val_loss: 0.6532 - val_acc: 0.6562 - val_binary_accuracy: 0.7969 - val_mean_absolute_error: 0.2700 - val_loss_no_weight_decay: 0.6532
# — val_kappa: 0.4049586776859504
#
# Epoch 00027: val_kappa did not improve from 0.54694
# Confusion matrix:
#  [[23  1  3]
#  [ 1  4  2]
#  [ 5  2 11]]
# Epoch 28/50
# 9/9 [==============================] - 13s 1s/step - loss: 0.5434 - acc: 0.7971 - binary_accuracy: 0.8630 - mean_absolute_error: 0.2290 - loss_no_weight_decay: 0.5434 - val_loss: 0.7294 - val_acc: 0.6538 - val_binary_accuracy: 0.7949 - val_mean_absolute_error: 0.2880 - val_loss_no_weight_decay: 0.7294
# — val_kappa: 0.5081967213114753
#
# Epoch 00028: val_kappa did not improve from 0.54694
# Confusion matrix:
#  [[21  1  3]
#  [ 2  3  3]
#  [ 4  5 10]]
# Epoch 29/50
# 9/9 [==============================] - 13s 1s/step - loss: 0.5508 - acc: 0.7896 - binary_accuracy: 0.8604 - mean_absolute_error: 0.2286 - loss_no_weight_decay: 0.5508 - val_loss: 0.7215 - val_acc: 0.6562 - val_binary_accuracy: 0.7760 - val_mean_absolute_error: 0.2664 - val_loss_no_weight_decay: 0.7215
# — val_kappa: 0.5853658536585367
#
# Epoch 00029: val_kappa improved from 0.54694 to 0.58537, saving model to base_2020-05-09-13-30-56-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[19  4  4]
#  [ 0  5  0]
#  [ 7  4  9]]
# Epoch 30/50
# 9/9 [==============================] - 13s 1s/step - loss: 0.5551 - acc: 0.7778 - binary_accuracy: 0.8467 - mean_absolute_error: 0.2323 - loss_no_weight_decay: 0.5551 - val_loss: 0.7338 - val_acc: 0.6346 - val_binary_accuracy: 0.7885 - val_mean_absolute_error: 0.2753 - val_loss_no_weight_decay: 0.7338
# — val_kappa: 0.41975308641975306
#
# Epoch 00030: val_kappa did not improve from 0.58537
# Confusion matrix:
#  [[21  1  1]
#  [ 0  4  1]
#  [ 6  3 15]]
# Epoch 31/50
# 9/9 [==============================] - 13s 1s/step - loss: 0.5256 - acc: 0.7758 - binary_accuracy: 0.8582 - mean_absolute_error: 0.2213 - loss_no_weight_decay: 0.5256 - val_loss: 0.6307 - val_acc: 0.7344 - val_binary_accuracy: 0.8125 - val_mean_absolute_error: 0.2467 - val_loss_no_weight_decay: 0.6307
# — val_kappa: 0.5506072874493927
#
# Epoch 00031: val_kappa did not improve from 0.58537
# Confusion matrix:
#  [[22  1  4]
#  [ 0  2  0]
#  [ 6  6 11]]
# Epoch 32/50
# 9/9 [==============================] - 14s 2s/step - loss: 0.5442 - acc: 0.7848 - binary_accuracy: 0.8520 - mean_absolute_error: 0.2250 - loss_no_weight_decay: 0.5442 - val_loss: 0.7012 - val_acc: 0.6538 - val_binary_accuracy: 0.7821 - val_mean_absolute_error: 0.2663 - val_loss_no_weight_decay: 0.7012
# — val_kappa: 0.41463414634146334
#
# Epoch 00032: val_kappa did not improve from 0.58537
# Confusion matrix:
#  [[21  2  1]
#  [ 1  4  2]
#  [ 7  1 13]]
# Epoch 33/50
# 9/9 [==============================] - 14s 2s/step - loss: 0.5323 - acc: 0.7886 - binary_accuracy: 0.8666 - mean_absolute_error: 0.2234 - loss_no_weight_decay: 0.5323 - val_loss: 0.7352 - val_acc: 0.7031 - val_binary_accuracy: 0.7865 - val_mean_absolute_error: 0.2698 - val_loss_no_weight_decay: 0.7352
# — val_kappa: 0.467741935483871
#
# Epoch 00033: val_kappa did not improve from 0.58537
# Confusion matrix:
#  [[22  0  5]
#  [ 2  3  2]
#  [ 3  1 14]]
# Epoch 34/50
# 9/9 [==============================] - 16s 2s/step - loss: 0.5131 - acc: 0.8021 - binary_accuracy: 0.8634 - mean_absolute_error: 0.2162 - loss_no_weight_decay: 0.5131 - val_loss: 0.6933 - val_acc: 0.7308 - val_binary_accuracy: 0.8205 - val_mean_absolute_error: 0.2489 - val_loss_no_weight_decay: 0.6933
# — val_kappa: 0.5679012345679013
#
# Epoch 00034: val_kappa did not improve from 0.58537
# Confusion matrix:
#  [[18  1  4]
#  [ 0  3  3]
#  [ 6  3 14]]
# Epoch 35/50
# 9/9 [==============================] - 13s 1s/step - loss: 0.5550 - acc: 0.7418 - binary_accuracy: 0.8377 - mean_absolute_error: 0.2323 - loss_no_weight_decay: 0.5550 - val_loss: 0.8418 - val_acc: 0.6094 - val_binary_accuracy: 0.7760 - val_mean_absolute_error: 0.3052 - val_loss_no_weight_decay: 0.8418
# — val_kappa: 0.6141078838174273
#
# Epoch 00035: val_kappa improved from 0.58537 to 0.61411, saving model to base_2020-05-09-13-30-56-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[24  2  5]
#  [ 0  2  1]
#  [ 3  5 10]]
# Epoch 36/50
# 9/9 [==============================] - 14s 2s/step - loss: 0.5323 - acc: 0.7748 - binary_accuracy: 0.8613 - mean_absolute_error: 0.2218 - loss_no_weight_decay: 0.5323 - val_loss: 0.7109 - val_acc: 0.6731 - val_binary_accuracy: 0.7885 - val_mean_absolute_error: 0.2707 - val_loss_no_weight_decay: 0.7109
# — val_kappa: 0.5577689243027889
#
# Epoch 00036: val_kappa did not improve from 0.61411
# Confusion matrix:
#  [[22  3  4]
#  [ 2  4  2]
#  [ 2  1 12]]
# Epoch 37/50
# 9/9 [==============================] - 15s 2s/step - loss: 0.4749 - acc: 0.8177 - binary_accuracy: 0.8808 - mean_absolute_error: 0.2010 - loss_no_weight_decay: 0.4749 - val_loss: 0.6836 - val_acc: 0.7188 - val_binary_accuracy: 0.8177 - val_mean_absolute_error: 0.2518 - val_loss_no_weight_decay: 0.6836
# — val_kappa: 0.5577689243027889
#
# Epoch 00037: val_kappa did not improve from 0.61411
# Confusion matrix:
#  [[18  1  4]
#  [ 1  3  2]
#  [ 9  3 11]]
# Epoch 38/50
# 9/9 [==============================] - 13s 1s/step - loss: 0.5109 - acc: 0.7796 - binary_accuracy: 0.8560 - mean_absolute_error: 0.2141 - loss_no_weight_decay: 0.5109 - val_loss: 0.8070 - val_acc: 0.7115 - val_binary_accuracy: 0.8205 - val_mean_absolute_error: 0.2488 - val_loss_no_weight_decay: 0.8070
# — val_kappa: 0.6639999999999999
#
# Epoch 00038: val_kappa improved from 0.61411 to 0.66400, saving model to base_2020-05-09-13-30-56-val_kapa_checkpoint.hdf5
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Confusion matrix:
#  [[23  0  4]
#  [ 1  3  3]
#  [ 6  5  7]]
# Epoch 39/50
# 9/9 [==============================] - 13s 1s/step - loss: 0.4633 - acc: 0.8219 - binary_accuracy: 0.8677 - mean_absolute_error: 0.1989 - loss_no_weight_decay: 0.4633 - val_loss: 0.5650 - val_acc: 0.7500 - val_binary_accuracy: 0.8542 - val_mean_absolute_error: 0.2363 - val_loss_no_weight_decay: 0.5650
# — val_kappa: 0.467741935483871
#
# Epoch 00039: val_kappa did not improve from 0.66400
# Confusion matrix:
#  [[28  0  1]
#  [ 0  6  1]
#  [ 5  2  9]]
# Epoch 40/50
# 9/9 [==============================] - 13s 1s/step - loss: 0.4382 - acc: 0.8440 - binary_accuracy: 0.8907 - mean_absolute_error: 0.1917 - loss_no_weight_decay: 0.4382 - val_loss: 0.6493 - val_acc: 0.6538 - val_binary_accuracy: 0.7628 - val_mean_absolute_error: 0.2535 - val_loss_no_weight_decay: 0.6493
# — val_kappa: 0.506024096385542
#
# Epoch 00040: val_kappa did not improve from 0.66400
# Confusion matrix:
#  [[26  2  3]
#  [ 1  3  1]
#  [ 2  2 12]]
# Epoch 41/50
# 9/9 [==============================] - 13s 1s/step - loss: 0.4718 - acc: 0.8134 - binary_accuracy: 0.8656 - mean_absolute_error: 0.2007 - loss_no_weight_decay: 0.4718 - val_loss: 0.5621 - val_acc: 0.7656 - val_binary_accuracy: 0.8490 - val_mean_absolute_error: 0.2005 - val_loss_no_weight_decay: 0.5621
# — val_kappa: 0.5403225806451613
#
# Epoch 00041: val_kappa did not improve from 0.66400
# Confusion matrix:
#  [[24  0  4]
#  [ 0  2  2]
#  [ 4  3 13]]
# Epoch 42/50
# 9/9 [==============================] - 13s 1s/step - loss: 0.4678 - acc: 0.8319 - binary_accuracy: 0.8833 - mean_absolute_error: 0.1969 - loss_no_weight_decay: 0.4678 - val_loss: 0.5541 - val_acc: 0.8077 - val_binary_accuracy: 0.8654 - val_mean_absolute_error: 0.2095 - val_loss_no_weight_decay: 0.5541
# — val_kappa: 0.6024096385542168
#
# Epoch 00042: val_kappa did not improve from 0.66400
# Confusion matrix:
#  [[22  0  2]
#  [ 2  3  1]
#  [ 5  5 12]]
# Epoch 43/50
# 9/9 [==============================] - 16s 2s/step - loss: 0.4513 - acc: 0.8108 - binary_accuracy: 0.8709 - mean_absolute_error: 0.1912 - loss_no_weight_decay: 0.4513 - val_loss: 0.6248 - val_acc: 0.7344 - val_binary_accuracy: 0.8281 - val_mean_absolute_error: 0.2150 - val_loss_no_weight_decay: 0.6248
# — val_kappa: 0.6129032258064515
#
# Epoch 00043: val_kappa did not improve from 0.66400
# Confusion matrix:
#  [[24  0  5]
#  [ 1  1  1]
#  [ 5  2 13]]
# Epoch 44/50
# 9/9 [==============================] - 14s 2s/step - loss: 0.4036 - acc: 0.8495 - binary_accuracy: 0.8944 - mean_absolute_error: 0.1827 - loss_no_weight_decay: 0.4036 - val_loss: 0.6730 - val_acc: 0.6923 - val_binary_accuracy: 0.8077 - val_mean_absolute_error: 0.2557 - val_loss_no_weight_decay: 0.6730
# — val_kappa: 0.5919999999999999
#
# Epoch 00044: val_kappa did not improve from 0.66400
# Confusion matrix:
#  [[23  0  2]
#  [ 1  2  3]
#  [ 3  3 15]]
# Epoch 45/50
# 9/9 [==============================] - 14s 2s/step - loss: 0.4343 - acc: 0.8086 - binary_accuracy: 0.8809 - mean_absolute_error: 0.1864 - loss_no_weight_decay: 0.4343 - val_loss: 0.6810 - val_acc: 0.7344 - val_binary_accuracy: 0.8281 - val_mean_absolute_error: 0.2240 - val_loss_no_weight_decay: 0.6810
# — val_kappa: 0.611764705882353
#
# Epoch 00045: val_kappa did not improve from 0.66400
# Confusion matrix:
#  [[18  2  1]
#  [ 1  3  2]
#  [ 5  2 18]]
# Epoch 46/50
# 9/9 [==============================] - 15s 2s/step - loss: 0.4579 - acc: 0.8166 - binary_accuracy: 0.8737 - mean_absolute_error: 0.1932 - loss_no_weight_decay: 0.4579 - val_loss: 0.6313 - val_acc: 0.7308 - val_binary_accuracy: 0.8141 - val_mean_absolute_error: 0.2395 - val_loss_no_weight_decay: 0.6313
# — val_kappa: 0.467741935483871
#
# Epoch 00046: val_kappa did not improve from 0.66400
# Confusion matrix:
#  [[22  2  3]
#  [ 0  5  1]
#  [ 1  2 16]]
# Epoch 47/50
# 9/9 [==============================] - 15s 2s/step - loss: 0.4193 - acc: 0.8464 - binary_accuracy: 0.8912 - mean_absolute_error: 0.1871 - loss_no_weight_decay: 0.4193 - val_loss: 0.6169 - val_acc: 0.7188 - val_binary_accuracy: 0.8177 - val_mean_absolute_error: 0.2458 - val_loss_no_weight_decay: 0.6169
# — val_kappa: 0.5748987854251012
#
# Epoch 00047: val_kappa did not improve from 0.66400
# Confusion matrix:
#  [[20  2  3]
#  [ 0  3  1]
#  [ 8  2 13]]
# Epoch 48/50
# 9/9 [==============================] - 12s 1s/step - loss: 0.4084 - acc: 0.8360 - binary_accuracy: 0.8860 - mean_absolute_error: 0.1825 - loss_no_weight_decay: 0.4084 - val_loss: 0.6093 - val_acc: 0.7885 - val_binary_accuracy: 0.8526 - val_mean_absolute_error: 0.1976 - val_loss_no_weight_decay: 0.6093
# — val_kappa: 0.6234817813765181
#
# Epoch 00048: val_kappa did not improve from 0.66400
# Confusion matrix:
#  [[23  1  6]
#  [ 1  2  1]
#  [ 4  3 11]]
# Epoch 49/50
# 9/9 [==============================] - 14s 2s/step - loss: 0.4312 - acc: 0.8264 - binary_accuracy: 0.8929 - mean_absolute_error: 0.1830 - loss_no_weight_decay: 0.4312 - val_loss: 0.7080 - val_acc: 0.6719 - val_binary_accuracy: 0.7917 - val_mean_absolute_error: 0.2518 - val_loss_no_weight_decay: 0.7080
# — val_kappa: 0.5919999999999999
#
# Epoch 00049: val_kappa did not improve from 0.66400
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Confusion matrix:
#  [[22  2  5]
#  [ 1  4  2]
#  [ 0  1 15]]
# Epoch 50/50
# 9/9 [==============================] - 13s 1s/step - loss: 0.4269 - acc: 0.8214 - binary_accuracy: 0.8867 - mean_absolute_error: 0.1885 - loss_no_weight_decay: 0.4269 - val_loss: 0.7580 - val_acc: 0.7308 - val_binary_accuracy: 0.7949 - val_mean_absolute_error: 0.2484 - val_loss_no_weight_decay: 0.7580
# — val_kappa: 0.5714285714285714
#
# Epoch 00050: val_kappa did not improve from 0.66400
# Confusion matrix:
#  [[21  2  5]
#  [ 0  6  1]
#  [ 2  3 12]]
# 176/176 [==============================] - 5s 29ms/step
# 176/176 [==============================] - 5s 28ms/step
# Test loss: 0.5467336911918789
# Test accuracy: 0.7727272727272727
# Confusion Matrix
# [[78  0 10]
#  [ 0 11  8]
#  [ 4 18 47]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.95      0.89      0.92        88
#            1       0.38      0.58      0.46        19
#            2       0.72      0.68      0.70        69
#
#     accuracy                           0.77       176
#    macro avg       0.68      0.72      0.69       176
# weighted avg       0.80      0.77      0.78       176

# %%
from Kappa_Skl import kappa
def kappa2(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    if len(y_true.shape) > 1 and y_true.shape[1] > 1:
        y_true = y_true.dot(range(y_true.shape[1]))
    if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
        y_pred = y_pred.dot(range(y_pred.shape[1]))
    try:
        return kappa(y_true, y_pred, weights='quadratic')
    except IndexError:
        return np.nan
    
print('Quadratic_wieghted_kappa')
print(kappa2(y_true, y_pred))
# Out:
# Quadratic_wieghted_kappa
# 0.7269665897309774

# %%
import numpy as np 
import matplotlib.pyplot as plt
import os
import wandb
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model loss.png')

# summarize history for val_kappa
plt.plot(history.history['val_kappa'])
plt.title('Validation_Kappa')
plt.ylabel('val_kappa')
plt.xlabel('epoch')
plt.legend([ 'validation'], loc='upper left')
plt.show()
#plt.savefig('model validation_kappa.png')

# summarize history for mean_absolute _error
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model mean_absolute_error')
plt.ylabel('mean_absolute_error')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model maey.png'
# Out:
# dict_keys(['val_loss', 'val_acc', 'val_binary_accuracy', 'val_mean_absolute_error', 'val_loss_no_weight_decay', 'loss', 'acc', 'binary_accuracy', 'mean_absolute_error', 'loss_no_weight_decay', 'val_kappa', 'lr'])
