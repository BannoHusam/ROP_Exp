# %%
import keras
from keras.models import Sequential, Input, Model
from keras.losses import mean_squared_error
from keras.layers import  *
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, InputLayer
from keras.regularizers import L1L2, l2, l1
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from custom_pooling import RMSPooling2D
from keras.optimizers import SGD, Adam
from keras.layers import LeakyReLU
#from data import BALANCE_WEIGHTS
from keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
#import os
from datetime import datetime as dt
from custom_loss import WeightedCategoricalCrossEntropy
from VCM import VCM
import keras.backend as K
from Fractional_MAXPOOL import FractionalPooling2D
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
def get_experiment_id():
    time_str = dt.now().strftime('%Y-%m-%d-%H-%M-%S')
    experiment_id = 'base_{}'.format(time_str)
    return experiment_id
p_ratio=[1.0, 1.44, 1.73, 1.0]

model = Sequential()


model.add(Conv2D(16, (5, 5), activation='tanh', input_shape=(270, 270, 3)))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(16, (3, 3), activation='tanh'))
model.add(Conv2D(16, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

#model.add(LeakyReLU(alpha=0.01))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))


model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))


model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))


#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))



#model.add(MaxPooling2D(pool_size=1))




model.add(MaxPooling2D(pool_size=2))

model.add(Flatten())


#chnaged from 10 to 5 because an error 
model.add(Dense(2, activation='softmax'))

sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.count_params()
#adam = Adam(lr=0.0005, decay=1e-6)
#rmsprop
#Mloss = WeightedCategoricalCrossEntropy({0: 0.4125861396437394, 1: 1.4918664786083686, 2: 0.690426457789382, 3: 3.9541433021806855, 4: 4.885604311008468})
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['mae','acc'])
model.summary()
loss_no_weight_decay = model.total_loss - sum(model.losses)
model.metrics_tensors.append(loss_no_weight_decay)
model.metrics_names.append('loss_no_weight_decay')
#############################################################################################
#############################################################################################
#############################################################################################
#############################################################################################
#Preparing Data Augmentation Configuration 
train_datagen = ImageDataGenerator(
        rescale=1./255,
#        featurewise_center=True,
 #       samplewise_center=True,
        shear_range=0,
        zoom_range=0.0,#[1 / 1.15, 1.15],
        horizontal_flip=False,#True,
        rotation_range=0)#90,
#        validation_split=0.2)
"""
For the test set only rescale should be made 
"""
test_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas_noch/train",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="training")
#    save_to_dir="D:/Separating Images into subfolders/train_augmented")


#print(train_generator.class_indices)

valid_generator = valid_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas_noch/vald",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="validation")
#    save_to_dir="D:/Separating Images into subfolders/val_augmented"


test_generator = test_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas_noch/test",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=1,
    class_mode="categorical",
    shuffle=False,
    seed=42)
#    save_to_dir="D:/Separating Images into subfolders/test_augmented")


# Fitting/Training the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
experiment_id = get_experiment_id()
callbacks = [
    EarlyStopping(monitor='val_acc', patience=50, min_delta=0.001, verbose=1),
    ModelCheckpoint(experiment_id + "-val_acc_checkpoint.hdf5", monitor='val_acc', verbose=1, save_best_only=True, mode='auto'),
    ReduceLROnPlateau(monitor='val_acc', factor=0.5, patience=7, verbose=1, mode='auto', min_delta=0.001, cooldown=0, min_lr=1e-7),
    VCM(valid_generator,STEP_SIZE_VALID)
    
]

class_weight_list = class_weight.compute_class_weight('balanced', np.unique(train_generator.classes), train_generator.classes)
class_weights = dict(zip(np.unique(train_generator.classes), class_weight_list))

history=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    #class_weight=class_weights,
                    callbacks=callbacks,
                    epochs=35  
)


# Evaluating the model 
#predicting output
#reseting the test generator before calling predict_generator, in order not to get weird output
test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 266, 266, 16)      1216
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 262, 262, 16)      6416
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 260, 260, 16)      2320
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 258, 258, 16)      2320
# _________________________________________________________________
# fractional_pooling2d_1 (Frac (None, 143, 143, 16)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 139, 139, 16)      6416
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 135, 135, 16)      6416
# _________________________________________________________________
# fractional_pooling2d_2 (Frac (None, 75, 75, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 71, 71, 16)        6416
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 67, 67, 16)        6416
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 65, 65, 32)        4640
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 63, 63, 32)        9248
# _________________________________________________________________
# fractional_pooling2d_3 (Frac (None, 35, 35, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 33, 33, 32)        9248
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 31, 31, 32)        9248
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 29, 29, 64)        18496
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 27, 27, 64)        36928
# _________________________________________________________________
# fractional_pooling2d_4 (Frac (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 13, 13, 64)        36928
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 11, 11, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1600)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 3202
# =================================================================
# Total params: 202,802
# Trainable params: 202,802
# Non-trainable params: 0
# _________________________________________________________________
# Found 582 images belonging to 2 classes.
# Found 78 images belonging to 2 classes.
# Found 121 images belonging to 2 classes.
# Epoch 1/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.6959 - mean_absolute_error: 0.5004 - acc: 0.5443 - loss_no_weight_decay: 0.6959 - val_loss: 0.6758 - val_mean_absolute_error: 0.4906 - val_acc: 0.7500 - val_loss_no_weight_decay: 0.6758
#
# Epoch 00001: val_acc improved from -inf to 0.75000, saving model to base_2020-05-11-21-58-12-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[48  0]
#  [16  0]]
# Epoch 2/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.6948 - mean_absolute_error: 0.5006 - acc: 0.5467 - loss_no_weight_decay: 0.6948 - val_loss: 0.6831 - val_mean_absolute_error: 0.4949 - val_acc: 0.7857 - val_loss_no_weight_decay: 0.6831
#
# Epoch 00002: val_acc improved from 0.75000 to 0.78571, saving model to base_2020-05-11-21-58-12-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[7 3]
#  [3 1]]
# Epoch 3/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.6900 - mean_absolute_error: 0.4983 - acc: 0.5747 - loss_no_weight_decay: 0.6900 - val_loss: 0.6968 - val_mean_absolute_error: 0.5016 - val_acc: 0.3906 - val_loss_no_weight_decay: 0.6968
#
# Epoch 00003: val_acc did not improve from 0.78571
# Confusion matrix:
#  [[11 38]
#  [ 0 15]]
# Epoch 4/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.6856 - mean_absolute_error: 0.4958 - acc: 0.5241 - loss_no_weight_decay: 0.6856 - val_loss: 0.6614 - val_mean_absolute_error: 0.4830 - val_acc: 0.7143 - val_loss_no_weight_decay: 0.6614
#
# Epoch 00004: val_acc did not improve from 0.78571
# Confusion matrix:
#  [[9 0]
#  [5 0]]
# Epoch 5/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.6795 - mean_absolute_error: 0.4924 - acc: 0.5938 - loss_no_weight_decay: 0.6795 - val_loss: 0.6880 - val_mean_absolute_error: 0.4959 - val_acc: 0.5000 - val_loss_no_weight_decay: 0.6880
#
# Epoch 00005: val_acc did not improve from 0.78571
# Confusion matrix:
#  [[15 33]
#  [ 0 16]]
# Epoch 6/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.6847 - mean_absolute_error: 0.4938 - acc: 0.5472 - loss_no_weight_decay: 0.6847 - val_loss: 0.6299 - val_mean_absolute_error: 0.4666 - val_acc: 0.8571 - val_loss_no_weight_decay: 0.6299
#
# Epoch 00006: val_acc improved from 0.78571 to 0.85714, saving model to base_2020-05-11-21-58-12-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[9 0]
#  [2 3]]
# Epoch 7/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.6631 - mean_absolute_error: 0.4831 - acc: 0.7031 - loss_no_weight_decay: 0.6631 - val_loss: 0.6954 - val_mean_absolute_error: 0.4964 - val_acc: 0.4688 - val_loss_no_weight_decay: 0.6954
#
# Epoch 00007: val_acc did not improve from 0.85714
# Confusion matrix:
#  [[15 31]
#  [ 0 18]]
# Epoch 8/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.6536 - mean_absolute_error: 0.4743 - acc: 0.6717 - loss_no_weight_decay: 0.6536 - val_loss: 0.6255 - val_mean_absolute_error: 0.4564 - val_acc: 0.7143 - val_loss_no_weight_decay: 0.6255
#
# Epoch 00008: val_acc did not improve from 0.85714
# Confusion matrix:
#  [[3 7]
#  [0 4]]
# Epoch 9/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.6354 - mean_absolute_error: 0.4627 - acc: 0.6910 - loss_no_weight_decay: 0.6354 - val_loss: 0.5872 - val_mean_absolute_error: 0.4357 - val_acc: 0.7344 - val_loss_no_weight_decay: 0.5872
#
# Epoch 00009: val_acc did not improve from 0.85714
# Confusion matrix:
#  [[30 20]
#  [ 1 13]]
# Epoch 10/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.5940 - mean_absolute_error: 0.4349 - acc: 0.6861 - loss_no_weight_decay: 0.5940 - val_loss: 0.7354 - val_mean_absolute_error: 0.4694 - val_acc: 0.7143 - val_loss_no_weight_decay: 0.7354
#
# Epoch 00010: val_acc did not improve from 0.85714
# Confusion matrix:
#  [[5 3]
#  [0 6]]
# Epoch 11/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.6100 - mean_absolute_error: 0.4221 - acc: 0.6685 - loss_no_weight_decay: 0.6100 - val_loss: 0.5087 - val_mean_absolute_error: 0.3829 - val_acc: 0.7969 - val_loss_no_weight_decay: 0.5087
#
# Epoch 00011: val_acc did not improve from 0.85714
# Confusion matrix:
#  [[36 10]
#  [ 3 15]]
# Epoch 12/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.5530 - mean_absolute_error: 0.4016 - acc: 0.7344 - loss_no_weight_decay: 0.5530 - val_loss: 0.7932 - val_mean_absolute_error: 0.4753 - val_acc: 0.5714 - val_loss_no_weight_decay: 0.7932
#
# Epoch 00012: val_acc did not improve from 0.85714
# Confusion matrix:
#  [[6 5]
#  [0 3]]
# Epoch 13/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.5469 - mean_absolute_error: 0.3740 - acc: 0.7261 - loss_no_weight_decay: 0.5469 - val_loss: 0.5111 - val_mean_absolute_error: 0.3692 - val_acc: 0.7031 - val_loss_no_weight_decay: 0.5111
#
# Epoch 00013: val_acc did not improve from 0.85714
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Confusion matrix:
#  [[32 15]
#  [ 1 16]]
# Epoch 14/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.5041 - mean_absolute_error: 0.3646 - acc: 0.7731 - loss_no_weight_decay: 0.5041 - val_loss: 0.3698 - val_mean_absolute_error: 0.2853 - val_acc: 0.8571 - val_loss_no_weight_decay: 0.3698
#
# Epoch 00014: val_acc did not improve from 0.85714
# Confusion matrix:
#  [[8 3]
#  [0 3]]
# Epoch 15/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.4982 - mean_absolute_error: 0.3615 - acc: 0.7708 - loss_no_weight_decay: 0.4982 - val_loss: 0.4798 - val_mean_absolute_error: 0.3403 - val_acc: 0.7656 - val_loss_no_weight_decay: 0.4798
#
# Epoch 00015: val_acc did not improve from 0.85714
# Confusion matrix:
#  [[32 16]
#  [ 1 15]]
# Epoch 16/35
# 9/9 [==============================] - 16s 2s/step - loss: 0.4648 - mean_absolute_error: 0.3333 - acc: 0.8016 - loss_no_weight_decay: 0.4648 - val_loss: 0.4701 - val_mean_absolute_error: 0.3101 - val_acc: 0.7857 - val_loss_no_weight_decay: 0.4701
#
# Epoch 00016: val_acc did not improve from 0.85714
# Confusion matrix:
#  [[10  3]
#  [ 0  1]]
# Epoch 17/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.4612 - mean_absolute_error: 0.3231 - acc: 0.8105 - loss_no_weight_decay: 0.4612 - val_loss: 0.4290 - val_mean_absolute_error: 0.2994 - val_acc: 0.7656 - val_loss_no_weight_decay: 0.4290
#
# Epoch 00017: val_acc did not improve from 0.85714
# Confusion matrix:
#  [[36 11]
#  [ 1 16]]
# Epoch 18/35
# 9/9 [==============================] - 16s 2s/step - loss: 0.4573 - mean_absolute_error: 0.3216 - acc: 0.7865 - loss_no_weight_decay: 0.4573 - val_loss: 0.3191 - val_mean_absolute_error: 0.2376 - val_acc: 0.8571 - val_loss_no_weight_decay: 0.3191
#
# Epoch 00018: val_acc did not improve from 0.85714
# Confusion matrix:
#  [[8 1]
#  [1 4]]
# Epoch 19/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.4560 - mean_absolute_error: 0.3137 - acc: 0.8078 - loss_no_weight_decay: 0.4560 - val_loss: 0.3378 - val_mean_absolute_error: 0.2567 - val_acc: 0.8594 - val_loss_no_weight_decay: 0.3378
#
# Epoch 00019: val_acc improved from 0.85714 to 0.85938, saving model to base_2020-05-11-21-58-12-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[40  6]
#  [ 5 13]]
# Epoch 20/35
# 9/9 [==============================] - 16s 2s/step - loss: 0.4092 - mean_absolute_error: 0.2957 - acc: 0.8108 - loss_no_weight_decay: 0.4092 - val_loss: 0.3331 - val_mean_absolute_error: 0.2439 - val_acc: 0.8571 - val_loss_no_weight_decay: 0.3331
#
# Epoch 00020: val_acc did not improve from 0.85938
# Confusion matrix:
#  [[8 0]
#  [0 6]]
# Epoch 21/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.3779 - mean_absolute_error: 0.2677 - acc: 0.8560 - loss_no_weight_decay: 0.3779 - val_loss: 0.4572 - val_mean_absolute_error: 0.2908 - val_acc: 0.7031 - val_loss_no_weight_decay: 0.4572
#
# Epoch 00021: val_acc did not improve from 0.85938
# Confusion matrix:
#  [[33 15]
#  [ 0 16]]
# Epoch 22/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.3818 - mean_absolute_error: 0.2670 - acc: 0.8333 - loss_no_weight_decay: 0.3818 - val_loss: 0.2413 - val_mean_absolute_error: 0.1909 - val_acc: 0.9286 - val_loss_no_weight_decay: 0.2413
#
# Epoch 00022: val_acc improved from 0.85938 to 0.92857, saving model to base_2020-05-11-21-58-12-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[9 2]
#  [0 3]]
# Epoch 23/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.3353 - mean_absolute_error: 0.2338 - acc: 0.8443 - loss_no_weight_decay: 0.3353 - val_loss: 0.6468 - val_mean_absolute_error: 0.3263 - val_acc: 0.7031 - val_loss_no_weight_decay: 0.6468
#
# Epoch 00023: val_acc did not improve from 0.92857
# Confusion matrix:
#  [[26 20]
#  [ 0 18]]
# Epoch 24/35
# 9/9 [==============================] - 16s 2s/step - loss: 0.3750 - mean_absolute_error: 0.2464 - acc: 0.8385 - loss_no_weight_decay: 0.3750 - val_loss: 0.5758 - val_mean_absolute_error: 0.3527 - val_acc: 0.7143 - val_loss_no_weight_decay: 0.5758
#
# Epoch 00024: val_acc did not improve from 0.92857
# Confusion matrix:
#  [[8 3]
#  [0 3]]
# Epoch 25/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.2992 - mean_absolute_error: 0.2195 - acc: 0.8834 - loss_no_weight_decay: 0.2992 - val_loss: 0.2403 - val_mean_absolute_error: 0.1904 - val_acc: 0.9375 - val_loss_no_weight_decay: 0.2403
#
# Epoch 00025: val_acc improved from 0.92857 to 0.93750, saving model to base_2020-05-11-21-58-12-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[44  5]
#  [ 1 14]]
# Epoch 26/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.2670 - mean_absolute_error: 0.1933 - acc: 0.9017 - loss_no_weight_decay: 0.2670 - val_loss: 0.2389 - val_mean_absolute_error: 0.1707 - val_acc: 0.8571 - val_loss_no_weight_decay: 0.2389
#
# Epoch 00026: val_acc did not improve from 0.93750
# Confusion matrix:
#  [[7 2]
#  [0 5]]
# Epoch 27/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.2765 - mean_absolute_error: 0.1897 - acc: 0.8876 - loss_no_weight_decay: 0.2765 - val_loss: 0.2470 - val_mean_absolute_error: 0.1705 - val_acc: 0.8750 - val_loss_no_weight_decay: 0.2470
#
# Epoch 00027: val_acc did not improve from 0.93750
# Confusion matrix:
#  [[49  1]
#  [ 6  8]]
# Epoch 28/35
# 9/9 [==============================] - 16s 2s/step - loss: 0.3653 - mean_absolute_error: 0.2272 - acc: 0.8438 - loss_no_weight_decay: 0.3653 - val_loss: 0.2228 - val_mean_absolute_error: 0.1611 - val_acc: 0.8571 - val_loss_no_weight_decay: 0.2228
#
# Epoch 00028: val_acc did not improve from 0.93750
# Confusion matrix:
#  [[10  1]
#  [ 0  3]]
# Epoch 29/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.2682 - mean_absolute_error: 0.1899 - acc: 0.9084 - loss_no_weight_decay: 0.2682 - val_loss: 0.6928 - val_mean_absolute_error: 0.3492 - val_acc: 0.6250 - val_loss_no_weight_decay: 0.6928
#
# Epoch 00029: val_acc did not improve from 0.93750
# Confusion matrix:
#  [[24 25]
#  [ 0 15]]
# Epoch 30/35
# 9/9 [==============================] - 16s 2s/step - loss: 0.2937 - mean_absolute_error: 0.2040 - acc: 0.8733 - loss_no_weight_decay: 0.2937 - val_loss: 0.2910 - val_mean_absolute_error: 0.2062 - val_acc: 0.8571 - val_loss_no_weight_decay: 0.2910
#
# Epoch 00030: val_acc did not improve from 0.93750
# Confusion matrix:
#  [[6 1]
#  [0 7]]
# Epoch 31/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.2306 - mean_absolute_error: 0.1729 - acc: 0.9219 - loss_no_weight_decay: 0.2306 - val_loss: 0.3026 - val_mean_absolute_error: 0.2027 - val_acc: 0.8438 - val_loss_no_weight_decay: 0.3026
#
# Epoch 00031: val_acc did not improve from 0.93750
# Confusion matrix:
#  [[45  6]
#  [ 0 13]]
# Epoch 32/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.2638 - mean_absolute_error: 0.1821 - acc: 0.8941 - loss_no_weight_decay: 0.2638 - val_loss: 0.1727 - val_mean_absolute_error: 0.1396 - val_acc: 0.9286 - val_loss_no_weight_decay: 0.1727
#
# Epoch 00032: val_acc did not improve from 0.93750
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Confusion matrix:
#  [[6 2]
#  [0 6]]
# Epoch 33/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.2054 - mean_absolute_error: 0.1505 - acc: 0.9315 - loss_no_weight_decay: 0.2054 - val_loss: 0.3111 - val_mean_absolute_error: 0.1997 - val_acc: 0.8438 - val_loss_no_weight_decay: 0.3111
#
# Epoch 00033: val_acc did not improve from 0.93750
# Confusion matrix:
#  [[37 11]
#  [ 0 16]]
# Epoch 34/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.1717 - mean_absolute_error: 0.1277 - acc: 0.9491 - loss_no_weight_decay: 0.1717 - val_loss: 0.2304 - val_mean_absolute_error: 0.1535 - val_acc: 0.8571 - val_loss_no_weight_decay: 0.2304
#
# Epoch 00034: val_acc did not improve from 0.93750
# Confusion matrix:
#  [[11  1]
#  [ 0  2]]
# Epoch 35/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.1740 - mean_absolute_error: 0.1272 - acc: 0.9421 - loss_no_weight_decay: 0.1740 - val_loss: 0.2386 - val_mean_absolute_error: 0.1599 - val_acc: 0.8594 - val_loss_no_weight_decay: 0.2386
#
# Epoch 00035: val_acc did not improve from 0.93750
# Confusion matrix:
#  [[42  6]
#  [ 0 16]]
# 121/121 [==============================] - 5s 39ms/step
# 121/121 [==============================] - 5s 37ms/step
# Test loss: 0.19652688595387421
# Test accuracy: 0.13548237496307736
# Confusion Matrix
# [[84  4]
#  [ 2 31]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.97        88
#            1       0.89      0.94      0.91        33
#
#     accuracy                           0.95       121
#    macro avg       0.93      0.95      0.94       121
# weighted avg       0.95      0.95      0.95       121

# %%
import numpy as np 
import matplotlib.pyplot as plt
import os
import wandb
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_mean_absolute_error', 'val_acc', 'val_loss_no_weight_decay', 'loss', 'mean_absolute_error', 'acc', 'loss_no_weight_decay', 'lr'])

# %%
from Kappa_Skl import kappa
def kappa2(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    if len(y_true.shape) > 1 and y_true.shape[1] > 1:
        y_true = y_true.dot(range(y_true.shape[1]))
    if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
        y_pred = y_pred.dot(range(y_pred.shape[1]))
    try:
        return kappa(y_true, y_pred, weights='quadratic')
    except IndexError:
        return np.nan
    
print('Quadratic_wieghted_kappa')
print(kappa2(y_true, y_pred))
# Out:
# Quadratic_wieghted_kappa
# 0.8773234200743494
