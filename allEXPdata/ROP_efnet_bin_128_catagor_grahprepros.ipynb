# %%
import efficientnet.keras as efn
from keras.models import Model, model_from_json
from keras.regularizers import l1_l2
from keras.layers import Dense, Dropout
from keras.optimizers import SGD, Adam
import pandas as pd
from keras_preprocessing.image import ImageDataGenerator
from datetime import datetime as dt
from sklearn.utils import class_weight
from keras.callbacks import EarlyStopping, ModelCheckpoint,LearningRateScheduler, TensorBoard
import keras.backend as K
from VCM import VCM 
from keras.initializers import Constant,Orthogonal
from keras import regularizers
from Kappa_Skl import kappa
import keras.backend as K
import matplotlib.pyplot as plt
import itertools
from Homotopy import Homotopy 
from QWK import QWK
import tensorflow as tf
from Fractional_MAXPOOL import FractionalPooling2D

import numpy as np 
import matplotlib.pyplot as plt
import os
import wandb
#from wandb.keras import WandbCallback
#wandb.init(project="rop")


top_layers_checkpoint_path = 'cp.top.best.hdf5'
fine_tuned_checkpoint_path = 'cp.fine_tuned.best.hdf5'
new_extended_inception_weights = 'final_weights.hdf5'





def get_experiment_id():
    time_str = dt.now().strftime('%Y-%m-%d-%H-%M-%S')
    experiment_id = 'base_{}'.format(time_str)
    return experiment_id

#def scheduler(epoch):
#    if epoch == 150:
#        K.set_value(model.optimizer.lr, 0.00003)
#    return K.get_value(model.optimizer.lr)


def create_model():
    base_model = efn.EfficientNetB0(weights=None,
                        include_top=False,
                        input_shape=(128, 128, 3), pooling='avg')
#    base_model._layers.pop()
#    model2 = Model(base_model.input, base_model.layers[-1].output)
##    base_model = InceptionV3(weights=None , include_top=False, input_tensor=None, input_shape=(299, 299, 3), pooling='avg') 
    x = base_model.output
    x = Dense(2, activation="softmax")(x)
    model = Model(inputs = base_model.input, outputs = x)
    model.load_weights('base_2019-12-11-23-01-58-val_kappa_checkpoint.hdf5')
#    model._layers.pop()
#    x = Model(model.input, model.layers[-1].output)
#    model.save_weights("tmp.h5")
#    top_layers_checkpoint_path = 'cp.top.best.hdf5'

#    # first: train only the top layers (which were randomly initialized)
#    # i.e. freeze all convolutional InceptionV3 layers
    for layer in base_model.layers:
        layer.trainable = False
#    
#    
#
##    regularizer = l1_l2(l1=0.0005, l2=0.0005)
##    for layer in model.layers:
##        for attr in ['kernel_regularizer', 'bias_regularizer']:
##            if hasattr(layer, attr) and layer.trainable:
##                setattr(layer, attr, regularizer)
#
##
#    out = model_from_json(model.to_json())
#    out.load_weights("tmp.h5", by_name=True)
#
    return model


model = create_model()




radam = Adam(lr=0.0014339, beta_1=0.9, beta_2=0.999, epsilon=0.1, decay=1e-6, amsgrad=False)
model.compile(loss='categorical_crossentropy', optimizer=radam, metrics=['mae','acc'])

#sgd = SGD(lr=0.0003, decay=1e-6, momentum=0.9, nesterov=True)
#model.compile(loss='mse', optimizer=sgd, metrics=['mae', 'acc'])

experiment_id = get_experiment_id()


train_datagen = ImageDataGenerator(
        rescale=1./255,
#        featurewise_center=True,
 #       samplewise_center=True,
        shear_range=0,
        zoom_range=0.0,#[1 / 1.15, 1.15],
        horizontal_flip=False,#True,
        rotation_range=0)#90,
#        validation_split=0.2)
"""
For the test set only rescale should be made 
"""
test_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas_grah/train",
    target_size=(128, 128),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="training")
#    save_to_dir="D:/Separating Images into subfolders/train_augmented")


#print(train_generator.class_indices)

valid_generator = valid_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas_grah/vald",
    target_size=(128, 128),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="validation")
#    save_to_dir="D:/Separating Images into subfolders/val_augmented"


test_generator = test_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas_grah/test",
    target_size=(128, 128),
    color_mode="rgb",
    batch_size=1,
    class_mode="categorical",
    shuffle=False,
    seed=42)
#    save_to_dir="D:/Separating Images into subfolders/test_augmented")


# Fitting/Training the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
experiment_id = get_experiment_id()


class_weight_list = class_weight.compute_class_weight('balanced', np.unique(train_generator.classes), train_generator.classes)
class_weights = dict(zip(np.unique(train_generator.classes), class_weight_list))

callbacks = [
#    Resample_Iterator(balance_weights),
    QWK(valid_generator, STEP_SIZE_VALID),
    ModelCheckpoint(top_layers_checkpoint_path, monitor='val_kappa', verbose=1, save_best_only=True, mode='max'),
#    EarlyStopping(monitor='val_kappa', patience=10, min_delta=0.001, verbose=1, restore_best_weights=True, mode='max',baseline=None),
    VCM(valid_generator, STEP_SIZE_VALID),
#    LearningRateScheduler(scheduler, verbose=1),
 #   TensorBoard(log_dir='./Graph', histogram_freq=0, write_graph=True, write_images=True),        
]




# train the model on the new data for a few epochs

history1=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
#                    class_weight=[balance_weights],
                    callbacks=callbacks,
                    epochs=10  
)


 

callbacks1 = [
#    Resample_Iterator(balance_weights1),
    QWK(valid_generator, STEP_SIZE_VALID),
    ModelCheckpoint(fine_tuned_checkpoint_path, monitor='val_kappa', verbose=1, save_best_only=True, mode='max'),
#    EarlyStopping(monitor='val_kappa', patience=20, min_delta=0.001, verbose=1, restore_best_weights=True, mode='max',baseline=None),
    VCM(valid_generator, STEP_SIZE_VALID),
#    LearningRateScheduler(scheduler, verbose=1),
#    TensorBoard(log_dir='./Graph', histogram_freq=0, write_graph=True, write_images=True),        
]



for layer in model.layers:
    layer.trainable = True
    
    
    
    
radam = Adam(lr=0.0014339, beta_1=0.9, beta_2=0.999, epsilon=0.1, decay=1e-6, amsgrad=False)
model.compile(loss='categorical_crossentropy', optimizer=radam, metrics=['mae','acc'])



# we train our model again (this time fine-tuning the top 2 inception blocks
# alongside the top Dense layers
history=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
#                    class_weight=[balance_weights1],
                    callbacks=callbacks1,
                    epochs=30) 




test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1']
print(classification_report(y_true, y_pred, target_names=target_names))
                    
                    
# list all data in history
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model loss.png')

# summarize history for val_kappa
plt.plot(history.history['val_kappa'])
plt.title('Validation_Kappa')
plt.ylabel('val_kappa')
plt.xlabel('epoch')
plt.legend([ 'validation'], loc='upper left')
plt.show()
#plt.savefig('model validation_kappa.png')

# summarize history for mean_absolute _error
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model mean_absolute_error')
plt.ylabel('mean_absolute_error')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model maey.png')
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Found 588 images belonging to 2 classes.
# Found 116 images belonging to 2 classes.
# Found 176 images belonging to 2 classes.
# Epoch 1/10
# 9/9 [==============================] - 4s 433ms/step - loss: 0.9172 - mean_absolute_error: 0.4370 - acc: 0.5787 - val_loss: 1.2072 - val_mean_absolute_error: 0.6301 - val_acc: 0.2969
# — val_kappa: -0.65625
#
# Epoch 00001: val_kappa improved from -inf to -0.65625, saving model to cp.top.best.hdf5
# Confusion matrix:
#  [[20  6]
#  [25  1]]
# Epoch 2/10
# 9/9 [==============================] - 2s 187ms/step - loss: 0.8967 - mean_absolute_error: 0.4312 - acc: 0.5940 - val_loss: 1.2443 - val_mean_absolute_error: 0.6462 - val_acc: 0.2500
# — val_kappa: -0.40625
#
# Epoch 00002: val_kappa improved from -0.65625 to -0.40625, saving model to cp.top.best.hdf5
# Confusion matrix:
#  [[12 15]
#  [25  0]]
# Epoch 3/10
# 9/9 [==============================] - 2s 176ms/step - loss: 0.8188 - mean_absolute_error: 0.4307 - acc: 0.5868 - val_loss: 1.2710 - val_mean_absolute_error: 0.6481 - val_acc: 0.2656
# — val_kappa: -0.375
#
# Epoch 00003: val_kappa improved from -0.40625 to -0.37500, saving model to cp.top.best.hdf5
# Confusion matrix:
#  [[ 9 13]
#  [29  1]]
# Epoch 4/10
# 9/9 [==============================] - 1s 131ms/step - loss: 0.8251 - mean_absolute_error: 0.4328 - acc: 0.5720 - val_loss: 1.2561 - val_mean_absolute_error: 0.6651 - val_acc: 0.2115
# — val_kappa: -0.46875
#
# Epoch 00004: val_kappa did not improve from -0.37500
# Confusion matrix:
#  [[12 15]
#  [25  0]]
# Epoch 5/10
# 9/9 [==============================] - 1s 139ms/step - loss: 0.7202 - mean_absolute_error: 0.4081 - acc: 0.6140 - val_loss: 1.2248 - val_mean_absolute_error: 0.6482 - val_acc: 0.2812
# — val_kappa: -0.46875
#
# Epoch 00005: val_kappa did not improve from -0.37500
# Confusion matrix:
#  [[13 15]
#  [24  0]]
# Epoch 6/10
# 9/9 [==============================] - 1s 135ms/step - loss: 0.6623 - mean_absolute_error: 0.3890 - acc: 0.6623 - val_loss: 1.2472 - val_mean_absolute_error: 0.6462 - val_acc: 0.2308
# — val_kappa: -0.53125
#
# Epoch 00006: val_kappa did not improve from -0.37500
# Confusion matrix:
#  [[15 14]
#  [23  0]]
# Epoch 7/10
# 9/9 [==============================] - 1s 157ms/step - loss: 0.6262 - mean_absolute_error: 0.3835 - acc: 0.6771 - val_loss: 1.3586 - val_mean_absolute_error: 0.6856 - val_acc: 0.2031
# — val_kappa: -0.625
#
# Epoch 00007: val_kappa did not improve from -0.37500
# Confusion matrix:
#  [[18 11]
#  [23  0]]
# Epoch 8/10
# 9/9 [==============================] - 1s 133ms/step - loss: 0.5286 - mean_absolute_error: 0.3520 - acc: 0.7360 - val_loss: 1.2138 - val_mean_absolute_error: 0.6360 - val_acc: 0.2885
# — val_kappa: -0.53125
#
# Epoch 00008: val_kappa did not improve from -0.37500
# Confusion matrix:
#  [[15 13]
#  [24  0]]
# Epoch 9/10
# 9/9 [==============================] - 1s 137ms/step - loss: 0.5488 - mean_absolute_error: 0.3585 - acc: 0.7117 - val_loss: 1.2191 - val_mean_absolute_error: 0.6400 - val_acc: 0.2500
# — val_kappa: -0.53125
#
# Epoch 00009: val_kappa did not improve from -0.37500
# Confusion matrix:
#  [[15 11]
#  [26  0]]
# Epoch 10/10
# 9/9 [==============================] - 1s 123ms/step - loss: 0.4978 - mean_absolute_error: 0.3321 - acc: 0.7410 - val_loss: 1.1762 - val_mean_absolute_error: 0.6286 - val_acc: 0.2885
# — val_kappa: -0.65625
#
# Epoch 00010: val_kappa did not improve from -0.37500
# Confusion matrix:
#  [[18 11]
#  [22  1]]
# Epoch 1/30
# 9/9 [==============================] - 12s 1s/step - loss: 0.4959 - mean_absolute_error: 0.3349 - acc: 0.7570 - val_loss: 0.4693 - val_mean_absolute_error: 0.3043 - val_acc: 0.7969
# — val_kappa: 0.5625
#
# Epoch 00001: val_kappa improved from -inf to 0.56250, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  [[21  5]
#  [ 6 20]]
# Epoch 2/30
# 9/9 [==============================] - 3s 280ms/step - loss: 0.4280 - mean_absolute_error: 0.3028 - acc: 0.8028 - val_loss: 0.4140 - val_mean_absolute_error: 0.2787 - val_acc: 0.7692
# — val_kappa: 0.5625
#
# Epoch 00002: val_kappa did not improve from 0.56250
# Confusion matrix:
#  [[20  2]
#  [ 8 22]]
# Epoch 3/30
# 9/9 [==============================] - 3s 305ms/step - loss: 0.3920 - mean_absolute_error: 0.2813 - acc: 0.8420 - val_loss: 0.3367 - val_mean_absolute_error: 0.2399 - val_acc: 0.8906
# — val_kappa: 0.6875
#
# Epoch 00003: val_kappa improved from 0.56250 to 0.68750, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  [[19  2]
#  [ 5 26]]
# Epoch 4/30
# 9/9 [==============================] - 2s 267ms/step - loss: 0.3673 - mean_absolute_error: 0.2599 - acc: 0.8565 - val_loss: 0.3052 - val_mean_absolute_error: 0.2203 - val_acc: 0.8846
# — val_kappa: 0.71875
#
# Epoch 00004: val_kappa improved from 0.68750 to 0.71875, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  [[24  5]
#  [ 3 20]]
# Epoch 5/30
# 9/9 [==============================] - 3s 315ms/step - loss: 0.3033 - mean_absolute_error: 0.2285 - acc: 0.8924 - val_loss: 0.2405 - val_mean_absolute_error: 0.1730 - val_acc: 0.9219
# — val_kappa: 0.71875
#
# Epoch 00005: val_kappa did not improve from 0.71875
# Confusion matrix:
#  [[24  3]
#  [ 2 23]]
# Epoch 6/30
# 9/9 [==============================] - 3s 286ms/step - loss: 0.2763 - mean_absolute_error: 0.2134 - acc: 0.8990 - val_loss: 0.2872 - val_mean_absolute_error: 0.1982 - val_acc: 0.8846
# — val_kappa: 0.84375
#
# Epoch 00006: val_kappa improved from 0.71875 to 0.84375, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  [[22  3]
#  [ 5 22]]
# Epoch 7/30
# 9/9 [==============================] - 3s 301ms/step - loss: 0.2181 - mean_absolute_error: 0.1757 - acc: 0.9456 - val_loss: 0.1998 - val_mean_absolute_error: 0.1498 - val_acc: 0.9219
# — val_kappa: 0.90625
#
# Epoch 00007: val_kappa improved from 0.84375 to 0.90625, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  [[21  1]
#  [ 6 24]]
# Epoch 8/30
# 9/9 [==============================] - 3s 284ms/step - loss: 0.2020 - mean_absolute_error: 0.1626 - acc: 0.9579 - val_loss: 0.2478 - val_mean_absolute_error: 0.1820 - val_acc: 0.8654
# — val_kappa: 0.875
#
# Epoch 00008: val_kappa did not improve from 0.90625
# Confusion matrix:
#  [[24  1]
#  [ 6 21]]
# Epoch 9/30
# 9/9 [==============================] - 2s 261ms/step - loss: 0.1792 - mean_absolute_error: 0.1490 - acc: 0.9737 - val_loss: 0.1654 - val_mean_absolute_error: 0.1234 - val_acc: 0.9688
# — val_kappa: 0.8125
#
# Epoch 00009: val_kappa did not improve from 0.90625
# Confusion matrix:
#  [[25  0]
#  [ 3 24]]
# Epoch 10/30
# 9/9 [==============================] - 3s 308ms/step - loss: 0.1690 - mean_absolute_error: 0.1354 - acc: 0.9688 - val_loss: 0.2089 - val_mean_absolute_error: 0.1531 - val_acc: 0.9038
# — val_kappa: 0.875
#
# Epoch 00010: val_kappa did not improve from 0.90625
# Confusion matrix:
#  [[30  1]
#  [ 2 19]]
# Epoch 11/30
# 9/9 [==============================] - 3s 286ms/step - loss: 0.1554 - mean_absolute_error: 0.1266 - acc: 0.9619 - val_loss: 0.1155 - val_mean_absolute_error: 0.0955 - val_acc: 0.9688
# — val_kappa: 0.875
#
# Epoch 00011: val_kappa did not improve from 0.90625
# Confusion matrix:
#  [[27  0]
#  [ 3 22]]
# Epoch 12/30
# 9/9 [==============================] - 3s 282ms/step - loss: 0.1482 - mean_absolute_error: 0.1171 - acc: 0.9602 - val_loss: 0.1472 - val_mean_absolute_error: 0.1134 - val_acc: 0.9423
# — val_kappa: 0.875
#
# Epoch 00012: val_kappa did not improve from 0.90625
# Confusion matrix:
#  [[29  0]
#  [ 3 20]]
# Epoch 13/30
# 9/9 [==============================] - 3s 284ms/step - loss: 0.1056 - mean_absolute_error: 0.0922 - acc: 0.9880 - val_loss: 0.1405 - val_mean_absolute_error: 0.1064 - val_acc: 0.9531
# — val_kappa: 0.90625
#
# Epoch 00013: val_kappa did not improve from 0.90625
# Confusion matrix:
#  [[28  0]
#  [ 2 22]]
# Epoch 14/30
# 9/9 [==============================] - 3s 284ms/step - loss: 0.1213 - mean_absolute_error: 0.0997 - acc: 0.9774 - val_loss: 0.1161 - val_mean_absolute_error: 0.0881 - val_acc: 0.9423
# — val_kappa: 0.875
#
# Epoch 00014: val_kappa did not improve from 0.90625
# Confusion matrix:
#  [[27  0]
#  [ 2 23]]
# Epoch 15/30
# 9/9 [==============================] - 3s 305ms/step - loss: 0.0938 - mean_absolute_error: 0.0778 - acc: 0.9861 - val_loss: 0.1337 - val_mean_absolute_error: 0.1058 - val_acc: 0.9531
# — val_kappa: 0.9375
#
# Epoch 00015: val_kappa improved from 0.90625 to 0.93750, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  [[25  0]
#  [ 3 24]]
# Epoch 16/30
# 9/9 [==============================] - 2s 253ms/step - loss: 0.0881 - mean_absolute_error: 0.0763 - acc: 0.9911 - val_loss: 0.1248 - val_mean_absolute_error: 0.0844 - val_acc: 0.9615
# — val_kappa: 0.90625
#
# Epoch 00016: val_kappa did not improve from 0.93750
# Confusion matrix:
#  [[25  0]
#  [ 2 25]]
# Epoch 17/30
# 9/9 [==============================] - 3s 303ms/step - loss: 0.0896 - mean_absolute_error: 0.0763 - acc: 0.9878 - val_loss: 0.1163 - val_mean_absolute_error: 0.0804 - val_acc: 0.9531
# — val_kappa: 0.84375
#
# Epoch 00017: val_kappa did not improve from 0.93750
# Confusion matrix:
#  [[25  0]
#  [ 0 27]]
# Epoch 18/30
# 9/9 [==============================] - 3s 291ms/step - loss: 0.0705 - mean_absolute_error: 0.0616 - acc: 0.9947 - val_loss: 0.1264 - val_mean_absolute_error: 0.1034 - val_acc: 0.9808
# — val_kappa: 0.90625
#
# Epoch 00018: val_kappa did not improve from 0.93750
# Confusion matrix:
#  [[30  0]
#  [ 1 21]]
# Epoch 19/30
# 9/9 [==============================] - 3s 281ms/step - loss: 0.0857 - mean_absolute_error: 0.0705 - acc: 0.9912 - val_loss: 0.0983 - val_mean_absolute_error: 0.0794 - val_acc: 0.9844
# — val_kappa: 0.9375
#
# Epoch 00019: val_kappa did not improve from 0.93750
# Confusion matrix:
#  [[29  0]
#  [ 1 22]]
# Epoch 20/30
# 9/9 [==============================] - 3s 278ms/step - loss: 0.0712 - mean_absolute_error: 0.0606 - acc: 0.9912 - val_loss: 0.0694 - val_mean_absolute_error: 0.0574 - val_acc: 0.9808
# — val_kappa: 0.9375
#
# Epoch 00020: val_kappa did not improve from 0.93750
# Confusion matrix:
#  [[25  0]
#  [ 1 26]]
# Epoch 21/30
# 9/9 [==============================] - 3s 279ms/step - loss: 0.0819 - mean_absolute_error: 0.0671 - acc: 0.9827 - val_loss: 0.0606 - val_mean_absolute_error: 0.0515 - val_acc: 0.9844
# — val_kappa: 0.96875
#
# Epoch 00021: val_kappa improved from 0.93750 to 0.96875, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  [[28  0]
#  [ 2 22]]
# Epoch 22/30
# 9/9 [==============================] - 3s 289ms/step - loss: 0.0640 - mean_absolute_error: 0.0568 - acc: 0.9947 - val_loss: 0.1185 - val_mean_absolute_error: 0.0803 - val_acc: 0.9808
# — val_kappa: 0.96875
#
# Epoch 00022: val_kappa did not improve from 0.96875
# Confusion matrix:
#  [[27  0]
#  [ 2 23]]
# Epoch 23/30
# 9/9 [==============================] - 3s 298ms/step - loss: 0.0706 - mean_absolute_error: 0.0588 - acc: 0.9810 - val_loss: 0.0745 - val_mean_absolute_error: 0.0604 - val_acc: 0.9844
# — val_kappa: 0.90625
#
# Epoch 00023: val_kappa did not improve from 0.96875
# Confusion matrix:
#  [[28  0]
#  [ 0 24]]
# Epoch 24/30
# 9/9 [==============================] - 3s 316ms/step - loss: 0.0517 - mean_absolute_error: 0.0443 - acc: 0.9931 - val_loss: 0.0956 - val_mean_absolute_error: 0.0777 - val_acc: 0.9615
# — val_kappa: 0.9375
#
# Epoch 00024: val_kappa did not improve from 0.96875
# Confusion matrix:
#  [[25  0]
#  [ 2 25]]
# Epoch 25/30
# 9/9 [==============================] - 3s 289ms/step - loss: 0.0474 - mean_absolute_error: 0.0431 - acc: 0.9965 - val_loss: 0.0985 - val_mean_absolute_error: 0.0682 - val_acc: 0.9844
# — val_kappa: 1.0
#
# Epoch 00025: val_kappa improved from 0.96875 to 1.00000, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  [[26  0]
#  [ 2 24]]
# Epoch 26/30
# 9/9 [==============================] - 3s 285ms/step - loss: 0.0592 - mean_absolute_error: 0.0471 - acc: 0.9897 - val_loss: 0.0670 - val_mean_absolute_error: 0.0552 - val_acc: 0.9808
# — val_kappa: 1.0
#
# Epoch 00026: val_kappa did not improve from 1.00000
# Confusion matrix:
#  [[21  0]
#  [ 2 29]]
# Epoch 27/30
# 9/9 [==============================] - 2s 262ms/step - loss: 0.0508 - mean_absolute_error: 0.0452 - acc: 0.9947 - val_loss: 0.0911 - val_mean_absolute_error: 0.0622 - val_acc: 0.9844
# — val_kappa: 1.0
#
# Epoch 00027: val_kappa did not improve from 1.00000
# Confusion matrix:
#  [[27  0]
#  [ 2 23]]
# Epoch 28/30
# 9/9 [==============================] - 3s 306ms/step - loss: 0.0429 - mean_absolute_error: 0.0363 - acc: 0.9983 - val_loss: 0.1153 - val_mean_absolute_error: 0.0773 - val_acc: 0.9615
# — val_kappa: 0.9375
#
# Epoch 00028: val_kappa did not improve from 1.00000
# Confusion matrix:
#  [[25  0]
#  [ 0 27]]
# Epoch 29/30
# 9/9 [==============================] - 3s 287ms/step - loss: 0.0416 - mean_absolute_error: 0.0376 - acc: 0.9982 - val_loss: 0.0940 - val_mean_absolute_error: 0.0636 - val_acc: 0.9844
# — val_kappa: 0.9375
#
# Epoch 00029: val_kappa did not improve from 1.00000
# Confusion matrix:
#  [[24  0]
#  [ 0 28]]
# Epoch 30/30
# 9/9 [==============================] - 3s 288ms/step - loss: 0.0343 - mean_absolute_error: 0.0317 - acc: 0.9982 - val_loss: 0.0674 - val_mean_absolute_error: 0.0581 - val_acc: 1.0000
# — val_kappa: 0.96875
#
# Epoch 00030: val_kappa did not improve from 1.00000
# Confusion matrix:
#  [[22  0]
#  [ 1 29]]
# 176/176 [==============================] - 2s 9ms/step
# 176/176 [==============================] - 2s 9ms/step
# Test loss: 0.0672580751081155
# Test accuracy: 0.051467168415890475
# Confusion Matrix
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-93bf87759ea5> in <module>
#     246 # generator.classes gives you the truth label y_true
#     247 print('Confusion Matrix')
# --> 248 cm = confusion_matrix(y_true, y_pred)
#     249
#     250 print(cm)
#
# NameError: name 'confusion_matrix' is not defined

# %%
from sklearn.metrics import confusion_matrix, classification_report

test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# 176/176 [==============================] - 2s 9ms/step
# 176/176 [==============================] - 2s 9ms/step
# Test loss: 0.0672580751081155
# Test accuracy: 0.051467168415890475
# Confusion Matrix
# [[87  1]
#  [ 1 87]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99        88
#            1       0.99      0.99      0.99        88
#
#     accuracy                           0.99       176
#    macro avg       0.99      0.99      0.99       176
# weighted avg       0.99      0.99      0.99       176

# %%
def kappa2(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    if len(y_true.shape) > 1 and y_true.shape[1] > 1:
        y_true = y_true.dot(range(y_true.shape[1]))
    if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
        y_pred = y_pred.dot(range(y_pred.shape[1]))
    try:
        return kappa(y_true, y_pred, weights='quadratic')
    except IndexError:
        return np.nan
    
print('Quadratic_wieghted_kappa')
print(kappa2(y_true, y_pred))
# Out:
# Quadratic_wieghted_kappa
# 0.9772727272727273

# %%
# list all data in history
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model loss.png')

# summarize history for val_kappa
plt.plot(history.history['val_kappa'])
plt.title('Validation_Kappa')
plt.ylabel('val_kappa')
plt.xlabel('epoch')
plt.legend([ 'validation'], loc='upper left')
plt.show()
#plt.savefig('model validation_kappa.png')

# summarize history for mean_absolute _error
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model mean_absolute_error')
plt.ylabel('mean_absolute_error')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model maey.png')
# Out:
# dict_keys(['val_loss', 'val_mean_absolute_error', 'val_acc', 'loss', 'mean_absolute_error', 'acc', 'val_kappa'])
