# %%
import keras
from keras.models import Sequential, Input, Model
from keras.losses import mean_squared_error
from keras.layers import  *
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, InputLayer
from keras.regularizers import L1L2, l2, l1
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from custom_pooling import RMSPooling2D
from keras.optimizers import SGD, Adam
from keras.layers import LeakyReLU
#from data import BALANCE_WEIGHTS
from keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
#import os
from datetime import datetime as dt
from custom_loss import WeightedCategoricalCrossEntropy
from VCM import VCM
import keras.backend as K
from Fractional_MAXPOOL import FractionalPooling2D
from QWK import QWK
import tensorflow as tf
from Fractional_MAXPOOL import FractionalPooling2D

import numpy as np 
import matplotlib.pyplot as plt
import os
import wandb
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
def get_experiment_id():
    time_str = dt.now().strftime('%Y-%m-%d-%H-%M-%S')
    experiment_id = 'base_{}'.format(time_str)
    return experiment_id
p_ratio=[1.0, 1.44, 1.73, 1.0]

model = Sequential()


model.add(Conv2D(16, (5, 5), activation='relu', input_shape=(270, 270, 3)))
model.add(Conv2D(16, (5, 5), activation='relu'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(16, (3, 3), activation='relu'))
model.add(Conv2D(16, (3, 3), activation='relu'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

#model.add(LeakyReLU(alpha=0.01))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))


model.add(Conv2D(16, (5, 5), activation='relu'))
model.add(Conv2D(16, (5, 5), activation='relu'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))


model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))
model.add(Conv2D(16, (5, 5), activation='relu'))
model.add(Conv2D(16, (5, 5), activation='relu'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))


#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(Conv2D(32, (3, 3), activation='relu'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(Conv2D(64, (3, 3), activation='relu'))

model.add(Conv2D(64, (3, 3), activation='relu'))

model.add(FractionalPooling2D(pool_ratio=(1, 1.7, 1.7, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(Conv2D(64, (3, 3), activation='relu'))

#model.add(MaxPooling2D(pool_size=1))


model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))




model.add(Flatten())


#chnaged from 10 to 5 because an error 
model.add(Dense(2, activation='softmax'))

sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.count_params()
#adam = Adam(lr=0.0005, decay=1e-6)
#rmsprop
#Mloss = WeightedCategoricalCrossEntropy({0: 0.4125861396437394, 1: 1.4918664786083686, 2: 0.690426457789382, 3: 3.9541433021806855, 4: 4.885604311008468})
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['acc','mae'])
model.summary()
loss_no_weight_decay = model.total_loss - sum(model.losses)
model.metrics_tensors.append(loss_no_weight_decay)
model.metrics_names.append('loss_no_weight_decay')
#############################################################################################
#############################################################################################
#############################################################################################
#############################################################################################
#Preparing Data Augmentation Configuration 
train_datagen = ImageDataGenerator(
        rescale=1./255,
#        featurewise_center=True,
 #       samplewise_center=True,
        shear_range=0,
        zoom_range=0.0,#[1 / 1.15, 1.15],
        horizontal_flip=False,#True,
        rotation_range=0)#90,
#        validation_split=0.2)
"""
For the test set only rescale should be made 
"""
test_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/grahprepross/bin_bal/train",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=32,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="training")
#    save_to_dir="D:/Separating Images into subfolders/train_augmented")


#print(train_generator.class_indices)

valid_generator = valid_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/grahprepross/bin_bal/vald",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=32,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="validation")
#    save_to_dir="D:/Separating Images into subfolders/val_augmented"


test_generator = test_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/grahprepross/bin_bal/test",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=1,
    class_mode="categorical",
    shuffle=False,
    seed=42)
#    save_to_dir="D:/Separating Images into subfolders/test_augmented")


# Fitting/Training the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
experiment_id = get_experiment_id()
callbacks = [
    EarlyStopping(monitor='val_acc', patience=10, min_delta=0.001, verbose=1),
    ModelCheckpoint(experiment_id + "-val_acc_checkpoint.hdf5", monitor='val_acc', verbose=1, save_best_only=True, mode='max'),
    ReduceLROnPlateau(monitor='val_acc', factor=0.5, patience=7, verbose=1, mode='auto', min_delta=0.001, cooldown=0, min_lr=1e-7),
    VCM(valid_generator,STEP_SIZE_VALID)
    
]

class_weight_list = class_weight.compute_class_weight('balanced', np.unique(train_generator.classes), train_generator.classes)
class_weights = dict(zip(np.unique(train_generator.classes), class_weight_list))

history=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    #class_weight=class_weights,
                    callbacks=callbacks,
                    epochs=35  
)


# Evaluating the model 
#predicting output
#reseting the test generator before calling predict_generator, in order not to get weird output
test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 266, 266, 16)      1216
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 262, 262, 16)      6416
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 260, 260, 16)      2320
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 258, 258, 16)      2320
# _________________________________________________________________
# fractional_pooling2d_1 (Frac (None, 143, 143, 16)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 139, 139, 16)      6416
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 135, 135, 16)      6416
# _________________________________________________________________
# fractional_pooling2d_2 (Frac (None, 75, 75, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 71, 71, 16)        6416
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 67, 67, 16)        6416
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 65, 65, 32)        4640
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 63, 63, 32)        9248
# _________________________________________________________________
# fractional_pooling2d_3 (Frac (None, 35, 35, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 33, 33, 64)        18496
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 31, 31, 64)        36928
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 29, 29, 64)        36928
# _________________________________________________________________
# fractional_pooling2d_4 (Frac (None, 17, 17, 64)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 15, 15, 64)        36928
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 13, 13, 64)        36928
# _________________________________________________________________
# fractional_pooling2d_5 (Frac (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3136)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 6274
# =================================================================
# Total params: 224,306
# Trainable params: 224,306
# Non-trainable params: 0
# _________________________________________________________________
# Found 462 images belonging to 2 classes.
# Found 154 images belonging to 2 classes.
# Found 66 images belonging to 2 classes.
# Epoch 1/35
# 14/14 [==============================] - 16s 1s/step - loss: 0.6931 - acc: 0.4982 - mean_absolute_error: 0.5000 - loss_no_weight_decay: 0.6931 - val_loss: 0.6930 - val_acc: 0.5156 - val_mean_absolute_error: 0.4999 - val_loss_no_weight_decay: 0.6930
#
# Epoch 00001: val_acc improved from -inf to 0.51562, saving model to base_2020-05-12-22-34-03-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[62  0]
#  [66  0]]
# Epoch 2/35
# 14/14 [==============================] - 11s 807ms/step - loss: 0.6934 - acc: 0.4879 - mean_absolute_error: 0.5001 - loss_no_weight_decay: 0.6934 - val_loss: 0.6933 - val_acc: 0.4754 - val_mean_absolute_error: 0.5001 - val_loss_no_weight_decay: 0.6933
#
# Epoch 00002: val_acc did not improve from 0.51562
# Confusion matrix:
#  [[61  0]
#  [61  0]]
# Epoch 3/35
# 14/14 [==============================] - 11s 777ms/step - loss: 0.6930 - acc: 0.5179 - mean_absolute_error: 0.4999 - loss_no_weight_decay: 0.6930 - val_loss: 0.6933 - val_acc: 0.4836 - val_mean_absolute_error: 0.5001 - val_loss_no_weight_decay: 0.6933
#
# Epoch 00003: val_acc did not improve from 0.51562
# Confusion matrix:
#  [[66  0]
#  [56  0]]
# Epoch 4/35
# 14/14 [==============================] - 11s 772ms/step - loss: 0.6934 - acc: 0.4794 - mean_absolute_error: 0.5001 - loss_no_weight_decay: 0.6934 - val_loss: 0.6931 - val_acc: 0.4918 - val_mean_absolute_error: 0.5000 - val_loss_no_weight_decay: 0.6931
#
# Epoch 00004: val_acc did not improve from 0.51562
# Confusion matrix:
#  [[ 0 63]
#  [ 0 59]]
# Epoch 5/35
# 14/14 [==============================] - 11s 771ms/step - loss: 0.6931 - acc: 0.5313 - mean_absolute_error: 0.5000 - loss_no_weight_decay: 0.6931 - val_loss: 0.6930 - val_acc: 0.6721 - val_mean_absolute_error: 0.4999 - val_loss_no_weight_decay: 0.6930
#
# Epoch 00005: val_acc improved from 0.51562 to 0.67213, saving model to base_2020-05-12-22-34-03-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[41 20]
#  [18 43]]
# Epoch 6/35
# 14/14 [==============================] - 11s 805ms/step - loss: 0.6931 - acc: 0.5379 - mean_absolute_error: 0.5000 - loss_no_weight_decay: 0.6931 - val_loss: 0.6930 - val_acc: 0.6250 - val_mean_absolute_error: 0.4999 - val_loss_no_weight_decay: 0.6930
#
# Epoch 00006: val_acc did not improve from 0.67213
# Confusion matrix:
#  [[52 14]
#  [28 34]]
# Epoch 7/35
# 14/14 [==============================] - 11s 780ms/step - loss: 0.6929 - acc: 0.5667 - mean_absolute_error: 0.4999 - loss_no_weight_decay: 0.6929 - val_loss: 0.6931 - val_acc: 0.5000 - val_mean_absolute_error: 0.5000 - val_loss_no_weight_decay: 0.6931
#
# Epoch 00007: val_acc did not improve from 0.67213
# Confusion matrix:
#  [[ 0 60]
#  [ 0 62]]
# Epoch 8/35
# 14/14 [==============================] - 11s 773ms/step - loss: 0.6933 - acc: 0.4835 - mean_absolute_error: 0.5001 - loss_no_weight_decay: 0.6933 - val_loss: 0.6929 - val_acc: 0.5246 - val_mean_absolute_error: 0.4998 - val_loss_no_weight_decay: 0.6929
#
# Epoch 00008: val_acc did not improve from 0.67213
# Confusion matrix:
#  [[ 0 60]
#  [ 0 62]]
# Epoch 9/35
# 14/14 [==============================] - 11s 756ms/step - loss: 0.6931 - acc: 0.5206 - mean_absolute_error: 0.5000 - loss_no_weight_decay: 0.6931 - val_loss: 0.6927 - val_acc: 0.5246 - val_mean_absolute_error: 0.4998 - val_loss_no_weight_decay: 0.6927
#
# Epoch 00009: val_acc did not improve from 0.67213
# Confusion matrix:
#  [[60  0]
#  [62  0]]
# Epoch 10/35
# 14/14 [==============================] - 11s 781ms/step - loss: 0.6933 - acc: 0.4861 - mean_absolute_error: 0.5001 - loss_no_weight_decay: 0.6933 - val_loss: 0.6929 - val_acc: 0.5000 - val_mean_absolute_error: 0.4999 - val_loss_no_weight_decay: 0.6929
#
# Epoch 00010: val_acc did not improve from 0.67213
# Confusion matrix:
#  [[63  0]
#  [59  0]]
# Epoch 11/35
# 14/14 [==============================] - 11s 813ms/step - loss: 0.6931 - acc: 0.4911 - mean_absolute_error: 0.5000 - loss_no_weight_decay: 0.6931 - val_loss: 0.6930 - val_acc: 0.4844 - val_mean_absolute_error: 0.4999 - val_loss_no_weight_decay: 0.6930
#
# Epoch 00011: val_acc did not improve from 0.67213
# Confusion matrix:
#  [[61  0]
#  [67  0]]
# Epoch 12/35
# 14/14 [==============================] - 11s 781ms/step - loss: 0.6930 - acc: 0.5443 - mean_absolute_error: 0.4999 - loss_no_weight_decay: 0.6930 - val_loss: 0.6928 - val_acc: 0.5082 - val_mean_absolute_error: 0.4998 - val_loss_no_weight_decay: 0.6928
#
# Epoch 00012: val_acc did not improve from 0.67213
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Confusion matrix:
#  [[60  0]
#  [62  0]]
# Epoch 13/35
# 14/14 [==============================] - 11s 780ms/step - loss: 0.6931 - acc: 0.4839 - mean_absolute_error: 0.5000 - loss_no_weight_decay: 0.6931 - val_loss: 0.6929 - val_acc: 0.4918 - val_mean_absolute_error: 0.4999 - val_loss_no_weight_decay: 0.6929
#
# Epoch 00013: val_acc did not improve from 0.67213
# Confusion matrix:
#  [[61  0]
#  [61  0]]
# Epoch 14/35
# 14/14 [==============================] - 11s 795ms/step - loss: 0.6928 - acc: 0.5497 - mean_absolute_error: 0.4998 - loss_no_weight_decay: 0.6928 - val_loss: 0.6925 - val_acc: 0.5328 - val_mean_absolute_error: 0.4997 - val_loss_no_weight_decay: 0.6925
#
# Epoch 00014: val_acc did not improve from 0.67213
# Confusion matrix:
#  [[59  0]
#  [63  0]]
# Epoch 15/35
# 14/14 [==============================] - 11s 775ms/step - loss: 0.6929 - acc: 0.5775 - mean_absolute_error: 0.4999 - loss_no_weight_decay: 0.6929 - val_loss: 0.6928 - val_acc: 0.6148 - val_mean_absolute_error: 0.4998 - val_loss_no_weight_decay: 0.6928
#
# Epoch 00015: val_acc did not improve from 0.67213
# Confusion matrix:
#  [[46 13]
#  [32 31]]
# Epoch 16/35
# 14/14 [==============================] - 11s 785ms/step - loss: 0.6929 - acc: 0.5179 - mean_absolute_error: 0.4999 - loss_no_weight_decay: 0.6929 - val_loss: 0.6927 - val_acc: 0.5078 - val_mean_absolute_error: 0.4998 - val_loss_no_weight_decay: 0.6927
#
# Epoch 00016: val_acc did not improve from 0.67213
# Confusion matrix:
#  [[65  0]
#  [63  0]]
# Epoch 17/35
# 14/14 [==============================] - 11s 800ms/step - loss: 0.6928 - acc: 0.5747 - mean_absolute_error: 0.4998 - loss_no_weight_decay: 0.6928 - val_loss: 0.6929 - val_acc: 0.5656 - val_mean_absolute_error: 0.4999 - val_loss_no_weight_decay: 0.6929
#
# Epoch 00017: val_acc did not improve from 0.67213
# Confusion matrix:
#  [[55  8]
#  [39 20]]
# Epoch 18/35
# 14/14 [==============================] - 11s 781ms/step - loss: 0.6928 - acc: 0.5403 - mean_absolute_error: 0.4998 - loss_no_weight_decay: 0.6928 - val_loss: 0.6924 - val_acc: 0.5246 - val_mean_absolute_error: 0.4996 - val_loss_no_weight_decay: 0.6924
#
# Epoch 00018: val_acc did not improve from 0.67213
# Confusion matrix:
#  [[62  0]
#  [60  0]]
# Epoch 19/35
# 14/14 [==============================] - 11s 807ms/step - loss: 0.6928 - acc: 0.5067 - mean_absolute_error: 0.4998 - loss_no_weight_decay: 0.6928 - val_loss: 0.6927 - val_acc: 0.4918 - val_mean_absolute_error: 0.4998 - val_loss_no_weight_decay: 0.6927
#
# Epoch 00019: val_acc did not improve from 0.67213
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Confusion matrix:
#  [[65  0]
#  [57  0]]
# Epoch 20/35
# 14/14 [==============================] - 11s 782ms/step - loss: 0.6929 - acc: 0.5018 - mean_absolute_error: 0.4999 - loss_no_weight_decay: 0.6929 - val_loss: 0.6927 - val_acc: 0.6393 - val_mean_absolute_error: 0.4998 - val_loss_no_weight_decay: 0.6927
#
# Epoch 00020: val_acc did not improve from 0.67213
# Confusion matrix:
#  [[47 10]
#  [42 23]]
# Epoch 21/35
# 14/14 [==============================] - 10s 748ms/step - loss: 0.6926 - acc: 0.5879 - mean_absolute_error: 0.4997 - loss_no_weight_decay: 0.6926 - val_loss: 0.6924 - val_acc: 0.5234 - val_mean_absolute_error: 0.4996 - val_loss_no_weight_decay: 0.6924
#
# Epoch 00021: val_acc did not improve from 0.67213
# Confusion matrix:
#  [[66  0]
#  [62  0]]
# Epoch 22/35
# 14/14 [==============================] - 11s 803ms/step - loss: 0.6930 - acc: 0.4799 - mean_absolute_error: 0.4999 - loss_no_weight_decay: 0.6930 - val_loss: 0.6928 - val_acc: 0.5820 - val_mean_absolute_error: 0.4998 - val_loss_no_weight_decay: 0.6928
#
# Epoch 00022: val_acc did not improve from 0.67213
# Confusion matrix:
#  [[51  8]
#  [44 19]]
# Epoch 23/35
# 14/14 [==============================] - 11s 776ms/step - loss: 0.6925 - acc: 0.6092 - mean_absolute_error: 0.4997 - loss_no_weight_decay: 0.6925 - val_loss: 0.6926 - val_acc: 0.5082 - val_mean_absolute_error: 0.4997 - val_loss_no_weight_decay: 0.6926
#
# Epoch 00023: val_acc did not improve from 0.67213
# Confusion matrix:
#  [[60  0]
#  [62  0]]
# Epoch 24/35
# 14/14 [==============================] - 11s 782ms/step - loss: 0.6930 - acc: 0.4794 - mean_absolute_error: 0.4999 - loss_no_weight_decay: 0.6930 - val_loss: 0.6927 - val_acc: 0.6311 - val_mean_absolute_error: 0.4998 - val_loss_no_weight_decay: 0.6927
#
# Epoch 00024: val_acc did not improve from 0.67213
# Confusion matrix:
#  [[51 12]
#  [30 29]]
# Epoch 25/35
# 14/14 [==============================] - 11s 781ms/step - loss: 0.6925 - acc: 0.6267 - mean_absolute_error: 0.4997 - loss_no_weight_decay: 0.6925 - val_loss: 0.6928 - val_acc: 0.4918 - val_mean_absolute_error: 0.4998 - val_loss_no_weight_decay: 0.6928
#
# Epoch 00025: val_acc did not improve from 0.67213
# Confusion matrix:
#  [[61  0]
#  [61  0]]
# Epoch 26/35
# 14/14 [==============================] - 11s 779ms/step - loss: 0.6930 - acc: 0.4866 - mean_absolute_error: 0.4999 - loss_no_weight_decay: 0.6930 - val_loss: 0.6925 - val_acc: 0.5234 - val_mean_absolute_error: 0.4996 - val_loss_no_weight_decay: 0.6925
#
# Epoch 00026: val_acc did not improve from 0.67213
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Confusion matrix:
#  [[64  0]
#  [64  0]]
# Epoch 27/35
# 14/14 [==============================] - 11s 783ms/step - loss: 0.6926 - acc: 0.5049 - mean_absolute_error: 0.4997 - loss_no_weight_decay: 0.6926 - val_loss: 0.6930 - val_acc: 0.4590 - val_mean_absolute_error: 0.4999 - val_loss_no_weight_decay: 0.6930
#
# Epoch 00027: val_acc did not improve from 0.67213
# Confusion matrix:
#  [[59  0]
#  [63  0]]
# Epoch 28/35
# 14/14 [==============================] - 11s 774ms/step - loss: 0.6927 - acc: 0.4946 - mean_absolute_error: 0.4998 - loss_no_weight_decay: 0.6927 - val_loss: 0.6923 - val_acc: 0.5492 - val_mean_absolute_error: 0.4996 - val_loss_no_weight_decay: 0.6923
#
# Epoch 00028: val_acc did not improve from 0.67213
# Confusion matrix:
#  [[60  0]
#  [62  0]]
# Epoch 29/35
# 14/14 [==============================] - 11s 773ms/step - loss: 0.6927 - acc: 0.4978 - mean_absolute_error: 0.4998 - loss_no_weight_decay: 0.6927 - val_loss: 0.6929 - val_acc: 0.4918 - val_mean_absolute_error: 0.4999 - val_loss_no_weight_decay: 0.6929
#
# Epoch 00029: val_acc did not improve from 0.67213
# Confusion matrix:
#  [[66  0]
#  [54  2]]
# Epoch 30/35
# 14/14 [==============================] - 11s 774ms/step - loss: 0.6927 - acc: 0.5546 - mean_absolute_error: 0.4998 - loss_no_weight_decay: 0.6927 - val_loss: 0.6926 - val_acc: 0.6148 - val_mean_absolute_error: 0.4997 - val_loss_no_weight_decay: 0.6926
#
# Epoch 00030: val_acc did not improve from 0.67213
# Confusion matrix:
#  [[60  2]
#  [48 12]]
# Epoch 31/35
# 14/14 [==============================] - 11s 773ms/step - loss: 0.6928 - acc: 0.5197 - mean_absolute_error: 0.4998 - loss_no_weight_decay: 0.6928 - val_loss: 0.6925 - val_acc: 0.5234 - val_mean_absolute_error: 0.4997 - val_loss_no_weight_decay: 0.6925
#
# Epoch 00031: val_acc did not improve from 0.67213
# Confusion matrix:
#  [[63  0]
#  [63  2]]
# Epoch 32/35
# 14/14 [==============================] - 11s 808ms/step - loss: 0.6927 - acc: 0.5893 - mean_absolute_error: 0.4998 - loss_no_weight_decay: 0.6927 - val_loss: 0.6927 - val_acc: 0.5656 - val_mean_absolute_error: 0.4998 - val_loss_no_weight_decay: 0.6927
#
# Epoch 00032: val_acc did not improve from 0.67213
# Confusion matrix:
#  [[59  9]
#  [34 20]]
# Epoch 33/35
# 14/14 [==============================] - 10s 747ms/step - loss: 0.6926 - acc: 0.6122 - mean_absolute_error: 0.4997 - loss_no_weight_decay: 0.6926 - val_loss: 0.6924 - val_acc: 0.6885 - val_mean_absolute_error: 0.4996 - val_loss_no_weight_decay: 0.6924
#
# Epoch 00033: val_acc improved from 0.67213 to 0.68852, saving model to base_2020-05-12-22-34-03-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[41 11]
#  [38 32]]
# Epoch 34/35
# 14/14 [==============================] - 11s 782ms/step - loss: 0.6926 - acc: 0.5748 - mean_absolute_error: 0.4997 - loss_no_weight_decay: 0.6926 - val_loss: 0.6929 - val_acc: 0.5164 - val_mean_absolute_error: 0.4998 - val_loss_no_weight_decay: 0.6929
#
# Epoch 00034: val_acc did not improve from 0.68852
# Confusion matrix:
#  [[69  0]
#  [50  3]]
# Epoch 35/35
# 14/14 [==============================] - 11s 777ms/step - loss: 0.6927 - acc: 0.5882 - mean_absolute_error: 0.4998 - loss_no_weight_decay: 0.6927 - val_loss: 0.6925 - val_acc: 0.6885 - val_mean_absolute_error: 0.4997 - val_loss_no_weight_decay: 0.6925
#
# Epoch 00035: val_acc improved from 0.68852 to 0.68852, saving model to base_2020-05-12-22-34-03-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[43 16]
#  [29 34]]
# Epoch 00032: early stopping
# 66/66 [==============================] - 1s 9ms/step
# 66/66 [==============================] - 1s 8ms/step
# Test loss: 0.6929210505702279
# Test accuracy: 0.5757575757575758
# Confusion Matrix
# [[23 10]
#  [18 15]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.56      0.70      0.62        33
#            1       0.60      0.45      0.52        33
#
#     accuracy                           0.58        66
#    macro avg       0.58      0.58      0.57        66
# weighted avg       0.58      0.58      0.57        66

# %%
from Kappa_Skl import kappa
def kappa2(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    if len(y_true.shape) > 1 and y_true.shape[1] > 1:
        y_true = y_true.dot(range(y_true.shape[1]))
    if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
        y_pred = y_pred.dot(range(y_pred.shape[1]))
    try:
        return kappa(y_true, y_pred, weights='quadratic')
    except IndexError:
        return np.nan
    
print('Quadratic_wieghted_kappa')
print(kappa2(y_true, y_pred))
# Out:
# Quadratic_wieghted_kappa
# 0.1515151515151516

# %%
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
