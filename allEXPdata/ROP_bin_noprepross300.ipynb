# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, InputLayer
from keras.regularizers import L1L2, l2, l1
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from custom_pooling import RMSPooling2D
from keras.optimizers import SGD, Adam
from keras.layers import LeakyReLU
#from data import BALANCE_WEIGHTS
from keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
#import os
from datetime import datetime as dt
from custom_loss import WeightedCategoricalCrossEntropy
from VCM import VCM
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
def get_experiment_id():
    time_str = dt.now().strftime('%Y-%m-%d-%H-%M-%S')
    experiment_id = 'base_{}'.format(time_str)
    return experiment_id
p_ratio=[1.0, 1.44, 1.73, 1.0]

model = Sequential()


model.add(Conv2D(16, (5, 5), activation='tanh', input_shape=(300, 300, 3)))
model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(16, (3, 3), activation='tanh'))
model.add(Conv2D(16, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))

#model.add(LeakyReLU(alpha=0.01))


model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))



model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))          
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(MaxPooling2D(pool_size=2))
#model.add(MaxPooling2D(pool_size=1))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
model.add(MaxPooling2D(pool_size=2))

model.add(Flatten())


#chnaged from 10 to 5 because an error 
model.add(Dense(2, activation='softmax'))

sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.count_params()
#adam = Adam(lr=0.0005, decay=1e-6)
#rmsprop
#Mloss = WeightedCategoricalCrossEntropy({0: 0.4125861396437394, 1: 1.4918664786083686, 2: 0.690426457789382, 3: 3.9541433021806855, 4: 4.885604311008468})
model.compile(loss='mse', optimizer=sgd, metrics=['mae','acc'])
model.summary()
loss_no_weight_decay = model.total_loss - sum(model.losses)
model.metrics_tensors.append(loss_no_weight_decay)
model.metrics_names.append('loss_no_weight_decay')
#############################################################################################
#############################################################################################
#############################################################################################
#############################################################################################
#Preparing Data Augmentation Configuration 
train_datagen = ImageDataGenerator(
        rescale=1./255,
#        featurewise_center=True,
 #       samplewise_center=True,
        shear_range=0,
        zoom_range=0.0,#[1 / 1.15, 1.15],
        horizontal_flip=False,#True,
        rotation_range=0)#90,
#        validation_split=0.2)
"""
For the test set only rescale should be made 
"""
test_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas/train",
    target_size=(300, 300),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="training")
#    save_to_dir="D:/Separating Images into subfolders/train_augmented")


#print(train_generator.class_indices)

valid_generator = valid_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas/vald",
    target_size=(300, 300),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="validation")
#    save_to_dir="D:/Separating Images into subfolders/val_augmented"


test_generator = test_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas/test",
    target_size=(300, 300),
    color_mode="rgb",
    batch_size=1,
    class_mode="categorical",
    shuffle=False,
    seed=42)
#    save_to_dir="D:/Separating Images into subfolders/test_augmented")


# Fitting/Training the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
experiment_id = get_experiment_id()
callbacks = [
    EarlyStopping(monitor='val_acc', patience=50, min_delta=0.001, verbose=1),
    ModelCheckpoint(experiment_id + "-val_acc_checkpoint.hdf5", monitor='val_acc', verbose=1, save_best_only=True, mode='auto'),
    ReduceLROnPlateau(monitor='val_acc', factor=0.5, patience=7, verbose=1, mode='auto', min_delta=0.001, cooldown=0, min_lr=1e-7),
    VCM(valid_generator,STEP_SIZE_VALID)
    
]

class_weight_list = class_weight.compute_class_weight('balanced', np.unique(train_generator.classes), train_generator.classes)
class_weights = dict(zip(np.unique(train_generator.classes), class_weight_list))

history=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    class_weight=class_weights,
                    callbacks=callbacks,
                    epochs=35  
)


# Evaluating the model 
#predicting output
#reseting the test generator before calling predict_generator, in order not to get weird output
test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 296, 296, 16)      1216
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 292, 292, 16)      6416
# _________________________________________________________________
# input_1 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 290, 290, 16)      2320
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 288, 288, 16)      2320
# _________________________________________________________________
# input_2 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 284, 284, 16)      6416
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 280, 280, 16)      6416
# _________________________________________________________________
# input_3 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 276, 276, 16)      6416
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 272, 272, 16)      6416
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 136, 136, 16)      0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 134, 134, 32)      4640
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 132, 132, 32)      9248
# _________________________________________________________________
# input_4 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 130, 130, 32)      9248
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 128, 128, 32)      9248
# _________________________________________________________________
# input_5 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 126, 126, 32)      9248
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 124, 124, 32)      9248
# _________________________________________________________________
# input_6 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 122, 122, 32)      9248
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 120, 120, 32)      9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 60, 60, 32)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 58, 58, 64)        18496
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 56, 56, 64)        36928
# _________________________________________________________________
# input_7 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 54, 54, 64)        36928
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 52, 52, 64)        36928
# _________________________________________________________________
# input_8 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 50, 50, 64)        36928
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 48, 48, 64)        36928
# _________________________________________________________________
# input_9 (InputLayer)         multiple                  0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 22, 22, 64)        36928
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 20, 20, 64)        36928
# _________________________________________________________________
# input_10 (InputLayer)        multiple                  0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 18, 18, 64)        36928
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# input_11 (InputLayer)        multiple                  0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 8194
# =================================================================
# Total params: 466,354
# Trainable params: 466,354
# Non-trainable params: 0
# _________________________________________________________________
# Found 588 images belonging to 2 classes.
# Found 116 images belonging to 2 classes.
# Found 176 images belonging to 2 classes.
# Epoch 1/35
# 9/9 [==============================] - 28s 3s/step - loss: 0.2499 - mean_absolute_error: 0.4991 - acc: 0.5215 - loss_no_weight_decay: 0.2499 - val_loss: 0.2476 - val_mean_absolute_error: 0.4975 - val_acc: 0.5000 - val_loss_no_weight_decay: 0.2476
#
# Epoch 00001: val_acc improved from -inf to 0.50000, saving model to base_2020-05-07-11-07-58-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[ 5 27]
#  [ 0 32]]
# Epoch 2/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.2467 - mean_absolute_error: 0.4964 - acc: 0.5679 - loss_no_weight_decay: 0.2467 - val_loss: 0.2411 - val_mean_absolute_error: 0.4902 - val_acc: 0.5962 - val_loss_no_weight_decay: 0.2411
#
# Epoch 00002: val_acc improved from 0.50000 to 0.59615, saving model to base_2020-05-07-11-07-58-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[ 0 27]
#  [ 0 25]]
# Epoch 3/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.2470 - mean_absolute_error: 0.4955 - acc: 0.4985 - loss_no_weight_decay: 0.2470 - val_loss: 0.2423 - val_mean_absolute_error: 0.4921 - val_acc: 0.7656 - val_loss_no_weight_decay: 0.2423
#
# Epoch 00003: val_acc improved from 0.59615 to 0.76562, saving model to base_2020-05-07-11-07-58-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[23  5]
#  [11 25]]
# Epoch 4/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.2435 - mean_absolute_error: 0.4932 - acc: 0.6438 - loss_no_weight_decay: 0.2435 - val_loss: 0.2423 - val_mean_absolute_error: 0.4920 - val_acc: 0.6923 - val_loss_no_weight_decay: 0.2423
#
# Epoch 00004: val_acc did not improve from 0.76562
# Confusion matrix:
#  [[17  7]
#  [ 9 19]]
# Epoch 5/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.2392 - mean_absolute_error: 0.4873 - acc: 0.6389 - loss_no_weight_decay: 0.2392 - val_loss: 0.2333 - val_mean_absolute_error: 0.4799 - val_acc: 0.6719 - val_loss_no_weight_decay: 0.2333
#
# Epoch 00005: val_acc did not improve from 0.76562
# Confusion matrix:
#  [[12 18]
#  [ 0 34]]
# Epoch 6/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.2356 - mean_absolute_error: 0.4821 - acc: 0.5906 - loss_no_weight_decay: 0.2356 - val_loss: 0.2424 - val_mean_absolute_error: 0.4833 - val_acc: 0.4808 - val_loss_no_weight_decay: 0.2424
#
# Epoch 00006: val_acc did not improve from 0.76562
# Confusion matrix:
#  [[28  2]
#  [22  0]]
# Epoch 7/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.2249 - mean_absolute_error: 0.4656 - acc: 0.6372 - loss_no_weight_decay: 0.2249 - val_loss: 0.2106 - val_mean_absolute_error: 0.4388 - val_acc: 0.6562 - val_loss_no_weight_decay: 0.2106
#
# Epoch 00007: val_acc did not improve from 0.76562
# Confusion matrix:
#  [[12 18]
#  [ 6 28]]
# Epoch 8/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.2465 - mean_absolute_error: 0.4571 - acc: 0.6167 - loss_no_weight_decay: 0.2465 - val_loss: 0.2075 - val_mean_absolute_error: 0.4435 - val_acc: 0.6346 - val_loss_no_weight_decay: 0.2075
#
# Epoch 00008: val_acc did not improve from 0.76562
# Confusion matrix:
#  [[27  3]
#  [15  7]]
# Epoch 9/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.2250 - mean_absolute_error: 0.4674 - acc: 0.6555 - loss_no_weight_decay: 0.2250 - val_loss: 0.1962 - val_mean_absolute_error: 0.4326 - val_acc: 0.7344 - val_loss_no_weight_decay: 0.1962
#
# Epoch 00009: val_acc did not improve from 0.76562
# Confusion matrix:
#  [[14 17]
#  [ 6 27]]
# Epoch 10/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.2109 - mean_absolute_error: 0.4399 - acc: 0.6892 - loss_no_weight_decay: 0.2109 - val_loss: 0.2073 - val_mean_absolute_error: 0.4206 - val_acc: 0.6731 - val_loss_no_weight_decay: 0.2073
#
# Epoch 00010: val_acc did not improve from 0.76562
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Confusion matrix:
#  [[23  2]
#  [17 10]]
# Epoch 11/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.2166 - mean_absolute_error: 0.4292 - acc: 0.6751 - loss_no_weight_decay: 0.2166 - val_loss: 0.1888 - val_mean_absolute_error: 0.3977 - val_acc: 0.7344 - val_loss_no_weight_decay: 0.1888
#
# Epoch 00011: val_acc did not improve from 0.76562
# Confusion matrix:
#  [[20 10]
#  [ 3 31]]
# Epoch 12/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.1987 - mean_absolute_error: 0.4158 - acc: 0.6924 - loss_no_weight_decay: 0.1987 - val_loss: 0.2070 - val_mean_absolute_error: 0.4146 - val_acc: 0.6731 - val_loss_no_weight_decay: 0.2070
#
# Epoch 00012: val_acc did not improve from 0.76562
# Confusion matrix:
#  [[11 13]
#  [ 3 25]]
# Epoch 13/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.2112 - mean_absolute_error: 0.4329 - acc: 0.6615 - loss_no_weight_decay: 0.2112 - val_loss: 0.1837 - val_mean_absolute_error: 0.4092 - val_acc: 0.7500 - val_loss_no_weight_decay: 0.1837
#
# Epoch 00013: val_acc did not improve from 0.76562
# Confusion matrix:
#  [[19 13]
#  [ 8 24]]
# Epoch 14/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.1866 - mean_absolute_error: 0.4093 - acc: 0.7550 - loss_no_weight_decay: 0.1866 - val_loss: 0.1930 - val_mean_absolute_error: 0.4110 - val_acc: 0.7500 - val_loss_no_weight_decay: 0.1930
#
# Epoch 00014: val_acc did not improve from 0.76562
# Confusion matrix:
#  [[20 10]
#  [ 7 15]]
# Epoch 15/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.1988 - mean_absolute_error: 0.4182 - acc: 0.6944 - loss_no_weight_decay: 0.1988 - val_loss: 0.1686 - val_mean_absolute_error: 0.3771 - val_acc: 0.7812 - val_loss_no_weight_decay: 0.1686
#
# Epoch 00015: val_acc improved from 0.76562 to 0.78125, saving model to base_2020-05-07-11-07-58-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[15 12]
#  [ 4 33]]
# Epoch 16/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.1949 - mean_absolute_error: 0.4077 - acc: 0.6857 - loss_no_weight_decay: 0.1949 - val_loss: 0.1966 - val_mean_absolute_error: 0.4112 - val_acc: 0.6538 - val_loss_no_weight_decay: 0.1966
#
# Epoch 00016: val_acc did not improve from 0.78125
# Confusion matrix:
#  [[23  5]
#  [ 5 19]]
# Epoch 17/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.1873 - mean_absolute_error: 0.4045 - acc: 0.7170 - loss_no_weight_decay: 0.1873 - val_loss: 0.1963 - val_mean_absolute_error: 0.4174 - val_acc: 0.6875 - val_loss_no_weight_decay: 0.1963
#
# Epoch 00017: val_acc did not improve from 0.78125
# Confusion matrix:
#  [[25  7]
#  [11 21]]
# Epoch 18/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.1855 - mean_absolute_error: 0.3979 - acc: 0.7062 - loss_no_weight_decay: 0.1855 - val_loss: 0.1548 - val_mean_absolute_error: 0.3653 - val_acc: 0.8462 - val_loss_no_weight_decay: 0.1548
#
# Epoch 00018: val_acc improved from 0.78125 to 0.84615, saving model to base_2020-05-07-11-07-58-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[21  5]
#  [ 8 18]]
# Epoch 19/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.1847 - mean_absolute_error: 0.3892 - acc: 0.7390 - loss_no_weight_decay: 0.1847 - val_loss: 0.1775 - val_mean_absolute_error: 0.3908 - val_acc: 0.7500 - val_loss_no_weight_decay: 0.1775
#
# Epoch 00019: val_acc did not improve from 0.84615
# Confusion matrix:
#  [[24  6]
#  [ 8 26]]
# Epoch 20/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.1851 - mean_absolute_error: 0.4002 - acc: 0.7189 - loss_no_weight_decay: 0.1851 - val_loss: 0.1702 - val_mean_absolute_error: 0.3794 - val_acc: 0.7500 - val_loss_no_weight_decay: 0.1702
#
# Epoch 00020: val_acc did not improve from 0.84615
# Confusion matrix:
#  [[16  8]
#  [ 8 20]]
# Epoch 21/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.1840 - mean_absolute_error: 0.3941 - acc: 0.7192 - loss_no_weight_decay: 0.1840 - val_loss: 0.1607 - val_mean_absolute_error: 0.3595 - val_acc: 0.7656 - val_loss_no_weight_decay: 0.1607
#
# Epoch 00021: val_acc did not improve from 0.84615
# Confusion matrix:
#  [[18 13]
#  [ 6 27]]
# Epoch 22/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.1784 - mean_absolute_error: 0.3886 - acc: 0.7482 - loss_no_weight_decay: 0.1784 - val_loss: 0.1852 - val_mean_absolute_error: 0.3979 - val_acc: 0.7500 - val_loss_no_weight_decay: 0.1852
#
# Epoch 00022: val_acc did not improve from 0.84615
# Confusion matrix:
#  [[18  8]
#  [ 4 22]]
# Epoch 23/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.1691 - mean_absolute_error: 0.3738 - acc: 0.7460 - loss_no_weight_decay: 0.1691 - val_loss: 0.1470 - val_mean_absolute_error: 0.3465 - val_acc: 0.7969 - val_loss_no_weight_decay: 0.1470
#
# Epoch 00023: val_acc did not improve from 0.84615
# Confusion matrix:
#  [[24  7]
#  [12 21]]
# Epoch 24/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.1713 - mean_absolute_error: 0.3717 - acc: 0.7447 - loss_no_weight_decay: 0.1713 - val_loss: 0.1856 - val_mean_absolute_error: 0.3898 - val_acc: 0.7308 - val_loss_no_weight_decay: 0.1856
#
# Epoch 00024: val_acc did not improve from 0.84615
# Confusion matrix:
#  [[23  3]
#  [10 16]]
# Epoch 25/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.1707 - mean_absolute_error: 0.3750 - acc: 0.7500 - loss_no_weight_decay: 0.1707 - val_loss: 0.1744 - val_mean_absolute_error: 0.3735 - val_acc: 0.7500 - val_loss_no_weight_decay: 0.1744
#
# Epoch 00025: val_acc did not improve from 0.84615
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Confusion matrix:
#  [[25  9]
#  [ 5 25]]
# Epoch 26/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.1605 - mean_absolute_error: 0.3552 - acc: 0.7685 - loss_no_weight_decay: 0.1605 - val_loss: 0.1414 - val_mean_absolute_error: 0.3342 - val_acc: 0.8269 - val_loss_no_weight_decay: 0.1414
#
# Epoch 00026: val_acc did not improve from 0.84615
# Confusion matrix:
#  [[19  9]
#  [ 6 18]]
# Epoch 27/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.1644 - mean_absolute_error: 0.3653 - acc: 0.7726 - loss_no_weight_decay: 0.1644 - val_loss: 0.1540 - val_mean_absolute_error: 0.3454 - val_acc: 0.7969 - val_loss_no_weight_decay: 0.1540
#
# Epoch 00027: val_acc did not improve from 0.84615
# Confusion matrix:
#  [[21 14]
#  [ 3 26]]
# Epoch 28/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.1650 - mean_absolute_error: 0.3620 - acc: 0.7500 - loss_no_weight_decay: 0.1650 - val_loss: 0.1686 - val_mean_absolute_error: 0.3658 - val_acc: 0.6923 - val_loss_no_weight_decay: 0.1686
# Epoch 00028: val_acc did not improve from 0.84615
# Confusion matrix:
#  [[25  5]
#  [ 6 16]]
# Epoch 29/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.1573 - mean_absolute_error: 0.3568 - acc: 0.7846 - loss_no_weight_decay: 0.1573 - val_loss: 0.1563 - val_mean_absolute_error: 0.3506 - val_acc: 0.7656 - val_loss_no_weight_decay: 0.1563
#
# Epoch 00029: val_acc did not improve from 0.84615
# Confusion matrix:
#  [[29  4]
#  [ 6 25]]
# Epoch 30/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.1659 - mean_absolute_error: 0.3621 - acc: 0.7608 - loss_no_weight_decay: 0.1659 - val_loss: 0.1551 - val_mean_absolute_error: 0.3513 - val_acc: 0.7692 - val_loss_no_weight_decay: 0.1551
#
# Epoch 00030: val_acc did not improve from 0.84615
# Confusion matrix:
#  [[18  5]
#  [ 7 22]]
# Epoch 31/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.1572 - mean_absolute_error: 0.3546 - acc: 0.7796 - loss_no_weight_decay: 0.1572 - val_loss: 0.1576 - val_mean_absolute_error: 0.3514 - val_acc: 0.7656 - val_loss_no_weight_decay: 0.1576
#
# Epoch 00031: val_acc did not improve from 0.84615
# Confusion matrix:
#  [[26 11]
#  [ 1 26]]
# Epoch 32/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.1673 - mean_absolute_error: 0.3701 - acc: 0.7585 - loss_no_weight_decay: 0.1673 - val_loss: 0.1592 - val_mean_absolute_error: 0.3590 - val_acc: 0.7885 - val_loss_no_weight_decay: 0.1592
#
# Epoch 00032: val_acc did not improve from 0.84615
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Confusion matrix:
#  [[20  4]
#  [ 4 24]]
# Epoch 33/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.1476 - mean_absolute_error: 0.3438 - acc: 0.7883 - loss_no_weight_decay: 0.1476 - val_loss: 0.1646 - val_mean_absolute_error: 0.3537 - val_acc: 0.7656 - val_loss_no_weight_decay: 0.1646
#
# Epoch 00033: val_acc did not improve from 0.84615
# Confusion matrix:
#  [[26  9]
#  [ 8 21]]
# Epoch 34/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.1670 - mean_absolute_error: 0.3638 - acc: 0.7330 - loss_no_weight_decay: 0.1670 - val_loss: 0.1312 - val_mean_absolute_error: 0.3223 - val_acc: 0.8269 - val_loss_no_weight_decay: 0.1312
#
# Epoch 00034: val_acc did not improve from 0.84615
# Confusion matrix:
#  [[18  8]
#  [ 2 24]]
# Epoch 35/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.1509 - mean_absolute_error: 0.3441 - acc: 0.7934 - loss_no_weight_decay: 0.1509 - val_loss: 0.1508 - val_mean_absolute_error: 0.3376 - val_acc: 0.7656 - val_loss_no_weight_decay: 0.1508
#
# Epoch 00035: val_acc did not improve from 0.84615
# Confusion matrix:
#  [[25  5]
#  [ 7 27]]
# 176/176 [==============================] - 5s 28ms/step
# 176/176 [==============================] - 5s 27ms/step
# Test loss: 0.1552705559694335
# Test accuracy: 0.34654368714175443
# Confusion Matrix
# [[74 14]
#  [26 62]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.74      0.84      0.79        88
#            1       0.82      0.70      0.76        88
#
#     accuracy                           0.77       176
#    macro avg       0.78      0.77      0.77       176
# weighted avg       0.78      0.77      0.77       176

# %%
import numpy as np 
import matplotlib.pyplot as plt
import os
import wandb
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_mean_absolute_error', 'val_acc', 'val_loss_no_weight_decay', 'loss', 'mean_absolute_error', 'acc', 'loss_no_weight_decay', 'lr'])

# %%
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
from Kappa_Skl import kappa
def kappa2(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    if len(y_true.shape) > 1 and y_true.shape[1] > 1:
        y_true = y_true.dot(range(y_true.shape[1]))
    if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
        y_pred = y_pred.dot(range(y_pred.shape[1]))
    try:
        return kappa(y_true, y_pred, weights='quadratic')
    except IndexError:
        return np.nan
    
print('Quadratic_wieghted_kappa')
print(kappa2(y_true, y_pred))
# Out:
# Quadratic_wieghted_kappa
# 0.5454545454545454

# %%
# summarize history for mean_absolute _error
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model mean_absolute_error')
plt.ylabel('mean_absolute_error')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model maey.png')
