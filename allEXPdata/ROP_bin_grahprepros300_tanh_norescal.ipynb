# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, InputLayer
from keras.regularizers import L1L2, l2, l1
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from custom_pooling import RMSPooling2D
from keras.optimizers import SGD, Adam
from keras.layers import LeakyReLU
#from data import BALANCE_WEIGHTS
from keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
#import os
from datetime import datetime as dt
from custom_loss import WeightedCategoricalCrossEntropy
from VCM import VCM
from QWK import QWK
import keras.backend as K
from Fractional_MAXPOOL import FractionalPooling2D
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
def get_experiment_id():
    time_str = dt.now().strftime('%Y-%m-%d-%H-%M-%S')
    experiment_id = 'base_{}'.format(time_str)
    return experiment_id
p_ratio=[1.0, 1.44, 1.73, 1.0]

model = Sequential()


model.add(Conv2D(16, (5, 5), activation='tanh', input_shape=(300, 300, 3)))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(16, (3, 3), activation='tanh'))
model.add(Conv2D(16, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))

#model.add(LeakyReLU(alpha=0.01))


model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))



model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))          
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))
#model.add(MaxPooling2D(pool_size=1))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Flatten())


#chnaged from 10 to 5 because an error 
model.add(Dense(2, activation='softmax'))

sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.count_params()
#adam = Adam(lr=0.0005, decay=1e-6)
#rmsprop
#Mloss = WeightedCategoricalCrossEntropy({0: 0.4125861396437394, 1: 1.4918664786083686, 2: 0.690426457789382, 3: 3.9541433021806855, 4: 4.885604311008468})
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['mae','acc'])
model.summary()
loss_no_weight_decay = model.total_loss - sum(model.losses)
model.metrics_tensors.append(loss_no_weight_decay)
model.metrics_names.append('loss_no_weight_decay')
#############################################################################################
#############################################################################################
#############################################################################################
#############################################################################################
#Preparing Data Augmentation Configuration 
train_datagen = ImageDataGenerator(
        
#        featurewise_center=True,
 #       samplewise_center=True,
        shear_range=0,
        zoom_range=0.0,#[1 / 1.15, 1.15],
        horizontal_flip=False,#True,
        rotation_range=0)#90,
#        validation_split=0.2)
"""
For the test set only rescale should be made 
"""
test_datagen = ImageDataGenerator()
valid_datagen = ImageDataGenerator()


train_generator = train_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas_grah/train",
    target_size=(300, 300),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="training")
#    save_to_dir="D:/Separating Images into subfolders/train_augmented")


#print(train_generator.class_indices)

valid_generator = valid_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas_grah/vald",
    target_size=(300, 300),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="validation")
#    save_to_dir="D:/Separating Images into subfolders/val_augmented"


test_generator = test_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas_grah/test",
    target_size=(300, 300),
    color_mode="rgb",
    batch_size=1,
    class_mode="categorical",
    shuffle=False,
    seed=42)
#    save_to_dir="D:/Separating Images into subfolders/test_augmented")


# Fitting/Training the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
experiment_id = get_experiment_id()
callbacks = [
    QWK(valid_generator, STEP_SIZE_VALID),
    EarlyStopping(monitor='val_acc', patience=50, min_delta=0.001, verbose=1),
    ModelCheckpoint(experiment_id + "-val_acc_checkpoint.hdf5", monitor='val_kappa', verbose=1, save_best_only=True, mode='max'),
    ReduceLROnPlateau(monitor='val_acc', factor=0.5, patience=7, verbose=1, mode='auto', min_delta=0.001, cooldown=0, min_lr=1e-7),
    VCM(valid_generator,STEP_SIZE_VALID)
    
]

class_weight_list = class_weight.compute_class_weight('balanced', np.unique(train_generator.classes), train_generator.classes)
class_weights = dict(zip(np.unique(train_generator.classes), class_weight_list))

history=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    #class_weight=class_weights,
                    callbacks=callbacks,
                    epochs=35  
)


# Evaluating the model 
#predicting output
#reseting the test generator before calling predict_generator, in order not to get weird output
test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 296, 296, 16)      1216
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 292, 292, 16)      6416
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 290, 290, 16)      2320
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 288, 288, 16)      2320
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 284, 284, 16)      6416
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 280, 280, 16)      6416
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 276, 276, 16)      6416
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 272, 272, 16)      6416
# _________________________________________________________________
# fractional_pooling2d_1 (Frac (None, 151, 151, 16)      0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 149, 149, 32)      4640
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 147, 147, 32)      9248
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 145, 145, 32)      9248
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 143, 143, 32)      9248
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 141, 141, 32)      9248
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 139, 139, 32)      9248
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 137, 137, 32)      9248
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 135, 135, 32)      9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 67, 67, 32)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 65, 65, 64)        18496
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 63, 63, 64)        36928
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 61, 61, 64)        36928
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 59, 59, 64)        36928
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 57, 57, 64)        36928
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 55, 55, 64)        36928
# _________________________________________________________________
# fractional_pooling2d_2 (Frac (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 28, 28, 64)        36928
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 26, 26, 64)        36928
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 24, 24, 64)        36928
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 22, 22, 64)        36928
# _________________________________________________________________
# fractional_pooling2d_3 (Frac (None, 12, 12, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 9216)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 18434
# =================================================================
# Total params: 476,594
# Trainable params: 476,594
# Non-trainable params: 0
# _________________________________________________________________
# Found 588 images belonging to 2 classes.
# Found 116 images belonging to 2 classes.
# Found 176 images belonging to 2 classes.
# Epoch 1/35
# 9/9 [==============================] - 37s 4s/step - loss: 0.7026 - mean_absolute_error: 0.5018 - acc: 0.5083 - loss_no_weight_decay: 0.7026 - val_loss: 0.7099 - val_mean_absolute_error: 0.5066 - val_acc: 0.4219 - val_loss_no_weight_decay: 0.7099
# — val_kappa: 0.0
#
# Epoch 00001: val_kappa improved from -inf to 0.00000, saving model to base_2020-05-10-15-04-00-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[ 0 26]
#  [ 0 26]]
# Epoch 2/35
# 9/9 [==============================] - 25s 3s/step - loss: 0.6979 - mean_absolute_error: 0.5009 - acc: 0.4867 - loss_no_weight_decay: 0.6979 - val_loss: 0.6724 - val_mean_absolute_error: 0.4891 - val_acc: 0.6923 - val_loss_no_weight_decay: 0.6724
# — val_kappa: 0.375
#
# Epoch 00002: val_kappa improved from 0.00000 to 0.37500, saving model to base_2020-05-10-15-04-00-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[18 12]
#  [ 0 22]]
# Epoch 3/35
# 9/9 [==============================] - 25s 3s/step - loss: 0.6829 - mean_absolute_error: 0.4923 - acc: 0.5556 - loss_no_weight_decay: 0.6829 - val_loss: 0.6520 - val_mean_absolute_error: 0.4784 - val_acc: 0.8281 - val_loss_no_weight_decay: 0.6520
# — val_kappa: 0.46875
#
# Epoch 00003: val_kappa improved from 0.37500 to 0.46875, saving model to base_2020-05-10-15-04-00-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[19  3]
#  [ 2 28]]
# Epoch 4/35
# 9/9 [==============================] - 22s 2s/step - loss: 0.6913 - mean_absolute_error: 0.4947 - acc: 0.5413 - loss_no_weight_decay: 0.6913 - val_loss: 0.6792 - val_mean_absolute_error: 0.4928 - val_acc: 0.7500 - val_loss_no_weight_decay: 0.6792
# — val_kappa: 0.5
#
# Epoch 00004: val_kappa improved from 0.46875 to 0.50000, saving model to base_2020-05-10-15-04-00-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[22  9]
#  [ 1 20]]
# Epoch 5/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.6795 - mean_absolute_error: 0.4919 - acc: 0.5862 - loss_no_weight_decay: 0.6795 - val_loss: 0.6590 - val_mean_absolute_error: 0.4800 - val_acc: 0.5312 - val_loss_no_weight_decay: 0.6590
# — val_kappa: 0.3125
#
# Epoch 00005: val_kappa did not improve from 0.50000
# Confusion matrix:
#  [[ 6 22]
#  [ 1 23]]
# Epoch 6/35
# 9/9 [==============================] - 20s 2s/step - loss: 0.6675 - mean_absolute_error: 0.4816 - acc: 0.6144 - loss_no_weight_decay: 0.6675 - val_loss: 0.6232 - val_mean_absolute_error: 0.4584 - val_acc: 0.7115 - val_loss_no_weight_decay: 0.6232
# — val_kappa: 0.3125
#
# Epoch 00006: val_kappa did not improve from 0.50000
# Confusion matrix:
#  [[ 8 19]
#  [ 1 24]]
# Epoch 7/35
# 9/9 [==============================] - 24s 3s/step - loss: 0.6453 - mean_absolute_error: 0.4687 - acc: 0.6684 - loss_no_weight_decay: 0.6453 - val_loss: 0.6007 - val_mean_absolute_error: 0.4475 - val_acc: 0.7969 - val_loss_no_weight_decay: 0.6007
# — val_kappa: 0.6875
#
# Epoch 00007: val_kappa improved from 0.50000 to 0.68750, saving model to base_2020-05-10-15-04-00-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[19 10]
#  [ 3 20]]
# Epoch 8/35
# 9/9 [==============================] - 22s 2s/step - loss: 0.6272 - mean_absolute_error: 0.4562 - acc: 0.6834 - loss_no_weight_decay: 0.6272 - val_loss: 0.5310 - val_mean_absolute_error: 0.3996 - val_acc: 0.7692 - val_loss_no_weight_decay: 0.5310
# — val_kappa: 0.65625
#
# Epoch 00008: val_kappa did not improve from 0.68750
# Confusion matrix:
#  [[18  7]
#  [ 5 22]]
# Epoch 9/35
# 9/9 [==============================] - 22s 2s/step - loss: 0.6109 - mean_absolute_error: 0.4316 - acc: 0.6801 - loss_no_weight_decay: 0.6109 - val_loss: 0.5543 - val_mean_absolute_error: 0.4169 - val_acc: 0.8281 - val_loss_no_weight_decay: 0.5543
# — val_kappa: 0.75
#
# Epoch 00009: val_kappa improved from 0.68750 to 0.75000, saving model to base_2020-05-10-15-04-00-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[20  6]
#  [ 7 19]]
# Epoch 10/35
# 9/9 [==============================] - 22s 2s/step - loss: 0.6416 - mean_absolute_error: 0.4639 - acc: 0.6413 - loss_no_weight_decay: 0.6416 - val_loss: 0.9873 - val_mean_absolute_error: 0.5344 - val_acc: 0.3846 - val_loss_no_weight_decay: 0.9873
# — val_kappa: 0.15625
#
# Epoch 00010: val_kappa did not improve from 0.75000
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Confusion matrix:
#  [[ 0 31]
#  [ 0 21]]
# Epoch 11/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.7001 - mean_absolute_error: 0.4606 - acc: 0.6242 - loss_no_weight_decay: 0.7001 - val_loss: 0.6350 - val_mean_absolute_error: 0.4678 - val_acc: 0.7344 - val_loss_no_weight_decay: 0.6350
# — val_kappa: 0.5625
#
# Epoch 00011: val_kappa did not improve from 0.75000
# Confusion matrix:
#  [[21  5]
#  [ 6 20]]
# Epoch 12/35
# 9/9 [==============================] - 22s 2s/step - loss: 0.6404 - mean_absolute_error: 0.4691 - acc: 0.6926 - loss_no_weight_decay: 0.6404 - val_loss: 0.5536 - val_mean_absolute_error: 0.4184 - val_acc: 0.8462 - val_loss_no_weight_decay: 0.5536
# — val_kappa: 0.625
#
# Epoch 00012: val_kappa did not improve from 0.75000
# Confusion matrix:
#  [[18  5]
#  [ 8 21]]
# Epoch 13/35
# 9/9 [==============================] - 22s 2s/step - loss: 0.5914 - mean_absolute_error: 0.4270 - acc: 0.7357 - loss_no_weight_decay: 0.5914 - val_loss: 0.4400 - val_mean_absolute_error: 0.3377 - val_acc: 0.8438 - val_loss_no_weight_decay: 0.4400
# — val_kappa: 0.5625
#
# Epoch 00013: val_kappa did not improve from 0.75000
# Confusion matrix:
#  [[22  6]
#  [ 2 22]]
# Epoch 14/35
# 9/9 [==============================] - 24s 3s/step - loss: 0.5674 - mean_absolute_error: 0.3907 - acc: 0.7240 - loss_no_weight_decay: 0.5674 - val_loss: 0.5458 - val_mean_absolute_error: 0.3792 - val_acc: 0.6923 - val_loss_no_weight_decay: 0.5458
# — val_kappa: 0.65625
#
# Epoch 00014: val_kappa did not improve from 0.75000
# Confusion matrix:
#  [[18  9]
#  [ 6 19]]
# Epoch 15/35
# 9/9 [==============================] - 21s 2s/step - loss: 0.5612 - mean_absolute_error: 0.3832 - acc: 0.7447 - loss_no_weight_decay: 0.5612 - val_loss: 0.5548 - val_mean_absolute_error: 0.3842 - val_acc: 0.6719 - val_loss_no_weight_decay: 0.5548
# — val_kappa: 0.6875
#
# Epoch 00015: val_kappa did not improve from 0.75000
# Confusion matrix:
#  [[17 14]
#  [ 2 19]]
# Epoch 16/35
# 9/9 [==============================] - 21s 2s/step - loss: 0.5283 - mean_absolute_error: 0.3570 - acc: 0.7447 - loss_no_weight_decay: 0.5283 - val_loss: 0.3629 - val_mean_absolute_error: 0.2691 - val_acc: 0.9038 - val_loss_no_weight_decay: 0.3629
# — val_kappa: 0.5
#
# Epoch 00016: val_kappa did not improve from 0.75000
# Confusion matrix:
#  [[18  9]
#  [ 0 25]]
# Epoch 17/35
# 9/9 [==============================] - 22s 2s/step - loss: 0.5811 - mean_absolute_error: 0.3856 - acc: 0.7064 - loss_no_weight_decay: 0.5811 - val_loss: 0.4608 - val_mean_absolute_error: 0.3449 - val_acc: 0.8438 - val_loss_no_weight_decay: 0.4608
# — val_kappa: 0.625
#
# Epoch 00017: val_kappa did not improve from 0.75000
# Confusion matrix:
#  [[15  9]
#  [ 1 27]]
# Epoch 18/35
# 9/9 [==============================] - 21s 2s/step - loss: 0.5243 - mean_absolute_error: 0.3684 - acc: 0.7515 - loss_no_weight_decay: 0.5243 - val_loss: 0.4551 - val_mean_absolute_error: 0.3231 - val_acc: 0.8077 - val_loss_no_weight_decay: 0.4551
# — val_kappa: 0.5625
#
# Epoch 00018: val_kappa did not improve from 0.75000
# Confusion matrix:
#  [[16  7]
#  [ 1 28]]
# Epoch 19/35
# 9/9 [==============================] - 21s 2s/step - loss: 0.5570 - mean_absolute_error: 0.3789 - acc: 0.6959 - loss_no_weight_decay: 0.5570 - val_loss: 0.4039 - val_mean_absolute_error: 0.3062 - val_acc: 0.8594 - val_loss_no_weight_decay: 0.4039
# — val_kappa: 0.59375
#
# Epoch 00019: val_kappa did not improve from 0.75000
# Confusion matrix:
#  [[19  5]
#  [ 2 26]]
# Epoch 20/35
# 9/9 [==============================] - 20s 2s/step - loss: 0.5110 - mean_absolute_error: 0.3594 - acc: 0.7513 - loss_no_weight_decay: 0.5110 - val_loss: 0.5026 - val_mean_absolute_error: 0.3519 - val_acc: 0.7692 - val_loss_no_weight_decay: 0.5026
# — val_kappa: 0.59375
#
# Epoch 00020: val_kappa did not improve from 0.75000
# Confusion matrix:
#  [[19  7]
#  [ 1 25]]
# Epoch 21/35
# 9/9 [==============================] - 21s 2s/step - loss: 0.5169 - mean_absolute_error: 0.3511 - acc: 0.7325 - loss_no_weight_decay: 0.5169 - val_loss: 0.4269 - val_mean_absolute_error: 0.3036 - val_acc: 0.8281 - val_loss_no_weight_decay: 0.4269
# — val_kappa: 0.5625
#
# Epoch 00021: val_kappa did not improve from 0.75000
# Confusion matrix:
#  [[14  7]
#  [ 1 30]]
# Epoch 22/35
# 9/9 [==============================] - 20s 2s/step - loss: 0.5070 - mean_absolute_error: 0.3499 - acc: 0.7395 - loss_no_weight_decay: 0.5070 - val_loss: 0.4056 - val_mean_absolute_error: 0.2995 - val_acc: 0.8654 - val_loss_no_weight_decay: 0.4056
# — val_kappa: 0.65625
#
# Epoch 00022: val_kappa did not improve from 0.75000
# Confusion matrix:
#  [[16  7]
#  [ 3 26]]
# Epoch 23/35
# 9/9 [==============================] - 20s 2s/step - loss: 0.5145 - mean_absolute_error: 0.3465 - acc: 0.7299 - loss_no_weight_decay: 0.5145 - val_loss: 0.3938 - val_mean_absolute_error: 0.2976 - val_acc: 0.8594 - val_loss_no_weight_decay: 0.3938
# — val_kappa: 0.5625
#
# Epoch 00023: val_kappa did not improve from 0.75000
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Confusion matrix:
#  [[22  4]
#  [ 2 24]]
# Epoch 24/35
# 9/9 [==============================] - 22s 2s/step - loss: 0.5169 - mean_absolute_error: 0.3484 - acc: 0.7656 - loss_no_weight_decay: 0.5169 - val_loss: 0.4944 - val_mean_absolute_error: 0.3398 - val_acc: 0.7885 - val_loss_no_weight_decay: 0.4944
# — val_kappa: 0.65625
#
# Epoch 00024: val_kappa did not improve from 0.75000
# Confusion matrix:
#  [[19  6]
#  [ 1 26]]
# Epoch 25/35
# 9/9 [==============================] - 18s 2s/step - loss: 0.4950 - mean_absolute_error: 0.3373 - acc: 0.7748 - loss_no_weight_decay: 0.4950 - val_loss: 0.4457 - val_mean_absolute_error: 0.3093 - val_acc: 0.7656 - val_loss_no_weight_decay: 0.4457
# — val_kappa: 0.75
#
# Epoch 00025: val_kappa did not improve from 0.75000
# Confusion matrix:
#  [[15 10]
#  [ 1 26]]
# Epoch 26/35
# 9/9 [==============================] - 20s 2s/step - loss: 0.5185 - mean_absolute_error: 0.3436 - acc: 0.7520 - loss_no_weight_decay: 0.5185 - val_loss: 0.4037 - val_mean_absolute_error: 0.2964 - val_acc: 0.8269 - val_loss_no_weight_decay: 0.4037
# — val_kappa: 0.625
#
# Epoch 00026: val_kappa did not improve from 0.75000
# Confusion matrix:
#  [[21  9]
#  [ 3 19]]
# Epoch 27/35
# 9/9 [==============================] - 20s 2s/step - loss: 0.4647 - mean_absolute_error: 0.3235 - acc: 0.7866 - loss_no_weight_decay: 0.4647 - val_loss: 0.4050 - val_mean_absolute_error: 0.3034 - val_acc: 0.8438 - val_loss_no_weight_decay: 0.4050
# — val_kappa: 0.625
#
# Epoch 00027: val_kappa did not improve from 0.75000
# Confusion matrix:
#  [[21  6]
#  [ 1 24]]
# Epoch 28/35
# 9/9 [==============================] - 22s 2s/step - loss: 0.4685 - mean_absolute_error: 0.3252 - acc: 0.7865 - loss_no_weight_decay: 0.4685 - val_loss: 0.4362 - val_mean_absolute_error: 0.2913 - val_acc: 0.8269 - val_loss_no_weight_decay: 0.4362
# — val_kappa: 0.65625
#
# Epoch 00028: val_kappa did not improve from 0.75000
# Confusion matrix:
#  [[16  7]
#  [ 0 29]]
# Epoch 29/35
# 9/9 [==============================] - 20s 2s/step - loss: 0.4624 - mean_absolute_error: 0.3164 - acc: 0.7901 - loss_no_weight_decay: 0.4624 - val_loss: 0.4103 - val_mean_absolute_error: 0.2854 - val_acc: 0.7969 - val_loss_no_weight_decay: 0.4103
# — val_kappa: 0.78125
#
# Epoch 00029: val_kappa improved from 0.75000 to 0.78125, saving model to base_2020-05-10-15-04-00-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[19  8]
#  [ 1 24]]
# Epoch 30/35
# 9/9 [==============================] - 20s 2s/step - loss: 0.4592 - mean_absolute_error: 0.3014 - acc: 0.7883 - loss_no_weight_decay: 0.4592 - val_loss: 0.3590 - val_mean_absolute_error: 0.2583 - val_acc: 0.8846 - val_loss_no_weight_decay: 0.3590
# — val_kappa: 0.625
#
# Epoch 00030: val_kappa did not improve from 0.78125
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Confusion matrix:
#  [[20  5]
#  [ 6 21]]
# Epoch 31/35
# 9/9 [==============================] - 21s 2s/step - loss: 0.4385 - mean_absolute_error: 0.2977 - acc: 0.8159 - loss_no_weight_decay: 0.4385 - val_loss: 0.3550 - val_mean_absolute_error: 0.2611 - val_acc: 0.8594 - val_loss_no_weight_decay: 0.3550
# — val_kappa: 0.65625
#
# Epoch 00031: val_kappa did not improve from 0.78125
# Confusion matrix:
#  [[20  7]
#  [ 0 25]]
# Epoch 32/35
# 9/9 [==============================] - 20s 2s/step - loss: 0.4572 - mean_absolute_error: 0.3043 - acc: 0.7745 - loss_no_weight_decay: 0.4572 - val_loss: 0.3719 - val_mean_absolute_error: 0.2587 - val_acc: 0.8462 - val_loss_no_weight_decay: 0.3719
# — val_kappa: 0.53125
#
# Epoch 00032: val_kappa did not improve from 0.78125
# Confusion matrix:
#  [[20  2]
#  [ 1 29]]
# Epoch 33/35
# 9/9 [==============================] - 21s 2s/step - loss: 0.4109 - mean_absolute_error: 0.2862 - acc: 0.8056 - loss_no_weight_decay: 0.4109 - val_loss: 0.3742 - val_mean_absolute_error: 0.2614 - val_acc: 0.8281 - val_loss_no_weight_decay: 0.3742
# — val_kappa: 0.78125
#
# Epoch 00033: val_kappa did not improve from 0.78125
# Confusion matrix:
#  [[19  8]
#  [ 1 24]]
# Epoch 34/35
# 9/9 [==============================] - 22s 2s/step - loss: 0.4528 - mean_absolute_error: 0.3010 - acc: 0.7899 - loss_no_weight_decay: 0.4528 - val_loss: 0.3501 - val_mean_absolute_error: 0.2525 - val_acc: 0.8846 - val_loss_no_weight_decay: 0.3501
# — val_kappa: 0.71875
#
# Epoch 00034: val_kappa did not improve from 0.78125
# Confusion matrix:
#  [[19  9]
#  [ 1 23]]
# Epoch 35/35
# 9/9 [==============================] - 20s 2s/step - loss: 0.4088 - mean_absolute_error: 0.2753 - acc: 0.8284 - loss_no_weight_decay: 0.4088 - val_loss: 0.3157 - val_mean_absolute_error: 0.2355 - val_acc: 0.8438 - val_loss_no_weight_decay: 0.3157
# — val_kappa: 0.6875
#
# Epoch 00035: val_kappa did not improve from 0.78125
# Confusion matrix:
#  [[26  5]
#  [ 1 20]]
# 176/176 [==============================] - 3s 15ms/step
# 176/176 [==============================] - 2s 14ms/step
# Test loss: 0.4463514558050189
# Test accuracy: 0.2988855002913624
# Confusion Matrix
# [[64 24]
#  [12 76]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.84      0.73      0.78        88
#            1       0.76      0.86      0.81        88
#
#     accuracy                           0.80       176
#    macro avg       0.80      0.80      0.79       176
# weighted avg       0.80      0.80      0.79       176

# %%
from Kappa_Skl import kappa
def kappa2(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    if len(y_true.shape) > 1 and y_true.shape[1] > 1:
        y_true = y_true.dot(range(y_true.shape[1]))
    if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
        y_pred = y_pred.dot(range(y_pred.shape[1]))
    try:
        return kappa(y_true, y_pred, weights='quadratic')
    except IndexError:
        return np.nan
    
print('Quadratic_wieghted_kappa')
print(kappa2(y_true, y_pred))
# Out:
# Quadratic_wieghted_kappa
# 0.5909090909090909

# %%
import numpy as np 
import matplotlib.pyplot as plt
import os
import wandb
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model loss.png')

# summarize history for val_kappa
plt.plot(history.history['val_kappa'])
plt.title('Validation_Kappa')
plt.ylabel('val_kappa')
plt.xlabel('epoch')
plt.legend([ 'validation'], loc='upper left')
plt.show()
#plt.savefig('model validation_kappa.png')

# summarize history for mean_absolute _error
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model mean_absolute_error')
plt.ylabel('mean_absolute_error')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model maey.png'
# Out:
# dict_keys(['val_loss', 'val_mean_absolute_error', 'val_acc', 'val_loss_no_weight_decay', 'loss', 'mean_absolute_error', 'acc', 'loss_no_weight_decay', 'val_kappa', 'lr'])
