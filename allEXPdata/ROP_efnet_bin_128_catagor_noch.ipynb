# %%
import efficientnet.keras as efn
from keras.models import Model, model_from_json
from keras.regularizers import l1_l2
from keras.layers import Dense, Dropout
from keras.optimizers import SGD, Adam
import pandas as pd
from keras_preprocessing.image import ImageDataGenerator
from datetime import datetime as dt
from sklearn.utils import class_weight
from keras.callbacks import EarlyStopping, ModelCheckpoint,LearningRateScheduler, TensorBoard
import keras.backend as K
from VCM import VCM 
from keras.initializers import Constant,Orthogonal
from keras import regularizers
from Kappa_Skl import kappa
import keras.backend as K
import matplotlib.pyplot as plt
import itertools
from Homotopy import Homotopy 
from QWK import QWK
import tensorflow as tf
from Fractional_MAXPOOL import FractionalPooling2D

import numpy as np 
import matplotlib.pyplot as plt
import os
import wandb
#from wandb.keras import WandbCallback
#wandb.init(project="rop")


top_layers_checkpoint_path = 'cp.top.best.hdf5'
fine_tuned_checkpoint_path = 'cp.fine_tuned.best.hdf5'
new_extended_inception_weights = 'final_weights.hdf5'





def get_experiment_id():
    time_str = dt.now().strftime('%Y-%m-%d-%H-%M-%S')
    experiment_id = 'base_{}'.format(time_str)
    return experiment_id

#def scheduler(epoch):
#    if epoch == 150:
#        K.set_value(model.optimizer.lr, 0.00003)
#    return K.get_value(model.optimizer.lr)


def create_model():
    base_model = efn.EfficientNetB0(weights=None,
                        include_top=False,
                        input_shape=(128, 128, 3), pooling='avg')
#    base_model._layers.pop()
#    model2 = Model(base_model.input, base_model.layers[-1].output)
##    base_model = InceptionV3(weights=None , include_top=False, input_tensor=None, input_shape=(299, 299, 3), pooling='avg') 
    x = base_model.output
    x = Dense(2, activation="softmax")(x)
    model = Model(inputs = base_model.input, outputs = x)
    model.load_weights('base_2019-12-11-23-01-58-val_kappa_checkpoint.hdf5')
#    model._layers.pop()
#    x = Model(model.input, model.layers[-1].output)
#    model.save_weights("tmp.h5")
#    top_layers_checkpoint_path = 'cp.top.best.hdf5'

#    # first: train only the top layers (which were randomly initialized)
#    # i.e. freeze all convolutional InceptionV3 layers
    for layer in base_model.layers:
        layer.trainable = False
#    
#    
#
##    regularizer = l1_l2(l1=0.0005, l2=0.0005)
##    for layer in model.layers:
##        for attr in ['kernel_regularizer', 'bias_regularizer']:
##            if hasattr(layer, attr) and layer.trainable:
##                setattr(layer, attr, regularizer)
#
##
#    out = model_from_json(model.to_json())
#    out.load_weights("tmp.h5", by_name=True)
#
    return model


model = create_model()




radam = Adam(lr=0.0014339, beta_1=0.9, beta_2=0.999, epsilon=0.1, decay=1e-6, amsgrad=False)
model.compile(loss='categorical_crossentropy', optimizer=radam, metrics=['mae','acc'])

#sgd = SGD(lr=0.0003, decay=1e-6, momentum=0.9, nesterov=True)
#model.compile(loss='mse', optimizer=sgd, metrics=['mae', 'acc'])

experiment_id = get_experiment_id()


train_datagen = ImageDataGenerator(
        rescale=1./255,
#        featurewise_center=True,
 #       samplewise_center=True,
        shear_range=0,
        zoom_range=0.0,#[1 / 1.15, 1.15],
        horizontal_flip=False,#True,
        rotation_range=0)#90,
#        validation_split=0.2)
"""
For the test set only rescale should be made 
"""
test_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas_noch/train",
    target_size=(128, 128),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="training")
#    save_to_dir="D:/Separating Images into subfolders/train_augmented")


#print(train_generator.class_indices)

valid_generator = valid_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas_noch/vald",
    target_size=(128, 128),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="validation")
#    save_to_dir="D:/Separating Images into subfolders/val_augmented"


test_generator = test_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas_noch/test",
    target_size=(128, 128),
    color_mode="rgb",
    batch_size=1,
    class_mode="categorical",
    shuffle=False,
    seed=42)
#    save_to_dir="D:/Separating Images into subfolders/test_augmented")


# Fitting/Training the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
experiment_id = get_experiment_id()


class_weight_list = class_weight.compute_class_weight('balanced', np.unique(train_generator.classes), train_generator.classes)
class_weights = dict(zip(np.unique(train_generator.classes), class_weight_list))

callbacks = [
#    Resample_Iterator(balance_weights),
    QWK(valid_generator, STEP_SIZE_VALID),
    ModelCheckpoint(top_layers_checkpoint_path, monitor='val_kappa', verbose=1, save_best_only=True, mode='max'),
#    EarlyStopping(monitor='val_kappa', patience=10, min_delta=0.001, verbose=1, restore_best_weights=True, mode='max',baseline=None),
    VCM(valid_generator, STEP_SIZE_VALID),
#    LearningRateScheduler(scheduler, verbose=1),
 #   TensorBoard(log_dir='./Graph', histogram_freq=0, write_graph=True, write_images=True),        
]




# train the model on the new data for a few epochs

history1=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
#                    class_weight=[balance_weights],
                    callbacks=callbacks,
                    epochs=10  
)


 

callbacks1 = [
#    Resample_Iterator(balance_weights1),
    QWK(valid_generator, STEP_SIZE_VALID),
    ModelCheckpoint(fine_tuned_checkpoint_path, monitor='val_kappa', verbose=1, save_best_only=True, mode='max'),
#    EarlyStopping(monitor='val_kappa', patience=20, min_delta=0.001, verbose=1, restore_best_weights=True, mode='max',baseline=None),
    VCM(valid_generator, STEP_SIZE_VALID),
#    LearningRateScheduler(scheduler, verbose=1),
#    TensorBoard(log_dir='./Graph', histogram_freq=0, write_graph=True, write_images=True),        
]



for layer in model.layers:
    layer.trainable = True
    
    
    
    
radam = Adam(lr=0.0014339, beta_1=0.9, beta_2=0.999, epsilon=0.1, decay=1e-6, amsgrad=False)
model.compile(loss='categorical_crossentropy', optimizer=radam, metrics=['mae','acc'])



# we train our model again (this time fine-tuning the top 2 inception blocks
# alongside the top Dense layers
history=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
#                    class_weight=[balance_weights1],
                    callbacks=callbacks1,
                    epochs=30) 




test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test mae:', score[1])
print('Test accuracy:', score[2])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1']
print(classification_report(y_true, y_pred, target_names=target_names))
                    
                    
# list all data in history
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model loss.png')

# summarize history for val_kappa
plt.plot(history.history['val_kappa'])
plt.title('Validation_Kappa')
plt.ylabel('val_kappa')
plt.xlabel('epoch')
plt.legend([ 'validation'], loc='upper left')
plt.show()
#plt.savefig('model validation_kappa.png')

# summarize history for mean_absolute _error
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model mean_absolute_error')
plt.ylabel('mean_absolute_error')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model maey.png')
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Found 582 images belonging to 2 classes.
# Found 78 images belonging to 2 classes.
# Found 121 images belonging to 2 classes.
# Epoch 1/10
# 9/9 [==============================] - 14s 2s/step - loss: 0.9822 - mean_absolute_error: 0.4612 - acc: 0.5425 - val_loss: 0.8305 - val_mean_absolute_error: 0.5008 - val_acc: 0.4688
# — val_kappa: 0.0
#
# Epoch 00001: val_kappa improved from -inf to 0.00000, saving model to cp.top.best.hdf5
# Confusion matrix:
#  [[8 2]
#  [3 1]]
# Epoch 2/10
# 9/9 [==============================] - 11s 1s/step - loss: 0.9440 - mean_absolute_error: 0.4619 - acc: 0.5176 - val_loss: 0.5442 - val_mean_absolute_error: 0.3958 - val_acc: 0.7857
# — val_kappa: 0.1875
#
# Epoch 00002: val_kappa improved from 0.00000 to 0.18750, saving model to cp.top.best.hdf5
# Confusion matrix:
#  [[7 4]
#  [1 2]]
# Epoch 3/10
# 9/9 [==============================] - 9s 999ms/step - loss: 0.8676 - mean_absolute_error: 0.4396 - acc: 0.5590 - val_loss: 0.8007 - val_mean_absolute_error: 0.4979 - val_acc: 0.5156
# — val_kappa: 0.125
#
# Epoch 00003: val_kappa did not improve from 0.18750
# Confusion matrix:
#  [[5 6]
#  [2 1]]
# Epoch 4/10
# 9/9 [==============================] - 9s 985ms/step - loss: 0.8303 - mean_absolute_error: 0.4440 - acc: 0.5499 - val_loss: 0.6302 - val_mean_absolute_error: 0.4133 - val_acc: 0.6429
# — val_kappa: 0.125
#
# Epoch 00004: val_kappa did not improve from 0.18750
# Confusion matrix:
#  [[5 6]
#  [1 2]]
# Epoch 5/10
# 9/9 [==============================] - 10s 1s/step - loss: 0.7927 - mean_absolute_error: 0.4280 - acc: 0.5808 - val_loss: 0.7626 - val_mean_absolute_error: 0.4802 - val_acc: 0.5469
# — val_kappa: -0.03125
#
# Epoch 00005: val_kappa did not improve from 0.18750
# Confusion matrix:
#  [[11  1]
#  [ 2  0]]
# Epoch 6/10
# 9/9 [==============================] - 10s 1s/step - loss: 0.7234 - mean_absolute_error: 0.4191 - acc: 0.5833 - val_loss: 0.7532 - val_mean_absolute_error: 0.4883 - val_acc: 0.4286
# — val_kappa: 0.0
#
# Epoch 00006: val_kappa did not improve from 0.18750
# Confusion matrix:
#  [[4 7]
#  [2 1]]
# Epoch 7/10
# 9/9 [==============================] - 10s 1s/step - loss: 0.6075 - mean_absolute_error: 0.3726 - acc: 0.6836 - val_loss: 0.7417 - val_mean_absolute_error: 0.4718 - val_acc: 0.5469
# — val_kappa: 0.0
#
# Epoch 00007: val_kappa did not improve from 0.18750
# Confusion matrix:
#  [[6 5]
#  [1 2]]
# Epoch 8/10
# 9/9 [==============================] - 9s 951ms/step - loss: 0.5999 - mean_absolute_error: 0.3735 - acc: 0.6731 - val_loss: 0.7230 - val_mean_absolute_error: 0.4769 - val_acc: 0.3571
# — val_kappa: 0.0
#
# Epoch 00008: val_kappa did not improve from 0.18750
# Confusion matrix:
#  [[5 6]
#  [2 1]]
# Epoch 9/10
# 9/9 [==============================] - 9s 1s/step - loss: 0.5393 - mean_absolute_error: 0.3509 - acc: 0.7072 - val_loss: 0.7439 - val_mean_absolute_error: 0.4689 - val_acc: 0.5312
# — val_kappa: -0.03125
#
# Epoch 00009: val_kappa did not improve from 0.18750
# Confusion matrix:
#  [[5 6]
#  [0 3]]
# Epoch 10/10
# 9/9 [==============================] - 10s 1s/step - loss: 0.4765 - mean_absolute_error: 0.3195 - acc: 0.7539 - val_loss: 0.6573 - val_mean_absolute_error: 0.4493 - val_acc: 0.4286
# — val_kappa: 0.125
#
# Epoch 00010: val_kappa did not improve from 0.18750
# Confusion matrix:
#  [[3 7]
#  [1 3]]
# Epoch 1/30
# 9/9 [==============================] - 15s 2s/step - loss: 0.4615 - mean_absolute_error: 0.3161 - acc: 0.7704 - val_loss: 0.4089 - val_mean_absolute_error: 0.2740 - val_acc: 0.7969
# — val_kappa: 0.5
#
# Epoch 00001: val_kappa improved from -inf to 0.50000, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  [[8 3]
#  [0 3]]
# Epoch 2/30
# 9/9 [==============================] - 13s 1s/step - loss: 0.4041 - mean_absolute_error: 0.2808 - acc: 0.8281 - val_loss: 0.6162 - val_mean_absolute_error: 0.3481 - val_acc: 0.5714
# — val_kappa: 0.6875
#
# Epoch 00002: val_kappa improved from 0.50000 to 0.68750, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  [[8 3]
#  [0 3]]
# Epoch 3/30
# 9/9 [==============================] - 9s 1s/step - loss: 0.4475 - mean_absolute_error: 0.2988 - acc: 0.7688 - val_loss: 0.3084 - val_mean_absolute_error: 0.2223 - val_acc: 0.8281
# — val_kappa: 0.625
#
# Epoch 00003: val_kappa did not improve from 0.68750
# Confusion matrix:
#  [[8 2]
#  [0 4]]
# Epoch 4/30
# 9/9 [==============================] - 10s 1s/step - loss: 0.3053 - mean_absolute_error: 0.2268 - acc: 0.9017 - val_loss: 0.3899 - val_mean_absolute_error: 0.2524 - val_acc: 0.7143
# — val_kappa: 0.75
#
# Epoch 00004: val_kappa improved from 0.68750 to 0.75000, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  [[9 1]
#  [0 4]]
# Epoch 5/30
# 9/9 [==============================] - 11s 1s/step - loss: 0.2697 - mean_absolute_error: 0.2078 - acc: 0.9062 - val_loss: 0.2795 - val_mean_absolute_error: 0.2040 - val_acc: 0.8750
# — val_kappa: 0.75
#
# Epoch 00005: val_kappa did not improve from 0.75000
# Confusion matrix:
#  [[11  1]
#  [ 0  2]]
# Epoch 6/30
# 9/9 [==============================] - 9s 983ms/step - loss: 0.2511 - mean_absolute_error: 0.1893 - acc: 0.9393 - val_loss: 0.1093 - val_mean_absolute_error: 0.0911 - val_acc: 0.9286
# — val_kappa: 0.78125
#
# Epoch 00006: val_kappa improved from 0.75000 to 0.78125, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  [[9 2]
#  [0 3]]
# Epoch 7/30
# 9/9 [==============================] - 8s 918ms/step - loss: 0.1995 - mean_absolute_error: 0.1598 - acc: 0.9596 - val_loss: 0.1775 - val_mean_absolute_error: 0.1404 - val_acc: 0.9219
# — val_kappa: 0.8125
#
# Epoch 00007: val_kappa improved from 0.78125 to 0.81250, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  [[8 1]
#  [0 5]]
# Epoch 8/30
# 9/9 [==============================] - 9s 1s/step - loss: 0.1630 - mean_absolute_error: 0.1334 - acc: 0.9644 - val_loss: 0.2025 - val_mean_absolute_error: 0.1512 - val_acc: 0.8571
# — val_kappa: 0.84375
#
# Epoch 00008: val_kappa improved from 0.81250 to 0.84375, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  [[11  2]
#  [ 0  1]]
# Epoch 9/30
# 9/9 [==============================] - 12s 1s/step - loss: 0.1419 - mean_absolute_error: 0.1173 - acc: 0.9740 - val_loss: 0.1352 - val_mean_absolute_error: 0.1089 - val_acc: 0.9531
# — val_kappa: 0.875
#
# Epoch 00009: val_kappa improved from 0.84375 to 0.87500, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  [[8 1]
#  [0 5]]
# Epoch 10/30
# 9/9 [==============================] - 9s 973ms/step - loss: 0.1222 - mean_absolute_error: 0.1044 - acc: 0.9789 - val_loss: 0.2059 - val_mean_absolute_error: 0.1601 - val_acc: 0.8571
# — val_kappa: 0.875
#
# Epoch 00010: val_kappa did not improve from 0.87500
# Confusion matrix:
#  [[7 1]
#  [0 6]]
# Epoch 11/30
# 9/9 [==============================] - 11s 1s/step - loss: 0.1357 - mean_absolute_error: 0.1131 - acc: 0.9691 - val_loss: 0.1203 - val_mean_absolute_error: 0.0989 - val_acc: 0.9531
# — val_kappa: 0.875
#
# Epoch 00011: val_kappa did not improve from 0.87500
# Confusion matrix:
#  [[13  0]
#  [ 0  1]]
# Epoch 12/30
# 9/9 [==============================] - 13s 1s/step - loss: 0.1149 - mean_absolute_error: 0.0973 - acc: 0.9844 - val_loss: 0.1374 - val_mean_absolute_error: 0.1059 - val_acc: 0.9286
# — val_kappa: 0.90625
#
# Epoch 00012: val_kappa improved from 0.87500 to 0.90625, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  [[10  1]
#  [ 0  3]]
# Epoch 13/30
# 9/9 [==============================] - 11s 1s/step - loss: 0.1906 - mean_absolute_error: 0.1264 - acc: 0.9387 - val_loss: 0.0857 - val_mean_absolute_error: 0.0713 - val_acc: 0.9688
# — val_kappa: 0.9375
#
# Epoch 00013: val_kappa improved from 0.90625 to 0.93750, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  [[9 1]
#  [0 4]]
# Epoch 14/30
# 9/9 [==============================] - 9s 1s/step - loss: 0.1040 - mean_absolute_error: 0.0899 - acc: 0.9877 - val_loss: 0.1963 - val_mean_absolute_error: 0.1573 - val_acc: 0.9286
# — val_kappa: 0.90625
#
# Epoch 00014: val_kappa did not improve from 0.93750
# Confusion matrix:
#  [[10  0]
#  [ 0  4]]
# Epoch 15/30
# 9/9 [==============================] - 10s 1s/step - loss: 0.0826 - mean_absolute_error: 0.0705 - acc: 0.9912 - val_loss: 0.0972 - val_mean_absolute_error: 0.0794 - val_acc: 0.9688
# — val_kappa: 0.9375
#
# Epoch 00015: val_kappa did not improve from 0.93750
# Confusion matrix:
#  [[11  0]
#  [ 0  3]]
# Epoch 16/30
# 9/9 [==============================] - 10s 1s/step - loss: 0.0781 - mean_absolute_error: 0.0671 - acc: 0.9744 - val_loss: 0.0868 - val_mean_absolute_error: 0.0780 - val_acc: 1.0000
# — val_kappa: 0.9375
#
# Epoch 00016: val_kappa did not improve from 0.93750
# Confusion matrix:
#  [[8 0]
#  [0 6]]
# Epoch 17/30
# 9/9 [==============================] - 10s 1s/step - loss: 0.0776 - mean_absolute_error: 0.0677 - acc: 0.9877 - val_loss: 0.0956 - val_mean_absolute_error: 0.0792 - val_acc: 0.9688
# — val_kappa: 0.9375
#
# Epoch 00017: val_kappa did not improve from 0.93750
# Confusion matrix:
#  [[9 0]
#  [0 5]]
# Epoch 18/30
# 9/9 [==============================] - 10s 1s/step - loss: 0.0627 - mean_absolute_error: 0.0555 - acc: 0.9931 - val_loss: 0.0255 - val_mean_absolute_error: 0.0247 - val_acc: 1.0000
# — val_kappa: 0.9375
#
# Epoch 00018: val_kappa did not improve from 0.93750
# Confusion matrix:
#  [[11  0]
#  [ 0  3]]
# Epoch 19/30
# 9/9 [==============================] - 8s 941ms/step - loss: 0.0838 - mean_absolute_error: 0.0682 - acc: 0.9796 - val_loss: 0.0620 - val_mean_absolute_error: 0.0537 - val_acc: 0.9844
# — val_kappa: 0.96875
#
# Epoch 00019: val_kappa improved from 0.93750 to 0.96875, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  [[9 1]
#  [0 4]]
# Epoch 20/30
# 9/9 [==============================] - 11s 1s/step - loss: 0.0524 - mean_absolute_error: 0.0479 - acc: 1.0000 - val_loss: 0.0790 - val_mean_absolute_error: 0.0724 - val_acc: 1.0000
# — val_kappa: 0.9375
#
# Epoch 00020: val_kappa did not improve from 0.96875
# Confusion matrix:
#  [[10  0]
#  [ 0  4]]
# Epoch 21/30
# 9/9 [==============================] - 11s 1s/step - loss: 0.0737 - mean_absolute_error: 0.0641 - acc: 0.9982 - val_loss: 0.0586 - val_mean_absolute_error: 0.0493 - val_acc: 0.9844
# — val_kappa: 0.96875
#
# Epoch 00021: val_kappa did not improve from 0.96875
# Confusion matrix:
#  [[10  0]
#  [ 0  4]]
# Epoch 22/30
# 9/9 [==============================] - 10s 1s/step - loss: 0.0506 - mean_absolute_error: 0.0456 - acc: 0.9947 - val_loss: 0.0915 - val_mean_absolute_error: 0.0810 - val_acc: 1.0000
# — val_kappa: 0.9375
#
# Epoch 00022: val_kappa did not improve from 0.96875
# Confusion matrix:
#  [[9 0]
#  [0 5]]
# Epoch 23/30
# 9/9 [==============================] - 9s 1s/step - loss: 0.0571 - mean_absolute_error: 0.0485 - acc: 0.9779 - val_loss: 0.0617 - val_mean_absolute_error: 0.0514 - val_acc: 0.9688
# — val_kappa: 0.96875
#
# Epoch 00023: val_kappa did not improve from 0.96875
# Confusion matrix:
#  [[11  1]
#  [ 0  2]]
# Epoch 24/30
# 9/9 [==============================] - 10s 1s/step - loss: 0.0410 - mean_absolute_error: 0.0368 - acc: 0.9965 - val_loss: 0.0549 - val_mean_absolute_error: 0.0505 - val_acc: 1.0000
# — val_kappa: 0.9375
#
# Epoch 00024: val_kappa did not improve from 0.96875
# Confusion matrix:
#  [[11  0]
#  [ 0  3]]
# Epoch 25/30
# 9/9 [==============================] - 9s 1s/step - loss: 0.0512 - mean_absolute_error: 0.0444 - acc: 0.9831 - val_loss: 0.0659 - val_mean_absolute_error: 0.0539 - val_acc: 0.9688
# — val_kappa: 0.9375
#
# Epoch 00025: val_kappa did not improve from 0.96875
# Confusion matrix:
#  [[12  0]
#  [ 0  2]]
# Epoch 26/30
# 9/9 [==============================] - 8s 847ms/step - loss: 0.0510 - mean_absolute_error: 0.0448 - acc: 0.9982 - val_loss: 0.0224 - val_mean_absolute_error: 0.0218 - val_acc: 1.0000
# — val_kappa: 0.9375
#
# Epoch 00026: val_kappa did not improve from 0.96875
# Confusion matrix:
#  [[8 1]
#  [0 5]]
# Epoch 27/30
# 9/9 [==============================] - 9s 1s/step - loss: 0.0306 - mean_absolute_error: 0.0277 - acc: 0.9965 - val_loss: 0.0476 - val_mean_absolute_error: 0.0411 - val_acc: 0.9844
# — val_kappa: 0.9375
#
# Epoch 00027: val_kappa did not improve from 0.96875
# Confusion matrix:
#  [[11  0]
#  [ 0  3]]
# Epoch 28/30
# 9/9 [==============================] - 10s 1s/step - loss: 0.0363 - mean_absolute_error: 0.0310 - acc: 0.9948 - val_loss: 0.0868 - val_mean_absolute_error: 0.0672 - val_acc: 0.9286
# — val_kappa: 0.96875
#
# Epoch 00028: val_kappa did not improve from 0.96875
# Confusion matrix:
#  [[10  0]
#  [ 0  4]]
# Epoch 29/30
# 9/9 [==============================] - 10s 1s/step - loss: 0.0310 - mean_absolute_error: 0.0290 - acc: 0.9982 - val_loss: 0.0516 - val_mean_absolute_error: 0.0435 - val_acc: 0.9844
# — val_kappa: 0.96875
#
# Epoch 00029: val_kappa did not improve from 0.96875
# Confusion matrix:
#  [[11  0]
#  [ 0  3]]
# Epoch 30/30
# 9/9 [==============================] - 11s 1s/step - loss: 0.0416 - mean_absolute_error: 0.0367 - acc: 1.0000 - val_loss: 0.0437 - val_mean_absolute_error: 0.0396 - val_acc: 1.0000
# — val_kappa: 1.0
#
# Epoch 00030: val_kappa improved from 0.96875 to 1.00000, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  [[12  1]
#  [ 0  1]]
# 121/121 [==============================] - 5s 38ms/step
# 121/121 [==============================] - 5s 39ms/step
# Test loss: 0.048244956795059815
# Test mae: 0.03836459807172097
# Test accuracy: 0.9834710743801653
# Confusion Matrix
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-44965133eff6> in <module>
#     247 # generator.classes gives you the truth label y_true
#     248 print('Confusion Matrix')
# --> 249 cm = confusion_matrix(y_true, y_pred)
#     250
#     251 print(cm)
#
# NameError: name 'confusion_matrix' is not defined

# %%
from sklearn.metrics import confusion_matrix, classification_report

test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test mae:', score[1])
print('Test accuracy:', score[2])


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# 121/121 [==============================] - 5s 40ms/step
# 121/121 [==============================] - 4s 36ms/step
# Test loss: 0.048244956795059815
# Test mae: 0.03836459807172097
# Test accuracy: 0.9834710743801653
# Confusion Matrix
# [[86  2]
#  [ 0 33]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99        88
#            1       0.94      1.00      0.97        33
#
#     accuracy                           0.98       121
#    macro avg       0.97      0.99      0.98       121
# weighted avg       0.98      0.98      0.98       121

# %%
def kappa2(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    if len(y_true.shape) > 1 and y_true.shape[1] > 1:
        y_true = y_true.dot(range(y_true.shape[1]))
    if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
        y_pred = y_pred.dot(range(y_pred.shape[1]))
    try:
        return kappa(y_true, y_pred, weights='quadratic')
    except IndexError:
        return np.nan
    
print('Quadratic_wieghted_kappa')
print(kappa2(y_true, y_pred))
# Out:
# Quadratic_wieghted_kappa
# 0.9591078066914498

# %%
# list all data in history
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model loss.png')

# summarize history for val_kappa
plt.plot(history.history['val_kappa'])
plt.title('Validation_Kappa')
plt.ylabel('val_kappa')
plt.xlabel('epoch')
plt.legend([ 'validation'], loc='upper left')
plt.show()
#plt.savefig('model validation_kappa.png')

# summarize history for mean_absolute _error
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model mean_absolute_error')
plt.ylabel('mean_absolute_error')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model maey.png')
# Out:
# dict_keys(['val_loss', 'val_mean_absolute_error', 'val_acc', 'loss', 'mean_absolute_error', 'acc', 'val_kappa'])
