# %%
import keras
from keras.models import Sequential, Input, Model
from keras.losses import mean_squared_error
from keras.layers import  *
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, InputLayer
from keras.regularizers import L1L2, l2, l1
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from custom_pooling import RMSPooling2D
from keras.optimizers import SGD, Adam
from keras.layers import LeakyReLU
#from data import BALANCE_WEIGHTS
from keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
#import os
from datetime import datetime as dt
from custom_loss import WeightedCategoricalCrossEntropy
from VCM import VCM
import keras.backend as K
from Fractional_MAXPOOL import FractionalPooling2D
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
def get_experiment_id():
    time_str = dt.now().strftime('%Y-%m-%d-%H-%M-%S')
    experiment_id = 'base_{}'.format(time_str)
    return experiment_id
p_ratio=[1.0, 1.44, 1.73, 1.0]

model = Sequential()


model.add(Conv2D(16, (5, 5), activation='tanh', input_shape=(270, 270, 3)))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(16, (3, 3), activation='tanh'))
model.add(Conv2D(16, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

#model.add(LeakyReLU(alpha=0.01))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))


model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))


model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))


#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))



#model.add(MaxPooling2D(pool_size=1))




model.add(MaxPooling2D(pool_size=2))

model.add(Flatten())


#chnaged from 10 to 5 because an error 
model.add(Dense(3, activation='softmax'))

sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.count_params()
#adam = Adam(lr=0.0005, decay=1e-6)
#rmsprop
#Mloss = WeightedCategoricalCrossEntropy({0: 0.4125861396437394, 1: 1.4918664786083686, 2: 0.690426457789382, 3: 3.9541433021806855, 4: 4.885604311008468})
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['acc','mae'])
model.summary()
loss_no_weight_decay = model.total_loss - sum(model.losses)
model.metrics_tensors.append(loss_no_weight_decay)
model.metrics_names.append('loss_no_weight_decay')
#############################################################################################
#############################################################################################
#############################################################################################
#############################################################################################
#Preparing Data Augmentation Configuration 
train_datagen = ImageDataGenerator(
        rescale=1./255,
#        featurewise_center=True,
 #       samplewise_center=True,
        shear_range=0,
        zoom_range=0.0,#[1 / 1.15, 1.15],
        horizontal_flip=False,#True,
        rotation_range=0)#90,
#        validation_split=0.2)
"""
For the test set only rescale should be made 
"""
test_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/threeclass_noch/train",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="training")
#    save_to_dir="D:/Separating Images into subfolders/train_augmented")


#print(train_generator.class_indices)

valid_generator = valid_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/threeclass_noch/vald",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="validation")
#    save_to_dir="D:/Separating Images into subfolders/val_augmented"


test_generator = test_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/threeclass_noch/test",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=1,
    class_mode="categorical",
    shuffle=False,
    seed=42)
#    save_to_dir="D:/Separating Images into subfolders/test_augmented")


# Fitting/Training the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
experiment_id = get_experiment_id()
callbacks = [
    EarlyStopping(monitor='val_acc', patience=50, min_delta=0.001, verbose=1),
    ModelCheckpoint(experiment_id + "-val_acc_checkpoint.hdf5", monitor='val_acc', verbose=1, save_best_only=True, mode='auto'),
    ReduceLROnPlateau(monitor='val_acc', factor=0.5, patience=7, verbose=1, mode='auto', min_delta=0.001, cooldown=0, min_lr=1e-7),
    VCM(valid_generator,STEP_SIZE_VALID)
    
]

class_weight_list = class_weight.compute_class_weight('balanced', np.unique(train_generator.classes), train_generator.classes)
class_weights = dict(zip(np.unique(train_generator.classes), class_weight_list))

history=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    #class_weight=class_weights,
                    callbacks=callbacks,
                    epochs=35  
)


# Evaluating the model 
#predicting output
#reseting the test generator before calling predict_generator, in order not to get weird output
test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1', '2']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 266, 266, 16)      1216
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 262, 262, 16)      6416
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 260, 260, 16)      2320
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 258, 258, 16)      2320
# _________________________________________________________________
# fractional_pooling2d_1 (Frac (None, 143, 143, 16)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 139, 139, 16)      6416
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 135, 135, 16)      6416
# _________________________________________________________________
# fractional_pooling2d_2 (Frac (None, 75, 75, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 71, 71, 16)        6416
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 67, 67, 16)        6416
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 65, 65, 32)        4640
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 63, 63, 32)        9248
# _________________________________________________________________
# fractional_pooling2d_3 (Frac (None, 35, 35, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 33, 33, 32)        9248
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 31, 31, 32)        9248
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 29, 29, 64)        18496
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 27, 27, 64)        36928
# _________________________________________________________________
# fractional_pooling2d_4 (Frac (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 13, 13, 64)        36928
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 11, 11, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1600)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 4803
# =================================================================
# Total params: 204,403
# Trainable params: 204,403
# Non-trainable params: 0
# _________________________________________________________________
# Found 579 images belonging to 3 classes.
# Found 81 images belonging to 3 classes.
# Found 121 images belonging to 3 classes.
# Epoch 1/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.9790 - acc: 0.4641 - mean_absolute_error: 0.4117 - loss_no_weight_decay: 0.9790 - val_loss: 0.7891 - val_acc: 0.7500 - val_mean_absolute_error: 0.3457 - val_loss_no_weight_decay: 0.7891
#
# Epoch 00001: val_acc improved from -inf to 0.75000, saving model to base_2020-05-12-13-41-18-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[46  0  0]
#  [ 4  0  0]
#  [14  0  0]]
# Epoch 2/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.9041 - acc: 0.4551 - mean_absolute_error: 0.3708 - loss_no_weight_decay: 0.9041 - val_loss: 1.0214 - val_acc: 0.5882 - val_mean_absolute_error: 0.3775 - val_loss_no_weight_decay: 1.0214
#
# Epoch 00002: val_acc did not improve from 0.75000
# Confusion matrix:
#  [[12  0]
#  [ 5  0]]
# Epoch 3/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.9225 - acc: 0.4269 - mean_absolute_error: 0.3717 - loss_no_weight_decay: 0.9225 - val_loss: 0.8987 - val_acc: 0.6562 - val_mean_absolute_error: 0.3878 - val_loss_no_weight_decay: 0.8987
#
# Epoch 00003: val_acc did not improve from 0.75000
# Confusion matrix:
#  [[47  0  0]
#  [ 4  0  0]
#  [13  0  0]]
# Epoch 4/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.8578 - acc: 0.5854 - mean_absolute_error: 0.3636 - loss_no_weight_decay: 0.8578 - val_loss: 0.6488 - val_acc: 0.7059 - val_mean_absolute_error: 0.2768 - val_loss_no_weight_decay: 0.6488
#
# Epoch 00004: val_acc did not improve from 0.75000
# Confusion matrix:
#  [[14  0]
#  [ 3  0]]
# Epoch 5/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.9757 - acc: 0.4444 - mean_absolute_error: 0.3799 - loss_no_weight_decay: 0.9757 - val_loss: 0.9167 - val_acc: 0.3125 - val_mean_absolute_error: 0.3890 - val_loss_no_weight_decay: 0.9167
#
# Epoch 00005: val_acc did not improve from 0.75000
# Confusion matrix:
#  [[46  0  0]
#  [ 4  0  0]
#  [14  0  0]]
# Epoch 6/35
# 9/9 [==============================] - 16s 2s/step - loss: 0.8764 - acc: 0.4832 - mean_absolute_error: 0.3708 - loss_no_weight_decay: 0.8764 - val_loss: 0.8243 - val_acc: 0.1765 - val_mean_absolute_error: 0.3729 - val_loss_no_weight_decay: 0.8243
#
# Epoch 00006: val_acc did not improve from 0.75000
# Confusion matrix:
#  [[ 0  0 13]
#  [ 0  0  2]
#  [ 0  0  2]]
# Epoch 7/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.9097 - acc: 0.5133 - mean_absolute_error: 0.3639 - loss_no_weight_decay: 0.9097 - val_loss: 0.7738 - val_acc: 0.7031 - val_mean_absolute_error: 0.3413 - val_loss_no_weight_decay: 0.7738
#
# Epoch 00007: val_acc did not improve from 0.75000
# Confusion matrix:
#  [[43  0  0]
#  [ 5  0  0]
#  [16  0  0]]
# Epoch 8/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.8555 - acc: 0.5196 - mean_absolute_error: 0.3706 - loss_no_weight_decay: 0.8555 - val_loss: 0.9730 - val_acc: 0.7059 - val_mean_absolute_error: 0.3724 - val_loss_no_weight_decay: 0.9730
#
# Epoch 00008: val_acc did not improve from 0.75000
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Confusion matrix:
#  [[10  0  0]
#  [ 1  0  0]
#  [ 6  0  0]]
# Epoch 9/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.9468 - acc: 0.5174 - mean_absolute_error: 0.3722 - loss_no_weight_decay: 0.9468 - val_loss: 0.8502 - val_acc: 0.7500 - val_mean_absolute_error: 0.3551 - val_loss_no_weight_decay: 0.8502
#
# Epoch 00009: val_acc did not improve from 0.75000
# Confusion matrix:
#  [[48  0  0]
#  [ 4  0  0]
#  [12  0  0]]
# Epoch 10/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.9384 - acc: 0.5168 - mean_absolute_error: 0.3739 - loss_no_weight_decay: 0.9384 - val_loss: 0.8268 - val_acc: 0.5294 - val_mean_absolute_error: 0.3619 - val_loss_no_weight_decay: 0.8268
#
# Epoch 00010: val_acc did not improve from 0.75000
# Confusion matrix:
#  [[13  0  0]
#  [ 2  0  0]
#  [ 2  0  0]]
# Epoch 11/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.8778 - acc: 0.5291 - mean_absolute_error: 0.3742 - loss_no_weight_decay: 0.8778 - val_loss: 0.8075 - val_acc: 0.7188 - val_mean_absolute_error: 0.3588 - val_loss_no_weight_decay: 0.8075
#
# Epoch 00011: val_acc did not improve from 0.75000
# Confusion matrix:
#  [[44  0  0]
#  [ 5  0  0]
#  [15  0  0]]
# Epoch 12/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.8735 - acc: 0.5553 - mean_absolute_error: 0.3720 - loss_no_weight_decay: 0.8735 - val_loss: 0.8624 - val_acc: 0.7059 - val_mean_absolute_error: 0.3495 - val_loss_no_weight_decay: 0.8624
#
# Epoch 00012: val_acc did not improve from 0.75000
# Confusion matrix:
#  [[13  0]
#  [ 4  0]]
# Epoch 13/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.8334 - acc: 0.5747 - mean_absolute_error: 0.3510 - loss_no_weight_decay: 0.8334 - val_loss: 0.8724 - val_acc: 0.5938 - val_mean_absolute_error: 0.3708 - val_loss_no_weight_decay: 0.8724
# Epoch 00013: val_acc did not improve from 0.75000
# Confusion matrix:
#  [[36  0  9]
#  [ 1  0  3]
#  [ 8  0  7]]
# Epoch 14/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.8944 - acc: 0.5658 - mean_absolute_error: 0.3632 - loss_no_weight_decay: 0.8944 - val_loss: 0.6652 - val_acc: 0.8235 - val_mean_absolute_error: 0.3193 - val_loss_no_weight_decay: 0.6652
#
# Epoch 00014: val_acc improved from 0.75000 to 0.82353, saving model to base_2020-05-12-13-41-18-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[8 0 3]
#  [0 0 1]
#  [4 0 1]]
# Epoch 15/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.8315 - acc: 0.5413 - mean_absolute_error: 0.3566 - loss_no_weight_decay: 0.8315 - val_loss: 0.7657 - val_acc: 0.7031 - val_mean_absolute_error: 0.3315 - val_loss_no_weight_decay: 0.7657
#
# Epoch 00015: val_acc did not improve from 0.82353
# Confusion matrix:
#  [[39  0  8]
#  [ 1  0  3]
#  [ 7  0  6]]
# Epoch 16/35
# 9/9 [==============================] - 16s 2s/step - loss: 0.8334 - acc: 0.6128 - mean_absolute_error: 0.3462 - loss_no_weight_decay: 0.8334 - val_loss: 0.8324 - val_acc: 0.5294 - val_mean_absolute_error: 0.3501 - val_loss_no_weight_decay: 0.8324
#
# Epoch 00016: val_acc did not improve from 0.82353
# Confusion matrix:
#  [[11  0  2]
#  [ 0  0  2]
#  [ 2  0  0]]
# Epoch 17/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.8320 - acc: 0.6239 - mean_absolute_error: 0.3485 - loss_no_weight_decay: 0.8320 - val_loss: 0.7008 - val_acc: 0.7500 - val_mean_absolute_error: 0.3124 - val_loss_no_weight_decay: 0.7008
#
# Epoch 00017: val_acc did not improve from 0.82353
# Confusion matrix:
#  [[37  0  9]
#  [ 0  0  4]
#  [ 6  0  8]]
# Epoch 18/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.7842 - acc: 0.6539 - mean_absolute_error: 0.3296 - loss_no_weight_decay: 0.7842 - val_loss: 1.1222 - val_acc: 0.4118 - val_mean_absolute_error: 0.4113 - val_loss_no_weight_decay: 1.1222
#
# Epoch 00018: val_acc did not improve from 0.82353
# Confusion matrix:
#  [[7 0 7]
#  [0 0 1]
#  [1 0 1]]
# Epoch 19/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.8727 - acc: 0.6027 - mean_absolute_error: 0.3448 - loss_no_weight_decay: 0.8727 - val_loss: 0.7677 - val_acc: 0.6406 - val_mean_absolute_error: 0.3287 - val_loss_no_weight_decay: 0.7677
#
# Epoch 00019: val_acc did not improve from 0.82353
# Confusion matrix:
#  [[30  0 14]
#  [ 0  0  4]
#  [ 3  0 13]]
# Epoch 20/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.7931 - acc: 0.6274 - mean_absolute_error: 0.3316 - loss_no_weight_decay: 0.7931 - val_loss: 0.7388 - val_acc: 0.5294 - val_mean_absolute_error: 0.3071 - val_loss_no_weight_decay: 0.7388
#
# Epoch 00020: val_acc did not improve from 0.82353
# Confusion matrix:
#  [[10  4]
#  [ 2  1]]
# Epoch 21/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.8030 - acc: 0.6592 - mean_absolute_error: 0.3248 - loss_no_weight_decay: 0.8030 - val_loss: 0.7390 - val_acc: 0.6719 - val_mean_absolute_error: 0.3113 - val_loss_no_weight_decay: 0.7390
#
# Epoch 00021: val_acc did not improve from 0.82353
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Confusion matrix:
#  [[39  0  8]
#  [ 0  0  5]
#  [ 4  0  8]]
# Epoch 22/35
# 9/9 [==============================] - 16s 2s/step - loss: 0.7870 - acc: 0.6580 - mean_absolute_error: 0.3297 - loss_no_weight_decay: 0.7870 - val_loss: 0.5073 - val_acc: 0.7059 - val_mean_absolute_error: 0.2499 - val_loss_no_weight_decay: 0.5073
#
# Epoch 00022: val_acc did not improve from 0.82353
# Confusion matrix:
#  [[13  0  0]
#  [ 1  0  0]
#  [ 2  0  1]]
# Epoch 23/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.7249 - acc: 0.6678 - mean_absolute_error: 0.3121 - loss_no_weight_decay: 0.7249 - val_loss: 0.7301 - val_acc: 0.6562 - val_mean_absolute_error: 0.3114 - val_loss_no_weight_decay: 0.7301
#
# Epoch 00023: val_acc did not improve from 0.82353
# Confusion matrix:
#  [[33  0 12]
#  [ 0  0  4]
#  [ 4  0 11]]
# Epoch 24/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.7209 - acc: 0.6815 - mean_absolute_error: 0.3041 - loss_no_weight_decay: 0.7209 - val_loss: 0.6778 - val_acc: 0.7059 - val_mean_absolute_error: 0.2952 - val_loss_no_weight_decay: 0.6778
#
# Epoch 00024: val_acc did not improve from 0.82353
# Confusion matrix:
#  [[8 3]
#  [2 4]]
# Epoch 25/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.7320 - acc: 0.6926 - mean_absolute_error: 0.3107 - loss_no_weight_decay: 0.7320 - val_loss: 0.6812 - val_acc: 0.6875 - val_mean_absolute_error: 0.2820 - val_loss_no_weight_decay: 0.6812
#
# Epoch 00025: val_acc did not improve from 0.82353
# Confusion matrix:
#  [[37  0 10]
#  [ 0  0  3]
#  [ 7  0  7]]
# Epoch 26/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.7297 - acc: 0.6979 - mean_absolute_error: 0.3035 - loss_no_weight_decay: 0.7297 - val_loss: 0.6045 - val_acc: 0.7647 - val_mean_absolute_error: 0.2753 - val_loss_no_weight_decay: 0.6045
#
# Epoch 00026: val_acc did not improve from 0.82353
# Confusion matrix:
#  [[14  2]
#  [ 0  1]]
# Epoch 27/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.7222 - acc: 0.6927 - mean_absolute_error: 0.2995 - loss_no_weight_decay: 0.7222 - val_loss: 0.7055 - val_acc: 0.6406 - val_mean_absolute_error: 0.2899 - val_loss_no_weight_decay: 0.7055
#
# Epoch 00027: val_acc did not improve from 0.82353
# Confusion matrix:
#  [[41  0  8]
#  [ 0  0  1]
#  [ 7  0  7]]
# Epoch 28/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.7964 - acc: 0.6413 - mean_absolute_error: 0.3224 - loss_no_weight_decay: 0.7964 - val_loss: 0.3865 - val_acc: 0.8235 - val_mean_absolute_error: 0.1797 - val_loss_no_weight_decay: 0.3865
#
# Epoch 00028: val_acc did not improve from 0.82353
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Confusion matrix:
#  [[11  2]
#  [ 1  3]]
# Epoch 29/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.6980 - acc: 0.7119 - mean_absolute_error: 0.2977 - loss_no_weight_decay: 0.6980 - val_loss: 0.6840 - val_acc: 0.6719 - val_mean_absolute_error: 0.2889 - val_loss_no_weight_decay: 0.6840
#
# Epoch 00029: val_acc did not improve from 0.82353
# Confusion matrix:
#  [[38  0  8]
#  [ 0  0  3]
#  [ 6  0  9]]
# Epoch 30/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.7269 - acc: 0.6731 - mean_absolute_error: 0.3102 - loss_no_weight_decay: 0.7269 - val_loss: 0.4705 - val_acc: 0.8235 - val_mean_absolute_error: 0.2251 - val_loss_no_weight_decay: 0.4705
#
# Epoch 00030: val_acc did not improve from 0.82353
# Confusion matrix:
#  [[13  0  0]
#  [ 0  0  1]
#  [ 1  0  2]]
# Epoch 31/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.7489 - acc: 0.6416 - mean_absolute_error: 0.2996 - loss_no_weight_decay: 0.7489 - val_loss: 0.7373 - val_acc: 0.6250 - val_mean_absolute_error: 0.3043 - val_loss_no_weight_decay: 0.7373
#
# Epoch 00031: val_acc did not improve from 0.82353
# Confusion matrix:
#  [[31  0 19]
#  [ 0  0  2]
#  [ 1  0 11]]
# Epoch 32/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.7590 - acc: 0.6501 - mean_absolute_error: 0.3169 - loss_no_weight_decay: 0.7590 - val_loss: 0.5397 - val_acc: 0.8824 - val_mean_absolute_error: 0.2493 - val_loss_no_weight_decay: 0.5397
#
# Epoch 00032: val_acc improved from 0.82353 to 0.88235, saving model to base_2020-05-12-13-41-18-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[10  3]
#  [ 1  3]]
# Epoch 33/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.7289 - acc: 0.7066 - mean_absolute_error: 0.3084 - loss_no_weight_decay: 0.7289 - val_loss: 0.6825 - val_acc: 0.6875 - val_mean_absolute_error: 0.2863 - val_loss_no_weight_decay: 0.6825
#
# Epoch 00033: val_acc did not improve from 0.88235
# Confusion matrix:
#  [[38  0  8]
#  [ 0  0  3]
#  [ 6  0  9]]
# Epoch 34/35
# 9/9 [==============================] - 16s 2s/step - loss: 0.7082 - acc: 0.7066 - mean_absolute_error: 0.2990 - loss_no_weight_decay: 0.7082 - val_loss: 0.5253 - val_acc: 0.7647 - val_mean_absolute_error: 0.2419 - val_loss_no_weight_decay: 0.5253
#
# Epoch 00034: val_acc did not improve from 0.88235
# Confusion matrix:
#  [[7 0 4]
#  [0 0 1]
#  [3 0 2]]
# Epoch 35/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.7345 - acc: 0.6538 - mean_absolute_error: 0.3107 - loss_no_weight_decay: 0.7345 - val_loss: 0.6240 - val_acc: 0.7344 - val_mean_absolute_error: 0.2663 - val_loss_no_weight_decay: 0.6240
# Epoch 00035: val_acc did not improve from 0.88235
# Confusion matrix:
#  [[39  0  8]
#  [ 0  0  5]
#  [ 5  0  7]]
# 121/121 [==============================] - 5s 40ms/step
# 121/121 [==============================] - 4s 34ms/step
# Test loss: 0.7165452219114816
# Test accuracy: 0.6363636363636364
# Confusion Matrix
# [[66  0 22]
#  [ 6  0  6]
#  [ 7  0 14]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.84      0.75      0.79        88
#            1       0.00      0.00      0.00        12
#            2       0.33      0.67      0.44        21
#
#     accuracy                           0.66       121
#    macro avg       0.39      0.47      0.41       121
# weighted avg       0.67      0.66      0.65       121
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
import numpy as np 
import matplotlib.pyplot as plt
import os
import wandb
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_acc', 'val_mean_absolute_error', 'val_loss_no_weight_decay', 'loss', 'acc', 'mean_absolute_error', 'loss_no_weight_decay', 'lr'])

# %%
from Kappa_Skl import kappa
def kappa2(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    if len(y_true.shape) > 1 and y_true.shape[1] > 1:
        y_true = y_true.dot(range(y_true.shape[1]))
    if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
        y_pred = y_pred.dot(range(y_pred.shape[1]))
    try:
        return kappa(y_true, y_pred, weights='quadratic')
    except IndexError:
        return np.nan
    
print('Quadratic_wieghted_kappa')
print(kappa2(y_true, y_pred))
# Out:
# Quadratic_wieghted_kappa
# 0.322840153899965
