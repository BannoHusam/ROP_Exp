# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, InputLayer
from keras.regularizers import L1L2, l2, l1
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from custom_pooling import RMSPooling2D
from keras.optimizers import SGD, Adam
from keras.layers import LeakyReLU
#from data import BALANCE_WEIGHTS
from keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
#import os
from datetime import datetime as dt
from custom_loss import WeightedCategoricalCrossEntropy
from VCM import VCM
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
def get_experiment_id():
    time_str = dt.now().strftime('%Y-%m-%d-%H-%M-%S')
    experiment_id = 'base_{}'.format(time_str)
    return experiment_id
p_ratio=[1.0, 1.44, 1.73, 1.0]

model = Sequential()


model.add(Conv2D(16, (5, 5), activation='tanh', input_shape=(270, 270, 3)))
model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(16, (3, 3), activation='tanh'))
model.add(Conv2D(16, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))

#model.add(LeakyReLU(alpha=0.01))


model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))



model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))          
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(MaxPooling2D(pool_size=2))
#model.add(MaxPooling2D(pool_size=1))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
model.add(MaxPooling2D(pool_size=2))

model.add(Flatten())


#chnaged from 10 to 5 because an error 
model.add(Dense(2, activation='softmax'))

sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.count_params()
#adam = Adam(lr=0.0005, decay=1e-6)
#rmsprop
#Mloss = WeightedCategoricalCrossEntropy({0: 0.4125861396437394, 1: 1.4918664786083686, 2: 0.690426457789382, 3: 3.9541433021806855, 4: 4.885604311008468})
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
model.summary()
loss_no_weight_decay = model.total_loss - sum(model.losses)
model.metrics_tensors.append(loss_no_weight_decay)
model.metrics_names.append('loss_no_weight_decay')
#############################################################################################
#############################################################################################
#############################################################################################
#############################################################################################
#Preparing Data Augmentation Configuration 
train_datagen = ImageDataGenerator(
        rescale=1./255,
#        featurewise_center=True,
 #       samplewise_center=True,
        shear_range=0,
        zoom_range=0.0,#[1 / 1.15, 1.15],
        horizontal_flip=False,#True,
        rotation_range=0)#90,
#        validation_split=0.2)
"""
For the test set only rescale should be made 
"""
test_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas/train",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="training")
#    save_to_dir="D:/Separating Images into subfolders/train_augmented")


#print(train_generator.class_indices)

valid_generator = valid_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas/vald",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="validation")
#    save_to_dir="D:/Separating Images into subfolders/val_augmented"


test_generator = test_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas/test",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=1,
    class_mode="categorical",
    shuffle=False,
    seed=42)
#    save_to_dir="D:/Separating Images into subfolders/test_augmented")


# Fitting/Training the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
experiment_id = get_experiment_id()
callbacks = [
    EarlyStopping(monitor='val_acc', patience=50, min_delta=0.001, verbose=1),
    ModelCheckpoint(experiment_id + "-val_acc_checkpoint.hdf5", monitor='val_acc', verbose=1, save_best_only=True, mode='auto'),
    ReduceLROnPlateau(monitor='val_acc', factor=0.5, patience=7, verbose=1, mode='auto', min_delta=0.001, cooldown=0, min_lr=1e-7),
    VCM(valid_generator,STEP_SIZE_VALID)
    
]

class_weight_list = class_weight.compute_class_weight('balanced', np.unique(train_generator.classes), train_generator.classes)
class_weights = dict(zip(np.unique(train_generator.classes), class_weight_list))

history=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    class_weight=class_weights,
                    callbacks=callbacks,
                    epochs=35  
)


# Evaluating the model 
#predicting output
#reseting the test generator before calling predict_generator, in order not to get weird output
test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 266, 266, 16)      1216
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 262, 262, 16)      6416
# _________________________________________________________________
# input_1 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 260, 260, 16)      2320
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 258, 258, 16)      2320
# _________________________________________________________________
# input_2 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 254, 254, 16)      6416
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 250, 250, 16)      6416
# _________________________________________________________________
# input_3 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 246, 246, 16)      6416
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 242, 242, 16)      6416
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 121, 121, 16)      0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 119, 119, 32)      4640
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 117, 117, 32)      9248
# _________________________________________________________________
# input_4 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 115, 115, 32)      9248
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 113, 113, 32)      9248
# _________________________________________________________________
# input_5 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 111, 111, 32)      9248
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 109, 109, 32)      9248
# _________________________________________________________________
# input_6 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 107, 107, 32)      9248
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 105, 105, 32)      9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 52, 52, 32)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 50, 50, 64)        18496
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 48, 48, 64)        36928
# _________________________________________________________________
# input_7 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 46, 46, 64)        36928
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 44, 44, 64)        36928
# _________________________________________________________________
# input_8 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 42, 42, 64)        36928
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 40, 40, 64)        36928
# _________________________________________________________________
# input_9 (InputLayer)         multiple                  0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 20, 20, 64)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 18, 18, 64)        36928
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# input_10 (InputLayer)        multiple                  0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 14, 14, 64)        36928
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 12, 12, 64)        36928
# _________________________________________________________________
# input_11 (InputLayer)        multiple                  0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 4610
# =================================================================
# Total params: 462,770
# Trainable params: 462,770
# Non-trainable params: 0
# _________________________________________________________________
# Found 588 images belonging to 2 classes.
# Found 116 images belonging to 2 classes.
# Found 176 images belonging to 2 classes.
# Epoch 1/35
# 9/9 [==============================] - 40s 4s/step - loss: 0.6964 - acc: 0.4890 - loss_no_weight_decay: 0.6964 - val_loss: 0.6937 - val_acc: 0.4844 - val_loss_no_weight_decay: 0.6937
#
# Epoch 00001: val_acc improved from -inf to 0.48438, saving model to base_2020-05-07-01-23-35-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[ 5 27]
#  [ 3 29]]
# Epoch 2/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.6908 - acc: 0.5170 - loss_no_weight_decay: 0.6908 - val_loss: 0.6816 - val_acc: 0.5962 - val_loss_no_weight_decay: 0.6816
#
# Epoch 00002: val_acc improved from 0.48438 to 0.59615, saving model to base_2020-05-07-01-23-35-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[ 0 27]
#  [ 0 25]]
# Epoch 3/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.6919 - acc: 0.4915 - loss_no_weight_decay: 0.6919 - val_loss: 0.6899 - val_acc: 0.4844 - val_loss_no_weight_decay: 0.6899
#
# Epoch 00003: val_acc did not improve from 0.59615
# Confusion matrix:
#  [[28  0]
#  [36  0]]
# Epoch 4/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.6858 - acc: 0.6055 - loss_no_weight_decay: 0.6858 - val_loss: 0.6830 - val_acc: 0.6346 - val_loss_no_weight_decay: 0.6830
#
# Epoch 00004: val_acc improved from 0.59615 to 0.63462, saving model to base_2020-05-07-01-23-35-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[19  8]
#  [ 5 20]]
# Epoch 5/35
# 9/9 [==============================] - 11s 1s/step - loss: 0.6734 - acc: 0.6335 - loss_no_weight_decay: 0.6734 - val_loss: 0.6780 - val_acc: 0.6250 - val_loss_no_weight_decay: 0.6780
#
# Epoch 00005: val_acc did not improve from 0.63462
# Confusion matrix:
#  [[10 20]
#  [ 0 34]]
# Epoch 6/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.6738 - acc: 0.5538 - loss_no_weight_decay: 0.6738 - val_loss: 0.6249 - val_acc: 0.7115 - val_loss_no_weight_decay: 0.6249
#
# Epoch 00006: val_acc improved from 0.63462 to 0.71154, saving model to base_2020-05-07-01-23-35-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[10 13]
#  [ 1 28]]
# Epoch 7/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.6480 - acc: 0.6536 - loss_no_weight_decay: 0.6480 - val_loss: 0.6396 - val_acc: 0.5938 - val_loss_no_weight_decay: 0.6396
#
# Epoch 00007: val_acc did not improve from 0.71154
# Confusion matrix:
#  [[13 17]
#  [ 8 26]]
# Epoch 8/35
# 9/9 [==============================] - 11s 1s/step - loss: 0.6516 - acc: 0.6293 - loss_no_weight_decay: 0.6516 - val_loss: 0.6118 - val_acc: 0.6731 - val_loss_no_weight_decay: 0.6118
#
# Epoch 00008: val_acc did not improve from 0.71154
# Confusion matrix:
#  [[23  5]
#  [10 14]]
# Epoch 9/35
# 9/9 [==============================] - 11s 1s/step - loss: 0.6327 - acc: 0.6536 - loss_no_weight_decay: 0.6327 - val_loss: 0.6385 - val_acc: 0.6562 - val_loss_no_weight_decay: 0.6385
#
# Epoch 00009: val_acc did not improve from 0.71154
# Confusion matrix:
#  [[21 10]
#  [13 20]]
# Epoch 10/35
# 9/9 [==============================] - 10s 1s/step - loss: 0.6094 - acc: 0.6643 - loss_no_weight_decay: 0.6094 - val_loss: 0.5547 - val_acc: 0.7115 - val_loss_no_weight_decay: 0.5547
#
# Epoch 00010: val_acc did not improve from 0.71154
# Confusion matrix:
#  [[21  8]
#  [10 13]]
# Epoch 11/35
# 9/9 [==============================] - 11s 1s/step - loss: 0.5955 - acc: 0.6889 - loss_no_weight_decay: 0.5955 - val_loss: 0.5902 - val_acc: 0.6875 - val_loss_no_weight_decay: 0.5902
#
# Epoch 00011: val_acc did not improve from 0.71154
# Confusion matrix:
#  [[21  9]
#  [12 22]]
# Epoch 12/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.6216 - acc: 0.6485 - loss_no_weight_decay: 0.6216 - val_loss: 0.6127 - val_acc: 0.6731 - val_loss_no_weight_decay: 0.6127
#
# Epoch 00012: val_acc did not improve from 0.71154
# Confusion matrix:
#  [[17 13]
#  [ 2 20]]
# Epoch 13/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.6044 - acc: 0.6773 - loss_no_weight_decay: 0.6044 - val_loss: 0.5959 - val_acc: 0.7500 - val_loss_no_weight_decay: 0.5959
#
# Epoch 00013: val_acc improved from 0.71154 to 0.75000, saving model to base_2020-05-07-01-23-35-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[18 14]
#  [ 4 28]]
# Epoch 14/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.5765 - acc: 0.6979 - loss_no_weight_decay: 0.5765 - val_loss: 0.4923 - val_acc: 0.7885 - val_loss_no_weight_decay: 0.4923
#
# Epoch 00014: val_acc improved from 0.75000 to 0.78846, saving model to base_2020-05-07-01-23-35-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[21  1]
#  [10 20]]
# Epoch 15/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.5520 - acc: 0.6961 - loss_no_weight_decay: 0.5520 - val_loss: 0.5373 - val_acc: 0.7344 - val_loss_no_weight_decay: 0.5373
#
# Epoch 00015: val_acc did not improve from 0.78846
# Confusion matrix:
#  [[20  7]
#  [ 9 28]]
# Epoch 16/35
# 9/9 [==============================] - 10s 1s/step - loss: 0.5343 - acc: 0.7169 - loss_no_weight_decay: 0.5343 - val_loss: 0.5011 - val_acc: 0.7500 - val_loss_no_weight_decay: 0.5011
#
# Epoch 00016: val_acc did not improve from 0.78846
# Confusion matrix:
#  [[21  5]
#  [12 14]]
# Epoch 17/35
# 9/9 [==============================] - 11s 1s/step - loss: 0.5458 - acc: 0.7184 - loss_no_weight_decay: 0.5458 - val_loss: 0.4436 - val_acc: 0.7656 - val_loss_no_weight_decay: 0.4436
#
# Epoch 00017: val_acc did not improve from 0.78846
# Confusion matrix:
#  [[18 14]
#  [ 3 29]]
# Epoch 18/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.4965 - acc: 0.7604 - loss_no_weight_decay: 0.4965 - val_loss: 0.5339 - val_acc: 0.7500 - val_loss_no_weight_decay: 0.5339
#
# Epoch 00018: val_acc did not improve from 0.78846
# Confusion matrix:
#  [[24  5]
#  [ 9 14]]
# Epoch 19/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.4851 - acc: 0.7620 - loss_no_weight_decay: 0.4851 - val_loss: 0.3962 - val_acc: 0.7969 - val_loss_no_weight_decay: 0.3962
#
# Epoch 00019: val_acc improved from 0.78846 to 0.79688, saving model to base_2020-05-07-01-23-35-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[24  6]
#  [ 7 27]]
# Epoch 20/35
# 9/9 [==============================] - 11s 1s/step - loss: 0.4583 - acc: 0.7986 - loss_no_weight_decay: 0.4583 - val_loss: 0.4635 - val_acc: 0.7500 - val_loss_no_weight_decay: 0.4635
#
# Epoch 00020: val_acc did not improve from 0.79688
# Confusion matrix:
#  [[20  7]
#  [ 5 20]]
# Epoch 21/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.4321 - acc: 0.7956 - loss_no_weight_decay: 0.4321 - val_loss: 0.4048 - val_acc: 0.8281 - val_loss_no_weight_decay: 0.4048
#
# Epoch 00021: val_acc improved from 0.79688 to 0.82812, saving model to base_2020-05-07-01-23-35-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[21 10]
#  [ 3 30]]
# Epoch 22/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.4947 - acc: 0.7643 - loss_no_weight_decay: 0.4947 - val_loss: 0.4711 - val_acc: 0.8077 - val_loss_no_weight_decay: 0.4711
#
# Epoch 00022: val_acc did not improve from 0.82812
# Confusion matrix:
#  [[18  8]
#  [ 7 19]]
# Epoch 23/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.3996 - acc: 0.8403 - loss_no_weight_decay: 0.3996 - val_loss: 0.3561 - val_acc: 0.8906 - val_loss_no_weight_decay: 0.3561
#
# Epoch 00023: val_acc improved from 0.82812 to 0.89062, saving model to base_2020-05-07-01-23-35-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[26  5]
#  [11 22]]
# Epoch 24/35
# 9/9 [==============================] - 10s 1s/step - loss: 0.4165 - acc: 0.8392 - loss_no_weight_decay: 0.4165 - val_loss: 0.4989 - val_acc: 0.7500 - val_loss_no_weight_decay: 0.4989
#
# Epoch 00024: val_acc did not improve from 0.89062
# Confusion matrix:
#  [[21  6]
#  [ 4 21]]
# Epoch 25/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.4052 - acc: 0.8407 - loss_no_weight_decay: 0.4052 - val_loss: 0.4419 - val_acc: 0.7969 - val_loss_no_weight_decay: 0.4419
#
# Epoch 00025: val_acc did not improve from 0.89062
# Confusion matrix:
#  [[31  3]
#  [ 5 25]]
# Epoch 26/35
# 9/9 [==============================] - 11s 1s/step - loss: 0.3318 - acc: 0.8843 - loss_no_weight_decay: 0.3318 - val_loss: 0.4647 - val_acc: 0.7115 - val_loss_no_weight_decay: 0.4647
#
# Epoch 00026: val_acc did not improve from 0.89062
# Confusion matrix:
#  [[16  7]
#  [ 3 26]]
# Epoch 27/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.3584 - acc: 0.8403 - loss_no_weight_decay: 0.3584 - val_loss: 0.4105 - val_acc: 0.8594 - val_loss_no_weight_decay: 0.4105
#
# Epoch 00027: val_acc did not improve from 0.89062
# Confusion matrix:
#  [[27  8]
#  [ 3 26]]
# Epoch 28/35
# 9/9 [==============================] - 11s 1s/step - loss: 0.2817 - acc: 0.8895 - loss_no_weight_decay: 0.2817 - val_loss: 0.3417 - val_acc: 0.8077 - val_loss_no_weight_decay: 0.3417
#
# Epoch 00028: val_acc did not improve from 0.89062
# Confusion matrix:
#  [[23  6]
#  [ 3 20]]
# Epoch 29/35
# 9/9 [==============================] - 10s 1s/step - loss: 0.2664 - acc: 0.9095 - loss_no_weight_decay: 0.2664 - val_loss: 0.4272 - val_acc: 0.8438 - val_loss_no_weight_decay: 0.4272
#
# Epoch 00029: val_acc did not improve from 0.89062
# Confusion matrix:
#  [[30  3]
#  [ 4 27]]
# Epoch 30/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.3420 - acc: 0.8455 - loss_no_weight_decay: 0.3420 - val_loss: 0.4445 - val_acc: 0.7885 - val_loss_no_weight_decay: 0.4445
#
# Epoch 00030: val_acc did not improve from 0.89062
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Confusion matrix:
#  [[20  2]
#  [ 9 21]]
# Epoch 31/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.2732 - acc: 0.8889 - loss_no_weight_decay: 0.2732 - val_loss: 0.3476 - val_acc: 0.8438 - val_loss_no_weight_decay: 0.3476
#
# Epoch 00031: val_acc did not improve from 0.89062
# Confusion matrix:
#  [[30  7]
#  [ 2 25]]
# Epoch 32/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.2275 - acc: 0.9131 - loss_no_weight_decay: 0.2275 - val_loss: 0.3349 - val_acc: 0.8846 - val_loss_no_weight_decay: 0.3349
#
# Epoch 00032: val_acc did not improve from 0.89062
# Confusion matrix:
#  [[21  4]
#  [ 2 25]]
# Epoch 33/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.2577 - acc: 0.8940 - loss_no_weight_decay: 0.2577 - val_loss: 0.3792 - val_acc: 0.8438 - val_loss_no_weight_decay: 0.3792
#
# Epoch 00033: val_acc did not improve from 0.89062
# Confusion matrix:
#  [[28  7]
#  [ 5 24]]
# Epoch 34/35
# 9/9 [==============================] - 11s 1s/step - loss: 0.2387 - acc: 0.8920 - loss_no_weight_decay: 0.2387 - val_loss: 0.2846 - val_acc: 0.8846 - val_loss_no_weight_decay: 0.2846
#
# Epoch 00034: val_acc did not improve from 0.89062
# Confusion matrix:
#  [[22  5]
#  [ 7 18]]
# Epoch 35/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.2284 - acc: 0.9193 - loss_no_weight_decay: 0.2284 - val_loss: 0.2505 - val_acc: 0.8906 - val_loss_no_weight_decay: 0.2505
#
# Epoch 00035: val_acc did not improve from 0.89062
# Confusion matrix:
#  [[29  1]
#  [ 5 29]]
# 176/176 [==============================] - 5s 27ms/step
# 176/176 [==============================] - 5s 29ms/step
# Test loss: 0.2245018278555852
# Test accuracy: 0.9204545454545454
# Confusion Matrix
# [[81  7]
#  [ 7 81]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92        88
#            1       0.92      0.92      0.92        88
#
#     accuracy                           0.92       176
#    macro avg       0.92      0.92      0.92       176
# weighted avg       0.92      0.92      0.92       176

# %%
import numpy as np 
import matplotlib.pyplot as plt
import os
import wandb
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_acc', 'val_loss_no_weight_decay', 'loss', 'acc', 'loss_no_weight_decay', 'lr'])

# %%
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
from QWK import QWK
def kappa2(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    if len(y_true.shape) > 1 and y_true.shape[1] > 1:
        y_true = y_true.dot(range(y_true.shape[1]))
    if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
        y_pred = y_pred.dot(range(y_pred.shape[1]))
    try:
        return kappa(y_true, y_pred, weights='quadratic')
    except IndexError:
        return np.nan
    
print('Quadratic_wieghted_kappa')
print(kappa2(y_true, y_pred))
# Out:
# Quadratic_wieghted_kappa
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-0a7a582f4102> in <module>
#      13
#      14 print('Quadratic_wieghted_kappa')
# ---> 15 print(kappa2(y_true, y_pred))
#
# <ipython-input-6-0a7a582f4102> in kappa2(y_true, y_pred)
#       8         y_pred = y_pred.dot(range(y_pred.shape[1]))
#       9     try:
# ---> 10         return kappa(y_true, y_pred, weights='quadratic')
#      11     except IndexError:
#      12         return np.nan
#
# NameError: name 'kappa' is not defined

# %%
from sklearn.metrics import confusion_matrix, classification_report

test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# 176/176 [==============================] - 5s 26ms/step
# 176/176 [==============================] - 5s 28ms/step
# Test loss: 0.2245018278555852
# Test accuracy: 0.9204545454545454
# Confusion Matrix
# [[81  7]
#  [ 7 81]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92        88
#            1       0.92      0.92      0.92        88
#
#     accuracy                           0.92       176
#    macro avg       0.92      0.92      0.92       176
# weighted avg       0.92      0.92      0.92       176

# %%
from Kappa_Skl import kappa
def kappa2(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    if len(y_true.shape) > 1 and y_true.shape[1] > 1:
        y_true = y_true.dot(range(y_true.shape[1]))
    if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
        y_pred = y_pred.dot(range(y_pred.shape[1]))
    try:
        return kappa(y_true, y_pred, weights='quadratic')
    except IndexError:
        return np.nan
    
print('Quadratic_wieghted_kappa')
print(kappa2(y_true, y_pred))
# Out:
# Quadratic_wieghted_kappa
# 0.8409090909090909
