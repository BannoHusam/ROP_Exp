# %%
import efficientnet.keras as efn
from keras.models import Model, model_from_json
from keras.regularizers import l1_l2
from keras.layers import Dense, Dropout
from keras.optimizers import SGD, Adam
import pandas as pd
from keras_preprocessing.image import ImageDataGenerator
from datetime import datetime as dt
from sklearn.utils import class_weight
from keras.callbacks import EarlyStopping, ModelCheckpoint,LearningRateScheduler, TensorBoard
import keras.backend as K
from VCM import VCM 
from keras.initializers import Constant,Orthogonal
from keras import regularizers
from Kappa_Skl import kappa
import keras.backend as K
import matplotlib.pyplot as plt
import itertools
from Homotopy import Homotopy 
from QWK import QWK
import tensorflow as tf
from Fractional_MAXPOOL import FractionalPooling2D

import numpy as np 
import matplotlib.pyplot as plt
import os
import wandb
#from wandb.keras import WandbCallback
#wandb.init(project="rop")


top_layers_checkpoint_path = 'cp.top.best.hdf5'
fine_tuned_checkpoint_path = 'cp.fine_tuned.best.hdf5'
new_extended_inception_weights = 'final_weights.hdf5'





def get_experiment_id():
    time_str = dt.now().strftime('%Y-%m-%d-%H-%M-%S')
    experiment_id = 'base_{}'.format(time_str)
    return experiment_id

#def scheduler(epoch):
#    if epoch == 150:
#        K.set_value(model.optimizer.lr, 0.00003)
#    return K.get_value(model.optimizer.lr)


def create_model():
    base_model = efn.EfficientNetB0(weights=None,
                        include_top=False,
                        input_shape=(128, 128, 3), pooling='avg')
#    base_model._layers.pop()
#    model2 = Model(base_model.input, base_model.layers[-1].output)
##    base_model = InceptionV3(weights=None , include_top=False, input_tensor=None, input_shape=(299, 299, 3), pooling='avg') 
    x = base_model.output
    x = Dense(2, activation="softmax")(x)
    model = Model(inputs = base_model.input, outputs = x)
    model.load_weights('base_2019-12-11-23-01-58-val_kappa_checkpoint.hdf5')
#    model._layers.pop()
#    x = Model(model.input, model.layers[-1].output)
#    model.save_weights("tmp.h5")
#    top_layers_checkpoint_path = 'cp.top.best.hdf5'

#    # first: train only the top layers (which were randomly initialized)
#    # i.e. freeze all convolutional InceptionV3 layers
    for layer in base_model.layers:
        layer.trainable = False
#    
#    
#
##    regularizer = l1_l2(l1=0.0005, l2=0.0005)
##    for layer in model.layers:
##        for attr in ['kernel_regularizer', 'bias_regularizer']:
##            if hasattr(layer, attr) and layer.trainable:
##                setattr(layer, attr, regularizer)
#
##
#    out = model_from_json(model.to_json())
#    out.load_weights("tmp.h5", by_name=True)
#
    return model


model = create_model()




radam = Adam(lr=0.0014339, beta_1=0.9, beta_2=0.999, epsilon=0.1, decay=1e-6, amsgrad=False)
model.compile(loss='categorical_crossentropy', optimizer=radam, metrics=['mae','acc'])

#sgd = SGD(lr=0.0003, decay=1e-6, momentum=0.9, nesterov=True)
#model.compile(loss='mse', optimizer=sgd, metrics=['mae', 'acc'])

experiment_id = get_experiment_id()


train_datagen = ImageDataGenerator(
        rescale=1./255,
#        featurewise_center=True,
 #       samplewise_center=True,
        shear_range=0,
        zoom_range=0.0,#[1 / 1.15, 1.15],
        horizontal_flip=False,#True,
        rotation_range=0)#90,
#        validation_split=0.2)
"""
For the test set only rescale should be made 
"""
test_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_class_treatment_noch/train",
    target_size=(128, 128),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="training")
#    save_to_dir="D:/Separating Images into subfolders/train_augmented")


#print(train_generator.class_indices)

valid_generator = valid_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_class_treatment_noch/vald",
    target_size=(128, 128),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="validation")
#    save_to_dir="D:/Separating Images into subfolders/val_augmented"


test_generator = test_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_class_treatment_noch/test",
    target_size=(128, 128),
    color_mode="rgb",
    batch_size=1,
    class_mode="categorical",
    shuffle=False,
    seed=42)
#    save_to_dir="D:/Separating Images into subfolders/test_augmented")


# Fitting/Training the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
experiment_id = get_experiment_id()


class_weight_list = class_weight.compute_class_weight('balanced', np.unique(train_generator.classes), train_generator.classes)
class_weights = dict(zip(np.unique(train_generator.classes), class_weight_list))

callbacks = [
#    Resample_Iterator(balance_weights),
   # QWK(valid_generator, STEP_SIZE_VALID),
    ModelCheckpoint(top_layers_checkpoint_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max'),
#    EarlyStopping(monitor='val_kappa', patience=10, min_delta=0.001, verbose=1, restore_best_weights=True, mode='max',baseline=None),
    VCM(valid_generator, STEP_SIZE_VALID),
#    LearningRateScheduler(scheduler, verbose=1),
 #   TensorBoard(log_dir='./Graph', histogram_freq=0, write_graph=True, write_images=True),        
]




# train the model on the new data for a few epochs

history1=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
#                    class_weight=[balance_weights],
                    callbacks=callbacks,
                    epochs=10  
)


 

callbacks1 = [
#    Resample_Iterator(balance_weights1),
    #QWK(valid_generator, STEP_SIZE_VALID),
    ModelCheckpoint(fine_tuned_checkpoint_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max'),
    EarlyStopping(monitor='val_acc', patience=7, min_delta=0.001, verbose=1, restore_best_weights=True, mode='max',baseline=None),
    VCM(valid_generator, STEP_SIZE_VALID),
#    LearningRateScheduler(scheduler, verbose=1),
#    TensorBoard(log_dir='./Graph', histogram_freq=0, write_graph=True, write_images=True),        
]



for layer in model.layers:
    layer.trainable = True
    
    
    
    
radam = Adam(lr=0.0014339, beta_1=0.9, beta_2=0.999, epsilon=0.1, decay=1e-6, amsgrad=False)
model.compile(loss='categorical_crossentropy', optimizer=radam, metrics=['mae','acc'])



# we train our model again (this time fine-tuning the top 2 inception blocks
# alongside the top Dense layers
history=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
#                    class_weight=[balance_weights1],
                    callbacks=callbacks1,
                    epochs=30) 




test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test mae:', score[1])
print('Test accuracy:', score[2])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1']
print(classification_report(y_true, y_pred, target_names=target_names))
                    
                    
# list all data in history
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model loss.png')

# summarize history for val_kappa
plt.plot(history.history['val_kappa'])
plt.title('Validation_Kappa')
plt.ylabel('val_kappa')
plt.xlabel('epoch')
plt.legend([ 'validation'], loc='upper left')
plt.show()
#plt.savefig('model validation_kappa.png')

# summarize history for mean_absolute _error
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model mean_absolute_error')
plt.ylabel('mean_absolute_error')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model maey.png')
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Found 285 images belonging to 2 classes.
# Found 23 images belonging to 2 classes.
# Found 33 images belonging to 2 classes.
# Epoch 1/10
# 4/4 [==============================] - 4s 927ms/step - loss: 1.7396 - mean_absolute_error: 0.6873 - acc: 0.2642 - val_loss: 1.0846 - val_mean_absolute_error: 0.5955 - val_acc: 0.3478
#
# Epoch 00001: val_acc improved from -inf to 0.34783, saving model to cp.top.best.hdf5
# Confusion matrix:
#  []
# Epoch 2/10
# 4/4 [==============================] - 1s 170ms/step - loss: 1.7127 - mean_absolute_error: 0.6852 - acc: 0.2656 - val_loss: 1.0687 - val_mean_absolute_error: 0.5922 - val_acc: 0.3478
#
# Epoch 00002: val_acc did not improve from 0.34783
# Confusion matrix:
#  []
# Epoch 3/10
# 4/4 [==============================] - 1s 204ms/step - loss: 1.5937 - mean_absolute_error: 0.6573 - acc: 0.2956 - val_loss: 1.0497 - val_mean_absolute_error: 0.5880 - val_acc: 0.3913
#
# Epoch 00003: val_acc improved from 0.34783 to 0.39130, saving model to cp.top.best.hdf5
# Confusion matrix:
#  []
# Epoch 4/10
# 4/4 [==============================] - 0s 108ms/step - loss: 1.5140 - mean_absolute_error: 0.6526 - acc: 0.2825 - val_loss: 1.0287 - val_mean_absolute_error: 0.5829 - val_acc: 0.3913
#
# Epoch 00004: val_acc did not improve from 0.39130
# Confusion matrix:
#  []
# Epoch 5/10
# 4/4 [==============================] - 1s 209ms/step - loss: 1.4426 - mean_absolute_error: 0.6366 - acc: 0.3047 - val_loss: 1.0075 - val_mean_absolute_error: 0.5774 - val_acc: 0.3913
#
# Epoch 00005: val_acc did not improve from 0.39130
# Confusion matrix:
#  []
# Epoch 6/10
# 4/4 [==============================] - 1s 160ms/step - loss: 1.2944 - mean_absolute_error: 0.6230 - acc: 0.3322 - val_loss: 0.9871 - val_mean_absolute_error: 0.5717 - val_acc: 0.3913
#
# Epoch 00006: val_acc did not improve from 0.39130
# Confusion matrix:
#  []
# Epoch 7/10
# 4/4 [==============================] - 1s 191ms/step - loss: 1.2444 - mean_absolute_error: 0.6099 - acc: 0.3314 - val_loss: 0.9666 - val_mean_absolute_error: 0.5655 - val_acc: 0.3913
#
# Epoch 00007: val_acc did not improve from 0.39130
# Confusion matrix:
#  []
# Epoch 8/10
# 4/4 [==============================] - 1s 202ms/step - loss: 1.0577 - mean_absolute_error: 0.5592 - acc: 0.4002 - val_loss: 0.9476 - val_mean_absolute_error: 0.5591 - val_acc: 0.4348
#
# Epoch 00008: val_acc improved from 0.39130 to 0.43478, saving model to cp.top.best.hdf5
# Confusion matrix:
#  []
# Epoch 9/10
# 4/4 [==============================] - 1s 158ms/step - loss: 1.0419 - mean_absolute_error: 0.5544 - acc: 0.4219 - val_loss: 0.9300 - val_mean_absolute_error: 0.5528 - val_acc: 0.4783
#
# Epoch 00009: val_acc improved from 0.43478 to 0.47826, saving model to cp.top.best.hdf5
# Confusion matrix:
#  []
# Epoch 10/10
# 4/4 [==============================] - 1s 142ms/step - loss: 0.9201 - mean_absolute_error: 0.5251 - acc: 0.4558 - val_loss: 0.9138 - val_mean_absolute_error: 0.5464 - val_acc: 0.4783
#
# Epoch 00010: val_acc did not improve from 0.47826
# Confusion matrix:
#  []
# Epoch 1/30
# 4/4 [==============================] - 11s 3s/step - loss: 0.8713 - mean_absolute_error: 0.5005 - acc: 0.4835 - val_loss: 0.8715 - val_mean_absolute_error: 0.5336 - val_acc: 0.3913
#
# Epoch 00001: val_acc improved from -inf to 0.39130, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  []
# Epoch 2/30
# 4/4 [==============================] - 1s 263ms/step - loss: 0.8021 - mean_absolute_error: 0.4833 - acc: 0.5190 - val_loss: 0.8598 - val_mean_absolute_error: 0.5284 - val_acc: 0.3913
#
# Epoch 00002: val_acc did not improve from 0.39130
# Confusion matrix:
#  []
# Epoch 3/30
# 4/4 [==============================] - 1s 270ms/step - loss: 0.7409 - mean_absolute_error: 0.4568 - acc: 0.5716 - val_loss: 0.7973 - val_mean_absolute_error: 0.5065 - val_acc: 0.4348
#
# Epoch 00003: val_acc improved from 0.39130 to 0.43478, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  []
# Epoch 4/30
# 4/4 [==============================] - 1s 305ms/step - loss: 0.7771 - mean_absolute_error: 0.4763 - acc: 0.5195 - val_loss: 0.7439 - val_mean_absolute_error: 0.4829 - val_acc: 0.4348
#
# Epoch 00004: val_acc did not improve from 0.43478
# Confusion matrix:
#  []
# Epoch 5/30
# 4/4 [==============================] - 1s 267ms/step - loss: 0.6844 - mean_absolute_error: 0.4372 - acc: 0.5805 - val_loss: 0.6953 - val_mean_absolute_error: 0.4621 - val_acc: 0.5217
#
# Epoch 00005: val_acc improved from 0.43478 to 0.52174, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  []
# Epoch 6/30
# 4/4 [==============================] - 1s 299ms/step - loss: 0.6497 - mean_absolute_error: 0.4199 - acc: 0.6211 - val_loss: 0.6498 - val_mean_absolute_error: 0.4411 - val_acc: 0.5217
#
# Epoch 00006: val_acc did not improve from 0.52174
# Confusion matrix:
#  []
# Epoch 7/30
# 4/4 [==============================] - 1s 261ms/step - loss: 0.5488 - mean_absolute_error: 0.3805 - acc: 0.7133 - val_loss: 0.5995 - val_mean_absolute_error: 0.4153 - val_acc: 0.5652
#
# Epoch 00007: val_acc improved from 0.52174 to 0.56522, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  []
# Epoch 8/30
# 4/4 [==============================] - 1s 271ms/step - loss: 0.5461 - mean_absolute_error: 0.3750 - acc: 0.7243 - val_loss: 0.5626 - val_mean_absolute_error: 0.3959 - val_acc: 0.5652
#
# Epoch 00008: val_acc did not improve from 0.56522
# Confusion matrix:
#  []
# Epoch 9/30
# 4/4 [==============================] - 1s 304ms/step - loss: 0.5083 - mean_absolute_error: 0.3600 - acc: 0.7617 - val_loss: 0.5227 - val_mean_absolute_error: 0.3742 - val_acc: 0.6957
#
# Epoch 00009: val_acc improved from 0.56522 to 0.69565, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  []
# Epoch 10/30
# 4/4 [==============================] - 1s 265ms/step - loss: 0.4743 - mean_absolute_error: 0.3423 - acc: 0.7920 - val_loss: 0.4882 - val_mean_absolute_error: 0.3547 - val_acc: 0.7391
#
# Epoch 00010: val_acc improved from 0.69565 to 0.73913, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  []
# Epoch 11/30
# 4/4 [==============================] - 1s 302ms/step - loss: 0.4350 - mean_absolute_error: 0.3173 - acc: 0.8047 - val_loss: 0.4569 - val_mean_absolute_error: 0.3371 - val_acc: 0.7826
#
# Epoch 00011: val_acc improved from 0.73913 to 0.78261, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  []
# Epoch 12/30
# 4/4 [==============================] - 1s 253ms/step - loss: 0.3907 - mean_absolute_error: 0.2920 - acc: 0.8476 - val_loss: 0.4265 - val_mean_absolute_error: 0.3196 - val_acc: 0.8261
#
# Epoch 00012: val_acc improved from 0.78261 to 0.82609, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  []
# Epoch 13/30
# 4/4 [==============================] - 1s 307ms/step - loss: 0.3863 - mean_absolute_error: 0.2864 - acc: 0.8672 - val_loss: 0.3970 - val_mean_absolute_error: 0.3026 - val_acc: 0.8261
#
# Epoch 00013: val_acc did not improve from 0.82609
# Confusion matrix:
#  []
# Epoch 14/30
# 4/4 [==============================] - 1s 239ms/step - loss: 0.3459 - mean_absolute_error: 0.2596 - acc: 0.8841 - val_loss: 0.3687 - val_mean_absolute_error: 0.2853 - val_acc: 0.9130
#
# Epoch 00014: val_acc improved from 0.82609 to 0.91304, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  []
# Epoch 15/30
# 4/4 [==============================] - 1s 302ms/step - loss: 0.3239 - mean_absolute_error: 0.2518 - acc: 0.8984 - val_loss: 0.3473 - val_mean_absolute_error: 0.2715 - val_acc: 0.9130
#
# Epoch 00015: val_acc did not improve from 0.91304
# Confusion matrix:
#  []
# Epoch 16/30
# 4/4 [==============================] - 1s 269ms/step - loss: 0.3186 - mean_absolute_error: 0.2449 - acc: 0.8839 - val_loss: 0.3307 - val_mean_absolute_error: 0.2605 - val_acc: 0.9130
#
# Epoch 00016: val_acc did not improve from 0.91304
# Confusion matrix:
#  []
# Epoch 17/30
# 4/4 [==============================] - 1s 303ms/step - loss: 0.3001 - mean_absolute_error: 0.2310 - acc: 0.8984 - val_loss: 0.3166 - val_mean_absolute_error: 0.2507 - val_acc: 0.9130
#
# Epoch 00017: val_acc did not improve from 0.91304
# Confusion matrix:
#  []
# Epoch 18/30
# 4/4 [==============================] - 1s 289ms/step - loss: 0.2686 - mean_absolute_error: 0.2140 - acc: 0.9277 - val_loss: 0.3037 - val_mean_absolute_error: 0.2424 - val_acc: 0.9130
#
# Epoch 00018: val_acc did not improve from 0.91304
# Confusion matrix:
#  []
# Epoch 19/30
# 4/4 [==============================] - 1s 287ms/step - loss: 0.2643 - mean_absolute_error: 0.2126 - acc: 0.9358 - val_loss: 0.2894 - val_mean_absolute_error: 0.2331 - val_acc: 0.9565
#
# Epoch 00019: val_acc improved from 0.91304 to 0.95652, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  []
# Epoch 20/30
# 4/4 [==============================] - 1s 265ms/step - loss: 0.2360 - mean_absolute_error: 0.1925 - acc: 0.9559 - val_loss: 0.2794 - val_mean_absolute_error: 0.2265 - val_acc: 0.9565
#
# Epoch 00020: val_acc did not improve from 0.95652
# Confusion matrix:
#  []
# Epoch 21/30
# 4/4 [==============================] - 1s 271ms/step - loss: 0.2170 - mean_absolute_error: 0.1820 - acc: 0.9600 - val_loss: 0.2680 - val_mean_absolute_error: 0.2185 - val_acc: 0.9565
#
# Epoch 00021: val_acc did not improve from 0.95652
# Confusion matrix:
#  []
# Epoch 22/30
# 4/4 [==============================] - 1s 305ms/step - loss: 0.2204 - mean_absolute_error: 0.1782 - acc: 0.9531 - val_loss: 0.2571 - val_mean_absolute_error: 0.2105 - val_acc: 0.9565
#
# Epoch 00022: val_acc did not improve from 0.95652
# Confusion matrix:
#  []
# Epoch 23/30
# 4/4 [==============================] - 1s 232ms/step - loss: 0.2386 - mean_absolute_error: 0.1894 - acc: 0.9425 - val_loss: 0.2466 - val_mean_absolute_error: 0.2033 - val_acc: 0.9565
#
# Epoch 00023: val_acc did not improve from 0.95652
# Confusion matrix:
#  []
# Epoch 24/30
# 4/4 [==============================] - 1s 266ms/step - loss: 0.1969 - mean_absolute_error: 0.1639 - acc: 0.9524 - val_loss: 0.2369 - val_mean_absolute_error: 0.1963 - val_acc: 0.9565
#
# Epoch 00024: val_acc did not improve from 0.95652
# Confusion matrix:
#  []
# Epoch 25/30
# 4/4 [==============================] - 1s 304ms/step - loss: 0.1892 - mean_absolute_error: 0.1580 - acc: 0.9727 - val_loss: 0.2269 - val_mean_absolute_error: 0.1887 - val_acc: 0.9565
#
# Epoch 00025: val_acc did not improve from 0.95652
# Confusion matrix:
#  []
# Epoch 26/30
# 4/4 [==============================] - 1s 266ms/step - loss: 0.1945 - mean_absolute_error: 0.1586 - acc: 0.9527 - val_loss: 0.2196 - val_mean_absolute_error: 0.1830 - val_acc: 0.9565
#
# Epoch 00026: val_acc did not improve from 0.95652
# Restoring model weights from the end of the best epoch
# Confusion matrix:
#  []
# Epoch 00026: early stopping
# 33/33 [==============================] - 1s 42ms/step
# 33/33 [==============================] - 0s 9ms/step
# Test loss: 0.6753973706879399
# Test mae: 0.4199920055089575
# Test accuracy: 0.5757575757575758
# Confusion Matrix
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-10fa646f6e6f> in <module>
#     247 # generator.classes gives you the truth label y_true
#     248 print('Confusion Matrix')
# --> 249 cm = confusion_matrix(y_true, y_pred)
#     250
#     251 print(cm)
#
# NameError: name 'confusion_matrix' is not defined

# %%
from sklearn.metrics import confusion_matrix, classification_report

test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test mae:', score[1])
print('Test accuracy:', score[2])


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# 33/33 [==============================] - 0s 11ms/step
# 33/33 [==============================] - 0s 10ms/step
# Test loss: 0.6753973706879399
# Test mae: 0.4199920055089575
# Test accuracy: 0.5757575757575758
# Confusion Matrix
# [[ 1 11]
#  [ 3 18]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.25      0.08      0.12        12
#            1       0.62      0.86      0.72        21
#
#     accuracy                           0.58        33
#    macro avg       0.44      0.47      0.42        33
# weighted avg       0.49      0.58      0.50        33

# %%
def kappa2(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    if len(y_true.shape) > 1 and y_true.shape[1] > 1:
        y_true = y_true.dot(range(y_true.shape[1]))
    if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
        y_pred = y_pred.dot(range(y_pred.shape[1]))
    try:
        return kappa(y_true, y_pred, weights='quadratic')
    except IndexError:
        return np.nan
    
print('Quadratic_wieghted_kappa')
print(kappa2(y_true, y_pred))
# Out:
# Quadratic_wieghted_kappa
# -0.0694444444444442

# %%
# list all data in history
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model loss.png')

# summarize history for val_kappa
plt.plot(history.history['val_kappa'])
plt.title('Validation_Kappa')
plt.ylabel('val_kappa')
plt.xlabel('epoch')
plt.legend([ 'validation'], loc='upper left')
plt.show()
#plt.savefig('model validation_kappa.png')

# summarize history for mean_absolute _error
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model mean_absolute_error')
plt.ylabel('mean_absolute_error')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model maey.png')
# Out:
# dict_keys(['val_loss', 'val_mean_absolute_error', 'val_acc', 'loss', 'mean_absolute_error', 'acc'])
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-b7c163781efd> in <module>
#      22
#      23 # summarize history for val_kappa
# ---> 24 plt.plot(history.history['val_kappa'])
#      25 plt.title('Validation_Kappa')
#      26 plt.ylabel('val_kappa')
#
# KeyError: 'val_kappa'
