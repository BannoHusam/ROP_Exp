# %%
import keras
from keras.models import Sequential, Input, Model
from keras.losses import mean_squared_error
from keras.layers import  *
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, InputLayer
from keras.regularizers import L1L2, l2, l1
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from custom_pooling import RMSPooling2D
from keras.optimizers import SGD, Adam
from keras.layers import LeakyReLU
#from data import BALANCE_WEIGHTS
from keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
#import os
from datetime import datetime as dt
from custom_loss import WeightedCategoricalCrossEntropy
from VCM import VCM
import keras.backend as K
from Fractional_MAXPOOL import FractionalPooling2D
from QWK import QWK
import tensorflow as tf
from Fractional_MAXPOOL import FractionalPooling2D

import numpy as np 
import matplotlib.pyplot as plt
import os
import wandb
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
def get_experiment_id():
    time_str = dt.now().strftime('%Y-%m-%d-%H-%M-%S')
    experiment_id = 'base_{}'.format(time_str)
    return experiment_id
p_ratio=[1.0, 1.44, 1.73, 1.0]

model = Sequential()


model.add(Conv2D(16, (5, 5), activation='tanh', input_shape=(270, 270, 3)))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(16, (3, 3), activation='tanh'))
model.add(Conv2D(16, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

#model.add(LeakyReLU(alpha=0.01))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))


model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))


model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))


#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))



#model.add(MaxPooling2D(pool_size=1))




model.add(MaxPooling2D(pool_size=2))

model.add(Flatten())


#chnaged from 10 to 5 because an error 
model.add(Dense(2, activation='softmax'))

sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.count_params()
#adam = Adam(lr=0.0005, decay=1e-6)
#rmsprop
#Mloss = WeightedCategoricalCrossEntropy({0: 0.4125861396437394, 1: 1.4918664786083686, 2: 0.690426457789382, 3: 3.9541433021806855, 4: 4.885604311008468})
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['acc','mae'])
model.summary()
loss_no_weight_decay = model.total_loss - sum(model.losses)
model.metrics_tensors.append(loss_no_weight_decay)
model.metrics_names.append('loss_no_weight_decay')
#############################################################################################
#############################################################################################
#############################################################################################
#############################################################################################
#Preparing Data Augmentation Configuration 
train_datagen = ImageDataGenerator(
        rescale=1./255,
#        featurewise_center=True,
 #       samplewise_center=True,
        shear_range=0,
        zoom_range=0.0,#[1 / 1.15, 1.15],
        horizontal_flip=False,#True,
        rotation_range=0)#90,
#        validation_split=0.2)
"""
For the test set only rescale should be made 
"""
test_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/grahprepross/bin_bal/train",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="training")
#    save_to_dir="D:/Separating Images into subfolders/train_augmented")


#print(train_generator.class_indices)

valid_generator = valid_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/grahprepross/bin_bal/vald",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="validation")
#    save_to_dir="D:/Separating Images into subfolders/val_augmented"


test_generator = test_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/grahprepross/bin_bal/test",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=1,
    class_mode="categorical",
    shuffle=False,
    seed=42)
#    save_to_dir="D:/Separating Images into subfolders/test_augmented")


# Fitting/Training the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
experiment_id = get_experiment_id()
callbacks = [
    EarlyStopping(monitor='val_acc', patience=10, min_delta=0.001, verbose=1),
    ModelCheckpoint(experiment_id + "-val_acc_checkpoint.hdf5", monitor='val_acc', verbose=1, save_best_only=True, mode='max'),
    ReduceLROnPlateau(monitor='val_acc', factor=0.5, patience=7, verbose=1, mode='auto', min_delta=0.001, cooldown=0, min_lr=1e-7),
    VCM(valid_generator,STEP_SIZE_VALID)
    
]

class_weight_list = class_weight.compute_class_weight('balanced', np.unique(train_generator.classes), train_generator.classes)
class_weights = dict(zip(np.unique(train_generator.classes), class_weight_list))

history=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    #class_weight=class_weights,
                    callbacks=callbacks,
                    epochs=35  
)


# Evaluating the model 
#predicting output
#reseting the test generator before calling predict_generator, in order not to get weird output
test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 266, 266, 16)      1216
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 262, 262, 16)      6416
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 260, 260, 16)      2320
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 258, 258, 16)      2320
# _________________________________________________________________
# fractional_pooling2d_1 (Frac (None, 143, 143, 16)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 139, 139, 16)      6416
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 135, 135, 16)      6416
# _________________________________________________________________
# fractional_pooling2d_2 (Frac (None, 75, 75, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 71, 71, 16)        6416
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 67, 67, 16)        6416
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 65, 65, 32)        4640
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 63, 63, 32)        9248
# _________________________________________________________________
# fractional_pooling2d_3 (Frac (None, 35, 35, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 33, 33, 32)        9248
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 31, 31, 32)        9248
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 29, 29, 64)        18496
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 27, 27, 64)        36928
# _________________________________________________________________
# fractional_pooling2d_4 (Frac (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 13, 13, 64)        36928
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 11, 11, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1600)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 3202
# =================================================================
# Total params: 202,802
# Trainable params: 202,802
# Non-trainable params: 0
# _________________________________________________________________
# Found 462 images belonging to 2 classes.
# Found 154 images belonging to 2 classes.
# Found 66 images belonging to 2 classes.
# Epoch 1/35
# 7/7 [==============================] - 18s 3s/step - loss: 0.6959 - acc: 0.5138 - mean_absolute_error: 0.4996 - loss_no_weight_decay: 0.6959 - val_loss: 0.6923 - val_acc: 0.5000 - val_mean_absolute_error: 0.4994 - val_loss_no_weight_decay: 0.6923
#
# Epoch 00001: val_acc improved from -inf to 0.50000, saving model to base_2020-05-12-20-35-25-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[58  4]
#  [59  7]]
# Epoch 2/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.6888 - acc: 0.5527 - mean_absolute_error: 0.4963 - loss_no_weight_decay: 0.6888 - val_loss: 0.6935 - val_acc: 0.5000 - val_mean_absolute_error: 0.4964 - val_loss_no_weight_decay: 0.6935
#
# Epoch 00002: val_acc did not improve from 0.50000
# Confusion matrix:
#  [[ 0 39]
#  [ 0 51]]
# Epoch 3/35
# 7/7 [==============================] - 11s 2s/step - loss: 0.6958 - acc: 0.4751 - mean_absolute_error: 0.4995 - loss_no_weight_decay: 0.6958 - val_loss: 0.6991 - val_acc: 0.4778 - val_mean_absolute_error: 0.4995 - val_loss_no_weight_decay: 0.6991
#
# Epoch 00003: val_acc did not improve from 0.50000
# Confusion matrix:
#  [[36  0]
#  [54  0]]
# Epoch 4/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.6935 - acc: 0.4906 - mean_absolute_error: 0.4982 - loss_no_weight_decay: 0.6935 - val_loss: 0.6846 - val_acc: 0.6172 - val_mean_absolute_error: 0.4955 - val_loss_no_weight_decay: 0.6846
#
# Epoch 00004: val_acc improved from 0.50000 to 0.61719, saving model to base_2020-05-12-20-35-25-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[55 12]
#  [37 24]]
# Epoch 5/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.6840 - acc: 0.6113 - mean_absolute_error: 0.4950 - loss_no_weight_decay: 0.6840 - val_loss: 0.6841 - val_acc: 0.6000 - val_mean_absolute_error: 0.4951 - val_loss_no_weight_decay: 0.6841
#
# Epoch 00005: val_acc did not improve from 0.61719
# Confusion matrix:
#  [[15 33]
#  [ 2 40]]
# Epoch 6/35
# 7/7 [==============================] - 13s 2s/step - loss: 0.6814 - acc: 0.6116 - mean_absolute_error: 0.4936 - loss_no_weight_decay: 0.6814 - val_loss: 0.6745 - val_acc: 0.7111 - val_mean_absolute_error: 0.4904 - val_loss_no_weight_decay: 0.6745
#
# Epoch 00006: val_acc improved from 0.61719 to 0.71111, saving model to base_2020-05-12-20-35-25-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[34 11]
#  [20 25]]
# Epoch 7/35
# 7/7 [==============================] - 11s 2s/step - loss: 0.6744 - acc: 0.6821 - mean_absolute_error: 0.4900 - loss_no_weight_decay: 0.6744 - val_loss: 0.6729 - val_acc: 0.6719 - val_mean_absolute_error: 0.4890 - val_loss_no_weight_decay: 0.6729
#
# Epoch 00007: val_acc did not improve from 0.71111
# Confusion matrix:
#  [[32 30]
#  [10 56]]
# Epoch 8/35
# 7/7 [==============================] - 11s 2s/step - loss: 0.6693 - acc: 0.6250 - mean_absolute_error: 0.4865 - loss_no_weight_decay: 0.6693 - val_loss: 0.6500 - val_acc: 0.7111 - val_mean_absolute_error: 0.4757 - val_loss_no_weight_decay: 0.6500
#
# Epoch 00008: val_acc did not improve from 0.71111
# Confusion matrix:
#  [[34  9]
#  [27 20]]
# Epoch 9/35
# 7/7 [==============================] - 11s 2s/step - loss: 0.6545 - acc: 0.6700 - mean_absolute_error: 0.4762 - loss_no_weight_decay: 0.6545 - val_loss: 0.6518 - val_acc: 0.5889 - val_mean_absolute_error: 0.4698 - val_loss_no_weight_decay: 0.6518
#
# Epoch 00009: val_acc did not improve from 0.71111
# Confusion matrix:
#  [[ 7 32]
#  [ 3 48]]
# Epoch 10/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.6781 - acc: 0.5612 - mean_absolute_error: 0.4778 - loss_no_weight_decay: 0.6781 - val_loss: 0.6509 - val_acc: 0.6094 - val_mean_absolute_error: 0.4692 - val_loss_no_weight_decay: 0.6509
#
# Epoch 00010: val_acc did not improve from 0.71111
# Confusion matrix:
#  [[19 45]
#  [ 3 61]]
# Epoch 11/35
# 7/7 [==============================] - 13s 2s/step - loss: 0.6522 - acc: 0.6161 - mean_absolute_error: 0.4631 - loss_no_weight_decay: 0.6522 - val_loss: 0.6600 - val_acc: 0.6000 - val_mean_absolute_error: 0.4766 - val_loss_no_weight_decay: 0.6600
#
# Epoch 00011: val_acc did not improve from 0.71111
# Confusion matrix:
#  [[44  6]
#  [15 25]]
# Epoch 12/35
# 7/7 [==============================] - 10s 1s/step - loss: 0.6357 - acc: 0.6552 - mean_absolute_error: 0.4568 - loss_no_weight_decay: 0.6357 - val_loss: 0.5893 - val_acc: 0.7556 - val_mean_absolute_error: 0.4387 - val_loss_no_weight_decay: 0.5893
#
# Epoch 00012: val_acc improved from 0.71111 to 0.75556, saving model to base_2020-05-12-20-35-25-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[30 10]
#  [16 34]]
# Epoch 13/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.6655 - acc: 0.6367 - mean_absolute_error: 0.4627 - loss_no_weight_decay: 0.6655 - val_loss: 0.6295 - val_acc: 0.6719 - val_mean_absolute_error: 0.4501 - val_loss_no_weight_decay: 0.6295
# Epoch 00013: val_acc did not improve from 0.75556
# Confusion matrix:
#  [[57  5]
#  [40 26]]
# Epoch 14/35
# 7/7 [==============================] - 13s 2s/step - loss: 0.5968 - acc: 0.7188 - mean_absolute_error: 0.4366 - loss_no_weight_decay: 0.5968 - val_loss: 0.5864 - val_acc: 0.7000 - val_mean_absolute_error: 0.4303 - val_loss_no_weight_decay: 0.5864
#
# Epoch 00014: val_acc did not improve from 0.75556
# Confusion matrix:
#  [[37  7]
#  [22 24]]
# Epoch 15/35
# 7/7 [==============================] - 11s 2s/step - loss: 0.6000 - acc: 0.6817 - mean_absolute_error: 0.4253 - loss_no_weight_decay: 0.6000 - val_loss: 0.5540 - val_acc: 0.7667 - val_mean_absolute_error: 0.4035 - val_loss_no_weight_decay: 0.5540
#
# Epoch 00015: val_acc improved from 0.75556 to 0.76667, saving model to base_2020-05-12-20-35-25-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[38 12]
#  [10 30]]
# Epoch 16/35
# 7/7 [==============================] - 11s 2s/step - loss: 0.5970 - acc: 0.6730 - mean_absolute_error: 0.3999 - loss_no_weight_decay: 0.5970 - val_loss: 0.5629 - val_acc: 0.7109 - val_mean_absolute_error: 0.3942 - val_loss_no_weight_decay: 0.5629
#
# Epoch 00016: val_acc did not improve from 0.76667
# Confusion matrix:
#  [[31 27]
#  [ 9 61]]
# Epoch 17/35
# 7/7 [==============================] - 11s 2s/step - loss: 0.6429 - acc: 0.6184 - mean_absolute_error: 0.4266 - loss_no_weight_decay: 0.6429 - val_loss: 0.6519 - val_acc: 0.6000 - val_mean_absolute_error: 0.4497 - val_loss_no_weight_decay: 0.6519
#
# Epoch 00017: val_acc did not improve from 0.76667
# Confusion matrix:
#  [[14 31]
#  [ 0 45]]
# Epoch 18/35
# 7/7 [==============================] - 11s 2s/step - loss: 0.5981 - acc: 0.6906 - mean_absolute_error: 0.4357 - loss_no_weight_decay: 0.5981 - val_loss: 0.5524 - val_acc: 0.7778 - val_mean_absolute_error: 0.4137 - val_loss_no_weight_decay: 0.5524
#
# Epoch 00018: val_acc improved from 0.76667 to 0.77778, saving model to base_2020-05-12-20-35-25-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[37 11]
#  [17 25]]
# Epoch 19/35
# 7/7 [==============================] - 11s 2s/step - loss: 0.5778 - acc: 0.7156 - mean_absolute_error: 0.4203 - loss_no_weight_decay: 0.5778 - val_loss: 0.5282 - val_acc: 0.7578 - val_mean_absolute_error: 0.3894 - val_loss_no_weight_decay: 0.5282
#
# Epoch 00019: val_acc did not improve from 0.77778
# Confusion matrix:
#  [[53 13]
#  [20 42]]
# Epoch 20/35
# 7/7 [==============================] - 13s 2s/step - loss: 0.5201 - acc: 0.7522 - mean_absolute_error: 0.3723 - loss_no_weight_decay: 0.5201 - val_loss: 0.5877 - val_acc: 0.6556 - val_mean_absolute_error: 0.3968 - val_loss_no_weight_decay: 0.5877
#
# Epoch 00020: val_acc did not improve from 0.77778
# Confusion matrix:
#  [[29 11]
#  [ 7 43]]
# Epoch 21/35
# 7/7 [==============================] - 10s 1s/step - loss: 0.4701 - acc: 0.7894 - mean_absolute_error: 0.3263 - loss_no_weight_decay: 0.4701 - val_loss: 0.4329 - val_acc: 0.8333 - val_mean_absolute_error: 0.2812 - val_loss_no_weight_decay: 0.4329
#
# Epoch 00021: val_acc improved from 0.77778 to 0.83333, saving model to base_2020-05-12-20-35-25-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[27 16]
#  [ 8 39]]
# Epoch 22/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.4683 - acc: 0.7524 - mean_absolute_error: 0.3018 - loss_no_weight_decay: 0.4683 - val_loss: 0.4555 - val_acc: 0.7969 - val_mean_absolute_error: 0.2953 - val_loss_no_weight_decay: 0.4555
#
# Epoch 00022: val_acc did not improve from 0.83333
# Confusion matrix:
#  [[60  6]
#  [18 44]]
# Epoch 23/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.4878 - acc: 0.7708 - mean_absolute_error: 0.3060 - loss_no_weight_decay: 0.4878 - val_loss: 0.5147 - val_acc: 0.7444 - val_mean_absolute_error: 0.3415 - val_loss_no_weight_decay: 0.5147
#
# Epoch 00023: val_acc did not improve from 0.83333
# Confusion matrix:
#  [[36  8]
#  [10 36]]
# Epoch 24/35
# 7/7 [==============================] - 13s 2s/step - loss: 0.4461 - acc: 0.7991 - mean_absolute_error: 0.3078 - loss_no_weight_decay: 0.4461 - val_loss: 0.4681 - val_acc: 0.7444 - val_mean_absolute_error: 0.3100 - val_loss_no_weight_decay: 0.4681
#
# Epoch 00024: val_acc did not improve from 0.83333
# Confusion matrix:
#  [[43  4]
#  [20 23]]
# Epoch 25/35
# 7/7 [==============================] - 11s 2s/step - loss: 0.4303 - acc: 0.7888 - mean_absolute_error: 0.2881 - loss_no_weight_decay: 0.4303 - val_loss: 0.4354 - val_acc: 0.7891 - val_mean_absolute_error: 0.2800 - val_loss_no_weight_decay: 0.4354
#
# Epoch 00025: val_acc did not improve from 0.83333
# Confusion matrix:
#  [[58  6]
#  [25 39]]
# Epoch 26/35
# 7/7 [==============================] - 11s 2s/step - loss: 0.3875 - acc: 0.8207 - mean_absolute_error: 0.2634 - loss_no_weight_decay: 0.3875 - val_loss: 0.7447 - val_acc: 0.6333 - val_mean_absolute_error: 0.3655 - val_loss_no_weight_decay: 0.7447
#
# Epoch 00026: val_acc did not improve from 0.83333
# Confusion matrix:
#  [[44  0]
#  [29 17]]
# Epoch 27/35
# 7/7 [==============================] - 13s 2s/step - loss: 0.4170 - acc: 0.8013 - mean_absolute_error: 0.2654 - loss_no_weight_decay: 0.4170 - val_loss: 0.3683 - val_acc: 0.8111 - val_mean_absolute_error: 0.2531 - val_loss_no_weight_decay: 0.3683
#
# Epoch 00027: val_acc did not improve from 0.83333
# Confusion matrix:
#  [[36 10]
#  [ 6 38]]
# Epoch 28/35
# 7/7 [==============================] - 10s 1s/step - loss: 0.4289 - acc: 0.7986 - mean_absolute_error: 0.2878 - loss_no_weight_decay: 0.4289 - val_loss: 0.3856 - val_acc: 0.8359 - val_mean_absolute_error: 0.2778 - val_loss_no_weight_decay: 0.3856
#
# Epoch 00028: val_acc improved from 0.83333 to 0.83594, saving model to base_2020-05-12-20-35-25-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[59  7]
#  [ 9 53]]
# Epoch 29/35
# 7/7 [==============================] - 11s 2s/step - loss: 0.3238 - acc: 0.8615 - mean_absolute_error: 0.2381 - loss_no_weight_decay: 0.3238 - val_loss: 0.3015 - val_acc: 0.8667 - val_mean_absolute_error: 0.2062 - val_loss_no_weight_decay: 0.3015
#
# Epoch 00029: val_acc improved from 0.83594 to 0.86667, saving model to base_2020-05-12-20-35-25-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[42  9]
#  [11 28]]
# Epoch 30/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.3562 - acc: 0.8482 - mean_absolute_error: 0.2240 - loss_no_weight_decay: 0.3562 - val_loss: 0.4155 - val_acc: 0.8333 - val_mean_absolute_error: 0.2335 - val_loss_no_weight_decay: 0.4155
#
# Epoch 00030: val_acc did not improve from 0.86667
# Confusion matrix:
#  [[45  0]
#  [13 32]]
# Epoch 31/35
# 7/7 [==============================] - 11s 2s/step - loss: 0.4560 - acc: 0.7724 - mean_absolute_error: 0.2654 - loss_no_weight_decay: 0.4560 - val_loss: 0.3781 - val_acc: 0.8359 - val_mean_absolute_error: 0.2653 - val_loss_no_weight_decay: 0.3781
#
# Epoch 00031: val_acc did not improve from 0.86667
# Confusion matrix:
#  [[59  7]
#  [12 50]]
# Epoch 32/35
# 7/7 [==============================] - 11s 2s/step - loss: 0.3468 - acc: 0.8729 - mean_absolute_error: 0.2483 - loss_no_weight_decay: 0.3468 - val_loss: 0.4060 - val_acc: 0.8333 - val_mean_absolute_error: 0.2544 - val_loss_no_weight_decay: 0.4060
#
# Epoch 00032: val_acc did not improve from 0.86667
# Confusion matrix:
#  [[44  6]
#  [11 29]]
# Epoch 33/35
# 7/7 [==============================] - 11s 2s/step - loss: 0.3548 - acc: 0.8340 - mean_absolute_error: 0.2339 - loss_no_weight_decay: 0.3548 - val_loss: 0.3466 - val_acc: 0.8556 - val_mean_absolute_error: 0.2190 - val_loss_no_weight_decay: 0.3466
#
# Epoch 00033: val_acc did not improve from 0.86667
# Confusion matrix:
#  [[35  8]
#  [ 5 42]]
# Epoch 34/35
# 7/7 [==============================] - 11s 2s/step - loss: 0.3609 - acc: 0.8364 - mean_absolute_error: 0.2270 - loss_no_weight_decay: 0.3609 - val_loss: 0.3428 - val_acc: 0.8672 - val_mean_absolute_error: 0.2272 - val_loss_no_weight_decay: 0.3428
#
# Epoch 00034: val_acc improved from 0.86667 to 0.86719, saving model to base_2020-05-12-20-35-25-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[65  0]
#  [19 44]]
# Epoch 35/35
# 7/7 [==============================] - 13s 2s/step - loss: 0.2776 - acc: 0.8772 - mean_absolute_error: 0.2009 - loss_no_weight_decay: 0.2776 - val_loss: 0.3974 - val_acc: 0.8111 - val_mean_absolute_error: 0.2329 - val_loss_no_weight_decay: 0.3974
#
# Epoch 00035: val_acc did not improve from 0.86719
# Confusion matrix:
#  [[32 13]
#  [ 4 41]]
# 66/66 [==============================] - 1s 9ms/step
# 66/66 [==============================] - 1s 8ms/step
# Test loss: 0.5416761557430481
# Test accuracy: 0.7727272727272727
# Confusion Matrix
# [[22 11]
#  [ 2 31]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.92      0.67      0.77        33
#            1       0.74      0.94      0.83        33
#
#     accuracy                           0.80        66
#    macro avg       0.83      0.80      0.80        66
# weighted avg       0.83      0.80      0.80        66

# %%
from Kappa_Skl import kappa
def kappa2(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    if len(y_true.shape) > 1 and y_true.shape[1] > 1:
        y_true = y_true.dot(range(y_true.shape[1]))
    if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
        y_pred = y_pred.dot(range(y_pred.shape[1]))
    try:
        return kappa(y_true, y_pred, weights='quadratic')
    except IndexError:
        return np.nan
    
print('Quadratic_wieghted_kappa')
print(kappa2(y_true, y_pred))
# Out:
# Quadratic_wieghted_kappa
# 0.6060606060606061

# %%
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
