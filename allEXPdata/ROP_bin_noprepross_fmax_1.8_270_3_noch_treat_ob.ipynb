# %%
import keras
from keras.models import Sequential, Input, Model
from keras.losses import mean_squared_error
from keras.layers import  *
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, InputLayer
from keras.regularizers import L1L2, l2, l1
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from custom_pooling import RMSPooling2D
from keras.optimizers import SGD, Adam
from keras.layers import LeakyReLU
#from data import BALANCE_WEIGHTS
from keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
#import os
from datetime import datetime as dt
from custom_loss import WeightedCategoricalCrossEntropy
from VCM import VCM
import keras.backend as K
from Fractional_MAXPOOL import FractionalPooling2D
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
def get_experiment_id():
    time_str = dt.now().strftime('%Y-%m-%d-%H-%M-%S')
    experiment_id = 'base_{}'.format(time_str)
    return experiment_id
p_ratio=[1.0, 1.44, 1.73, 1.0]

model = Sequential()


model.add(Conv2D(16, (5, 5), activation='tanh', input_shape=(270, 270, 3)))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(16, (3, 3), activation='tanh'))
model.add(Conv2D(16, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

#model.add(LeakyReLU(alpha=0.01))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))


model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))


model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))


#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))



#model.add(MaxPooling2D(pool_size=1))




model.add(MaxPooling2D(pool_size=2))

model.add(Flatten())


#chnaged from 10 to 5 because an error 
model.add(Dense(2, activation='softmax'))

sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.count_params()
#adam = Adam(lr=0.0005, decay=1e-6)
#rmsprop
#Mloss = WeightedCategoricalCrossEntropy({0: 0.4125861396437394, 1: 1.4918664786083686, 2: 0.690426457789382, 3: 3.9541433021806855, 4: 4.885604311008468})
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['mae','acc'])
model.summary()
loss_no_weight_decay = model.total_loss - sum(model.losses)
model.metrics_tensors.append(loss_no_weight_decay)
model.metrics_names.append('loss_no_weight_decay')
#############################################################################################
#############################################################################################
#############################################################################################
#############################################################################################
#Preparing Data Augmentation Configuration 
train_datagen = ImageDataGenerator(
        rescale=1./255,
#        featurewise_center=True,
 #       samplewise_center=True,
        shear_range=0,
        zoom_range=0.0,#[1 / 1.15, 1.15],
        horizontal_flip=False,#True,
        rotation_range=0)#90,
#        validation_split=0.2)
"""
For the test set only rescale should be made 
"""
test_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_class_treatment_noch/train",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="training")
#    save_to_dir="D:/Separating Images into subfolders/train_augmented")


#print(train_generator.class_indices)

valid_generator = valid_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_class_treatment_noch/vald",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="validation")
#    save_to_dir="D:/Separating Images into subfolders/val_augmented"


test_generator = test_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_class_treatment_noch/test",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=1,
    class_mode="categorical",
    shuffle=False,
    seed=42)
#    save_to_dir="D:/Separating Images into subfolders/test_augmented")


# Fitting/Training the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
experiment_id = get_experiment_id()
callbacks = [
    EarlyStopping(monitor='val_acc', patience=50, min_delta=0.001, verbose=1),
    ModelCheckpoint(experiment_id + "-val_acc_checkpoint.hdf5", monitor='val_acc', verbose=1, save_best_only=True, mode='auto'),
    ReduceLROnPlateau(monitor='val_acc', factor=0.5, patience=7, verbose=1, mode='auto', min_delta=0.001, cooldown=0, min_lr=1e-7),
    VCM(valid_generator,STEP_SIZE_VALID)
    
]

class_weight_list = class_weight.compute_class_weight('balanced', np.unique(train_generator.classes), train_generator.classes)
class_weights = dict(zip(np.unique(train_generator.classes), class_weight_list))

history=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    #class_weight=class_weights,
                    callbacks=callbacks,
                    epochs=35  
)


# Evaluating the model 
#predicting output
#reseting the test generator before calling predict_generator, in order not to get weird output
test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 266, 266, 16)      1216
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 262, 262, 16)      6416
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 260, 260, 16)      2320
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 258, 258, 16)      2320
# _________________________________________________________________
# fractional_pooling2d_1 (Frac (None, 143, 143, 16)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 139, 139, 16)      6416
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 135, 135, 16)      6416
# _________________________________________________________________
# fractional_pooling2d_2 (Frac (None, 75, 75, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 71, 71, 16)        6416
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 67, 67, 16)        6416
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 65, 65, 32)        4640
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 63, 63, 32)        9248
# _________________________________________________________________
# fractional_pooling2d_3 (Frac (None, 35, 35, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 33, 33, 32)        9248
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 31, 31, 32)        9248
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 29, 29, 64)        18496
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 27, 27, 64)        36928
# _________________________________________________________________
# fractional_pooling2d_4 (Frac (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 13, 13, 64)        36928
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 11, 11, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1600)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 3202
# =================================================================
# Total params: 202,802
# Trainable params: 202,802
# Non-trainable params: 0
# _________________________________________________________________
# Found 285 images belonging to 2 classes.
# Found 23 images belonging to 2 classes.
# Found 33 images belonging to 2 classes.
# Epoch 1/35
# 4/4 [==============================] - 14s 3s/step - loss: 0.6823 - mean_absolute_error: 0.4916 - acc: 0.5089 - loss_no_weight_decay: 0.6823 - val_loss: 0.5637 - val_mean_absolute_error: 0.4103 - val_acc: 0.7826 - val_loss_no_weight_decay: 0.5637
#
# Epoch 00001: val_acc improved from -inf to 0.78261, saving model to base_2020-05-12-13-25-19-val_acc_checkpoint.hdf5
# Confusion matrix:
#  []
# Epoch 2/35
# 4/4 [==============================] - 6s 2s/step - loss: 0.4296 - mean_absolute_error: 0.3029 - acc: 0.8721 - loss_no_weight_decay: 0.4296 - val_loss: 0.5894 - val_mean_absolute_error: 0.2763 - val_acc: 0.7826 - val_loss_no_weight_decay: 0.5894
#
# Epoch 00002: val_acc did not improve from 0.78261
# Confusion matrix:
#  []
# Epoch 3/35
# 4/4 [==============================] - 7s 2s/step - loss: 0.4323 - mean_absolute_error: 0.2118 - acc: 0.8516 - loss_no_weight_decay: 0.4323 - val_loss: 0.6296 - val_mean_absolute_error: 0.2613 - val_acc: 0.7826 - val_loss_no_weight_decay: 0.6296
#
# Epoch 00003: val_acc did not improve from 0.78261
# Confusion matrix:
#  []
# Epoch 4/35
# 4/4 [==============================] - 6s 2s/step - loss: 0.5173 - mean_absolute_error: 0.2534 - acc: 0.8164 - loss_no_weight_decay: 0.5173 - val_loss: 0.5437 - val_mean_absolute_error: 0.3057 - val_acc: 0.7826 - val_loss_no_weight_decay: 0.5437
#
# Epoch 00004: val_acc did not improve from 0.78261
# Confusion matrix:
#  []
# Epoch 5/35
# 4/4 [==============================] - 6s 2s/step - loss: 0.4393 - mean_absolute_error: 0.2786 - acc: 0.8404 - loss_no_weight_decay: 0.4393 - val_loss: 0.5302 - val_mean_absolute_error: 0.3295 - val_acc: 0.7826 - val_loss_no_weight_decay: 0.5302
#
# Epoch 00005: val_acc did not improve from 0.78261
# Confusion matrix:
#  []
# Epoch 6/35
# 4/4 [==============================] - 6s 2s/step - loss: 0.4105 - mean_absolute_error: 0.2803 - acc: 0.8638 - loss_no_weight_decay: 0.4105 - val_loss: 0.5402 - val_mean_absolute_error: 0.3083 - val_acc: 0.7826 - val_loss_no_weight_decay: 0.5402
#
# Epoch 00006: val_acc did not improve from 0.78261
# Confusion matrix:
#  []
# Epoch 7/35
# 4/4 [==============================] - 7s 2s/step - loss: 0.4194 - mean_absolute_error: 0.2513 - acc: 0.8516 - loss_no_weight_decay: 0.4194 - val_loss: 0.5629 - val_mean_absolute_error: 0.2876 - val_acc: 0.7826 - val_loss_no_weight_decay: 0.5629
#
# Epoch 00007: val_acc did not improve from 0.78261
# Confusion matrix:
#  []
# Epoch 8/35
# 4/4 [==============================] - 7s 2s/step - loss: 0.4710 - mean_absolute_error: 0.2604 - acc: 0.8240 - loss_no_weight_decay: 0.4710 - val_loss: 0.5461 - val_mean_absolute_error: 0.3005 - val_acc: 0.7826 - val_loss_no_weight_decay: 0.5461
#
# Epoch 00008: val_acc did not improve from 0.78261
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Confusion matrix:
#  []
# Epoch 9/35
# 4/4 [==============================] - 6s 1s/step - loss: 0.4229 - mean_absolute_error: 0.2576 - acc: 0.8489 - loss_no_weight_decay: 0.4229 - val_loss: 0.5373 - val_mean_absolute_error: 0.3101 - val_acc: 0.7826 - val_loss_no_weight_decay: 0.5373
#
# Epoch 00009: val_acc did not improve from 0.78261
# Confusion matrix:
#  []
# Epoch 10/35
# 4/4 [==============================] - 7s 2s/step - loss: 0.4145 - mean_absolute_error: 0.2645 - acc: 0.8555 - loss_no_weight_decay: 0.4145 - val_loss: 0.5357 - val_mean_absolute_error: 0.3123 - val_acc: 0.7826 - val_loss_no_weight_decay: 0.5357
#
# Epoch 00010: val_acc did not improve from 0.78261
# Confusion matrix:
#  []
# Epoch 11/35
# 4/4 [==============================] - 6s 2s/step - loss: 0.4014 - mean_absolute_error: 0.2536 - acc: 0.8635 - loss_no_weight_decay: 0.4014 - val_loss: 0.5438 - val_mean_absolute_error: 0.3017 - val_acc: 0.7826 - val_loss_no_weight_decay: 0.5438
#
# Epoch 00011: val_acc did not improve from 0.78261
# Confusion matrix:
#  []
# Epoch 12/35
# 4/4 [==============================] - 7s 2s/step - loss: 0.4328 - mean_absolute_error: 0.2601 - acc: 0.8438 - loss_no_weight_decay: 0.4328 - val_loss: 0.5459 - val_mean_absolute_error: 0.2998 - val_acc: 0.7826 - val_loss_no_weight_decay: 0.5459
#
# Epoch 00012: val_acc did not improve from 0.78261
# Confusion matrix:
#  []
# Epoch 13/35
# 4/4 [==============================] - 5s 1s/step - loss: 0.4117 - mean_absolute_error: 0.2464 - acc: 0.8564 - loss_no_weight_decay: 0.4117 - val_loss: 0.5493 - val_mean_absolute_error: 0.2964 - val_acc: 0.7826 - val_loss_no_weight_decay: 0.5493
#
# Epoch 00013: val_acc did not improve from 0.78261
# Confusion matrix:
#  []
# Epoch 14/35
# 4/4 [==============================] - 7s 2s/step - loss: 0.4192 - mean_absolute_error: 0.2459 - acc: 0.8516 - loss_no_weight_decay: 0.4192 - val_loss: 0.5501 - val_mean_absolute_error: 0.2960 - val_acc: 0.7826 - val_loss_no_weight_decay: 0.5501
# Epoch 00014: val_acc did not improve from 0.78261
# Confusion matrix:
#  []
# Epoch 15/35
# 4/4 [==============================] - 6s 2s/step - loss: 0.4392 - mean_absolute_error: 0.2567 - acc: 0.8401 - loss_no_weight_decay: 0.4392 - val_loss: 0.5443 - val_mean_absolute_error: 0.3009 - val_acc: 0.7826 - val_loss_no_weight_decay: 0.5443
#
# Epoch 00015: val_acc did not improve from 0.78261
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Confusion matrix:
#  []
# Epoch 16/35
# 4/4 [==============================] - 6s 2s/step - loss: 0.4124 - mean_absolute_error: 0.2512 - acc: 0.8554 - loss_no_weight_decay: 0.4124 - val_loss: 0.5419 - val_mean_absolute_error: 0.3032 - val_acc: 0.7826 - val_loss_no_weight_decay: 0.5419
#
# Epoch 00016: val_acc did not improve from 0.78261
# Confusion matrix:
#  []
# Epoch 17/35
# 4/4 [==============================] - 7s 2s/step - loss: 0.3863 - mean_absolute_error: 0.2432 - acc: 0.8711 - loss_no_weight_decay: 0.3863 - val_loss: 0.5425 - val_mean_absolute_error: 0.3030 - val_acc: 0.7826 - val_loss_no_weight_decay: 0.5425
#
# Epoch 00017: val_acc did not improve from 0.78261
# Confusion matrix:
#  []
# Epoch 18/35
# 4/4 [==============================] - 6s 2s/step - loss: 0.4658 - mean_absolute_error: 0.2757 - acc: 0.8237 - loss_no_weight_decay: 0.4658 - val_loss: 0.5405 - val_mean_absolute_error: 0.3049 - val_acc: 0.7826 - val_loss_no_weight_decay: 0.5405
#
# Epoch 00018: val_acc did not improve from 0.78261
# Confusion matrix:
#  []
# Epoch 19/35
# 4/4 [==============================] - 6s 2s/step - loss: 0.4175 - mean_absolute_error: 0.2575 - acc: 0.8519 - loss_no_weight_decay: 0.4175 - val_loss: 0.5409 - val_mean_absolute_error: 0.3042 - val_acc: 0.7826 - val_loss_no_weight_decay: 0.5409
#
# Epoch 00019: val_acc did not improve from 0.78261
# Confusion matrix:
#  []
# Epoch 20/35
# 4/4 [==============================] - 6s 2s/step - loss: 0.4168 - mean_absolute_error: 0.2568 - acc: 0.8522 - loss_no_weight_decay: 0.4168 - val_loss: 0.5416 - val_mean_absolute_error: 0.3037 - val_acc: 0.7826 - val_loss_no_weight_decay: 0.5416
#
# Epoch 00020: val_acc did not improve from 0.78261
# Confusion matrix:
#  []
# Epoch 21/35
# 4/4 [==============================] - 7s 2s/step - loss: 0.4328 - mean_absolute_error: 0.2623 - acc: 0.8438 - loss_no_weight_decay: 0.4328 - val_loss: 0.5418 - val_mean_absolute_error: 0.3034 - val_acc: 0.7826 - val_loss_no_weight_decay: 0.5418
#
# Epoch 00021: val_acc did not improve from 0.78261
# Confusion matrix:
#  []
# Epoch 22/35
# 4/4 [==============================] - 6s 1s/step - loss: 0.4428 - mean_absolute_error: 0.2654 - acc: 0.8358 - loss_no_weight_decay: 0.4428 - val_loss: 0.5417 - val_mean_absolute_error: 0.3037 - val_acc: 0.7826 - val_loss_no_weight_decay: 0.5417
#
# Epoch 00022: val_acc did not improve from 0.78261
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Confusion matrix:
#  []
# Epoch 23/35
# 4/4 [==============================] - 7s 2s/step - loss: 0.4198 - mean_absolute_error: 0.2570 - acc: 0.8516 - loss_no_weight_decay: 0.4198 - val_loss: 0.5414 - val_mean_absolute_error: 0.3041 - val_acc: 0.7826 - val_loss_no_weight_decay: 0.5414
#
# Epoch 00023: val_acc did not improve from 0.78261
# Confusion matrix:
#  []
# Epoch 24/35
# 4/4 [==============================] - 5s 1s/step - loss: 0.3970 - mean_absolute_error: 0.2469 - acc: 0.8652 - loss_no_weight_decay: 0.3970 - val_loss: 0.5425 - val_mean_absolute_error: 0.3025 - val_acc: 0.7826 - val_loss_no_weight_decay: 0.5425
#
# Epoch 00024: val_acc did not improve from 0.78261
# Confusion matrix:
#  []
# Epoch 25/35
# 4/4 [==============================] - 7s 2s/step - loss: 0.4244 - mean_absolute_error: 0.2575 - acc: 0.8477 - loss_no_weight_decay: 0.4244 - val_loss: 0.5432 - val_mean_absolute_error: 0.3020 - val_acc: 0.7826 - val_loss_no_weight_decay: 0.5432
#
# Epoch 00025: val_acc did not improve from 0.78261
# Confusion matrix:
#  []
# Epoch 26/35
# 4/4 [==============================] - 6s 2s/step - loss: 0.4437 - mean_absolute_error: 0.2647 - acc: 0.8358 - loss_no_weight_decay: 0.4437 - val_loss: 0.5432 - val_mean_absolute_error: 0.3019 - val_acc: 0.7826 - val_loss_no_weight_decay: 0.5432
#
# Epoch 00026: val_acc did not improve from 0.78261
# Confusion matrix:
#  []
# Epoch 27/35
# 4/4 [==============================] - 6s 2s/step - loss: 0.3920 - mean_absolute_error: 0.2423 - acc: 0.8678 - loss_no_weight_decay: 0.3920 - val_loss: 0.5448 - val_mean_absolute_error: 0.3003 - val_acc: 0.7826 - val_loss_no_weight_decay: 0.5448
#
# Epoch 00027: val_acc did not improve from 0.78261
# Confusion matrix:
#  []
# Epoch 28/35
# 4/4 [==============================] - 7s 2s/step - loss: 0.4052 - mean_absolute_error: 0.2465 - acc: 0.8594 - loss_no_weight_decay: 0.4052 - val_loss: 0.5457 - val_mean_absolute_error: 0.2994 - val_acc: 0.7826 - val_loss_no_weight_decay: 0.5457
#
# Epoch 00028: val_acc did not improve from 0.78261
# Confusion matrix:
#  []
# Epoch 29/35
# 4/4 [==============================] - 6s 2s/step - loss: 0.4369 - mean_absolute_error: 0.2601 - acc: 0.8401 - loss_no_weight_decay: 0.4369 - val_loss: 0.5447 - val_mean_absolute_error: 0.3003 - val_acc: 0.7826 - val_loss_no_weight_decay: 0.5447
#
# Epoch 00029: val_acc did not improve from 0.78261
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Confusion matrix:
#  []
# Epoch 30/35
# 4/4 [==============================] - 6s 2s/step - loss: 0.4265 - mean_absolute_error: 0.2556 - acc: 0.8479 - loss_no_weight_decay: 0.4265 - val_loss: 0.5445 - val_mean_absolute_error: 0.3007 - val_acc: 0.7826 - val_loss_no_weight_decay: 0.5445
#
# Epoch 00030: val_acc did not improve from 0.78261
# Confusion matrix:
#  []
# Epoch 31/35
# 4/4 [==============================] - 6s 2s/step - loss: 0.4592 - mean_absolute_error: 0.2697 - acc: 0.8280 - loss_no_weight_decay: 0.4592 - val_loss: 0.5437 - val_mean_absolute_error: 0.3017 - val_acc: 0.7826 - val_loss_no_weight_decay: 0.5437
#
# Epoch 00031: val_acc did not improve from 0.78261
# Confusion matrix:
#  []
# Epoch 32/35
# 4/4 [==============================] - 6s 2s/step - loss: 0.3353 - mean_absolute_error: 0.2197 - acc: 0.9000 - loss_no_weight_decay: 0.3353 - val_loss: 0.5450 - val_mean_absolute_error: 0.3004 - val_acc: 0.7826 - val_loss_no_weight_decay: 0.5450
#
# Epoch 00032: val_acc did not improve from 0.78261
# Confusion matrix:
#  []
# Epoch 33/35
# 4/4 [==============================] - 7s 2s/step - loss: 0.4651 - mean_absolute_error: 0.2713 - acc: 0.8242 - loss_no_weight_decay: 0.4651 - val_loss: 0.5448 - val_mean_absolute_error: 0.3005 - val_acc: 0.7826 - val_loss_no_weight_decay: 0.5448
#
# Epoch 00033: val_acc did not improve from 0.78261
# Confusion matrix:
#  []
# Epoch 34/35
# 4/4 [==============================] - 6s 2s/step - loss: 0.4467 - mean_absolute_error: 0.2643 - acc: 0.8355 - loss_no_weight_decay: 0.4467 - val_loss: 0.5446 - val_mean_absolute_error: 0.3009 - val_acc: 0.7826 - val_loss_no_weight_decay: 0.5446
#
# Epoch 00034: val_acc did not improve from 0.78261
# Confusion matrix:
#  []
# Epoch 35/35
# 4/4 [==============================] - 7s 2s/step - loss: 0.4151 - mean_absolute_error: 0.2529 - acc: 0.8530 - loss_no_weight_decay: 0.4151 - val_loss: 0.5428 - val_mean_absolute_error: 0.3017 - val_acc: 0.7826 - val_loss_no_weight_decay: 0.5428
#
# Epoch 00035: val_acc did not improve from 0.78261
# Confusion matrix:
#  []
# 33/33 [==============================] - 0s 13ms/step
# 33/33 [==============================] - 0s 8ms/step
# Test loss: 0.7778457127737276
# Test accuracy: 0.4031488805106192
# Confusion Matrix
# [[ 0 12]
#  [ 0 21]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        12
#            1       0.64      1.00      0.78        21
#
#     accuracy                           0.64        33
#    macro avg       0.32      0.50      0.39        33
# weighted avg       0.40      0.64      0.49        33
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
import numpy as np 
import matplotlib.pyplot as plt
import os
import wandb
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_mean_absolute_error', 'val_acc', 'val_loss_no_weight_decay', 'loss', 'mean_absolute_error', 'acc', 'loss_no_weight_decay', 'lr'])

# %%
from Kappa_Skl import kappa
def kappa2(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    if len(y_true.shape) > 1 and y_true.shape[1] > 1:
        y_true = y_true.dot(range(y_true.shape[1]))
    if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
        y_pred = y_pred.dot(range(y_pred.shape[1]))
    try:
        return kappa(y_true, y_pred, weights='quadratic')
    except IndexError:
        return np.nan
    
print('Quadratic_wieghted_kappa')
print(kappa2(y_true, y_pred))
# Out:
# Quadratic_wieghted_kappa
# 0.0
