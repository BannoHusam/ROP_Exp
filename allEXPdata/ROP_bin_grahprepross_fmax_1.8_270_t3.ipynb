# %%
import keras
from keras.models import Sequential, Input, Model
from keras.losses import mean_squared_error
from keras.layers import  *
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, InputLayer
from keras.regularizers import L1L2, l2, l1
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from custom_pooling import RMSPooling2D
from keras.optimizers import SGD, Adam
from keras.layers import LeakyReLU
#from data import BALANCE_WEIGHTS
from keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
#import os
from datetime import datetime as dt
from custom_loss import WeightedCategoricalCrossEntropy
from VCM import VCM
import keras.backend as K
from Fractional_MAXPOOL import FractionalPooling2D
from QWK import QWK
import tensorflow as tf
from Fractional_MAXPOOL import FractionalPooling2D

import numpy as np 
import matplotlib.pyplot as plt
import os
import wandb
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
def get_experiment_id():
    time_str = dt.now().strftime('%Y-%m-%d-%H-%M-%S')
    experiment_id = 'base_{}'.format(time_str)
    return experiment_id
p_ratio=[1.0, 1.44, 1.73, 1.0]

model = Sequential()


model.add(Conv2D(16, (5, 5), activation='tanh', input_shape=(270, 270, 3)))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(16, (3, 3), activation='tanh'))
model.add(Conv2D(16, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

#model.add(LeakyReLU(alpha=0.01))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))


model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))


model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))
model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))


#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))

model.add(Conv2D(64, (3, 3), activation='tanh'))

model.add(FractionalPooling2D(pool_ratio=(1, 1.7, 1.7, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))

#model.add(MaxPooling2D(pool_size=1))


model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))




model.add(Flatten())


#chnaged from 10 to 5 because an error 
model.add(Dense(2, activation='softmax'))

sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.count_params()
#adam = Adam(lr=0.0005, decay=1e-6)
#rmsprop
#Mloss = WeightedCategoricalCrossEntropy({0: 0.4125861396437394, 1: 1.4918664786083686, 2: 0.690426457789382, 3: 3.9541433021806855, 4: 4.885604311008468})
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['acc','mae'])
model.summary()
loss_no_weight_decay = model.total_loss - sum(model.losses)
model.metrics_tensors.append(loss_no_weight_decay)
model.metrics_names.append('loss_no_weight_decay')
#############################################################################################
#############################################################################################
#############################################################################################
#############################################################################################
#Preparing Data Augmentation Configuration 
train_datagen = ImageDataGenerator(
        rescale=1./255,
#        featurewise_center=True,
 #       samplewise_center=True,
        shear_range=0,
        zoom_range=0.0,#[1 / 1.15, 1.15],
        horizontal_flip=False,#True,
        rotation_range=0)#90,
#        validation_split=0.2)
"""
For the test set only rescale should be made 
"""
test_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/grahprepross/bin_bal/train",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="training")
#    save_to_dir="D:/Separating Images into subfolders/train_augmented")


#print(train_generator.class_indices)

valid_generator = valid_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/grahprepross/bin_bal/vald",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="validation")
#    save_to_dir="D:/Separating Images into subfolders/val_augmented"


test_generator = test_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/grahprepross/bin_bal/test",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=1,
    class_mode="categorical",
    shuffle=False,
    seed=42)
#    save_to_dir="D:/Separating Images into subfolders/test_augmented")


# Fitting/Training the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
experiment_id = get_experiment_id()
callbacks = [
    EarlyStopping(monitor='val_acc', patience=10, min_delta=0.001, verbose=1),
    ModelCheckpoint(experiment_id + "-val_acc_checkpoint.hdf5", monitor='val_acc', verbose=1, save_best_only=True, mode='max'),
    ReduceLROnPlateau(monitor='val_acc', factor=0.5, patience=7, verbose=1, mode='auto', min_delta=0.001, cooldown=0, min_lr=1e-7),
    VCM(valid_generator,STEP_SIZE_VALID)
    
]

class_weight_list = class_weight.compute_class_weight('balanced', np.unique(train_generator.classes), train_generator.classes)
class_weights = dict(zip(np.unique(train_generator.classes), class_weight_list))

history=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    #class_weight=class_weights,
                    callbacks=callbacks,
                    epochs=35  
)


# Evaluating the model 
#predicting output
#reseting the test generator before calling predict_generator, in order not to get weird output
test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 266, 266, 16)      1216
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 262, 262, 16)      6416
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 260, 260, 16)      2320
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 258, 258, 16)      2320
# _________________________________________________________________
# fractional_pooling2d_1 (Frac (None, 143, 143, 16)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 139, 139, 16)      6416
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 135, 135, 16)      6416
# _________________________________________________________________
# fractional_pooling2d_2 (Frac (None, 75, 75, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 71, 71, 16)        6416
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 67, 67, 16)        6416
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 65, 65, 32)        4640
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 63, 63, 32)        9248
# _________________________________________________________________
# fractional_pooling2d_3 (Frac (None, 35, 35, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 33, 33, 64)        18496
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 31, 31, 64)        36928
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 29, 29, 64)        36928
# _________________________________________________________________
# fractional_pooling2d_4 (Frac (None, 17, 17, 64)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 15, 15, 64)        36928
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 13, 13, 64)        36928
# _________________________________________________________________
# fractional_pooling2d_5 (Frac (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3136)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 6274
# =================================================================
# Total params: 224,306
# Trainable params: 224,306
# Non-trainable params: 0
# _________________________________________________________________
# Found 462 images belonging to 2 classes.
# Found 154 images belonging to 2 classes.
# Found 66 images belonging to 2 classes.
# Epoch 1/35
# 7/7 [==============================] - 18s 3s/step - loss: 0.6939 - acc: 0.4885 - mean_absolute_error: 0.4996 - loss_no_weight_decay: 0.6939 - val_loss: 0.6902 - val_acc: 0.5391 - val_mean_absolute_error: 0.4985 - val_loss_no_weight_decay: 0.6902
#
# Epoch 00001: val_acc improved from -inf to 0.53906, saving model to base_2020-05-12-21-46-42-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[11 51]
#  [ 0 66]]
# Epoch 2/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.6929 - acc: 0.5066 - mean_absolute_error: 0.4995 - loss_no_weight_decay: 0.6929 - val_loss: 0.6879 - val_acc: 0.5000 - val_mean_absolute_error: 0.4972 - val_loss_no_weight_decay: 0.6879
#
# Epoch 00002: val_acc did not improve from 0.53906
# Confusion matrix:
#  [[39  0]
#  [51  0]]
# Epoch 3/35
# 7/7 [==============================] - 11s 2s/step - loss: 0.6955 - acc: 0.4972 - mean_absolute_error: 0.4991 - loss_no_weight_decay: 0.6955 - val_loss: 0.7142 - val_acc: 0.4778 - val_mean_absolute_error: 0.5009 - val_loss_no_weight_decay: 0.7142
#
# Epoch 00003: val_acc did not improve from 0.53906
# Confusion matrix:
#  [[36  0]
#  [54  0]]
# Epoch 4/35
# 7/7 [==============================] - 13s 2s/step - loss: 0.6971 - acc: 0.5179 - mean_absolute_error: 0.4996 - loss_no_weight_decay: 0.6971 - val_loss: 0.6854 - val_acc: 0.5000 - val_mean_absolute_error: 0.4952 - val_loss_no_weight_decay: 0.6854
#
# Epoch 00004: val_acc did not improve from 0.53906
# Confusion matrix:
#  [[ 0 67]
#  [ 0 61]]
# Epoch 5/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.6873 - acc: 0.5253 - mean_absolute_error: 0.4952 - loss_no_weight_decay: 0.6873 - val_loss: 0.6808 - val_acc: 0.6333 - val_mean_absolute_error: 0.4935 - val_loss_no_weight_decay: 0.6808
#
# Epoch 00005: val_acc improved from 0.53906 to 0.63333, saving model to base_2020-05-12-21-46-42-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[17 31]
#  [ 0 42]]
# Epoch 6/35
# 7/7 [==============================] - 11s 2s/step - loss: 0.6809 - acc: 0.5841 - mean_absolute_error: 0.4933 - loss_no_weight_decay: 0.6809 - val_loss: 0.6723 - val_acc: 0.5333 - val_mean_absolute_error: 0.4884 - val_loss_no_weight_decay: 0.6723
#
# Epoch 00006: val_acc did not improve from 0.63333
# Confusion matrix:
#  [[45  0]
#  [45  0]]
# Epoch 7/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.6794 - acc: 0.6153 - mean_absolute_error: 0.4923 - loss_no_weight_decay: 0.6794 - val_loss: 0.6706 - val_acc: 0.6641 - val_mean_absolute_error: 0.4880 - val_loss_no_weight_decay: 0.6706
#
# Epoch 00007: val_acc improved from 0.63333 to 0.66406, saving model to base_2020-05-12-21-46-42-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[26 36]
#  [ 2 64]]
# Epoch 8/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.6677 - acc: 0.6615 - mean_absolute_error: 0.4861 - loss_no_weight_decay: 0.6677 - val_loss: 0.6525 - val_acc: 0.6111 - val_mean_absolute_error: 0.4775 - val_loss_no_weight_decay: 0.6525
#
# Epoch 00008: val_acc did not improve from 0.66406
# Confusion matrix:
#  [[42  1]
#  [34 13]]
# Epoch 9/35
# 7/7 [==============================] - 11s 2s/step - loss: 0.6681 - acc: 0.6430 - mean_absolute_error: 0.4855 - loss_no_weight_decay: 0.6681 - val_loss: 0.6657 - val_acc: 0.4889 - val_mean_absolute_error: 0.4823 - val_loss_no_weight_decay: 0.6657
#
# Epoch 00009: val_acc did not improve from 0.66406
# Confusion matrix:
#  [[38  1]
#  [47  4]]
# Epoch 10/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.6531 - acc: 0.6202 - mean_absolute_error: 0.4763 - loss_no_weight_decay: 0.6531 - val_loss: 0.6328 - val_acc: 0.5781 - val_mean_absolute_error: 0.4622 - val_loss_no_weight_decay: 0.6328
#
# Epoch 00010: val_acc did not improve from 0.66406
# Confusion matrix:
#  [[61  3]
#  [49 15]]
# Epoch 11/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.6412 - acc: 0.6430 - mean_absolute_error: 0.4648 - loss_no_weight_decay: 0.6412 - val_loss: 0.6460 - val_acc: 0.6222 - val_mean_absolute_error: 0.4666 - val_loss_no_weight_decay: 0.6460
#
# Epoch 00011: val_acc did not improve from 0.66406
# Confusion matrix:
#  [[50  0]
#  [20 20]]
# Epoch 12/35
# 7/7 [==============================] - 11s 2s/step - loss: 0.5876 - acc: 0.7299 - mean_absolute_error: 0.4321 - loss_no_weight_decay: 0.5876 - val_loss: 0.5598 - val_acc: 0.7667 - val_mean_absolute_error: 0.4187 - val_loss_no_weight_decay: 0.5598
#
# Epoch 00012: val_acc improved from 0.66406 to 0.76667, saving model to base_2020-05-12-21-46-42-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[32  8]
#  [ 8 42]]
# Epoch 13/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.5545 - acc: 0.7276 - mean_absolute_error: 0.4078 - loss_no_weight_decay: 0.5545 - val_loss: 0.6290 - val_acc: 0.6562 - val_mean_absolute_error: 0.4196 - val_loss_no_weight_decay: 0.6290
#
# Epoch 00013: val_acc did not improve from 0.76667
# Confusion matrix:
#  [[15 47]
#  [ 1 65]]
# Epoch 14/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.5444 - acc: 0.7391 - mean_absolute_error: 0.3956 - loss_no_weight_decay: 0.5444 - val_loss: 0.5723 - val_acc: 0.6778 - val_mean_absolute_error: 0.3821 - val_loss_no_weight_decay: 0.5723
#
# Epoch 00014: val_acc did not improve from 0.76667
# Confusion matrix:
#  [[23 21]
#  [ 2 44]]
# Epoch 15/35
# 7/7 [==============================] - 11s 2s/step - loss: 0.5569 - acc: 0.7250 - mean_absolute_error: 0.3798 - loss_no_weight_decay: 0.5569 - val_loss: 0.4868 - val_acc: 0.7667 - val_mean_absolute_error: 0.3521 - val_loss_no_weight_decay: 0.4868
#
# Epoch 00015: val_acc improved from 0.76667 to 0.76667, saving model to base_2020-05-12-21-46-42-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[42  8]
#  [23 17]]
# Epoch 16/35
# 7/7 [==============================] - 13s 2s/step - loss: 0.5089 - acc: 0.7366 - mean_absolute_error: 0.3632 - loss_no_weight_decay: 0.5089 - val_loss: 0.5432 - val_acc: 0.7422 - val_mean_absolute_error: 0.3745 - val_loss_no_weight_decay: 0.5432
#
# Epoch 00016: val_acc did not improve from 0.76667
# Confusion matrix:
#  [[45 13]
#  [20 50]]
# Epoch 17/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.5196 - acc: 0.7046 - mean_absolute_error: 0.3449 - loss_no_weight_decay: 0.5196 - val_loss: 0.6283 - val_acc: 0.6667 - val_mean_absolute_error: 0.4543 - val_loss_no_weight_decay: 0.6283
#
# Epoch 00017: val_acc did not improve from 0.76667
# Confusion matrix:
#  [[14 31]
#  [ 0 45]]
# Epoch 18/35
# 7/7 [==============================] - 11s 2s/step - loss: 0.5436 - acc: 0.6815 - mean_absolute_error: 0.3894 - loss_no_weight_decay: 0.5436 - val_loss: 0.5040 - val_acc: 0.7444 - val_mean_absolute_error: 0.3690 - val_loss_no_weight_decay: 0.5040
#
# Epoch 00018: val_acc did not improve from 0.76667
# Confusion matrix:
#  [[43  5]
#  [22 20]]
# Epoch 19/35
# 7/7 [==============================] - 13s 2s/step - loss: 0.4686 - acc: 0.7679 - mean_absolute_error: 0.3337 - loss_no_weight_decay: 0.4686 - val_loss: 0.4374 - val_acc: 0.8125 - val_mean_absolute_error: 0.3181 - val_loss_no_weight_decay: 0.4374
#
# Epoch 00019: val_acc improved from 0.76667 to 0.81250, saving model to base_2020-05-12-21-46-42-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[55 11]
#  [17 45]]
# Epoch 20/35
# 7/7 [==============================] - 10s 1s/step - loss: 0.4799 - acc: 0.7500 - mean_absolute_error: 0.3316 - loss_no_weight_decay: 0.4799 - val_loss: 0.5006 - val_acc: 0.7111 - val_mean_absolute_error: 0.3297 - val_loss_no_weight_decay: 0.5006
#
# Epoch 00020: val_acc did not improve from 0.81250
# Confusion matrix:
#  [[35  5]
#  [ 9 41]]
# Epoch 21/35
# 7/7 [==============================] - 11s 2s/step - loss: 0.4402 - acc: 0.7932 - mean_absolute_error: 0.3140 - loss_no_weight_decay: 0.4402 - val_loss: 0.3932 - val_acc: 0.8667 - val_mean_absolute_error: 0.2954 - val_loss_no_weight_decay: 0.3932
#
# Epoch 00021: val_acc improved from 0.81250 to 0.86667, saving model to base_2020-05-12-21-46-42-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[38  5]
#  [17 30]]
# Epoch 22/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.4153 - acc: 0.7977 - mean_absolute_error: 0.2963 - loss_no_weight_decay: 0.4153 - val_loss: 0.3417 - val_acc: 0.9219 - val_mean_absolute_error: 0.2679 - val_loss_no_weight_decay: 0.3417
#
# Epoch 00022: val_acc improved from 0.86667 to 0.92188, saving model to base_2020-05-12-21-46-42-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[60  6]
#  [ 7 55]]
# Epoch 23/35
# 7/7 [==============================] - 13s 2s/step - loss: 0.3854 - acc: 0.8482 - mean_absolute_error: 0.2765 - loss_no_weight_decay: 0.3854 - val_loss: 0.4018 - val_acc: 0.8556 - val_mean_absolute_error: 0.2762 - val_loss_no_weight_decay: 0.4018
#
# Epoch 00023: val_acc did not improve from 0.92188
# Confusion matrix:
#  [[39  5]
#  [ 3 43]]
# Epoch 24/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.3624 - acc: 0.8547 - mean_absolute_error: 0.2519 - loss_no_weight_decay: 0.3624 - val_loss: 0.2807 - val_acc: 0.8889 - val_mean_absolute_error: 0.2004 - val_loss_no_weight_decay: 0.2807
#
# Epoch 00024: val_acc did not improve from 0.92188
# Confusion matrix:
#  [[37 10]
#  [ 1 42]]
# Epoch 25/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.3379 - acc: 0.8409 - mean_absolute_error: 0.2351 - loss_no_weight_decay: 0.3379 - val_loss: 0.2595 - val_acc: 0.9219 - val_mean_absolute_error: 0.1978 - val_loss_no_weight_decay: 0.2595
#
# Epoch 00025: val_acc did not improve from 0.92188
# Confusion matrix:
#  [[53 11]
#  [ 2 62]]
# Epoch 26/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.3055 - acc: 0.8772 - mean_absolute_error: 0.2175 - loss_no_weight_decay: 0.3055 - val_loss: 0.2636 - val_acc: 0.8889 - val_mean_absolute_error: 0.1915 - val_loss_no_weight_decay: 0.2636
#
# Epoch 00026: val_acc did not improve from 0.92188
# Confusion matrix:
#  [[39  5]
#  [ 2 44]]
# Epoch 27/35
# 7/7 [==============================] - 13s 2s/step - loss: 0.3422 - acc: 0.8504 - mean_absolute_error: 0.2216 - loss_no_weight_decay: 0.3422 - val_loss: 0.2994 - val_acc: 0.9111 - val_mean_absolute_error: 0.2022 - val_loss_no_weight_decay: 0.2994
#
# Epoch 00027: val_acc did not improve from 0.92188
# Confusion matrix:
#  [[45  1]
#  [ 9 35]]
# Epoch 28/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.3008 - acc: 0.8723 - mean_absolute_error: 0.2035 - loss_no_weight_decay: 0.3008 - val_loss: 0.1975 - val_acc: 0.9297 - val_mean_absolute_error: 0.1479 - val_loss_no_weight_decay: 0.1975
#
# Epoch 00028: val_acc improved from 0.92188 to 0.92969, saving model to base_2020-05-12-21-46-42-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[59  7]
#  [ 2 60]]
# Epoch 29/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.2833 - acc: 0.9138 - mean_absolute_error: 0.1967 - loss_no_weight_decay: 0.2833 - val_loss: 0.1951 - val_acc: 0.9333 - val_mean_absolute_error: 0.1501 - val_loss_no_weight_decay: 0.1951
#
# Epoch 00029: val_acc improved from 0.92969 to 0.93333, saving model to base_2020-05-12-21-46-42-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[50  1]
#  [ 4 35]]
# Epoch 30/35
# 7/7 [==============================] - 10s 1s/step - loss: 0.2138 - acc: 0.9399 - mean_absolute_error: 0.1543 - loss_no_weight_decay: 0.2138 - val_loss: 0.2030 - val_acc: 0.9222 - val_mean_absolute_error: 0.1623 - val_loss_no_weight_decay: 0.2030
#
# Epoch 00030: val_acc did not improve from 0.93333
# Confusion matrix:
#  [[40  5]
#  [ 1 44]]
# Epoch 31/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.2523 - acc: 0.9070 - mean_absolute_error: 0.1661 - loss_no_weight_decay: 0.2523 - val_loss: 0.1472 - val_acc: 0.9609 - val_mean_absolute_error: 0.1119 - val_loss_no_weight_decay: 0.1472
#
# Epoch 00031: val_acc improved from 0.93333 to 0.96094, saving model to base_2020-05-12-21-46-42-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[62  4]
#  [ 3 59]]
# Epoch 32/35
# 7/7 [==============================] - 13s 2s/step - loss: 0.2212 - acc: 0.9219 - mean_absolute_error: 0.1487 - loss_no_weight_decay: 0.2212 - val_loss: 0.1821 - val_acc: 0.9333 - val_mean_absolute_error: 0.1139 - val_loss_no_weight_decay: 0.1821
#
# Epoch 00032: val_acc did not improve from 0.96094
# Confusion matrix:
#  [[48  2]
#  [ 2 38]]
# Epoch 33/35
# 7/7 [==============================] - 11s 2s/step - loss: 0.2627 - acc: 0.8905 - mean_absolute_error: 0.1683 - loss_no_weight_decay: 0.2627 - val_loss: 0.2101 - val_acc: 0.9333 - val_mean_absolute_error: 0.1613 - val_loss_no_weight_decay: 0.2101
#
# Epoch 00033: val_acc did not improve from 0.96094
# Confusion matrix:
#  [[37  6]
#  [ 3 44]]
# Epoch 34/35
# 7/7 [==============================] - 13s 2s/step - loss: 0.2827 - acc: 0.9018 - mean_absolute_error: 0.1691 - loss_no_weight_decay: 0.2827 - val_loss: 0.1219 - val_acc: 0.9844 - val_mean_absolute_error: 0.1021 - val_loss_no_weight_decay: 0.1219
#
# Epoch 00034: val_acc improved from 0.96094 to 0.98438, saving model to base_2020-05-12-21-46-42-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[59  6]
#  [ 2 61]]
# Epoch 35/35
# 7/7 [==============================] - 11s 2s/step - loss: 0.1856 - acc: 0.9454 - mean_absolute_error: 0.1317 - loss_no_weight_decay: 0.1856 - val_loss: 0.1509 - val_acc: 0.9667 - val_mean_absolute_error: 0.1091 - val_loss_no_weight_decay: 0.1509
#
# Epoch 00035: val_acc did not improve from 0.98438
# Confusion matrix:
#  [[38  2]
#  [ 5 45]]
# 66/66 [==============================] - 1s 9ms/step
# 66/66 [==============================] - 1s 8ms/step
# Test loss: 0.19692367175593972
# Test accuracy: 0.9393939393939394
# Confusion Matrix
# [[31  2]
#  [ 3 30]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.91      0.94      0.93        33
#            1       0.94      0.91      0.92        33
#
#     accuracy                           0.92        66
#    macro avg       0.92      0.92      0.92        66
# weighted avg       0.92      0.92      0.92        66

# %%
from Kappa_Skl import kappa
def kappa2(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    if len(y_true.shape) > 1 and y_true.shape[1] > 1:
        y_true = y_true.dot(range(y_true.shape[1]))
    if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
        y_pred = y_pred.dot(range(y_pred.shape[1]))
    try:
        return kappa(y_true, y_pred, weights='quadratic')
    except IndexError:
        return np.nan
    
print('Quadratic_wieghted_kappa')
print(kappa2(y_true, y_pred))
# Out:
# Quadratic_wieghted_kappa
# 0.8484848484848485

# %%
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
