# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, InputLayer
from keras.regularizers import L1L2, l2, l1
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from custom_pooling import RMSPooling2D
from keras.optimizers import SGD, Adam
from keras.layers import LeakyReLU
#from data import BALANCE_WEIGHTS
from keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
#import os
from datetime import datetime as dt
from custom_loss import WeightedCategoricalCrossEntropy
from VCM import VCM
from QWK import QWK
import keras.backend as K
from Fractional_MAXPOOL import FractionalPooling2D
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
def get_experiment_id():
    time_str = dt.now().strftime('%Y-%m-%d-%H-%M-%S')
    experiment_id = 'base_{}'.format(time_str)
    return experiment_id
p_ratio=[1.0, 1.44, 1.73, 1.0]

model = Sequential()


model.add(Conv2D(16, (5, 5), activation='tanh', input_shape=(300, 300, 3)))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(16, (3, 3), activation='tanh'))
model.add(Conv2D(16, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

#model.add(LeakyReLU(alpha=0.01))


model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))


model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))          
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))


model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

#model.add(MaxPooling2D(pool_size=1))




model.add(MaxPooling2D(pool_size=2))

model.add(Flatten())


#chnaged from 10 to 5 because an error 
model.add(Dense(3, activation='softmax'))

sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.count_params()
#adam = Adam(lr=0.0005, decay=1e-6)
#rmsprop
#Mloss = WeightedCategoricalCrossEntropy({0: 0.4125861396437394, 1: 1.4918664786083686, 2: 0.690426457789382, 3: 3.9541433021806855, 4: 4.885604311008468})
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['acc','binary_accuracy','mae'])
model.summary()
loss_no_weight_decay = model.total_loss - sum(model.losses)
model.metrics_tensors.append(loss_no_weight_decay)
model.metrics_names.append('loss_no_weight_decay')
#############################################################################################
#############################################################################################
#############################################################################################
#############################################################################################
#Preparing Data Augmentation Configuration 
train_datagen = ImageDataGenerator(
        rescale=1./255,
#        featurewise_center=True,
 #       samplewise_center=True,
        shear_range=0,
        zoom_range=0.0,#[1 / 1.15, 1.15],
        horizontal_flip=False,#True,
        rotation_range=0)#90,
#        validation_split=0.2)
"""
For the test set only rescale should be made 
"""
test_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/three_class/train",
    target_size=(300, 300),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="training")
#    save_to_dir="D:/Separating Images into subfolders/train_augmented")


#print(train_generator.class_indices)

valid_generator = valid_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/three_class/vald",
    target_size=(300, 300),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="validation")
#    save_to_dir="D:/Separating Images into subfolders/val_augmented"


test_generator = test_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/three_class/test",
    target_size=(300, 300),
    color_mode="rgb",
    batch_size=1,
    class_mode="categorical",
    shuffle=False,
    seed=42)
#    save_to_dir="D:/Separating Images into subfolders/test_augmented")


# Fitting/Training the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
experiment_id = get_experiment_id()
callbacks = [
    QWK(valid_generator, STEP_SIZE_VALID),
    EarlyStopping(monitor='val_acc', patience=50, min_delta=0.001, verbose=1),
    ModelCheckpoint(experiment_id + "-val_kapa_checkpoint.hdf5", monitor='val_kappa', verbose=1, save_best_only=True, mode='max'),
    ReduceLROnPlateau(monitor='val_acc', factor=0.5, patience=7, verbose=1, mode='auto', min_delta=0.001, cooldown=0, min_lr=1e-7),
    VCM(valid_generator,STEP_SIZE_VALID)
    
]

class_weight_list = class_weight.compute_class_weight('balanced', np.unique(train_generator.classes), train_generator.classes)
class_weights = dict(zip(np.unique(train_generator.classes), class_weight_list))

history=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    class_weight=class_weights,
                    callbacks=callbacks,
                    epochs=50  
)


# Evaluating the model 
#predicting output
#reseting the test generator before calling predict_generator, in order not to get weird output
test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1', '2']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 296, 296, 16)      1216
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 292, 292, 16)      6416
# _________________________________________________________________
# fractional_pooling2d_1 (Frac (None, 162, 162, 16)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 160, 160, 16)      2320
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 158, 158, 16)      2320
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 154, 154, 16)      6416
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 150, 150, 16)      6416
# _________________________________________________________________
# fractional_pooling2d_2 (Frac (None, 83, 83, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 79, 79, 16)        6416
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 75, 75, 16)        6416
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 73, 73, 32)        4640
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 71, 71, 32)        9248
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 69, 69, 32)        9248
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 67, 67, 32)        9248
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 65, 65, 32)        9248
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 63, 63, 32)        9248
# _________________________________________________________________
# fractional_pooling2d_3 (Frac (None, 35, 35, 32)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 33, 33, 32)        9248
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 31, 31, 32)        9248
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 29, 29, 64)        18496
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 27, 27, 64)        36928
# _________________________________________________________________
# fractional_pooling2d_4 (Frac (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 13, 13, 64)        36928
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 11, 11, 64)        36928
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 9, 9, 64)          36928
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 7, 7, 64)          36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 3, 3, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 576)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 1731
# =================================================================
# Total params: 312,179
# Trainable params: 312,179
# Non-trainable params: 0
# _________________________________________________________________
# Found 588 images belonging to 3 classes.
# Found 116 images belonging to 3 classes.
# Found 176 images belonging to 3 classes.
# Epoch 1/50
# 9/9 [==============================] - 27s 3s/step - loss: 1.0936 - acc: 0.4078 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4409 - loss_no_weight_decay: 1.0936 - val_loss: 1.1029 - val_acc: 0.2969 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4453 - val_loss_no_weight_decay: 1.1029
# — val_kappa: 0.0
#
# Epoch 00001: val_kappa improved from -inf to 0.00000, saving model to base_2020-05-09-14-04-16-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[26  0  0]
#  [ 5  0  0]
#  [21  0  0]]
# Epoch 2/50
# 9/9 [==============================] - 18s 2s/step - loss: 1.0722 - acc: 0.1733 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4467 - loss_no_weight_decay: 1.0722 - val_loss: 1.0995 - val_acc: 0.3269 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4446 - val_loss_no_weight_decay: 1.0995
# — val_kappa: 0.0
#
# Epoch 00002: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[27  0  0]
#  [ 7  0  0]
#  [18  0  0]]
# Epoch 3/50
# 9/9 [==============================] - 18s 2s/step - loss: 1.1285 - acc: 0.3216 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4492 - loss_no_weight_decay: 1.1285 - val_loss: 1.1189 - val_acc: 0.3906 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4478 - val_loss_no_weight_decay: 1.1189
# — val_kappa: 0.0
#
# Epoch 00003: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[22  0  0]
#  [ 6  0  0]
#  [24  0  0]]
# Epoch 4/50
# 9/9 [==============================] - 19s 2s/step - loss: 1.0919 - acc: 0.2500 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4472 - loss_no_weight_decay: 1.0919 - val_loss: 1.0955 - val_acc: 0.3269 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4436 - val_loss_no_weight_decay: 1.0955
# — val_kappa: 0.0
#
# Epoch 00004: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[23  0  0]
#  [ 6  0  0]
#  [23  0  0]]
# Epoch 5/50
# 9/9 [==============================] - 18s 2s/step - loss: 1.0643 - acc: 0.4849 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4418 - loss_no_weight_decay: 1.0643 - val_loss: 1.0717 - val_acc: 0.5938 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4382 - val_loss_no_weight_decay: 1.0717
# — val_kappa: 0.0
#
# Epoch 00005: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[28  0  0]
#  [ 5  0  0]
#  [19  0  0]]
# Epoch 6/50
# 9/9 [==============================] - 17s 2s/step - loss: 1.1172 - acc: 0.4557 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4402 - loss_no_weight_decay: 1.1172 - val_loss: 1.0777 - val_acc: 0.5577 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4390 - val_loss_no_weight_decay: 1.0777
# — val_kappa: 0.0
#
# Epoch 00006: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[29  0  0]
#  [ 5  0  0]
#  [18  0  0]]
# Epoch 7/50
# 9/9 [==============================] - 16s 2s/step - loss: 1.0994 - acc: 0.4563 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4420 - loss_no_weight_decay: 1.0994 - val_loss: 1.0793 - val_acc: 0.3906 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4392 - val_loss_no_weight_decay: 1.0793
# — val_kappa: 0.0
#
# Epoch 00007: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[29  0  0]
#  [ 4  0  0]
#  [19  0  0]]
# Epoch 8/50
# 9/9 [==============================] - 19s 2s/step - loss: 1.0705 - acc: 0.3715 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4401 - loss_no_weight_decay: 1.0705 - val_loss: 1.0743 - val_acc: 0.3654 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4369 - val_loss_no_weight_decay: 1.0743
# — val_kappa: 0.0
#
# Epoch 00008: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[28  0  0]
#  [ 7  0  0]
#  [17  0  0]]
# Epoch 9/50
# 9/9 [==============================] - 17s 2s/step - loss: 1.0742 - acc: 0.3690 - binary_accuracy: 0.6708 - mean_absolute_error: 0.4388 - loss_no_weight_decay: 1.0742 - val_loss: 0.9531 - val_acc: 0.6562 - val_binary_accuracy: 0.7240 - val_mean_absolute_error: 0.4037 - val_loss_no_weight_decay: 0.9531
# — val_kappa: 0.11940298507462677
#
# Epoch 00009: val_kappa improved from 0.00000 to 0.11940, saving model to base_2020-05-09-14-04-16-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[26  0  0]
#  [ 6  0  0]
#  [20  0  0]]
# Epoch 10/50
# 9/9 [==============================] - 17s 2s/step - loss: 1.0709 - acc: 0.4927 - binary_accuracy: 0.6865 - mean_absolute_error: 0.4258 - loss_no_weight_decay: 1.0709 - val_loss: 0.9174 - val_acc: 0.5577 - val_binary_accuracy: 0.7692 - val_mean_absolute_error: 0.3873 - val_loss_no_weight_decay: 0.9174
# — val_kappa: 0.23584905660377364
#
# Epoch 00010: val_kappa improved from 0.11940 to 0.23585, saving model to base_2020-05-09-14-04-16-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[29  0  0]
#  [ 4  0  0]
#  [19  0  0]]
# Epoch 11/50
# 9/9 [==============================] - 17s 2s/step - loss: 1.0196 - acc: 0.4779 - binary_accuracy: 0.7068 - mean_absolute_error: 0.4154 - loss_no_weight_decay: 1.0196 - val_loss: 0.9258 - val_acc: 0.5469 - val_binary_accuracy: 0.7448 - val_mean_absolute_error: 0.3892 - val_loss_no_weight_decay: 0.9258
# — val_kappa: 0.2318840579710143
#
# Epoch 00011: val_kappa did not improve from 0.23585
# Confusion matrix:
#  [[26  0  0]
#  [ 4  0  0]
#  [22  0  0]]
# Epoch 12/50
# 9/9 [==============================] - 19s 2s/step - loss: 1.0438 - acc: 0.4375 - binary_accuracy: 0.7043 - mean_absolute_error: 0.4135 - loss_no_weight_decay: 1.0438 - val_loss: 1.0963 - val_acc: 0.3846 - val_binary_accuracy: 0.6859 - val_mean_absolute_error: 0.4280 - val_loss_no_weight_decay: 1.0963
# — val_kappa: 0.14084507042253513
#
# Epoch 00012: val_kappa did not improve from 0.23585
# Confusion matrix:
#  [[29  2  0]
#  [ 2  2  0]
#  [15  2  0]]
# Epoch 13/50
# 9/9 [==============================] - 18s 2s/step - loss: 1.0314 - acc: 0.4511 - binary_accuracy: 0.6755 - mean_absolute_error: 0.4096 - loss_no_weight_decay: 1.0314 - val_loss: 1.1155 - val_acc: 0.3906 - val_binary_accuracy: 0.6771 - val_mean_absolute_error: 0.4328 - val_loss_no_weight_decay: 1.1155
# — val_kappa: 0.08163265306122436
#
# Epoch 00013: val_kappa did not improve from 0.23585
# Confusion matrix:
#  [[27  1  0]
#  [ 5  0  0]
#  [18  1  0]]
# Epoch 14/50
# 9/9 [==============================] - 17s 2s/step - loss: 1.0487 - acc: 0.5156 - binary_accuracy: 0.6738 - mean_absolute_error: 0.4258 - loss_no_weight_decay: 1.0487 - val_loss: 0.9331 - val_acc: 0.6923 - val_binary_accuracy: 0.7179 - val_mean_absolute_error: 0.3977 - val_loss_no_weight_decay: 0.9331
# — val_kappa: 0.14925373134328357
#
# Epoch 00014: val_kappa did not improve from 0.23585
# Confusion matrix:
#  [[27  0  0]
#  [ 6  0  0]
#  [19  0  0]]
# Epoch 15/50
# 9/9 [==============================] - 18s 2s/step - loss: 0.9748 - acc: 0.5358 - binary_accuracy: 0.7233 - mean_absolute_error: 0.3982 - loss_no_weight_decay: 0.9748 - val_loss: 0.9596 - val_acc: 0.6250 - val_binary_accuracy: 0.7448 - val_mean_absolute_error: 0.3913 - val_loss_no_weight_decay: 0.9596
# — val_kappa: 0.20289855072463758
#
# Epoch 00015: val_kappa did not improve from 0.23585
# Confusion matrix:
#  [[31  0  0]
#  [ 5  0  0]
#  [16  0  0]]
# Epoch 16/50
# 9/9 [==============================] - 19s 2s/step - loss: 0.9318 - acc: 0.6100 - binary_accuracy: 0.7341 - mean_absolute_error: 0.3837 - loss_no_weight_decay: 0.9318 - val_loss: 0.8839 - val_acc: 0.5962 - val_binary_accuracy: 0.7372 - val_mean_absolute_error: 0.3775 - val_loss_no_weight_decay: 0.8839
# — val_kappa: 0.2571428571428571
#
# Epoch 00016: val_kappa improved from 0.23585 to 0.25714, saving model to base_2020-05-09-14-04-16-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[23  0  1]
#  [ 9  0  0]
#  [18  1  0]]
# Epoch 17/50
# 9/9 [==============================] - 19s 2s/step - loss: 0.9599 - acc: 0.5799 - binary_accuracy: 0.7361 - mean_absolute_error: 0.3843 - loss_no_weight_decay: 0.9599 - val_loss: 0.9517 - val_acc: 0.5625 - val_binary_accuracy: 0.7240 - val_mean_absolute_error: 0.3932 - val_loss_no_weight_decay: 0.9517
# — val_kappa: 0.344186046511628
#
# Epoch 00017: val_kappa improved from 0.25714 to 0.34419, saving model to base_2020-05-09-14-04-16-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[23  1  0]
#  [ 4  1  1]
#  [15  5  2]]
# Epoch 18/50
# 9/9 [==============================] - 19s 2s/step - loss: 0.9638 - acc: 0.5611 - binary_accuracy: 0.7429 - mean_absolute_error: 0.3851 - loss_no_weight_decay: 0.9638 - val_loss: 0.8717 - val_acc: 0.5769 - val_binary_accuracy: 0.7436 - val_mean_absolute_error: 0.3700 - val_loss_no_weight_decay: 0.8717
# — val_kappa: 0.2909090909090909
#
# Epoch 00018: val_kappa did not improve from 0.34419
# Confusion matrix:
#  [[31  1  0]
#  [ 2  1  0]
#  [17  0  0]]
# Epoch 19/50
# 9/9 [==============================] - 19s 2s/step - loss: 0.8604 - acc: 0.5859 - binary_accuracy: 0.7459 - mean_absolute_error: 0.3660 - loss_no_weight_decay: 0.8604 - val_loss: 0.8137 - val_acc: 0.5781 - val_binary_accuracy: 0.7604 - val_mean_absolute_error: 0.3454 - val_loss_no_weight_decay: 0.8137
# — val_kappa: 0.4810126582278481
#
# Epoch 00019: val_kappa improved from 0.34419 to 0.48101, saving model to base_2020-05-09-14-04-16-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[23  1  0]
#  [ 4  2  0]
#  [18  3  1]]
# Epoch 20/50
# 9/9 [==============================] - 18s 2s/step - loss: 0.8993 - acc: 0.5336 - binary_accuracy: 0.7206 - mean_absolute_error: 0.3728 - loss_no_weight_decay: 0.8993 - val_loss: 0.8866 - val_acc: 0.5962 - val_binary_accuracy: 0.7564 - val_mean_absolute_error: 0.3574 - val_loss_no_weight_decay: 0.8866
# — val_kappa: 0.24347826086956526
#
# Epoch 00020: val_kappa did not improve from 0.48101
# Confusion matrix:
#  [[24  0  0]
#  [ 2  3  1]
#  [15  4  3]]
# Epoch 21/50
# 9/9 [==============================] - 18s 2s/step - loss: 0.8283 - acc: 0.6242 - binary_accuracy: 0.7477 - mean_absolute_error: 0.3471 - loss_no_weight_decay: 0.8283 - val_loss: 0.8267 - val_acc: 0.6250 - val_binary_accuracy: 0.7708 - val_mean_absolute_error: 0.3493 - val_loss_no_weight_decay: 0.8267
# — val_kappa: 0.430379746835443
#
# Epoch 00021: val_kappa did not improve from 0.48101
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Confusion matrix:
#  [[18  0  3]
#  [ 4  4  1]
#  [12  5  5]]
# Epoch 22/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.8424 - acc: 0.6192 - binary_accuracy: 0.7472 - mean_absolute_error: 0.3453 - loss_no_weight_decay: 0.8424 - val_loss: 0.7557 - val_acc: 0.6923 - val_binary_accuracy: 0.7692 - val_mean_absolute_error: 0.3317 - val_loss_no_weight_decay: 0.7557
# — val_kappa: 0.36842105263157887
#
# Epoch 00022: val_kappa did not improve from 0.48101
# Confusion matrix:
#  [[26  1  0]
#  [ 4  4  1]
#  [11  1  4]]
# Epoch 23/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.7742 - acc: 0.6593 - binary_accuracy: 0.7693 - mean_absolute_error: 0.3201 - loss_no_weight_decay: 0.7742 - val_loss: 0.8569 - val_acc: 0.6406 - val_binary_accuracy: 0.7552 - val_mean_absolute_error: 0.3495 - val_loss_no_weight_decay: 0.8569
# — val_kappa: 0.4206008583690988
#
# Epoch 00023: val_kappa did not improve from 0.48101
# Confusion matrix:
#  [[23  1  2]
#  [ 1  3  2]
#  [12  2  6]]
# Epoch 24/50
# 9/9 [==============================] - 19s 2s/step - loss: 0.7802 - acc: 0.6840 - binary_accuracy: 0.7836 - mean_absolute_error: 0.3282 - loss_no_weight_decay: 0.7802 - val_loss: 0.8087 - val_acc: 0.6923 - val_binary_accuracy: 0.8013 - val_mean_absolute_error: 0.3357 - val_loss_no_weight_decay: 0.8087
# — val_kappa: 0.48275862068965514
#
# Epoch 00024: val_kappa improved from 0.48101 to 0.48276, saving model to base_2020-05-09-14-04-16-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[19  2  2]
#  [ 2  4  1]
#  [14  3  5]]
# Epoch 25/50
# 9/9 [==============================] - 16s 2s/step - loss: 0.7594 - acc: 0.6552 - binary_accuracy: 0.7719 - mean_absolute_error: 0.3232 - loss_no_weight_decay: 0.7594 - val_loss: 0.8234 - val_acc: 0.6562 - val_binary_accuracy: 0.7656 - val_mean_absolute_error: 0.3380 - val_loss_no_weight_decay: 0.8234
# — val_kappa: 0.5643153526970954
#
# Epoch 00025: val_kappa improved from 0.48276 to 0.56432, saving model to base_2020-05-09-14-04-16-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[17  2  6]
#  [ 2  2  2]
#  [11  3  7]]
# Epoch 26/50
# 9/9 [==============================] - 19s 2s/step - loss: 0.7528 - acc: 0.6580 - binary_accuracy: 0.7830 - mean_absolute_error: 0.3152 - loss_no_weight_decay: 0.7528 - val_loss: 0.7746 - val_acc: 0.6154 - val_binary_accuracy: 0.7564 - val_mean_absolute_error: 0.3183 - val_loss_no_weight_decay: 0.7746
# — val_kappa: 0.3797468354430379
#
# Epoch 00026: val_kappa did not improve from 0.56432
# Confusion matrix:
#  [[25  1  0]
#  [ 3  3  0]
#  [14  2  4]]
# Epoch 27/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.7665 - acc: 0.6450 - binary_accuracy: 0.7763 - mean_absolute_error: 0.3198 - loss_no_weight_decay: 0.7665 - val_loss: 0.7954 - val_acc: 0.6875 - val_binary_accuracy: 0.7552 - val_mean_absolute_error: 0.3327 - val_loss_no_weight_decay: 0.7954
# — val_kappa: 0.42499999999999993
#
# Epoch 00027: val_kappa did not improve from 0.56432
# Confusion matrix:
#  [[27  0  0]
#  [ 0  4  3]
#  [15  1  2]]
# Epoch 28/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.7792 - acc: 0.6225 - binary_accuracy: 0.7570 - mean_absolute_error: 0.3192 - loss_no_weight_decay: 0.7792 - val_loss: 0.7937 - val_acc: 0.6154 - val_binary_accuracy: 0.7885 - val_mean_absolute_error: 0.3229 - val_loss_no_weight_decay: 0.7937
# — val_kappa: 0.3999999999999999
#
# Epoch 00028: val_kappa did not improve from 0.56432
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Confusion matrix:
#  [[21  1  3]
#  [ 1  4  3]
#  [ 5  2 12]]
# Epoch 29/50
# 9/9 [==============================] - 18s 2s/step - loss: 0.6847 - acc: 0.7125 - binary_accuracy: 0.8160 - mean_absolute_error: 0.2861 - loss_no_weight_decay: 0.6847 - val_loss: 0.7007 - val_acc: 0.6719 - val_binary_accuracy: 0.7969 - val_mean_absolute_error: 0.3056 - val_loss_no_weight_decay: 0.7007
# — val_kappa: 0.5469387755102041
#
# Epoch 00029: val_kappa did not improve from 0.56432
# Confusion matrix:
#  [[25  2  0]
#  [ 1  3  1]
#  [11  4  5]]
# Epoch 30/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.7242 - acc: 0.6643 - binary_accuracy: 0.7943 - mean_absolute_error: 0.2980 - loss_no_weight_decay: 0.7242 - val_loss: 0.7345 - val_acc: 0.7115 - val_binary_accuracy: 0.8013 - val_mean_absolute_error: 0.2909 - val_loss_no_weight_decay: 0.7345
# — val_kappa: 0.5249999999999999
#
# Epoch 00030: val_kappa did not improve from 0.56432
# Confusion matrix:
#  [[20  1  2]
#  [ 0  3  2]
#  [ 9  3 12]]
# Epoch 31/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.6877 - acc: 0.6709 - binary_accuracy: 0.8021 - mean_absolute_error: 0.2784 - loss_no_weight_decay: 0.6877 - val_loss: 0.8009 - val_acc: 0.6719 - val_binary_accuracy: 0.7812 - val_mean_absolute_error: 0.3224 - val_loss_no_weight_decay: 0.8009
# — val_kappa: 0.4297520661157025
#
# Epoch 00031: val_kappa did not improve from 0.56432
# Confusion matrix:
#  [[22  1  4]
#  [ 0  2  0]
#  [13  2  8]]
# Epoch 32/50
# 9/9 [==============================] - 19s 2s/step - loss: 0.7080 - acc: 0.6667 - binary_accuracy: 0.7899 - mean_absolute_error: 0.2985 - loss_no_weight_decay: 0.7080 - val_loss: 0.7133 - val_acc: 0.7115 - val_binary_accuracy: 0.8013 - val_mean_absolute_error: 0.3063 - val_loss_no_weight_decay: 0.7133
# — val_kappa: 0.4999999999999999
#
# Epoch 00032: val_kappa did not improve from 0.56432
# Confusion matrix:
#  [[22  2  0]
#  [ 1  5  1]
#  [11  4  6]]
# Epoch 33/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.6943 - acc: 0.6979 - binary_accuracy: 0.7984 - mean_absolute_error: 0.2849 - loss_no_weight_decay: 0.6943 - val_loss: 0.8794 - val_acc: 0.5938 - val_binary_accuracy: 0.7292 - val_mean_absolute_error: 0.3391 - val_loss_no_weight_decay: 0.8794
# — val_kappa: 0.3999999999999999
#
# Epoch 00033: val_kappa did not improve from 0.56432
# Confusion matrix:
#  [[23  1  3]
#  [ 1  4  2]
#  [ 6  2 10]]
# Epoch 34/50
# 9/9 [==============================] - 19s 2s/step - loss: 0.7015 - acc: 0.6649 - binary_accuracy: 0.7940 - mean_absolute_error: 0.2877 - loss_no_weight_decay: 0.7015 - val_loss: 0.7703 - val_acc: 0.6538 - val_binary_accuracy: 0.7500 - val_mean_absolute_error: 0.3098 - val_loss_no_weight_decay: 0.7703
# — val_kappa: 0.3999999999999999
#
# Epoch 00034: val_kappa did not improve from 0.56432
# Confusion matrix:
#  [[19  1  3]
#  [ 1  4  1]
#  [ 8  5 10]]
# Epoch 35/50
# 9/9 [==============================] - 16s 2s/step - loss: 0.6823 - acc: 0.7187 - binary_accuracy: 0.8050 - mean_absolute_error: 0.2767 - loss_no_weight_decay: 0.6823 - val_loss: 0.7923 - val_acc: 0.6875 - val_binary_accuracy: 0.7552 - val_mean_absolute_error: 0.3269 - val_loss_no_weight_decay: 0.7923
# — val_kappa: 0.475
#
# Epoch 00035: val_kappa did not improve from 0.56432
# Confusion matrix:
#  [[24  3  4]
#  [ 0  3  0]
#  [ 9  5  4]]
# Epoch 36/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.6806 - acc: 0.6779 - binary_accuracy: 0.7980 - mean_absolute_error: 0.2868 - loss_no_weight_decay: 0.6806 - val_loss: 0.6869 - val_acc: 0.7308 - val_binary_accuracy: 0.7949 - val_mean_absolute_error: 0.2998 - val_loss_no_weight_decay: 0.6869
# — val_kappa: 0.5020242914979756
#
# Epoch 00036: val_kappa did not improve from 0.56432
# Confusion matrix:
#  [[23  3  3]
#  [ 2  4  2]
#  [ 5  1  9]]
# Epoch 37/50
# 9/9 [==============================] - 18s 2s/step - loss: 0.6880 - acc: 0.6869 - binary_accuracy: 0.7960 - mean_absolute_error: 0.2882 - loss_no_weight_decay: 0.6880 - val_loss: 0.7785 - val_acc: 0.6875 - val_binary_accuracy: 0.7812 - val_mean_absolute_error: 0.3146 - val_loss_no_weight_decay: 0.7785
# — val_kappa: 0.5185185185185186
#
# Epoch 00037: val_kappa did not improve from 0.56432
# Confusion matrix:
#  [[20  2  1]
#  [ 1  3  2]
#  [ 8  4 11]]
# Epoch 38/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.7000 - acc: 0.6876 - binary_accuracy: 0.8038 - mean_absolute_error: 0.2855 - loss_no_weight_decay: 0.7000 - val_loss: 0.7378 - val_acc: 0.6731 - val_binary_accuracy: 0.7885 - val_mean_absolute_error: 0.2906 - val_loss_no_weight_decay: 0.7378
# — val_kappa: 0.5327868852459015
#
# Epoch 00038: val_kappa did not improve from 0.56432
# Confusion matrix:
#  [[25  0  2]
#  [ 1  3  3]
#  [ 6  5  7]]
# Epoch 39/50
# 9/9 [==============================] - 19s 2s/step - loss: 0.6470 - acc: 0.7274 - binary_accuracy: 0.8154 - mean_absolute_error: 0.2721 - loss_no_weight_decay: 0.6470 - val_loss: 0.7477 - val_acc: 0.6562 - val_binary_accuracy: 0.7708 - val_mean_absolute_error: 0.3115 - val_loss_no_weight_decay: 0.7477
# — val_kappa: 0.4297520661157025
#
# Epoch 00039: val_kappa did not improve from 0.56432
# Confusion matrix:
#  [[28  0  1]
#  [ 0  6  1]
#  [ 3  4  9]]
# Epoch 40/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.6660 - acc: 0.6854 - binary_accuracy: 0.8065 - mean_absolute_error: 0.2788 - loss_no_weight_decay: 0.6660 - val_loss: 0.6896 - val_acc: 0.6538 - val_binary_accuracy: 0.8141 - val_mean_absolute_error: 0.2912 - val_loss_no_weight_decay: 0.6896
# — val_kappa: 0.4878048780487805
#
# Epoch 00040: val_kappa did not improve from 0.56432
# Confusion matrix:
#  [[28  1  2]
#  [ 1  3  1]
#  [ 5  3  8]]
# Epoch 41/50
# 9/9 [==============================] - 18s 2s/step - loss: 0.6478 - acc: 0.7079 - binary_accuracy: 0.8060 - mean_absolute_error: 0.2714 - loss_no_weight_decay: 0.6478 - val_loss: 0.5936 - val_acc: 0.7500 - val_binary_accuracy: 0.8438 - val_mean_absolute_error: 0.2695 - val_loss_no_weight_decay: 0.5936
# — val_kappa: 0.4545454545454546
#
# Epoch 00041: val_kappa did not improve from 0.56432
# Confusion matrix:
#  [[27  0  1]
#  [ 0  2  2]
#  [ 6  4 10]]
# Epoch 42/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.6631 - acc: 0.7154 - binary_accuracy: 0.8127 - mean_absolute_error: 0.2693 - loss_no_weight_decay: 0.6631 - val_loss: 0.7687 - val_acc: 0.6346 - val_binary_accuracy: 0.7756 - val_mean_absolute_error: 0.2864 - val_loss_no_weight_decay: 0.7687
# — val_kappa: 0.45344129554655865
#
# Epoch 00042: val_kappa did not improve from 0.56432
# Confusion matrix:
#  [[22  0  2]
#  [ 3  2  1]
#  [ 4  7 11]]
# Epoch 43/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.6883 - acc: 0.6698 - binary_accuracy: 0.7936 - mean_absolute_error: 0.2829 - loss_no_weight_decay: 0.6883 - val_loss: 0.7219 - val_acc: 0.7031 - val_binary_accuracy: 0.7969 - val_mean_absolute_error: 0.2887 - val_loss_no_weight_decay: 0.7219
# — val_kappa: 0.5606694560669456
#
# Epoch 00043: val_kappa did not improve from 0.56432
# Confusion matrix:
#  [[26  0  3]
#  [ 1  2  0]
#  [ 7  6  7]]
# Epoch 44/50
# 9/9 [==============================] - 19s 2s/step - loss: 0.6250 - acc: 0.7292 - binary_accuracy: 0.8177 - mean_absolute_error: 0.2612 - loss_no_weight_decay: 0.6250 - val_loss: 0.7589 - val_acc: 0.6538 - val_binary_accuracy: 0.7692 - val_mean_absolute_error: 0.3079 - val_loss_no_weight_decay: 0.7589
# — val_kappa: 0.44999999999999996
#
# Epoch 00044: val_kappa did not improve from 0.56432
# Confusion matrix:
#  [[24  0  1]
#  [ 1  2  3]
#  [ 4  6 11]]
# Epoch 45/50
# 9/9 [==============================] - 19s 2s/step - loss: 0.6305 - acc: 0.6788 - binary_accuracy: 0.7922 - mean_absolute_error: 0.2768 - loss_no_weight_decay: 0.6305 - val_loss: 0.6728 - val_acc: 0.6406 - val_binary_accuracy: 0.7760 - val_mean_absolute_error: 0.2752 - val_loss_no_weight_decay: 0.6728
# — val_kappa: 0.5959183673469388
#
# Epoch 00045: val_kappa improved from 0.56432 to 0.59592, saving model to base_2020-05-09-14-04-16-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[18  2  1]
#  [ 3  2  1]
#  [ 9  4 12]]
# Epoch 46/50
# 9/9 [==============================] - 16s 2s/step - loss: 0.5979 - acc: 0.7595 - binary_accuracy: 0.8376 - mean_absolute_error: 0.2517 - loss_no_weight_decay: 0.5979 - val_loss: 0.6308 - val_acc: 0.7500 - val_binary_accuracy: 0.8141 - val_mean_absolute_error: 0.2742 - val_loss_no_weight_decay: 0.6308
# — val_kappa: 0.5469387755102041
#
# Epoch 00046: val_kappa did not improve from 0.59592
# Confusion matrix:
#  [[23  2  2]
#  [ 0  5  1]
#  [ 6  4  9]]
# Epoch 47/50
# 9/9 [==============================] - 19s 2s/step - loss: 0.6622 - acc: 0.6806 - binary_accuracy: 0.7992 - mean_absolute_error: 0.2687 - loss_no_weight_decay: 0.6622 - val_loss: 0.5457 - val_acc: 0.7969 - val_binary_accuracy: 0.8438 - val_mean_absolute_error: 0.2400 - val_loss_no_weight_decay: 0.5457
# — val_kappa: 0.5263157894736842
#
# Epoch 00047: val_kappa did not improve from 0.59592
# Confusion matrix:
#  [[21  2  2]
#  [ 0  3  1]
#  [10  4  9]]
# Epoch 48/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.6127 - acc: 0.7500 - binary_accuracy: 0.8356 - mean_absolute_error: 0.2528 - loss_no_weight_decay: 0.6127 - val_loss: 0.6765 - val_acc: 0.7308 - val_binary_accuracy: 0.8077 - val_mean_absolute_error: 0.2750 - val_loss_no_weight_decay: 0.6765
# — val_kappa: 0.5506072874493927
#
# Epoch 00048: val_kappa did not improve from 0.59592
# Confusion matrix:
#  [[27  1  2]
#  [ 1  2  1]
#  [ 7  2  9]]
# Epoch 49/50
# 9/9 [==============================] - 18s 2s/step - loss: 0.6070 - acc: 0.7202 - binary_accuracy: 0.8238 - mean_absolute_error: 0.2542 - loss_no_weight_decay: 0.6070 - val_loss: 0.6168 - val_acc: 0.7656 - val_binary_accuracy: 0.8021 - val_mean_absolute_error: 0.2620 - val_loss_no_weight_decay: 0.6168
# — val_kappa: 0.4590163934426228
#
# Epoch 00049: val_kappa did not improve from 0.59592
# Confusion matrix:
#  [[26  1  2]
#  [ 3  4  0]
#  [ 3  3 10]]
# Epoch 50/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.7399 - acc: 0.6698 - binary_accuracy: 0.7857 - mean_absolute_error: 0.2978 - loss_no_weight_decay: 0.7399 - val_loss: 0.7431 - val_acc: 0.6923 - val_binary_accuracy: 0.8269 - val_mean_absolute_error: 0.2941 - val_loss_no_weight_decay: 0.7431
# — val_kappa: 0.5506072874493927
#
# Epoch 00050: val_kappa did not improve from 0.59592
# Confusion matrix:
#  [[23  2  3]
#  [ 0  6  1]
#  [ 9  5  3]]
# 176/176 [==============================] - 5s 28ms/step
# 176/176 [==============================] - 5s 27ms/step
# Test loss: 0.6486491862094474
# Test accuracy: 0.7272727272727273
# Confusion Matrix
# [[80  0  8]
#  [ 3  8  8]
#  [15 19 35]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.82      0.91      0.86        88
#            1       0.30      0.42      0.35        19
#            2       0.69      0.51      0.58        69
#
#     accuracy                           0.70       176
#    macro avg       0.60      0.61      0.60       176
# weighted avg       0.71      0.70      0.70       176

# %%
from Kappa_Skl import kappa
def kappa2(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    if len(y_true.shape) > 1 and y_true.shape[1] > 1:
        y_true = y_true.dot(range(y_true.shape[1]))
    if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
        y_pred = y_pred.dot(range(y_pred.shape[1]))
    try:
        return kappa(y_true, y_pred, weights='quadratic')
    except IndexError:
        return np.nan
    
print('Quadratic_wieghted_kappa')
print(kappa2(y_true, y_pred))
# Out:
# Quadratic_wieghted_kappa
# 0.5876320338006529

# %%
import numpy as np 
import matplotlib.pyplot as plt
import os
import wandb
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model loss.png')

# summarize history for val_kappa
plt.plot(history.history['val_kappa'])
plt.title('Validation_Kappa')
plt.ylabel('val_kappa')
plt.xlabel('epoch')
plt.legend([ 'validation'], loc='upper left')
plt.show()
#plt.savefig('model validation_kappa.png')

# summarize history for mean_absolute _error
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model mean_absolute_error')
plt.ylabel('mean_absolute_error')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model maey.png'
# Out:
# dict_keys(['val_loss', 'val_acc', 'val_binary_accuracy', 'val_mean_absolute_error', 'val_loss_no_weight_decay', 'loss', 'acc', 'binary_accuracy', 'mean_absolute_error', 'loss_no_weight_decay', 'val_kappa', 'lr'])
