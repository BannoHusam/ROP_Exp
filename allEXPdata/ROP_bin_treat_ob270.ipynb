# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, InputLayer
from keras.regularizers import L1L2, l2, l1
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from custom_pooling import RMSPooling2D
from keras.optimizers import SGD, Adam
from keras.layers import LeakyReLU
#from data import BALANCE_WEIGHTS
from keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
#import os
from datetime import datetime as dt
from custom_loss import WeightedCategoricalCrossEntropy
from VCM import VCM
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
def get_experiment_id():
    time_str = dt.now().strftime('%Y-%m-%d-%H-%M-%S')
    experiment_id = 'base_{}'.format(time_str)
    return experiment_id
p_ratio=[1.0, 1.44, 1.73, 1.0]

model = Sequential()


model.add(Conv2D(16, (5, 5), activation='tanh', input_shape=(270, 270, 3)))
model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(16, (3, 3), activation='tanh'))
model.add(Conv2D(16, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))

#model.add(LeakyReLU(alpha=0.01))


model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))



model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))          
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(MaxPooling2D(pool_size=2))
#model.add(MaxPooling2D(pool_size=1))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
model.add(MaxPooling2D(pool_size=2))

model.add(Flatten())


#chnaged from 10 to 5 because an error 
model.add(Dense(2, activation='softmax'))

sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.count_params()
#adam = Adam(lr=0.0005, decay=1e-6)
#rmsprop
#Mloss = WeightedCategoricalCrossEntropy({0: 0.4125861396437394, 1: 1.4918664786083686, 2: 0.690426457789382, 3: 3.9541433021806855, 4: 4.885604311008468})
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['mae','acc'])
model.summary()
loss_no_weight_decay = model.total_loss - sum(model.losses)
model.metrics_tensors.append(loss_no_weight_decay)
model.metrics_names.append('loss_no_weight_decay')
#############################################################################################
#############################################################################################
#############################################################################################
#############################################################################################
#Preparing Data Augmentation Configuration 
train_datagen = ImageDataGenerator(
        rescale=1./255,
#        featurewise_center=True,
 #       samplewise_center=True,
        shear_range=0,
        zoom_range=0.0,#[1 / 1.15, 1.15],
        horizontal_flip=False,#True,
        rotation_range=0)#90,
#        validation_split=0.2)
"""
For the test set only rescale should be made 
"""
test_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_class_treatment/train",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="training")
#    save_to_dir="D:/Separating Images into subfolders/train_augmented")


#print(train_generator.class_indices)

valid_generator = valid_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_class_treatment/vald",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="validation")
#    save_to_dir="D:/Separating Images into subfolders/val_augmented"


test_generator = test_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_class_treatment/test",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=1,
    class_mode="categorical",
    shuffle=False,
    seed=42)
#    save_to_dir="D:/Separating Images into subfolders/test_augmented")


# Fitting/Training the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
experiment_id = get_experiment_id()
callbacks = [
    EarlyStopping(monitor='val_acc', patience=50, min_delta=0.001, verbose=1),
    ModelCheckpoint(experiment_id + "-val_acc_checkpoint.hdf5", monitor='val_acc', verbose=1, save_best_only=True, mode='auto'),
    ReduceLROnPlateau(monitor='val_acc', factor=0.5, patience=7, verbose=1, mode='auto', min_delta=0.001, cooldown=0, min_lr=1e-7),
    VCM(valid_generator,STEP_SIZE_VALID)
    
]

class_weight_list = class_weight.compute_class_weight('balanced', np.unique(train_generator.classes), train_generator.classes)
class_weights = dict(zip(np.unique(train_generator.classes), class_weight_list))

history=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    #class_weight=class_weights,
                    callbacks=callbacks,
                    epochs=35  
)


# Evaluating the model 
#predicting output
#reseting the test generator before calling predict_generator, in order not to get weird output
test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 266, 266, 16)      1216
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 262, 262, 16)      6416
# _________________________________________________________________
# input_1 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 260, 260, 16)      2320
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 258, 258, 16)      2320
# _________________________________________________________________
# input_2 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 254, 254, 16)      6416
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 250, 250, 16)      6416
# _________________________________________________________________
# input_3 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 246, 246, 16)      6416
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 242, 242, 16)      6416
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 121, 121, 16)      0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 119, 119, 32)      4640
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 117, 117, 32)      9248
# _________________________________________________________________
# input_4 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 115, 115, 32)      9248
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 113, 113, 32)      9248
# _________________________________________________________________
# input_5 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 111, 111, 32)      9248
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 109, 109, 32)      9248
# _________________________________________________________________
# input_6 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 107, 107, 32)      9248
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 105, 105, 32)      9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 52, 52, 32)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 50, 50, 64)        18496
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 48, 48, 64)        36928
# _________________________________________________________________
# input_7 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 46, 46, 64)        36928
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 44, 44, 64)        36928
# _________________________________________________________________
# input_8 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 42, 42, 64)        36928
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 40, 40, 64)        36928
# _________________________________________________________________
# input_9 (InputLayer)         multiple                  0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 20, 20, 64)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 18, 18, 64)        36928
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# input_10 (InputLayer)        multiple                  0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 14, 14, 64)        36928
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 12, 12, 64)        36928
# _________________________________________________________________
# input_11 (InputLayer)        multiple                  0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 4610
# =================================================================
# Total params: 462,770
# Trainable params: 462,770
# Non-trainable params: 0
# _________________________________________________________________
# Found 294 images belonging to 2 classes.
# Found 58 images belonging to 2 classes.
# Found 88 images belonging to 2 classes.
# Epoch 1/35
# 4/4 [==============================] - 21s 5s/step - loss: 0.6383 - mean_absolute_error: 0.4557 - acc: 0.6184 - loss_no_weight_decay: 0.6383 - val_loss: 0.5392 - val_mean_absolute_error: 0.3714 - val_acc: 0.7759 - val_loss_no_weight_decay: 0.5392
#
# Epoch 00001: val_acc improved from -inf to 0.77586, saving model to base_2020-05-08-16-03-26-val_acc_checkpoint.hdf5
# Confusion matrix:
#  []
# Epoch 2/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.5377 - mean_absolute_error: 0.3540 - acc: 0.7709 - loss_no_weight_decay: 0.5377 - val_loss: 0.5382 - val_mean_absolute_error: 0.3274 - val_acc: 0.7759 - val_loss_no_weight_decay: 0.5382
#
# Epoch 00002: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 3/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.6670 - mean_absolute_error: 0.4289 - acc: 0.6742 - loss_no_weight_decay: 0.6670 - val_loss: 0.5851 - val_mean_absolute_error: 0.4313 - val_acc: 0.7759 - val_loss_no_weight_decay: 0.5851
#
# Epoch 00003: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 4/35
# 4/4 [==============================] - 5s 1s/step - loss: 0.5733 - mean_absolute_error: 0.3978 - acc: 0.7539 - loss_no_weight_decay: 0.5733 - val_loss: 0.5331 - val_mean_absolute_error: 0.3454 - val_acc: 0.7759 - val_loss_no_weight_decay: 0.5331
#
# Epoch 00004: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 5/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.5777 - mean_absolute_error: 0.3689 - acc: 0.7389 - loss_no_weight_decay: 0.5777 - val_loss: 0.5350 - val_mean_absolute_error: 0.3639 - val_acc: 0.7759 - val_loss_no_weight_decay: 0.5350
#
# Epoch 00005: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 6/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.5730 - mean_absolute_error: 0.3851 - acc: 0.7411 - loss_no_weight_decay: 0.5730 - val_loss: 0.5405 - val_mean_absolute_error: 0.3782 - val_acc: 0.7759 - val_loss_no_weight_decay: 0.5405
#
# Epoch 00006: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 7/35
# 4/4 [==============================] - 5s 1s/step - loss: 0.5814 - mean_absolute_error: 0.4004 - acc: 0.7344 - loss_no_weight_decay: 0.5814 - val_loss: 0.5376 - val_mean_absolute_error: 0.3719 - val_acc: 0.7759 - val_loss_no_weight_decay: 0.5376
#
# Epoch 00007: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 8/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.5853 - mean_absolute_error: 0.3865 - acc: 0.7291 - loss_no_weight_decay: 0.5853 - val_loss: 0.5356 - val_mean_absolute_error: 0.3664 - val_acc: 0.7759 - val_loss_no_weight_decay: 0.5356
#
# Epoch 00008: val_acc did not improve from 0.77586
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Confusion matrix:
#  []
# Epoch 9/35
# 4/4 [==============================] - 5s 1s/step - loss: 0.5720 - mean_absolute_error: 0.3835 - acc: 0.7411 - loss_no_weight_decay: 0.5720 - val_loss: 0.5370 - val_mean_absolute_error: 0.3705 - val_acc: 0.7759 - val_loss_no_weight_decay: 0.5370
#
# Epoch 00009: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 10/35
# 4/4 [==============================] - 5s 1s/step - loss: 0.5621 - mean_absolute_error: 0.3835 - acc: 0.7509 - loss_no_weight_decay: 0.5621 - val_loss: 0.5363 - val_mean_absolute_error: 0.3686 - val_acc: 0.7759 - val_loss_no_weight_decay: 0.5363
#
# Epoch 00010: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 11/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.5588 - mean_absolute_error: 0.3765 - acc: 0.7533 - loss_no_weight_decay: 0.5588 - val_loss: 0.5336 - val_mean_absolute_error: 0.3583 - val_acc: 0.7759 - val_loss_no_weight_decay: 0.5336
#
# Epoch 00011: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 12/35
# 4/4 [==============================] - 5s 1s/step - loss: 0.6141 - mean_absolute_error: 0.4012 - acc: 0.7031 - loss_no_weight_decay: 0.6141 - val_loss: 0.5399 - val_mean_absolute_error: 0.3772 - val_acc: 0.7759 - val_loss_no_weight_decay: 0.5399
#
# Epoch 00012: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 13/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.5214 - mean_absolute_error: 0.3598 - acc: 0.7916 - loss_no_weight_decay: 0.5214 - val_loss: 0.5328 - val_mean_absolute_error: 0.3528 - val_acc: 0.7759 - val_loss_no_weight_decay: 0.5328
#
# Epoch 00013: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 14/35
# 4/4 [==============================] - 5s 1s/step - loss: 0.5641 - mean_absolute_error: 0.3671 - acc: 0.7500 - loss_no_weight_decay: 0.5641 - val_loss: 0.5329 - val_mean_absolute_error: 0.3533 - val_acc: 0.7759 - val_loss_no_weight_decay: 0.5329
#
# Epoch 00014: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 15/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.6046 - mean_absolute_error: 0.3887 - acc: 0.7128 - loss_no_weight_decay: 0.6046 - val_loss: 0.5372 - val_mean_absolute_error: 0.3710 - val_acc: 0.7759 - val_loss_no_weight_decay: 0.5372
#
# Epoch 00015: val_acc did not improve from 0.77586
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Confusion matrix:
#  []
# Epoch 16/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.5692 - mean_absolute_error: 0.3907 - acc: 0.7445 - loss_no_weight_decay: 0.5692 - val_loss: 0.5445 - val_mean_absolute_error: 0.3859 - val_acc: 0.7759 - val_loss_no_weight_decay: 0.5445
#
# Epoch 00016: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 17/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.6132 - mean_absolute_error: 0.4237 - acc: 0.7019 - loss_no_weight_decay: 0.6132 - val_loss: 0.5537 - val_mean_absolute_error: 0.3992 - val_acc: 0.7759 - val_loss_no_weight_decay: 0.5537
#
# Epoch 00017: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 18/35
# 4/4 [==============================] - 5s 1s/step - loss: 0.5807 - mean_absolute_error: 0.4095 - acc: 0.7383 - loss_no_weight_decay: 0.5807 - val_loss: 0.5460 - val_mean_absolute_error: 0.3882 - val_acc: 0.7759 - val_loss_no_weight_decay: 0.5460
#
# Epoch 00018: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 19/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.5746 - mean_absolute_error: 0.3969 - acc: 0.7408 - loss_no_weight_decay: 0.5746 - val_loss: 0.5380 - val_mean_absolute_error: 0.3731 - val_acc: 0.7759 - val_loss_no_weight_decay: 0.5380
#
# Epoch 00019: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 20/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.5785 - mean_absolute_error: 0.3881 - acc: 0.7347 - loss_no_weight_decay: 0.5785 - val_loss: 0.5349 - val_mean_absolute_error: 0.3642 - val_acc: 0.7759 - val_loss_no_weight_decay: 0.5349
#
# Epoch 00020: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 21/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.5634 - mean_absolute_error: 0.3744 - acc: 0.7496 - loss_no_weight_decay: 0.5634 - val_loss: 0.5336 - val_mean_absolute_error: 0.3582 - val_acc: 0.7759 - val_loss_no_weight_decay: 0.5336
#
# Epoch 00021: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 22/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.5932 - mean_absolute_error: 0.3876 - acc: 0.7230 - loss_no_weight_decay: 0.5932 - val_loss: 0.5352 - val_mean_absolute_error: 0.3650 - val_acc: 0.7759 - val_loss_no_weight_decay: 0.5352
#
# Epoch 00022: val_acc did not improve from 0.77586
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Confusion matrix:
#  []
# Epoch 23/35
# 4/4 [==============================] - 5s 1s/step - loss: 0.5540 - mean_absolute_error: 0.3741 - acc: 0.7578 - loss_no_weight_decay: 0.5540 - val_loss: 0.5354 - val_mean_absolute_error: 0.3658 - val_acc: 0.7759 - val_loss_no_weight_decay: 0.5354
#
# Epoch 00023: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 24/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.5841 - mean_absolute_error: 0.3906 - acc: 0.7301 - loss_no_weight_decay: 0.5841 - val_loss: 0.5370 - val_mean_absolute_error: 0.3703 - val_acc: 0.7759 - val_loss_no_weight_decay: 0.5370
#
# Epoch 00024: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 25/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.5840 - mean_absolute_error: 0.3917 - acc: 0.7291 - loss_no_weight_decay: 0.5840 - val_loss: 0.5372 - val_mean_absolute_error: 0.3709 - val_acc: 0.7759 - val_loss_no_weight_decay: 0.5372
#
# Epoch 00025: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 26/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.5959 - mean_absolute_error: 0.3995 - acc: 0.7171 - loss_no_weight_decay: 0.5959 - val_loss: 0.5388 - val_mean_absolute_error: 0.3750 - val_acc: 0.7759 - val_loss_no_weight_decay: 0.5388
#
# Epoch 00026: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 27/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.5622 - mean_absolute_error: 0.3844 - acc: 0.7522 - loss_no_weight_decay: 0.5622 - val_loss: 0.5378 - val_mean_absolute_error: 0.3726 - val_acc: 0.7759 - val_loss_no_weight_decay: 0.5378
#
# Epoch 00027: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 28/35
# 4/4 [==============================] - 5s 1s/step - loss: 0.5743 - mean_absolute_error: 0.3897 - acc: 0.7383 - loss_no_weight_decay: 0.5743 - val_loss: 0.5377 - val_mean_absolute_error: 0.3723 - val_acc: 0.7759 - val_loss_no_weight_decay: 0.5377
#
# Epoch 00028: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 29/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.5675 - mean_absolute_error: 0.3858 - acc: 0.7454 - loss_no_weight_decay: 0.5675 - val_loss: 0.5369 - val_mean_absolute_error: 0.3702 - val_acc: 0.7759 - val_loss_no_weight_decay: 0.5369
#
# Epoch 00029: val_acc did not improve from 0.77586
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Confusion matrix:
#  []
# Epoch 30/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.5741 - mean_absolute_error: 0.3864 - acc: 0.7392 - loss_no_weight_decay: 0.5741 - val_loss: 0.5360 - val_mean_absolute_error: 0.3677 - val_acc: 0.7759 - val_loss_no_weight_decay: 0.5360
# Epoch 00030: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 31/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.5507 - mean_absolute_error: 0.3739 - acc: 0.7611 - loss_no_weight_decay: 0.5507 - val_loss: 0.5353 - val_mean_absolute_error: 0.3655 - val_acc: 0.7759 - val_loss_no_weight_decay: 0.5353
#
# Epoch 00031: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 32/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.5710 - mean_absolute_error: 0.3819 - acc: 0.7414 - loss_no_weight_decay: 0.5710 - val_loss: 0.5350 - val_mean_absolute_error: 0.3644 - val_acc: 0.7759 - val_loss_no_weight_decay: 0.5350
#
# Epoch 00032: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 33/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.6056 - mean_absolute_error: 0.3971 - acc: 0.7091 - loss_no_weight_decay: 0.6056 - val_loss: 0.5353 - val_mean_absolute_error: 0.3655 - val_acc: 0.7759 - val_loss_no_weight_decay: 0.5353
#
# Epoch 00033: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 34/35
# 4/4 [==============================] - 5s 1s/step - loss: 0.5669 - mean_absolute_error: 0.3792 - acc: 0.7461 - loss_no_weight_decay: 0.5669 - val_loss: 0.5352 - val_mean_absolute_error: 0.3651 - val_acc: 0.7759 - val_loss_no_weight_decay: 0.5352
#
# Epoch 00034: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 35/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.5607 - mean_absolute_error: 0.3777 - acc: 0.7515 - loss_no_weight_decay: 0.5607 - val_loss: 0.5355 - val_mean_absolute_error: 0.3662 - val_acc: 0.7759 - val_loss_no_weight_decay: 0.5355
#
# Epoch 00035: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# 88/88 [==============================] - 1s 12ms/step
# 88/88 [==============================] - 1s 9ms/step
# Test loss: 0.5262541306967085
# Test accuracy: 0.36196519840847363
# Confusion Matrix
# [[ 0 19]
#  [ 0 69]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        19
#            1       0.78      1.00      0.88        69
#
#     accuracy                           0.78        88
#    macro avg       0.39      0.50      0.44        88
# weighted avg       0.61      0.78      0.69        88
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
import numpy as np 
import matplotlib.pyplot as plt
import os
import wandb
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_mean_absolute_error', 'val_acc', 'val_loss_no_weight_decay', 'loss', 'mean_absolute_error', 'acc', 'loss_no_weight_decay', 'lr'])

# %%
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
from Kappa_Skl import kappa
def kappa2(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    if len(y_true.shape) > 1 and y_true.shape[1] > 1:
        y_true = y_true.dot(range(y_true.shape[1]))
    if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
        y_pred = y_pred.dot(range(y_pred.shape[1]))
    try:
        return kappa(y_true, y_pred, weights='quadratic')
    except IndexError:
        return np.nan
    
print('Quadratic_wieghted_kappa')
print(kappa2(y_true, y_pred))
# Out:
# Quadratic_wieghted_kappa
# 0.0

# %%
# summarize history for mean_absolute _error
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model mean_absolute_error')
plt.ylabel('mean_absolute_error')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model maey.png')
