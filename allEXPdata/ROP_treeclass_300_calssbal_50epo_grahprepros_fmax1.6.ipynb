# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, InputLayer
from keras.regularizers import L1L2, l2, l1
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from custom_pooling import RMSPooling2D
from keras.optimizers import SGD, Adam
from keras.layers import LeakyReLU
#from data import BALANCE_WEIGHTS
from keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
#import os
from datetime import datetime as dt
from custom_loss import WeightedCategoricalCrossEntropy
from VCM import VCM
from QWK import QWK
import keras.backend as K
from Fractional_MAXPOOL import FractionalPooling2D
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
def get_experiment_id():
    time_str = dt.now().strftime('%Y-%m-%d-%H-%M-%S')
    experiment_id = 'base_{}'.format(time_str)
    return experiment_id
p_ratio=[1.0, 1.44, 1.73, 1.0]

model = Sequential()


model.add(Conv2D(16, (5, 5), activation='tanh', input_shape=(300, 300, 3)))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))
model.add(FractionalPooling2D(pool_ratio=(1, 1.6, 1.6, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(16, (3, 3), activation='tanh'))
model.add(Conv2D(16, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

#model.add(LeakyReLU(alpha=0.01))


model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))


model.add(FractionalPooling2D(pool_ratio=(1, 1.6, 1.6, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))          
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
model.add(FractionalPooling2D(pool_ratio=(1, 1.6, 1.6, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(FractionalPooling2D(pool_ratio=(1, 1.6, 1.6, 1),pseudo_random = True,overlap=True))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))


model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

#model.add(MaxPooling2D(pool_size=1))




model.add(FractionalPooling2D(pool_ratio=(1, 1.7, 1.7, 1),pseudo_random = True,overlap=True))

model.add(Flatten())


#chnaged from 10 to 5 because an error 
model.add(Dense(3, activation='softmax'))

sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.count_params()
#adam = Adam(lr=0.0005, decay=1e-6)
#rmsprop
#Mloss = WeightedCategoricalCrossEntropy({0: 0.4125861396437394, 1: 1.4918664786083686, 2: 0.690426457789382, 3: 3.9541433021806855, 4: 4.885604311008468})
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['acc','binary_accuracy','mae'])
model.summary()
loss_no_weight_decay = model.total_loss - sum(model.losses)
model.metrics_tensors.append(loss_no_weight_decay)
model.metrics_names.append('loss_no_weight_decay')
#############################################################################################
#############################################################################################
#############################################################################################
#############################################################################################
#Preparing Data Augmentation Configuration 
train_datagen = ImageDataGenerator(
        rescale=1./255,
#        featurewise_center=True,
 #       samplewise_center=True,
        shear_range=0,
        zoom_range=0.0,#[1 / 1.15, 1.15],
        horizontal_flip=False,#True,
        rotation_range=0)#90,
#        validation_split=0.2)
"""
For the test set only rescale should be made 
"""
test_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/three_class_grah/train",
    target_size=(300, 300),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="training")
#    save_to_dir="D:/Separating Images into subfolders/train_augmented")


#print(train_generator.class_indices)

valid_generator = valid_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/three_class_grah/vald",
    target_size=(300, 300),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="validation")
#    save_to_dir="D:/Separating Images into subfolders/val_augmented"


test_generator = test_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/three_class_grah/test",
    target_size=(300, 300),
    color_mode="rgb",
    batch_size=1,
    class_mode="categorical",
    shuffle=False,
    seed=42)
#    save_to_dir="D:/Separating Images into subfolders/test_augmented")


# Fitting/Training the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
experiment_id = get_experiment_id()
callbacks = [
    QWK(valid_generator, STEP_SIZE_VALID),
    EarlyStopping(monitor='val_acc', patience=50, min_delta=0.001, verbose=1),
    ModelCheckpoint(experiment_id + "-val_kapa_checkpoint.hdf5", monitor='val_kappa', verbose=1, save_best_only=True, mode='max'),
    ReduceLROnPlateau(monitor='val_acc', factor=0.5, patience=7, verbose=1, mode='auto', min_delta=0.001, cooldown=0, min_lr=1e-7),
    VCM(valid_generator,STEP_SIZE_VALID)
    
]

class_weight_list = class_weight.compute_class_weight('balanced', np.unique(train_generator.classes), train_generator.classes)
class_weights = dict(zip(np.unique(train_generator.classes), class_weight_list))

history=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    class_weight=class_weights,
                    callbacks=callbacks,
                    epochs=50  
)


# Evaluating the model 
#predicting output
#reseting the test generator before calling predict_generator, in order not to get weird output
test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1', '2']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 296, 296, 16)      1216
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 292, 292, 16)      6416
# _________________________________________________________________
# fractional_pooling2d_1 (Frac (None, 182, 182, 16)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 180, 180, 16)      2320
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 178, 178, 16)      2320
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 174, 174, 16)      6416
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 170, 170, 16)      6416
# _________________________________________________________________
# fractional_pooling2d_2 (Frac (None, 106, 106, 16)      0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 102, 102, 16)      6416
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 98, 98, 16)        6416
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 96, 96, 32)        4640
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 94, 94, 32)        9248
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 92, 92, 32)        9248
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 90, 90, 32)        9248
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 88, 88, 32)        9248
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 86, 86, 32)        9248
# _________________________________________________________________
# fractional_pooling2d_3 (Frac (None, 53, 53, 32)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 51, 51, 32)        9248
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 49, 49, 32)        9248
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 47, 47, 64)        18496
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 45, 45, 64)        36928
# _________________________________________________________________
# fractional_pooling2d_4 (Frac (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 26, 26, 64)        36928
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 24, 24, 64)        36928
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 22, 22, 64)        36928
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 20, 20, 64)        36928
# _________________________________________________________________
# fractional_pooling2d_5 (Frac (None, 11, 11, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 7744)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 23235
# =================================================================
# Total params: 333,683
# Trainable params: 333,683
# Non-trainable params: 0
# _________________________________________________________________
# Found 588 images belonging to 3 classes.
# Found 116 images belonging to 3 classes.
# Found 176 images belonging to 3 classes.
# Epoch 1/50
# 9/9 [==============================] - 31s 3s/step - loss: 1.1048 - acc: 0.2507 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4448 - loss_no_weight_decay: 1.1048 - val_loss: 1.0978 - val_acc: 0.2969 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4442 - val_loss_no_weight_decay: 1.0978
# — val_kappa: 0.0
#
# Epoch 00001: val_kappa improved from -inf to 0.00000, saving model to base_2020-05-10-19-29-18-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[26  0  0]
#  [ 7  0  0]
#  [19  0  0]]
# Epoch 2/50
# 9/9 [==============================] - 22s 2s/step - loss: 1.0821 - acc: 0.4542 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4412 - loss_no_weight_decay: 1.0821 - val_loss: 1.0862 - val_acc: 0.4038 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4411 - val_loss_no_weight_decay: 1.0862
# — val_kappa: 0.0
#
# Epoch 00002: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[30  0  0]
#  [ 7  0  0]
#  [15  0  0]]
# Epoch 3/50
# 9/9 [==============================] - 21s 2s/step - loss: 1.1369 - acc: 0.4747 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4393 - loss_no_weight_decay: 1.1369 - val_loss: 1.0886 - val_acc: 0.5469 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4422 - val_loss_no_weight_decay: 1.0886
# — val_kappa: 0.0
#
# Epoch 00003: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[22  0  0]
#  [ 8  0  0]
#  [22  0  0]]
# Epoch 4/50
# 9/9 [==============================] - 24s 3s/step - loss: 1.0651 - acc: 0.4167 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4441 - loss_no_weight_decay: 1.0651 - val_loss: 1.0948 - val_acc: 0.3654 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4431 - val_loss_no_weight_decay: 1.0948
# — val_kappa: 0.0
#
# Epoch 00004: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[31  0  0]
#  [ 9  0  0]
#  [12  0  0]]
# Epoch 5/50
# 9/9 [==============================] - 22s 2s/step - loss: 1.0811 - acc: 0.4369 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4420 - loss_no_weight_decay: 1.0811 - val_loss: 1.0830 - val_acc: 0.6875 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4409 - val_loss_no_weight_decay: 1.0830
# — val_kappa: 0.0
#
# Epoch 00005: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[28  0  0]
#  [ 5  0  0]
#  [19  0  0]]
# Epoch 6/50
# 9/9 [==============================] - 21s 2s/step - loss: 1.1221 - acc: 0.5193 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4403 - loss_no_weight_decay: 1.1221 - val_loss: 1.0685 - val_acc: 0.5385 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4372 - val_loss_no_weight_decay: 1.0685
# — val_kappa: 0.0
#
# Epoch 00006: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[27  0  0]
#  [ 6  0  0]
#  [19  0  0]]
# Epoch 7/50
# 9/9 [==============================] - 21s 2s/step - loss: 1.0591 - acc: 0.5018 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4388 - loss_no_weight_decay: 1.0591 - val_loss: 1.0642 - val_acc: 0.5781 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4362 - val_loss_no_weight_decay: 1.0642
# — val_kappa: 0.0
#
# Epoch 00007: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[29  0  0]
#  [ 6  0  0]
#  [17  0  0]]
# Epoch 8/50
# 9/9 [==============================] - 19s 2s/step - loss: 1.0872 - acc: 0.5252 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4350 - loss_no_weight_decay: 1.0872 - val_loss: 1.0186 - val_acc: 0.5769 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4242 - val_loss_no_weight_decay: 1.0186
# — val_kappa: 0.0
#
# Epoch 00008: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[25  0  0]
#  [ 6  0  0]
#  [21  0  0]]
# Epoch 9/50
# 9/9 [==============================] - 24s 3s/step - loss: 1.0678 - acc: 0.5191 - binary_accuracy: 0.6794 - mean_absolute_error: 0.4253 - loss_no_weight_decay: 1.0678 - val_loss: 1.0407 - val_acc: 0.5000 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4283 - val_loss_no_weight_decay: 1.0407
# — val_kappa: 0.0
#
# Epoch 00009: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[26  0  0]
#  [ 8  0  0]
#  [18  0  0]]
# Epoch 10/50
# 9/9 [==============================] - 21s 2s/step - loss: 1.1080 - acc: 0.4033 - binary_accuracy: 0.6690 - mean_absolute_error: 0.4387 - loss_no_weight_decay: 1.1080 - val_loss: 0.9852 - val_acc: 0.6346 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4152 - val_loss_no_weight_decay: 0.9852
# — val_kappa: 0.0
#
# Epoch 00010: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[31  0  0]
#  [ 9  0  0]
#  [12  0  0]]
# Epoch 11/50
# 9/9 [==============================] - 22s 2s/step - loss: 1.0107 - acc: 0.4892 - binary_accuracy: 0.6719 - mean_absolute_error: 0.4250 - loss_no_weight_decay: 1.0107 - val_loss: 0.9706 - val_acc: 0.6406 - val_binary_accuracy: 0.6719 - val_mean_absolute_error: 0.4116 - val_loss_no_weight_decay: 0.9706
# — val_kappa: 0.04123711340206171
#
# Epoch 00011: val_kappa improved from 0.00000 to 0.04124, saving model to base_2020-05-10-19-29-18-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[26  0  0]
#  [ 6  0  0]
#  [20  0  0]]
# Epoch 12/50
# 9/9 [==============================] - 22s 2s/step - loss: 1.0215 - acc: 0.5556 - binary_accuracy: 0.6848 - mean_absolute_error: 0.4095 - loss_no_weight_decay: 1.0215 - val_loss: 0.8648 - val_acc: 0.6731 - val_binary_accuracy: 0.7308 - val_mean_absolute_error: 0.3789 - val_loss_no_weight_decay: 0.8648
# — val_kappa: 0.3142857142857143
#
# Epoch 00012: val_kappa improved from 0.04124 to 0.31429, saving model to base_2020-05-10-19-29-18-val_kapa_checkpoint.hdf5
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Confusion matrix:
#  [[23  0  0]
#  [ 6  0  0]
#  [23  0  0]]
# Epoch 13/50
# 9/9 [==============================] - 23s 3s/step - loss: 0.9708 - acc: 0.6267 - binary_accuracy: 0.7436 - mean_absolute_error: 0.3819 - loss_no_weight_decay: 0.9708 - val_loss: 0.8557 - val_acc: 0.6406 - val_binary_accuracy: 0.7552 - val_mean_absolute_error: 0.3733 - val_loss_no_weight_decay: 0.8557
# — val_kappa: 0.3119266055045873
#
# Epoch 00013: val_kappa did not improve from 0.31429
# Confusion matrix:
#  [[28  0  0]
#  [ 5  0  0]
#  [16  0  3]]
# Epoch 14/50
# 9/9 [==============================] - 19s 2s/step - loss: 0.9483 - acc: 0.6073 - binary_accuracy: 0.7422 - mean_absolute_error: 0.3715 - loss_no_weight_decay: 0.9483 - val_loss: 0.8713 - val_acc: 0.6538 - val_binary_accuracy: 0.7436 - val_mean_absolute_error: 0.3716 - val_loss_no_weight_decay: 0.8713
# — val_kappa: 0.37788018433179715
#
# Epoch 00014: val_kappa improved from 0.31429 to 0.37788, saving model to base_2020-05-10-19-29-18-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[22  0  5]
#  [ 6  0  0]
#  [15  1  3]]
# Epoch 15/50
# 9/9 [==============================] - 24s 3s/step - loss: 0.9187 - acc: 0.5816 - binary_accuracy: 0.7402 - mean_absolute_error: 0.3691 - loss_no_weight_decay: 0.9187 - val_loss: 0.9471 - val_acc: 0.5000 - val_binary_accuracy: 0.6979 - val_mean_absolute_error: 0.3901 - val_loss_no_weight_decay: 0.9471
# — val_kappa: 0.2995594713656389
#
# Epoch 00015: val_kappa did not improve from 0.37788
# Confusion matrix:
#  [[26  2  3]
#  [ 3  3  0]
#  [ 9  5  1]]
# Epoch 16/50
# 9/9 [==============================] - 21s 2s/step - loss: 0.9264 - acc: 0.4897 - binary_accuracy: 0.7120 - mean_absolute_error: 0.3821 - loss_no_weight_decay: 0.9264 - val_loss: 0.7611 - val_acc: 0.6346 - val_binary_accuracy: 0.7885 - val_mean_absolute_error: 0.3326 - val_loss_no_weight_decay: 0.7611
# — val_kappa: 0.38938053097345127
#
# Epoch 00016: val_kappa improved from 0.37788 to 0.38938, saving model to base_2020-05-10-19-29-18-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[27  0  0]
#  [ 5  2  0]
#  [16  2  0]]
# Epoch 17/50
# 9/9 [==============================] - 21s 2s/step - loss: 0.8984 - acc: 0.5822 - binary_accuracy: 0.7494 - mean_absolute_error: 0.3609 - loss_no_weight_decay: 0.8984 - val_loss: 0.8698 - val_acc: 0.6250 - val_binary_accuracy: 0.7500 - val_mean_absolute_error: 0.3664 - val_loss_no_weight_decay: 0.8698
# — val_kappa: 0.31999999999999995
#
# Epoch 00017: val_kappa did not improve from 0.38938
# Confusion matrix:
#  [[19  1  4]
#  [ 6  0  1]
#  [17  0  4]]
# Epoch 18/50
# 9/9 [==============================] - 21s 2s/step - loss: 0.8828 - acc: 0.6325 - binary_accuracy: 0.7563 - mean_absolute_error: 0.3544 - loss_no_weight_decay: 0.8828 - val_loss: 0.8964 - val_acc: 0.5769 - val_binary_accuracy: 0.7308 - val_mean_absolute_error: 0.3670 - val_loss_no_weight_decay: 0.8964
# — val_kappa: 0.33766233766233755
#
# Epoch 00018: val_kappa did not improve from 0.38938
# Confusion matrix:
#  [[18  0  5]
#  [ 6  1  2]
#  [12  1  7]]
# Epoch 19/50
# 9/9 [==============================] - 21s 2s/step - loss: 0.8319 - acc: 0.6227 - binary_accuracy: 0.7525 - mean_absolute_error: 0.3391 - loss_no_weight_decay: 0.8319 - val_loss: 1.0915 - val_acc: 0.4062 - val_binary_accuracy: 0.6562 - val_mean_absolute_error: 0.4021 - val_loss_no_weight_decay: 1.0915
# — val_kappa: 0.22127659574468073
#
# Epoch 00019: val_kappa did not improve from 0.38938
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Confusion matrix:
#  [[17  1  6]
#  [ 3  4  0]
#  [10  8  3]]
# Epoch 20/50
# 9/9 [==============================] - 21s 2s/step - loss: 0.8192 - acc: 0.6097 - binary_accuracy: 0.7555 - mean_absolute_error: 0.3324 - loss_no_weight_decay: 0.8192 - val_loss: 0.7480 - val_acc: 0.6346 - val_binary_accuracy: 0.7885 - val_mean_absolute_error: 0.3313 - val_loss_no_weight_decay: 0.7480
# — val_kappa: 0.3948497854077253
#
# Epoch 00020: val_kappa improved from 0.38938 to 0.39485, saving model to base_2020-05-10-19-29-18-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[23  0  3]
#  [ 2  1  1]
#  [ 7  3 12]]
# Epoch 21/50
# 9/9 [==============================] - 22s 2s/step - loss: 0.7993 - acc: 0.6558 - binary_accuracy: 0.7757 - mean_absolute_error: 0.3225 - loss_no_weight_decay: 0.7993 - val_loss: 0.7480 - val_acc: 0.6875 - val_binary_accuracy: 0.7708 - val_mean_absolute_error: 0.3044 - val_loss_no_weight_decay: 0.7480
# — val_kappa: 0.5679012345679013
#
# Epoch 00021: val_kappa improved from 0.39485 to 0.56790, saving model to base_2020-05-10-19-29-18-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[20  0  1]
#  [ 3  6  0]
#  [13  3  6]]
# Epoch 22/50
# 9/9 [==============================] - 23s 3s/step - loss: 0.7969 - acc: 0.6962 - binary_accuracy: 0.7975 - mean_absolute_error: 0.3114 - loss_no_weight_decay: 0.7969 - val_loss: 0.6629 - val_acc: 0.7308 - val_binary_accuracy: 0.8462 - val_mean_absolute_error: 0.2993 - val_loss_no_weight_decay: 0.6629
# — val_kappa: 0.5145228215767634
#
# Epoch 00022: val_kappa did not improve from 0.56790
# Confusion matrix:
#  [[21  1  1]
#  [ 2  5  0]
#  [12  4  6]]
# Epoch 23/50
# 9/9 [==============================] - 19s 2s/step - loss: 0.9220 - acc: 0.6266 - binary_accuracy: 0.7388 - mean_absolute_error: 0.3418 - loss_no_weight_decay: 0.9220 - val_loss: 0.8288 - val_acc: 0.6719 - val_binary_accuracy: 0.7604 - val_mean_absolute_error: 0.3445 - val_loss_no_weight_decay: 0.8288
# — val_kappa: 0.33333333333333315
#
# Epoch 00023: val_kappa did not improve from 0.56790
# Confusion matrix:
#  [[24  0  2]
#  [ 2  6  0]
#  [ 5  8  5]]
# Epoch 24/50
# 9/9 [==============================] - 23s 3s/step - loss: 0.8236 - acc: 0.6024 - binary_accuracy: 0.7407 - mean_absolute_error: 0.3412 - loss_no_weight_decay: 0.8236 - val_loss: 0.8396 - val_acc: 0.4808 - val_binary_accuracy: 0.7436 - val_mean_absolute_error: 0.3444 - val_loss_no_weight_decay: 0.8396
# — val_kappa: 0.3793103448275862
#
# Epoch 00024: val_kappa did not improve from 0.56790
# Confusion matrix:
#  [[24  1  0]
#  [ 1  4  0]
#  [11  5  6]]
# Epoch 25/50
# 9/9 [==============================] - 19s 2s/step - loss: 0.7174 - acc: 0.6790 - binary_accuracy: 0.7928 - mean_absolute_error: 0.3088 - loss_no_weight_decay: 0.7174 - val_loss: 0.6785 - val_acc: 0.7031 - val_binary_accuracy: 0.7865 - val_mean_absolute_error: 0.2904 - val_loss_no_weight_decay: 0.6785
# — val_kappa: 0.44999999999999996
#
# Epoch 00025: val_kappa did not improve from 0.56790
# Confusion matrix:
#  [[21  1  3]
#  [ 4  1  1]
#  [ 6  1 14]]
# Epoch 26/50
# 9/9 [==============================] - 23s 3s/step - loss: 0.8368 - acc: 0.6424 - binary_accuracy: 0.7662 - mean_absolute_error: 0.3142 - loss_no_weight_decay: 0.8368 - val_loss: 0.8863 - val_acc: 0.5769 - val_binary_accuracy: 0.7308 - val_mean_absolute_error: 0.3509 - val_loss_no_weight_decay: 0.8863
# — val_kappa: 0.34024896265560156
#
# Epoch 00026: val_kappa did not improve from 0.56790
# Confusion matrix:
#  [[23  2  5]
#  [ 1  2  0]
#  [ 5  9  5]]
# Epoch 27/50
# 9/9 [==============================] - 21s 2s/step - loss: 0.7765 - acc: 0.6115 - binary_accuracy: 0.7626 - mean_absolute_error: 0.3070 - loss_no_weight_decay: 0.7765 - val_loss: 0.6488 - val_acc: 0.7031 - val_binary_accuracy: 0.7969 - val_mean_absolute_error: 0.2881 - val_loss_no_weight_decay: 0.6488
# — val_kappa: 0.4545454545454546
#
# Epoch 00027: val_kappa did not improve from 0.56790
# Confusion matrix:
#  [[26  0  1]
#  [ 2  5  0]
#  [ 8  6  4]]
# Epoch 28/50
# 9/9 [==============================] - 21s 2s/step - loss: 0.7591 - acc: 0.6525 - binary_accuracy: 0.7712 - mean_absolute_error: 0.3076 - loss_no_weight_decay: 0.7591 - val_loss: 0.7388 - val_acc: 0.6538 - val_binary_accuracy: 0.7885 - val_mean_absolute_error: 0.2971 - val_loss_no_weight_decay: 0.7388
# — val_kappa: 0.5469387755102041
#
# Epoch 00028: val_kappa did not improve from 0.56790
# Confusion matrix:
#  [[23  0  0]
#  [ 2  4  0]
#  [11  6  6]]
# Epoch 29/50
# 9/9 [==============================] - 19s 2s/step - loss: 0.7690 - acc: 0.6295 - binary_accuracy: 0.7755 - mean_absolute_error: 0.3105 - loss_no_weight_decay: 0.7690 - val_loss: 1.0317 - val_acc: 0.5312 - val_binary_accuracy: 0.6823 - val_mean_absolute_error: 0.3733 - val_loss_no_weight_decay: 1.0317
# — val_kappa: 0.41004184100418406
#
# Epoch 00029: val_kappa did not improve from 0.56790
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Confusion matrix:
#  [[15  0 12]
#  [ 1  0  6]
#  [ 6  2 10]]
# Epoch 30/50
# 9/9 [==============================] - 23s 3s/step - loss: 0.8373 - acc: 0.6233 - binary_accuracy: 0.7535 - mean_absolute_error: 0.3319 - loss_no_weight_decay: 0.8373 - val_loss: 0.7739 - val_acc: 0.6346 - val_binary_accuracy: 0.7179 - val_mean_absolute_error: 0.3158 - val_loss_no_weight_decay: 0.7739
# — val_kappa: 0.575
#
# Epoch 00030: val_kappa improved from 0.56790 to 0.57500, saving model to base_2020-05-10-19-29-18-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[22  1  2]
#  [ 1  4  0]
#  [12  4  6]]
# Epoch 31/50
# 9/9 [==============================] - 23s 3s/step - loss: 0.7538 - acc: 0.6562 - binary_accuracy: 0.7697 - mean_absolute_error: 0.3102 - loss_no_weight_decay: 0.7538 - val_loss: 0.7622 - val_acc: 0.6406 - val_binary_accuracy: 0.7500 - val_mean_absolute_error: 0.3124 - val_loss_no_weight_decay: 0.7622
# — val_kappa: 0.5573770491803278
#
# Epoch 00031: val_kappa did not improve from 0.57500
# Confusion matrix:
#  [[25  1  1]
#  [ 1  2  0]
#  [11  6  5]]
# Epoch 32/50
# 9/9 [==============================] - 19s 2s/step - loss: 0.6631 - acc: 0.6740 - binary_accuracy: 0.7853 - mean_absolute_error: 0.2882 - loss_no_weight_decay: 0.6631 - val_loss: 0.5321 - val_acc: 0.7692 - val_binary_accuracy: 0.8718 - val_mean_absolute_error: 0.2391 - val_loss_no_weight_decay: 0.5321
# — val_kappa: 0.5365853658536585
#
# Epoch 00032: val_kappa did not improve from 0.57500
# Confusion matrix:
#  [[22  0  0]
#  [ 3  6  0]
#  [ 8  4  9]]
# Epoch 33/50
# 9/9 [==============================] - 23s 3s/step - loss: 0.7674 - acc: 0.6910 - binary_accuracy: 0.7963 - mean_absolute_error: 0.2859 - loss_no_weight_decay: 0.7674 - val_loss: 0.6546 - val_acc: 0.7500 - val_binary_accuracy: 0.8229 - val_mean_absolute_error: 0.2718 - val_loss_no_weight_decay: 0.6546
# — val_kappa: 0.5121951219512195
#
# Epoch 00033: val_kappa did not improve from 0.57500
# Confusion matrix:
#  [[24  1  2]
#  [ 1  6  0]
#  [ 5  4  9]]
# Epoch 34/50
# 9/9 [==============================] - 21s 2s/step - loss: 0.6577 - acc: 0.7252 - binary_accuracy: 0.8176 - mean_absolute_error: 0.2643 - loss_no_weight_decay: 0.6577 - val_loss: 0.6402 - val_acc: 0.7308 - val_binary_accuracy: 0.8269 - val_mean_absolute_error: 0.2730 - val_loss_no_weight_decay: 0.6402
# — val_kappa: 0.5161290322580646
#
# Epoch 00034: val_kappa did not improve from 0.57500
# Confusion matrix:
#  [[26  0  2]
#  [ 1  2  3]
#  [ 4  2 12]]
# Epoch 35/50
# 9/9 [==============================] - 21s 2s/step - loss: 0.6900 - acc: 0.7310 - binary_accuracy: 0.8316 - mean_absolute_error: 0.2658 - loss_no_weight_decay: 0.6900 - val_loss: 0.6572 - val_acc: 0.6875 - val_binary_accuracy: 0.7917 - val_mean_absolute_error: 0.2647 - val_loss_no_weight_decay: 0.6572
# — val_kappa: 0.5573770491803278
#
# Epoch 00035: val_kappa did not improve from 0.57500
# Confusion matrix:
#  [[29  1  1]
#  [ 1  2  0]
#  [ 6  4  8]]
# Epoch 36/50
# 9/9 [==============================] - 21s 2s/step - loss: 0.6693 - acc: 0.7370 - binary_accuracy: 0.8323 - mean_absolute_error: 0.2587 - loss_no_weight_decay: 0.6693 - val_loss: 0.5309 - val_acc: 0.8077 - val_binary_accuracy: 0.8654 - val_mean_absolute_error: 0.2401 - val_loss_no_weight_decay: 0.5309
# — val_kappa: 0.616
#
# Epoch 00036: val_kappa improved from 0.57500 to 0.61600, saving model to base_2020-05-10-19-29-18-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[22  0  1]
#  [ 2  4  2]
#  [ 4  5 12]]
# Epoch 37/50
# 9/9 [==============================] - 21s 2s/step - loss: 0.7102 - acc: 0.7305 - binary_accuracy: 0.8139 - mean_absolute_error: 0.2617 - loss_no_weight_decay: 0.7102 - val_loss: 0.6295 - val_acc: 0.7188 - val_binary_accuracy: 0.7969 - val_mean_absolute_error: 0.2703 - val_loss_no_weight_decay: 0.6295
# — val_kappa: 0.6585365853658537
#
# Epoch 00037: val_kappa improved from 0.61600 to 0.65854, saving model to base_2020-05-10-19-29-18-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[19  2  2]
#  [ 1  5  1]
#  [ 4  8 10]]
# Epoch 38/50
# 9/9 [==============================] - 21s 2s/step - loss: 0.6729 - acc: 0.6909 - binary_accuracy: 0.7951 - mean_absolute_error: 0.2695 - loss_no_weight_decay: 0.6729 - val_loss: 0.6456 - val_acc: 0.7115 - val_binary_accuracy: 0.8013 - val_mean_absolute_error: 0.2616 - val_loss_no_weight_decay: 0.6456
# — val_kappa: 0.588709677419355
#
# Epoch 00038: val_kappa did not improve from 0.65854
# Confusion matrix:
#  [[25  1  0]
#  [ 1  7  0]
#  [ 9  7  2]]
# Epoch 39/50
# 9/9 [==============================] - 21s 2s/step - loss: 0.6983 - acc: 0.6746 - binary_accuracy: 0.7888 - mean_absolute_error: 0.2784 - loss_no_weight_decay: 0.6983 - val_loss: 0.6870 - val_acc: 0.7344 - val_binary_accuracy: 0.7917 - val_mean_absolute_error: 0.2784 - val_loss_no_weight_decay: 0.6870
# — val_kappa: 0.5020242914979756
#
# Epoch 00039: val_kappa did not improve from 0.65854
# Confusion matrix:
#  [[25  0  4]
#  [ 0  6  2]
#  [ 5  3  7]]
# Epoch 40/50
# 9/9 [==============================] - 21s 2s/step - loss: 0.6922 - acc: 0.7222 - binary_accuracy: 0.8195 - mean_absolute_error: 0.2607 - loss_no_weight_decay: 0.6922 - val_loss: 0.5268 - val_acc: 0.8077 - val_binary_accuracy: 0.8910 - val_mean_absolute_error: 0.2235 - val_loss_no_weight_decay: 0.5268
# — val_kappa: 0.7096774193548387
#
# Epoch 00040: val_kappa improved from 0.65854 to 0.70968, saving model to base_2020-05-10-19-29-18-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[16  0  2]
#  [ 5  5  1]
#  [ 6  3 14]]
# Epoch 41/50
# 9/9 [==============================] - 21s 2s/step - loss: 0.7216 - acc: 0.7342 - binary_accuracy: 0.8349 - mean_absolute_error: 0.2526 - loss_no_weight_decay: 0.7216 - val_loss: 0.6329 - val_acc: 0.7188 - val_binary_accuracy: 0.8125 - val_mean_absolute_error: 0.2567 - val_loss_no_weight_decay: 0.6329
# — val_kappa: 0.5573770491803278
#
# Epoch 00041: val_kappa did not improve from 0.70968
# Confusion matrix:
#  [[27  0  1]
#  [ 0  4  0]
#  [ 8  8  4]]
# Epoch 42/50
# 9/9 [==============================] - 21s 2s/step - loss: 0.6988 - acc: 0.6468 - binary_accuracy: 0.7820 - mean_absolute_error: 0.2848 - loss_no_weight_decay: 0.6988 - val_loss: 0.6588 - val_acc: 0.7308 - val_binary_accuracy: 0.8269 - val_mean_absolute_error: 0.2761 - val_loss_no_weight_decay: 0.6588
# — val_kappa: 0.6533864541832669
#
# Epoch 00042: val_kappa did not improve from 0.70968
# Confusion matrix:
#  [[28  0  1]
#  [ 2  4  0]
#  [ 6  9  2]]
# Epoch 43/50
# 9/9 [==============================] - 21s 2s/step - loss: 0.6831 - acc: 0.7217 - binary_accuracy: 0.8164 - mean_absolute_error: 0.2624 - loss_no_weight_decay: 0.6831 - val_loss: 0.6027 - val_acc: 0.7344 - val_binary_accuracy: 0.8438 - val_mean_absolute_error: 0.2373 - val_loss_no_weight_decay: 0.6027
# — val_kappa: 0.6370967741935485
#
# Epoch 00043: val_kappa did not improve from 0.70968
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Confusion matrix:
#  [[27  1  1]
#  [ 0  2  2]
#  [ 5  3 11]]
# Epoch 44/50
# 9/9 [==============================] - 21s 2s/step - loss: 0.6245 - acc: 0.7658 - binary_accuracy: 0.8357 - mean_absolute_error: 0.2470 - loss_no_weight_decay: 0.6245 - val_loss: 0.5367 - val_acc: 0.7308 - val_binary_accuracy: 0.8333 - val_mean_absolute_error: 0.2405 - val_loss_no_weight_decay: 0.5367
# — val_kappa: 0.5577689243027889
#
# Epoch 00044: val_kappa did not improve from 0.70968
# Confusion matrix:
#  [[20  0  3]
#  [ 3  5  1]
#  [ 2  5 13]]
# Epoch 45/50
# 9/9 [==============================] - 22s 2s/step - loss: 0.6844 - acc: 0.7465 - binary_accuracy: 0.8448 - mean_absolute_error: 0.2394 - loss_no_weight_decay: 0.6844 - val_loss: 0.5305 - val_acc: 0.7969 - val_binary_accuracy: 0.8646 - val_mean_absolute_error: 0.2236 - val_loss_no_weight_decay: 0.5305
# — val_kappa: 0.76
#
# Epoch 00045: val_kappa improved from 0.70968 to 0.76000, saving model to base_2020-05-10-19-29-18-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[19  1  1]
#  [ 2  3  1]
#  [ 8  8  9]]
# Epoch 46/50
# 9/9 [==============================] - 23s 3s/step - loss: 0.6094 - acc: 0.7500 - binary_accuracy: 0.8339 - mean_absolute_error: 0.2511 - loss_no_weight_decay: 0.6094 - val_loss: 0.6017 - val_acc: 0.6923 - val_binary_accuracy: 0.7885 - val_mean_absolute_error: 0.2509 - val_loss_no_weight_decay: 0.6017
# — val_kappa: 0.6533864541832669
#
# Epoch 00046: val_kappa did not improve from 0.76000
# Confusion matrix:
#  [[23  1  1]
#  [ 1  4  1]
#  [ 5  6 10]]
# Epoch 47/50
# 9/9 [==============================] - 21s 2s/step - loss: 0.6590 - acc: 0.7262 - binary_accuracy: 0.8122 - mean_absolute_error: 0.2543 - loss_no_weight_decay: 0.6590 - val_loss: 0.5698 - val_acc: 0.7500 - val_binary_accuracy: 0.8490 - val_mean_absolute_error: 0.2372 - val_loss_no_weight_decay: 0.5698
# — val_kappa: 0.6265060240963856
#
# Epoch 00047: val_kappa did not improve from 0.76000
# Confusion matrix:
#  [[25  0  0]
#  [ 1  5  0]
#  [ 4  8  9]]
# Epoch 48/50
# 9/9 [==============================] - 19s 2s/step - loss: 0.6579 - acc: 0.7497 - binary_accuracy: 0.8363 - mean_absolute_error: 0.2513 - loss_no_weight_decay: 0.6579 - val_loss: 0.5863 - val_acc: 0.7115 - val_binary_accuracy: 0.8141 - val_mean_absolute_error: 0.2432 - val_loss_no_weight_decay: 0.5863
# — val_kappa: 0.6639999999999999
#
# Epoch 00048: val_kappa did not improve from 0.76000
# Confusion matrix:
#  [[24  0  2]
#  [ 2  3  1]
#  [ 7  6  7]]
# Epoch 49/50
# 9/9 [==============================] - 23s 3s/step - loss: 0.6367 - acc: 0.7535 - binary_accuracy: 0.8328 - mean_absolute_error: 0.2420 - loss_no_weight_decay: 0.6367 - val_loss: 0.5721 - val_acc: 0.7500 - val_binary_accuracy: 0.8385 - val_mean_absolute_error: 0.2247 - val_loss_no_weight_decay: 0.5721
# — val_kappa: 0.6129032258064515
#
# Epoch 00049: val_kappa did not improve from 0.76000
# Confusion matrix:
#  [[26  1  2]
#  [ 1  6  0]
#  [ 5  2  9]]
# Epoch 50/50
# 9/9 [==============================] - 21s 2s/step - loss: 0.5863 - acc: 0.7585 - binary_accuracy: 0.8414 - mean_absolute_error: 0.2329 - loss_no_weight_decay: 0.5863 - val_loss: 0.6642 - val_acc: 0.6538 - val_binary_accuracy: 0.7756 - val_mean_absolute_error: 0.2825 - val_loss_no_weight_decay: 0.6642
# — val_kappa: 0.6666666666666667
#
# Epoch 00050: val_kappa did not improve from 0.76000
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Confusion matrix:
#  [[17  1  2]
#  [ 0  6  2]
#  [ 5  6 13]]
# 176/176 [==============================] - 3s 16ms/step
# 176/176 [==============================] - 2s 9ms/step
# Test loss: 0.7405720046345695
# Test accuracy: 0.6761363636363636
# Confusion Matrix
# [[66  4 18]
#  [ 0 13  9]
#  [ 7 15 44]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.90      0.75      0.82        88
#            1       0.41      0.59      0.48        22
#            2       0.62      0.67      0.64        66
#
#     accuracy                           0.70       176
#    macro avg       0.64      0.67      0.65       176
# weighted avg       0.74      0.70      0.71       176

# %%
from Kappa_Skl import kappa
def kappa2(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    if len(y_true.shape) > 1 and y_true.shape[1] > 1:
        y_true = y_true.dot(range(y_true.shape[1]))
    if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
        y_pred = y_pred.dot(range(y_pred.shape[1]))
    try:
        return kappa(y_true, y_pred, weights='quadratic')
    except IndexError:
        return np.nan
    
print('Quadratic_wieghted_kappa')
print(kappa2(y_true, y_pred))
# Out:
# Quadratic_wieghted_kappa
# 0.5697478991596638

# %%
import numpy as np 
import matplotlib.pyplot as plt
import os
import wandb
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model loss.png')

# summarize history for val_kappa
plt.plot(history.history['val_kappa'])
plt.title('Validation_Kappa')
plt.ylabel('val_kappa')
plt.xlabel('epoch')
plt.legend([ 'validation'], loc='upper left')
plt.show()
#plt.savefig('model validation_kappa.png')

# summarize history for mean_absolute _error
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model mean_absolute_error')
plt.ylabel('mean_absolute_error')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model maey.png'
# Out:
# dict_keys(['val_loss', 'val_acc', 'val_binary_accuracy', 'val_mean_absolute_error', 'val_loss_no_weight_decay', 'loss', 'acc', 'binary_accuracy', 'mean_absolute_error', 'loss_no_weight_decay', 'val_kappa', 'lr'])
