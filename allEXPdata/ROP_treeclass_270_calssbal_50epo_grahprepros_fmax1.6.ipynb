# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, InputLayer
from keras.regularizers import L1L2, l2, l1
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from custom_pooling import RMSPooling2D
from keras.optimizers import SGD, Adam
from keras.layers import LeakyReLU
#from data import BALANCE_WEIGHTS
from keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
#import os
from datetime import datetime as dt
from custom_loss import WeightedCategoricalCrossEntropy
from VCM import VCM
from QWK import QWK
import keras.backend as K
from Fractional_MAXPOOL import FractionalPooling2D
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
def get_experiment_id():
    time_str = dt.now().strftime('%Y-%m-%d-%H-%M-%S')
    experiment_id = 'base_{}'.format(time_str)
    return experiment_id
p_ratio=[1.0, 1.44, 1.73, 1.0]

model = Sequential()


model.add(Conv2D(16, (5, 5), activation='tanh', input_shape=(270, 270, 3)))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))
model.add(FractionalPooling2D(pool_ratio=(1, 1.6, 1.6, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(16, (3, 3), activation='tanh'))
model.add(Conv2D(16, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

#model.add(LeakyReLU(alpha=0.01))


model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))


model.add(FractionalPooling2D(pool_ratio=(1, 1.6, 1.6, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))          
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
model.add(FractionalPooling2D(pool_ratio=(1, 1.6, 1.6, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(FractionalPooling2D(pool_ratio=(1, 1.6, 1.6, 1),pseudo_random = True,overlap=True))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))


model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

#model.add(MaxPooling2D(pool_size=1))




model.add(FractionalPooling2D(pool_ratio=(1, 1.7, 1.7, 1),pseudo_random = True,overlap=True))

model.add(Flatten())


#chnaged from 10 to 5 because an error 
model.add(Dense(3, activation='softmax'))

sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.count_params()
#adam = Adam(lr=0.0005, decay=1e-6)
#rmsprop
#Mloss = WeightedCategoricalCrossEntropy({0: 0.4125861396437394, 1: 1.4918664786083686, 2: 0.690426457789382, 3: 3.9541433021806855, 4: 4.885604311008468})
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['acc','binary_accuracy','mae'])
model.summary()
loss_no_weight_decay = model.total_loss - sum(model.losses)
model.metrics_tensors.append(loss_no_weight_decay)
model.metrics_names.append('loss_no_weight_decay')
#############################################################################################
#############################################################################################
#############################################################################################
#############################################################################################
#Preparing Data Augmentation Configuration 
train_datagen = ImageDataGenerator(
        rescale=1./255,
#        featurewise_center=True,
 #       samplewise_center=True,
        shear_range=0,
        zoom_range=0.0,#[1 / 1.15, 1.15],
        horizontal_flip=False,#True,
        rotation_range=0)#90,
#        validation_split=0.2)
"""
For the test set only rescale should be made 
"""
test_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/three_class_grah/train",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="training")
#    save_to_dir="D:/Separating Images into subfolders/train_augmented")


#print(train_generator.class_indices)

valid_generator = valid_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/three_class_grah/vald",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="validation")
#    save_to_dir="D:/Separating Images into subfolders/val_augmented"


test_generator = test_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/three_class_grah/test",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=1,
    class_mode="categorical",
    shuffle=False,
    seed=42)
#    save_to_dir="D:/Separating Images into subfolders/test_augmented")


# Fitting/Training the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
experiment_id = get_experiment_id()
callbacks = [
    QWK(valid_generator, STEP_SIZE_VALID),
    EarlyStopping(monitor='val_acc', patience=50, min_delta=0.001, verbose=1),
    ModelCheckpoint(experiment_id + "-val_kapa_checkpoint.hdf5", monitor='val_kappa', verbose=1, save_best_only=True, mode='max'),
    ReduceLROnPlateau(monitor='val_acc', factor=0.5, patience=7, verbose=1, mode='auto', min_delta=0.001, cooldown=0, min_lr=1e-7),
    VCM(valid_generator,STEP_SIZE_VALID)
    
]

class_weight_list = class_weight.compute_class_weight('balanced', np.unique(train_generator.classes), train_generator.classes)
class_weights = dict(zip(np.unique(train_generator.classes), class_weight_list))

history=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    class_weight=class_weights,
                    callbacks=callbacks,
                    epochs=50  
)


# Evaluating the model 
#predicting output
#reseting the test generator before calling predict_generator, in order not to get weird output
test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1', '2']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 266, 266, 16)      1216
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 262, 262, 16)      6416
# _________________________________________________________________
# fractional_pooling2d_1 (Frac (None, 163, 163, 16)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 161, 161, 16)      2320
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 159, 159, 16)      2320
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 155, 155, 16)      6416
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 151, 151, 16)      6416
# _________________________________________________________________
# fractional_pooling2d_2 (Frac (None, 94, 94, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 90, 90, 16)        6416
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 86, 86, 16)        6416
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 84, 84, 32)        4640
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 82, 82, 32)        9248
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 80, 80, 32)        9248
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 78, 78, 32)        9248
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 76, 76, 32)        9248
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 74, 74, 32)        9248
# _________________________________________________________________
# fractional_pooling2d_3 (Frac (None, 46, 46, 32)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 44, 44, 32)        9248
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 42, 42, 32)        9248
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 40, 40, 64)        18496
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 38, 38, 64)        36928
# _________________________________________________________________
# fractional_pooling2d_4 (Frac (None, 23, 23, 64)        0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 21, 21, 64)        36928
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 19, 19, 64)        36928
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 17, 17, 64)        36928
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 15, 15, 64)        36928
# _________________________________________________________________
# fractional_pooling2d_5 (Frac (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 12291
# =================================================================
# Total params: 322,739
# Trainable params: 322,739
# Non-trainable params: 0
# _________________________________________________________________
# Found 588 images belonging to 3 classes.
# Found 116 images belonging to 3 classes.
# Found 176 images belonging to 3 classes.
# Epoch 1/50
# 9/9 [==============================] - 24s 3s/step - loss: 1.1040 - acc: 0.1658 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4476 - loss_no_weight_decay: 1.1040 - val_loss: 1.0912 - val_acc: 0.4375 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4427 - val_loss_no_weight_decay: 1.0912
# — val_kappa: 0.0
#
# Epoch 00001: val_kappa improved from -inf to 0.00000, saving model to base_2020-05-10-20-39-53-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[26  0  0]
#  [ 7  0  0]
#  [19  0  0]]
# Epoch 2/50
# 9/9 [==============================] - 18s 2s/step - loss: 1.0792 - acc: 0.3625 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4438 - loss_no_weight_decay: 1.0792 - val_loss: 1.0871 - val_acc: 0.4038 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4412 - val_loss_no_weight_decay: 1.0871
# — val_kappa: 0.0
#
# Epoch 00002: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[30  0  0]
#  [ 7  0  0]
#  [15  0  0]]
# Epoch 3/50
# 9/9 [==============================] - 19s 2s/step - loss: 1.1254 - acc: 0.4809 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4386 - loss_no_weight_decay: 1.1254 - val_loss: 1.0877 - val_acc: 0.5000 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4420 - val_loss_no_weight_decay: 1.0877
# — val_kappa: 0.0
#
# Epoch 00003: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[22  0  0]
#  [ 8  0  0]
#  [22  0  0]]
# Epoch 4/50
# 9/9 [==============================] - 17s 2s/step - loss: 1.0894 - acc: 0.4156 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4464 - loss_no_weight_decay: 1.0894 - val_loss: 1.1068 - val_acc: 0.3654 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4455 - val_loss_no_weight_decay: 1.1068
# — val_kappa: 0.0
#
# Epoch 00004: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[31  0  0]
#  [ 9  0  0]
#  [12  0  0]]
# Epoch 5/50
# 9/9 [==============================] - 17s 2s/step - loss: 1.0956 - acc: 0.3632 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4447 - loss_no_weight_decay: 1.0956 - val_loss: 1.0915 - val_acc: 0.3594 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4428 - val_loss_no_weight_decay: 1.0915
# — val_kappa: 0.0
#
# Epoch 00005: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[28  0  0]
#  [ 5  0  0]
#  [19  0  0]]
# Epoch 6/50
# 9/9 [==============================] - 15s 2s/step - loss: 1.1010 - acc: 0.4905 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4385 - loss_no_weight_decay: 1.1010 - val_loss: 1.0542 - val_acc: 0.5192 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4335 - val_loss_no_weight_decay: 1.0542
# — val_kappa: 0.0
#
# Epoch 00006: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[27  0  0]
#  [ 6  0  0]
#  [19  0  0]]
# Epoch 7/50
# 9/9 [==============================] - 17s 2s/step - loss: 1.1133 - acc: 0.3094 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4431 - loss_no_weight_decay: 1.1133 - val_loss: 1.0754 - val_acc: 0.3906 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4380 - val_loss_no_weight_decay: 1.0754
# — val_kappa: 0.0
#
# Epoch 00007: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[29  0  0]
#  [ 6  0  0]
#  [17  0  0]]
# Epoch 8/50
# 9/9 [==============================] - 19s 2s/step - loss: 1.0467 - acc: 0.3576 - binary_accuracy: 0.6771 - mean_absolute_error: 0.4355 - loss_no_weight_decay: 1.0467 - val_loss: 1.0337 - val_acc: 0.4808 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4286 - val_loss_no_weight_decay: 1.0337
# — val_kappa: 0.0
#
# Epoch 00008: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[25  0  0]
#  [ 6  0  0]
#  [21  0  0]]
# Epoch 9/50
# 9/9 [==============================] - 17s 2s/step - loss: 1.0313 - acc: 0.5178 - binary_accuracy: 0.6743 - mean_absolute_error: 0.4264 - loss_no_weight_decay: 1.0313 - val_loss: 1.0004 - val_acc: 0.4688 - val_binary_accuracy: 0.7135 - val_mean_absolute_error: 0.4126 - val_loss_no_weight_decay: 1.0004
# — val_kappa: 0.3162790697674419
#
# Epoch 00009: val_kappa improved from 0.00000 to 0.31628, saving model to base_2020-05-10-20-39-53-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[26  0  0]
#  [ 8  0  0]
#  [18  0  0]]
# Epoch 10/50
# 9/9 [==============================] - 17s 2s/step - loss: 1.0913 - acc: 0.3642 - binary_accuracy: 0.6550 - mean_absolute_error: 0.4401 - loss_no_weight_decay: 1.0913 - val_loss: 0.9375 - val_acc: 0.6154 - val_binary_accuracy: 0.6795 - val_mean_absolute_error: 0.4019 - val_loss_no_weight_decay: 0.9375
# — val_kappa: 0.020725388601036232
#
# Epoch 00010: val_kappa did not improve from 0.31628
# Confusion matrix:
#  [[29  0  0]
#  [ 5  0  0]
#  [18  0  0]]
# Epoch 11/50
# 9/9 [==============================] - 17s 2s/step - loss: 1.0385 - acc: 0.4359 - binary_accuracy: 0.6637 - mean_absolute_error: 0.4293 - loss_no_weight_decay: 1.0385 - val_loss: 1.0045 - val_acc: 0.5938 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4182 - val_loss_no_weight_decay: 1.0045
# — val_kappa: 0.0
#
# Epoch 00011: val_kappa did not improve from 0.31628
# Confusion matrix:
#  [[26  0  0]
#  [ 6  0  0]
#  [20  0  0]]
# Epoch 12/50
# 9/9 [==============================] - 17s 2s/step - loss: 1.0746 - acc: 0.4479 - binary_accuracy: 0.6725 - mean_absolute_error: 0.4286 - loss_no_weight_decay: 1.0746 - val_loss: 0.9590 - val_acc: 0.5385 - val_binary_accuracy: 0.7372 - val_mean_absolute_error: 0.4051 - val_loss_no_weight_decay: 0.9590
# — val_kappa: 0.18719211822660098
#
# Epoch 00012: val_kappa did not improve from 0.31628
# Confusion matrix:
#  [[23  0  0]
#  [ 6  0  0]
#  [23  0  0]]
# Epoch 13/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.9669 - acc: 0.5276 - binary_accuracy: 0.7041 - mean_absolute_error: 0.4031 - loss_no_weight_decay: 0.9669 - val_loss: 0.8895 - val_acc: 0.5625 - val_binary_accuracy: 0.7188 - val_mean_absolute_error: 0.3832 - val_loss_no_weight_decay: 0.8895
# — val_kappa: 0.12621359223300976
#
# Epoch 00013: val_kappa did not improve from 0.31628
# Confusion matrix:
#  [[27  0  1]
#  [ 5  0  0]
#  [16  1  2]]
# Epoch 14/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.9697 - acc: 0.5193 - binary_accuracy: 0.7017 - mean_absolute_error: 0.3945 - loss_no_weight_decay: 0.9697 - val_loss: 0.8881 - val_acc: 0.5000 - val_binary_accuracy: 0.7436 - val_mean_absolute_error: 0.3802 - val_loss_no_weight_decay: 0.8881
# — val_kappa: 0.3207547169811321
#
# Epoch 00014: val_kappa improved from 0.31628 to 0.32075, saving model to base_2020-05-10-20-39-53-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[26  1  0]
#  [ 6  1  0]
#  [16  2  0]]
# Epoch 15/50
# 9/9 [==============================] - 19s 2s/step - loss: 0.9501 - acc: 0.4653 - binary_accuracy: 0.7118 - mean_absolute_error: 0.3939 - loss_no_weight_decay: 0.9501 - val_loss: 0.8921 - val_acc: 0.5469 - val_binary_accuracy: 0.7448 - val_mean_absolute_error: 0.3735 - val_loss_no_weight_decay: 0.8921
# — val_kappa: 0.34545454545454546
#
# Epoch 00015: val_kappa improved from 0.32075 to 0.34545, saving model to base_2020-05-10-20-39-53-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[29  1  1]
#  [ 3  3  0]
#  [14  1  0]]
# Epoch 16/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.9049 - acc: 0.5226 - binary_accuracy: 0.7238 - mean_absolute_error: 0.3702 - loss_no_weight_decay: 0.9049 - val_loss: 0.8253 - val_acc: 0.5000 - val_binary_accuracy: 0.7436 - val_mean_absolute_error: 0.3402 - val_loss_no_weight_decay: 0.8253
# — val_kappa: 0.31759656652360524
#
# Epoch 00016: val_kappa did not improve from 0.34545
# Confusion matrix:
#  [[27  0  0]
#  [ 4  3  0]
#  [10  8  0]]
# Epoch 17/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.8888 - acc: 0.5138 - binary_accuracy: 0.7027 - mean_absolute_error: 0.3653 - loss_no_weight_decay: 0.8888 - val_loss: 0.7817 - val_acc: 0.5156 - val_binary_accuracy: 0.7708 - val_mean_absolute_error: 0.3262 - val_loss_no_weight_decay: 0.7817
# — val_kappa: 0.3677130044843048
#
# Epoch 00017: val_kappa improved from 0.34545 to 0.36771, saving model to base_2020-05-10-20-39-53-val_kapa_checkpoint.hdf5
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Confusion matrix:
#  [[23  0  1]
#  [ 7  0  0]
#  [21  0  0]]
# Epoch 18/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.8412 - acc: 0.5418 - binary_accuracy: 0.7407 - mean_absolute_error: 0.3428 - loss_no_weight_decay: 0.8412 - val_loss: 0.8815 - val_acc: 0.5192 - val_binary_accuracy: 0.7051 - val_mean_absolute_error: 0.3551 - val_loss_no_weight_decay: 0.8815
# — val_kappa: 0.2845188284518828
#
# Epoch 00018: val_kappa did not improve from 0.36771
# Confusion matrix:
#  [[21  2  0]
#  [ 1  8  0]
#  [ 6 14  0]]
# Epoch 19/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.8798 - acc: 0.4865 - binary_accuracy: 0.6839 - mean_absolute_error: 0.3674 - loss_no_weight_decay: 0.8798 - val_loss: 0.8129 - val_acc: 0.5625 - val_binary_accuracy: 0.7448 - val_mean_absolute_error: 0.3230 - val_loss_no_weight_decay: 0.8129
# — val_kappa: 0.35242290748898686
#
# Epoch 00019: val_kappa did not improve from 0.36771
# Confusion matrix:
#  [[21  0  3]
#  [ 5  2  0]
#  [18  1  2]]
# Epoch 20/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.8620 - acc: 0.5276 - binary_accuracy: 0.7363 - mean_absolute_error: 0.3482 - loss_no_weight_decay: 0.8620 - val_loss: 0.8103 - val_acc: 0.5000 - val_binary_accuracy: 0.7179 - val_mean_absolute_error: 0.3457 - val_loss_no_weight_decay: 0.8103
# — val_kappa: 0.42152466367713004
#
# Epoch 00020: val_kappa improved from 0.36771 to 0.42152, saving model to base_2020-05-10-20-39-53-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[24  0  0]
#  [ 5  2  0]
#  [19  2  0]]
# Epoch 21/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.8295 - acc: 0.5559 - binary_accuracy: 0.7410 - mean_absolute_error: 0.3388 - loss_no_weight_decay: 0.8295 - val_loss: 0.8050 - val_acc: 0.5469 - val_binary_accuracy: 0.7448 - val_mean_absolute_error: 0.3193 - val_loss_no_weight_decay: 0.8050
# — val_kappa: 0.35344827586206884
#
# Epoch 00021: val_kappa did not improve from 0.42152
# Confusion matrix:
#  [[19  0  2]
#  [ 4  5  0]
#  [15  6  1]]
# Epoch 22/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.8279 - acc: 0.5265 - binary_accuracy: 0.7278 - mean_absolute_error: 0.3400 - loss_no_weight_decay: 0.8279 - val_loss: 0.8151 - val_acc: 0.5577 - val_binary_accuracy: 0.7308 - val_mean_absolute_error: 0.3316 - val_loss_no_weight_decay: 0.8151
# — val_kappa: 0.3999999999999999
#
# Epoch 00022: val_kappa did not improve from 0.42152
# Confusion matrix:
#  [[19  2  2]
#  [ 2  5  0]
#  [13  9  0]]
# Epoch 23/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.8737 - acc: 0.5075 - binary_accuracy: 0.7035 - mean_absolute_error: 0.3511 - loss_no_weight_decay: 0.8737 - val_loss: 0.7050 - val_acc: 0.6094 - val_binary_accuracy: 0.7656 - val_mean_absolute_error: 0.2935 - val_loss_no_weight_decay: 0.7050
# — val_kappa: 0.31168831168831157
#
# Epoch 00023: val_kappa did not improve from 0.42152
# Confusion matrix:
#  [[25  0  1]
#  [ 5  3  0]
#  [12  6  0]]
# Epoch 24/50
# 9/9 [==============================] - 19s 2s/step - loss: 0.8307 - acc: 0.5156 - binary_accuracy: 0.7205 - mean_absolute_error: 0.3365 - loss_no_weight_decay: 0.8307 - val_loss: 0.8484 - val_acc: 0.4808 - val_binary_accuracy: 0.7244 - val_mean_absolute_error: 0.3351 - val_loss_no_weight_decay: 0.8484
# — val_kappa: 0.3362831858407078
#
# Epoch 00024: val_kappa did not improve from 0.42152
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Confusion matrix:
#  [[24  1  0]
#  [ 1  4  0]
#  [14  7  1]]
# Epoch 25/50
# 9/9 [==============================] - 15s 2s/step - loss: 0.7941 - acc: 0.5671 - binary_accuracy: 0.7405 - mean_absolute_error: 0.3315 - loss_no_weight_decay: 0.7941 - val_loss: 0.7619 - val_acc: 0.5938 - val_binary_accuracy: 0.7552 - val_mean_absolute_error: 0.3123 - val_loss_no_weight_decay: 0.7619
# — val_kappa: 0.3948497854077253
#
# Epoch 00025: val_kappa did not improve from 0.42152
# Confusion matrix:
#  [[20  1  4]
#  [ 3  3  0]
#  [16  3  2]]
# Epoch 26/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.8227 - acc: 0.5714 - binary_accuracy: 0.7497 - mean_absolute_error: 0.3301 - loss_no_weight_decay: 0.8227 - val_loss: 0.8394 - val_acc: 0.4615 - val_binary_accuracy: 0.7051 - val_mean_absolute_error: 0.3395 - val_loss_no_weight_decay: 0.8394
# — val_kappa: 0.4358974358974358
#
# Epoch 00026: val_kappa improved from 0.42152 to 0.43590, saving model to base_2020-05-10-20-39-53-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[24  1  1]
#  [ 1  7  0]
#  [ 5 13  0]]
# Epoch 27/50
# 9/9 [==============================] - 19s 2s/step - loss: 0.8419 - acc: 0.5174 - binary_accuracy: 0.7106 - mean_absolute_error: 0.3415 - loss_no_weight_decay: 0.8419 - val_loss: 0.8529 - val_acc: 0.5156 - val_binary_accuracy: 0.6875 - val_mean_absolute_error: 0.3425 - val_loss_no_weight_decay: 0.8529
# — val_kappa: 0.19753086419753096
#
# Epoch 00027: val_kappa did not improve from 0.43590
# Confusion matrix:
#  [[25  1  1]
#  [ 0  7  0]
#  [ 2 14  2]]
# Epoch 28/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.7825 - acc: 0.5819 - binary_accuracy: 0.7447 - mean_absolute_error: 0.3278 - loss_no_weight_decay: 0.7825 - val_loss: 0.8530 - val_acc: 0.5192 - val_binary_accuracy: 0.7179 - val_mean_absolute_error: 0.3421 - val_loss_no_weight_decay: 0.8530
# — val_kappa: 0.4453781512605042
#
# Epoch 00028: val_kappa improved from 0.43590 to 0.44538, saving model to base_2020-05-10-20-39-53-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[19  0  4]
#  [ 4  2  0]
#  [21  1  1]]
# Epoch 29/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.7881 - acc: 0.6102 - binary_accuracy: 0.7494 - mean_absolute_error: 0.3277 - loss_no_weight_decay: 0.7881 - val_loss: 0.8497 - val_acc: 0.5312 - val_binary_accuracy: 0.7396 - val_mean_absolute_error: 0.3289 - val_loss_no_weight_decay: 0.8497
# — val_kappa: 0.4152542372881356
#
# Epoch 00029: val_kappa did not improve from 0.44538
# Confusion matrix:
#  [[23  2  2]
#  [ 1  6  0]
#  [11  7  0]]
# Epoch 30/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.8137 - acc: 0.5752 - binary_accuracy: 0.7406 - mean_absolute_error: 0.3279 - loss_no_weight_decay: 0.8137 - val_loss: 0.8454 - val_acc: 0.5000 - val_binary_accuracy: 0.7051 - val_mean_absolute_error: 0.3326 - val_loss_no_weight_decay: 0.8454
# — val_kappa: 0.4049586776859504
#
# Epoch 00030: val_kappa did not improve from 0.44538
# Confusion matrix:
#  [[21  2  0]
#  [ 1  6  0]
#  [ 8 12  2]]
# Epoch 31/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.7653 - acc: 0.5333 - binary_accuracy: 0.7261 - mean_absolute_error: 0.3244 - loss_no_weight_decay: 0.7653 - val_loss: 0.7553 - val_acc: 0.6094 - val_binary_accuracy: 0.7865 - val_mean_absolute_error: 0.3016 - val_loss_no_weight_decay: 0.7553
# — val_kappa: 0.38493723849372385
#
# Epoch 00031: val_kappa did not improve from 0.44538
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Confusion matrix:
#  [[25  1  1]
#  [ 1  2  0]
#  [12  9  1]]
# Epoch 32/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.7773 - acc: 0.5924 - binary_accuracy: 0.7482 - mean_absolute_error: 0.3183 - loss_no_weight_decay: 0.7773 - val_loss: 0.8508 - val_acc: 0.5192 - val_binary_accuracy: 0.6987 - val_mean_absolute_error: 0.3478 - val_loss_no_weight_decay: 0.8508
# — val_kappa: 0.3076923076923076
#
# Epoch 00032: val_kappa did not improve from 0.44538
# Confusion matrix:
#  [[20  1  1]
#  [ 2  7  0]
#  [12  9  0]]
# Epoch 33/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.8035 - acc: 0.5689 - binary_accuracy: 0.7264 - mean_absolute_error: 0.3269 - loss_no_weight_decay: 0.8035 - val_loss: 0.7557 - val_acc: 0.5625 - val_binary_accuracy: 0.7552 - val_mean_absolute_error: 0.3063 - val_loss_no_weight_decay: 0.7557
# — val_kappa: 0.2749999999999998
#
# Epoch 00033: val_kappa did not improve from 0.44538
# Confusion matrix:
#  [[24  3  0]
#  [ 1  6  0]
#  [ 9  7  2]]
# Epoch 34/50
# 9/9 [==============================] - 19s 2s/step - loss: 0.7723 - acc: 0.5694 - binary_accuracy: 0.7494 - mean_absolute_error: 0.3203 - loss_no_weight_decay: 0.7723 - val_loss: 0.7925 - val_acc: 0.5385 - val_binary_accuracy: 0.7436 - val_mean_absolute_error: 0.3270 - val_loss_no_weight_decay: 0.7925
# — val_kappa: 0.43103448275862055
#
# Epoch 00034: val_kappa did not improve from 0.44538
# Confusion matrix:
#  [[26  0  2]
#  [ 2  4  0]
#  [ 6 12  0]]
# Epoch 35/50
# 9/9 [==============================] - 15s 2s/step - loss: 0.7762 - acc: 0.5789 - binary_accuracy: 0.7459 - mean_absolute_error: 0.3208 - loss_no_weight_decay: 0.7762 - val_loss: 0.7042 - val_acc: 0.6094 - val_binary_accuracy: 0.7969 - val_mean_absolute_error: 0.2956 - val_loss_no_weight_decay: 0.7042
# — val_kappa: 0.3433476394849786
#
# Epoch 00035: val_kappa did not improve from 0.44538
# Confusion matrix:
#  [[29  2  0]
#  [ 0  3  0]
#  [11  6  1]]
# Epoch 36/50
# 9/9 [==============================] - 19s 2s/step - loss: 0.7583 - acc: 0.5729 - binary_accuracy: 0.7459 - mean_absolute_error: 0.3168 - loss_no_weight_decay: 0.7583 - val_loss: 0.8999 - val_acc: 0.4231 - val_binary_accuracy: 0.6795 - val_mean_absolute_error: 0.3446 - val_loss_no_weight_decay: 0.8999
# — val_kappa: 0.39495798319327724
#
# Epoch 00036: val_kappa did not improve from 0.44538
# Confusion matrix:
#  [[21  1  1]
#  [ 1  7  0]
#  [ 8 12  1]]
# Epoch 37/50
# 9/9 [==============================] - 16s 2s/step - loss: 0.8006 - acc: 0.5700 - binary_accuracy: 0.7327 - mean_absolute_error: 0.3292 - loss_no_weight_decay: 0.8006 - val_loss: 0.6940 - val_acc: 0.5938 - val_binary_accuracy: 0.7552 - val_mean_absolute_error: 0.2916 - val_loss_no_weight_decay: 0.6940
# — val_kappa: 0.430379746835443
#
# Epoch 00037: val_kappa did not improve from 0.44538
# Confusion matrix:
#  [[20  3  0]
#  [ 2  5  0]
#  [15  7  0]]
# Epoch 38/50
# 9/9 [==============================] - 19s 2s/step - loss: 0.7668 - acc: 0.6007 - binary_accuracy: 0.7529 - mean_absolute_error: 0.3147 - loss_no_weight_decay: 0.7668 - val_loss: 0.8180 - val_acc: 0.5192 - val_binary_accuracy: 0.7564 - val_mean_absolute_error: 0.3262 - val_loss_no_weight_decay: 0.8180
# — val_kappa: 0.41004184100418406
#
# Epoch 00038: val_kappa did not improve from 0.44538
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Confusion matrix:
#  [[22  3  1]
#  [ 1  7  0]
#  [ 6 11  1]]
# Epoch 39/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.7649 - acc: 0.5596 - binary_accuracy: 0.7274 - mean_absolute_error: 0.3223 - loss_no_weight_decay: 0.7649 - val_loss: 0.8394 - val_acc: 0.5312 - val_binary_accuracy: 0.7292 - val_mean_absolute_error: 0.3308 - val_loss_no_weight_decay: 0.8394
# — val_kappa: 0.2904564315352697
#
# Epoch 00039: val_kappa did not improve from 0.44538
# Confusion matrix:
#  [[26  1  2]
#  [ 1  7  0]
#  [ 5 10  0]]
# Epoch 40/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.7862 - acc: 0.5769 - binary_accuracy: 0.7356 - mean_absolute_error: 0.3248 - loss_no_weight_decay: 0.7862 - val_loss: 0.7104 - val_acc: 0.5769 - val_binary_accuracy: 0.7692 - val_mean_absolute_error: 0.2888 - val_loss_no_weight_decay: 0.7104
# — val_kappa: 0.4691358024691358
#
# Epoch 00040: val_kappa improved from 0.44538 to 0.46914, saving model to base_2020-05-10-20-39-53-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[16  0  2]
#  [ 2  9  0]
#  [12 11  0]]
# Epoch 41/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.8029 - acc: 0.6115 - binary_accuracy: 0.7574 - mean_absolute_error: 0.3113 - loss_no_weight_decay: 0.8029 - val_loss: 0.8197 - val_acc: 0.5000 - val_binary_accuracy: 0.7396 - val_mean_absolute_error: 0.3176 - val_loss_no_weight_decay: 0.8197
# — val_kappa: 0.3755102040816326
#
# Epoch 00041: val_kappa did not improve from 0.46914
# Confusion matrix:
#  [[27  1  0]
#  [ 1  3  0]
#  [ 3 16  1]]
# Epoch 42/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.7843 - acc: 0.5491 - binary_accuracy: 0.7100 - mean_absolute_error: 0.3335 - loss_no_weight_decay: 0.7843 - val_loss: 0.8074 - val_acc: 0.5385 - val_binary_accuracy: 0.7244 - val_mean_absolute_error: 0.3204 - val_loss_no_weight_decay: 0.8074
# — val_kappa: 0.2941176470588235
#
# Epoch 00042: val_kappa did not improve from 0.46914
# Confusion matrix:
#  [[28  1  0]
#  [ 1  5  0]
#  [ 3 13  1]]
# Epoch 43/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.7851 - acc: 0.5566 - binary_accuracy: 0.7338 - mean_absolute_error: 0.3251 - loss_no_weight_decay: 0.7851 - val_loss: 0.7037 - val_acc: 0.6250 - val_binary_accuracy: 0.7812 - val_mean_absolute_error: 0.2910 - val_loss_no_weight_decay: 0.7037
# — val_kappa: 0.3697478991596638
#
# Epoch 00043: val_kappa did not improve from 0.46914
# Confusion matrix:
#  [[23  2  4]
#  [ 0  4  0]
#  [10  8  1]]
# Epoch 44/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.7640 - acc: 0.5666 - binary_accuracy: 0.7361 - mean_absolute_error: 0.3224 - loss_no_weight_decay: 0.7640 - val_loss: 0.7983 - val_acc: 0.5000 - val_binary_accuracy: 0.6859 - val_mean_absolute_error: 0.3235 - val_loss_no_weight_decay: 0.7983
# — val_kappa: 0.3096234309623431
#
# Epoch 00044: val_kappa did not improve from 0.46914
# Confusion matrix:
#  [[21  1  3]
#  [ 1  5  0]
#  [12  7  2]]
# Epoch 45/50
# 9/9 [==============================] - 19s 2s/step - loss: 0.7694 - acc: 0.5972 - binary_accuracy: 0.7541 - mean_absolute_error: 0.3181 - loss_no_weight_decay: 0.7694 - val_loss: 0.7862 - val_acc: 0.5156 - val_binary_accuracy: 0.7552 - val_mean_absolute_error: 0.3084 - val_loss_no_weight_decay: 0.7862
# — val_kappa: 0.4999999999999999
#
# Epoch 00045: val_kappa improved from 0.46914 to 0.50000, saving model to base_2020-05-10-20-39-53-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[18  1  2]
#  [ 3  3  0]
#  [12 11  2]]
# Epoch 46/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.8101 - acc: 0.5614 - binary_accuracy: 0.7347 - mean_absolute_error: 0.3239 - loss_no_weight_decay: 0.8101 - val_loss: 0.7549 - val_acc: 0.5577 - val_binary_accuracy: 0.7500 - val_mean_absolute_error: 0.3062 - val_loss_no_weight_decay: 0.7549
# — val_kappa: 0.40485829959514175
#
# Epoch 00046: val_kappa did not improve from 0.50000
# Confusion matrix:
#  [[23  2  0]
#  [ 0  6  0]
#  [ 7 14  0]]
# Epoch 47/50
# 9/9 [==============================] - 15s 2s/step - loss: 0.7436 - acc: 0.5924 - binary_accuracy: 0.7466 - mean_absolute_error: 0.3150 - loss_no_weight_decay: 0.7436 - val_loss: 0.8079 - val_acc: 0.4844 - val_binary_accuracy: 0.7135 - val_mean_absolute_error: 0.3210 - val_loss_no_weight_decay: 0.8079
# — val_kappa: 0.3589743589743588
#
# Epoch 00047: val_kappa did not improve from 0.50000
# Confusion matrix:
#  [[24  0  1]
#  [ 0  6  0]
#  [10  9  2]]
# Epoch 48/50
# 9/9 [==============================] - 19s 2s/step - loss: 0.7532 - acc: 0.6042 - binary_accuracy: 0.7569 - mean_absolute_error: 0.3080 - loss_no_weight_decay: 0.7532 - val_loss: 0.6683 - val_acc: 0.5769 - val_binary_accuracy: 0.7436 - val_mean_absolute_error: 0.2863 - val_loss_no_weight_decay: 0.6683
# — val_kappa: 0.3305785123966942
#
# Epoch 00048: val_kappa did not improve from 0.50000
# Confusion matrix:
#  [[26  0  0]
#  [ 1  5  0]
#  [ 5 15  0]]
# Epoch 49/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.7869 - acc: 0.5599 - binary_accuracy: 0.7281 - mean_absolute_error: 0.3276 - loss_no_weight_decay: 0.7869 - val_loss: 0.8260 - val_acc: 0.5156 - val_binary_accuracy: 0.7083 - val_mean_absolute_error: 0.3213 - val_loss_no_weight_decay: 0.8260
# — val_kappa: 0.37446808510638296
#
# Epoch 00049: val_kappa did not improve from 0.50000
# Confusion matrix:
#  [[25  1  3]
#  [ 2  5  0]
#  [ 5  9  2]]
# Epoch 50/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.7793 - acc: 0.5736 - binary_accuracy: 0.7430 - mean_absolute_error: 0.3218 - loss_no_weight_decay: 0.7793 - val_loss: 0.8178 - val_acc: 0.5385 - val_binary_accuracy: 0.7436 - val_mean_absolute_error: 0.3082 - val_loss_no_weight_decay: 0.8178
# — val_kappa: 0.4201680672268908
#
# Epoch 00050: val_kappa did not improve from 0.50000
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Confusion matrix:
#  [[19  1  0]
#  [ 2  6  0]
#  [10 13  1]]
# 176/176 [==============================] - 1s 8ms/step
# 176/176 [==============================] - 1s 8ms/step
# Test loss: 0.8403493170838126
# Test accuracy: 0.5454545454545454
# Confusion Matrix
# [[60 14 14]
#  [ 0 15  7]
#  [11 29 26]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.85      0.68      0.75        88
#            1       0.26      0.68      0.38        22
#            2       0.55      0.39      0.46        66
#
#     accuracy                           0.57       176
#    macro avg       0.55      0.59      0.53       176
# weighted avg       0.66      0.57      0.60       176

# %%
from Kappa_Skl import kappa
def kappa2(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    if len(y_true.shape) > 1 and y_true.shape[1] > 1:
        y_true = y_true.dot(range(y_true.shape[1]))
    if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
        y_pred = y_pred.dot(range(y_pred.shape[1]))
    try:
        return kappa(y_true, y_pred, weights='quadratic')
    except IndexError:
        return np.nan
    
print('Quadratic_wieghted_kappa')
print(kappa2(y_true, y_pred))
# Out:
# Quadratic_wieghted_kappa
# 0.43609022556390975

# %%
import numpy as np 
import matplotlib.pyplot as plt
import os
import wandb
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model loss.png')

# summarize history for val_kappa
plt.plot(history.history['val_kappa'])
plt.title('Validation_Kappa')
plt.ylabel('val_kappa')
plt.xlabel('epoch')
plt.legend([ 'validation'], loc='upper left')
plt.show()
#plt.savefig('model validation_kappa.png')

# summarize history for mean_absolute _error
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model mean_absolute_error')
plt.ylabel('mean_absolute_error')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model maey.png'
# Out:
# dict_keys(['val_loss', 'val_acc', 'val_binary_accuracy', 'val_mean_absolute_error', 'val_loss_no_weight_decay', 'loss', 'acc', 'binary_accuracy', 'mean_absolute_error', 'loss_no_weight_decay', 'val_kappa', 'lr'])
