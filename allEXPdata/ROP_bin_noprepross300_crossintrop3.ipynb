# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, InputLayer
from keras.regularizers import L1L2, l2, l1
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from custom_pooling import RMSPooling2D
from keras.optimizers import SGD, Adam
from keras.layers import LeakyReLU
#from data import BALANCE_WEIGHTS
from keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
#import os
from datetime import datetime as dt
from custom_loss import WeightedCategoricalCrossEntropy
from VCM import VCM
import keras.backend as K
from Fractional_MAXPOOL import FractionalPooling2D
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
def get_experiment_id():
    time_str = dt.now().strftime('%Y-%m-%d-%H-%M-%S')
    experiment_id = 'base_{}'.format(time_str)
    return experiment_id
p_ratio=[1.0, 1.44, 1.73, 1.0]

model = Sequential()


model.add(Conv2D(16, (5, 5), activation='tanh', input_shape=(300, 300, 3)))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(16, (3, 3), activation='tanh'))
model.add(Conv2D(16, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))

#model.add(LeakyReLU(alpha=0.01))


model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))



model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))          
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))
#model.add(MaxPooling2D(pool_size=1))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Flatten())


#chnaged from 10 to 5 because an error 
model.add(Dense(2, activation='softmax'))

sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.count_params()
#adam = Adam(lr=0.0005, decay=1e-6)
#rmsprop
#Mloss = WeightedCategoricalCrossEntropy({0: 0.4125861396437394, 1: 1.4918664786083686, 2: 0.690426457789382, 3: 3.9541433021806855, 4: 4.885604311008468})
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['mae','acc'])
model.summary()
loss_no_weight_decay = model.total_loss - sum(model.losses)
model.metrics_tensors.append(loss_no_weight_decay)
model.metrics_names.append('loss_no_weight_decay')
#############################################################################################
#############################################################################################
#############################################################################################
#############################################################################################
#Preparing Data Augmentation Configuration 
train_datagen = ImageDataGenerator(
        rescale=1./255,
#        featurewise_center=True,
 #       samplewise_center=True,
        shear_range=0,
        zoom_range=0.0,#[1 / 1.15, 1.15],
        horizontal_flip=False,#True,
        rotation_range=0)#90,
#        validation_split=0.2)
"""
For the test set only rescale should be made 
"""
test_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas/train",
    target_size=(300, 300),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="training")
#    save_to_dir="D:/Separating Images into subfolders/train_augmented")


#print(train_generator.class_indices)

valid_generator = valid_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas/vald",
    target_size=(300, 300),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="validation")
#    save_to_dir="D:/Separating Images into subfolders/val_augmented"


test_generator = test_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas/test",
    target_size=(300, 300),
    color_mode="rgb",
    batch_size=1,
    class_mode="categorical",
    shuffle=False,
    seed=42)
#    save_to_dir="D:/Separating Images into subfolders/test_augmented")


# Fitting/Training the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
experiment_id = get_experiment_id()
callbacks = [
    EarlyStopping(monitor='val_acc', patience=50, min_delta=0.001, verbose=1),
    ModelCheckpoint(experiment_id + "-val_acc_checkpoint.hdf5", monitor='val_acc', verbose=1, save_best_only=True, mode='auto'),
    ReduceLROnPlateau(monitor='val_acc', factor=0.5, patience=7, verbose=1, mode='auto', min_delta=0.001, cooldown=0, min_lr=1e-7),
    VCM(valid_generator,STEP_SIZE_VALID)
    
]

class_weight_list = class_weight.compute_class_weight('balanced', np.unique(train_generator.classes), train_generator.classes)
class_weights = dict(zip(np.unique(train_generator.classes), class_weight_list))

history=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    #class_weight=class_weights,
                    callbacks=callbacks,
                    epochs=35  
)


# Evaluating the model 
#predicting output
#reseting the test generator before calling predict_generator, in order not to get weird output
test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 296, 296, 16)      1216
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 292, 292, 16)      6416
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 290, 290, 16)      2320
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 288, 288, 16)      2320
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 284, 284, 16)      6416
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 280, 280, 16)      6416
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 276, 276, 16)      6416
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 272, 272, 16)      6416
# _________________________________________________________________
# fractional_pooling2d_1 (Frac (None, 151, 151, 16)      0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 149, 149, 32)      4640
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 147, 147, 32)      9248
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 145, 145, 32)      9248
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 143, 143, 32)      9248
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 141, 141, 32)      9248
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 139, 139, 32)      9248
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 137, 137, 32)      9248
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 135, 135, 32)      9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 67, 67, 32)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 65, 65, 64)        18496
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 63, 63, 64)        36928
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 61, 61, 64)        36928
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 59, 59, 64)        36928
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 57, 57, 64)        36928
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 55, 55, 64)        36928
# _________________________________________________________________
# fractional_pooling2d_2 (Frac (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 28, 28, 64)        36928
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 26, 26, 64)        36928
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 24, 24, 64)        36928
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 22, 22, 64)        36928
# _________________________________________________________________
# fractional_pooling2d_3 (Frac (None, 12, 12, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 9216)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 18434
# =================================================================
# Total params: 476,594
# Trainable params: 476,594
# Non-trainable params: 0
# _________________________________________________________________
# Found 588 images belonging to 2 classes.
# Found 116 images belonging to 2 classes.
# Found 176 images belonging to 2 classes.
# Epoch 1/35
# 9/9 [==============================] - 39s 4s/step - loss: 0.6892 - mean_absolute_error: 0.4978 - acc: 0.5699 - loss_no_weight_decay: 0.6892 - val_loss: 0.6868 - val_mean_absolute_error: 0.4963 - val_acc: 0.5000 - val_loss_no_weight_decay: 0.6868
#
# Epoch 00001: val_acc improved from -inf to 0.50000, saving model to base_2020-05-08-02-07-47-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[22 10]
#  [17 15]]
# Epoch 2/35
# 9/9 [==============================] - 26s 3s/step - loss: 0.6785 - mean_absolute_error: 0.4917 - acc: 0.6117 - loss_no_weight_decay: 0.6785 - val_loss: 0.6469 - val_mean_absolute_error: 0.4676 - val_acc: 0.5962 - val_loss_no_weight_decay: 0.6469
#
# Epoch 00002: val_acc improved from 0.50000 to 0.59615, saving model to base_2020-05-08-02-07-47-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[ 0 26]
#  [ 0 26]]
# Epoch 3/35
# 9/9 [==============================] - 26s 3s/step - loss: 0.6555 - mean_absolute_error: 0.4735 - acc: 0.6094 - loss_no_weight_decay: 0.6555 - val_loss: 0.6352 - val_mean_absolute_error: 0.4374 - val_acc: 0.6562 - val_loss_no_weight_decay: 0.6352
#
# Epoch 00003: val_acc improved from 0.59615 to 0.65625, saving model to base_2020-05-08-02-07-47-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[ 8 20]
#  [ 1 35]]
# Epoch 4/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.6792 - mean_absolute_error: 0.4687 - acc: 0.6288 - loss_no_weight_decay: 0.6792 - val_loss: 0.6088 - val_mean_absolute_error: 0.4511 - val_acc: 0.7500 - val_loss_no_weight_decay: 0.6088
#
# Epoch 00004: val_acc improved from 0.65625 to 0.75000, saving model to base_2020-05-08-02-07-47-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[17  8]
#  [ 4 23]]
# Epoch 5/35
# 9/9 [==============================] - 21s 2s/step - loss: 0.6068 - mean_absolute_error: 0.4406 - acc: 0.6732 - loss_no_weight_decay: 0.6068 - val_loss: 0.5341 - val_mean_absolute_error: 0.3940 - val_acc: 0.7969 - val_loss_no_weight_decay: 0.5341
#
# Epoch 00005: val_acc improved from 0.75000 to 0.79688, saving model to base_2020-05-08-02-07-47-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[19 11]
#  [ 7 27]]
# Epoch 6/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.5635 - mean_absolute_error: 0.3926 - acc: 0.7114 - loss_no_weight_decay: 0.5635 - val_loss: 0.5358 - val_mean_absolute_error: 0.3871 - val_acc: 0.7308 - val_loss_no_weight_decay: 0.5358
#
# Epoch 00006: val_acc did not improve from 0.79688
# Confusion matrix:
#  [[23  8]
#  [ 4 17]]
# Epoch 7/35
# 9/9 [==============================] - 25s 3s/step - loss: 0.5227 - mean_absolute_error: 0.3723 - acc: 0.7448 - loss_no_weight_decay: 0.5227 - val_loss: 0.4899 - val_mean_absolute_error: 0.3493 - val_acc: 0.8125 - val_loss_no_weight_decay: 0.4899
#
# Epoch 00007: val_acc improved from 0.79688 to 0.81250, saving model to base_2020-05-08-02-07-47-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[17 13]
#  [ 6 28]]
# Epoch 8/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.5420 - mean_absolute_error: 0.3608 - acc: 0.7250 - loss_no_weight_decay: 0.5420 - val_loss: 0.5503 - val_mean_absolute_error: 0.3843 - val_acc: 0.7115 - val_loss_no_weight_decay: 0.5503
#
# Epoch 00008: val_acc did not improve from 0.81250
# Confusion matrix:
#  [[16 10]
#  [ 5 21]]
# Epoch 9/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.5292 - mean_absolute_error: 0.3691 - acc: 0.7094 - loss_no_weight_decay: 0.5292 - val_loss: 0.4781 - val_mean_absolute_error: 0.3444 - val_acc: 0.7969 - val_loss_no_weight_decay: 0.4781
#
# Epoch 00009: val_acc did not improve from 0.81250
# Confusion matrix:
#  [[18 13]
#  [ 5 28]]
# Epoch 10/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.5013 - mean_absolute_error: 0.3518 - acc: 0.7395 - loss_no_weight_decay: 0.5013 - val_loss: 0.4971 - val_mean_absolute_error: 0.3409 - val_acc: 0.7885 - val_loss_no_weight_decay: 0.4971
#
# Epoch 00010: val_acc did not improve from 0.81250
# Confusion matrix:
#  [[18  8]
#  [ 4 22]]
# Epoch 11/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.4755 - mean_absolute_error: 0.3256 - acc: 0.7708 - loss_no_weight_decay: 0.4755 - val_loss: 0.4604 - val_mean_absolute_error: 0.3321 - val_acc: 0.8125 - val_loss_no_weight_decay: 0.4604
#
# Epoch 00011: val_acc did not improve from 0.81250
# Confusion matrix:
#  [[19 11]
#  [ 1 33]]
# Epoch 12/35
# 9/9 [==============================] - 24s 3s/step - loss: 0.6347 - mean_absolute_error: 0.3988 - acc: 0.6689 - loss_no_weight_decay: 0.6347 - val_loss: 0.6768 - val_mean_absolute_error: 0.4273 - val_acc: 0.5192 - val_loss_no_weight_decay: 0.6768
#
# Epoch 00012: val_acc did not improve from 0.81250
# Confusion matrix:
#  [[32  0]
#  [20  0]]
# Epoch 13/35
# 9/9 [==============================] - 24s 3s/step - loss: 0.5668 - mean_absolute_error: 0.3970 - acc: 0.6779 - loss_no_weight_decay: 0.5668 - val_loss: 0.5465 - val_mean_absolute_error: 0.3970 - val_acc: 0.7344 - val_loss_no_weight_decay: 0.5465
#
# Epoch 00013: val_acc did not improve from 0.81250
# Confusion matrix:
#  [[17 15]
#  [ 4 28]]
# Epoch 14/35
# 9/9 [==============================] - 27s 3s/step - loss: 0.4933 - mean_absolute_error: 0.3494 - acc: 0.7587 - loss_no_weight_decay: 0.4933 - val_loss: 0.4053 - val_mean_absolute_error: 0.2906 - val_acc: 0.8269 - val_loss_no_weight_decay: 0.4053
#
# Epoch 00014: val_acc improved from 0.81250 to 0.82692, saving model to base_2020-05-08-02-07-47-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[21  6]
#  [ 3 22]]
# Epoch 15/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.4221 - mean_absolute_error: 0.3018 - acc: 0.8150 - loss_no_weight_decay: 0.4221 - val_loss: 0.4462 - val_mean_absolute_error: 0.3144 - val_acc: 0.7812 - val_loss_no_weight_decay: 0.4462
#
# Epoch 00015: val_acc did not improve from 0.82692
# Confusion matrix:
#  [[22  5]
#  [ 8 29]]
# Epoch 16/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.3938 - mean_absolute_error: 0.2723 - acc: 0.8164 - loss_no_weight_decay: 0.3938 - val_loss: 0.4037 - val_mean_absolute_error: 0.2752 - val_acc: 0.8077 - val_loss_no_weight_decay: 0.4037
#
# Epoch 00016: val_acc did not improve from 0.82692
# Confusion matrix:
#  [[18  5]
#  [ 3 26]]
# Epoch 17/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.3182 - mean_absolute_error: 0.2212 - acc: 0.8790 - loss_no_weight_decay: 0.3182 - val_loss: 0.4061 - val_mean_absolute_error: 0.2324 - val_acc: 0.7656 - val_loss_no_weight_decay: 0.4061
#
# Epoch 00017: val_acc did not improve from 0.82692
# Confusion matrix:
#  [[22 10]
#  [ 4 28]]
# Epoch 18/35
# 9/9 [==============================] - 25s 3s/step - loss: 0.3682 - mean_absolute_error: 0.2154 - acc: 0.8420 - loss_no_weight_decay: 0.3682 - val_loss: 0.3383 - val_mean_absolute_error: 0.2423 - val_acc: 0.9038 - val_loss_no_weight_decay: 0.3383
#
# Epoch 00018: val_acc improved from 0.82692 to 0.90385, saving model to base_2020-05-08-02-07-47-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[25  4]
#  [ 5 18]]
# Epoch 19/35
# 9/9 [==============================] - 24s 3s/step - loss: 0.2793 - mean_absolute_error: 0.1963 - acc: 0.8848 - loss_no_weight_decay: 0.2793 - val_loss: 0.3262 - val_mean_absolute_error: 0.2196 - val_acc: 0.8438 - val_loss_no_weight_decay: 0.3262
#
# Epoch 00019: val_acc did not improve from 0.90385
# Confusion matrix:
#  [[22  8]
#  [ 4 30]]
# Epoch 20/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.2868 - mean_absolute_error: 0.1927 - acc: 0.8775 - loss_no_weight_decay: 0.2868 - val_loss: 0.3654 - val_mean_absolute_error: 0.2157 - val_acc: 0.8462 - val_loss_no_weight_decay: 0.3654
#
# Epoch 00020: val_acc did not improve from 0.90385
# Confusion matrix:
#  [[19  6]
#  [ 5 22]]
# Epoch 21/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.2054 - mean_absolute_error: 0.1426 - acc: 0.9123 - loss_no_weight_decay: 0.2054 - val_loss: 0.2657 - val_mean_absolute_error: 0.1493 - val_acc: 0.9062 - val_loss_no_weight_decay: 0.2657
#
# Epoch 00021: val_acc improved from 0.90385 to 0.90625, saving model to base_2020-05-08-02-07-47-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[26  5]
#  [ 2 31]]
# Epoch 22/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.2693 - mean_absolute_error: 0.1646 - acc: 0.8863 - loss_no_weight_decay: 0.2693 - val_loss: 0.3774 - val_mean_absolute_error: 0.2367 - val_acc: 0.8077 - val_loss_no_weight_decay: 0.3774
#
# Epoch 00022: val_acc did not improve from 0.90625
# Confusion matrix:
#  [[21  4]
#  [ 4 23]]
# Epoch 23/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.1728 - mean_absolute_error: 0.1257 - acc: 0.9386 - loss_no_weight_decay: 0.1728 - val_loss: 0.3243 - val_mean_absolute_error: 0.1982 - val_acc: 0.8594 - val_loss_no_weight_decay: 0.3243
#
# Epoch 00023: val_acc did not improve from 0.90625
# Confusion matrix:
#  [[22  9]
#  [ 2 31]]
# Epoch 24/35
# 9/9 [==============================] - 26s 3s/step - loss: 0.1721 - mean_absolute_error: 0.1195 - acc: 0.9306 - loss_no_weight_decay: 0.1721 - val_loss: 0.2238 - val_mean_absolute_error: 0.1323 - val_acc: 0.8846 - val_loss_no_weight_decay: 0.2238
#
# Epoch 00024: val_acc did not improve from 0.90625
# Confusion matrix:
#  [[18  4]
#  [ 3 27]]
# Epoch 25/35
# 9/9 [==============================] - 21s 2s/step - loss: 0.1657 - mean_absolute_error: 0.1154 - acc: 0.9311 - loss_no_weight_decay: 0.1657 - val_loss: 0.3623 - val_mean_absolute_error: 0.1911 - val_acc: 0.8594 - val_loss_no_weight_decay: 0.3623
#
# Epoch 00025: val_acc did not improve from 0.90625
# Confusion matrix:
#  [[28  6]
#  [ 1 29]]
# Epoch 26/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.1607 - mean_absolute_error: 0.1078 - acc: 0.9371 - loss_no_weight_decay: 0.1607 - val_loss: 0.2300 - val_mean_absolute_error: 0.1233 - val_acc: 0.9038 - val_loss_no_weight_decay: 0.2300
#
# Epoch 00026: val_acc did not improve from 0.90625
# Confusion matrix:
#  [[22  5]
#  [ 0 25]]
# Epoch 27/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.1612 - mean_absolute_error: 0.1045 - acc: 0.9424 - loss_no_weight_decay: 0.1612 - val_loss: 0.2980 - val_mean_absolute_error: 0.1607 - val_acc: 0.8750 - val_loss_no_weight_decay: 0.2980
#
# Epoch 00027: val_acc did not improve from 0.90625
# Confusion matrix:
#  [[27  8]
#  [ 0 29]]
# Epoch 28/35
# 9/9 [==============================] - 26s 3s/step - loss: 0.1285 - mean_absolute_error: 0.0880 - acc: 0.9549 - loss_no_weight_decay: 0.1285 - val_loss: 0.2098 - val_mean_absolute_error: 0.1221 - val_acc: 0.9038 - val_loss_no_weight_decay: 0.2098
#
# Epoch 00028: val_acc did not improve from 0.90625
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Confusion matrix:
#  [[22  2]
#  [ 2 26]]
# Epoch 29/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.0922 - mean_absolute_error: 0.0675 - acc: 0.9737 - loss_no_weight_decay: 0.0922 - val_loss: 0.2831 - val_mean_absolute_error: 0.1390 - val_acc: 0.8750 - val_loss_no_weight_decay: 0.2831
#
# Epoch 00029: val_acc did not improve from 0.90625
# Confusion matrix:
#  [[28  5]
#  [ 1 30]]
# Epoch 30/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.1528 - mean_absolute_error: 0.0972 - acc: 0.9389 - loss_no_weight_decay: 0.1528 - val_loss: 0.1715 - val_mean_absolute_error: 0.1022 - val_acc: 0.9231 - val_loss_no_weight_decay: 0.1715
#
# Epoch 00030: val_acc improved from 0.90625 to 0.92308, saving model to base_2020-05-08-02-07-47-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[21  3]
#  [ 0 28]]
# Epoch 31/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.1119 - mean_absolute_error: 0.0747 - acc: 0.9547 - loss_no_weight_decay: 0.1119 - val_loss: 0.1821 - val_mean_absolute_error: 0.1267 - val_acc: 0.8906 - val_loss_no_weight_decay: 0.1821
#
# Epoch 00031: val_acc did not improve from 0.92308
# Confusion matrix:
#  [[34  3]
#  [ 0 27]]
# Epoch 32/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.1105 - mean_absolute_error: 0.0771 - acc: 0.9599 - loss_no_weight_decay: 0.1105 - val_loss: 0.1023 - val_mean_absolute_error: 0.0663 - val_acc: 0.9423 - val_loss_no_weight_decay: 0.1023
#
# Epoch 00032: val_acc improved from 0.92308 to 0.94231, saving model to base_2020-05-08-02-07-47-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[18  4]
#  [ 1 29]]
# Epoch 33/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.0885 - mean_absolute_error: 0.0626 - acc: 0.9737 - loss_no_weight_decay: 0.0885 - val_loss: 0.0912 - val_mean_absolute_error: 0.0754 - val_acc: 1.0000 - val_loss_no_weight_decay: 0.0912
#
# Epoch 00033: val_acc improved from 0.94231 to 1.00000, saving model to base_2020-05-08-02-07-47-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[33  2]
#  [ 1 28]]
# Epoch 34/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.0861 - mean_absolute_error: 0.0630 - acc: 0.9702 - loss_no_weight_decay: 0.0861 - val_loss: 0.2092 - val_mean_absolute_error: 0.1154 - val_acc: 0.8846 - val_loss_no_weight_decay: 0.2092
#
# Epoch 00034: val_acc did not improve from 1.00000
# Confusion matrix:
#  [[25  2]
#  [ 1 24]]
# Epoch 35/35
# 9/9 [==============================] - 25s 3s/step - loss: 0.0828 - mean_absolute_error: 0.0568 - acc: 0.9705 - loss_no_weight_decay: 0.0828 - val_loss: 0.1352 - val_mean_absolute_error: 0.0968 - val_acc: 0.9375 - val_loss_no_weight_decay: 0.1352
#
# Epoch 00035: val_acc did not improve from 1.00000
# Confusion matrix:
#  [[25  5]
#  [ 2 32]]
# 176/176 [==============================] - 5s 31ms/step
# 176/176 [==============================] - 5s 29ms/step
# Test loss: 0.18519343477093095
# Test accuracy: 0.08904315993520516
# Confusion Matrix
# [[83  5]
#  [ 5 83]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94        88
#            1       0.94      0.94      0.94        88
#
#     accuracy                           0.94       176
#    macro avg       0.94      0.94      0.94       176
# weighted avg       0.94      0.94      0.94       176

# %%
import numpy as np 
import matplotlib.pyplot as plt
import os
import wandb
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_mean_absolute_error', 'val_acc', 'val_loss_no_weight_decay', 'loss', 'mean_absolute_error', 'acc', 'loss_no_weight_decay', 'lr'])

# %%
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
from Kappa_Skl import kappa
def kappa2(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    if len(y_true.shape) > 1 and y_true.shape[1] > 1:
        y_true = y_true.dot(range(y_true.shape[1]))
    if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
        y_pred = y_pred.dot(range(y_pred.shape[1]))
    try:
        return kappa(y_true, y_pred, weights='quadratic')
    except IndexError:
        return np.nan
    
print('Quadratic_wieghted_kappa')
print(kappa2(y_true, y_pred))
# Out:
# Quadratic_wieghted_kappa
# 0.8863636363636364

# %%
# summarize history for mean_absolute _error
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model mean_absolute_error')
plt.ylabel('mean_absolute_error')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model maey.png')
