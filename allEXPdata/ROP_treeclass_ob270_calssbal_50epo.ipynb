# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, InputLayer
from keras.regularizers import L1L2, l2, l1
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from custom_pooling import RMSPooling2D
from keras.optimizers import SGD, Adam
from keras.layers import LeakyReLU
#from data import BALANCE_WEIGHTS
from keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
#import os
from datetime import datetime as dt
from custom_loss import WeightedCategoricalCrossEntropy
from VCM import VCM
from QWK import QWK
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
def get_experiment_id():
    time_str = dt.now().strftime('%Y-%m-%d-%H-%M-%S')
    experiment_id = 'base_{}'.format(time_str)
    return experiment_id
p_ratio=[1.0, 1.44, 1.73, 1.0]

model = Sequential()


model.add(Conv2D(16, (5, 5), activation='tanh', input_shape=(270, 270, 3)))
model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(16, (3, 3), activation='tanh'))
model.add(Conv2D(16, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))

#model.add(LeakyReLU(alpha=0.01))


model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))



model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))          
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(MaxPooling2D(pool_size=2))
#model.add(MaxPooling2D(pool_size=1))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
model.add(MaxPooling2D(pool_size=2))

model.add(Flatten())


#chnaged from 10 to 5 because an error 
model.add(Dense(3, activation='softmax'))

sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.count_params()
#adam = Adam(lr=0.0005, decay=1e-6)
#rmsprop
#Mloss = WeightedCategoricalCrossEntropy({0: 0.4125861396437394, 1: 1.4918664786083686, 2: 0.690426457789382, 3: 3.9541433021806855, 4: 4.885604311008468})
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['acc','binary_accuracy','mae'])
model.summary()
loss_no_weight_decay = model.total_loss - sum(model.losses)
model.metrics_tensors.append(loss_no_weight_decay)
model.metrics_names.append('loss_no_weight_decay')
#############################################################################################
#############################################################################################
#############################################################################################
#############################################################################################
#Preparing Data Augmentation Configuration 
train_datagen = ImageDataGenerator(
        rescale=1./255,
#        featurewise_center=True,
 #       samplewise_center=True,
        shear_range=0,
        zoom_range=0.0,#[1 / 1.15, 1.15],
        horizontal_flip=False,#True,
        rotation_range=0)#90,
#        validation_split=0.2)
"""
For the test set only rescale should be made 
"""
test_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/three_class/train",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="training")
#    save_to_dir="D:/Separating Images into subfolders/train_augmented")


#print(train_generator.class_indices)

valid_generator = valid_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/three_class/vald",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="validation")
#    save_to_dir="D:/Separating Images into subfolders/val_augmented"


test_generator = test_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/three_class/test",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=1,
    class_mode="categorical",
    shuffle=False,
    seed=42)
#    save_to_dir="D:/Separating Images into subfolders/test_augmented")


# Fitting/Training the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
experiment_id = get_experiment_id()
callbacks = [
    QWK(valid_generator, STEP_SIZE_VALID),
    EarlyStopping(monitor='val_acc', patience=50, min_delta=0.001, verbose=1),
    ModelCheckpoint(experiment_id + "-val_kapa_checkpoint.hdf5", monitor='val_kappa', verbose=1, save_best_only=True, mode='max'),
    ReduceLROnPlateau(monitor='val_acc', factor=0.5, patience=7, verbose=1, mode='auto', min_delta=0.001, cooldown=0, min_lr=1e-7),
    VCM(valid_generator,STEP_SIZE_VALID)
    
]

class_weight_list = class_weight.compute_class_weight('balanced', np.unique(train_generator.classes), train_generator.classes)
class_weights = dict(zip(np.unique(train_generator.classes), class_weight_list))

history=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    class_weight=class_weights,
                    callbacks=callbacks,
                    epochs=50  
)


# Evaluating the model 
#predicting output
#reseting the test generator before calling predict_generator, in order not to get weird output
test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1', '2']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 266, 266, 16)      1216
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 262, 262, 16)      6416
# _________________________________________________________________
# input_1 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 260, 260, 16)      2320
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 258, 258, 16)      2320
# _________________________________________________________________
# input_2 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 254, 254, 16)      6416
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 250, 250, 16)      6416
# _________________________________________________________________
# input_3 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 246, 246, 16)      6416
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 242, 242, 16)      6416
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 121, 121, 16)      0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 119, 119, 32)      4640
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 117, 117, 32)      9248
# _________________________________________________________________
# input_4 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 115, 115, 32)      9248
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 113, 113, 32)      9248
# _________________________________________________________________
# input_5 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 111, 111, 32)      9248
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 109, 109, 32)      9248
# _________________________________________________________________
# input_6 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 107, 107, 32)      9248
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 105, 105, 32)      9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 52, 52, 32)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 50, 50, 64)        18496
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 48, 48, 64)        36928
# _________________________________________________________________
# input_7 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 46, 46, 64)        36928
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 44, 44, 64)        36928
# _________________________________________________________________
# input_8 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 42, 42, 64)        36928
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 40, 40, 64)        36928
# _________________________________________________________________
# input_9 (InputLayer)         multiple                  0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 20, 20, 64)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 18, 18, 64)        36928
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# input_10 (InputLayer)        multiple                  0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 14, 14, 64)        36928
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 12, 12, 64)        36928
# _________________________________________________________________
# input_11 (InputLayer)        multiple                  0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 6915
# =================================================================
# Total params: 465,075
# Trainable params: 465,075
# Non-trainable params: 0
# _________________________________________________________________
# Found 588 images belonging to 3 classes.
# Found 116 images belonging to 3 classes.
# Found 176 images belonging to 3 classes.
# Epoch 1/50
# 9/9 [==============================] - 23s 3s/step - loss: 1.1012 - acc: 0.3903 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4416 - loss_no_weight_decay: 1.1012 - val_loss: 1.1120 - val_acc: 0.2344 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4471 - val_loss_no_weight_decay: 1.1120
# — val_kappa: 0.0
#
# Epoch 00001: val_kappa improved from -inf to 0.00000, saving model to base_2020-05-09-13-08-24-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[26  0  0]
#  [ 5  0  0]
#  [21  0  0]]
# Epoch 2/50
# 9/9 [==============================] - 14s 2s/step - loss: 1.0769 - acc: 0.3838 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4441 - loss_no_weight_decay: 1.0769 - val_loss: 1.0892 - val_acc: 0.4615 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4422 - val_loss_no_weight_decay: 1.0892
# — val_kappa: 0.0
#
# Epoch 00002: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[30  0  0]
#  [ 7  0  0]
#  [15  0  0]]
# Epoch 3/50
# 9/9 [==============================] - 12s 1s/step - loss: 1.0990 - acc: 0.3975 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4431 - loss_no_weight_decay: 1.0990 - val_loss: 1.1029 - val_acc: 0.2656 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4450 - val_loss_no_weight_decay: 1.1029
# — val_kappa: 0.0
#
# Epoch 00003: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[22  0  0]
#  [ 6  0  0]
#  [24  0  0]]
# Epoch 4/50
# 9/9 [==============================] - 13s 1s/step - loss: 1.0778 - acc: 0.4740 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4404 - loss_no_weight_decay: 1.0778 - val_loss: 1.0654 - val_acc: 0.5769 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4366 - val_loss_no_weight_decay: 1.0654
# — val_kappa: 0.0
#
# Epoch 00004: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[23  0  0]
#  [ 6  0  0]
#  [23  0  0]]
# Epoch 5/50
# 9/9 [==============================] - 11s 1s/step - loss: 1.0635 - acc: 0.6085 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4318 - loss_no_weight_decay: 1.0635 - val_loss: 1.0658 - val_acc: 0.5000 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4356 - val_loss_no_weight_decay: 1.0658
# — val_kappa: 0.0
#
# Epoch 00005: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[28  0  0]
#  [ 5  0  0]
#  [19  0  0]]
# Epoch 6/50
# 9/9 [==============================] - 10s 1s/step - loss: 1.0026 - acc: 0.5444 - binary_accuracy: 0.6691 - mean_absolute_error: 0.4217 - loss_no_weight_decay: 1.0026 - val_loss: 1.0072 - val_acc: 0.4423 - val_binary_accuracy: 0.6859 - val_mean_absolute_error: 0.4183 - val_loss_no_weight_decay: 1.0072
# — val_kappa: 0.05102040816326525
#
# Epoch 00006: val_kappa improved from 0.00000 to 0.05102, saving model to base_2020-05-09-13-08-24-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[29  0  0]
#  [ 5  0  0]
#  [18  0  0]]
# Epoch 7/50
# 9/9 [==============================] - 12s 1s/step - loss: 1.1139 - acc: 0.3177 - binary_accuracy: 0.6753 - mean_absolute_error: 0.4408 - loss_no_weight_decay: 1.1139 - val_loss: 0.9350 - val_acc: 0.5938 - val_binary_accuracy: 0.7292 - val_mean_absolute_error: 0.3947 - val_loss_no_weight_decay: 0.9350
# — val_kappa: 0.24644549763033186
#
# Epoch 00007: val_kappa improved from 0.05102 to 0.24645, saving model to base_2020-05-09-13-08-24-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[29  0  0]
#  [ 4  0  0]
#  [18  0  1]]
# Epoch 8/50
# 9/9 [==============================] - 9s 1s/step - loss: 1.0323 - acc: 0.5597 - binary_accuracy: 0.6987 - mean_absolute_error: 0.4086 - loss_no_weight_decay: 1.0323 - val_loss: 0.9857 - val_acc: 0.5385 - val_binary_accuracy: 0.6923 - val_mean_absolute_error: 0.4121 - val_loss_no_weight_decay: 0.9857
# — val_kappa: 0.1212121212121211
#
# Epoch 00008: val_kappa did not improve from 0.24645
# Confusion matrix:
#  [[28  0  0]
#  [ 7  0  0]
#  [17  0  0]]
# Epoch 9/50
# 9/9 [==============================] - 10s 1s/step - loss: 1.0511 - acc: 0.5493 - binary_accuracy: 0.6935 - mean_absolute_error: 0.4107 - loss_no_weight_decay: 1.0511 - val_loss: 0.9200 - val_acc: 0.5938 - val_binary_accuracy: 0.7240 - val_mean_absolute_error: 0.3889 - val_loss_no_weight_decay: 0.9200
# — val_kappa: 0.26086956521739124
#
# Epoch 00009: val_kappa improved from 0.24645 to 0.26087, saving model to base_2020-05-09-13-08-24-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[25  0  1]
#  [ 6  0  0]
#  [18  0  2]]
# Epoch 10/50
# 9/9 [==============================] - 10s 1s/step - loss: 0.9886 - acc: 0.5434 - binary_accuracy: 0.7095 - mean_absolute_error: 0.4004 - loss_no_weight_decay: 0.9886 - val_loss: 0.9681 - val_acc: 0.6346 - val_binary_accuracy: 0.7115 - val_mean_absolute_error: 0.4051 - val_loss_no_weight_decay: 0.9681
# — val_kappa: 0.16831683168316836
#
# Epoch 00010: val_kappa did not improve from 0.26087
# Confusion matrix:
#  [[29  0  0]
#  [ 4  0  0]
#  [18  0  1]]
# Epoch 11/50
# 9/9 [==============================] - 10s 1s/step - loss: 0.9822 - acc: 0.5265 - binary_accuracy: 0.7098 - mean_absolute_error: 0.3987 - loss_no_weight_decay: 0.9822 - val_loss: 0.8520 - val_acc: 0.6406 - val_binary_accuracy: 0.7656 - val_mean_absolute_error: 0.3655 - val_loss_no_weight_decay: 0.8520
# — val_kappa: 0.3835616438356164
#
# Epoch 00011: val_kappa improved from 0.26087 to 0.38356, saving model to base_2020-05-09-13-08-24-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[26  0  0]
#  [ 4  0  0]
#  [20  0  2]]
# Epoch 12/50
# 9/9 [==============================] - 14s 2s/step - loss: 0.9387 - acc: 0.5902 - binary_accuracy: 0.7319 - mean_absolute_error: 0.3797 - loss_no_weight_decay: 0.9387 - val_loss: 0.9001 - val_acc: 0.5769 - val_binary_accuracy: 0.7436 - val_mean_absolute_error: 0.3784 - val_loss_no_weight_decay: 0.9001
# — val_kappa: 0.3033175355450237
#
# Epoch 00012: val_kappa did not improve from 0.38356
# Confusion matrix:
#  [[30  0  1]
#  [ 3  1  0]
#  [13  3  1]]
# Epoch 13/50
# 9/9 [==============================] - 13s 1s/step - loss: 0.9655 - acc: 0.5330 - binary_accuracy: 0.7164 - mean_absolute_error: 0.3865 - loss_no_weight_decay: 0.9655 - val_loss: 0.8315 - val_acc: 0.5938 - val_binary_accuracy: 0.7604 - val_mean_absolute_error: 0.3501 - val_loss_no_weight_decay: 0.8315
# — val_kappa: 0.40528634361233473
#
# Epoch 00013: val_kappa improved from 0.38356 to 0.40529, saving model to base_2020-05-09-13-08-24-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[28  0  0]
#  [ 5  0  0]
#  [16  1  2]]
# Epoch 14/50
# 9/9 [==============================] - 13s 1s/step - loss: 1.0778 - acc: 0.3670 - binary_accuracy: 0.6759 - mean_absolute_error: 0.4338 - loss_no_weight_decay: 1.0778 - val_loss: 1.0486 - val_acc: 0.5385 - val_binary_accuracy: 0.6795 - val_mean_absolute_error: 0.4300 - val_loss_no_weight_decay: 1.0486
# — val_kappa: 0.0
#
# Epoch 00014: val_kappa did not improve from 0.40529
# Confusion matrix:
#  [[27  0  0]
#  [ 6  0  0]
#  [19  0  0]]
# Epoch 15/50
# 9/9 [==============================] - 11s 1s/step - loss: 1.0958 - acc: 0.4258 - binary_accuracy: 0.6828 - mean_absolute_error: 0.4329 - loss_no_weight_decay: 1.0958 - val_loss: 0.9867 - val_acc: 0.5938 - val_binary_accuracy: 0.6875 - val_mean_absolute_error: 0.4139 - val_loss_no_weight_decay: 0.9867
# — val_kappa: 0.020725388601036232
#
# Epoch 00015: val_kappa did not improve from 0.40529
# Confusion matrix:
#  [[31  0  0]
#  [ 5  0  0]
#  [16  0  0]]
# Epoch 16/50
# 9/9 [==============================] - 11s 1s/step - loss: 1.0189 - acc: 0.5213 - binary_accuracy: 0.7058 - mean_absolute_error: 0.4083 - loss_no_weight_decay: 1.0189 - val_loss: 0.8917 - val_acc: 0.7308 - val_binary_accuracy: 0.7436 - val_mean_absolute_error: 0.3850 - val_loss_no_weight_decay: 0.8917
# — val_kappa: 0.2857142857142856
#
# Epoch 00016: val_kappa did not improve from 0.40529
# Confusion matrix:
#  [[24  0  0]
#  [ 9  0  0]
#  [19  0  0]]
# Epoch 17/50
# 9/9 [==============================] - 11s 1s/step - loss: 1.0175 - acc: 0.5686 - binary_accuracy: 0.7366 - mean_absolute_error: 0.3802 - loss_no_weight_decay: 1.0175 - val_loss: 0.8147 - val_acc: 0.6562 - val_binary_accuracy: 0.8021 - val_mean_absolute_error: 0.3513 - val_loss_no_weight_decay: 0.8147
# — val_kappa: 0.3831775700934579
#
# Epoch 00017: val_kappa did not improve from 0.40529
# Confusion matrix:
#  [[24  0  0]
#  [ 6  0  0]
#  [20  0  2]]
# Epoch 18/50
# 9/9 [==============================] - 12s 1s/step - loss: 0.9374 - acc: 0.5642 - binary_accuracy: 0.7494 - mean_absolute_error: 0.3789 - loss_no_weight_decay: 0.9374 - val_loss: 0.8635 - val_acc: 0.6154 - val_binary_accuracy: 0.7628 - val_mean_absolute_error: 0.3665 - val_loss_no_weight_decay: 0.8635
# — val_kappa: 0.3207547169811321
#
# Epoch 00018: val_kappa did not improve from 0.40529
# Confusion matrix:
#  [[32  0  0]
#  [ 1  1  1]
#  [13  1  3]]
# Epoch 19/50
# 9/9 [==============================] - 10s 1s/step - loss: 0.9095 - acc: 0.5964 - binary_accuracy: 0.7599 - mean_absolute_error: 0.3577 - loss_no_weight_decay: 0.9095 - val_loss: 0.8095 - val_acc: 0.5938 - val_binary_accuracy: 0.7812 - val_mean_absolute_error: 0.3363 - val_loss_no_weight_decay: 0.8095
# — val_kappa: 0.4366812227074236
#
# Epoch 00019: val_kappa improved from 0.40529 to 0.43668, saving model to base_2020-05-09-13-08-24-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[23  1  0]
#  [ 4  1  1]
#  [17  2  3]]
# Epoch 20/50
# 9/9 [==============================] - 11s 1s/step - loss: 0.8288 - acc: 0.6067 - binary_accuracy: 0.7639 - mean_absolute_error: 0.3427 - loss_no_weight_decay: 0.8288 - val_loss: 0.7233 - val_acc: 0.6731 - val_binary_accuracy: 0.8077 - val_mean_absolute_error: 0.3060 - val_loss_no_weight_decay: 0.7233
# — val_kappa: 0.4260869565217391
#
# Epoch 00020: val_kappa did not improve from 0.43668
# Confusion matrix:
#  [[24  0  0]
#  [ 6  0  0]
#  [14  3  5]]
# Epoch 21/50
# 9/9 [==============================] - 11s 1s/step - loss: 0.8162 - acc: 0.6643 - binary_accuracy: 0.7810 - mean_absolute_error: 0.3263 - loss_no_weight_decay: 0.8162 - val_loss: 0.7948 - val_acc: 0.5938 - val_binary_accuracy: 0.7500 - val_mean_absolute_error: 0.3371 - val_loss_no_weight_decay: 0.7948
# — val_kappa: 0.46153846153846145
#
# Epoch 00021: val_kappa improved from 0.43668 to 0.46154, saving model to base_2020-05-09-13-08-24-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[19  0  2]
#  [ 5  4  0]
#  [11  5  6]]
# Epoch 22/50
# 9/9 [==============================] - 13s 1s/step - loss: 0.7946 - acc: 0.6851 - binary_accuracy: 0.7846 - mean_absolute_error: 0.3241 - loss_no_weight_decay: 0.7946 - val_loss: 0.6731 - val_acc: 0.7500 - val_binary_accuracy: 0.8013 - val_mean_absolute_error: 0.2998 - val_loss_no_weight_decay: 0.6731
# — val_kappa: 0.44067796610169496
#
# Epoch 00022: val_kappa did not improve from 0.46154
# Confusion matrix:
#  [[27  0  0]
#  [ 7  2  0]
#  [ 5  3  8]]
# Epoch 23/50
# 9/9 [==============================] - 12s 1s/step - loss: 0.7801 - acc: 0.6954 - binary_accuracy: 0.8040 - mean_absolute_error: 0.3123 - loss_no_weight_decay: 0.7801 - val_loss: 0.6830 - val_acc: 0.7656 - val_binary_accuracy: 0.8125 - val_mean_absolute_error: 0.2921 - val_loss_no_weight_decay: 0.6830
# — val_kappa: 0.4155844155844155
#
# Epoch 00023: val_kappa did not improve from 0.46154
# Confusion matrix:
#  [[26  0  0]
#  [ 2  4  0]
#  [13  2  5]]
# Epoch 24/50
# 9/9 [==============================] - 14s 2s/step - loss: 0.7485 - acc: 0.6806 - binary_accuracy: 0.7888 - mean_absolute_error: 0.3017 - loss_no_weight_decay: 0.7485 - val_loss: 0.6061 - val_acc: 0.6923 - val_binary_accuracy: 0.8333 - val_mean_absolute_error: 0.2585 - val_loss_no_weight_decay: 0.6061
# — val_kappa: 0.49382716049382713
#
# Epoch 00024: val_kappa improved from 0.46154 to 0.49383, saving model to base_2020-05-09-13-08-24-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[20  0  3]
#  [ 1  3  3]
#  [ 5  2 15]]
# Epoch 25/50
# 9/9 [==============================] - 11s 1s/step - loss: 0.6842 - acc: 0.7092 - binary_accuracy: 0.8252 - mean_absolute_error: 0.2806 - loss_no_weight_decay: 0.6842 - val_loss: 0.7547 - val_acc: 0.6562 - val_binary_accuracy: 0.7865 - val_mean_absolute_error: 0.2975 - val_loss_no_weight_decay: 0.7547
# — val_kappa: 0.5785123966942148
#
# Epoch 00025: val_kappa improved from 0.49383 to 0.57851, saving model to base_2020-05-09-13-08-24-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[19  2  4]
#  [ 3  2  1]
#  [ 5  5 11]]
# Epoch 26/50
# 9/9 [==============================] - 12s 1s/step - loss: 0.7022 - acc: 0.6875 - binary_accuracy: 0.8021 - mean_absolute_error: 0.2792 - loss_no_weight_decay: 0.7022 - val_loss: 0.6240 - val_acc: 0.7692 - val_binary_accuracy: 0.8526 - val_mean_absolute_error: 0.2608 - val_loss_no_weight_decay: 0.6240
# — val_kappa: 0.6419753086419753
#
# Epoch 00026: val_kappa improved from 0.57851 to 0.64198, saving model to base_2020-05-09-13-08-24-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[25  0  1]
#  [ 1  3  2]
#  [ 9  4  7]]
# Epoch 27/50
# 9/9 [==============================] - 10s 1s/step - loss: 0.7266 - acc: 0.6897 - binary_accuracy: 0.7960 - mean_absolute_error: 0.2884 - loss_no_weight_decay: 0.7266 - val_loss: 0.7133 - val_acc: 0.7031 - val_binary_accuracy: 0.8229 - val_mean_absolute_error: 0.2843 - val_loss_no_weight_decay: 0.7133
# — val_kappa: 0.5394190871369294
#
# Epoch 00027: val_kappa did not improve from 0.64198
# Confusion matrix:
#  [[25  1  1]
#  [ 2  4  1]
#  [ 6  2 10]]
# Epoch 28/50
# 9/9 [==============================] - 10s 1s/step - loss: 0.6550 - acc: 0.7016 - binary_accuracy: 0.8149 - mean_absolute_error: 0.2714 - loss_no_weight_decay: 0.6550 - val_loss: 0.7164 - val_acc: 0.6538 - val_binary_accuracy: 0.8141 - val_mean_absolute_error: 0.2682 - val_loss_no_weight_decay: 0.7164
# — val_kappa: 0.617283950617284
#
# Epoch 00028: val_kappa did not improve from 0.64198
# Confusion matrix:
#  [[23  0  2]
#  [ 2  3  3]
#  [ 5  4 10]]
# Epoch 29/50
# 9/9 [==============================] - 11s 1s/step - loss: 0.6709 - acc: 0.7292 - binary_accuracy: 0.8287 - mean_absolute_error: 0.2634 - loss_no_weight_decay: 0.6709 - val_loss: 0.6742 - val_acc: 0.6406 - val_binary_accuracy: 0.7760 - val_mean_absolute_error: 0.2835 - val_loss_no_weight_decay: 0.6742
# — val_kappa: 0.5432098765432098
#
# Epoch 00029: val_kappa did not improve from 0.64198
# Confusion matrix:
#  [[22  4  1]
#  [ 0  5  0]
#  [ 7  7  6]]
# Epoch 30/50
# 9/9 [==============================] - 9s 1s/step - loss: 0.6732 - acc: 0.7219 - binary_accuracy: 0.8245 - mean_absolute_error: 0.2680 - loss_no_weight_decay: 0.6732 - val_loss: 0.6840 - val_acc: 0.6346 - val_binary_accuracy: 0.7756 - val_mean_absolute_error: 0.2630 - val_loss_no_weight_decay: 0.6840
# — val_kappa: 0.5643153526970954
#
# Epoch 00030: val_kappa did not improve from 0.64198
# Confusion matrix:
#  [[19  0  4]
#  [ 0  4  1]
#  [10  3 11]]
# Epoch 31/50
# 9/9 [==============================] - 10s 1s/step - loss: 0.5820 - acc: 0.7776 - binary_accuracy: 0.8458 - mean_absolute_error: 0.2371 - loss_no_weight_decay: 0.5820 - val_loss: 0.6136 - val_acc: 0.7031 - val_binary_accuracy: 0.8073 - val_mean_absolute_error: 0.2447 - val_loss_no_weight_decay: 0.6136
# — val_kappa: 0.6097560975609756
#
# Epoch 00031: val_kappa did not improve from 0.64198
# Confusion matrix:
#  [[27  0  0]
#  [ 0  2  0]
#  [11  3  9]]
# Epoch 32/50
# 9/9 [==============================] - 13s 1s/step - loss: 0.5476 - acc: 0.8021 - binary_accuracy: 0.8636 - mean_absolute_error: 0.2219 - loss_no_weight_decay: 0.5476 - val_loss: 0.5535 - val_acc: 0.8077 - val_binary_accuracy: 0.8782 - val_mean_absolute_error: 0.2294 - val_loss_no_weight_decay: 0.5535
# — val_kappa: 0.6190476190476191
#
# Epoch 00032: val_kappa did not improve from 0.64198
# Confusion matrix:
#  [[22  1  1]
#  [ 0  4  3]
#  [ 3  2 16]]
# Epoch 33/50
# 9/9 [==============================] - 14s 2s/step - loss: 0.5553 - acc: 0.7535 - binary_accuracy: 0.8438 - mean_absolute_error: 0.2185 - loss_no_weight_decay: 0.5553 - val_loss: 0.6591 - val_acc: 0.6875 - val_binary_accuracy: 0.7708 - val_mean_absolute_error: 0.2518 - val_loss_no_weight_decay: 0.6591
# — val_kappa: 0.48962655601659744
#
# Epoch 00033: val_kappa did not improve from 0.64198
# Confusion matrix:
#  [[23  1  3]
#  [ 0  4  3]
#  [ 3  5 10]]
# Epoch 34/50
# 9/9 [==============================] - 13s 1s/step - loss: 0.5685 - acc: 0.7648 - binary_accuracy: 0.8552 - mean_absolute_error: 0.2224 - loss_no_weight_decay: 0.5685 - val_loss: 0.5250 - val_acc: 0.7885 - val_binary_accuracy: 0.8462 - val_mean_absolute_error: 0.2160 - val_loss_no_weight_decay: 0.5250
# — val_kappa: 0.7250996015936255
#
# Epoch 00034: val_kappa improved from 0.64198 to 0.72510, saving model to base_2020-05-09-13-08-24-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[20  0  3]
#  [ 0  2  4]
#  [ 5  1 17]]
# Epoch 35/50
# 9/9 [==============================] - 11s 1s/step - loss: 0.5020 - acc: 0.8076 - binary_accuracy: 0.8699 - mean_absolute_error: 0.2029 - loss_no_weight_decay: 0.5020 - val_loss: 0.6605 - val_acc: 0.6875 - val_binary_accuracy: 0.7969 - val_mean_absolute_error: 0.2386 - val_loss_no_weight_decay: 0.6605
# — val_kappa: 0.5403225806451613
#
# Epoch 00035: val_kappa did not improve from 0.72510
# Confusion matrix:
#  [[30  0  1]
#  [ 0  2  1]
#  [ 6  6  6]]
# Epoch 36/50
# 9/9 [==============================] - 13s 1s/step - loss: 0.5639 - acc: 0.7604 - binary_accuracy: 0.8495 - mean_absolute_error: 0.2210 - loss_no_weight_decay: 0.5639 - val_loss: 0.5199 - val_acc: 0.7500 - val_binary_accuracy: 0.8205 - val_mean_absolute_error: 0.2201 - val_loss_no_weight_decay: 0.5199
# — val_kappa: 0.6097560975609756
#
# Epoch 00036: val_kappa did not improve from 0.72510
# Confusion matrix:
#  [[26  1  2]
#  [ 0  4  4]
#  [ 3  5  7]]
# Epoch 37/50
# 9/9 [==============================] - 11s 1s/step - loss: 0.4835 - acc: 0.8039 - binary_accuracy: 0.8664 - mean_absolute_error: 0.1929 - loss_no_weight_decay: 0.4835 - val_loss: 0.6418 - val_acc: 0.6719 - val_binary_accuracy: 0.7917 - val_mean_absolute_error: 0.2453 - val_loss_no_weight_decay: 0.6418
# — val_kappa: 0.6506024096385542
#
# Epoch 00037: val_kappa did not improve from 0.72510
# Confusion matrix:
#  [[19  0  4]
#  [ 0  3  3]
#  [ 3  9 11]]
# Epoch 38/50
# 9/9 [==============================] - 11s 1s/step - loss: 0.4519 - acc: 0.8319 - binary_accuracy: 0.8845 - mean_absolute_error: 0.1863 - loss_no_weight_decay: 0.4519 - val_loss: 0.6343 - val_acc: 0.7500 - val_binary_accuracy: 0.8397 - val_mean_absolute_error: 0.2038 - val_loss_no_weight_decay: 0.6343
# — val_kappa: 0.749003984063745
#
# Epoch 00038: val_kappa improved from 0.72510 to 0.74900, saving model to base_2020-05-09-13-08-24-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[24  0  3]
#  [ 1  2  4]
#  [11  1  6]]
# Epoch 39/50
# 9/9 [==============================] - 9s 1s/step - loss: 0.4848 - acc: 0.8044 - binary_accuracy: 0.8690 - mean_absolute_error: 0.1977 - loss_no_weight_decay: 0.4848 - val_loss: 0.5659 - val_acc: 0.7344 - val_binary_accuracy: 0.8229 - val_mean_absolute_error: 0.2161 - val_loss_no_weight_decay: 0.5659
# — val_kappa: 0.5849802371541502
#
# Epoch 00039: val_kappa did not improve from 0.74900
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Confusion matrix:
#  [[29  0  0]
#  [ 1  6  0]
#  [ 3  4  9]]
# Epoch 40/50
# 9/9 [==============================] - 11s 1s/step - loss: 0.4452 - acc: 0.8420 - binary_accuracy: 0.8918 - mean_absolute_error: 0.1740 - loss_no_weight_decay: 0.4452 - val_loss: 0.5531 - val_acc: 0.6923 - val_binary_accuracy: 0.7885 - val_mean_absolute_error: 0.2074 - val_loss_no_weight_decay: 0.5531
# — val_kappa: 0.5577689243027889
#
# Epoch 00040: val_kappa did not improve from 0.74900
# Confusion matrix:
#  [[29  1  1]
#  [ 0  3  2]
#  [ 1  5 10]]
# Epoch 41/50
# 9/9 [==============================] - 11s 1s/step - loss: 0.4375 - acc: 0.8256 - binary_accuracy: 0.8935 - mean_absolute_error: 0.1826 - loss_no_weight_decay: 0.4375 - val_loss: 0.3732 - val_acc: 0.8281 - val_binary_accuracy: 0.8906 - val_mean_absolute_error: 0.1594 - val_loss_no_weight_decay: 0.3732
# — val_kappa: 0.616
#
# Epoch 00041: val_kappa did not improve from 0.74900
# Confusion matrix:
#  [[28  0  0]
#  [ 0  2  2]
#  [ 4  3 13]]
# Epoch 42/50
# 9/9 [==============================] - 13s 1s/step - loss: 0.4399 - acc: 0.8236 - binary_accuracy: 0.8888 - mean_absolute_error: 0.1764 - loss_no_weight_decay: 0.4399 - val_loss: 0.4892 - val_acc: 0.7308 - val_binary_accuracy: 0.8269 - val_mean_absolute_error: 0.1842 - val_loss_no_weight_decay: 0.4892
# — val_kappa: 0.6561264822134387
#
# Epoch 00042: val_kappa did not improve from 0.74900
# Confusion matrix:
#  [[21  1  2]
#  [ 0  3  3]
#  [ 3  8 11]]
# Epoch 43/50
# 9/9 [==============================] - 13s 1s/step - loss: 0.4097 - acc: 0.8462 - binary_accuracy: 0.8969 - mean_absolute_error: 0.1712 - loss_no_weight_decay: 0.4097 - val_loss: 0.5498 - val_acc: 0.7500 - val_binary_accuracy: 0.8385 - val_mean_absolute_error: 0.2099 - val_loss_no_weight_decay: 0.5498
# — val_kappa: 0.616
#
# Epoch 00043: val_kappa did not improve from 0.74900
# Confusion matrix:
#  [[27  0  2]
#  [ 0  1  2]
#  [ 2  5 13]]
# Epoch 44/50
# 9/9 [==============================] - 12s 1s/step - loss: 0.3778 - acc: 0.8778 - binary_accuracy: 0.9185 - mean_absolute_error: 0.1583 - loss_no_weight_decay: 0.3778 - val_loss: 0.6337 - val_acc: 0.6346 - val_binary_accuracy: 0.7821 - val_mean_absolute_error: 0.2304 - val_loss_no_weight_decay: 0.6337
# — val_kappa: 0.6370967741935485
#
# Epoch 00044: val_kappa did not improve from 0.74900
# Confusion matrix:
#  [[23  1  1]
#  [ 0  2  4]
#  [ 3  8 10]]
# Epoch 45/50
# 9/9 [==============================] - 13s 1s/step - loss: 0.3822 - acc: 0.8559 - binary_accuracy: 0.9039 - mean_absolute_error: 0.1603 - loss_no_weight_decay: 0.3822 - val_loss: 0.4941 - val_acc: 0.7812 - val_binary_accuracy: 0.8490 - val_mean_absolute_error: 0.1999 - val_loss_no_weight_decay: 0.4941
# — val_kappa: 0.6428571428571428
#
# Epoch 00045: val_kappa did not improve from 0.74900
# Confusion matrix:
#  [[20  0  1]
#  [ 0  3  3]
#  [ 2  8 15]]
# Epoch 46/50
# 9/9 [==============================] - 11s 1s/step - loss: 0.3625 - acc: 0.8860 - binary_accuracy: 0.9188 - mean_absolute_error: 0.1533 - loss_no_weight_decay: 0.3625 - val_loss: 0.5649 - val_acc: 0.7115 - val_binary_accuracy: 0.8269 - val_mean_absolute_error: 0.1981 - val_loss_no_weight_decay: 0.5649
# — val_kappa: 0.5199999999999999
#
# Epoch 00046: val_kappa did not improve from 0.74900
# Confusion matrix:
#  [[26  1  0]
#  [ 0  5  1]
#  [ 3  3 13]]
# Epoch 47/50
# 9/9 [==============================] - 11s 1s/step - loss: 0.3458 - acc: 0.8655 - binary_accuracy: 0.9121 - mean_absolute_error: 0.1484 - loss_no_weight_decay: 0.3458 - val_loss: 0.5982 - val_acc: 0.7344 - val_binary_accuracy: 0.8177 - val_mean_absolute_error: 0.2146 - val_loss_no_weight_decay: 0.5982
# — val_kappa: 0.608695652173913
#
# Epoch 00047: val_kappa did not improve from 0.74900
# Confusion matrix:
#  [[23  1  1]
#  [ 0  3  1]
#  [ 2  5 16]]
# Epoch 48/50
# 9/9 [==============================] - 11s 1s/step - loss: 0.3492 - acc: 0.8760 - binary_accuracy: 0.9197 - mean_absolute_error: 0.1432 - loss_no_weight_decay: 0.3492 - val_loss: 0.4435 - val_acc: 0.8077 - val_binary_accuracy: 0.8654 - val_mean_absolute_error: 0.1679 - val_loss_no_weight_decay: 0.4435
# — val_kappa: 0.6692913385826772
#
# Epoch 00048: val_kappa did not improve from 0.74900
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Confusion matrix:
#  [[24  1  5]
#  [ 0  2  2]
#  [ 0  7 11]]
# Epoch 49/50
# 9/9 [==============================] - 9s 958ms/step - loss: 0.3774 - acc: 0.8694 - binary_accuracy: 0.9041 - mean_absolute_error: 0.1606 - loss_no_weight_decay: 0.3774 - val_loss: 0.4554 - val_acc: 0.7812 - val_binary_accuracy: 0.8542 - val_mean_absolute_error: 0.1775 - val_loss_no_weight_decay: 0.4554
# — val_kappa: 0.588235294117647
#
# Epoch 00049: val_kappa did not improve from 0.74900
# Confusion matrix:
#  [[27  0  2]
#  [ 0  4  3]
#  [ 3  5  8]]
# Epoch 50/50
# 9/9 [==============================] - 10s 1s/step - loss: 0.3361 - acc: 0.8750 - binary_accuracy: 0.9172 - mean_absolute_error: 0.1451 - loss_no_weight_decay: 0.3361 - val_loss: 0.5134 - val_acc: 0.8077 - val_binary_accuracy: 0.8526 - val_mean_absolute_error: 0.1928 - val_loss_no_weight_decay: 0.5134
# — val_kappa: 0.5952380952380953
#
# Epoch 00050: val_kappa did not improve from 0.74900
# Confusion matrix:
#  [[26  1  1]
#  [ 0  6  1]
#  [ 4  3 10]]
# 176/176 [==============================] - 5s 30ms/step
# 176/176 [==============================] - 5s 29ms/step
# Test loss: 0.4746877033683797
# Test accuracy: 0.7613636363636364
# Confusion Matrix
# [[81  0  7]
#  [ 0 15  4]
#  [ 5 26 38]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.94      0.92      0.93        88
#            1       0.37      0.79      0.50        19
#            2       0.78      0.55      0.64        69
#
#     accuracy                           0.76       176
#    macro avg       0.69      0.75      0.69       176
# weighted avg       0.81      0.76      0.77       176

# %%
from Kappa_Skl import kappa
def kappa2(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    if len(y_true.shape) > 1 and y_true.shape[1] > 1:
        y_true = y_true.dot(range(y_true.shape[1]))
    if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
        y_pred = y_pred.dot(range(y_pred.shape[1]))
    try:
        return kappa(y_true, y_pred, weights='quadratic')
    except IndexError:
        return np.nan
    
print('Quadratic_wieghted_kappa')
print(kappa2(y_true, y_pred))
# Out:
# Quadratic_wieghted_kappa
# 0.7253631016684672

# %%
import numpy as np 
import matplotlib.pyplot as plt
import os
import wandb
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_acc', 'val_binary_accuracy', 'val_mean_absolute_error', 'val_loss_no_weight_decay', 'loss', 'acc', 'binary_accuracy', 'mean_absolute_error', 'loss_no_weight_decay', 'val_kappa', 'lr'])

# %%
# list all data in history
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model loss.png')

# summarize history for val_kappa
plt.plot(history.history['val_kappa'])
plt.title('Validation_Kappa')
plt.ylabel('val_kappa')
plt.xlabel('epoch')
plt.legend([ 'validation'], loc='upper left')
plt.show()
#plt.savefig('model validation_kappa.png')

# summarize history for mean_absolute _error
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model mean_absolute_error')
plt.ylabel('mean_absolute_error')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model maey.png')
# Out:
# dict_keys(['val_loss', 'val_acc', 'val_binary_accuracy', 'val_mean_absolute_error', 'val_loss_no_weight_decay', 'loss', 'acc', 'binary_accuracy', 'mean_absolute_error', 'loss_no_weight_decay', 'val_kappa', 'lr'])
