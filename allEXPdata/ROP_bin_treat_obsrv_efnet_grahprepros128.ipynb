# %%
import efficientnet.keras as efn
from keras.models import Model, model_from_json
from keras.regularizers import l1_l2
from keras.layers import Dense, Dropout
from keras.optimizers import SGD, Adam
import pandas as pd
from keras_preprocessing.image import ImageDataGenerator
from datetime import datetime as dt
from sklearn.utils import class_weight
from keras.callbacks import EarlyStopping, ModelCheckpoint,LearningRateScheduler, TensorBoard
import keras.backend as K
from VCM import VCM 
from keras.initializers import Constant,Orthogonal
from keras import regularizers
from Kappa_Skl import kappa
import keras.backend as K
import matplotlib.pyplot as plt
import itertools
from Homotopy import Homotopy 
from QWK import QWK
import tensorflow as tf
from Fractional_MAXPOOL import FractionalPooling2D

import numpy as np 
import matplotlib.pyplot as plt
import os
import wandb
#from wandb.keras import WandbCallback
#wandb.init(project="rop")


top_layers_checkpoint_path = 'cp.top.best.hdf5'
fine_tuned_checkpoint_path = 'cp.fine_tuned.best.hdf5'
new_extended_inception_weights = 'final_weights.hdf5'





def get_experiment_id():
    time_str = dt.now().strftime('%Y-%m-%d-%H-%M-%S')
    experiment_id = 'base_{}'.format(time_str)
    return experiment_id

#def scheduler(epoch):
#    if epoch == 150:
#        K.set_value(model.optimizer.lr, 0.00003)
#    return K.get_value(model.optimizer.lr)


def create_model():
    base_model = efn.EfficientNetB0(weights=None,
                        include_top=False,
                        input_shape=(128, 128, 3), pooling='avg')
#    base_model._layers.pop()
#    model2 = Model(base_model.input, base_model.layers[-1].output)
##    base_model = InceptionV3(weights=None , include_top=False, input_tensor=None, input_shape=(299, 299, 3), pooling='avg') 
    x = base_model.output
    x = Dense(2, activation="softmax")(x)
    model = Model(inputs = base_model.input, outputs = x)
    model.load_weights('base_2019-12-11-23-01-58-val_kappa_checkpoint.hdf5')
#    model._layers.pop()
#    x = Model(model.input, model.layers[-1].output)
#    model.save_weights("tmp.h5")
#    top_layers_checkpoint_path = 'cp.top.best.hdf5'

#    # first: train only the top layers (which were randomly initialized)
#    # i.e. freeze all convolutional InceptionV3 layers
    for layer in base_model.layers:
        layer.trainable = False
#    
#    
#
##    regularizer = l1_l2(l1=0.0005, l2=0.0005)
##    for layer in model.layers:
##        for attr in ['kernel_regularizer', 'bias_regularizer']:
##            if hasattr(layer, attr) and layer.trainable:
##                setattr(layer, attr, regularizer)
#
##
#    out = model_from_json(model.to_json())
#    out.load_weights("tmp.h5", by_name=True)
#
    return model


model = create_model()




radam = Adam(lr=0.0014339, beta_1=0.9, beta_2=0.999, epsilon=0.1, decay=1e-6, amsgrad=False)
model.compile(loss='categorical_crossentropy', optimizer=radam, metrics=['mae','acc'])

#sgd = SGD(lr=0.0003, decay=1e-6, momentum=0.9, nesterov=True)
#model.compile(loss='mse', optimizer=sgd, metrics=['mae', 'acc'])

experiment_id = get_experiment_id()


train_datagen = ImageDataGenerator(
        rescale=1./255,
#        featurewise_center=True,
 #       samplewise_center=True,
        shear_range=0,
        zoom_range=0.0,#[1 / 1.15, 1.15],
        horizontal_flip=False,#True,
        rotation_range=0)#90,
#        validation_split=0.2)
"""
For the test set only rescale should be made 
"""
test_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_class_treatment_grah/train",
    target_size=(128, 128),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="training")
#    save_to_dir="D:/Separating Images into subfolders/train_augmented")


#print(train_generator.class_indices)

valid_generator = valid_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_class_treatment_grah/vald",
    target_size=(128, 128),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="validation")
#    save_to_dir="D:/Separating Images into subfolders/val_augmented"


test_generator = test_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_class_treatment_grah/test",
    target_size=(128, 128),
    color_mode="rgb",
    batch_size=1,
    class_mode="categorical",
    shuffle=False,
    seed=42)
#    save_to_dir="D:/Separating Images into subfolders/test_augmented")


# Fitting/Training the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
experiment_id = get_experiment_id()


class_weight_list = class_weight.compute_class_weight('balanced', np.unique(train_generator.classes), train_generator.classes)
class_weights = dict(zip(np.unique(train_generator.classes), class_weight_list))

callbacks = [
#    Resample_Iterator(balance_weights),
#    QWK(valid_generator, STEP_SIZE_VALID),
    ModelCheckpoint(top_layers_checkpoint_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max'),
#    EarlyStopping(monitor='val_kappa', patience=10, min_delta=0.001, verbose=1, restore_best_weights=True, mode='max',baseline=None),
    VCM(valid_generator, STEP_SIZE_VALID),
#    LearningRateScheduler(scheduler, verbose=1),
 #   TensorBoard(log_dir='./Graph', histogram_freq=0, write_graph=True, write_images=True),        
]




# train the model on the new data for a few epochs

history1=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
#                    class_weight=[balance_weights],
                    callbacks=callbacks,
                    epochs=10  
)


 

callbacks1 = [
#    Resample_Iterator(balance_weights1),
#    QWK(valid_generator, STEP_SIZE_VALID),
    ModelCheckpoint(fine_tuned_checkpoint_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max'),
#    EarlyStopping(monitor='val_kappa', patience=20, min_delta=0.001, verbose=1, restore_best_weights=True, mode='max',baseline=None),
    VCM(valid_generator, STEP_SIZE_VALID),
#    LearningRateScheduler(scheduler, verbose=1),
#    TensorBoard(log_dir='./Graph', histogram_freq=0, write_graph=True, write_images=True),        
]



for layer in model.layers:
    layer.trainable = True
    
    
    
    
radam = Adam(lr=0.0014339, beta_1=0.9, beta_2=0.999, epsilon=0.1, decay=1e-6, amsgrad=False)
model.compile(loss='categorical_crossentropy', optimizer=radam, metrics=['mae','acc'])



# we train our model again (this time fine-tuning the top 2 inception blocks
# alongside the top Dense layers
history=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
#                    class_weight=[balance_weights1],
                    callbacks=callbacks1,
                    epochs=30) 




test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1']
print(classification_report(y_true, y_pred, target_names=target_names))
                    
                    
# list all data in history
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model loss.png')

# summarize history for val_kappa
plt.plot(history.history['val_kappa'])
plt.title('Validation_Kappa')
plt.ylabel('val_kappa')
plt.xlabel('epoch')
plt.legend([ 'validation'], loc='upper left')
plt.show()
#plt.savefig('model validation_kappa.png')

# summarize history for mean_absolute _error
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model mean_absolute_error')
plt.ylabel('mean_absolute_error')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model maey.png')
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Found 294 images belonging to 2 classes.
# Found 58 images belonging to 2 classes.
# Found 88 images belonging to 2 classes.
# Epoch 1/10
# 4/4 [==============================] - 3s 860ms/step - loss: 1.5907 - mean_absolute_error: 0.6327 - acc: 0.3117 - val_loss: 1.3167 - val_mean_absolute_error: 0.6396 - val_acc: 0.2759
#
# Epoch 00001: val_acc improved from -inf to 0.27586, saving model to cp.top.best.hdf5
# Confusion matrix:
#  []
# Epoch 2/10
# 4/4 [==============================] - 1s 134ms/step - loss: 1.6301 - mean_absolute_error: 0.6665 - acc: 0.2752 - val_loss: 1.3077 - val_mean_absolute_error: 0.6387 - val_acc: 0.2759
#
# Epoch 00002: val_acc did not improve from 0.27586
# Confusion matrix:
#  []
# Epoch 3/10
# 4/4 [==============================] - 1s 167ms/step - loss: 1.4086 - mean_absolute_error: 0.6029 - acc: 0.3474 - val_loss: 1.2970 - val_mean_absolute_error: 0.6377 - val_acc: 0.2759
#
# Epoch 00003: val_acc did not improve from 0.27586
# Confusion matrix:
#  []
# Epoch 4/10
# 4/4 [==============================] - 1s 155ms/step - loss: 1.5050 - mean_absolute_error: 0.6417 - acc: 0.3253 - val_loss: 1.2852 - val_mean_absolute_error: 0.6365 - val_acc: 0.2759
#
# Epoch 00004: val_acc did not improve from 0.27586
# Confusion matrix:
#  []
# Epoch 5/10
# 4/4 [==============================] - 1s 167ms/step - loss: 1.3818 - mean_absolute_error: 0.6167 - acc: 0.3359 - val_loss: 1.2723 - val_mean_absolute_error: 0.6352 - val_acc: 0.2586
#
# Epoch 00005: val_acc did not improve from 0.27586
# Confusion matrix:
#  []
# Epoch 6/10
# 4/4 [==============================] - 1s 154ms/step - loss: 1.3166 - mean_absolute_error: 0.6106 - acc: 0.3327 - val_loss: 1.2583 - val_mean_absolute_error: 0.6336 - val_acc: 0.2586
#
# Epoch 00006: val_acc did not improve from 0.27586
# Confusion matrix:
#  []
# Epoch 7/10
# 4/4 [==============================] - 1s 158ms/step - loss: 1.1775 - mean_absolute_error: 0.5830 - acc: 0.3649 - val_loss: 1.2446 - val_mean_absolute_error: 0.6321 - val_acc: 0.2586
#
# Epoch 00007: val_acc did not improve from 0.27586
# Confusion matrix:
#  []
# Epoch 8/10
# 4/4 [==============================] - 1s 177ms/step - loss: 1.1080 - mean_absolute_error: 0.5667 - acc: 0.3828 - val_loss: 1.2300 - val_mean_absolute_error: 0.6303 - val_acc: 0.2586
#
# Epoch 00008: val_acc did not improve from 0.27586
# Confusion matrix:
#  []
# Epoch 9/10
# 4/4 [==============================] - 1s 164ms/step - loss: 1.0076 - mean_absolute_error: 0.5402 - acc: 0.4478 - val_loss: 1.2158 - val_mean_absolute_error: 0.6285 - val_acc: 0.2586
#
# Epoch 00009: val_acc did not improve from 0.27586
# Confusion matrix:
#  []
# Epoch 10/10
# 4/4 [==============================] - 1s 145ms/step - loss: 0.9298 - mean_absolute_error: 0.5291 - acc: 0.4613 - val_loss: 1.2023 - val_mean_absolute_error: 0.6267 - val_acc: 0.2586
#
# Epoch 00010: val_acc did not improve from 0.27586
# Confusion matrix:
#  []
# Epoch 1/30
# 4/4 [==============================] - 11s 3s/step - loss: 0.8619 - mean_absolute_error: 0.4981 - acc: 0.5040 - val_loss: 0.8999 - val_mean_absolute_error: 0.4991 - val_acc: 0.4483
#
# Epoch 00001: val_acc improved from -inf to 0.44828, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  []
# Epoch 2/30
# 4/4 [==============================] - 1s 312ms/step - loss: 0.8692 - mean_absolute_error: 0.5054 - acc: 0.4766 - val_loss: 0.8761 - val_mean_absolute_error: 0.4943 - val_acc: 0.4310
#
# Epoch 00002: val_acc did not improve from 0.44828
# Confusion matrix:
#  []
# Epoch 3/30
# 4/4 [==============================] - 1s 280ms/step - loss: 0.8782 - mean_absolute_error: 0.5062 - acc: 0.4720 - val_loss: 0.8575 - val_mean_absolute_error: 0.4892 - val_acc: 0.4483
#
# Epoch 00003: val_acc did not improve from 0.44828
# Confusion matrix:
#  []
# Epoch 4/30
# 4/4 [==============================] - 1s 285ms/step - loss: 0.7488 - mean_absolute_error: 0.4578 - acc: 0.5623 - val_loss: 0.8376 - val_mean_absolute_error: 0.4845 - val_acc: 0.4483
#
# Epoch 00004: val_acc did not improve from 0.44828
# Confusion matrix:
#  []
# Epoch 5/30
# 4/4 [==============================] - 1s 282ms/step - loss: 0.8009 - mean_absolute_error: 0.4814 - acc: 0.5111 - val_loss: 0.8081 - val_mean_absolute_error: 0.4771 - val_acc: 0.4655
#
# Epoch 00005: val_acc improved from 0.44828 to 0.46552, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  []
# Epoch 6/30
# 4/4 [==============================] - 1s 291ms/step - loss: 0.7012 - mean_absolute_error: 0.4382 - acc: 0.6004 - val_loss: 0.7875 - val_mean_absolute_error: 0.4710 - val_acc: 0.4828
#
# Epoch 00006: val_acc improved from 0.46552 to 0.48276, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  []
# Epoch 7/30
# 4/4 [==============================] - 1s 296ms/step - loss: 0.6084 - mean_absolute_error: 0.4057 - acc: 0.6407 - val_loss: 0.7715 - val_mean_absolute_error: 0.4661 - val_acc: 0.4655
#
# Epoch 00007: val_acc did not improve from 0.48276
# Confusion matrix:
#  []
# Epoch 8/30
# 4/4 [==============================] - 1s 322ms/step - loss: 0.5919 - mean_absolute_error: 0.3962 - acc: 0.6953 - val_loss: 0.7519 - val_mean_absolute_error: 0.4590 - val_acc: 0.4828
#
# Epoch 00008: val_acc did not improve from 0.48276
# Confusion matrix:
#  []
# Epoch 9/30
# 4/4 [==============================] - 1s 262ms/step - loss: 0.5282 - mean_absolute_error: 0.3671 - acc: 0.7293 - val_loss: 0.7333 - val_mean_absolute_error: 0.4520 - val_acc: 0.4828
#
# Epoch 00009: val_acc did not improve from 0.48276
# Confusion matrix:
#  []
# Epoch 10/30
# 4/4 [==============================] - 1s 318ms/step - loss: 0.5214 - mean_absolute_error: 0.3569 - acc: 0.7383 - val_loss: 0.7177 - val_mean_absolute_error: 0.4456 - val_acc: 0.5345
#
# Epoch 00010: val_acc improved from 0.48276 to 0.53448, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  []
# Epoch 11/30
# 4/4 [==============================] - 1s 288ms/step - loss: 0.4902 - mean_absolute_error: 0.3485 - acc: 0.7531 - val_loss: 0.7043 - val_mean_absolute_error: 0.4392 - val_acc: 0.5517
#
# Epoch 00011: val_acc improved from 0.53448 to 0.55172, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  []
# Epoch 12/30
# 4/4 [==============================] - 1s 315ms/step - loss: 0.4459 - mean_absolute_error: 0.3202 - acc: 0.8008 - val_loss: 0.6940 - val_mean_absolute_error: 0.4341 - val_acc: 0.5690
#
# Epoch 00012: val_acc improved from 0.55172 to 0.56897, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  []
# Epoch 13/30
# 4/4 [==============================] - 1s 288ms/step - loss: 0.4144 - mean_absolute_error: 0.3052 - acc: 0.8412 - val_loss: 0.6820 - val_mean_absolute_error: 0.4279 - val_acc: 0.5690
#
# Epoch 00013: val_acc did not improve from 0.56897
# Confusion matrix:
#  []
# Epoch 14/30
# 4/4 [==============================] - 1s 287ms/step - loss: 0.4047 - mean_absolute_error: 0.2977 - acc: 0.8274 - val_loss: 0.6704 - val_mean_absolute_error: 0.4219 - val_acc: 0.5690
#
# Epoch 00014: val_acc did not improve from 0.56897
# Confusion matrix:
#  []
# Epoch 15/30
# 4/4 [==============================] - 1s 288ms/step - loss: 0.3774 - mean_absolute_error: 0.2811 - acc: 0.8569 - val_loss: 0.6645 - val_mean_absolute_error: 0.4180 - val_acc: 0.5690
#
# Epoch 00015: val_acc did not improve from 0.56897
# Confusion matrix:
#  []
# Epoch 16/30
# 4/4 [==============================] - 1s 293ms/step - loss: 0.3679 - mean_absolute_error: 0.2737 - acc: 0.8532 - val_loss: 0.6553 - val_mean_absolute_error: 0.4124 - val_acc: 0.5862
#
# Epoch 00016: val_acc improved from 0.56897 to 0.58621, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  []
# Epoch 17/30
# 4/4 [==============================] - 1s 288ms/step - loss: 0.3276 - mean_absolute_error: 0.2539 - acc: 0.9073 - val_loss: 0.6492 - val_mean_absolute_error: 0.4086 - val_acc: 0.6034
#
# Epoch 00017: val_acc improved from 0.58621 to 0.60345, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  []
# Epoch 18/30
# 4/4 [==============================] - 1s 320ms/step - loss: 0.2955 - mean_absolute_error: 0.2340 - acc: 0.9102 - val_loss: 0.6450 - val_mean_absolute_error: 0.4051 - val_acc: 0.6552
#
# Epoch 00018: val_acc improved from 0.60345 to 0.65517, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  []
# Epoch 19/30
# 4/4 [==============================] - 1s 300ms/step - loss: 0.2735 - mean_absolute_error: 0.2209 - acc: 0.9318 - val_loss: 0.6385 - val_mean_absolute_error: 0.4007 - val_acc: 0.6552
# Epoch 00019: val_acc did not improve from 0.65517
# Confusion matrix:
#  []
# Epoch 20/30
# 4/4 [==============================] - 1s 287ms/step - loss: 0.2805 - mean_absolute_error: 0.2235 - acc: 0.9177 - val_loss: 0.6362 - val_mean_absolute_error: 0.3985 - val_acc: 0.6552
#
# Epoch 00020: val_acc did not improve from 0.65517
# Confusion matrix:
#  []
# Epoch 21/30
# 4/4 [==============================] - 1s 285ms/step - loss: 0.2656 - mean_absolute_error: 0.2145 - acc: 0.9358 - val_loss: 0.6336 - val_mean_absolute_error: 0.3964 - val_acc: 0.6552
#
# Epoch 00021: val_acc did not improve from 0.65517
# Confusion matrix:
#  []
# Epoch 22/30
# 4/4 [==============================] - 1s 308ms/step - loss: 0.2449 - mean_absolute_error: 0.1993 - acc: 0.9492 - val_loss: 0.6312 - val_mean_absolute_error: 0.3940 - val_acc: 0.6552
#
# Epoch 00022: val_acc did not improve from 0.65517
# Confusion matrix:
#  []
# Epoch 23/30
# 4/4 [==============================] - 1s 270ms/step - loss: 0.2464 - mean_absolute_error: 0.2013 - acc: 0.9566 - val_loss: 0.6321 - val_mean_absolute_error: 0.3926 - val_acc: 0.6552
#
# Epoch 00023: val_acc did not improve from 0.65517
# Confusion matrix:
#  []
# Epoch 24/30
# 4/4 [==============================] - 1s 286ms/step - loss: 0.2493 - mean_absolute_error: 0.1957 - acc: 0.9361 - val_loss: 0.6291 - val_mean_absolute_error: 0.3895 - val_acc: 0.6552
#
# Epoch 00024: val_acc did not improve from 0.65517
# Confusion matrix:
#  []
# Epoch 25/30
# 4/4 [==============================] - 1s 310ms/step - loss: 0.2187 - mean_absolute_error: 0.1772 - acc: 0.9648 - val_loss: 0.6289 - val_mean_absolute_error: 0.3875 - val_acc: 0.6379
#
# Epoch 00025: val_acc did not improve from 0.65517
# Confusion matrix:
#  []
# Epoch 26/30
# 4/4 [==============================] - 1s 286ms/step - loss: 0.2074 - mean_absolute_error: 0.1725 - acc: 0.9475 - val_loss: 0.6278 - val_mean_absolute_error: 0.3854 - val_acc: 0.6552
#
# Epoch 00026: val_acc did not improve from 0.65517
# Confusion matrix:
#  []
# Epoch 27/30
# 4/4 [==============================] - 1s 311ms/step - loss: 0.1911 - mean_absolute_error: 0.1605 - acc: 0.9805 - val_loss: 0.6240 - val_mean_absolute_error: 0.3822 - val_acc: 0.6724
#
# Epoch 00027: val_acc improved from 0.65517 to 0.67241, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  []
# Epoch 28/30
# 4/4 [==============================] - 1s 288ms/step - loss: 0.1850 - mean_absolute_error: 0.1559 - acc: 0.9760 - val_loss: 0.6218 - val_mean_absolute_error: 0.3802 - val_acc: 0.6897
#
# Epoch 00028: val_acc improved from 0.67241 to 0.68966, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  []
# Epoch 29/30
# 4/4 [==============================] - 1s 261ms/step - loss: 0.2114 - mean_absolute_error: 0.1690 - acc: 0.9420 - val_loss: 0.6206 - val_mean_absolute_error: 0.3776 - val_acc: 0.6897
#
# Epoch 00029: val_acc did not improve from 0.68966
# Confusion matrix:
#  []
# Epoch 30/30
# 4/4 [==============================] - 1s 310ms/step - loss: 0.1819 - mean_absolute_error: 0.1543 - acc: 0.9844 - val_loss: 0.6210 - val_mean_absolute_error: 0.3766 - val_acc: 0.6897
#
# Epoch 00030: val_acc did not improve from 0.68966
# Confusion matrix:
#  []
# 88/88 [==============================] - 2s 20ms/step
# 88/88 [==============================] - 1s 9ms/step
# Test loss: 0.33088899790362286
# Test accuracy: 0.23766145151669413
# Confusion Matrix
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1964f6105b9f> in <module>
#     246 # generator.classes gives you the truth label y_true
#     247 print('Confusion Matrix')
# --> 248 cm = confusion_matrix(y_true, y_pred)
#     249
#     250 print(cm)
#
# NameError: name 'confusion_matrix' is not defined

# %%
from sklearn.metrics import confusion_matrix, classification_report

test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# 88/88 [==============================] - 1s 9ms/step
# 88/88 [==============================] - 1s 9ms/step
# Test loss: 0.33088899790362286
# Test accuracy: 0.23766145151669413
# Confusion Matrix
# [[12 10]
#  [ 3 63]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.80      0.55      0.65        22
#            1       0.86      0.95      0.91        66
#
#     accuracy                           0.85        88
#    macro avg       0.83      0.75      0.78        88
# weighted avg       0.85      0.85      0.84        88

# %%
def kappa2(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    if len(y_true.shape) > 1 and y_true.shape[1] > 1:
        y_true = y_true.dot(range(y_true.shape[1]))
    if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
        y_pred = y_pred.dot(range(y_pred.shape[1]))
    try:
        return kappa(y_true, y_pred, weights='quadratic')
    except IndexError:
        return np.nan
    
print('Quadratic_wieghted_kappa')
print(kappa2(y_true, y_pred))
# Out:
# Quadratic_wieghted_kappa
# 0.5593220338983051

# %%
import numpy as np 
import matplotlib.pyplot as plt
import os
import wandb
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model loss.png')

# summarize history for val_kappa
plt.plot(history.history['val_kappa'])
plt.title('Validation_Kappa')
plt.ylabel('val_kappa')
plt.xlabel('epoch')
plt.legend([ 'validation'], loc='upper left')
plt.show()
#plt.savefig('model validation_kappa.png')

# summarize history for mean_absolute _error
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model mean_absolute_error')
plt.ylabel('mean_absolute_error')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model maey.png'
# Out:
# dict_keys(['val_loss', 'val_mean_absolute_error', 'val_acc', 'loss', 'mean_absolute_error', 'acc'])
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-511ccd1e0b9e> in <module>
#      24
#      25 # summarize history for val_kappa
# ---> 26 plt.plot(history.history['val_kappa'])
#      27 plt.title('Validation_Kappa')
#      28 plt.ylabel('val_kappa')
#
# KeyError: 'val_kappa'
