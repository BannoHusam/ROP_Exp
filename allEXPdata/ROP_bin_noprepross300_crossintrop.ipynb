# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, InputLayer
from keras.regularizers import L1L2, l2, l1
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from custom_pooling import RMSPooling2D
from keras.optimizers import SGD, Adam
from keras.layers import LeakyReLU
#from data import BALANCE_WEIGHTS
from keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
#import os
from datetime import datetime as dt
from custom_loss import WeightedCategoricalCrossEntropy
from VCM import VCM
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
def get_experiment_id():
    time_str = dt.now().strftime('%Y-%m-%d-%H-%M-%S')
    experiment_id = 'base_{}'.format(time_str)
    return experiment_id
p_ratio=[1.0, 1.44, 1.73, 1.0]

model = Sequential()


model.add(Conv2D(16, (5, 5), activation='tanh', input_shape=(300, 300, 3)))
model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(16, (3, 3), activation='tanh'))
model.add(Conv2D(16, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))

#model.add(LeakyReLU(alpha=0.01))


model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))



model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))          
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(MaxPooling2D(pool_size=2))
#model.add(MaxPooling2D(pool_size=1))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
model.add(MaxPooling2D(pool_size=2))

model.add(Flatten())


#chnaged from 10 to 5 because an error 
model.add(Dense(2, activation='softmax'))

sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.count_params()
#adam = Adam(lr=0.0005, decay=1e-6)
#rmsprop
#Mloss = WeightedCategoricalCrossEntropy({0: 0.4125861396437394, 1: 1.4918664786083686, 2: 0.690426457789382, 3: 3.9541433021806855, 4: 4.885604311008468})
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['mae','acc'])
model.summary()
loss_no_weight_decay = model.total_loss - sum(model.losses)
model.metrics_tensors.append(loss_no_weight_decay)
model.metrics_names.append('loss_no_weight_decay')
#############################################################################################
#############################################################################################
#############################################################################################
#############################################################################################
#Preparing Data Augmentation Configuration 
train_datagen = ImageDataGenerator(
        rescale=1./255,
#        featurewise_center=True,
 #       samplewise_center=True,
        shear_range=0,
        zoom_range=0.0,#[1 / 1.15, 1.15],
        horizontal_flip=False,#True,
        rotation_range=0)#90,
#        validation_split=0.2)
"""
For the test set only rescale should be made 
"""
test_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas/train",
    target_size=(300, 300),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="training")
#    save_to_dir="D:/Separating Images into subfolders/train_augmented")


#print(train_generator.class_indices)

valid_generator = valid_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas/vald",
    target_size=(300, 300),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="validation")
#    save_to_dir="D:/Separating Images into subfolders/val_augmented"


test_generator = test_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas/test",
    target_size=(300, 300),
    color_mode="rgb",
    batch_size=1,
    class_mode="categorical",
    shuffle=False,
    seed=42)
#    save_to_dir="D:/Separating Images into subfolders/test_augmented")


# Fitting/Training the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
experiment_id = get_experiment_id()
callbacks = [
    EarlyStopping(monitor='val_acc', patience=50, min_delta=0.001, verbose=1),
    ModelCheckpoint(experiment_id + "-val_acc_checkpoint.hdf5", monitor='val_acc', verbose=1, save_best_only=True, mode='auto'),
    ReduceLROnPlateau(monitor='val_acc', factor=0.5, patience=7, verbose=1, mode='auto', min_delta=0.001, cooldown=0, min_lr=1e-7),
    VCM(valid_generator,STEP_SIZE_VALID)
    
]

class_weight_list = class_weight.compute_class_weight('balanced', np.unique(train_generator.classes), train_generator.classes)
class_weights = dict(zip(np.unique(train_generator.classes), class_weight_list))

history=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    class_weight=class_weights,
                    callbacks=callbacks,
                    epochs=35  
)


# Evaluating the model 
#predicting output
#reseting the test generator before calling predict_generator, in order not to get weird output
test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 296, 296, 16)      1216
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 292, 292, 16)      6416
# _________________________________________________________________
# input_1 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 290, 290, 16)      2320
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 288, 288, 16)      2320
# _________________________________________________________________
# input_2 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 284, 284, 16)      6416
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 280, 280, 16)      6416
# _________________________________________________________________
# input_3 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 276, 276, 16)      6416
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 272, 272, 16)      6416
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 136, 136, 16)      0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 134, 134, 32)      4640
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 132, 132, 32)      9248
# _________________________________________________________________
# input_4 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 130, 130, 32)      9248
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 128, 128, 32)      9248
# _________________________________________________________________
# input_5 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 126, 126, 32)      9248
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 124, 124, 32)      9248
# _________________________________________________________________
# input_6 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 122, 122, 32)      9248
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 120, 120, 32)      9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 60, 60, 32)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 58, 58, 64)        18496
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 56, 56, 64)        36928
# _________________________________________________________________
# input_7 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 54, 54, 64)        36928
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 52, 52, 64)        36928
# _________________________________________________________________
# input_8 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 50, 50, 64)        36928
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 48, 48, 64)        36928
# _________________________________________________________________
# input_9 (InputLayer)         multiple                  0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 22, 22, 64)        36928
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 20, 20, 64)        36928
# _________________________________________________________________
# input_10 (InputLayer)        multiple                  0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 18, 18, 64)        36928
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# input_11 (InputLayer)        multiple                  0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 8194
# =================================================================
# Total params: 466,354
# Trainable params: 466,354
# Non-trainable params: 0
# _________________________________________________________________
# Found 588 images belonging to 2 classes.
# Found 116 images belonging to 2 classes.
# Found 176 images belonging to 2 classes.
# Epoch 1/35
# 9/9 [==============================] - 29s 3s/step - loss: 0.7005 - mean_absolute_error: 0.4975 - acc: 0.4925 - loss_no_weight_decay: 0.7005 - val_loss: 0.7069 - val_mean_absolute_error: 0.5056 - val_acc: 0.4219 - val_loss_no_weight_decay: 0.7069
#
# Epoch 00001: val_acc improved from -inf to 0.42188, saving model to base_2020-05-07-23-53-58-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[ 0 32]
#  [ 0 32]]
# Epoch 2/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.6916 - mean_absolute_error: 0.4976 - acc: 0.5293 - loss_no_weight_decay: 0.6916 - val_loss: 0.6764 - val_mean_absolute_error: 0.4903 - val_acc: 0.5962 - val_loss_no_weight_decay: 0.6764
#
# Epoch 00002: val_acc improved from 0.42188 to 0.59615, saving model to base_2020-05-07-23-53-58-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[ 0 27]
#  [ 0 25]]
# Epoch 3/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.6901 - mean_absolute_error: 0.4976 - acc: 0.5015 - loss_no_weight_decay: 0.6901 - val_loss: 0.6839 - val_mean_absolute_error: 0.4952 - val_acc: 0.6250 - val_loss_no_weight_decay: 0.6839
#
# Epoch 00003: val_acc improved from 0.59615 to 0.62500, saving model to base_2020-05-07-23-53-58-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[ 7 21]
#  [ 1 35]]
# Epoch 4/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.6801 - mean_absolute_error: 0.4932 - acc: 0.6510 - loss_no_weight_decay: 0.6801 - val_loss: 0.6702 - val_mean_absolute_error: 0.4882 - val_acc: 0.7308 - val_loss_no_weight_decay: 0.6702
#
# Epoch 00004: val_acc improved from 0.62500 to 0.73077, saving model to base_2020-05-07-23-53-58-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[15 11]
#  [ 7 19]]
# Epoch 5/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.6674 - mean_absolute_error: 0.4861 - acc: 0.6784 - loss_no_weight_decay: 0.6674 - val_loss: 0.6252 - val_mean_absolute_error: 0.4630 - val_acc: 0.7344 - val_loss_no_weight_decay: 0.6252
#
# Epoch 00005: val_acc improved from 0.73077 to 0.73438, saving model to base_2020-05-07-23-53-58-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[15 15]
#  [ 9 25]]
# Epoch 6/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.6249 - mean_absolute_error: 0.4590 - acc: 0.7062 - loss_no_weight_decay: 0.6249 - val_loss: 0.6237 - val_mean_absolute_error: 0.4560 - val_acc: 0.6154 - val_loss_no_weight_decay: 0.6237
#
# Epoch 00006: val_acc did not improve from 0.73438
# Confusion matrix:
#  [[25  2]
#  [14 11]]
# Epoch 7/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.6050 - mean_absolute_error: 0.4394 - acc: 0.6953 - loss_no_weight_decay: 0.6050 - val_loss: 0.5404 - val_mean_absolute_error: 0.4024 - val_acc: 0.7656 - val_loss_no_weight_decay: 0.5404
#
# Epoch 00007: val_acc improved from 0.73438 to 0.76562, saving model to base_2020-05-07-23-53-58-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[24  6]
#  [14 20]]
# Epoch 8/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.5846 - mean_absolute_error: 0.4266 - acc: 0.7240 - loss_no_weight_decay: 0.5846 - val_loss: 0.5560 - val_mean_absolute_error: 0.3942 - val_acc: 0.7500 - val_loss_no_weight_decay: 0.5560
#
# Epoch 00008: val_acc did not improve from 0.76562
# Confusion matrix:
#  [[16 10]
#  [ 4 22]]
# Epoch 9/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.5236 - mean_absolute_error: 0.3766 - acc: 0.7588 - loss_no_weight_decay: 0.5236 - val_loss: 0.4649 - val_mean_absolute_error: 0.3339 - val_acc: 0.8125 - val_loss_no_weight_decay: 0.4649
#
# Epoch 00009: val_acc improved from 0.76562 to 0.81250, saving model to base_2020-05-07-23-53-58-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[19 12]
#  [ 5 28]]
# Epoch 10/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.5704 - mean_absolute_error: 0.3937 - acc: 0.7027 - loss_no_weight_decay: 0.5704 - val_loss: 0.5205 - val_mean_absolute_error: 0.3759 - val_acc: 0.7692 - val_loss_no_weight_decay: 0.5205
#
# Epoch 00010: val_acc did not improve from 0.81250
# Confusion matrix:
#  [[21  6]
#  [ 2 23]]
# Epoch 11/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.5119 - mean_absolute_error: 0.3624 - acc: 0.7680 - loss_no_weight_decay: 0.5119 - val_loss: 0.4902 - val_mean_absolute_error: 0.3584 - val_acc: 0.7969 - val_loss_no_weight_decay: 0.4902
#
# Epoch 00011: val_acc did not improve from 0.81250
# Confusion matrix:
#  [[21  9]
#  [ 5 29]]
# Epoch 12/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.4670 - mean_absolute_error: 0.3399 - acc: 0.8144 - loss_no_weight_decay: 0.4670 - val_loss: 0.5752 - val_mean_absolute_error: 0.3934 - val_acc: 0.6346 - val_loss_no_weight_decay: 0.5752
#
# Epoch 00012: val_acc did not improve from 0.81250
# Confusion matrix:
#  [[20  3]
#  [15 14]]
# Epoch 13/35
# 9/9 [==============================] - 16s 2s/step - loss: 0.5298 - mean_absolute_error: 0.3558 - acc: 0.7528 - loss_no_weight_decay: 0.5298 - val_loss: 0.4956 - val_mean_absolute_error: 0.3545 - val_acc: 0.7969 - val_loss_no_weight_decay: 0.4956
#
# Epoch 00013: val_acc did not improve from 0.81250
# Confusion matrix:
#  [[25  7]
#  [ 6 26]]
# Epoch 14/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.4425 - mean_absolute_error: 0.3237 - acc: 0.8196 - loss_no_weight_decay: 0.4425 - val_loss: 0.5069 - val_mean_absolute_error: 0.3482 - val_acc: 0.6731 - val_loss_no_weight_decay: 0.5069
#
# Epoch 00014: val_acc did not improve from 0.81250
# Confusion matrix:
#  [[ 8 11]
#  [ 6 27]]
# Epoch 15/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.4550 - mean_absolute_error: 0.3168 - acc: 0.7706 - loss_no_weight_decay: 0.4550 - val_loss: 0.3386 - val_mean_absolute_error: 0.2488 - val_acc: 0.8906 - val_loss_no_weight_decay: 0.3386
#
# Epoch 00015: val_acc improved from 0.81250 to 0.89062, saving model to base_2020-05-07-23-53-58-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[24  3]
#  [ 7 30]]
# Epoch 16/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.4133 - mean_absolute_error: 0.2939 - acc: 0.8166 - loss_no_weight_decay: 0.4133 - val_loss: 0.5235 - val_mean_absolute_error: 0.3662 - val_acc: 0.7692 - val_loss_no_weight_decay: 0.5235
#
# Epoch 00016: val_acc did not improve from 0.89062
# Confusion matrix:
#  [[25  1]
#  [ 4 22]]
# Epoch 17/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.3416 - mean_absolute_error: 0.2585 - acc: 0.8958 - loss_no_weight_decay: 0.3416 - val_loss: 0.3879 - val_mean_absolute_error: 0.2418 - val_acc: 0.8438 - val_loss_no_weight_decay: 0.3879
#
# Epoch 00017: val_acc did not improve from 0.89062
# Confusion matrix:
#  [[26  6]
#  [ 6 26]]
# Epoch 18/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.3050 - mean_absolute_error: 0.2149 - acc: 0.8810 - loss_no_weight_decay: 0.3050 - val_loss: 0.4279 - val_mean_absolute_error: 0.2758 - val_acc: 0.7692 - val_loss_no_weight_decay: 0.4279
#
# Epoch 00018: val_acc did not improve from 0.89062
# Confusion matrix:
#  [[23  2]
#  [14 13]]
# Epoch 19/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.5742 - mean_absolute_error: 0.3360 - acc: 0.7232 - loss_no_weight_decay: 0.5742 - val_loss: 0.8371 - val_mean_absolute_error: 0.4276 - val_acc: 0.5469 - val_loss_no_weight_decay: 0.8371
#
# Epoch 00019: val_acc did not improve from 0.89062
# Confusion matrix:
#  [[ 9 21]
#  [ 3 31]]
# Epoch 20/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.4716 - mean_absolute_error: 0.3033 - acc: 0.7726 - loss_no_weight_decay: 0.4716 - val_loss: 0.5373 - val_mean_absolute_error: 0.3641 - val_acc: 0.7500 - val_loss_no_weight_decay: 0.5373
#
# Epoch 00020: val_acc did not improve from 0.89062
# Confusion matrix:
#  [[15  6]
#  [ 6 25]]
# Epoch 21/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.4221 - mean_absolute_error: 0.2945 - acc: 0.7908 - loss_no_weight_decay: 0.4221 - val_loss: 0.4016 - val_mean_absolute_error: 0.2983 - val_acc: 0.8281 - val_loss_no_weight_decay: 0.4016
#
# Epoch 00021: val_acc did not improve from 0.89062
# Confusion matrix:
#  [[26  5]
#  [ 5 28]]
# Epoch 22/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.3947 - mean_absolute_error: 0.2818 - acc: 0.8271 - loss_no_weight_decay: 0.3947 - val_loss: 0.4430 - val_mean_absolute_error: 0.3061 - val_acc: 0.7885 - val_loss_no_weight_decay: 0.4430
#
# Epoch 00022: val_acc did not improve from 0.89062
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Confusion matrix:
#  [[13 13]
#  [ 1 25]]
# Epoch 23/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.3419 - mean_absolute_error: 0.2472 - acc: 0.8755 - loss_no_weight_decay: 0.3419 - val_loss: 0.3215 - val_mean_absolute_error: 0.2430 - val_acc: 0.8125 - val_loss_no_weight_decay: 0.3215
#
# Epoch 00023: val_acc did not improve from 0.89062
# Confusion matrix:
#  [[24  7]
#  [ 9 24]]
# Epoch 24/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.3372 - mean_absolute_error: 0.2281 - acc: 0.8287 - loss_no_weight_decay: 0.3372 - val_loss: 0.4046 - val_mean_absolute_error: 0.2782 - val_acc: 0.7885 - val_loss_no_weight_decay: 0.4046
#
# Epoch 00024: val_acc did not improve from 0.89062
# Confusion matrix:
#  [[21  4]
#  [ 0 27]]
# Epoch 25/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.3160 - mean_absolute_error: 0.2221 - acc: 0.8534 - loss_no_weight_decay: 0.3160 - val_loss: 0.3574 - val_mean_absolute_error: 0.2288 - val_acc: 0.8438 - val_loss_no_weight_decay: 0.3574
#
# Epoch 00025: val_acc did not improve from 0.89062
# Confusion matrix:
#  [[24 10]
#  [ 0 30]]
# Epoch 26/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.2849 - mean_absolute_error: 0.2013 - acc: 0.8690 - loss_no_weight_decay: 0.2849 - val_loss: 0.2970 - val_mean_absolute_error: 0.2184 - val_acc: 0.8846 - val_loss_no_weight_decay: 0.2970
#
# Epoch 00026: val_acc did not improve from 0.89062
# Confusion matrix:
#  [[21  6]
#  [ 1 24]]
# Epoch 27/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.2768 - mean_absolute_error: 0.1957 - acc: 0.8924 - loss_no_weight_decay: 0.2768 - val_loss: 0.2823 - val_mean_absolute_error: 0.1878 - val_acc: 0.8906 - val_loss_no_weight_decay: 0.2823
#
# Epoch 00027: val_acc did not improve from 0.89062
# Confusion matrix:
#  [[28  7]
#  [ 1 28]]
# Epoch 28/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.2320 - mean_absolute_error: 0.1637 - acc: 0.9003 - loss_no_weight_decay: 0.2320 - val_loss: 0.2998 - val_mean_absolute_error: 0.2102 - val_acc: 0.8654 - val_loss_no_weight_decay: 0.2998
# Epoch 00028: val_acc did not improve from 0.89062
# Confusion matrix:
#  [[19  3]
#  [ 3 27]]
# Epoch 29/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.2288 - mean_absolute_error: 0.1583 - acc: 0.9063 - loss_no_weight_decay: 0.2288 - val_loss: 0.3250 - val_mean_absolute_error: 0.2130 - val_acc: 0.8594 - val_loss_no_weight_decay: 0.3250
#
# Epoch 00029: val_acc did not improve from 0.89062
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Confusion matrix:
#  [[30  3]
#  [ 3 28]]
# Epoch 30/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.2587 - mean_absolute_error: 0.1767 - acc: 0.9045 - loss_no_weight_decay: 0.2587 - val_loss: 0.2635 - val_mean_absolute_error: 0.1918 - val_acc: 0.8462 - val_loss_no_weight_decay: 0.2635
#
# Epoch 00030: val_acc did not improve from 0.89062
# Confusion matrix:
#  [[18  5]
#  [ 1 28]]
# Epoch 31/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.2051 - mean_absolute_error: 0.1505 - acc: 0.9211 - loss_no_weight_decay: 0.2051 - val_loss: 0.2983 - val_mean_absolute_error: 0.1830 - val_acc: 0.8750 - val_loss_no_weight_decay: 0.2983
#
# Epoch 00031: val_acc did not improve from 0.89062
# Confusion matrix:
#  [[32  5]
#  [ 2 25]]
# Epoch 32/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.2258 - mean_absolute_error: 0.1555 - acc: 0.8958 - loss_no_weight_decay: 0.2258 - val_loss: 0.2459 - val_mean_absolute_error: 0.1629 - val_acc: 0.9038 - val_loss_no_weight_decay: 0.2459
#
# Epoch 00032: val_acc improved from 0.89062 to 0.90385, saving model to base_2020-05-07-23-53-58-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[15  2]
#  [ 1 34]]
# Epoch 33/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.2092 - mean_absolute_error: 0.1471 - acc: 0.9244 - loss_no_weight_decay: 0.2092 - val_loss: 0.3326 - val_mean_absolute_error: 0.1814 - val_acc: 0.8750 - val_loss_no_weight_decay: 0.3326
#
# Epoch 00033: val_acc did not improve from 0.90385
# Confusion matrix:
#  [[31  4]
#  [ 2 27]]
# Epoch 34/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.2302 - mean_absolute_error: 0.1557 - acc: 0.9025 - loss_no_weight_decay: 0.2302 - val_loss: 0.2674 - val_mean_absolute_error: 0.1465 - val_acc: 0.8846 - val_loss_no_weight_decay: 0.2674
#
# Epoch 00034: val_acc did not improve from 0.90385
# Confusion matrix:
#  [[21  5]
#  [ 0 26]]
# Epoch 35/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.2026 - mean_absolute_error: 0.1440 - acc: 0.9219 - loss_no_weight_decay: 0.2026 - val_loss: 0.3365 - val_mean_absolute_error: 0.1858 - val_acc: 0.8594 - val_loss_no_weight_decay: 0.3365
#
# Epoch 00035: val_acc did not improve from 0.90385
# Confusion matrix:
#  [[27  3]
#  [ 2 32]]
# 176/176 [==============================] - 5s 29ms/step
# 176/176 [==============================] - 5s 29ms/step
# Test loss: 0.2932951864079056
# Test accuracy: 0.17849698845068154
# Confusion Matrix
# [[80  8]
#  [11 77]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.88      0.91      0.89        88
#            1       0.91      0.88      0.89        88
#
#     accuracy                           0.89       176
#    macro avg       0.89      0.89      0.89       176
# weighted avg       0.89      0.89      0.89       176

# %%
import numpy as np 
import matplotlib.pyplot as plt
import os
import wandb
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_mean_absolute_error', 'val_acc', 'val_loss_no_weight_decay', 'loss', 'mean_absolute_error', 'acc', 'loss_no_weight_decay', 'lr'])

# %%
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
from Kappa_Skl import kappa
def kappa2(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    if len(y_true.shape) > 1 and y_true.shape[1] > 1:
        y_true = y_true.dot(range(y_true.shape[1]))
    if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
        y_pred = y_pred.dot(range(y_pred.shape[1]))
    try:
        return kappa(y_true, y_pred, weights='quadratic')
    except IndexError:
        return np.nan
    
print('Quadratic_wieghted_kappa')
print(kappa2(y_true, y_pred))
# Out:
# Quadratic_wieghted_kappa
# 0.7840909090909091

# %%
# summarize history for mean_absolute _error
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model mean_absolute_error')
plt.ylabel('mean_absolute_error')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model maey.png')
