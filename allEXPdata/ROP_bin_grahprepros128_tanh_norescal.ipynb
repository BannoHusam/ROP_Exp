# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, InputLayer
from keras.regularizers import L1L2, l2, l1
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from custom_pooling import RMSPooling2D
from keras.optimizers import SGD, Adam
from keras.layers import LeakyReLU
#from data import BALANCE_WEIGHTS
from keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
#import os
from datetime import datetime as dt
from custom_loss import WeightedCategoricalCrossEntropy
from VCM import VCM
from QWK import QWK
import keras.backend as K
from Fractional_MAXPOOL import FractionalPooling2D
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
def get_experiment_id():
    time_str = dt.now().strftime('%Y-%m-%d-%H-%M-%S')
    experiment_id = 'base_{}'.format(time_str)
    return experiment_id
p_ratio=[1.0, 1.44, 1.73, 1.0]

model = Sequential()


model.add(Conv2D(16, (5, 5), activation='tanh', input_shape=(128, 128, 3)))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(16, (3, 3), activation='tanh'))
model.add(Conv2D(16, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))

#model.add(LeakyReLU(alpha=0.01))


model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))



model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))
model.add(FractionalPooling2D(pool_ratio=(1, 1.6, 1.6, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))          
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))


model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(FractionalPooling2D(pool_ratio=(1, 1.7, 1.7, 1),pseudo_random = True,overlap=True))
#model.add(MaxPooling2D(pool_size=1))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Flatten())


#chnaged from 10 to 5 because an error 
model.add(Dense(2, activation='softmax'))

sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.count_params()
#adam = Adam(lr=0.0005, decay=1e-6)
#rmsprop
#Mloss = WeightedCategoricalCrossEntropy({0: 0.4125861396437394, 1: 1.4918664786083686, 2: 0.690426457789382, 3: 3.9541433021806855, 4: 4.885604311008468})
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['mae','acc'])
model.summary()
loss_no_weight_decay = model.total_loss - sum(model.losses)
model.metrics_tensors.append(loss_no_weight_decay)
model.metrics_names.append('loss_no_weight_decay')
#############################################################################################
#############################################################################################
#############################################################################################
#############################################################################################
#Preparing Data Augmentation Configuration 
train_datagen = ImageDataGenerator(
        
#        featurewise_center=True,
 #       samplewise_center=True,
        shear_range=0,
        zoom_range=0.0,#[1 / 1.15, 1.15],
        horizontal_flip=False,#True,
        rotation_range=0)#90,
#        validation_split=0.2)
"""
For the test set only rescale should be made 
"""
test_datagen = ImageDataGenerator()
valid_datagen = ImageDataGenerator()


train_generator = train_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas_grah/train",
    target_size=(128, 128),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="training")
#    save_to_dir="D:/Separating Images into subfolders/train_augmented")


#print(train_generator.class_indices)

valid_generator = valid_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas_grah/vald",
    target_size=(128, 128),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="validation")
#    save_to_dir="D:/Separating Images into subfolders/val_augmented"


test_generator = test_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas_grah/test",
    target_size=(128, 128),
    color_mode="rgb",
    batch_size=1,
    class_mode="categorical",
    shuffle=False,
    seed=42)
#    save_to_dir="D:/Separating Images into subfolders/test_augmented")


# Fitting/Training the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
experiment_id = get_experiment_id()
callbacks = [
    QWK(valid_generator, STEP_SIZE_VALID),
    EarlyStopping(monitor='val_acc', patience=50, min_delta=0.001, verbose=1),
    ModelCheckpoint(experiment_id + "-val_acc_checkpoint.hdf5", monitor='val_kappa', verbose=1, save_best_only=True, mode='max'),
    ReduceLROnPlateau(monitor='val_acc', factor=0.5, patience=7, verbose=1, mode='auto', min_delta=0.001, cooldown=0, min_lr=1e-7),
    VCM(valid_generator,STEP_SIZE_VALID)
    
]

class_weight_list = class_weight.compute_class_weight('balanced', np.unique(train_generator.classes), train_generator.classes)
class_weights = dict(zip(np.unique(train_generator.classes), class_weight_list))

history=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    #class_weight=class_weights,
                    callbacks=callbacks,
                    epochs=35  
)


# Evaluating the model 
#predicting output
#reseting the test generator before calling predict_generator, in order not to get weird output
test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 124, 124, 16)      1216
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 120, 120, 16)      6416
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 118, 118, 16)      2320
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 116, 116, 16)      2320
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 112, 112, 16)      6416
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 108, 108, 16)      6416
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 104, 104, 16)      6416
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 100, 100, 16)      6416
# _________________________________________________________________
# fractional_pooling2d_1 (Frac (None, 62, 62, 16)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 60, 60, 32)        4640
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 58, 58, 32)        9248
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 56, 56, 32)        9248
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 54, 54, 32)        9248
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 52, 52, 32)        9248
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 50, 50, 32)        9248
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 48, 48, 64)        18496
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 46, 46, 64)        36928
# _________________________________________________________________
# fractional_pooling2d_2 (Frac (None, 27, 27, 64)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 25, 25, 64)        36928
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 23, 23, 64)        36928
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 21, 21, 64)        36928
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 19, 19, 64)        36928
# _________________________________________________________________
# fractional_pooling2d_3 (Frac (None, 10, 10, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 6400)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 12802
# =================================================================
# Total params: 304,754
# Trainable params: 304,754
# Non-trainable params: 0
# _________________________________________________________________
# Found 588 images belonging to 2 classes.
# Found 116 images belonging to 2 classes.
# Found 176 images belonging to 2 classes.
# Epoch 1/35
# 9/9 [==============================] - 9s 973ms/step - loss: 0.6974 - mean_absolute_error: 0.5011 - acc: 0.4830 - loss_no_weight_decay: 0.6974 - val_loss: 0.6833 - val_mean_absolute_error: 0.4942 - val_acc: 0.5625 - val_loss_no_weight_decay: 0.6833
# — val_kappa: 0.0
#
# Epoch 00001: val_kappa improved from -inf to 0.00000, saving model to base_2020-05-10-15-22-05-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[24  2]
#  [25  1]]
# Epoch 2/35
# 9/9 [==============================] - 5s 525ms/step - loss: 0.6912 - mean_absolute_error: 0.4983 - acc: 0.5173 - loss_no_weight_decay: 0.6912 - val_loss: 0.6784 - val_mean_absolute_error: 0.4924 - val_acc: 0.7885 - val_loss_no_weight_decay: 0.6784
# — val_kappa: 0.4375
#
# Epoch 00002: val_kappa improved from 0.00000 to 0.43750, saving model to base_2020-05-10-15-22-05-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[24  6]
#  [ 6 16]]
# Epoch 3/35
# 9/9 [==============================] - 4s 474ms/step - loss: 0.6865 - mean_absolute_error: 0.4940 - acc: 0.5554 - loss_no_weight_decay: 0.6865 - val_loss: 0.6766 - val_mean_absolute_error: 0.4875 - val_acc: 0.5000 - val_loss_no_weight_decay: 0.6766
# — val_kappa: -0.125
#
# Epoch 00003: val_kappa did not improve from 0.43750
# Confusion matrix:
#  [[ 0 22]
#  [ 0 30]]
# Epoch 4/35
# 9/9 [==============================] - 4s 476ms/step - loss: 0.6854 - mean_absolute_error: 0.4945 - acc: 0.5646 - loss_no_weight_decay: 0.6854 - val_loss: 0.6711 - val_mean_absolute_error: 0.4885 - val_acc: 0.7308 - val_loss_no_weight_decay: 0.6711
# — val_kappa: 0.65625
#
# Epoch 00004: val_kappa improved from 0.43750 to 0.65625, saving model to base_2020-05-10-15-22-05-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[11 12]
#  [ 3 26]]
# Epoch 5/35
# 9/9 [==============================] - 5s 514ms/step - loss: 0.6790 - mean_absolute_error: 0.4921 - acc: 0.6250 - loss_no_weight_decay: 0.6790 - val_loss: 0.6579 - val_mean_absolute_error: 0.4816 - val_acc: 0.7812 - val_loss_no_weight_decay: 0.6579
# — val_kappa: 0.78125
#
# Epoch 00005: val_kappa improved from 0.65625 to 0.78125, saving model to base_2020-05-10-15-22-05-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[18 10]
#  [ 5 19]]
# Epoch 6/35
# 9/9 [==============================] - 4s 423ms/step - loss: 0.6694 - mean_absolute_error: 0.4854 - acc: 0.6326 - loss_no_weight_decay: 0.6694 - val_loss: 0.6516 - val_mean_absolute_error: 0.4774 - val_acc: 0.8077 - val_loss_no_weight_decay: 0.6516
# — val_kappa: 0.75
#
# Epoch 00006: val_kappa did not improve from 0.78125
# Confusion matrix:
#  [[26  3]
#  [ 8 15]]
# Epoch 7/35
# 9/9 [==============================] - 5s 511ms/step - loss: 0.6636 - mean_absolute_error: 0.4809 - acc: 0.6424 - loss_no_weight_decay: 0.6636 - val_loss: 0.6059 - val_mean_absolute_error: 0.4489 - val_acc: 0.7344 - val_loss_no_weight_decay: 0.6059
# — val_kappa: 0.625
#
# Epoch 00007: val_kappa did not improve from 0.78125
# Confusion matrix:
#  [[14 15]
#  [ 1 22]]
# Epoch 8/35
# 9/9 [==============================] - 4s 421ms/step - loss: 0.6385 - mean_absolute_error: 0.4602 - acc: 0.6613 - loss_no_weight_decay: 0.6385 - val_loss: 0.5642 - val_mean_absolute_error: 0.4249 - val_acc: 0.8462 - val_loss_no_weight_decay: 0.5642
# — val_kappa: 0.59375
#
# Epoch 00008: val_kappa did not improve from 0.78125
# Confusion matrix:
#  [[19  9]
#  [ 1 23]]
# Epoch 9/35
# 9/9 [==============================] - 5s 512ms/step - loss: 0.6083 - mean_absolute_error: 0.4435 - acc: 0.7222 - loss_no_weight_decay: 0.6083 - val_loss: 0.5052 - val_mean_absolute_error: 0.3871 - val_acc: 0.8281 - val_loss_no_weight_decay: 0.5052
# — val_kappa: 0.59375
#
# Epoch 00009: val_kappa did not improve from 0.78125
# Confusion matrix:
#  [[17  9]
#  [ 1 25]]
# Epoch 10/35
# 9/9 [==============================] - 4s 465ms/step - loss: 0.5646 - mean_absolute_error: 0.4062 - acc: 0.7495 - loss_no_weight_decay: 0.5646 - val_loss: 0.4287 - val_mean_absolute_error: 0.3273 - val_acc: 0.8654 - val_loss_no_weight_decay: 0.4287
# — val_kappa: 0.71875
#
# Epoch 00010: val_kappa did not improve from 0.78125
# Confusion matrix:
#  [[23  6]
#  [ 2 21]]
# Epoch 11/35
# 9/9 [==============================] - 5s 510ms/step - loss: 0.5573 - mean_absolute_error: 0.3846 - acc: 0.7240 - loss_no_weight_decay: 0.5573 - val_loss: 0.4242 - val_mean_absolute_error: 0.3287 - val_acc: 0.9062 - val_loss_no_weight_decay: 0.4242
# — val_kappa: 0.65625
#
# Epoch 00011: val_kappa did not improve from 0.78125
# Confusion matrix:
#  [[18  8]
#  [ 1 25]]
# Epoch 12/35
# 9/9 [==============================] - 4s 437ms/step - loss: 0.5487 - mean_absolute_error: 0.3649 - acc: 0.7440 - loss_no_weight_decay: 0.5487 - val_loss: 0.5942 - val_mean_absolute_error: 0.4127 - val_acc: 0.7115 - val_loss_no_weight_decay: 0.5942
# — val_kappa: 0.34375
#
# Epoch 00012: val_kappa did not improve from 0.78125
# Confusion matrix:
#  [[23  8]
#  [12  9]]
# Epoch 13/35
# 9/9 [==============================] - 4s 479ms/step - loss: 0.6060 - mean_absolute_error: 0.4027 - acc: 0.7009 - loss_no_weight_decay: 0.6060 - val_loss: 0.5005 - val_mean_absolute_error: 0.3834 - val_acc: 0.9062 - val_loss_no_weight_decay: 0.5005
# — val_kappa: 0.78125
#
# Epoch 00013: val_kappa did not improve from 0.78125
# Confusion matrix:
#  [[23  5]
#  [ 2 22]]
# Epoch 14/35
# 9/9 [==============================] - 4s 473ms/step - loss: 0.5435 - mean_absolute_error: 0.3847 - acc: 0.7828 - loss_no_weight_decay: 0.5435 - val_loss: 0.5231 - val_mean_absolute_error: 0.3617 - val_acc: 0.7115 - val_loss_no_weight_decay: 0.5231
# — val_kappa: 0.6875
#
# Epoch 00014: val_kappa did not improve from 0.78125
# Confusion matrix:
#  [[17 10]
#  [ 0 25]]
# Epoch 15/35
# 9/9 [==============================] - 5s 523ms/step - loss: 0.5590 - mean_absolute_error: 0.3760 - acc: 0.7274 - loss_no_weight_decay: 0.5590 - val_loss: 0.5254 - val_mean_absolute_error: 0.3791 - val_acc: 0.7344 - val_loss_no_weight_decay: 0.5254
# — val_kappa: 0.71875
#
# Epoch 00015: val_kappa did not improve from 0.78125
# Confusion matrix:
#  [[17 14]
#  [ 1 20]]
# Epoch 16/35
# 9/9 [==============================] - 4s 470ms/step - loss: 0.5691 - mean_absolute_error: 0.3826 - acc: 0.7257 - loss_no_weight_decay: 0.5691 - val_loss: 0.5110 - val_mean_absolute_error: 0.3644 - val_acc: 0.8077 - val_loss_no_weight_decay: 0.5110
# — val_kappa: 0.71875
#
# Epoch 00016: val_kappa did not improve from 0.78125
# Confusion matrix:
#  [[20  4]
#  [ 1 27]]
# Epoch 17/35
# 9/9 [==============================] - 4s 434ms/step - loss: 0.5609 - mean_absolute_error: 0.3793 - acc: 0.7384 - loss_no_weight_decay: 0.5609 - val_loss: 0.3938 - val_mean_absolute_error: 0.2818 - val_acc: 0.8594 - val_loss_no_weight_decay: 0.3938
# — val_kappa: 0.6875
#
# Epoch 00017: val_kappa did not improve from 0.78125
# Confusion matrix:
#  [[15  9]
#  [ 0 28]]
# Epoch 18/35
# 9/9 [==============================] - 5s 518ms/step - loss: 0.5437 - mean_absolute_error: 0.3726 - acc: 0.7274 - loss_no_weight_decay: 0.5437 - val_loss: 0.4432 - val_mean_absolute_error: 0.2997 - val_acc: 0.8846 - val_loss_no_weight_decay: 0.4432
# — val_kappa: 0.75
#
# Epoch 00018: val_kappa did not improve from 0.78125
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Confusion matrix:
#  [[25  7]
#  [ 1 19]]
# Epoch 19/35
# 9/9 [==============================] - 4s 469ms/step - loss: 0.5170 - mean_absolute_error: 0.3631 - acc: 0.7365 - loss_no_weight_decay: 0.5170 - val_loss: 0.4639 - val_mean_absolute_error: 0.3547 - val_acc: 0.8750 - val_loss_no_weight_decay: 0.4639
# — val_kappa: 0.53125
#
# Epoch 00019: val_kappa did not improve from 0.78125
# Confusion matrix:
#  [[19  5]
#  [ 2 26]]
# Epoch 20/35
# 9/9 [==============================] - 4s 463ms/step - loss: 0.4975 - mean_absolute_error: 0.3297 - acc: 0.7916 - loss_no_weight_decay: 0.4975 - val_loss: 0.4230 - val_mean_absolute_error: 0.2858 - val_acc: 0.8077 - val_loss_no_weight_decay: 0.4230
# — val_kappa: 0.59375
#
# Epoch 00020: val_kappa did not improve from 0.78125
# Confusion matrix:
#  [[17  7]
#  [ 0 28]]
# Epoch 21/35
# 9/9 [==============================] - 4s 478ms/step - loss: 0.4921 - mean_absolute_error: 0.3260 - acc: 0.7640 - loss_no_weight_decay: 0.4921 - val_loss: 0.4047 - val_mean_absolute_error: 0.2878 - val_acc: 0.8594 - val_loss_no_weight_decay: 0.4047
# — val_kappa: 0.5625
#
# Epoch 00021: val_kappa did not improve from 0.78125
# Confusion matrix:
#  [[18  3]
#  [ 1 30]]
# Epoch 22/35
# 9/9 [==============================] - 4s 472ms/step - loss: 0.4519 - mean_absolute_error: 0.3124 - acc: 0.7966 - loss_no_weight_decay: 0.4519 - val_loss: 0.3828 - val_mean_absolute_error: 0.2887 - val_acc: 0.8654 - val_loss_no_weight_decay: 0.3828
# — val_kappa: 0.71875
#
# Epoch 00022: val_kappa did not improve from 0.78125
# Confusion matrix:
#  [[19  8]
#  [ 1 24]]
# Epoch 23/35
# 9/9 [==============================] - 4s 469ms/step - loss: 0.5064 - mean_absolute_error: 0.3374 - acc: 0.7387 - loss_no_weight_decay: 0.5064 - val_loss: 0.4658 - val_mean_absolute_error: 0.3137 - val_acc: 0.8125 - val_loss_no_weight_decay: 0.4658
# — val_kappa: 0.5
#
# Epoch 00023: val_kappa did not improve from 0.78125
# Confusion matrix:
#  [[21  5]
#  [ 6 20]]
# Epoch 24/35
# 9/9 [==============================] - 4s 481ms/step - loss: 0.5690 - mean_absolute_error: 0.3754 - acc: 0.7172 - loss_no_weight_decay: 0.5690 - val_loss: 0.4432 - val_mean_absolute_error: 0.3233 - val_acc: 0.8077 - val_loss_no_weight_decay: 0.4432
# — val_kappa: 0.625
#
# Epoch 00024: val_kappa did not improve from 0.78125
# Confusion matrix:
#  [[14  9]
#  [ 0 29]]
# Epoch 25/35
# 9/9 [==============================] - 4s 476ms/step - loss: 0.4984 - mean_absolute_error: 0.3366 - acc: 0.7901 - loss_no_weight_decay: 0.4984 - val_loss: 0.4608 - val_mean_absolute_error: 0.3066 - val_acc: 0.8125 - val_loss_no_weight_decay: 0.4608
# — val_kappa: 0.65625
#
# Epoch 00025: val_kappa did not improve from 0.78125
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Confusion matrix:
#  [[17  8]
#  [ 1 26]]
# Epoch 26/35
# 9/9 [==============================] - 5s 529ms/step - loss: 0.4675 - mean_absolute_error: 0.3152 - acc: 0.8021 - loss_no_weight_decay: 0.4675 - val_loss: 0.4225 - val_mean_absolute_error: 0.3153 - val_acc: 0.8462 - val_loss_no_weight_decay: 0.4225
# — val_kappa: 0.8125
#
# Epoch 00026: val_kappa improved from 0.78125 to 0.81250, saving model to base_2020-05-10-15-22-05-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[17  9]
#  [ 2 24]]
# Epoch 27/35
# 9/9 [==============================] - 4s 472ms/step - loss: 0.4763 - mean_absolute_error: 0.3325 - acc: 0.7660 - loss_no_weight_decay: 0.4763 - val_loss: 0.4209 - val_mean_absolute_error: 0.3151 - val_acc: 0.8438 - val_loss_no_weight_decay: 0.4209
# — val_kappa: 0.53125
#
# Epoch 00027: val_kappa did not improve from 0.81250
# Confusion matrix:
#  [[21  6]
#  [ 0 25]]
# Epoch 28/35
# 9/9 [==============================] - 4s 419ms/step - loss: 0.4369 - mean_absolute_error: 0.3027 - acc: 0.8182 - loss_no_weight_decay: 0.4369 - val_loss: 0.4380 - val_mean_absolute_error: 0.2854 - val_acc: 0.7885 - val_loss_no_weight_decay: 0.4380
# — val_kappa: 0.6875
#
# Epoch 00028: val_kappa did not improve from 0.81250
# Confusion matrix:
#  [[14 11]
#  [ 0 27]]
# Epoch 29/35
# 9/9 [==============================] - 5s 506ms/step - loss: 0.4858 - mean_absolute_error: 0.3080 - acc: 0.7639 - loss_no_weight_decay: 0.4858 - val_loss: 0.3984 - val_mean_absolute_error: 0.2905 - val_acc: 0.8438 - val_loss_no_weight_decay: 0.3984
# — val_kappa: 0.75
#
# Epoch 00029: val_kappa did not improve from 0.81250
# Confusion matrix:
#  [[17 10]
#  [ 1 24]]
# Epoch 30/35
# 9/9 [==============================] - 4s 464ms/step - loss: 0.4365 - mean_absolute_error: 0.3040 - acc: 0.8161 - loss_no_weight_decay: 0.4365 - val_loss: 0.4551 - val_mean_absolute_error: 0.3252 - val_acc: 0.7692 - val_loss_no_weight_decay: 0.4551
# — val_kappa: 0.75
#
# Epoch 00030: val_kappa did not improve from 0.81250
# Confusion matrix:
#  [[16  7]
#  [ 0 29]]
# Epoch 31/35
# 9/9 [==============================] - 4s 463ms/step - loss: 0.4959 - mean_absolute_error: 0.3305 - acc: 0.7750 - loss_no_weight_decay: 0.4959 - val_loss: 0.3952 - val_mean_absolute_error: 0.2949 - val_acc: 0.9219 - val_loss_no_weight_decay: 0.3952
# — val_kappa: 0.75
#
# Epoch 00031: val_kappa did not improve from 0.81250
# Confusion matrix:
#  [[22  5]
#  [ 1 24]]
# Epoch 32/35
# 9/9 [==============================] - 4s 465ms/step - loss: 0.4563 - mean_absolute_error: 0.3041 - acc: 0.7903 - loss_no_weight_decay: 0.4563 - val_loss: 0.4490 - val_mean_absolute_error: 0.3144 - val_acc: 0.7692 - val_loss_no_weight_decay: 0.4490
# — val_kappa: 0.6875
#
# Epoch 00032: val_kappa did not improve from 0.81250
# Confusion matrix:
#  [[13 11]
#  [ 1 27]]
# Epoch 33/35
# 9/9 [==============================] - 4s 483ms/step - loss: 0.4468 - mean_absolute_error: 0.3108 - acc: 0.7969 - loss_no_weight_decay: 0.4468 - val_loss: 0.5156 - val_mean_absolute_error: 0.3572 - val_acc: 0.7344 - val_loss_no_weight_decay: 0.5156
# — val_kappa: 0.75
#
# Epoch 00033: val_kappa did not improve from 0.81250
# Confusion matrix:
#  [[12 15]
#  [ 1 24]]
# Epoch 34/35
# 9/9 [==============================] - 4s 467ms/step - loss: 0.4505 - mean_absolute_error: 0.3104 - acc: 0.8021 - loss_no_weight_decay: 0.4505 - val_loss: 0.3659 - val_mean_absolute_error: 0.2698 - val_acc: 0.8846 - val_loss_no_weight_decay: 0.3659
# — val_kappa: 0.6875
#
# Epoch 00034: val_kappa did not improve from 0.81250
# Confusion matrix:
#  [[16  7]
#  [ 1 28]]
# Epoch 35/35
# 9/9 [==============================] - 4s 470ms/step - loss: 0.4152 - mean_absolute_error: 0.2629 - acc: 0.8264 - loss_no_weight_decay: 0.4152 - val_loss: 0.3418 - val_mean_absolute_error: 0.2472 - val_acc: 0.8906 - val_loss_no_weight_decay: 0.3418
# — val_kappa: 0.65625
#
# Epoch 00035: val_kappa did not improve from 0.81250
# Confusion matrix:
#  [[21 10]
#  [ 0 21]]
# 176/176 [==============================] - 1s 4ms/step
# 176/176 [==============================] - 1s 4ms/step
# Test loss: 0.4568273937488398
# Test accuracy: 0.29019626044266095
# Confusion Matrix
# [[59 29]
#  [10 78]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.86      0.67      0.75        88
#            1       0.73      0.89      0.80        88
#
#     accuracy                           0.78       176
#    macro avg       0.79      0.78      0.78       176
# weighted avg       0.79      0.78      0.78       176

# %%
from Kappa_Skl import kappa
def kappa2(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    if len(y_true.shape) > 1 and y_true.shape[1] > 1:
        y_true = y_true.dot(range(y_true.shape[1]))
    if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
        y_pred = y_pred.dot(range(y_pred.shape[1]))
    try:
        return kappa(y_true, y_pred, weights='quadratic')
    except IndexError:
        return np.nan
    
print('Quadratic_wieghted_kappa')
print(kappa2(y_true, y_pred))
# Out:
# Quadratic_wieghted_kappa
# 0.5568181818181819

# %%
import numpy as np 
import matplotlib.pyplot as plt
import os
import wandb
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model loss.png')

# summarize history for val_kappa
plt.plot(history.history['val_kappa'])
plt.title('Validation_Kappa')
plt.ylabel('val_kappa')
plt.xlabel('epoch')
plt.legend([ 'validation'], loc='upper left')
plt.show()
#plt.savefig('model validation_kappa.png')

# summarize history for mean_absolute _error
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model mean_absolute_error')
plt.ylabel('mean_absolute_error')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model maey.png'
# Out:
# dict_keys(['val_loss', 'val_mean_absolute_error', 'val_acc', 'val_loss_no_weight_decay', 'loss', 'mean_absolute_error', 'acc', 'loss_no_weight_decay', 'val_kappa', 'lr'])
