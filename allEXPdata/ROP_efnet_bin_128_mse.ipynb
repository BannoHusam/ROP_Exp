# %%
import efficientnet.keras as efn
from keras.models import Model, model_from_json
from keras.regularizers import l1_l2
from keras.layers import Dense, Dropout
from keras.optimizers import SGD, Adam
import pandas as pd
from keras_preprocessing.image import ImageDataGenerator
from datetime import datetime as dt
from sklearn.utils import class_weight
from keras.callbacks import EarlyStopping, ModelCheckpoint,LearningRateScheduler, TensorBoard
import keras.backend as K
from VCM import VCM 
from keras.initializers import Constant,Orthogonal
from keras import regularizers
from Kappa_Skl import kappa
import keras.backend as K
import matplotlib.pyplot as plt
import itertools
from Homotopy import Homotopy 
from QWK import QWK
import tensorflow as tf
from Fractional_MAXPOOL import FractionalPooling2D

import numpy as np 
import matplotlib.pyplot as plt
import os
import wandb
#from wandb.keras import WandbCallback
#wandb.init(project="rop")


top_layers_checkpoint_path = 'cp.top.best.hdf5'
fine_tuned_checkpoint_path = 'cp.fine_tuned.best.hdf5'
new_extended_inception_weights = 'final_weights.hdf5'





def get_experiment_id():
    time_str = dt.now().strftime('%Y-%m-%d-%H-%M-%S')
    experiment_id = 'base_{}'.format(time_str)
    return experiment_id

#def scheduler(epoch):
#    if epoch == 150:
#        K.set_value(model.optimizer.lr, 0.00003)
#    return K.get_value(model.optimizer.lr)


def create_model():
    base_model = efn.EfficientNetB0(weights=None,
                        include_top=False,
                        input_shape=(128, 128, 3), pooling='avg')
#    base_model._layers.pop()
#    model2 = Model(base_model.input, base_model.layers[-1].output)
##    base_model = InceptionV3(weights=None , include_top=False, input_tensor=None, input_shape=(299, 299, 3), pooling='avg') 
    x = base_model.output
    x = Dense(2, activation="softmax")(x)
    model = Model(inputs = base_model.input, outputs = x)
    model.load_weights('base_2019-12-11-23-01-58-val_kappa_checkpoint.hdf5')
#    model._layers.pop()
#    x = Model(model.input, model.layers[-1].output)
#    model.save_weights("tmp.h5")
#    top_layers_checkpoint_path = 'cp.top.best.hdf5'

#    # first: train only the top layers (which were randomly initialized)
#    # i.e. freeze all convolutional InceptionV3 layers
    for layer in base_model.layers:
        layer.trainable = False
#    
#    
#
##    regularizer = l1_l2(l1=0.0005, l2=0.0005)
##    for layer in model.layers:
##        for attr in ['kernel_regularizer', 'bias_regularizer']:
##            if hasattr(layer, attr) and layer.trainable:
##                setattr(layer, attr, regularizer)
#
##
#    out = model_from_json(model.to_json())
#    out.load_weights("tmp.h5", by_name=True)
#
    return model


model = create_model()




radam = Adam(lr=0.0014339, beta_1=0.9, beta_2=0.999, epsilon=0.1, decay=1e-6, amsgrad=False)
model.compile(loss='mse', optimizer=radam, metrics=['mae','acc'])

#sgd = SGD(lr=0.0003, decay=1e-6, momentum=0.9, nesterov=True)
#model.compile(loss='mse', optimizer=sgd, metrics=['mae', 'acc'])

experiment_id = get_experiment_id()


train_datagen = ImageDataGenerator(
        rescale=1./255,
#        featurewise_center=True,
 #       samplewise_center=True,
        shear_range=0,
        zoom_range=0.0,#[1 / 1.15, 1.15],
        horizontal_flip=False,#True,
        rotation_range=0)#90,
#        validation_split=0.2)
"""
For the test set only rescale should be made 
"""
test_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas/train",
    target_size=(128, 128),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="training")
#    save_to_dir="D:/Separating Images into subfolders/train_augmented")


#print(train_generator.class_indices)

valid_generator = valid_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas/vald",
    target_size=(128, 128),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="validation")
#    save_to_dir="D:/Separating Images into subfolders/val_augmented"


test_generator = test_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas/test",
    target_size=(128, 128),
    color_mode="rgb",
    batch_size=1,
    class_mode="categorical",
    shuffle=False,
    seed=42)
#    save_to_dir="D:/Separating Images into subfolders/test_augmented")


# Fitting/Training the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
experiment_id = get_experiment_id()


class_weight_list = class_weight.compute_class_weight('balanced', np.unique(train_generator.classes), train_generator.classes)
class_weights = dict(zip(np.unique(train_generator.classes), class_weight_list))

callbacks = [
#    Resample_Iterator(balance_weights),
    QWK(valid_generator, STEP_SIZE_VALID),
    ModelCheckpoint(top_layers_checkpoint_path, monitor='val_kappa', verbose=1, save_best_only=True, mode='max'),
#    EarlyStopping(monitor='val_kappa', patience=10, min_delta=0.001, verbose=1, restore_best_weights=True, mode='max',baseline=None),
    VCM(valid_generator, STEP_SIZE_VALID),
#    LearningRateScheduler(scheduler, verbose=1),
 #   TensorBoard(log_dir='./Graph', histogram_freq=0, write_graph=True, write_images=True),        
]




# train the model on the new data for a few epochs

history1=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
#                    class_weight=[balance_weights],
                    callbacks=callbacks,
                    epochs=10  
)


 

callbacks1 = [
#    Resample_Iterator(balance_weights1),
    QWK(valid_generator, STEP_SIZE_VALID),
    ModelCheckpoint(fine_tuned_checkpoint_path, monitor='val_kappa', verbose=1, save_best_only=True, mode='max'),
#    EarlyStopping(monitor='val_kappa', patience=20, min_delta=0.001, verbose=1, restore_best_weights=True, mode='max',baseline=None),
    VCM(valid_generator, STEP_SIZE_VALID),
#    LearningRateScheduler(scheduler, verbose=1),
#    TensorBoard(log_dir='./Graph', histogram_freq=0, write_graph=True, write_images=True),        
]



for layer in model.layers:
    layer.trainable = True
    
    
    
    
radam = Adam(lr=0.0014339, beta_1=0.9, beta_2=0.999, epsilon=0.1, decay=1e-6, amsgrad=False)
model.compile(loss='mse', optimizer=radam, metrics=['mae','acc'])



# we train our model again (this time fine-tuning the top 2 inception blocks
# alongside the top Dense layers
history=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
#                    class_weight=[balance_weights1],
                    callbacks=callbacks1,
                    epochs=30) 




test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1']
print(classification_report(y_true, y_pred, target_names=target_names))
                    
                    
# list all data in history
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model loss.png')

# summarize history for val_kappa
plt.plot(history.history['val_kappa'])
plt.title('Validation_Kappa')
plt.ylabel('val_kappa')
plt.xlabel('epoch')
plt.legend([ 'validation'], loc='upper left')
plt.show()
#plt.savefig('model validation_kappa.png')

# summarize history for mean_absolute _error
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model mean_absolute_error')
plt.ylabel('mean_absolute_error')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model maey.png')
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Found 588 images belonging to 2 classes.
# Found 116 images belonging to 2 classes.
# Found 176 images belonging to 2 classes.
# Epoch 1/10
# 9/9 [==============================] - 16s 2s/step - loss: 0.3476 - mean_absolute_error: 0.4838 - acc: 0.5174 - val_loss: 0.3291 - val_mean_absolute_error: 0.5247 - val_acc: 0.4219
# — val_kappa: -0.1875
#
# Epoch 00001: val_kappa improved from -inf to -0.18750, saving model to cp.top.best.hdf5
# Confusion matrix:
#  [[16 10]
#  [19  7]]
# Epoch 2/10
# 9/9 [==============================] - 10s 1s/step - loss: 0.3200 - mean_absolute_error: 0.4604 - acc: 0.5050 - val_loss: 0.3586 - val_mean_absolute_error: 0.5473 - val_acc: 0.4231
# — val_kappa: -0.0625
#
# Epoch 00002: val_kappa improved from -0.18750 to -0.06250, saving model to cp.top.best.hdf5
# Confusion matrix:
#  [[16 11]
#  [22  3]]
# Epoch 3/10
# 9/9 [==============================] - 9s 975ms/step - loss: 0.3516 - mean_absolute_error: 0.4925 - acc: 0.4985 - val_loss: 0.3024 - val_mean_absolute_error: 0.4976 - val_acc: 0.4844
# — val_kappa: -0.09375
#
# Epoch 00003: val_kappa did not improve from -0.06250
# Confusion matrix:
#  [[12 10]
#  [22  8]]
# Epoch 4/10
# 9/9 [==============================] - 10s 1s/step - loss: 0.3329 - mean_absolute_error: 0.4725 - acc: 0.5125 - val_loss: 0.3521 - val_mean_absolute_error: 0.5518 - val_acc: 0.3654
# — val_kappa: -0.03125
#
# Epoch 00004: val_kappa improved from -0.06250 to -0.03125, saving model to cp.top.best.hdf5
# Confusion matrix:
#  [[12 11]
#  [23  6]]
# Epoch 5/10
# 9/9 [==============================] - 10s 1s/step - loss: 0.3222 - mean_absolute_error: 0.4615 - acc: 0.5399 - val_loss: 0.3090 - val_mean_absolute_error: 0.5048 - val_acc: 0.4688
# — val_kappa: -0.25
#
# Epoch 00005: val_kappa did not improve from -0.03125
# Confusion matrix:
#  [[18 10]
#  [17  7]]
# Epoch 6/10
# 9/9 [==============================] - 9s 1s/step - loss: 0.3009 - mean_absolute_error: 0.4451 - acc: 0.5386 - val_loss: 0.3431 - val_mean_absolute_error: 0.5368 - val_acc: 0.3846
# — val_kappa: -0.03125
#
# Epoch 00006: val_kappa did not improve from -0.03125
# Confusion matrix:
#  [[14 15]
#  [17  6]]
# Epoch 7/10
# 9/9 [==============================] - 9s 1s/step - loss: 0.2789 - mean_absolute_error: 0.4279 - acc: 0.5679 - val_loss: 0.3637 - val_mean_absolute_error: 0.5660 - val_acc: 0.3594
# — val_kappa: -0.15625
#
# Epoch 00007: val_kappa did not improve from -0.03125
# Confusion matrix:
#  [[18 11]
#  [15  8]]
# Epoch 8/10
# 9/9 [==============================] - 8s 908ms/step - loss: 0.3047 - mean_absolute_error: 0.4554 - acc: 0.5469 - val_loss: 0.3308 - val_mean_absolute_error: 0.5339 - val_acc: 0.4038
# — val_kappa: -0.0625
#
# Epoch 00008: val_kappa did not improve from -0.03125
# Confusion matrix:
#  [[15 13]
#  [16  8]]
# Epoch 9/10
# 9/9 [==============================] - 8s 857ms/step - loss: 0.2944 - mean_absolute_error: 0.4406 - acc: 0.5621 - val_loss: 0.3306 - val_mean_absolute_error: 0.5367 - val_acc: 0.4531
# — val_kappa: 0.09375
#
# Epoch 00009: val_kappa improved from -0.03125 to 0.09375, saving model to cp.top.best.hdf5
# Confusion matrix:
#  [[13 13]
#  [18  8]]
# Epoch 10/10
# 9/9 [==============================] - 11s 1s/step - loss: 0.2617 - mean_absolute_error: 0.4149 - acc: 0.5920 - val_loss: 0.2984 - val_mean_absolute_error: 0.5033 - val_acc: 0.4423
# — val_kappa: 0.03125
#
# Epoch 00010: val_kappa did not improve from 0.09375
# Confusion matrix:
#  [[13 12]
#  [14 13]]
# Epoch 1/30
# 9/9 [==============================] - 15s 2s/step - loss: 0.2676 - mean_absolute_error: 0.4232 - acc: 0.5903 - val_loss: 0.2762 - val_mean_absolute_error: 0.4161 - val_acc: 0.5781
# — val_kappa: 0.09375
#
# Epoch 00001: val_kappa improved from -inf to 0.09375, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  [[20  6]
#  [14 12]]
# Epoch 2/30
# 9/9 [==============================] - 11s 1s/step - loss: 0.2466 - mean_absolute_error: 0.3976 - acc: 0.6182 - val_loss: 0.2465 - val_mean_absolute_error: 0.4010 - val_acc: 0.6154
# — val_kappa: 0.34375
#
# Epoch 00002: val_kappa improved from 0.09375 to 0.34375, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  [[15  7]
#  [18 12]]
# Epoch 3/30
# 9/9 [==============================] - 10s 1s/step - loss: 0.2402 - mean_absolute_error: 0.3928 - acc: 0.6260 - val_loss: 0.2575 - val_mean_absolute_error: 0.4027 - val_acc: 0.5938
# — val_kappa: 0.28125
#
# Epoch 00003: val_kappa did not improve from 0.34375
# Confusion matrix:
#  [[18  3]
#  [17 14]]
# Epoch 4/30
# 9/9 [==============================] - 11s 1s/step - loss: 0.2151 - mean_absolute_error: 0.3659 - acc: 0.6753 - val_loss: 0.2566 - val_mean_absolute_error: 0.4050 - val_acc: 0.5962
# — val_kappa: 0.15625
#
# Epoch 00004: val_kappa did not improve from 0.34375
# Confusion matrix:
#  [[28  1]
#  [ 9 14]]
# Epoch 5/30
# 9/9 [==============================] - 9s 987ms/step - loss: 0.1907 - mean_absolute_error: 0.3425 - acc: 0.7134 - val_loss: 0.1647 - val_mean_absolute_error: 0.3162 - val_acc: 0.7344
# — val_kappa: 0.34375
#
# Epoch 00005: val_kappa did not improve from 0.34375
# Confusion matrix:
#  [[21  6]
#  [ 7 18]]
# Epoch 6/30
# 9/9 [==============================] - 9s 948ms/step - loss: 0.1786 - mean_absolute_error: 0.3260 - acc: 0.7372 - val_loss: 0.1125 - val_mean_absolute_error: 0.2408 - val_acc: 0.8462
# — val_kappa: 0.59375
#
# Epoch 00006: val_kappa improved from 0.34375 to 0.59375, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  [[20  5]
#  [ 9 18]]
# Epoch 7/30
# 9/9 [==============================] - 9s 1s/step - loss: 0.1454 - mean_absolute_error: 0.2905 - acc: 0.7745 - val_loss: 0.1702 - val_mean_absolute_error: 0.3234 - val_acc: 0.7344
# — val_kappa: 0.5625
#
# Epoch 00007: val_kappa did not improve from 0.59375
# Confusion matrix:
#  [[19  3]
#  [ 9 21]]
# Epoch 8/30
# 9/9 [==============================] - 10s 1s/step - loss: 0.1331 - mean_absolute_error: 0.2750 - acc: 0.8038 - val_loss: 0.1235 - val_mean_absolute_error: 0.2629 - val_acc: 0.7885
# — val_kappa: 0.5
#
# Epoch 00008: val_kappa did not improve from 0.59375
# Confusion matrix:
#  [[19  3]
#  [ 7 23]]
# Epoch 9/30
# 9/9 [==============================] - 10s 1s/step - loss: 0.1215 - mean_absolute_error: 0.2619 - acc: 0.8066 - val_loss: 0.1061 - val_mean_absolute_error: 0.2427 - val_acc: 0.8438
# — val_kappa: 0.59375
#
# Epoch 00009: val_kappa did not improve from 0.59375
# Confusion matrix:
#  [[24  1]
#  [ 4 23]]
# Epoch 10/30
# 9/9 [==============================] - 9s 986ms/step - loss: 0.0961 - mean_absolute_error: 0.2254 - acc: 0.8692 - val_loss: 0.0957 - val_mean_absolute_error: 0.2206 - val_acc: 0.8462
# — val_kappa: 0.6875
#
# Epoch 00010: val_kappa improved from 0.59375 to 0.68750, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  [[31  3]
#  [ 4 14]]
# Epoch 11/30
# 9/9 [==============================] - 10s 1s/step - loss: 0.0908 - mean_absolute_error: 0.2191 - acc: 0.8813 - val_loss: 0.0735 - val_mean_absolute_error: 0.2054 - val_acc: 0.8906
# — val_kappa: 0.84375
#
# Epoch 00011: val_kappa improved from 0.68750 to 0.84375, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  [[25  2]
#  [ 6 19]]
# Epoch 12/30
# 9/9 [==============================] - 10s 1s/step - loss: 0.0702 - mean_absolute_error: 0.1917 - acc: 0.9264 - val_loss: 0.0826 - val_mean_absolute_error: 0.1944 - val_acc: 0.8846
# — val_kappa: 0.84375
#
# Epoch 00012: val_kappa did not improve from 0.84375
# Confusion matrix:
#  [[21  3]
#  [ 3 25]]
# Epoch 13/30
# 9/9 [==============================] - 10s 1s/step - loss: 0.0609 - mean_absolute_error: 0.1781 - acc: 0.9319 - val_loss: 0.0506 - val_mean_absolute_error: 0.1564 - val_acc: 0.9531
# — val_kappa: 0.9375
#
# Epoch 00013: val_kappa improved from 0.84375 to 0.93750, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  [[25  3]
#  [ 3 21]]
# Epoch 14/30
# 9/9 [==============================] - 9s 987ms/step - loss: 0.0571 - mean_absolute_error: 0.1595 - acc: 0.9374 - val_loss: 0.0743 - val_mean_absolute_error: 0.1961 - val_acc: 0.9231
# — val_kappa: 0.9375
#
# Epoch 00014: val_kappa did not improve from 0.93750
# Confusion matrix:
#  [[21  2]
#  [ 1 28]]
# Epoch 15/30
# 9/9 [==============================] - 10s 1s/step - loss: 0.0508 - mean_absolute_error: 0.1529 - acc: 0.9479 - val_loss: 0.0689 - val_mean_absolute_error: 0.1820 - val_acc: 0.9219
# — val_kappa: 0.84375
#
# Epoch 00015: val_kappa did not improve from 0.93750
# Confusion matrix:
#  [[25  0]
#  [ 0 27]]
# Epoch 16/30
# 9/9 [==============================] - 9s 1s/step - loss: 0.0429 - mean_absolute_error: 0.1427 - acc: 0.9649 - val_loss: 0.0573 - val_mean_absolute_error: 0.1657 - val_acc: 0.9423
# — val_kappa: 0.90625
#
# Epoch 00016: val_kappa did not improve from 0.93750
# Confusion matrix:
#  [[24  1]
#  [ 1 26]]
# Epoch 17/30
# 9/9 [==============================] - 10s 1s/step - loss: 0.0392 - mean_absolute_error: 0.1363 - acc: 0.9719 - val_loss: 0.0422 - val_mean_absolute_error: 0.1393 - val_acc: 0.9688
# — val_kappa: 0.9375
#
# Epoch 00017: val_kappa did not improve from 0.93750
# Confusion matrix:
#  [[23  2]
#  [ 1 26]]
# Epoch 18/30
# 9/9 [==============================] - 9s 1s/step - loss: 0.0373 - mean_absolute_error: 0.1272 - acc: 0.9702 - val_loss: 0.0404 - val_mean_absolute_error: 0.1334 - val_acc: 0.9615
# — val_kappa: 0.9375
#
# Epoch 00018: val_kappa did not improve from 0.93750
# Confusion matrix:
#  [[22  1]
#  [ 2 27]]
# Epoch 19/30
# 9/9 [==============================] - 9s 998ms/step - loss: 0.0361 - mean_absolute_error: 0.1316 - acc: 0.9739 - val_loss: 0.0310 - val_mean_absolute_error: 0.1158 - val_acc: 0.9688
# — val_kappa: 0.9375
#
# Epoch 00019: val_kappa did not improve from 0.93750
# Confusion matrix:
#  [[27  2]
#  [ 1 22]]
# Epoch 20/30
# 9/9 [==============================] - 10s 1s/step - loss: 0.0269 - mean_absolute_error: 0.1113 - acc: 0.9825 - val_loss: 0.0420 - val_mean_absolute_error: 0.1402 - val_acc: 0.9423
# — val_kappa: 0.90625
#
# Epoch 00020: val_kappa did not improve from 0.93750
# Confusion matrix:
#  [[25  2]
#  [ 1 24]]
# Epoch 21/30
# 9/9 [==============================] - 9s 961ms/step - loss: 0.0442 - mean_absolute_error: 0.1301 - acc: 0.9431 - val_loss: 0.0280 - val_mean_absolute_error: 0.1123 - val_acc: 0.9688
# — val_kappa: 0.9375
#
# Epoch 00021: val_kappa did not improve from 0.93750
# Confusion matrix:
#  [[27  1]
#  [ 1 23]]
# Epoch 22/30
# 9/9 [==============================] - 11s 1s/step - loss: 0.0233 - mean_absolute_error: 0.1005 - acc: 0.9844 - val_loss: 0.0381 - val_mean_absolute_error: 0.1247 - val_acc: 0.9615
# — val_kappa: 0.9375
#
# Epoch 00022: val_kappa did not improve from 0.93750
# Confusion matrix:
#  [[26  0]
#  [ 2 24]]
# Epoch 23/30
# 9/9 [==============================] - 10s 1s/step - loss: 0.0217 - mean_absolute_error: 0.0990 - acc: 0.9844 - val_loss: 0.0276 - val_mean_absolute_error: 0.0999 - val_acc: 0.9688
# — val_kappa: 0.96875
#
# Epoch 00023: val_kappa improved from 0.93750 to 0.96875, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  [[25  3]
#  [ 0 24]]
# Epoch 24/30
# 9/9 [==============================] - 9s 1s/step - loss: 0.0215 - mean_absolute_error: 0.0920 - acc: 0.9825 - val_loss: 0.0313 - val_mean_absolute_error: 0.1213 - val_acc: 0.9615
# — val_kappa: 0.9375
#
# Epoch 00024: val_kappa did not improve from 0.96875
# Confusion matrix:
#  [[23  2]
#  [ 1 26]]
# Epoch 25/30
# 9/9 [==============================] - 10s 1s/step - loss: 0.0185 - mean_absolute_error: 0.0855 - acc: 0.9930 - val_loss: 0.0267 - val_mean_absolute_error: 0.1100 - val_acc: 0.9844
# — val_kappa: 0.96875
#
# Epoch 00025: val_kappa did not improve from 0.96875
# Confusion matrix:
#  [[24  2]
#  [ 0 26]]
# Epoch 26/30
# 9/9 [==============================] - 11s 1s/step - loss: 0.0229 - mean_absolute_error: 0.0920 - acc: 0.9861 - val_loss: 0.0256 - val_mean_absolute_error: 0.0922 - val_acc: 0.9615
# — val_kappa: 0.90625
#
# Epoch 00026: val_kappa did not improve from 0.96875
# Confusion matrix:
#  [[21  0]
#  [ 0 31]]
# Epoch 27/30
# 9/9 [==============================] - 10s 1s/step - loss: 0.0153 - mean_absolute_error: 0.0784 - acc: 0.9912 - val_loss: 0.0185 - val_mean_absolute_error: 0.0851 - val_acc: 0.9688
# — val_kappa: 0.9375
#
# Epoch 00027: val_kappa did not improve from 0.96875
# Confusion matrix:
#  [[27  0]
#  [ 1 24]]
# Epoch 28/30
# 9/9 [==============================] - 9s 1s/step - loss: 0.0227 - mean_absolute_error: 0.0887 - acc: 0.9845 - val_loss: 0.0155 - val_mean_absolute_error: 0.0873 - val_acc: 1.0000
# — val_kappa: 1.0
#
# Epoch 00028: val_kappa improved from 0.96875 to 1.00000, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  [[23  2]
#  [ 1 26]]
# Epoch 29/30
# 9/9 [==============================] - 10s 1s/step - loss: 0.0171 - mean_absolute_error: 0.0831 - acc: 0.9930 - val_loss: 0.0316 - val_mean_absolute_error: 0.1099 - val_acc: 0.9531
# — val_kappa: 0.96875
#
# Epoch 00029: val_kappa did not improve from 1.00000
# Confusion matrix:
#  [[21  3]
#  [ 0 28]]
# Epoch 30/30
# 9/9 [==============================] - 9s 994ms/step - loss: 0.0171 - mean_absolute_error: 0.0816 - acc: 0.9895 - val_loss: 0.0379 - val_mean_absolute_error: 0.1152 - val_acc: 0.9423
# — val_kappa: 0.90625
#
# Epoch 00030: val_kappa did not improve from 1.00000
# Confusion matrix:
#  [[22  0]
#  [ 0 30]]
# 176/176 [==============================] - 5s 31ms/step
# 176/176 [==============================] - 5s 26ms/step
# Test loss: 0.023413820353236522
# Test accuracy: 0.08986534421335984
# Confusion Matrix
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-61c680afeb24> in <module>
#     246 # generator.classes gives you the truth label y_true
#     247 print('Confusion Matrix')
# --> 248 cm = confusion_matrix(y_true, y_pred)
#     249
#     250 print(cm)
#
# NameError: name 'confusion_matrix' is not defined

# %%
from sklearn.metrics import confusion_matrix, classification_report

test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# 176/176 [==============================] - 5s 30ms/step
# 176/176 [==============================] - 5s 28ms/step
# Test loss: 0.023413820353236522
# Test accuracy: 0.08986534421335984
# Confusion Matrix
# [[84  4]
#  [ 1 87]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.99      0.95      0.97        88
#            1       0.96      0.99      0.97        88
#
#     accuracy                           0.97       176
#    macro avg       0.97      0.97      0.97       176
# weighted avg       0.97      0.97      0.97       176

# %%
def kappa2(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    if len(y_true.shape) > 1 and y_true.shape[1] > 1:
        y_true = y_true.dot(range(y_true.shape[1]))
    if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
        y_pred = y_pred.dot(range(y_pred.shape[1]))
    try:
        return kappa(y_true, y_pred, weights='quadratic')
    except IndexError:
        return np.nan
    
print('Quadratic_wieghted_kappa')
print(kappa2(y_true, y_pred))
# Out:
# Quadratic_wieghted_kappa
# 0.9431818181818181

# %%
# list all data in history
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model loss.png')

# summarize history for val_kappa
plt.plot(history.history['val_kappa'])
plt.title('Validation_Kappa')
plt.ylabel('val_kappa')
plt.xlabel('epoch')
plt.legend([ 'validation'], loc='upper left')
plt.show()
#plt.savefig('model validation_kappa.png')

# summarize history for mean_absolute _error
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model mean_absolute_error')
plt.ylabel('mean_absolute_error')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model maey.png')
# Out:
# dict_keys(['val_loss', 'val_mean_absolute_error', 'val_acc', 'loss', 'mean_absolute_error', 'acc', 'val_kappa'])
