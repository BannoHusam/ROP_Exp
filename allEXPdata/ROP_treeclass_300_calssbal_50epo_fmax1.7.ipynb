# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, InputLayer
from keras.regularizers import L1L2, l2, l1
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from custom_pooling import RMSPooling2D
from keras.optimizers import SGD, Adam
from keras.layers import LeakyReLU
#from data import BALANCE_WEIGHTS
from keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
#import os
from datetime import datetime as dt
from custom_loss import WeightedCategoricalCrossEntropy
from VCM import VCM
from QWK import QWK
import keras.backend as K
from Fractional_MAXPOOL import FractionalPooling2D
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
def get_experiment_id():
    time_str = dt.now().strftime('%Y-%m-%d-%H-%M-%S')
    experiment_id = 'base_{}'.format(time_str)
    return experiment_id
p_ratio=[1.0, 1.44, 1.73, 1.0]

model = Sequential()


model.add(Conv2D(16, (5, 5), activation='tanh', input_shape=(300, 300, 3)))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))
model.add(FractionalPooling2D(pool_ratio=(1, 1.7, 1.7, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(16, (3, 3), activation='tanh'))
model.add(Conv2D(16, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

#model.add(LeakyReLU(alpha=0.01))


model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))


model.add(FractionalPooling2D(pool_ratio=(1, 1.7, 1.7, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))          
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
model.add(FractionalPooling2D(pool_ratio=(1, 1.7, 1.7, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(FractionalPooling2D(pool_ratio=(1, 1.7, 1.7, 1),pseudo_random = True,overlap=True))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))


model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

#model.add(MaxPooling2D(pool_size=1))




model.add(FractionalPooling2D(pool_ratio=(1, 1.7, 1.7, 1),pseudo_random = True,overlap=True))

model.add(Flatten())


#chnaged from 10 to 5 because an error 
model.add(Dense(3, activation='softmax'))

sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.count_params()
#adam = Adam(lr=0.0005, decay=1e-6)
#rmsprop
#Mloss = WeightedCategoricalCrossEntropy({0: 0.4125861396437394, 1: 1.4918664786083686, 2: 0.690426457789382, 3: 3.9541433021806855, 4: 4.885604311008468})
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['acc','binary_accuracy','mae'])
model.summary()
loss_no_weight_decay = model.total_loss - sum(model.losses)
model.metrics_tensors.append(loss_no_weight_decay)
model.metrics_names.append('loss_no_weight_decay')
#############################################################################################
#############################################################################################
#############################################################################################
#############################################################################################
#Preparing Data Augmentation Configuration 
train_datagen = ImageDataGenerator(
        rescale=1./255,
#        featurewise_center=True,
 #       samplewise_center=True,
        shear_range=0,
        zoom_range=0.0,#[1 / 1.15, 1.15],
        horizontal_flip=False,#True,
        rotation_range=0)#90,
#        validation_split=0.2)
"""
For the test set only rescale should be made 
"""
test_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/three_class/train",
    target_size=(300, 300),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="training")
#    save_to_dir="D:/Separating Images into subfolders/train_augmented")


#print(train_generator.class_indices)

valid_generator = valid_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/three_class/vald",
    target_size=(300, 300),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="validation")
#    save_to_dir="D:/Separating Images into subfolders/val_augmented"


test_generator = test_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/three_class/test",
    target_size=(300, 300),
    color_mode="rgb",
    batch_size=1,
    class_mode="categorical",
    shuffle=False,
    seed=42)
#    save_to_dir="D:/Separating Images into subfolders/test_augmented")


# Fitting/Training the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
experiment_id = get_experiment_id()
callbacks = [
    QWK(valid_generator, STEP_SIZE_VALID),
    EarlyStopping(monitor='val_acc', patience=50, min_delta=0.001, verbose=1),
    ModelCheckpoint(experiment_id + "-val_kapa_checkpoint.hdf5", monitor='val_kappa', verbose=1, save_best_only=True, mode='max'),
    ReduceLROnPlateau(monitor='val_acc', factor=0.5, patience=7, verbose=1, mode='auto', min_delta=0.001, cooldown=0, min_lr=1e-7),
    VCM(valid_generator,STEP_SIZE_VALID)
    
]

class_weight_list = class_weight.compute_class_weight('balanced', np.unique(train_generator.classes), train_generator.classes)
class_weights = dict(zip(np.unique(train_generator.classes), class_weight_list))

history=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    class_weight=class_weights,
                    callbacks=callbacks,
                    epochs=50  
)


# Evaluating the model 
#predicting output
#reseting the test generator before calling predict_generator, in order not to get weird output
test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1', '2']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 296, 296, 16)      1216
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 292, 292, 16)      6416
# _________________________________________________________________
# fractional_pooling2d_1 (Frac (None, 171, 171, 16)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 169, 169, 16)      2320
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 167, 167, 16)      2320
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 163, 163, 16)      6416
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 159, 159, 16)      6416
# _________________________________________________________________
# fractional_pooling2d_2 (Frac (None, 93, 93, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 89, 89, 16)        6416
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 85, 85, 16)        6416
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 83, 83, 32)        4640
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 81, 81, 32)        9248
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 79, 79, 32)        9248
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 77, 77, 32)        9248
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 75, 75, 32)        9248
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 73, 73, 32)        9248
# _________________________________________________________________
# fractional_pooling2d_3 (Frac (None, 42, 42, 32)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 40, 40, 32)        9248
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 38, 38, 32)        9248
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 36, 36, 64)        18496
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 34, 34, 64)        36928
# _________________________________________________________________
# fractional_pooling2d_4 (Frac (None, 20, 20, 64)        0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 18, 18, 64)        36928
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 14, 14, 64)        36928
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 12, 12, 64)        36928
# _________________________________________________________________
# fractional_pooling2d_5 (Frac (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3136)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 9411
# =================================================================
# Total params: 319,859
# Trainable params: 319,859
# Non-trainable params: 0
# _________________________________________________________________
# Found 588 images belonging to 3 classes.
# Found 116 images belonging to 3 classes.
# Found 176 images belonging to 3 classes.
# Epoch 1/50
# 9/9 [==============================] - 29s 3s/step - loss: 1.0879 - acc: 0.3484 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4438 - loss_no_weight_decay: 1.0879 - val_loss: 1.0876 - val_acc: 0.5938 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4418 - val_loss_no_weight_decay: 1.0876
# — val_kappa: 0.0
#
# Epoch 00001: val_kappa improved from -inf to 0.00000, saving model to base_2020-05-09-15-41-00-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[26  0  0]
#  [ 5  0  0]
#  [21  0  0]]
# Epoch 2/50
# 9/9 [==============================] - 21s 2s/step - loss: 1.0859 - acc: 0.4654 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4433 - loss_no_weight_decay: 1.0859 - val_loss: 1.0848 - val_acc: 0.5962 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4412 - val_loss_no_weight_decay: 1.0848
# — val_kappa: 0.0
#
# Epoch 00002: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[27  0  0]
#  [ 7  0  0]
#  [18  0  0]]
# Epoch 3/50
# 9/9 [==============================] - 20s 2s/step - loss: 1.0776 - acc: 0.5143 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4410 - loss_no_weight_decay: 1.0776 - val_loss: 1.0803 - val_acc: 0.4531 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4387 - val_loss_no_weight_decay: 1.0803
# — val_kappa: 0.0
#
# Epoch 00003: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[22  0  0]
#  [ 6  0  0]
#  [24  0  0]]
# Epoch 4/50
# 9/9 [==============================] - 22s 2s/step - loss: 1.1210 - acc: 0.4271 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4414 - loss_no_weight_decay: 1.1210 - val_loss: 1.0547 - val_acc: 0.5192 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4328 - val_loss_no_weight_decay: 1.0547
# — val_kappa: 0.0
#
# Epoch 00004: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[23  0  0]
#  [ 6  0  0]
#  [23  0  0]]
# Epoch 5/50
# 9/9 [==============================] - 21s 2s/step - loss: 1.0489 - acc: 0.4511 - binary_accuracy: 0.6673 - mean_absolute_error: 0.4346 - loss_no_weight_decay: 1.0489 - val_loss: 1.1632 - val_acc: 0.2812 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4492 - val_loss_no_weight_decay: 1.1632
# — val_kappa: 0.0
#
# Epoch 00005: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[28  0  0]
#  [ 5  0  0]
#  [19  0  0]]
# Epoch 6/50
# 9/9 [==============================] - 21s 2s/step - loss: 1.0368 - acc: 0.4917 - binary_accuracy: 0.6819 - mean_absolute_error: 0.4253 - loss_no_weight_decay: 1.0368 - val_loss: 0.9924 - val_acc: 0.5000 - val_binary_accuracy: 0.7115 - val_mean_absolute_error: 0.4088 - val_loss_no_weight_decay: 0.9924
# — val_kappa: 0.15533980582524276
#
# Epoch 00006: val_kappa improved from 0.00000 to 0.15534, saving model to base_2020-05-09-15-41-00-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[29  0  0]
#  [ 5  0  0]
#  [18  0  0]]
# Epoch 7/50
# 9/9 [==============================] - 21s 2s/step - loss: 1.0108 - acc: 0.5486 - binary_accuracy: 0.7206 - mean_absolute_error: 0.3969 - loss_no_weight_decay: 1.0108 - val_loss: 1.0345 - val_acc: 0.3438 - val_binary_accuracy: 0.7135 - val_mean_absolute_error: 0.4177 - val_loss_no_weight_decay: 1.0345
# — val_kappa: 0.2318840579710143
#
# Epoch 00007: val_kappa improved from 0.15534 to 0.23188, saving model to base_2020-05-09-15-41-00-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[29  0  0]
#  [ 4  0  0]
#  [19  0  0]]
# Epoch 8/50
# 9/9 [==============================] - 18s 2s/step - loss: 1.0549 - acc: 0.4329 - binary_accuracy: 0.6901 - mean_absolute_error: 0.4146 - loss_no_weight_decay: 1.0549 - val_loss: 1.0339 - val_acc: 0.5962 - val_binary_accuracy: 0.6731 - val_mean_absolute_error: 0.4253 - val_loss_no_weight_decay: 1.0339
# — val_kappa: 0.020725388601036232
#
# Epoch 00008: val_kappa did not improve from 0.23188
# Confusion matrix:
#  [[28  0  0]
#  [ 7  0  0]
#  [17  0  0]]
# Epoch 9/50
# 9/9 [==============================] - 22s 2s/step - loss: 1.0328 - acc: 0.5503 - binary_accuracy: 0.6696 - mean_absolute_error: 0.4266 - loss_no_weight_decay: 1.0328 - val_loss: 0.9904 - val_acc: 0.5469 - val_binary_accuracy: 0.6823 - val_mean_absolute_error: 0.4153 - val_loss_no_weight_decay: 0.9904
# — val_kappa: 0.08163265306122436
#
# Epoch 00009: val_kappa did not improve from 0.23188
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Confusion matrix:
#  [[26  0  0]
#  [ 6  0  0]
#  [20  0  0]]
# Epoch 10/50
# 9/9 [==============================] - 20s 2s/step - loss: 1.0084 - acc: 0.5188 - binary_accuracy: 0.6989 - mean_absolute_error: 0.4056 - loss_no_weight_decay: 1.0084 - val_loss: 0.9099 - val_acc: 0.5385 - val_binary_accuracy: 0.7564 - val_mean_absolute_error: 0.3741 - val_loss_no_weight_decay: 0.9099
# — val_kappa: 0.23636363636363622
#
# Epoch 00010: val_kappa improved from 0.23188 to 0.23636, saving model to base_2020-05-09-15-41-00-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[27  2  0]
#  [ 3  1  0]
#  [16  3  0]]
# Epoch 11/50
# 9/9 [==============================] - 20s 2s/step - loss: 0.9850 - acc: 0.4777 - binary_accuracy: 0.7075 - mean_absolute_error: 0.3929 - loss_no_weight_decay: 0.9850 - val_loss: 0.9751 - val_acc: 0.4219 - val_binary_accuracy: 0.6979 - val_mean_absolute_error: 0.3987 - val_loss_no_weight_decay: 0.9751
# — val_kappa: 0.23963133640552992
#
# Epoch 00011: val_kappa improved from 0.23636 to 0.23963, saving model to base_2020-05-09-15-41-00-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[25  1  0]
#  [ 4  0  0]
#  [19  3  0]]
# Epoch 12/50
# 9/9 [==============================] - 20s 2s/step - loss: 0.9855 - acc: 0.4985 - binary_accuracy: 0.6978 - mean_absolute_error: 0.3933 - loss_no_weight_decay: 0.9855 - val_loss: 1.1463 - val_acc: 0.4231 - val_binary_accuracy: 0.6346 - val_mean_absolute_error: 0.4329 - val_loss_no_weight_decay: 1.1463
# — val_kappa: 0.06250000000000011
#
# Epoch 00012: val_kappa did not improve from 0.23963
# Confusion matrix:
#  [[27  4  0]
#  [ 1  3  0]
#  [ 9  8  0]]
# Epoch 13/50
# 9/9 [==============================] - 20s 2s/step - loss: 0.9595 - acc: 0.4862 - binary_accuracy: 0.7028 - mean_absolute_error: 0.3987 - loss_no_weight_decay: 0.9595 - val_loss: 0.9788 - val_acc: 0.4688 - val_binary_accuracy: 0.6927 - val_mean_absolute_error: 0.4048 - val_loss_no_weight_decay: 0.9788
# — val_kappa: 0.2949308755760367
#
# Epoch 00013: val_kappa improved from 0.23963 to 0.29493, saving model to base_2020-05-09-15-41-00-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[28  0  0]
#  [ 5  0  0]
#  [19  0  0]]
# Epoch 14/50
# 9/9 [==============================] - 21s 2s/step - loss: 0.9778 - acc: 0.5626 - binary_accuracy: 0.7219 - mean_absolute_error: 0.3859 - loss_no_weight_decay: 0.9778 - val_loss: 0.9086 - val_acc: 0.5769 - val_binary_accuracy: 0.7564 - val_mean_absolute_error: 0.3723 - val_loss_no_weight_decay: 0.9086
# — val_kappa: 0.31999999999999995
#
# Epoch 00014: val_kappa improved from 0.29493 to 0.32000, saving model to base_2020-05-09-15-41-00-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[26  1  0]
#  [ 5  1  0]
#  [13  6  0]]
# Epoch 15/50
# 9/9 [==============================] - 20s 2s/step - loss: 0.9060 - acc: 0.5927 - binary_accuracy: 0.7269 - mean_absolute_error: 0.3698 - loss_no_weight_decay: 0.9060 - val_loss: 0.8628 - val_acc: 0.5625 - val_binary_accuracy: 0.7552 - val_mean_absolute_error: 0.3712 - val_loss_no_weight_decay: 0.8628
# — val_kappa: 0.26728110599078325
#
# Epoch 00015: val_kappa did not improve from 0.32000
# Confusion matrix:
#  [[30  0  1]
#  [ 4  0  1]
#  [14  1  1]]
# Epoch 16/50
# 9/9 [==============================] - 21s 2s/step - loss: 0.9442 - acc: 0.6007 - binary_accuracy: 0.7402 - mean_absolute_error: 0.3720 - loss_no_weight_decay: 0.9442 - val_loss: 0.9546 - val_acc: 0.4423 - val_binary_accuracy: 0.7372 - val_mean_absolute_error: 0.3803 - val_loss_no_weight_decay: 0.9546
# — val_kappa: 0.19999999999999996
#
# Epoch 00016: val_kappa did not improve from 0.32000
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Confusion matrix:
#  [[23  0  1]
#  [ 5  3  1]
#  [16  2  1]]
# Epoch 17/50
# 9/9 [==============================] - 20s 2s/step - loss: 0.8577 - acc: 0.6117 - binary_accuracy: 0.7523 - mean_absolute_error: 0.3577 - loss_no_weight_decay: 0.8577 - val_loss: 0.8015 - val_acc: 0.6719 - val_binary_accuracy: 0.7760 - val_mean_absolute_error: 0.3397 - val_loss_no_weight_decay: 0.8015
# — val_kappa: 0.36283185840707954
#
# Epoch 00017: val_kappa improved from 0.32000 to 0.36283, saving model to base_2020-05-09-15-41-00-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[23  1  0]
#  [ 3  1  2]
#  [17  4  1]]
# Epoch 18/50
# 9/9 [==============================] - 20s 2s/step - loss: 0.9145 - acc: 0.6065 - binary_accuracy: 0.7431 - mean_absolute_error: 0.3586 - loss_no_weight_decay: 0.9145 - val_loss: 0.8087 - val_acc: 0.5769 - val_binary_accuracy: 0.7885 - val_mean_absolute_error: 0.3427 - val_loss_no_weight_decay: 0.8087
# — val_kappa: 0.23318385650224205
#
# Epoch 00018: val_kappa did not improve from 0.36283
# Confusion matrix:
#  [[31  0  1]
#  [ 2  1  0]
#  [13  3  1]]
# Epoch 19/50
# 9/9 [==============================] - 20s 2s/step - loss: 0.8570 - acc: 0.5995 - binary_accuracy: 0.7395 - mean_absolute_error: 0.3584 - loss_no_weight_decay: 0.8570 - val_loss: 0.9060 - val_acc: 0.4375 - val_binary_accuracy: 0.7083 - val_mean_absolute_error: 0.3705 - val_loss_no_weight_decay: 0.9060
# — val_kappa: 0.3739130434782608
#
# Epoch 00019: val_kappa improved from 0.36283 to 0.37391, saving model to base_2020-05-09-15-41-00-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[23  0  1]
#  [ 4  2  0]
#  [14  7  1]]
# Epoch 20/50
# 9/9 [==============================] - 19s 2s/step - loss: 0.8543 - acc: 0.6065 - binary_accuracy: 0.7515 - mean_absolute_error: 0.3488 - loss_no_weight_decay: 0.8543 - val_loss: 0.8615 - val_acc: 0.5769 - val_binary_accuracy: 0.7436 - val_mean_absolute_error: 0.3454 - val_loss_no_weight_decay: 0.8615
# — val_kappa: 0.18181818181818177
#
# Epoch 00020: val_kappa did not improve from 0.37391
# Confusion matrix:
#  [[24  0  0]
#  [ 3  3  0]
#  [16  5  1]]
# Epoch 21/50
# 9/9 [==============================] - 22s 2s/step - loss: 0.8556 - acc: 0.6094 - binary_accuracy: 0.7523 - mean_absolute_error: 0.3435 - loss_no_weight_decay: 0.8556 - val_loss: 0.8615 - val_acc: 0.5156 - val_binary_accuracy: 0.7188 - val_mean_absolute_error: 0.3561 - val_loss_no_weight_decay: 0.8615
# — val_kappa: 0.4206008583690988
#
# Epoch 00021: val_kappa improved from 0.37391 to 0.42060, saving model to base_2020-05-09-15-41-00-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[19  1  1]
#  [ 4  3  2]
#  [14  7  1]]
# Epoch 22/50
# 9/9 [==============================] - 18s 2s/step - loss: 0.8660 - acc: 0.5889 - binary_accuracy: 0.7404 - mean_absolute_error: 0.3516 - loss_no_weight_decay: 0.8660 - val_loss: 0.7487 - val_acc: 0.6538 - val_binary_accuracy: 0.7821 - val_mean_absolute_error: 0.3308 - val_loss_no_weight_decay: 0.7487
# — val_kappa: 0.25688073394495414
#
# Epoch 00022: val_kappa did not improve from 0.42060
# Confusion matrix:
#  [[27  0  0]
#  [ 3  4  2]
#  [10  3  3]]
# Epoch 23/50
# 9/9 [==============================] - 20s 2s/step - loss: 0.8249 - acc: 0.6603 - binary_accuracy: 0.7597 - mean_absolute_error: 0.3372 - loss_no_weight_decay: 0.8249 - val_loss: 0.8574 - val_acc: 0.6250 - val_binary_accuracy: 0.7240 - val_mean_absolute_error: 0.3585 - val_loss_no_weight_decay: 0.8574
# — val_kappa: 0.2831858407079645
#
# Epoch 00023: val_kappa did not improve from 0.42060
# Confusion matrix:
#  [[26  0  0]
#  [ 4  2  0]
#  [15  3  2]]
# Epoch 24/50
# 9/9 [==============================] - 20s 2s/step - loss: 0.8262 - acc: 0.6175 - binary_accuracy: 0.7693 - mean_absolute_error: 0.3324 - loss_no_weight_decay: 0.8262 - val_loss: 0.7750 - val_acc: 0.6154 - val_binary_accuracy: 0.7756 - val_mean_absolute_error: 0.3344 - val_loss_no_weight_decay: 0.7750
# — val_kappa: 0.31999999999999995
#
# Epoch 00024: val_kappa did not improve from 0.42060
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Confusion matrix:
#  [[21  0  2]
#  [ 3  4  0]
#  [12  9  1]]
# Epoch 25/50
# 9/9 [==============================] - 20s 2s/step - loss: 0.8054 - acc: 0.6225 - binary_accuracy: 0.7576 - mean_absolute_error: 0.3316 - loss_no_weight_decay: 0.8054 - val_loss: 0.8089 - val_acc: 0.5781 - val_binary_accuracy: 0.7708 - val_mean_absolute_error: 0.3371 - val_loss_no_weight_decay: 0.8089
# — val_kappa: 0.476595744680851
#
# Epoch 00025: val_kappa improved from 0.42060 to 0.47660, saving model to base_2020-05-09-15-41-00-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[25  0  0]
#  [ 4  1  1]
#  [12  7  2]]
# Epoch 26/50
# 9/9 [==============================] - 21s 2s/step - loss: 0.7918 - acc: 0.6510 - binary_accuracy: 0.7668 - mean_absolute_error: 0.3237 - loss_no_weight_decay: 0.7918 - val_loss: 0.8497 - val_acc: 0.5000 - val_binary_accuracy: 0.7308 - val_mean_absolute_error: 0.3483 - val_loss_no_weight_decay: 0.8497
# — val_kappa: 0.3948497854077253
#
# Epoch 00026: val_kappa did not improve from 0.47660
# Confusion matrix:
#  [[26  0  0]
#  [ 5  1  0]
#  [11  7  2]]
# Epoch 27/50
# 9/9 [==============================] - 20s 2s/step - loss: 0.8187 - acc: 0.6290 - binary_accuracy: 0.7590 - mean_absolute_error: 0.3234 - loss_no_weight_decay: 0.8187 - val_loss: 0.7792 - val_acc: 0.5469 - val_binary_accuracy: 0.7396 - val_mean_absolute_error: 0.3288 - val_loss_no_weight_decay: 0.7792
# — val_kappa: 0.31759656652360524
#
# Epoch 00027: val_kappa did not improve from 0.47660
# Confusion matrix:
#  [[26  0  1]
#  [ 4  3  0]
#  [14  3  1]]
# Epoch 28/50
# 9/9 [==============================] - 20s 2s/step - loss: 0.7632 - acc: 0.6501 - binary_accuracy: 0.7812 - mean_absolute_error: 0.3205 - loss_no_weight_decay: 0.7632 - val_loss: 0.7858 - val_acc: 0.5962 - val_binary_accuracy: 0.7500 - val_mean_absolute_error: 0.3279 - val_loss_no_weight_decay: 0.7858
# — val_kappa: 0.36909871244635195
#
# Epoch 00028: val_kappa did not improve from 0.47660
# Confusion matrix:
#  [[24  0  1]
#  [ 5  2  1]
#  [14  3  2]]
# Epoch 29/50
# 9/9 [==============================] - 20s 2s/step - loss: 0.8737 - acc: 0.5874 - binary_accuracy: 0.7493 - mean_absolute_error: 0.3360 - loss_no_weight_decay: 0.8737 - val_loss: 0.8482 - val_acc: 0.5156 - val_binary_accuracy: 0.7188 - val_mean_absolute_error: 0.3542 - val_loss_no_weight_decay: 0.8482
# — val_kappa: 0.3580786026200874
#
# Epoch 00029: val_kappa did not improve from 0.47660
# Confusion matrix:
#  [[26  1  0]
#  [ 0  5  0]
#  [11  9  0]]
# Epoch 30/50
# 9/9 [==============================] - 20s 2s/step - loss: 0.8138 - acc: 0.6443 - binary_accuracy: 0.7643 - mean_absolute_error: 0.3260 - loss_no_weight_decay: 0.8138 - val_loss: 0.8454 - val_acc: 0.6346 - val_binary_accuracy: 0.7500 - val_mean_absolute_error: 0.3455 - val_loss_no_weight_decay: 0.8454
# — val_kappa: 0.42553191489361697
#
# Epoch 00030: val_kappa did not improve from 0.47660
# Confusion matrix:
#  [[23  0  0]
#  [ 3  1  1]
#  [18  4  2]]
# Epoch 31/50
# 9/9 [==============================] - 20s 2s/step - loss: 0.7546 - acc: 0.7177 - binary_accuracy: 0.8028 - mean_absolute_error: 0.3096 - loss_no_weight_decay: 0.7546 - val_loss: 0.8153 - val_acc: 0.5781 - val_binary_accuracy: 0.7396 - val_mean_absolute_error: 0.3326 - val_loss_no_weight_decay: 0.8153
# — val_kappa: 0.4260869565217391
#
# Epoch 00031: val_kappa did not improve from 0.47660
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Confusion matrix:
#  [[27  0  0]
#  [ 0  2  0]
#  [15  8  0]]
# Epoch 32/50
# 9/9 [==============================] - 19s 2s/step - loss: 0.7982 - acc: 0.6222 - binary_accuracy: 0.7629 - mean_absolute_error: 0.3234 - loss_no_weight_decay: 0.7982 - val_loss: 0.8685 - val_acc: 0.5000 - val_binary_accuracy: 0.7308 - val_mean_absolute_error: 0.3534 - val_loss_no_weight_decay: 0.8685
# — val_kappa: 0.32599118942731276
#
# Epoch 00032: val_kappa did not improve from 0.47660
# Confusion matrix:
#  [[24  0  0]
#  [ 3  3  1]
#  [16  5  0]]
# Epoch 33/50
# 9/9 [==============================] - 20s 2s/step - loss: 0.7935 - acc: 0.6466 - binary_accuracy: 0.7685 - mean_absolute_error: 0.3181 - loss_no_weight_decay: 0.7935 - val_loss: 0.8391 - val_acc: 0.5781 - val_binary_accuracy: 0.7344 - val_mean_absolute_error: 0.3394 - val_loss_no_weight_decay: 0.8391
# — val_kappa: 0.3389830508474576
#
# Epoch 00033: val_kappa did not improve from 0.47660
# Confusion matrix:
#  [[25  0  2]
#  [ 6  1  0]
#  [13  3  2]]
# Epoch 34/50
# 9/9 [==============================] - 20s 2s/step - loss: 0.7662 - acc: 0.6646 - binary_accuracy: 0.7740 - mean_absolute_error: 0.3182 - loss_no_weight_decay: 0.7662 - val_loss: 0.7613 - val_acc: 0.5962 - val_binary_accuracy: 0.7436 - val_mean_absolute_error: 0.3275 - val_loss_no_weight_decay: 0.7613
# — val_kappa: 0.4206008583690988
#
# Epoch 00034: val_kappa did not improve from 0.47660
# Confusion matrix:
#  [[21  0  2]
#  [ 2  2  2]
#  [13  8  2]]
# Epoch 35/50
# 9/9 [==============================] - 22s 2s/step - loss: 0.7547 - acc: 0.6771 - binary_accuracy: 0.7847 - mean_absolute_error: 0.3066 - loss_no_weight_decay: 0.7547 - val_loss: 0.8527 - val_acc: 0.5938 - val_binary_accuracy: 0.7188 - val_mean_absolute_error: 0.3511 - val_loss_no_weight_decay: 0.8527
# — val_kappa: 0.3739130434782608
#
# Epoch 00035: val_kappa did not improve from 0.47660
# Confusion matrix:
#  [[30  0  1]
#  [ 1  1  1]
#  [11  6  1]]
# Epoch 36/50
# 9/9 [==============================] - 18s 2s/step - loss: 0.7491 - acc: 0.6858 - binary_accuracy: 0.7782 - mean_absolute_error: 0.3010 - loss_no_weight_decay: 0.7491 - val_loss: 0.8551 - val_acc: 0.5769 - val_binary_accuracy: 0.7115 - val_mean_absolute_error: 0.3548 - val_loss_no_weight_decay: 0.8551
# — val_kappa: 0.31168831168831157
#
# Epoch 00036: val_kappa did not improve from 0.47660
# Confusion matrix:
#  [[26  0  3]
#  [ 5  2  1]
#  [10  3  2]]
# Epoch 37/50
# 9/9 [==============================] - 20s 2s/step - loss: 0.7765 - acc: 0.6721 - binary_accuracy: 0.7809 - mean_absolute_error: 0.3165 - loss_no_weight_decay: 0.7765 - val_loss: 0.8089 - val_acc: 0.6094 - val_binary_accuracy: 0.7396 - val_mean_absolute_error: 0.3288 - val_loss_no_weight_decay: 0.8089
# — val_kappa: 0.4201680672268908
#
# Epoch 00037: val_kappa did not improve from 0.47660
# Confusion matrix:
#  [[20  0  3]
#  [ 3  2  1]
#  [13  6  4]]
# Epoch 38/50
# 9/9 [==============================] - 20s 2s/step - loss: 0.8006 - acc: 0.6641 - binary_accuracy: 0.7734 - mean_absolute_error: 0.3188 - loss_no_weight_decay: 0.8006 - val_loss: 0.7448 - val_acc: 0.6538 - val_binary_accuracy: 0.7949 - val_mean_absolute_error: 0.3064 - val_loss_no_weight_decay: 0.7448
# — val_kappa: 0.38427947598253265
#
# Epoch 00038: val_kappa did not improve from 0.47660
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Confusion matrix:
#  [[26  0  1]
#  [ 4  1  2]
#  [ 9  5  4]]
# Epoch 39/50
# 9/9 [==============================] - 21s 2s/step - loss: 0.7730 - acc: 0.6719 - binary_accuracy: 0.8003 - mean_absolute_error: 0.2993 - loss_no_weight_decay: 0.7730 - val_loss: 0.7631 - val_acc: 0.6094 - val_binary_accuracy: 0.7500 - val_mean_absolute_error: 0.3314 - val_loss_no_weight_decay: 0.7631
# — val_kappa: 0.2600896860986547
#
# Epoch 00039: val_kappa did not improve from 0.47660
# Confusion matrix:
#  [[27  1  1]
#  [ 2  4  1]
#  [ 7  6  3]]
# Epoch 40/50
# 9/9 [==============================] - 20s 2s/step - loss: 0.7504 - acc: 0.6766 - binary_accuracy: 0.7775 - mean_absolute_error: 0.3141 - loss_no_weight_decay: 0.7504 - val_loss: 0.7621 - val_acc: 0.5962 - val_binary_accuracy: 0.7692 - val_mean_absolute_error: 0.3163 - val_loss_no_weight_decay: 0.7621
# — val_kappa: 0.3275862068965517
#
# Epoch 00040: val_kappa did not improve from 0.47660
# Confusion matrix:
#  [[30  0  1]
#  [ 4  1  0]
#  [11  3  2]]
# Epoch 41/50
# 9/9 [==============================] - 20s 2s/step - loss: 0.7682 - acc: 0.6819 - binary_accuracy: 0.7909 - mean_absolute_error: 0.3070 - loss_no_weight_decay: 0.7682 - val_loss: 0.7840 - val_acc: 0.6250 - val_binary_accuracy: 0.7552 - val_mean_absolute_error: 0.3226 - val_loss_no_weight_decay: 0.7840
# — val_kappa: 0.32173913043478264
#
# Epoch 00041: val_kappa did not improve from 0.47660
# Confusion matrix:
#  [[27  0  1]
#  [ 3  1  0]
#  [12  6  2]]
# Epoch 42/50
# 9/9 [==============================] - 20s 2s/step - loss: 0.7821 - acc: 0.6854 - binary_accuracy: 0.7810 - mean_absolute_error: 0.3105 - loss_no_weight_decay: 0.7821 - val_loss: 0.7201 - val_acc: 0.6538 - val_binary_accuracy: 0.7949 - val_mean_absolute_error: 0.3000 - val_loss_no_weight_decay: 0.7201
# — val_kappa: 0.4206008583690988
#
# Epoch 00042: val_kappa did not improve from 0.47660
# Confusion matrix:
#  [[22  0  2]
#  [ 5  1  0]
#  [14  6  2]]
# Epoch 43/50
# 9/9 [==============================] - 22s 2s/step - loss: 0.7672 - acc: 0.6545 - binary_accuracy: 0.7801 - mean_absolute_error: 0.3111 - loss_no_weight_decay: 0.7672 - val_loss: 0.7999 - val_acc: 0.6406 - val_binary_accuracy: 0.7448 - val_mean_absolute_error: 0.3295 - val_loss_no_weight_decay: 0.7999
# — val_kappa: 0.3433476394849786
#
# Epoch 00043: val_kappa did not improve from 0.47660
# Confusion matrix:
#  [[27  0  2]
#  [ 2  0  1]
#  [12  5  3]]
# Epoch 44/50
# 9/9 [==============================] - 18s 2s/step - loss: 0.7099 - acc: 0.6992 - binary_accuracy: 0.7933 - mean_absolute_error: 0.3016 - loss_no_weight_decay: 0.7099 - val_loss: 0.9056 - val_acc: 0.5769 - val_binary_accuracy: 0.7115 - val_mean_absolute_error: 0.3590 - val_loss_no_weight_decay: 0.9056
# — val_kappa: 0.35983263598326354
#
# Epoch 00044: val_kappa did not improve from 0.47660
# Confusion matrix:
#  [[24  0  1]
#  [ 5  1  0]
#  [15  4  2]]
# Epoch 45/50
# 9/9 [==============================] - 20s 2s/step - loss: 0.7483 - acc: 0.7047 - binary_accuracy: 0.7880 - mean_absolute_error: 0.3054 - loss_no_weight_decay: 0.7483 - val_loss: 0.7644 - val_acc: 0.6250 - val_binary_accuracy: 0.7604 - val_mean_absolute_error: 0.3129 - val_loss_no_weight_decay: 0.7644
# — val_kappa: 0.38983050847457623
#
# Epoch 00045: val_kappa did not improve from 0.47660
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Confusion matrix:
#  [[21  0  0]
#  [ 4  2  0]
#  [14  8  3]]
# Epoch 46/50
# 9/9 [==============================] - 20s 2s/step - loss: 0.7525 - acc: 0.6919 - binary_accuracy: 0.7913 - mean_absolute_error: 0.3059 - loss_no_weight_decay: 0.7525 - val_loss: 0.7556 - val_acc: 0.6538 - val_binary_accuracy: 0.7692 - val_mean_absolute_error: 0.3150 - val_loss_no_weight_decay: 0.7556
# — val_kappa: 0.33766233766233755
#
# Epoch 00046: val_kappa did not improve from 0.47660
# Confusion matrix:
#  [[26  0  1]
#  [ 2  3  1]
#  [10  7  2]]
# Epoch 47/50
# 9/9 [==============================] - 22s 2s/step - loss: 0.7440 - acc: 0.6910 - binary_accuracy: 0.7957 - mean_absolute_error: 0.3014 - loss_no_weight_decay: 0.7440 - val_loss: 0.7753 - val_acc: 0.6250 - val_binary_accuracy: 0.7500 - val_mean_absolute_error: 0.3231 - val_loss_no_weight_decay: 0.7753
# — val_kappa: 0.41025641025641013
#
# Epoch 00047: val_kappa did not improve from 0.47660
# Confusion matrix:
#  [[23  0  2]
#  [ 3  1  0]
#  [14  7  2]]
# Epoch 48/50
# 9/9 [==============================] - 19s 2s/step - loss: 0.7874 - acc: 0.6633 - binary_accuracy: 0.7811 - mean_absolute_error: 0.3058 - loss_no_weight_decay: 0.7874 - val_loss: 0.7570 - val_acc: 0.6346 - val_binary_accuracy: 0.7692 - val_mean_absolute_error: 0.3159 - val_loss_no_weight_decay: 0.7570
# — val_kappa: 0.3846153846153846
#
# Epoch 00048: val_kappa did not improve from 0.47660
# Confusion matrix:
#  [[25  0  5]
#  [ 2  2  0]
#  [10  4  4]]
# Epoch 49/50
# 9/9 [==============================] - 20s 2s/step - loss: 0.7244 - acc: 0.6839 - binary_accuracy: 0.7898 - mean_absolute_error: 0.3034 - loss_no_weight_decay: 0.7244 - val_loss: 0.7268 - val_acc: 0.6406 - val_binary_accuracy: 0.7760 - val_mean_absolute_error: 0.3030 - val_loss_no_weight_decay: 0.7268
# — val_kappa: 0.26956521739130435
#
# Epoch 00049: val_kappa did not improve from 0.47660
# Confusion matrix:
#  [[28  0  1]
#  [ 3  3  1]
#  [ 9  4  3]]
# Epoch 50/50
# 9/9 [==============================] - 19s 2s/step - loss: 0.7932 - acc: 0.6716 - binary_accuracy: 0.7765 - mean_absolute_error: 0.3117 - loss_no_weight_decay: 0.7932 - val_loss: 0.8744 - val_acc: 0.5962 - val_binary_accuracy: 0.7436 - val_mean_absolute_error: 0.3438 - val_loss_no_weight_decay: 0.8744
# — val_kappa: 0.3433476394849786
#
# Epoch 00050: val_kappa did not improve from 0.47660
# Confusion matrix:
#  [[26  0  2]
#  [ 3  4  0]
#  [ 8  7  2]]
# 176/176 [==============================] - 5s 27ms/step
# 176/176 [==============================] - 5s 28ms/step
# Test loss: 0.7265884410378269
# Test accuracy: 0.6477272727272727
# Confusion Matrix
# [[76  0 12]
#  [ 2 14  3]
#  [19 26 24]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.78      0.86      0.82        88
#            1       0.35      0.74      0.47        19
#            2       0.62      0.35      0.44        69
#
#     accuracy                           0.65       176
#    macro avg       0.58      0.65      0.58       176
# weighted avg       0.67      0.65      0.64       176

# %%
from Kappa_Skl import kappa
def kappa2(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    if len(y_true.shape) > 1 and y_true.shape[1] > 1:
        y_true = y_true.dot(range(y_true.shape[1]))
    if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
        y_pred = y_pred.dot(range(y_pred.shape[1]))
    try:
        return kappa(y_true, y_pred, weights='quadratic')
    except IndexError:
        return np.nan
    
print('Quadratic_wieghted_kappa')
print(kappa2(y_true, y_pred))
# Out:
# Quadratic_wieghted_kappa
# 0.4473705534397536

# %%
import numpy as np 
import matplotlib.pyplot as plt
import os
import wandb
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model loss.png')

# summarize history for val_kappa
plt.plot(history.history['val_kappa'])
plt.title('Validation_Kappa')
plt.ylabel('val_kappa')
plt.xlabel('epoch')
plt.legend([ 'validation'], loc='upper left')
plt.show()
#plt.savefig('model validation_kappa.png')

# summarize history for mean_absolute _error
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model mean_absolute_error')
plt.ylabel('mean_absolute_error')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model maey.png'
# Out:
# dict_keys(['val_loss', 'val_acc', 'val_binary_accuracy', 'val_mean_absolute_error', 'val_loss_no_weight_decay', 'loss', 'acc', 'binary_accuracy', 'mean_absolute_error', 'loss_no_weight_decay', 'val_kappa', 'lr'])
