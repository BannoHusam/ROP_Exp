# %%
import keras
from keras.models import Sequential, Input, Model
from keras.losses import mean_squared_error
from keras.layers import  *
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, InputLayer
from keras.regularizers import L1L2, l2, l1
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from custom_pooling import RMSPooling2D
from keras.optimizers import SGD, Adam
from keras.layers import LeakyReLU
#from data import BALANCE_WEIGHTS
from keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
#import os
from datetime import datetime as dt
from custom_loss import WeightedCategoricalCrossEntropy
from VCM import VCM
import keras.backend as K
from Fractional_MAXPOOL import FractionalPooling2D
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
def get_experiment_id():
    time_str = dt.now().strftime('%Y-%m-%d-%H-%M-%S')
    experiment_id = 'base_{}'.format(time_str)
    return experiment_id
p_ratio=[1.0, 1.44, 1.73, 1.0]

model = Sequential()


model.add(Conv2D(16, (5, 5), activation='tanh', input_shape=(270, 270, 3)))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(16, (3, 3), activation='tanh'))
model.add(Conv2D(16, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

#model.add(LeakyReLU(alpha=0.01))


model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))


model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))          
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))


model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

#model.add(MaxPooling2D(pool_size=1))




model.add(MaxPooling2D(pool_size=2))

model.add(Flatten())


#chnaged from 10 to 5 because an error 
model.add(Dense(2, activation='softmax'))

sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.count_params()
#adam = Adam(lr=0.0005, decay=1e-6)
#rmsprop
#Mloss = WeightedCategoricalCrossEntropy({0: 0.4125861396437394, 1: 1.4918664786083686, 2: 0.690426457789382, 3: 3.9541433021806855, 4: 4.885604311008468})
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['mae','acc'])
model.summary()
loss_no_weight_decay = model.total_loss - sum(model.losses)
model.metrics_tensors.append(loss_no_weight_decay)
model.metrics_names.append('loss_no_weight_decay')
#############################################################################################
#############################################################################################
#############################################################################################
#############################################################################################
#Preparing Data Augmentation Configuration 
train_datagen = ImageDataGenerator(
        rescale=1./255,
#        featurewise_center=True,
 #       samplewise_center=True,
        shear_range=0,
        zoom_range=0.0,#[1 / 1.15, 1.15],
        horizontal_flip=False,#True,
        rotation_range=0)#90,
#        validation_split=0.2)
"""
For the test set only rescale should be made 
"""
test_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas/train",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="training")
#    save_to_dir="D:/Separating Images into subfolders/train_augmented")


#print(train_generator.class_indices)

valid_generator = valid_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas/vald",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="validation")
#    save_to_dir="D:/Separating Images into subfolders/val_augmented"


test_generator = test_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas/test",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=1,
    class_mode="categorical",
    shuffle=False,
    seed=42)
#    save_to_dir="D:/Separating Images into subfolders/test_augmented")


# Fitting/Training the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
experiment_id = get_experiment_id()
callbacks = [
    EarlyStopping(monitor='val_acc', patience=50, min_delta=0.001, verbose=1),
    ModelCheckpoint(experiment_id + "-val_acc_checkpoint.hdf5", monitor='val_acc', verbose=1, save_best_only=True, mode='auto'),
    ReduceLROnPlateau(monitor='val_acc', factor=0.5, patience=7, verbose=1, mode='auto', min_delta=0.001, cooldown=0, min_lr=1e-7),
    VCM(valid_generator,STEP_SIZE_VALID)
    
]

class_weight_list = class_weight.compute_class_weight('balanced', np.unique(train_generator.classes), train_generator.classes)
class_weights = dict(zip(np.unique(train_generator.classes), class_weight_list))

history=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    #class_weight=class_weights,
                    callbacks=callbacks,
                    epochs=35  
)


# Evaluating the model 
#predicting output
#reseting the test generator before calling predict_generator, in order not to get weird output
test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 266, 266, 16)      1216
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 262, 262, 16)      6416
# _________________________________________________________________
# fractional_pooling2d_1 (Frac (None, 145, 145, 16)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 143, 143, 16)      2320
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 141, 141, 16)      2320
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 137, 137, 16)      6416
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 133, 133, 16)      6416
# _________________________________________________________________
# fractional_pooling2d_2 (Frac (None, 73, 73, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 69, 69, 16)        6416
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 65, 65, 16)        6416
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 63, 63, 32)        4640
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 61, 61, 32)        9248
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 59, 59, 32)        9248
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 57, 57, 32)        9248
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 55, 55, 32)        9248
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 53, 53, 32)        9248
# _________________________________________________________________
# fractional_pooling2d_3 (Frac (None, 29, 29, 32)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 27, 27, 32)        9248
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 25, 25, 32)        9248
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 23, 23, 64)        18496
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 21, 21, 64)        36928
# _________________________________________________________________
# fractional_pooling2d_4 (Frac (None, 11, 11, 64)        0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 9, 9, 64)          36928
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 7, 7, 64)          36928
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 5, 5, 64)          36928
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 3, 3, 64)          36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 1, 1, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 310,578
# Trainable params: 310,578
# Non-trainable params: 0
# _________________________________________________________________
# Found 588 images belonging to 2 classes.
# Found 116 images belonging to 2 classes.
# Found 176 images belonging to 2 classes.
# Epoch 1/35
# 9/9 [==============================] - 21s 2s/step - loss: 0.6978 - mean_absolute_error: 0.5004 - acc: 0.5100 - loss_no_weight_decay: 0.6978 - val_loss: 0.6959 - val_mean_absolute_error: 0.5013 - val_acc: 0.4219 - val_loss_no_weight_decay: 0.6959
#
# Epoch 00001: val_acc improved from -inf to 0.42188, saving model to base_2020-05-07-21-44-40-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[ 1 31]
#  [ 0 32]]
# Epoch 2/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.6917 - mean_absolute_error: 0.4972 - acc: 0.5258 - loss_no_weight_decay: 0.6917 - val_loss: 0.6739 - val_mean_absolute_error: 0.4870 - val_acc: 0.5962 - val_loss_no_weight_decay: 0.6739
#
# Epoch 00002: val_acc improved from 0.42188 to 0.59615, saving model to base_2020-05-07-21-44-40-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[ 0 26]
#  [ 0 26]]
# Epoch 3/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.6948 - mean_absolute_error: 0.4994 - acc: 0.5017 - loss_no_weight_decay: 0.6948 - val_loss: 0.6901 - val_mean_absolute_error: 0.4984 - val_acc: 0.6250 - val_loss_no_weight_decay: 0.6901
#
# Epoch 00003: val_acc improved from 0.59615 to 0.62500, saving model to base_2020-05-07-21-44-40-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[ 6 22]
#  [ 1 35]]
# Epoch 4/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.6912 - mean_absolute_error: 0.4962 - acc: 0.5402 - loss_no_weight_decay: 0.6912 - val_loss: 0.7044 - val_mean_absolute_error: 0.5000 - val_acc: 0.5000 - val_loss_no_weight_decay: 0.7044
#
# Epoch 00004: val_acc did not improve from 0.62500
# Confusion matrix:
#  [[31  0]
#  [21  0]]
# Epoch 5/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.6971 - mean_absolute_error: 0.5001 - acc: 0.5087 - loss_no_weight_decay: 0.6971 - val_loss: 0.6834 - val_mean_absolute_error: 0.4950 - val_acc: 0.6562 - val_loss_no_weight_decay: 0.6834
#
# Epoch 00005: val_acc improved from 0.62500 to 0.65625, saving model to base_2020-05-07-21-44-40-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[ 7 23]
#  [ 0 34]]
# Epoch 6/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.6907 - mean_absolute_error: 0.4974 - acc: 0.5065 - loss_no_weight_decay: 0.6907 - val_loss: 0.6941 - val_mean_absolute_error: 0.4998 - val_acc: 0.4231 - val_loss_no_weight_decay: 0.6941
#
# Epoch 00006: val_acc did not improve from 0.65625
# Confusion matrix:
#  [[ 3 22]
#  [ 0 27]]
# Epoch 7/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.6858 - mean_absolute_error: 0.4960 - acc: 0.5710 - loss_no_weight_decay: 0.6858 - val_loss: 0.6826 - val_mean_absolute_error: 0.4942 - val_acc: 0.5156 - val_loss_no_weight_decay: 0.6826
#
# Epoch 00007: val_acc did not improve from 0.65625
# Confusion matrix:
#  [[30  0]
#  [34  0]]
# Epoch 8/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.6827 - mean_absolute_error: 0.4940 - acc: 0.5399 - loss_no_weight_decay: 0.6827 - val_loss: 0.6731 - val_mean_absolute_error: 0.4879 - val_acc: 0.6538 - val_loss_no_weight_decay: 0.6731
#
# Epoch 00008: val_acc did not improve from 0.65625
# Confusion matrix:
#  [[ 6 19]
#  [ 0 27]]
# Epoch 9/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.6759 - mean_absolute_error: 0.4893 - acc: 0.5856 - loss_no_weight_decay: 0.6759 - val_loss: 0.6745 - val_mean_absolute_error: 0.4886 - val_acc: 0.6094 - val_loss_no_weight_decay: 0.6745
#
# Epoch 00009: val_acc did not improve from 0.65625
# Confusion matrix:
#  [[ 9 22]
#  [ 5 28]]
# Epoch 10/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.6656 - mean_absolute_error: 0.4844 - acc: 0.6337 - loss_no_weight_decay: 0.6656 - val_loss: 0.6299 - val_mean_absolute_error: 0.4646 - val_acc: 0.7115 - val_loss_no_weight_decay: 0.6299
#
# Epoch 00010: val_acc improved from 0.65625 to 0.71154, saving model to base_2020-05-07-21-44-40-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[10 10]
#  [ 6 26]]
# Epoch 11/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.6509 - mean_absolute_error: 0.4700 - acc: 0.6418 - loss_no_weight_decay: 0.6509 - val_loss: 0.7178 - val_mean_absolute_error: 0.4329 - val_acc: 0.5938 - val_loss_no_weight_decay: 0.7178
#
# Epoch 00011: val_acc did not improve from 0.71154
# Confusion matrix:
#  [[30  0]
#  [34  0]]
# Epoch 12/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.6953 - mean_absolute_error: 0.4766 - acc: 0.5754 - loss_no_weight_decay: 0.6953 - val_loss: 0.6154 - val_mean_absolute_error: 0.4421 - val_acc: 0.6731 - val_loss_no_weight_decay: 0.6154
#
# Epoch 00012: val_acc did not improve from 0.71154
# Confusion matrix:
#  [[ 9 20]
#  [ 0 23]]
# Epoch 13/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.6601 - mean_absolute_error: 0.4728 - acc: 0.6205 - loss_no_weight_decay: 0.6601 - val_loss: 0.6625 - val_mean_absolute_error: 0.4822 - val_acc: 0.6875 - val_loss_no_weight_decay: 0.6625
#
# Epoch 00013: val_acc did not improve from 0.71154
# Confusion matrix:
#  [[24  8]
#  [15 17]]
# Epoch 14/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.6527 - mean_absolute_error: 0.4759 - acc: 0.6365 - loss_no_weight_decay: 0.6527 - val_loss: 0.6198 - val_mean_absolute_error: 0.4563 - val_acc: 0.6538 - val_loss_no_weight_decay: 0.6198
#
# Epoch 00014: val_acc did not improve from 0.71154
# Confusion matrix:
#  [[14  6]
#  [13 19]]
# Epoch 15/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.6425 - mean_absolute_error: 0.4661 - acc: 0.6280 - loss_no_weight_decay: 0.6425 - val_loss: 0.5774 - val_mean_absolute_error: 0.4261 - val_acc: 0.7500 - val_loss_no_weight_decay: 0.5774
#
# Epoch 00015: val_acc improved from 0.71154 to 0.75000, saving model to base_2020-05-07-21-44-40-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[16 11]
#  [10 27]]
# Epoch 16/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.6011 - mean_absolute_error: 0.4293 - acc: 0.6580 - loss_no_weight_decay: 0.6011 - val_loss: 0.7376 - val_mean_absolute_error: 0.4758 - val_acc: 0.5192 - val_loss_no_weight_decay: 0.7376
#
# Epoch 00016: val_acc did not improve from 0.75000
# Confusion matrix:
#  [[23  3]
#  [16 10]]
# Epoch 17/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.6533 - mean_absolute_error: 0.4476 - acc: 0.6146 - loss_no_weight_decay: 0.6533 - val_loss: 0.6050 - val_mean_absolute_error: 0.4428 - val_acc: 0.7500 - val_loss_no_weight_decay: 0.6050
#
# Epoch 00017: val_acc did not improve from 0.75000
# Confusion matrix:
#  [[23  9]
#  [ 9 23]]
# Epoch 18/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.5982 - mean_absolute_error: 0.4293 - acc: 0.6987 - loss_no_weight_decay: 0.5982 - val_loss: 0.5902 - val_mean_absolute_error: 0.4171 - val_acc: 0.6923 - val_loss_no_weight_decay: 0.5902
#
# Epoch 00018: val_acc did not improve from 0.75000
# Confusion matrix:
#  [[26  5]
#  [10 11]]
# Epoch 19/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.6105 - mean_absolute_error: 0.4245 - acc: 0.6470 - loss_no_weight_decay: 0.6105 - val_loss: 0.5036 - val_mean_absolute_error: 0.3726 - val_acc: 0.7812 - val_loss_no_weight_decay: 0.5036
#
# Epoch 00019: val_acc improved from 0.75000 to 0.78125, saving model to base_2020-05-07-21-44-40-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[15 15]
#  [ 6 28]]
# Epoch 20/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.5521 - mean_absolute_error: 0.4021 - acc: 0.7062 - loss_no_weight_decay: 0.5521 - val_loss: 0.6020 - val_mean_absolute_error: 0.4224 - val_acc: 0.7115 - val_loss_no_weight_decay: 0.6020
#
# Epoch 00020: val_acc did not improve from 0.78125
# Confusion matrix:
#  [[18  6]
#  [ 9 19]]
# Epoch 21/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.5755 - mean_absolute_error: 0.3984 - acc: 0.6999 - loss_no_weight_decay: 0.5755 - val_loss: 0.5075 - val_mean_absolute_error: 0.3776 - val_acc: 0.7812 - val_loss_no_weight_decay: 0.5075
#
# Epoch 00021: val_acc did not improve from 0.78125
# Confusion matrix:
#  [[24  7]
#  [ 6 27]]
# Epoch 22/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.5565 - mean_absolute_error: 0.3961 - acc: 0.7290 - loss_no_weight_decay: 0.5565 - val_loss: 0.5337 - val_mean_absolute_error: 0.3796 - val_acc: 0.7308 - val_loss_no_weight_decay: 0.5337
#
# Epoch 00022: val_acc did not improve from 0.78125
# Confusion matrix:
#  [[18  7]
#  [ 5 22]]
# Epoch 23/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.5011 - mean_absolute_error: 0.3574 - acc: 0.7587 - loss_no_weight_decay: 0.5011 - val_loss: 0.4920 - val_mean_absolute_error: 0.3651 - val_acc: 0.7500 - val_loss_no_weight_decay: 0.4920
#
# Epoch 00023: val_acc did not improve from 0.78125
# Confusion matrix:
#  [[25  6]
#  [10 23]]
# Epoch 24/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.4832 - mean_absolute_error: 0.3312 - acc: 0.7773 - loss_no_weight_decay: 0.4832 - val_loss: 0.4712 - val_mean_absolute_error: 0.3132 - val_acc: 0.7308 - val_loss_no_weight_decay: 0.4712
#
# Epoch 00024: val_acc did not improve from 0.78125
# Confusion matrix:
#  [[13 13]
#  [ 0 26]]
# Epoch 25/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.4155 - mean_absolute_error: 0.3044 - acc: 0.8194 - loss_no_weight_decay: 0.4155 - val_loss: 0.3883 - val_mean_absolute_error: 0.2958 - val_acc: 0.8125 - val_loss_no_weight_decay: 0.3883
#
# Epoch 00025: val_acc improved from 0.78125 to 0.81250, saving model to base_2020-05-07-21-44-40-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[27  7]
#  [ 3 27]]
# Epoch 26/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.3907 - mean_absolute_error: 0.2795 - acc: 0.8366 - loss_no_weight_decay: 0.3907 - val_loss: 0.3734 - val_mean_absolute_error: 0.2368 - val_acc: 0.8462 - val_loss_no_weight_decay: 0.3734
#
# Epoch 00026: val_acc improved from 0.81250 to 0.84615, saving model to base_2020-05-07-21-44-40-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[18 13]
#  [ 0 21]]
# Epoch 27/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.3291 - mean_absolute_error: 0.2275 - acc: 0.8667 - loss_no_weight_decay: 0.3291 - val_loss: 0.3906 - val_mean_absolute_error: 0.2210 - val_acc: 0.8125 - val_loss_no_weight_decay: 0.3906
#
# Epoch 00027: val_acc did not improve from 0.84615
# Confusion matrix:
#  [[15 20]
#  [ 1 28]]
# Epoch 28/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.3253 - mean_absolute_error: 0.2172 - acc: 0.8524 - loss_no_weight_decay: 0.3253 - val_loss: 0.3130 - val_mean_absolute_error: 0.2239 - val_acc: 0.8654 - val_loss_no_weight_decay: 0.3130
#
# Epoch 00028: val_acc improved from 0.84615 to 0.86538, saving model to base_2020-05-07-21-44-40-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[25  0]
#  [ 8 19]]
# Epoch 29/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.2706 - mean_absolute_error: 0.1830 - acc: 0.8828 - loss_no_weight_decay: 0.2706 - val_loss: 0.4296 - val_mean_absolute_error: 0.2264 - val_acc: 0.7812 - val_loss_no_weight_decay: 0.4296
#
# Epoch 00029: val_acc did not improve from 0.86538
# Confusion matrix:
#  [[24  9]
#  [ 0 31]]
# Epoch 30/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.3088 - mean_absolute_error: 0.1812 - acc: 0.8795 - loss_no_weight_decay: 0.3088 - val_loss: 0.2108 - val_mean_absolute_error: 0.1522 - val_acc: 0.9423 - val_loss_no_weight_decay: 0.2108
#
# Epoch 00030: val_acc improved from 0.86538 to 0.94231, saving model to base_2020-05-07-21-44-40-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[22  3]
#  [ 1 26]]
# Epoch 31/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.2323 - mean_absolute_error: 0.1628 - acc: 0.9023 - loss_no_weight_decay: 0.2323 - val_loss: 0.2928 - val_mean_absolute_error: 0.2119 - val_acc: 0.9062 - val_loss_no_weight_decay: 0.2928
#
# Epoch 00031: val_acc did not improve from 0.94231
# Confusion matrix:
#  [[37  0]
#  [ 6 21]]
# Epoch 32/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.2454 - mean_absolute_error: 0.1620 - acc: 0.9038 - loss_no_weight_decay: 0.2454 - val_loss: 0.3506 - val_mean_absolute_error: 0.2281 - val_acc: 0.8077 - val_loss_no_weight_decay: 0.3506
#
# Epoch 00032: val_acc did not improve from 0.94231
# Confusion matrix:
#  [[22  2]
#  [ 8 20]]
# Epoch 33/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.2242 - mean_absolute_error: 0.1486 - acc: 0.9023 - loss_no_weight_decay: 0.2242 - val_loss: 0.2395 - val_mean_absolute_error: 0.1592 - val_acc: 0.8906 - val_loss_no_weight_decay: 0.2395
#
# Epoch 00033: val_acc did not improve from 0.94231
# Confusion matrix:
#  [[31  4]
#  [ 1 28]]
# Epoch 34/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.1800 - mean_absolute_error: 0.1182 - acc: 0.9316 - loss_no_weight_decay: 0.1800 - val_loss: 0.1826 - val_mean_absolute_error: 0.0960 - val_acc: 0.9615 - val_loss_no_weight_decay: 0.1826
#
# Epoch 00034: val_acc improved from 0.94231 to 0.96154, saving model to base_2020-05-07-21-44-40-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[24  2]
#  [ 0 26]]
# Epoch 35/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.1760 - mean_absolute_error: 0.1133 - acc: 0.9236 - loss_no_weight_decay: 0.1760 - val_loss: 0.1746 - val_mean_absolute_error: 0.1062 - val_acc: 0.9375 - val_loss_no_weight_decay: 0.1746
#
# Epoch 00035: val_acc did not improve from 0.96154
# Confusion matrix:
#  [[30  0]
#  [ 3 31]]
# 176/176 [==============================] - 5s 27ms/step
# 176/176 [==============================] - 5s 27ms/step
# Test loss: 0.21929663085624765
# Test accuracy: 0.13999381914188483
# Confusion Matrix
# [[82  6]
#  [10 78]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91        88
#            1       0.93      0.89      0.91        88
#
#     accuracy                           0.91       176
#    macro avg       0.91      0.91      0.91       176
# weighted avg       0.91      0.91      0.91       176

# %%
import numpy as np 
import matplotlib.pyplot as plt
import os
import wandb
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_mean_absolute_error', 'val_acc', 'val_loss_no_weight_decay', 'loss', 'mean_absolute_error', 'acc', 'loss_no_weight_decay', 'lr'])

# %%
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
from Kappa_Skl import kappa
def kappa2(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    if len(y_true.shape) > 1 and y_true.shape[1] > 1:
        y_true = y_true.dot(range(y_true.shape[1]))
    if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
        y_pred = y_pred.dot(range(y_pred.shape[1]))
    try:
        return kappa(y_true, y_pred, weights='quadratic')
    except IndexError:
        return np.nan
    
print('Quadratic_wieghted_kappa')
print(kappa2(y_true, y_pred))
# Out:
# Quadratic_wieghted_kappa
# 0.8181818181818181

# %%
# summarize history for mean_absolute _error
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model mean_absolute_error')
plt.ylabel('mean_absolute_error')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model maey.png')
