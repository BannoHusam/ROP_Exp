# %%
import keras
from keras.models import Sequential, Input, Model
from keras.losses import mean_squared_error
from keras.layers import  *
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, InputLayer
from keras.regularizers import L1L2, l2, l1
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from custom_pooling import RMSPooling2D
from keras.optimizers import SGD, Adam
from keras.layers import LeakyReLU
#from data import BALANCE_WEIGHTS
from keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
#import os
from datetime import datetime as dt
from custom_loss import WeightedCategoricalCrossEntropy
from VCM import VCM
import keras.backend as K
from Fractional_MAXPOOL import FractionalPooling2D
from QWK import QWK
import tensorflow as tf
from Fractional_MAXPOOL import FractionalPooling2D

import numpy as np 
import matplotlib.pyplot as plt
import os
import wandb
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
def get_experiment_id():
    time_str = dt.now().strftime('%Y-%m-%d-%H-%M-%S')
    experiment_id = 'base_{}'.format(time_str)
    return experiment_id
p_ratio=[1.0, 1.44, 1.73, 1.0]

model = Sequential()


model.add(Conv2D(16, (5, 5), activation='tanh', input_shape=(300, 300, 3)))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(16, (3, 3), activation='tanh'))
model.add(Conv2D(16, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

#model.add(LeakyReLU(alpha=0.01))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))


model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))


model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))


#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))



#model.add(MaxPooling2D(pool_size=1))




model.add(MaxPooling2D(pool_size=2))

model.add(Flatten())


#chnaged from 10 to 5 because an error 
model.add(Dense(2, activation='softmax'))

sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.count_params()
#adam = Adam(lr=0.0005, decay=1e-6)
#rmsprop
#Mloss = WeightedCategoricalCrossEntropy({0: 0.4125861396437394, 1: 1.4918664786083686, 2: 0.690426457789382, 3: 3.9541433021806855, 4: 4.885604311008468})
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['acc','mae'])
model.summary()
loss_no_weight_decay = model.total_loss - sum(model.losses)
model.metrics_tensors.append(loss_no_weight_decay)
model.metrics_names.append('loss_no_weight_decay')
#############################################################################################
#############################################################################################
#############################################################################################
#############################################################################################
#Preparing Data Augmentation Configuration 
train_datagen = ImageDataGenerator(
        rescale=1./255,
#        featurewise_center=True,
 #       samplewise_center=True,
        shear_range=0,
        zoom_range=0.0,#[1 / 1.15, 1.15],
        horizontal_flip=False,#True,
        rotation_range=0)#90,
#        validation_split=0.2)
"""
For the test set only rescale should be made 
"""
test_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/grahprepross/bin_bal/train",
    target_size=(300, 300),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="training")
#    save_to_dir="D:/Separating Images into subfolders/train_augmented")


#print(train_generator.class_indices)

valid_generator = valid_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/grahprepross/bin_bal/vald",
    target_size=(300, 300),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="validation")
#    save_to_dir="D:/Separating Images into subfolders/val_augmented"


test_generator = test_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/grahprepross/bin_bal/test",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=1,
    class_mode="categorical",
    shuffle=False,
    seed=42)
#    save_to_dir="D:/Separating Images into subfolders/test_augmented")


# Fitting/Training the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
experiment_id = get_experiment_id()
callbacks = [
    EarlyStopping(monitor='val_acc', patience=10, min_delta=0.001, verbose=1),
    ModelCheckpoint(experiment_id + "-val_acc_checkpoint.hdf5", monitor='val_acc', verbose=1, save_best_only=True, mode='max'),
    ReduceLROnPlateau(monitor='val_acc', factor=0.5, patience=7, verbose=1, mode='auto', min_delta=0.001, cooldown=0, min_lr=1e-7),
    VCM(valid_generator,STEP_SIZE_VALID)
    
]

class_weight_list = class_weight.compute_class_weight('balanced', np.unique(train_generator.classes), train_generator.classes)
class_weights = dict(zip(np.unique(train_generator.classes), class_weight_list))

history=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    #class_weight=class_weights,
                    callbacks=callbacks,
                    epochs=35  
)


# Evaluating the model 
#predicting output
#reseting the test generator before calling predict_generator, in order not to get weird output
test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 296, 296, 16)      1216
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 292, 292, 16)      6416
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 290, 290, 16)      2320
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 288, 288, 16)      2320
# _________________________________________________________________
# fractional_pooling2d_1 (Frac (None, 160, 160, 16)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 156, 156, 16)      6416
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 152, 152, 16)      6416
# _________________________________________________________________
# fractional_pooling2d_2 (Frac (None, 84, 84, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 80, 80, 16)        6416
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 76, 76, 16)        6416
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 74, 74, 32)        4640
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 72, 72, 32)        9248
# _________________________________________________________________
# fractional_pooling2d_3 (Frac (None, 40, 40, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 38, 38, 32)        9248
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 36, 36, 32)        9248
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 34, 34, 64)        18496
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 32, 32, 64)        36928
# _________________________________________________________________
# fractional_pooling2d_4 (Frac (None, 17, 17, 64)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 15, 15, 64)        36928
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 13, 13, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 4610
# =================================================================
# Total params: 204,210
# Trainable params: 204,210
# Non-trainable params: 0
# _________________________________________________________________
# Found 462 images belonging to 2 classes.
# Found 154 images belonging to 2 classes.
# Found 66 images belonging to 2 classes.
# Epoch 1/35
# 7/7 [==============================] - 21s 3s/step - loss: 0.6997 - acc: 0.4159 - mean_absolute_error: 0.5029 - loss_no_weight_decay: 0.6997 - val_loss: 0.6956 - val_acc: 0.5156 - val_mean_absolute_error: 0.5007 - val_loss_no_weight_decay: 0.6956
#
# Epoch 00001: val_acc improved from -inf to 0.51562, saving model to base_2020-05-12-20-22-32-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[62  0]
#  [66  0]]
# Epoch 2/35
# 7/7 [==============================] - 15s 2s/step - loss: 0.6980 - acc: 0.4454 - mean_absolute_error: 0.5022 - loss_no_weight_decay: 0.6980 - val_loss: 0.6973 - val_acc: 0.5000 - val_mean_absolute_error: 0.5014 - val_loss_no_weight_decay: 0.6973
#
# Epoch 00002: val_acc did not improve from 0.51562
# Confusion matrix:
#  [[39  0]
#  [51  0]]
# Epoch 3/35
# 7/7 [==============================] - 14s 2s/step - loss: 0.6988 - acc: 0.4683 - mean_absolute_error: 0.5024 - loss_no_weight_decay: 0.6988 - val_loss: 0.6976 - val_acc: 0.4778 - val_mean_absolute_error: 0.5016 - val_loss_no_weight_decay: 0.6976
#
# Epoch 00003: val_acc did not improve from 0.51562
# Confusion matrix:
#  [[36  0]
#  [54  0]]
# Epoch 4/35
# 7/7 [==============================] - 16s 2s/step - loss: 0.6952 - acc: 0.4799 - mean_absolute_error: 0.5007 - loss_no_weight_decay: 0.6952 - val_loss: 0.6944 - val_acc: 0.5000 - val_mean_absolute_error: 0.5004 - val_loss_no_weight_decay: 0.6944
#
# Epoch 00004: val_acc did not improve from 0.51562
# Confusion matrix:
#  [[ 0 67]
#  [ 0 61]]
# Epoch 5/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.6959 - acc: 0.4839 - mean_absolute_error: 0.5007 - loss_no_weight_decay: 0.6959 - val_loss: 0.6951 - val_acc: 0.4556 - val_mean_absolute_error: 0.5007 - val_loss_no_weight_decay: 0.6951
#
# Epoch 00005: val_acc did not improve from 0.51562
# Confusion matrix:
#  [[48  0]
#  [42  0]]
# Epoch 6/35
# 7/7 [==============================] - 16s 2s/step - loss: 0.6950 - acc: 0.4643 - mean_absolute_error: 0.5007 - loss_no_weight_decay: 0.6950 - val_loss: 0.6954 - val_acc: 0.4778 - val_mean_absolute_error: 0.5011 - val_loss_no_weight_decay: 0.6954
#
# Epoch 00006: val_acc did not improve from 0.51562
# Confusion matrix:
#  [[ 1 44]
#  [ 0 45]]
# Epoch 7/35
# 7/7 [==============================] - 14s 2s/step - loss: 0.6956 - acc: 0.4958 - mean_absolute_error: 0.5004 - loss_no_weight_decay: 0.6956 - val_loss: 0.6923 - val_acc: 0.4844 - val_mean_absolute_error: 0.4996 - val_loss_no_weight_decay: 0.6923
#
# Epoch 00007: val_acc did not improve from 0.51562
# Confusion matrix:
#  [[47 15]
#  [51 15]]
# Epoch 8/35
# 7/7 [==============================] - 14s 2s/step - loss: 0.6930 - acc: 0.4932 - mean_absolute_error: 0.4997 - loss_no_weight_decay: 0.6930 - val_loss: 0.6927 - val_acc: 0.4333 - val_mean_absolute_error: 0.4997 - val_loss_no_weight_decay: 0.6927
#
# Epoch 00008: val_acc did not improve from 0.51562
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Confusion matrix:
#  [[36  8]
#  [42  4]]
# Epoch 9/35
# 7/7 [==============================] - 16s 2s/step - loss: 0.6907 - acc: 0.5737 - mean_absolute_error: 0.4987 - loss_no_weight_decay: 0.6907 - val_loss: 0.6900 - val_acc: 0.5111 - val_mean_absolute_error: 0.4983 - val_loss_no_weight_decay: 0.6900
#
# Epoch 00009: val_acc did not improve from 0.51562
# Confusion matrix:
#  [[ 1 38]
#  [ 1 50]]
# Epoch 10/35
# 7/7 [==============================] - 13s 2s/step - loss: 0.6894 - acc: 0.5278 - mean_absolute_error: 0.4979 - loss_no_weight_decay: 0.6894 - val_loss: 0.6942 - val_acc: 0.4766 - val_mean_absolute_error: 0.5000 - val_loss_no_weight_decay: 0.6942
#
# Epoch 00010: val_acc did not improve from 0.51562
# Confusion matrix:
#  [[ 0 64]
#  [ 0 64]]
# Epoch 11/35
# 7/7 [==============================] - 16s 2s/step - loss: 0.6903 - acc: 0.5089 - mean_absolute_error: 0.4980 - loss_no_weight_decay: 0.6903 - val_loss: 0.6820 - val_acc: 0.5667 - val_mean_absolute_error: 0.4938 - val_loss_no_weight_decay: 0.6820
#
# Epoch 00011: val_acc improved from 0.51562 to 0.56667, saving model to base_2020-05-12-20-22-32-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[ 0 46]
#  [ 0 44]]
# Epoch 12/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.6900 - acc: 0.5510 - mean_absolute_error: 0.4982 - loss_no_weight_decay: 0.6900 - val_loss: 0.6911 - val_acc: 0.5333 - val_mean_absolute_error: 0.4988 - val_loss_no_weight_decay: 0.6911
#
# Epoch 00012: val_acc did not improve from 0.56667
# Confusion matrix:
#  [[16 24]
#  [ 2 48]]
# Epoch 13/35
# 7/7 [==============================] - 14s 2s/step - loss: 0.6903 - acc: 0.5358 - mean_absolute_error: 0.4985 - loss_no_weight_decay: 0.6903 - val_loss: 0.6884 - val_acc: 0.5781 - val_mean_absolute_error: 0.4975 - val_loss_no_weight_decay: 0.6884
#
# Epoch 00013: val_acc improved from 0.56667 to 0.57812, saving model to base_2020-05-12-20-22-32-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[56  6]
#  [54 12]]
# Epoch 14/35
# 7/7 [==============================] - 16s 2s/step - loss: 0.6873 - acc: 0.6161 - mean_absolute_error: 0.4970 - loss_no_weight_decay: 0.6873 - val_loss: 0.6870 - val_acc: 0.6111 - val_mean_absolute_error: 0.4968 - val_loss_no_weight_decay: 0.6870
#
# Epoch 00014: val_acc improved from 0.57812 to 0.61111, saving model to base_2020-05-12-20-22-32-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[14 30]
#  [ 4 42]]
# Epoch 15/35
# 7/7 [==============================] - 14s 2s/step - loss: 0.6877 - acc: 0.5933 - mean_absolute_error: 0.4971 - loss_no_weight_decay: 0.6877 - val_loss: 0.6864 - val_acc: 0.6333 - val_mean_absolute_error: 0.4965 - val_loss_no_weight_decay: 0.6864
#
# Epoch 00015: val_acc improved from 0.61111 to 0.63333, saving model to base_2020-05-12-20-22-32-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[11 39]
#  [ 2 38]]
# Epoch 16/35
# 7/7 [==============================] - 14s 2s/step - loss: 0.6857 - acc: 0.5860 - mean_absolute_error: 0.4961 - loss_no_weight_decay: 0.6857 - val_loss: 0.6854 - val_acc: 0.6406 - val_mean_absolute_error: 0.4960 - val_loss_no_weight_decay: 0.6854
#
# Epoch 00016: val_acc improved from 0.63333 to 0.64062, saving model to base_2020-05-12-20-22-32-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[48 10]
#  [38 32]]
# Epoch 17/35
# 7/7 [==============================] - 14s 2s/step - loss: 0.6838 - acc: 0.6280 - mean_absolute_error: 0.4938 - loss_no_weight_decay: 0.6838 - val_loss: 0.6937 - val_acc: 0.5111 - val_mean_absolute_error: 0.4942 - val_loss_no_weight_decay: 0.6937
#
# Epoch 00017: val_acc did not improve from 0.64062
# Confusion matrix:
#  [[45  0]
#  [45  0]]
# Epoch 18/35
# 7/7 [==============================] - 14s 2s/step - loss: 0.6959 - acc: 0.4841 - mean_absolute_error: 0.4986 - loss_no_weight_decay: 0.6959 - val_loss: 0.6832 - val_acc: 0.6444 - val_mean_absolute_error: 0.4948 - val_loss_no_weight_decay: 0.6832
#
# Epoch 00018: val_acc improved from 0.64062 to 0.64444, saving model to base_2020-05-12-20-22-32-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[38 10]
#  [24 18]]
# Epoch 19/35
# 7/7 [==============================] - 14s 2s/step - loss: 0.6828 - acc: 0.6659 - mean_absolute_error: 0.4946 - loss_no_weight_decay: 0.6828 - val_loss: 0.6852 - val_acc: 0.5000 - val_mean_absolute_error: 0.4954 - val_loss_no_weight_decay: 0.6852
#
# Epoch 00019: val_acc did not improve from 0.64444
# Confusion matrix:
#  [[66  0]
#  [58  4]]
# Epoch 20/35
# 7/7 [==============================] - 14s 2s/step - loss: 0.6832 - acc: 0.5937 - mean_absolute_error: 0.4947 - loss_no_weight_decay: 0.6832 - val_loss: 0.6831 - val_acc: 0.5889 - val_mean_absolute_error: 0.4947 - val_loss_no_weight_decay: 0.6831
#
# Epoch 00020: val_acc did not improve from 0.64444
# Confusion matrix:
#  [[24 16]
#  [ 3 47]]
# Epoch 21/35
# 7/7 [==============================] - 16s 2s/step - loss: 0.6800 - acc: 0.6429 - mean_absolute_error: 0.4931 - loss_no_weight_decay: 0.6800 - val_loss: 0.6760 - val_acc: 0.7556 - val_mean_absolute_error: 0.4911 - val_loss_no_weight_decay: 0.6760
#
# Epoch 00021: val_acc improved from 0.64444 to 0.75556, saving model to base_2020-05-12-20-22-32-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[32  8]
#  [16 34]]
# Epoch 22/35
# 7/7 [==============================] - 13s 2s/step - loss: 0.6751 - acc: 0.6713 - mean_absolute_error: 0.4904 - loss_no_weight_decay: 0.6751 - val_loss: 0.6777 - val_acc: 0.6406 - val_mean_absolute_error: 0.4917 - val_loss_no_weight_decay: 0.6777
#
# Epoch 00022: val_acc did not improve from 0.75556
# Confusion matrix:
#  [[38 28]
#  [13 49]]
# Epoch 23/35
# 7/7 [==============================] - 16s 2s/step - loss: 0.6745 - acc: 0.6451 - mean_absolute_error: 0.4898 - loss_no_weight_decay: 0.6745 - val_loss: 0.6634 - val_acc: 0.7333 - val_mean_absolute_error: 0.4842 - val_loss_no_weight_decay: 0.6634
#
# Epoch 00023: val_acc did not improve from 0.75556
# Confusion matrix:
#  [[24 20]
#  [ 9 37]]
# Epoch 24/35
# 7/7 [==============================] - 14s 2s/step - loss: 0.6652 - acc: 0.7051 - mean_absolute_error: 0.4848 - loss_no_weight_decay: 0.6652 - val_loss: 0.6649 - val_acc: 0.6000 - val_mean_absolute_error: 0.4835 - val_loss_no_weight_decay: 0.6649
#
# Epoch 00024: val_acc did not improve from 0.75556
# Confusion matrix:
#  [[42  5]
#  [28 15]]
# Epoch 25/35
# 7/7 [==============================] - 14s 2s/step - loss: 0.6644 - acc: 0.6435 - mean_absolute_error: 0.4830 - loss_no_weight_decay: 0.6644 - val_loss: 0.6506 - val_acc: 0.7109 - val_mean_absolute_error: 0.4765 - val_loss_no_weight_decay: 0.6506
#
# Epoch 00025: val_acc did not improve from 0.75556
# Confusion matrix:
#  [[45 19]
#  [21 43]]
# Epoch 26/35
# 7/7 [==============================] - 16s 2s/step - loss: 0.6537 - acc: 0.6674 - mean_absolute_error: 0.4770 - loss_no_weight_decay: 0.6537 - val_loss: 0.6552 - val_acc: 0.6000 - val_mean_absolute_error: 0.4754 - val_loss_no_weight_decay: 0.6552
#
# Epoch 00026: val_acc did not improve from 0.75556
# Confusion matrix:
#  [[38  6]
#  [29 17]]
# Epoch 27/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.6496 - acc: 0.6064 - mean_absolute_error: 0.4659 - loss_no_weight_decay: 0.6496 - val_loss: 0.6233 - val_acc: 0.6556 - val_mean_absolute_error: 0.4566 - val_loss_no_weight_decay: 0.6233
#
# Epoch 00027: val_acc did not improve from 0.75556
# Confusion matrix:
#  [[18 28]
#  [ 5 39]]
# Epoch 28/35
# 7/7 [==============================] - 16s 2s/step - loss: 0.6400 - acc: 0.6540 - mean_absolute_error: 0.4628 - loss_no_weight_decay: 0.6400 - val_loss: 0.6353 - val_acc: 0.6641 - val_mean_absolute_error: 0.4617 - val_loss_no_weight_decay: 0.6353
#
# Epoch 00028: val_acc did not improve from 0.75556
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Confusion matrix:
#  [[35 31]
#  [ 6 56]]
# Epoch 29/35
# 7/7 [==============================] - 14s 2s/step - loss: 0.6429 - acc: 0.6135 - mean_absolute_error: 0.4570 - loss_no_weight_decay: 0.6429 - val_loss: 0.6004 - val_acc: 0.7222 - val_mean_absolute_error: 0.4412 - val_loss_no_weight_decay: 0.6004
#
# Epoch 00029: val_acc did not improve from 0.75556
# Confusion matrix:
#  [[37 14]
#  [20 19]]
# Epoch 30/35
# 7/7 [==============================] - 14s 2s/step - loss: 0.6106 - acc: 0.6730 - mean_absolute_error: 0.4438 - loss_no_weight_decay: 0.6106 - val_loss: 0.6122 - val_acc: 0.6778 - val_mean_absolute_error: 0.4452 - val_loss_no_weight_decay: 0.6122
#
# Epoch 00030: val_acc did not improve from 0.75556
# Confusion matrix:
#  [[27 15]
#  [ 9 39]]
# Epoch 31/35
# 7/7 [==============================] - 14s 2s/step - loss: 0.6007 - acc: 0.7072 - mean_absolute_error: 0.4376 - loss_no_weight_decay: 0.6007 - val_loss: 0.6014 - val_acc: 0.6953 - val_mean_absolute_error: 0.4366 - val_loss_no_weight_decay: 0.6014
#
# Epoch 00031: val_acc did not improve from 0.75556
# Confusion matrix:
#  [[50 16]
#  [22 40]]
# Epoch 32/35
# 7/7 [==============================] - 14s 2s/step - loss: 0.5904 - acc: 0.7183 - mean_absolute_error: 0.4282 - loss_no_weight_decay: 0.5904 - val_loss: 0.5513 - val_acc: 0.7444 - val_mean_absolute_error: 0.4052 - val_loss_no_weight_decay: 0.5513
#
# Epoch 00032: val_acc did not improve from 0.75556
# Confusion matrix:
#  [[35 15]
#  [12 28]]
# Epoch 33/35
# 7/7 [==============================] - 14s 2s/step - loss: 0.5996 - acc: 0.6789 - mean_absolute_error: 0.4250 - loss_no_weight_decay: 0.5996 - val_loss: 0.6638 - val_acc: 0.6444 - val_mean_absolute_error: 0.4364 - val_loss_no_weight_decay: 0.6638
#
# Epoch 00033: val_acc did not improve from 0.75556
# Confusion matrix:
#  [[14 29]
#  [ 1 46]]
# Epoch 34/35
# 7/7 [==============================] - 14s 2s/step - loss: 0.5965 - acc: 0.6890 - mean_absolute_error: 0.4093 - loss_no_weight_decay: 0.5965 - val_loss: 0.5585 - val_acc: 0.7500 - val_mean_absolute_error: 0.4021 - val_loss_no_weight_decay: 0.5585
#
# Epoch 00034: val_acc did not improve from 0.75556
# Confusion matrix:
#  [[48 17]
#  [12 51]]
# Epoch 35/35
# 7/7 [==============================] - 14s 2s/step - loss: 0.6078 - acc: 0.6754 - mean_absolute_error: 0.4044 - loss_no_weight_decay: 0.6078 - val_loss: 0.5450 - val_acc: 0.7222 - val_mean_absolute_error: 0.3987 - val_loss_no_weight_decay: 0.5450
#
# Epoch 00035: val_acc did not improve from 0.75556
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Confusion matrix:
#  [[35 10]
#  [10 35]]
# Epoch 00035: early stopping
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-573933b68dd5> in <module>
#     171 #test_imgs, test_labels = next(test_generator)
#     172
# --> 173 y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))
#     174
#     175 score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
#
# /usr/local/lib/python3.6/dist-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in predict_generator(self, generator, steps, callbacks, max_queue_size, workers, use_multiprocessing, verbose)
#    1770             workers=workers,
#    1771             use_multiprocessing=use_multiprocessing,
# -> 1772             verbose=verbose)
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_generator.py in predict_generator(model, generator, steps, callbacks, max_queue_size, workers, use_multiprocessing, verbose)
#     514             callbacks._call_batch_hook('predict', 'begin', steps_done, batch_logs)
#     515
# --> 516             outs = model.predict_on_batch(x)
#     517             outs = to_list(outs)
#     518
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in predict_on_batch(self, x)
#    1498             Numpy array(s) of predictions.
#    1499         """
# -> 1500         x, _, _ = self._standardize_user_data(x)
#    1501         if self._uses_dynamic_learning_phase():
#    1502             ins = x + [0.]
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
#     755             feed_input_shapes,
#     756             check_batch_axis=False,  # Don't enforce the batch size.
# --> 757             exception_prefix='input')
#     758
#     759         if y is not None:
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_utils.py in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     139                             ': expected ' + names[i] + ' to have shape ' +
#     140                             str(shape) + ' but got array with shape ' +
# --> 141                             str(data_shape))
#     142     return data
#     143
#
# ValueError: Error when checking input: expected conv2d_1_input to have shape (300, 300, 3) but got array with shape (270, 270, 3)

# %%
test_generator = test_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/grahprepross/bin_bal/test",
    target_size=(300, 300),
    color_mode="rgb",
    batch_size=1,
    class_mode="categorical",
    shuffle=False,
    seed=42)
#    save_to_dir="D:/Separating Images into subfolders/test_augmented")

test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# Found 66 images belonging to 2 classes.
# 66/66 [==============================] - 1s 11ms/step
# 66/66 [==============================] - 1s 10ms/step
# Test loss: 0.6328511373563246
# Test accuracy: 0.6515151515151515
# Confusion Matrix
# [[22 11]
#  [12 21]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.65      0.67      0.66        33
#            1       0.66      0.64      0.65        33
#
#     accuracy                           0.65        66
#    macro avg       0.65      0.65      0.65        66
# weighted avg       0.65      0.65      0.65        66

# %%
from Kappa_Skl import kappa
def kappa2(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    if len(y_true.shape) > 1 and y_true.shape[1] > 1:
        y_true = y_true.dot(range(y_true.shape[1]))
    if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
        y_pred = y_pred.dot(range(y_pred.shape[1]))
    try:
        return kappa(y_true, y_pred, weights='quadratic')
    except IndexError:
        return np.nan
    
print('Quadratic_wieghted_kappa')
print(kappa2(y_true, y_pred))
# Out:
# Quadratic_wieghted_kappa
# 0.303030303030303

# %%
# summarize history for mean_absolute _error
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model mean_absolute_error')
plt.ylabel('mean_absolute_error')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model maey.png')

# %%
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
