# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, InputLayer
from keras.regularizers import L1L2, l2, l1
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from custom_pooling import RMSPooling2D
from keras.optimizers import SGD, Adam
from keras.layers import LeakyReLU
#from data import BALANCE_WEIGHTS
from keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
#import os
from datetime import datetime as dt
from custom_loss import WeightedCategoricalCrossEntropy
from VCM import VCM
from QWK import QWK
import keras.backend as K
from Fractional_MAXPOOL import FractionalPooling2D
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
def get_experiment_id():
    time_str = dt.now().strftime('%Y-%m-%d-%H-%M-%S')
    experiment_id = 'base_{}'.format(time_str)
    return experiment_id
p_ratio=[1.0, 1.44, 1.73, 1.0]

model = Sequential()


model.add(Conv2D(16, (5, 5), activation='tanh', input_shape=(300, 300, 3)))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))
model.add(FractionalPooling2D(pool_ratio=(1, 1.6, 1.6, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(16, (3, 3), activation='tanh'))
model.add(Conv2D(16, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

#model.add(LeakyReLU(alpha=0.01))


model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))


model.add(FractionalPooling2D(pool_ratio=(1, 1.6, 1.6, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))          
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
model.add(FractionalPooling2D(pool_ratio=(1, 1.6, 1.6, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(FractionalPooling2D(pool_ratio=(1, 1.6, 1.6, 1),pseudo_random = True,overlap=True))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))


model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

#model.add(MaxPooling2D(pool_size=1))




model.add(FractionalPooling2D(pool_ratio=(1, 1.7, 1.7, 1),pseudo_random = True,overlap=True))

model.add(Flatten())


#chnaged from 10 to 5 because an error 
model.add(Dense(3, activation='softmax'))

sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.count_params()
#adam = Adam(lr=0.0005, decay=1e-6)
#rmsprop
#Mloss = WeightedCategoricalCrossEntropy({0: 0.4125861396437394, 1: 1.4918664786083686, 2: 0.690426457789382, 3: 3.9541433021806855, 4: 4.885604311008468})
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['acc','binary_accuracy','mae'])
model.summary()
loss_no_weight_decay = model.total_loss - sum(model.losses)
model.metrics_tensors.append(loss_no_weight_decay)
model.metrics_names.append('loss_no_weight_decay')
#############################################################################################
#############################################################################################
#############################################################################################
#############################################################################################
#Preparing Data Augmentation Configuration 
train_datagen = ImageDataGenerator(
        rescale=1./255,
#        featurewise_center=True,
 #       samplewise_center=True,
        shear_range=0,
        zoom_range=0.0,#[1 / 1.15, 1.15],
        horizontal_flip=False,#True,
        rotation_range=0)#90,
#        validation_split=0.2)
"""
For the test set only rescale should be made 
"""
test_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/three_class/train",
    target_size=(300, 300),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="training")
#    save_to_dir="D:/Separating Images into subfolders/train_augmented")


#print(train_generator.class_indices)

valid_generator = valid_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/three_class/vald",
    target_size=(300, 300),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="validation")
#    save_to_dir="D:/Separating Images into subfolders/val_augmented"


test_generator = test_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/three_class/test",
    target_size=(300, 300),
    color_mode="rgb",
    batch_size=1,
    class_mode="categorical",
    shuffle=False,
    seed=42)
#    save_to_dir="D:/Separating Images into subfolders/test_augmented")


# Fitting/Training the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
experiment_id = get_experiment_id()
callbacks = [
    QWK(valid_generator, STEP_SIZE_VALID),
    EarlyStopping(monitor='val_acc', patience=50, min_delta=0.001, verbose=1),
    ModelCheckpoint(experiment_id + "-val_kapa_checkpoint.hdf5", monitor='val_kappa', verbose=1, save_best_only=True, mode='max'),
    ReduceLROnPlateau(monitor='val_acc', factor=0.5, patience=7, verbose=1, mode='auto', min_delta=0.001, cooldown=0, min_lr=1e-7),
    VCM(valid_generator,STEP_SIZE_VALID)
    
]

class_weight_list = class_weight.compute_class_weight('balanced', np.unique(train_generator.classes), train_generator.classes)
class_weights = dict(zip(np.unique(train_generator.classes), class_weight_list))

history=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    class_weight=class_weights,
                    callbacks=callbacks,
                    epochs=50  
)


# Evaluating the model 
#predicting output
#reseting the test generator before calling predict_generator, in order not to get weird output
test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1', '2']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 296, 296, 16)      1216
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 292, 292, 16)      6416
# _________________________________________________________________
# fractional_pooling2d_1 (Frac (None, 182, 182, 16)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 180, 180, 16)      2320
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 178, 178, 16)      2320
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 174, 174, 16)      6416
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 170, 170, 16)      6416
# _________________________________________________________________
# fractional_pooling2d_2 (Frac (None, 106, 106, 16)      0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 102, 102, 16)      6416
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 98, 98, 16)        6416
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 96, 96, 32)        4640
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 94, 94, 32)        9248
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 92, 92, 32)        9248
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 90, 90, 32)        9248
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 88, 88, 32)        9248
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 86, 86, 32)        9248
# _________________________________________________________________
# fractional_pooling2d_3 (Frac (None, 53, 53, 32)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 51, 51, 32)        9248
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 49, 49, 32)        9248
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 47, 47, 64)        18496
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 45, 45, 64)        36928
# _________________________________________________________________
# fractional_pooling2d_4 (Frac (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 26, 26, 64)        36928
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 24, 24, 64)        36928
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 22, 22, 64)        36928
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 20, 20, 64)        36928
# _________________________________________________________________
# fractional_pooling2d_5 (Frac (None, 11, 11, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 7744)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 23235
# =================================================================
# Total params: 333,683
# Trainable params: 333,683
# Non-trainable params: 0
# _________________________________________________________________
# Found 588 images belonging to 3 classes.
# Found 116 images belonging to 3 classes.
# Found 176 images belonging to 3 classes.
# Epoch 1/50
# 9/9 [==============================] - 31s 3s/step - loss: 1.0684 - acc: 0.5276 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4350 - loss_no_weight_decay: 1.0684 - val_loss: 1.0948 - val_acc: 0.2969 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4430 - val_loss_no_weight_decay: 1.0948
# — val_kappa: 0.0
#
# Epoch 00001: val_kappa improved from -inf to 0.00000, saving model to base_2020-05-09-16-07-45-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[26  0  0]
#  [ 5  0  0]
#  [21  0  0]]
# Epoch 2/50
# 9/9 [==============================] - 24s 3s/step - loss: 1.1168 - acc: 0.2277 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4482 - loss_no_weight_decay: 1.1168 - val_loss: 1.1110 - val_acc: 0.1731 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4469 - val_loss_no_weight_decay: 1.1110
# — val_kappa: 0.0
#
# Epoch 00002: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[30  0  0]
#  [ 7  0  0]
#  [15  0  0]]
# Epoch 3/50
# 9/9 [==============================] - 23s 3s/step - loss: 1.1104 - acc: 0.3833 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4430 - loss_no_weight_decay: 1.1104 - val_loss: 1.1162 - val_acc: 0.2500 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4469 - val_loss_no_weight_decay: 1.1162
# — val_kappa: 0.0
#
# Epoch 00003: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[22  0  0]
#  [ 6  0  0]
#  [24  0  0]]
# Epoch 4/50
# 9/9 [==============================] - 23s 3s/step - loss: 1.0626 - acc: 0.3164 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4461 - loss_no_weight_decay: 1.0626 - val_loss: 1.0692 - val_acc: 0.5192 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4368 - val_loss_no_weight_decay: 1.0692
# — val_kappa: 0.0
#
# Epoch 00004: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[23  0  0]
#  [ 6  0  0]
#  [23  0  0]]
# Epoch 5/50
# 9/9 [==============================] - 23s 3s/step - loss: 1.0766 - acc: 0.5626 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4356 - loss_no_weight_decay: 1.0766 - val_loss: 1.0386 - val_acc: 0.5000 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4285 - val_loss_no_weight_decay: 1.0386
# — val_kappa: 0.0
#
# Epoch 00005: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[28  0  0]
#  [ 5  0  0]
#  [19  0  0]]
# Epoch 6/50
# 9/9 [==============================] - 23s 3s/step - loss: 1.0946 - acc: 0.4799 - binary_accuracy: 0.6684 - mean_absolute_error: 0.4337 - loss_no_weight_decay: 1.0946 - val_loss: 1.0676 - val_acc: 0.3654 - val_binary_accuracy: 0.6731 - val_mean_absolute_error: 0.4320 - val_loss_no_weight_decay: 1.0676
# — val_kappa: 0.04123711340206171
#
# Epoch 00006: val_kappa improved from 0.00000 to 0.04124, saving model to base_2020-05-09-16-07-45-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[29  0  0]
#  [ 5  0  0]
#  [18  0  0]]
# Epoch 7/50
# 9/9 [==============================] - 25s 3s/step - loss: 1.0138 - acc: 0.4167 - binary_accuracy: 0.7054 - mean_absolute_error: 0.4202 - loss_no_weight_decay: 1.0138 - val_loss: 0.9832 - val_acc: 0.4219 - val_binary_accuracy: 0.7292 - val_mean_absolute_error: 0.4015 - val_loss_no_weight_decay: 0.9832
# — val_kappa: 0.27884615384615385
#
# Epoch 00007: val_kappa improved from 0.04124 to 0.27885, saving model to base_2020-05-09-16-07-45-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[29  0  0]
#  [ 4  0  0]
#  [19  0  0]]
# Epoch 8/50
# 9/9 [==============================] - 20s 2s/step - loss: 1.0416 - acc: 0.4439 - binary_accuracy: 0.6992 - mean_absolute_error: 0.4191 - loss_no_weight_decay: 1.0416 - val_loss: 0.9309 - val_acc: 0.6538 - val_binary_accuracy: 0.7500 - val_mean_absolute_error: 0.3961 - val_loss_no_weight_decay: 0.9309
# — val_kappa: 0.24271844660194186
#
# Epoch 00008: val_kappa did not improve from 0.27885
# Confusion matrix:
#  [[28  0  0]
#  [ 7  0  0]
#  [17  0  0]]
# Epoch 9/50
# 9/9 [==============================] - 25s 3s/step - loss: 0.9800 - acc: 0.6007 - binary_accuracy: 0.7216 - mean_absolute_error: 0.4045 - loss_no_weight_decay: 0.9800 - val_loss: 0.9054 - val_acc: 0.6250 - val_binary_accuracy: 0.7708 - val_mean_absolute_error: 0.3786 - val_loss_no_weight_decay: 0.9054
# — val_kappa: 0.3207547169811321
#
# Epoch 00009: val_kappa improved from 0.27885 to 0.32075, saving model to base_2020-05-09-16-07-45-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[26  0  0]
#  [ 6  0  0]
#  [20  0  0]]
# Epoch 10/50
# 9/9 [==============================] - 23s 3s/step - loss: 0.9726 - acc: 0.5366 - binary_accuracy: 0.7383 - mean_absolute_error: 0.3779 - loss_no_weight_decay: 0.9726 - val_loss: 0.8929 - val_acc: 0.5192 - val_binary_accuracy: 0.7564 - val_mean_absolute_error: 0.3624 - val_loss_no_weight_decay: 0.8929
# — val_kappa: 0.33944954128440363
#
# Epoch 00010: val_kappa improved from 0.32075 to 0.33945, saving model to base_2020-05-09-16-07-45-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[29  0  0]
#  [ 2  2  0]
#  [16  3  0]]
# Epoch 11/50
# 9/9 [==============================] - 23s 3s/step - loss: 0.9592 - acc: 0.4937 - binary_accuracy: 0.7144 - mean_absolute_error: 0.3782 - loss_no_weight_decay: 0.9592 - val_loss: 0.8499 - val_acc: 0.6406 - val_binary_accuracy: 0.7240 - val_mean_absolute_error: 0.3599 - val_loss_no_weight_decay: 0.8499
# — val_kappa: 0.24999999999999978
#
# Epoch 00011: val_kappa did not improve from 0.33945
# Confusion matrix:
#  [[26  0  0]
#  [ 4  0  0]
#  [22  0  0]]
# Epoch 12/50
# 9/9 [==============================] - 23s 3s/step - loss: 0.9086 - acc: 0.5977 - binary_accuracy: 0.7320 - mean_absolute_error: 0.3569 - loss_no_weight_decay: 0.9086 - val_loss: 1.1817 - val_acc: 0.5962 - val_binary_accuracy: 0.7436 - val_mean_absolute_error: 0.3883 - val_loss_no_weight_decay: 1.1817
# — val_kappa: 0.4206008583690988
#
# Epoch 00012: val_kappa improved from 0.33945 to 0.42060, saving model to base_2020-05-09-16-07-45-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[28  0  3]
#  [ 2  0  2]
#  [ 8  1  8]]
# Epoch 13/50
# 9/9 [==============================] - 23s 3s/step - loss: 0.9269 - acc: 0.5752 - binary_accuracy: 0.7426 - mean_absolute_error: 0.3594 - loss_no_weight_decay: 0.9269 - val_loss: 0.9935 - val_acc: 0.3906 - val_binary_accuracy: 0.6823 - val_mean_absolute_error: 0.3917 - val_loss_no_weight_decay: 0.9935
# — val_kappa: 0.23999999999999988
#
# Epoch 00013: val_kappa did not improve from 0.42060
# Confusion matrix:
#  [[25  3  0]
#  [ 2  3  0]
#  [ 8 11  0]]
# Epoch 14/50
# 9/9 [==============================] - 25s 3s/step - loss: 0.8902 - acc: 0.5347 - binary_accuracy: 0.7263 - mean_absolute_error: 0.3498 - loss_no_weight_decay: 0.8902 - val_loss: 0.8158 - val_acc: 0.6538 - val_binary_accuracy: 0.7628 - val_mean_absolute_error: 0.3322 - val_loss_no_weight_decay: 0.8158
# — val_kappa: 0.3207547169811321
#
# Epoch 00014: val_kappa did not improve from 0.42060
# Confusion matrix:
#  [[27  0  0]
#  [ 5  1  0]
#  [18  1  0]]
# Epoch 15/50
# 9/9 [==============================] - 23s 3s/step - loss: 0.8229 - acc: 0.5924 - binary_accuracy: 0.7522 - mean_absolute_error: 0.3323 - loss_no_weight_decay: 0.8229 - val_loss: 0.7345 - val_acc: 0.6719 - val_binary_accuracy: 0.7917 - val_mean_absolute_error: 0.3084 - val_loss_no_weight_decay: 0.7345
# — val_kappa: 0.39473684210526305
#
# Epoch 00015: val_kappa did not improve from 0.42060
# Confusion matrix:
#  [[31  0  0]
#  [ 4  0  1]
#  [16  0  0]]
# Epoch 16/50
# 9/9 [==============================] - 23s 3s/step - loss: 0.7248 - acc: 0.7117 - binary_accuracy: 0.8030 - mean_absolute_error: 0.2876 - loss_no_weight_decay: 0.7248 - val_loss: 0.7304 - val_acc: 0.6731 - val_binary_accuracy: 0.8205 - val_mean_absolute_error: 0.3111 - val_loss_no_weight_decay: 0.7304
# — val_kappa: 0.5493562231759657
#
# Epoch 00016: val_kappa improved from 0.42060 to 0.54936, saving model to base_2020-05-09-16-07-45-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[23  0  1]
#  [ 3  3  3]
#  [ 6  5  8]]
# Epoch 17/50
# 9/9 [==============================] - 24s 3s/step - loss: 0.7375 - acc: 0.6563 - binary_accuracy: 0.7874 - mean_absolute_error: 0.2911 - loss_no_weight_decay: 0.7375 - val_loss: 0.5563 - val_acc: 0.7812 - val_binary_accuracy: 0.8490 - val_mean_absolute_error: 0.2580 - val_loss_no_weight_decay: 0.5563
# — val_kappa: 0.6523605150214593
#
# Epoch 00017: val_kappa improved from 0.54936 to 0.65236, saving model to base_2020-05-09-16-07-45-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[24  0  0]
#  [ 3  1  2]
#  [15  3  4]]
# Epoch 18/50
# 9/9 [==============================] - 22s 2s/step - loss: 0.6735 - acc: 0.7102 - binary_accuracy: 0.7939 - mean_absolute_error: 0.2591 - loss_no_weight_decay: 0.6735 - val_loss: 0.5885 - val_acc: 0.6538 - val_binary_accuracy: 0.7628 - val_mean_absolute_error: 0.2515 - val_loss_no_weight_decay: 0.5885
# — val_kappa: 0.30578512396694224
#
# Epoch 00018: val_kappa did not improve from 0.65236
# Confusion matrix:
#  [[32  0  0]
#  [ 0  3  0]
#  [ 4 13  0]]
# Epoch 19/50
# 9/9 [==============================] - 23s 3s/step - loss: 0.5596 - acc: 0.7723 - binary_accuracy: 0.8429 - mean_absolute_error: 0.2196 - loss_no_weight_decay: 0.5596 - val_loss: 0.6523 - val_acc: 0.6562 - val_binary_accuracy: 0.7552 - val_mean_absolute_error: 0.2748 - val_loss_no_weight_decay: 0.6523
# — val_kappa: 0.5919999999999999
#
# Epoch 00019: val_kappa did not improve from 0.65236
# Confusion matrix:
#  [[24  0  0]
#  [ 3  2  1]
#  [ 6 10  6]]
# Epoch 20/50
# 9/9 [==============================] - 24s 3s/step - loss: 0.5088 - acc: 0.7914 - binary_accuracy: 0.8656 - mean_absolute_error: 0.1955 - loss_no_weight_decay: 0.5088 - val_loss: 0.3083 - val_acc: 0.8846 - val_binary_accuracy: 0.9103 - val_mean_absolute_error: 0.1419 - val_loss_no_weight_decay: 0.3083
# — val_kappa: 0.6294820717131475
#
# Epoch 00020: val_kappa did not improve from 0.65236
# Confusion matrix:
#  [[24  0  0]
#  [ 0  3  3]
#  [ 4  1 17]]
# Epoch 21/50
# 9/9 [==============================] - 25s 3s/step - loss: 0.5938 - acc: 0.7517 - binary_accuracy: 0.8380 - mean_absolute_error: 0.2086 - loss_no_weight_decay: 0.5938 - val_loss: 1.7112 - val_acc: 0.3125 - val_binary_accuracy: 0.5365 - val_mean_absolute_error: 0.4098 - val_loss_no_weight_decay: 1.7112
# — val_kappa: -0.06374501992031867
#
# Epoch 00021: val_kappa did not improve from 0.65236
# Confusion matrix:
#  [[13  8  0]
#  [ 0  9  0]
#  [ 0 22  0]]
# Epoch 22/50
# 9/9 [==============================] - 21s 2s/step - loss: 0.7180 - acc: 0.7445 - binary_accuracy: 0.8118 - mean_absolute_error: 0.2448 - loss_no_weight_decay: 0.7180 - val_loss: 0.5204 - val_acc: 0.5769 - val_binary_accuracy: 0.7436 - val_mean_absolute_error: 0.2333 - val_loss_no_weight_decay: 0.5204
# — val_kappa: 0.376
#
# Epoch 00022: val_kappa did not improve from 0.65236
# Confusion matrix:
#  [[27  0  0]
#  [ 1  8  0]
#  [ 6 10  0]]
# Epoch 23/50
# 9/9 [==============================] - 23s 3s/step - loss: 0.5670 - acc: 0.6992 - binary_accuracy: 0.8064 - mean_absolute_error: 0.2175 - loss_no_weight_decay: 0.5670 - val_loss: 0.5632 - val_acc: 0.5781 - val_binary_accuracy: 0.7240 - val_mean_absolute_error: 0.2508 - val_loss_no_weight_decay: 0.5632
# — val_kappa: 0.39516129032258074
#
# Epoch 00023: val_kappa did not improve from 0.65236
# Confusion matrix:
#  [[26  0  0]
#  [ 0  6  0]
#  [ 4 15  1]]
# Epoch 24/50
# 9/9 [==============================] - 22s 2s/step - loss: 0.5792 - acc: 0.7342 - binary_accuracy: 0.8211 - mean_absolute_error: 0.2050 - loss_no_weight_decay: 0.5792 - val_loss: 0.3718 - val_acc: 0.7885 - val_binary_accuracy: 0.8462 - val_mean_absolute_error: 0.1765 - val_loss_no_weight_decay: 0.3718
# — val_kappa: 0.7747035573122529
#
# Epoch 00024: val_kappa improved from 0.65236 to 0.77470, saving model to base_2020-05-09-16-07-45-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[23  0  0]
#  [ 2  0  5]
#  [ 2  1 19]]
# Epoch 25/50
# 9/9 [==============================] - 25s 3s/step - loss: 0.5090 - acc: 0.7639 - binary_accuracy: 0.8472 - mean_absolute_error: 0.1844 - loss_no_weight_decay: 0.5090 - val_loss: 0.3806 - val_acc: 0.8125 - val_binary_accuracy: 0.8698 - val_mean_absolute_error: 0.1647 - val_loss_no_weight_decay: 0.3806
# — val_kappa: 0.7142857142857143
#
# Epoch 00025: val_kappa did not improve from 0.77470
# Confusion matrix:
#  [[25  0  0]
#  [ 1  1  4]
#  [ 4  7 10]]
# Epoch 26/50
# 9/9 [==============================] - 23s 3s/step - loss: 0.4845 - acc: 0.8181 - binary_accuracy: 0.8747 - mean_absolute_error: 0.1827 - loss_no_weight_decay: 0.4845 - val_loss: 0.4248 - val_acc: 0.7885 - val_binary_accuracy: 0.8654 - val_mean_absolute_error: 0.1960 - val_loss_no_weight_decay: 0.4248
# — val_kappa: 0.5952380952380953
#
# Epoch 00026: val_kappa did not improve from 0.77470
# Confusion matrix:
#  [[26  0  0]
#  [ 0  4  2]
#  [ 1  8 11]]
# Epoch 27/50
# 9/9 [==============================] - 20s 2s/step - loss: 0.4880 - acc: 0.7911 - binary_accuracy: 0.8659 - mean_absolute_error: 0.1860 - loss_no_weight_decay: 0.4880 - val_loss: 0.4514 - val_acc: 0.8125 - val_binary_accuracy: 0.8854 - val_mean_absolute_error: 0.2020 - val_loss_no_weight_decay: 0.4514
# — val_kappa: 0.7747035573122529
#
# Epoch 00027: val_kappa did not improve from 0.77470
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Confusion matrix:
#  [[24  0  3]
#  [ 1  1  5]
#  [ 3  1 14]]
# Epoch 28/50
# 9/9 [==============================] - 25s 3s/step - loss: 0.5104 - acc: 0.8108 - binary_accuracy: 0.8715 - mean_absolute_error: 0.1893 - loss_no_weight_decay: 0.5104 - val_loss: 0.4056 - val_acc: 0.7885 - val_binary_accuracy: 0.8590 - val_mean_absolute_error: 0.1927 - val_loss_no_weight_decay: 0.4056
# — val_kappa: 0.6798418972332015
#
# Epoch 00028: val_kappa did not improve from 0.77470
# Confusion matrix:
#  [[25  0  0]
#  [ 1  5  2]
#  [ 1  8 10]]
# Epoch 29/50
# 9/9 [==============================] - 23s 3s/step - loss: 0.4424 - acc: 0.8404 - binary_accuracy: 0.8971 - mean_absolute_error: 0.1653 - loss_no_weight_decay: 0.4424 - val_loss: 0.5504 - val_acc: 0.6250 - val_binary_accuracy: 0.7448 - val_mean_absolute_error: 0.2362 - val_loss_no_weight_decay: 0.5504
# — val_kappa: 0.53125
#
# Epoch 00029: val_kappa did not improve from 0.77470
# Confusion matrix:
#  [[27  0  0]
#  [ 0  5  0]
#  [ 1 15  4]]
# Epoch 30/50
# 9/9 [==============================] - 22s 2s/step - loss: 0.4327 - acc: 0.8271 - binary_accuracy: 0.8859 - mean_absolute_error: 0.1677 - loss_no_weight_decay: 0.4327 - val_loss: 0.4160 - val_acc: 0.7692 - val_binary_accuracy: 0.8526 - val_mean_absolute_error: 0.1866 - val_loss_no_weight_decay: 0.4160
# — val_kappa: 0.7401574803149606
#
# Epoch 00030: val_kappa did not improve from 0.77470
# Confusion matrix:
#  [[23  0  0]
#  [ 0  2  3]
#  [ 2  5 17]]
# Epoch 31/50
# 9/9 [==============================] - 23s 3s/step - loss: 0.4082 - acc: 0.8475 - binary_accuracy: 0.8977 - mean_absolute_error: 0.1520 - loss_no_weight_decay: 0.4082 - val_loss: 0.3555 - val_acc: 0.7969 - val_binary_accuracy: 0.8646 - val_mean_absolute_error: 0.1671 - val_loss_no_weight_decay: 0.3555
# — val_kappa: 0.7421875
#
# Epoch 00031: val_kappa did not improve from 0.77470
# Confusion matrix:
#  [[27  0  0]
#  [ 0  2  0]
#  [ 3 11  9]]
# Epoch 32/50
# 9/9 [==============================] - 23s 3s/step - loss: 0.4575 - acc: 0.8126 - binary_accuracy: 0.8745 - mean_absolute_error: 0.1704 - loss_no_weight_decay: 0.4575 - val_loss: 0.5297 - val_acc: 0.6154 - val_binary_accuracy: 0.7244 - val_mean_absolute_error: 0.2438 - val_loss_no_weight_decay: 0.5297
# — val_kappa: 0.47058823529411764
#
# Epoch 00032: val_kappa did not improve from 0.77470
# Confusion matrix:
#  [[23  0  1]
#  [ 0  7  0]
#  [ 0 17  4]]
# Epoch 33/50
# 9/9 [==============================] - 22s 2s/step - loss: 0.4591 - acc: 0.7938 - binary_accuracy: 0.8655 - mean_absolute_error: 0.1750 - loss_no_weight_decay: 0.4591 - val_loss: 0.4391 - val_acc: 0.7969 - val_binary_accuracy: 0.8646 - val_mean_absolute_error: 0.1912 - val_loss_no_weight_decay: 0.4391
# — val_kappa: 0.6823529411764706
#
# Epoch 00033: val_kappa did not improve from 0.77470
# Confusion matrix:
#  [[26  0  1]
#  [ 1  3  3]
#  [ 1 10  7]]
# Epoch 34/50
# 9/9 [==============================] - 25s 3s/step - loss: 0.4394 - acc: 0.8073 - binary_accuracy: 0.8727 - mean_absolute_error: 0.1681 - loss_no_weight_decay: 0.4394 - val_loss: 0.3899 - val_acc: 0.7885 - val_binary_accuracy: 0.8590 - val_mean_absolute_error: 0.1809 - val_loss_no_weight_decay: 0.3899
# — val_kappa: 0.7874015748031495
#
# Epoch 00034: val_kappa improved from 0.77470 to 0.78740, saving model to base_2020-05-09-16-07-45-val_kapa_checkpoint.hdf5
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Confusion matrix:
#  [[22  0  1]
#  [ 0  3  3]
#  [ 2  7 14]]
# Epoch 35/50
# 9/9 [==============================] - 20s 2s/step - loss: 0.4028 - acc: 0.8498 - binary_accuracy: 0.8970 - mean_absolute_error: 0.1500 - loss_no_weight_decay: 0.4028 - val_loss: 0.3699 - val_acc: 0.8594 - val_binary_accuracy: 0.9010 - val_mean_absolute_error: 0.1760 - val_loss_no_weight_decay: 0.3699
# — val_kappa: 0.8
#
# Epoch 00035: val_kappa improved from 0.78740 to 0.80000, saving model to base_2020-05-09-16-07-45-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[29  0  2]
#  [ 0  1  2]
#  [ 0  7 11]]
# Epoch 36/50
# 9/9 [==============================] - 25s 3s/step - loss: 0.4117 - acc: 0.8177 - binary_accuracy: 0.8767 - mean_absolute_error: 0.1634 - loss_no_weight_decay: 0.4117 - val_loss: 0.4430 - val_acc: 0.7308 - val_binary_accuracy: 0.8205 - val_mean_absolute_error: 0.1824 - val_loss_no_weight_decay: 0.4430
# — val_kappa: 0.7401574803149606
#
# Epoch 00036: val_kappa did not improve from 0.80000
# Confusion matrix:
#  [[28  0  1]
#  [ 0  3  5]
#  [ 0  3 12]]
# Epoch 37/50
# 9/9 [==============================] - 24s 3s/step - loss: 0.3640 - acc: 0.8705 - binary_accuracy: 0.9119 - mean_absolute_error: 0.1337 - loss_no_weight_decay: 0.3640 - val_loss: 0.3562 - val_acc: 0.8281 - val_binary_accuracy: 0.8854 - val_mean_absolute_error: 0.1592 - val_loss_no_weight_decay: 0.3562
# — val_kappa: 0.8
#
# Epoch 00037: val_kappa did not improve from 0.80000
# Confusion matrix:
#  [[23  0  0]
#  [ 0  4  2]
#  [ 2  6 15]]
# Epoch 38/50
# 9/9 [==============================] - 22s 2s/step - loss: 0.4163 - acc: 0.8267 - binary_accuracy: 0.8844 - mean_absolute_error: 0.1627 - loss_no_weight_decay: 0.4163 - val_loss: 0.2927 - val_acc: 0.8654 - val_binary_accuracy: 0.9103 - val_mean_absolute_error: 0.1357 - val_loss_no_weight_decay: 0.2927
# — val_kappa: 0.7509881422924901
#
# Epoch 00038: val_kappa did not improve from 0.80000
# Confusion matrix:
#  [[26  0  1]
#  [ 0  5  2]
#  [ 2  8  8]]
# Epoch 39/50
# 9/9 [==============================] - 20s 2s/step - loss: 0.3765 - acc: 0.8537 - binary_accuracy: 0.9037 - mean_absolute_error: 0.1448 - loss_no_weight_decay: 0.3765 - val_loss: 0.3144 - val_acc: 0.8594 - val_binary_accuracy: 0.9062 - val_mean_absolute_error: 0.1385 - val_loss_no_weight_decay: 0.3144
# — val_kappa: 0.6692913385826772
#
# Epoch 00039: val_kappa did not improve from 0.80000
# Confusion matrix:
#  [[29  0  0]
#  [ 0  4  3]
#  [ 1  3 12]]
# Epoch 40/50
# 9/9 [==============================] - 24s 3s/step - loss: 0.3917 - acc: 0.8403 - binary_accuracy: 0.8941 - mean_absolute_error: 0.1495 - loss_no_weight_decay: 0.3917 - val_loss: 0.6072 - val_acc: 0.7692 - val_binary_accuracy: 0.8462 - val_mean_absolute_error: 0.2312 - val_loss_no_weight_decay: 0.6072
# — val_kappa: 0.7401574803149606
#
# Epoch 00040: val_kappa did not improve from 0.80000
# Confusion matrix:
#  [[31  0  0]
#  [ 0  3  2]
#  [ 0  4 12]]
# Epoch 41/50
# 9/9 [==============================] - 22s 2s/step - loss: 0.3886 - acc: 0.8304 - binary_accuracy: 0.8881 - mean_absolute_error: 0.1529 - loss_no_weight_decay: 0.3886 - val_loss: 0.3534 - val_acc: 0.8281 - val_binary_accuracy: 0.8906 - val_mean_absolute_error: 0.1572 - val_loss_no_weight_decay: 0.3534
# — val_kappa: 0.71875
#
# Epoch 00041: val_kappa did not improve from 0.80000
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Confusion matrix:
#  [[28  0  0]
#  [ 0  1  3]
#  [ 2  3 15]]
# Epoch 42/50
# 9/9 [==============================] - 22s 2s/step - loss: 0.4222 - acc: 0.8289 - binary_accuracy: 0.8883 - mean_absolute_error: 0.1610 - loss_no_weight_decay: 0.4222 - val_loss: 0.2988 - val_acc: 0.8846 - val_binary_accuracy: 0.9231 - val_mean_absolute_error: 0.1474 - val_loss_no_weight_decay: 0.2988
# — val_kappa: 0.6798418972332015
#
# Epoch 00042: val_kappa did not improve from 0.80000
# Confusion matrix:
#  [[24  0  0]
#  [ 0  6  0]
#  [ 0  9 13]]
# Epoch 43/50
# 9/9 [==============================] - 23s 3s/step - loss: 0.3695 - acc: 0.8324 - binary_accuracy: 0.8889 - mean_absolute_error: 0.1494 - loss_no_weight_decay: 0.3695 - val_loss: 0.2785 - val_acc: 0.8281 - val_binary_accuracy: 0.8854 - val_mean_absolute_error: 0.1271 - val_loss_no_weight_decay: 0.2785
# — val_kappa: 0.671875
#
# Epoch 00043: val_kappa did not improve from 0.80000
# Confusion matrix:
#  [[28  0  1]
#  [ 0  2  1]
#  [ 1  5 14]]
# Epoch 44/50
# 9/9 [==============================] - 22s 2s/step - loss: 0.3644 - acc: 0.8797 - binary_accuracy: 0.9192 - mean_absolute_error: 0.1324 - loss_no_weight_decay: 0.3644 - val_loss: 0.4075 - val_acc: 0.7885 - val_binary_accuracy: 0.8590 - val_mean_absolute_error: 0.1756 - val_loss_no_weight_decay: 0.4075
# — val_kappa: 0.7890625
#
# Epoch 00044: val_kappa did not improve from 0.80000
# Confusion matrix:
#  [[25  0  0]
#  [ 0  2  4]
#  [ 0  5 16]]
# Epoch 45/50
# 9/9 [==============================] - 25s 3s/step - loss: 0.3994 - acc: 0.8403 - binary_accuracy: 0.8912 - mean_absolute_error: 0.1576 - loss_no_weight_decay: 0.3994 - val_loss: 0.3606 - val_acc: 0.8281 - val_binary_accuracy: 0.8802 - val_mean_absolute_error: 0.1507 - val_loss_no_weight_decay: 0.3606
# — val_kappa: 0.776470588235294
#
# Epoch 00045: val_kappa did not improve from 0.80000
# Confusion matrix:
#  [[20  0  1]
#  [ 0  4  2]
#  [ 4  9 12]]
# Epoch 46/50
# 9/9 [==============================] - 22s 2s/step - loss: 0.3901 - acc: 0.8357 - binary_accuracy: 0.8916 - mean_absolute_error: 0.1490 - loss_no_weight_decay: 0.3901 - val_loss: 0.3720 - val_acc: 0.8654 - val_binary_accuracy: 0.9103 - val_mean_absolute_error: 0.1644 - val_loss_no_weight_decay: 0.3720
# — val_kappa: 0.765625
#
# Epoch 00046: val_kappa did not improve from 0.80000
# Confusion matrix:
#  [[26  0  1]
#  [ 0  5  1]
#  [ 1  8 10]]
# Epoch 47/50
# 9/9 [==============================] - 23s 3s/step - loss: 0.3732 - acc: 0.8672 - binary_accuracy: 0.9127 - mean_absolute_error: 0.1470 - loss_no_weight_decay: 0.3732 - val_loss: 0.3374 - val_acc: 0.8594 - val_binary_accuracy: 0.9062 - val_mean_absolute_error: 0.1618 - val_loss_no_weight_decay: 0.3374
# — val_kappa: 0.8359375
#
# Epoch 00047: val_kappa improved from 0.80000 to 0.83594, saving model to base_2020-05-09-16-07-45-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[25  0  0]
#  [ 0  3  1]
#  [ 3  5 15]]
# Epoch 48/50
# 9/9 [==============================] - 22s 2s/step - loss: 0.3577 - acc: 0.8497 - binary_accuracy: 0.9010 - mean_absolute_error: 0.1420 - loss_no_weight_decay: 0.3577 - val_loss: 0.5138 - val_acc: 0.7308 - val_binary_accuracy: 0.8269 - val_mean_absolute_error: 0.2051 - val_loss_no_weight_decay: 0.5138
# — val_kappa: 0.7421875
#
# Epoch 00048: val_kappa did not improve from 0.83594
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Confusion matrix:
#  [[30  0  0]
#  [ 0  4  0]
#  [ 2  3 13]]
# Epoch 49/50
# 9/9 [==============================] - 20s 2s/step - loss: 0.4032 - acc: 0.8405 - binary_accuracy: 0.8966 - mean_absolute_error: 0.1490 - loss_no_weight_decay: 0.4032 - val_loss: 0.3330 - val_acc: 0.8750 - val_binary_accuracy: 0.9115 - val_mean_absolute_error: 0.1536 - val_loss_no_weight_decay: 0.3330
# — val_kappa: 0.6456692913385826
#
# Epoch 00049: val_kappa did not improve from 0.83594
# Confusion matrix:
#  [[27  0  2]
#  [ 0  6  1]
#  [ 0  3 13]]
# Epoch 50/50
# 9/9 [==============================] - 25s 3s/step - loss: 0.3612 - acc: 0.8576 - binary_accuracy: 0.9045 - mean_absolute_error: 0.1452 - loss_no_weight_decay: 0.3612 - val_loss: 0.4570 - val_acc: 0.7885 - val_binary_accuracy: 0.8590 - val_mean_absolute_error: 0.1916 - val_loss_no_weight_decay: 0.4570
# — val_kappa: 0.7294117647058824
#
# Epoch 00050: val_kappa did not improve from 0.83594
# Confusion matrix:
#  [[27  0  1]
#  [ 0  7  0]
#  [ 2  4 11]]
# 176/176 [==============================] - 5s 28ms/step
# 176/176 [==============================] - 5s 29ms/step
# Test loss: 0.5100119150956743
# Test accuracy: 0.7272727272727273
# Confusion Matrix
# [[84  0  4]
#  [ 0 12  7]
#  [ 6 32 31]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94        88
#            1       0.27      0.63      0.38        19
#            2       0.74      0.45      0.56        69
#
#     accuracy                           0.72       176
#    macro avg       0.65      0.68      0.63       176
# weighted avg       0.79      0.72      0.73       176

# %%
from Kappa_Skl import kappa
def kappa2(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    if len(y_true.shape) > 1 and y_true.shape[1] > 1:
        y_true = y_true.dot(range(y_true.shape[1]))
    if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
        y_pred = y_pred.dot(range(y_pred.shape[1]))
    try:
        return kappa(y_true, y_pred, weights='quadratic')
    except IndexError:
        return np.nan
    
print('Quadratic_wieghted_kappa')
print(kappa2(y_true, y_pred))
# Out:
# Quadratic_wieghted_kappa
# 0.7164763458401305

# %%
import numpy as np 
import matplotlib.pyplot as plt
import os
import wandb
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model loss.png')

# summarize history for val_kappa
plt.plot(history.history['val_kappa'])
plt.title('Validation_Kappa')
plt.ylabel('val_kappa')
plt.xlabel('epoch')
plt.legend([ 'validation'], loc='upper left')
plt.show()
#plt.savefig('model validation_kappa.png')

# summarize history for mean_absolute _error
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model mean_absolute_error')
plt.ylabel('mean_absolute_error')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model maey.png'
# Out:
# dict_keys(['val_loss', 'val_acc', 'val_binary_accuracy', 'val_mean_absolute_error', 'val_loss_no_weight_decay', 'loss', 'acc', 'binary_accuracy', 'mean_absolute_error', 'loss_no_weight_decay', 'val_kappa', 'lr'])
