# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, InputLayer
from keras.regularizers import L1L2, l2, l1
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from custom_pooling import RMSPooling2D
from keras.optimizers import SGD, Adam
from keras.layers import LeakyReLU
#from data import BALANCE_WEIGHTS
from keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
#import os
from datetime import datetime as dt
from custom_loss import WeightedCategoricalCrossEntropy
from VCM import VCM
from QWK import QWK
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
def get_experiment_id():
    time_str = dt.now().strftime('%Y-%m-%d-%H-%M-%S')
    experiment_id = 'base_{}'.format(time_str)
    return experiment_id
p_ratio=[1.0, 1.44, 1.73, 1.0]

model = Sequential()


model.add(Conv2D(16, (5, 5), activation='tanh', input_shape=(270, 270, 3)))
model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(16, (3, 3), activation='tanh'))
model.add(Conv2D(16, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))

#model.add(LeakyReLU(alpha=0.01))


model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))



model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))          
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(MaxPooling2D(pool_size=2))
#model.add(MaxPooling2D(pool_size=1))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
model.add(MaxPooling2D(pool_size=2))

model.add(Flatten())


#chnaged from 10 to 5 because an error 
model.add(Dense(3, activation='softmax'))

sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.count_params()
#adam = Adam(lr=0.0005, decay=1e-6)
#rmsprop
#Mloss = WeightedCategoricalCrossEntropy({0: 0.4125861396437394, 1: 1.4918664786083686, 2: 0.690426457789382, 3: 3.9541433021806855, 4: 4.885604311008468})
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['acc','binary_accuracy','mae'])
model.summary()
loss_no_weight_decay = model.total_loss - sum(model.losses)
model.metrics_tensors.append(loss_no_weight_decay)
model.metrics_names.append('loss_no_weight_decay')
#############################################################################################
#############################################################################################
#############################################################################################
#############################################################################################
#Preparing Data Augmentation Configuration 
train_datagen = ImageDataGenerator(
        rescale=1./255,
#        featurewise_center=True,
 #       samplewise_center=True,
        shear_range=0,
        zoom_range=0.0,#[1 / 1.15, 1.15],
        horizontal_flip=False,#True,
        rotation_range=0)#90,
#        validation_split=0.2)
"""
For the test set only rescale should be made 
"""
test_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/three_class/train",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="training")
#    save_to_dir="D:/Separating Images into subfolders/train_augmented")


#print(train_generator.class_indices)

valid_generator = valid_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/three_class/vald",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="validation")
#    save_to_dir="D:/Separating Images into subfolders/val_augmented"


test_generator = test_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/three_class/test",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=1,
    class_mode="categorical",
    shuffle=False,
    seed=42)
#    save_to_dir="D:/Separating Images into subfolders/test_augmented")


# Fitting/Training the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
experiment_id = get_experiment_id()
callbacks = [
    QWK(valid_generator, STEP_SIZE_VALID),
    EarlyStopping(monitor='val_acc', patience=50, min_delta=0.001, verbose=1),
    ModelCheckpoint(experiment_id + "-val_kapa_checkpoint.hdf5", monitor='val_kappa', verbose=1, save_best_only=True, mode='max'),
    ReduceLROnPlateau(monitor='val_acc', factor=0.5, patience=7, verbose=1, mode='auto', min_delta=0.001, cooldown=0, min_lr=1e-7),
    VCM(valid_generator,STEP_SIZE_VALID)
    
]

class_weight_list = class_weight.compute_class_weight('balanced', np.unique(train_generator.classes), train_generator.classes)
class_weights = dict(zip(np.unique(train_generator.classes), class_weight_list))

history=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    class_weight=class_weights,
                    callbacks=callbacks,
                    epochs=35  
)


# Evaluating the model 
#predicting output
#reseting the test generator before calling predict_generator, in order not to get weird output
test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1', '2']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 266, 266, 16)      1216
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 262, 262, 16)      6416
# _________________________________________________________________
# input_1 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 260, 260, 16)      2320
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 258, 258, 16)      2320
# _________________________________________________________________
# input_2 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 254, 254, 16)      6416
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 250, 250, 16)      6416
# _________________________________________________________________
# input_3 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 246, 246, 16)      6416
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 242, 242, 16)      6416
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 121, 121, 16)      0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 119, 119, 32)      4640
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 117, 117, 32)      9248
# _________________________________________________________________
# input_4 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 115, 115, 32)      9248
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 113, 113, 32)      9248
# _________________________________________________________________
# input_5 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 111, 111, 32)      9248
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 109, 109, 32)      9248
# _________________________________________________________________
# input_6 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 107, 107, 32)      9248
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 105, 105, 32)      9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 52, 52, 32)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 50, 50, 64)        18496
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 48, 48, 64)        36928
# _________________________________________________________________
# input_7 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 46, 46, 64)        36928
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 44, 44, 64)        36928
# _________________________________________________________________
# input_8 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 42, 42, 64)        36928
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 40, 40, 64)        36928
# _________________________________________________________________
# input_9 (InputLayer)         multiple                  0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 20, 20, 64)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 18, 18, 64)        36928
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# input_10 (InputLayer)        multiple                  0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 14, 14, 64)        36928
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 12, 12, 64)        36928
# _________________________________________________________________
# input_11 (InputLayer)        multiple                  0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 6915
# =================================================================
# Total params: 465,075
# Trainable params: 465,075
# Non-trainable params: 0
# _________________________________________________________________
# Found 588 images belonging to 3 classes.
# Found 116 images belonging to 3 classes.
# Found 176 images belonging to 3 classes.
# Epoch 1/35
# 9/9 [==============================] - 23s 3s/step - loss: 1.0848 - acc: 0.4248 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4409 - loss_no_weight_decay: 1.0848 - val_loss: 1.0828 - val_acc: 0.5625 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4408 - val_loss_no_weight_decay: 1.0828
# — val_kappa: 0.0
#
# Epoch 00001: val_kappa improved from -inf to 0.00000, saving model to base_2020-05-09-12-55-31-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[26  0  0]
#  [ 5  0  0]
#  [21  0  0]]
# Epoch 2/35
# 9/9 [==============================] - 14s 2s/step - loss: 1.1023 - acc: 0.2172 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4476 - loss_no_weight_decay: 1.1023 - val_loss: 1.1155 - val_acc: 0.0962 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4481 - val_loss_no_weight_decay: 1.1155
# — val_kappa: 0.0
#
# Epoch 00002: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[30  0  0]
#  [ 7  0  0]
#  [15  0  0]]
# Epoch 3/35
# 9/9 [==============================] - 13s 1s/step - loss: 1.1020 - acc: 0.3011 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4461 - loss_no_weight_decay: 1.1020 - val_loss: 1.0974 - val_acc: 0.3594 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4441 - val_loss_no_weight_decay: 1.0974
# — val_kappa: 0.0
#
# Epoch 00003: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[22  0  0]
#  [ 6  0  0]
#  [24  0  0]]
# Epoch 4/35
# 9/9 [==============================] - 12s 1s/step - loss: 1.0976 - acc: 0.3753 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4454 - loss_no_weight_decay: 1.0976 - val_loss: 1.1047 - val_acc: 0.4808 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4446 - val_loss_no_weight_decay: 1.1047
# — val_kappa: 0.0
#
# Epoch 00004: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[23  0  0]
#  [ 6  0  0]
#  [23  0  0]]
# Epoch 5/35
# 9/9 [==============================] - 12s 1s/step - loss: 1.1041 - acc: 0.3993 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4442 - loss_no_weight_decay: 1.1041 - val_loss: 1.0980 - val_acc: 0.4844 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4440 - val_loss_no_weight_decay: 1.0980
# — val_kappa: 0.0
#
# Epoch 00005: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[28  0  0]
#  [ 5  0  0]
#  [19  0  0]]
# Epoch 6/35
# 9/9 [==============================] - 10s 1s/step - loss: 1.0601 - acc: 0.4627 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4383 - loss_no_weight_decay: 1.0601 - val_loss: 1.0726 - val_acc: 0.5000 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4377 - val_loss_no_weight_decay: 1.0726
# — val_kappa: 0.0
#
# Epoch 00006: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[29  0  0]
#  [ 5  0  0]
#  [18  0  0]]
# Epoch 7/35
# 9/9 [==============================] - 11s 1s/step - loss: 1.0808 - acc: 0.5260 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4362 - loss_no_weight_decay: 1.0808 - val_loss: 1.1030 - val_acc: 0.4688 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4416 - val_loss_no_weight_decay: 1.1030
# — val_kappa: 0.0
#
# Epoch 00007: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[29  0  0]
#  [ 4  0  0]
#  [19  0  0]]
# Epoch 8/35
# 9/9 [==============================] - 10s 1s/step - loss: 1.0426 - acc: 0.4982 - binary_accuracy: 0.6708 - mean_absolute_error: 0.4330 - loss_no_weight_decay: 1.0426 - val_loss: 0.9996 - val_acc: 0.5769 - val_binary_accuracy: 0.6923 - val_mean_absolute_error: 0.4161 - val_loss_no_weight_decay: 0.9996
# — val_kappa: 0.06153846153846165
#
# Epoch 00008: val_kappa improved from 0.00000 to 0.06154, saving model to base_2020-05-09-12-55-31-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[28  0  0]
#  [ 7  0  0]
#  [17  0  0]]
# Epoch 9/35
# 9/9 [==============================] - 10s 1s/step - loss: 1.0984 - acc: 0.4715 - binary_accuracy: 0.6673 - mean_absolute_error: 0.4393 - loss_no_weight_decay: 1.0984 - val_loss: 1.0372 - val_acc: 0.5312 - val_binary_accuracy: 0.6719 - val_mean_absolute_error: 0.4282 - val_loss_no_weight_decay: 1.0372
# — val_kappa: 0.020725388601036232
#
# Epoch 00009: val_kappa did not improve from 0.06154
# Confusion matrix:
#  [[26  0  0]
#  [ 6  0  0]
#  [20  0  0]]
# Epoch 10/35
# 9/9 [==============================] - 9s 1s/step - loss: 1.0829 - acc: 0.4336 - binary_accuracy: 0.6724 - mean_absolute_error: 0.4311 - loss_no_weight_decay: 1.0829 - val_loss: 1.0987 - val_acc: 0.4038 - val_binary_accuracy: 0.6923 - val_mean_absolute_error: 0.4353 - val_loss_no_weight_decay: 1.0987
# — val_kappa: 0.06153846153846165
#
# Epoch 00010: val_kappa did not improve from 0.06154
# Confusion matrix:
#  [[29  0  0]
#  [ 4  0  0]
#  [19  0  0]]
# Epoch 11/35
# 9/9 [==============================] - 10s 1s/step - loss: 1.0693 - acc: 0.3915 - binary_accuracy: 0.6818 - mean_absolute_error: 0.4328 - loss_no_weight_decay: 1.0693 - val_loss: 1.0447 - val_acc: 0.3750 - val_binary_accuracy: 0.6979 - val_mean_absolute_error: 0.4242 - val_loss_no_weight_decay: 1.0447
# — val_kappa: 0.15999999999999992
#
# Epoch 00011: val_kappa improved from 0.06154 to 0.16000, saving model to base_2020-05-09-12-55-31-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[26  0  0]
#  [ 4  0  0]
#  [22  0  0]]
# Epoch 12/35
# 9/9 [==============================] - 13s 1s/step - loss: 1.0680 - acc: 0.4123 - binary_accuracy: 0.6976 - mean_absolute_error: 0.4274 - loss_no_weight_decay: 1.0680 - val_loss: 1.0382 - val_acc: 0.3462 - val_binary_accuracy: 0.7115 - val_mean_absolute_error: 0.4226 - val_loss_no_weight_decay: 1.0382
# — val_kappa: 0.08040201005025116
#
# Epoch 00012: val_kappa did not improve from 0.16000
# Confusion matrix:
#  [[31  0  0]
#  [ 4  0  0]
#  [17  0  0]]
# Epoch 13/35
# 9/9 [==============================] - 13s 1s/step - loss: 1.0205 - acc: 0.4774 - binary_accuracy: 0.7101 - mean_absolute_error: 0.4108 - loss_no_weight_decay: 1.0205 - val_loss: 0.9665 - val_acc: 0.5625 - val_binary_accuracy: 0.7031 - val_mean_absolute_error: 0.4005 - val_loss_no_weight_decay: 0.9665
# — val_kappa: 0.16901408450704214
#
# Epoch 00013: val_kappa improved from 0.16000 to 0.16901, saving model to base_2020-05-09-12-55-31-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[28  0  0]
#  [ 5  0  0]
#  [19  0  0]]
# Epoch 14/35
# 9/9 [==============================] - 11s 1s/step - loss: 1.0392 - acc: 0.4019 - binary_accuracy: 0.7004 - mean_absolute_error: 0.4113 - loss_no_weight_decay: 1.0392 - val_loss: 1.0208 - val_acc: 0.4615 - val_binary_accuracy: 0.7244 - val_mean_absolute_error: 0.4103 - val_loss_no_weight_decay: 1.0208
# — val_kappa: 0.13
#
# Epoch 00014: val_kappa did not improve from 0.16901
# Confusion matrix:
#  [[27  0  0]
#  [ 6  0  0]
#  [19  0  0]]
# Epoch 15/35
# 9/9 [==============================] - 11s 1s/step - loss: 1.0375 - acc: 0.4755 - binary_accuracy: 0.7126 - mean_absolute_error: 0.4048 - loss_no_weight_decay: 1.0375 - val_loss: 1.0390 - val_acc: 0.3750 - val_binary_accuracy: 0.7031 - val_mean_absolute_error: 0.4183 - val_loss_no_weight_decay: 1.0390
# — val_kappa: 0.1470588235294119
#
# Epoch 00015: val_kappa did not improve from 0.16901
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Confusion matrix:
#  [[30  1  0]
#  [ 5  0  0]
#  [16  0  0]]
# Epoch 16/35
# 9/9 [==============================] - 11s 1s/step - loss: 0.9823 - acc: 0.4790 - binary_accuracy: 0.7173 - mean_absolute_error: 0.4117 - loss_no_weight_decay: 0.9823 - val_loss: 0.8817 - val_acc: 0.6731 - val_binary_accuracy: 0.7821 - val_mean_absolute_error: 0.3805 - val_loss_no_weight_decay: 0.8817
# — val_kappa: 0.33333333333333326
#
# Epoch 00016: val_kappa improved from 0.16901 to 0.33333, saving model to base_2020-05-09-12-55-31-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[24  0  0]
#  [ 9  0  0]
#  [19  0  0]]
# Epoch 17/35
# 9/9 [==============================] - 10s 1s/step - loss: 1.0236 - acc: 0.5423 - binary_accuracy: 0.7285 - mean_absolute_error: 0.3978 - loss_no_weight_decay: 1.0236 - val_loss: 1.0258 - val_acc: 0.4375 - val_binary_accuracy: 0.7135 - val_mean_absolute_error: 0.4122 - val_loss_no_weight_decay: 1.0258
# — val_kappa: 0.21674876847290625
#
# Epoch 00017: val_kappa did not improve from 0.33333
# Confusion matrix:
#  [[24  0  0]
#  [ 6  0  0]
#  [21  0  1]]
# Epoch 18/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.9353 - acc: 0.5938 - binary_accuracy: 0.7442 - mean_absolute_error: 0.3822 - loss_no_weight_decay: 0.9353 - val_loss: 0.9013 - val_acc: 0.5962 - val_binary_accuracy: 0.7564 - val_mean_absolute_error: 0.3770 - val_loss_no_weight_decay: 0.9013
# — val_kappa: 0.28837209302325584
#
# Epoch 00018: val_kappa did not improve from 0.33333
# Confusion matrix:
#  [[32  0  0]
#  [ 3  0  0]
#  [16  0  1]]
# Epoch 19/35
# 9/9 [==============================] - 10s 1s/step - loss: 0.9652 - acc: 0.5789 - binary_accuracy: 0.7471 - mean_absolute_error: 0.3809 - loss_no_weight_decay: 0.9652 - val_loss: 0.9141 - val_acc: 0.5625 - val_binary_accuracy: 0.7656 - val_mean_absolute_error: 0.3723 - val_loss_no_weight_decay: 0.9141
# — val_kappa: 0.44843049327354245
#
# Epoch 00019: val_kappa improved from 0.33333 to 0.44843, saving model to base_2020-05-09-12-55-31-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[24  0  0]
#  [ 6  0  0]
#  [21  0  1]]
# Epoch 20/35
# 9/9 [==============================] - 9s 1s/step - loss: 0.9123 - acc: 0.5681 - binary_accuracy: 0.7356 - mean_absolute_error: 0.3690 - loss_no_weight_decay: 0.9123 - val_loss: 0.8090 - val_acc: 0.6731 - val_binary_accuracy: 0.7949 - val_mean_absolute_error: 0.3422 - val_loss_no_weight_decay: 0.8090
# — val_kappa: 0.33484162895927605
#
# Epoch 00020: val_kappa did not improve from 0.44843
# Confusion matrix:
#  [[24  0  0]
#  [ 5  1  0]
#  [17  2  3]]
# Epoch 21/35
# 9/9 [==============================] - 10s 1s/step - loss: 0.9309 - acc: 0.5489 - binary_accuracy: 0.7204 - mean_absolute_error: 0.3774 - loss_no_weight_decay: 0.9309 - val_loss: 0.8828 - val_acc: 0.5781 - val_binary_accuracy: 0.7812 - val_mean_absolute_error: 0.3613 - val_loss_no_weight_decay: 0.8828
# — val_kappa: 0.4054054054054054
#
# Epoch 00021: val_kappa did not improve from 0.44843
# Confusion matrix:
#  [[21  0  0]
#  [ 7  2  0]
#  [19  2  1]]
# Epoch 22/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.8971 - acc: 0.6065 - binary_accuracy: 0.7604 - mean_absolute_error: 0.3594 - loss_no_weight_decay: 0.8971 - val_loss: 0.8051 - val_acc: 0.6731 - val_binary_accuracy: 0.7821 - val_mean_absolute_error: 0.3454 - val_loss_no_weight_decay: 0.8051
# — val_kappa: 0.3727272727272727
#
# Epoch 00022: val_kappa did not improve from 0.44843
# Confusion matrix:
#  [[27  0  0]
#  [ 9  0  0]
#  [13  0  3]]
# Epoch 23/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.8888 - acc: 0.6302 - binary_accuracy: 0.7622 - mean_absolute_error: 0.3431 - loss_no_weight_decay: 0.8888 - val_loss: 0.8774 - val_acc: 0.5625 - val_binary_accuracy: 0.7396 - val_mean_absolute_error: 0.3633 - val_loss_no_weight_decay: 0.8774
# — val_kappa: 0.33484162895927605
#
# Epoch 00023: val_kappa did not improve from 0.44843
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Confusion matrix:
#  [[26  0  0]
#  [ 3  3  0]
#  [14  2  4]]
# Epoch 24/35
# 9/9 [==============================] - 11s 1s/step - loss: 0.7938 - acc: 0.6634 - binary_accuracy: 0.7931 - mean_absolute_error: 0.3281 - loss_no_weight_decay: 0.7938 - val_loss: 0.6886 - val_acc: 0.7308 - val_binary_accuracy: 0.8141 - val_mean_absolute_error: 0.3052 - val_loss_no_weight_decay: 0.6886
# — val_kappa: 0.4107142857142857
#
# Epoch 00024: val_kappa did not improve from 0.44843
# Confusion matrix:
#  [[23  0  0]
#  [ 5  2  0]
#  [17  0  5]]
# Epoch 25/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.8448 - acc: 0.6580 - binary_accuracy: 0.7749 - mean_absolute_error: 0.3298 - loss_no_weight_decay: 0.8448 - val_loss: 0.9136 - val_acc: 0.5000 - val_binary_accuracy: 0.7188 - val_mean_absolute_error: 0.3622 - val_loss_no_weight_decay: 0.9136
# — val_kappa: 0.46288209606986896
#
# Epoch 00025: val_kappa improved from 0.44843 to 0.46288, saving model to base_2020-05-09-12-55-31-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[22  3  0]
#  [ 4  2  0]
#  [ 9  7  5]]
# Epoch 26/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.8410 - acc: 0.6400 - binary_accuracy: 0.7762 - mean_absolute_error: 0.3297 - loss_no_weight_decay: 0.8410 - val_loss: 0.7796 - val_acc: 0.6923 - val_binary_accuracy: 0.7885 - val_mean_absolute_error: 0.3237 - val_loss_no_weight_decay: 0.7796
# — val_kappa: 0.5
#
# Epoch 00026: val_kappa improved from 0.46288 to 0.50000, saving model to base_2020-05-09-12-55-31-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[26  0  0]
#  [ 4  2  0]
#  [16  3  1]]
# Epoch 27/35
# 9/9 [==============================] - 11s 1s/step - loss: 0.8838 - acc: 0.6062 - binary_accuracy: 0.7684 - mean_absolute_error: 0.3415 - loss_no_weight_decay: 0.8838 - val_loss: 0.8195 - val_acc: 0.6250 - val_binary_accuracy: 0.7552 - val_mean_absolute_error: 0.3360 - val_loss_no_weight_decay: 0.8195
# — val_kappa: 0.34666666666666646
#
# Epoch 00027: val_kappa did not improve from 0.50000
# Confusion matrix:
#  [[27  0  0]
#  [ 5  2  0]
#  [12  1  5]]
# Epoch 28/35
# 9/9 [==============================] - 11s 1s/step - loss: 0.7923 - acc: 0.6588 - binary_accuracy: 0.7814 - mean_absolute_error: 0.3108 - loss_no_weight_decay: 0.7923 - val_loss: 0.8250 - val_acc: 0.6731 - val_binary_accuracy: 0.7436 - val_mean_absolute_error: 0.3439 - val_loss_no_weight_decay: 0.8250
# — val_kappa: 0.42105263157894735
#
# Epoch 00028: val_kappa did not improve from 0.50000
# Confusion matrix:
#  [[24  1  0]
#  [ 6  2  0]
#  [12  3  4]]
# Epoch 29/35
# 9/9 [==============================] - 11s 1s/step - loss: 0.7883 - acc: 0.6706 - binary_accuracy: 0.7882 - mean_absolute_error: 0.3084 - loss_no_weight_decay: 0.7883 - val_loss: 0.7953 - val_acc: 0.5625 - val_binary_accuracy: 0.7552 - val_mean_absolute_error: 0.3262 - val_loss_no_weight_decay: 0.7953
# — val_kappa: 0.4358974358974358
#
# Epoch 00029: val_kappa did not improve from 0.50000
# Confusion matrix:
#  [[25  1  1]
#  [ 0  5  0]
#  [11  7  2]]
# Epoch 30/35
# 9/9 [==============================] - 10s 1s/step - loss: 0.8061 - acc: 0.6418 - binary_accuracy: 0.7756 - mean_absolute_error: 0.3128 - loss_no_weight_decay: 0.8061 - val_loss: 0.7796 - val_acc: 0.5962 - val_binary_accuracy: 0.7628 - val_mean_absolute_error: 0.3130 - val_loss_no_weight_decay: 0.7796
# — val_kappa: 0.5128205128205128
#
# Epoch 00030: val_kappa improved from 0.50000 to 0.51282, saving model to base_2020-05-09-12-55-31-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[22  0  1]
#  [ 4  1  0]
#  [17  3  4]]
# Epoch 31/35
# 9/9 [==============================] - 10s 1s/step - loss: 0.7622 - acc: 0.7037 - binary_accuracy: 0.8043 - mean_absolute_error: 0.2992 - loss_no_weight_decay: 0.7622 - val_loss: 0.8949 - val_acc: 0.5469 - val_binary_accuracy: 0.7448 - val_mean_absolute_error: 0.3545 - val_loss_no_weight_decay: 0.8949
# — val_kappa: 0.502127659574468
#
# Epoch 00031: val_kappa did not improve from 0.51282
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Confusion matrix:
#  [[25  0  2]
#  [ 0  2  0]
#  [16  6  1]]
# Epoch 32/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.7728 - acc: 0.6849 - binary_accuracy: 0.7971 - mean_absolute_error: 0.3095 - loss_no_weight_decay: 0.7728 - val_loss: 0.8174 - val_acc: 0.5962 - val_binary_accuracy: 0.7436 - val_mean_absolute_error: 0.3356 - val_loss_no_weight_decay: 0.8174
# — val_kappa: 0.4104803493449781
#
# Epoch 00032: val_kappa did not improve from 0.51282
# Confusion matrix:
#  [[22  1  1]
#  [ 3  4  0]
#  [14  6  1]]
# Epoch 33/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.8403 - acc: 0.6354 - binary_accuracy: 0.7691 - mean_absolute_error: 0.3250 - loss_no_weight_decay: 0.8403 - val_loss: 0.8389 - val_acc: 0.5938 - val_binary_accuracy: 0.7552 - val_mean_absolute_error: 0.3388 - val_loss_no_weight_decay: 0.8389
# — val_kappa: 0.3677130044843048
#
# Epoch 00033: val_kappa did not improve from 0.51282
# Confusion matrix:
#  [[26  0  1]
#  [ 5  2  0]
#  [10  2  6]]
# Epoch 34/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.7694 - acc: 0.6941 - binary_accuracy: 0.7904 - mean_absolute_error: 0.3043 - loss_no_weight_decay: 0.7694 - val_loss: 0.7521 - val_acc: 0.6346 - val_binary_accuracy: 0.7756 - val_mean_absolute_error: 0.3126 - val_loss_no_weight_decay: 0.7521
# — val_kappa: 0.5677966101694916
#
# Epoch 00034: val_kappa improved from 0.51282 to 0.56780, saving model to base_2020-05-09-12-55-31-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[22  0  1]
#  [ 4  1  1]
#  [15  5  3]]
# Epoch 35/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.7731 - acc: 0.6952 - binary_accuracy: 0.7901 - mean_absolute_error: 0.3028 - loss_no_weight_decay: 0.7731 - val_loss: 0.7793 - val_acc: 0.6562 - val_binary_accuracy: 0.7708 - val_mean_absolute_error: 0.3259 - val_loss_no_weight_decay: 0.7793
# — val_kappa: 0.4366812227074236
#
# Epoch 00035: val_kappa did not improve from 0.56780
# Confusion matrix:
#  [[28  1  2]
#  [ 1  2  0]
#  [11  7  0]]
# 176/176 [==============================] - 5s 28ms/step
# 176/176 [==============================] - 5s 28ms/step
# Test loss: 0.7603780369602398
# Test accuracy: 0.6193181818181818
# Confusion Matrix
# [[74  1 13]
#  [ 2 11  6]
#  [17 28 24]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.80      0.84      0.82        88
#            1       0.28      0.58      0.37        19
#            2       0.56      0.35      0.43        69
#
#     accuracy                           0.62       176
#    macro avg       0.54      0.59      0.54       176
# weighted avg       0.65      0.62      0.62       176

# %%
from Kappa_Skl import kappa
def kappa2(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    if len(y_true.shape) > 1 and y_true.shape[1] > 1:
        y_true = y_true.dot(range(y_true.shape[1]))
    if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
        y_pred = y_pred.dot(range(y_pred.shape[1]))
    try:
        return kappa(y_true, y_pred, weights='quadratic')
    except IndexError:
        return np.nan
    
print('Quadratic_wieghted_kappa')
print(kappa2(y_true, y_pred))
# Out:
# Quadratic_wieghted_kappa
# 0.44366594185390995

# %%
import numpy as np 
import matplotlib.pyplot as plt
import os
import wandb
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_acc', 'val_binary_accuracy', 'val_mean_absolute_error', 'val_loss_no_weight_decay', 'loss', 'acc', 'binary_accuracy', 'mean_absolute_error', 'loss_no_weight_decay', 'val_kappa', 'lr'])
