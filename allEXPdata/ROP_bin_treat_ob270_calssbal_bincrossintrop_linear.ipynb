# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, InputLayer
from keras.regularizers import L1L2, l2, l1
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from custom_pooling import RMSPooling2D
from keras.optimizers import SGD, Adam
from keras.layers import LeakyReLU
#from data import BALANCE_WEIGHTS
from keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
#import os
from datetime import datetime as dt
from custom_loss import WeightedCategoricalCrossEntropy
from VCM import VCM
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
def get_experiment_id():
    time_str = dt.now().strftime('%Y-%m-%d-%H-%M-%S')
    experiment_id = 'base_{}'.format(time_str)
    return experiment_id
p_ratio=[1.0, 1.44, 1.73, 1.0]

model = Sequential()


model.add(Conv2D(16, (5, 5), activation='linear', input_shape=(270, 270, 3)))
model.add(Conv2D(16, (5, 5), activation='linear'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(16, (3, 3), activation='linear'))
model.add(Conv2D(16, (3, 3), activation='linear'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))

#model.add(LeakyReLU(alpha=0.01))


model.add(Conv2D(16, (5, 5), activation='linear'))
model.add(Conv2D(16, (5, 5), activation='linear'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))



model.add(Conv2D(16, (5, 5), activation='linear'))
model.add(Conv2D(16, (5, 5), activation='linear'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(32, (3, 3), activation='linear'))
model.add(Conv2D(32, (3, 3), activation='linear'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))          
model.add(Conv2D(32, (3, 3), activation='linear'))
model.add(Conv2D(32, (3, 3), activation='linear'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(32, (3, 3), activation='linear'))
model.add(Conv2D(32, (3, 3), activation='linear'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))

model.add(Conv2D(32, (3, 3), activation='linear'))
model.add(Conv2D(32, (3, 3), activation='linear'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(64, (3, 3), activation='linear'))
model.add(Conv2D(64, (3, 3), activation='linear'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='linear'))
model.add(Conv2D(64, (3, 3), activation='linear'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='linear'))
model.add(Conv2D(64, (3, 3), activation='linear'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(MaxPooling2D(pool_size=2))
#model.add(MaxPooling2D(pool_size=1))
model.add(Conv2D(64, (3, 3), activation='linear'))
model.add(Conv2D(64, (3, 3), activation='linear'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='linear'))
model.add(Conv2D(64, (3, 3), activation='linear'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
model.add(MaxPooling2D(pool_size=2))

model.add(Flatten())


#chnaged from 10 to 5 because an error 
model.add(Dense(2, activation='softmax'))

sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.count_params()
#adam = Adam(lr=0.0005, decay=1e-6)
#rmsprop
#Mloss = WeightedCategoricalCrossEntropy({0: 0.4125861396437394, 1: 1.4918664786083686, 2: 0.690426457789382, 3: 3.9541433021806855, 4: 4.885604311008468})
model.compile(loss='binary_crossentropy', optimizer=sgd, metrics=['acc','binary_accuracy','mae'])
model.summary()
loss_no_weight_decay = model.total_loss - sum(model.losses)
model.metrics_tensors.append(loss_no_weight_decay)
model.metrics_names.append('loss_no_weight_decay')
#############################################################################################
#############################################################################################
#############################################################################################
#############################################################################################
#Preparing Data Augmentation Configuration 
train_datagen = ImageDataGenerator(
        rescale=1./255,
#        featurewise_center=True,
 #       samplewise_center=True,
        shear_range=0,
        zoom_range=0.0,#[1 / 1.15, 1.15],
        horizontal_flip=False,#True,
        rotation_range=0)#90,
#        validation_split=0.2)
"""
For the test set only rescale should be made 
"""
test_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_class_treatment/train",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="training")
#    save_to_dir="D:/Separating Images into subfolders/train_augmented")


#print(train_generator.class_indices)

valid_generator = valid_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_class_treatment/vald",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="validation")
#    save_to_dir="D:/Separating Images into subfolders/val_augmented"


test_generator = test_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_class_treatment/test",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=1,
    class_mode="categorical",
    shuffle=False,
    seed=42)
#    save_to_dir="D:/Separating Images into subfolders/test_augmented")


# Fitting/Training the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
experiment_id = get_experiment_id()
callbacks = [
    EarlyStopping(monitor='val_acc', patience=50, min_delta=0.001, verbose=1),
    ModelCheckpoint(experiment_id + "-val_acc_checkpoint.hdf5", monitor='val_acc', verbose=1, save_best_only=True, mode='auto'),
    ReduceLROnPlateau(monitor='val_acc', factor=0.5, patience=7, verbose=1, mode='auto', min_delta=0.001, cooldown=0, min_lr=1e-7),
    VCM(valid_generator,STEP_SIZE_VALID)
    
]

class_weight_list = class_weight.compute_class_weight('balanced', np.unique(train_generator.classes), train_generator.classes)
class_weights = dict(zip(np.unique(train_generator.classes), class_weight_list))

history=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    class_weight=class_weights,
                    callbacks=callbacks,
                    epochs=35  
)


# Evaluating the model 
#predicting output
#reseting the test generator before calling predict_generator, in order not to get weird output
test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 266, 266, 16)      1216
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 262, 262, 16)      6416
# _________________________________________________________________
# input_1 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 260, 260, 16)      2320
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 258, 258, 16)      2320
# _________________________________________________________________
# input_2 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 254, 254, 16)      6416
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 250, 250, 16)      6416
# _________________________________________________________________
# input_3 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 246, 246, 16)      6416
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 242, 242, 16)      6416
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 121, 121, 16)      0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 119, 119, 32)      4640
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 117, 117, 32)      9248
# _________________________________________________________________
# input_4 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 115, 115, 32)      9248
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 113, 113, 32)      9248
# _________________________________________________________________
# input_5 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 111, 111, 32)      9248
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 109, 109, 32)      9248
# _________________________________________________________________
# input_6 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 107, 107, 32)      9248
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 105, 105, 32)      9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 52, 52, 32)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 50, 50, 64)        18496
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 48, 48, 64)        36928
# _________________________________________________________________
# input_7 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 46, 46, 64)        36928
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 44, 44, 64)        36928
# _________________________________________________________________
# input_8 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 42, 42, 64)        36928
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 40, 40, 64)        36928
# _________________________________________________________________
# input_9 (InputLayer)         multiple                  0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 20, 20, 64)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 18, 18, 64)        36928
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# input_10 (InputLayer)        multiple                  0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 14, 14, 64)        36928
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 12, 12, 64)        36928
# _________________________________________________________________
# input_11 (InputLayer)        multiple                  0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 4610
# =================================================================
# Total params: 462,770
# Trainable params: 462,770
# Non-trainable params: 0
# _________________________________________________________________
# Found 294 images belonging to 2 classes.
# Found 58 images belonging to 2 classes.
# Found 88 images belonging to 2 classes.
# Epoch 1/35
# 4/4 [==============================] - 20s 5s/step - loss: 0.6916 - acc: 0.5615 - binary_accuracy: 0.5615 - mean_absolute_error: 0.4975 - loss_no_weight_decay: 0.6916 - val_loss: 0.6833 - val_acc: 0.6379 - val_binary_accuracy: 0.6379 - val_mean_absolute_error: 0.4945 - val_loss_no_weight_decay: 0.6833
#
# Epoch 00001: val_acc improved from -inf to 0.63793, saving model to base_2020-05-08-19-03-14-val_acc_checkpoint.hdf5
# Confusion matrix:
#  []
# Epoch 2/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.6889 - acc: 0.6211 - binary_accuracy: 0.6211 - mean_absolute_error: 0.4879 - loss_no_weight_decay: 0.6889 - val_loss: 0.6748 - val_acc: 0.6724 - val_binary_accuracy: 0.6724 - val_mean_absolute_error: 0.4901 - val_loss_no_weight_decay: 0.6748
#
# Epoch 00002: val_acc improved from 0.63793 to 0.67241, saving model to base_2020-05-08-19-03-14-val_acc_checkpoint.hdf5
# Confusion matrix:
#  []
# Epoch 3/35
# 4/4 [==============================] - 4s 922ms/step - loss: 0.7230 - acc: 0.5435 - binary_accuracy: 0.5435 - mean_absolute_error: 0.5007 - loss_no_weight_decay: 0.7230 - val_loss: 0.7771 - val_acc: 0.3103 - val_binary_accuracy: 0.3103 - val_mean_absolute_error: 0.5344 - val_loss_no_weight_decay: 0.7771
#
# Epoch 00003: val_acc did not improve from 0.67241
# Confusion matrix:
#  []
# Epoch 4/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.6842 - acc: 0.3555 - binary_accuracy: 0.3555 - mean_absolute_error: 0.5195 - loss_no_weight_decay: 0.6842 - val_loss: 0.6820 - val_acc: 0.5690 - val_binary_accuracy: 0.5690 - val_mean_absolute_error: 0.4933 - val_loss_no_weight_decay: 0.6820
#
# Epoch 00004: val_acc did not improve from 0.67241
# Confusion matrix:
#  []
# Epoch 5/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.6861 - acc: 0.6130 - binary_accuracy: 0.6130 - mean_absolute_error: 0.4861 - loss_no_weight_decay: 0.6861 - val_loss: 0.6575 - val_acc: 0.6724 - val_binary_accuracy: 0.6724 - val_mean_absolute_error: 0.4800 - val_loss_no_weight_decay: 0.6575
#
# Epoch 00005: val_acc did not improve from 0.67241
# Confusion matrix:
#  []
# Epoch 6/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.6867 - acc: 0.6508 - binary_accuracy: 0.6508 - mean_absolute_error: 0.4845 - loss_no_weight_decay: 0.6867 - val_loss: 0.6812 - val_acc: 0.6034 - val_binary_accuracy: 0.6034 - val_mean_absolute_error: 0.4931 - val_loss_no_weight_decay: 0.6812
#
# Epoch 00006: val_acc did not improve from 0.67241
# Confusion matrix:
#  []
# Epoch 7/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.6702 - acc: 0.5842 - binary_accuracy: 0.5842 - mean_absolute_error: 0.4917 - loss_no_weight_decay: 0.6702 - val_loss: 0.6646 - val_acc: 0.6552 - val_binary_accuracy: 0.6552 - val_mean_absolute_error: 0.4842 - val_loss_no_weight_decay: 0.6646
#
# Epoch 00007: val_acc did not improve from 0.67241
# Confusion matrix:
#  []
# Epoch 8/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.6930 - acc: 0.6055 - binary_accuracy: 0.6055 - mean_absolute_error: 0.4920 - loss_no_weight_decay: 0.6930 - val_loss: 0.6825 - val_acc: 0.6207 - val_binary_accuracy: 0.6207 - val_mean_absolute_error: 0.4933 - val_loss_no_weight_decay: 0.6825
#
# Epoch 00008: val_acc did not improve from 0.67241
# Confusion matrix:
#  []
# Epoch 9/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.6835 - acc: 0.5586 - binary_accuracy: 0.5586 - mean_absolute_error: 0.4936 - loss_no_weight_decay: 0.6835 - val_loss: 0.6988 - val_acc: 0.5345 - val_binary_accuracy: 0.5345 - val_mean_absolute_error: 0.5005 - val_loss_no_weight_decay: 0.6988
#
# Epoch 00009: val_acc did not improve from 0.67241
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Confusion matrix:
#  []
# Epoch 10/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.6814 - acc: 0.5645 - binary_accuracy: 0.5645 - mean_absolute_error: 0.4956 - loss_no_weight_decay: 0.6814 - val_loss: 0.6691 - val_acc: 0.6897 - val_binary_accuracy: 0.6897 - val_mean_absolute_error: 0.4852 - val_loss_no_weight_decay: 0.6691
#
# Epoch 00010: val_acc improved from 0.67241 to 0.68966, saving model to base_2020-05-08-19-03-14-val_acc_checkpoint.hdf5
# Confusion matrix:
#  []
# Epoch 11/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.6817 - acc: 0.6806 - binary_accuracy: 0.6806 - mean_absolute_error: 0.4698 - loss_no_weight_decay: 0.6817 - val_loss: 0.6703 - val_acc: 0.6724 - val_binary_accuracy: 0.6724 - val_mean_absolute_error: 0.4856 - val_loss_no_weight_decay: 0.6703
#
# Epoch 00011: val_acc did not improve from 0.68966
# Confusion matrix:
#  []
# Epoch 12/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.6744 - acc: 0.6133 - binary_accuracy: 0.6133 - mean_absolute_error: 0.4904 - loss_no_weight_decay: 0.6744 - val_loss: 0.7017 - val_acc: 0.5690 - val_binary_accuracy: 0.5690 - val_mean_absolute_error: 0.5003 - val_loss_no_weight_decay: 0.7017
#
# Epoch 00012: val_acc did not improve from 0.68966
# Confusion matrix:
#  []
# Epoch 13/35
# 4/4 [==============================] - 4s 930ms/step - loss: 0.6385 - acc: 0.6219 - binary_accuracy: 0.6219 - mean_absolute_error: 0.4756 - loss_no_weight_decay: 0.6385 - val_loss: 0.6090 - val_acc: 0.7414 - val_binary_accuracy: 0.7414 - val_mean_absolute_error: 0.4469 - val_loss_no_weight_decay: 0.6090
#
# Epoch 00013: val_acc improved from 0.68966 to 0.74138, saving model to base_2020-05-08-19-03-14-val_acc_checkpoint.hdf5
# Confusion matrix:
#  []
# Epoch 14/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.6719 - acc: 0.6289 - binary_accuracy: 0.6289 - mean_absolute_error: 0.4735 - loss_no_weight_decay: 0.6719 - val_loss: 0.6531 - val_acc: 0.6552 - val_binary_accuracy: 0.6552 - val_mean_absolute_error: 0.4751 - val_loss_no_weight_decay: 0.6531
#
# Epoch 00014: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# Epoch 15/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.7074 - acc: 0.5648 - binary_accuracy: 0.5648 - mean_absolute_error: 0.4947 - loss_no_weight_decay: 0.7074 - val_loss: 0.6707 - val_acc: 0.6552 - val_binary_accuracy: 0.6552 - val_mean_absolute_error: 0.4846 - val_loss_no_weight_decay: 0.6707
#
# Epoch 00015: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# Epoch 16/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.6744 - acc: 0.6875 - binary_accuracy: 0.6875 - mean_absolute_error: 0.4655 - loss_no_weight_decay: 0.6744 - val_loss: 0.6458 - val_acc: 0.6724 - val_binary_accuracy: 0.6724 - val_mean_absolute_error: 0.4716 - val_loss_no_weight_decay: 0.6458
#
# Epoch 00016: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# Epoch 17/35
# 4/4 [==============================] - 4s 923ms/step - loss: 0.7072 - acc: 0.5437 - binary_accuracy: 0.5437 - mean_absolute_error: 0.4897 - loss_no_weight_decay: 0.7072 - val_loss: 0.7415 - val_acc: 0.4138 - val_binary_accuracy: 0.4138 - val_mean_absolute_error: 0.5176 - val_loss_no_weight_decay: 0.7415
#
# Epoch 00017: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# Epoch 18/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.6727 - acc: 0.5061 - binary_accuracy: 0.5061 - mean_absolute_error: 0.5061 - loss_no_weight_decay: 0.6727 - val_loss: 0.6955 - val_acc: 0.5345 - val_binary_accuracy: 0.5345 - val_mean_absolute_error: 0.4984 - val_loss_no_weight_decay: 0.6955
#
# Epoch 00018: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# Epoch 19/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.6652 - acc: 0.6055 - binary_accuracy: 0.6055 - mean_absolute_error: 0.4886 - loss_no_weight_decay: 0.6652 - val_loss: 0.6506 - val_acc: 0.6552 - val_binary_accuracy: 0.6552 - val_mean_absolute_error: 0.4747 - val_loss_no_weight_decay: 0.6506
#
# Epoch 00019: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# Epoch 20/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.6767 - acc: 0.6718 - binary_accuracy: 0.6718 - mean_absolute_error: 0.4698 - loss_no_weight_decay: 0.6767 - val_loss: 0.6450 - val_acc: 0.6552 - val_binary_accuracy: 0.6552 - val_mean_absolute_error: 0.4713 - val_loss_no_weight_decay: 0.6450
#
# Epoch 00020: val_acc did not improve from 0.74138
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Confusion matrix:
#  []
# Epoch 21/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.6535 - acc: 0.6265 - binary_accuracy: 0.6265 - mean_absolute_error: 0.4749 - loss_no_weight_decay: 0.6535 - val_loss: 0.6595 - val_acc: 0.6379 - val_binary_accuracy: 0.6379 - val_mean_absolute_error: 0.4795 - val_loss_no_weight_decay: 0.6595
#
# Epoch 00021: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# Epoch 22/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.6550 - acc: 0.6449 - binary_accuracy: 0.6449 - mean_absolute_error: 0.4783 - loss_no_weight_decay: 0.6550 - val_loss: 0.6407 - val_acc: 0.6207 - val_binary_accuracy: 0.6207 - val_mean_absolute_error: 0.4683 - val_loss_no_weight_decay: 0.6407
#
# Epoch 00022: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# Epoch 23/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.6746 - acc: 0.6602 - binary_accuracy: 0.6602 - mean_absolute_error: 0.4661 - loss_no_weight_decay: 0.6746 - val_loss: 0.6487 - val_acc: 0.6724 - val_binary_accuracy: 0.6724 - val_mean_absolute_error: 0.4725 - val_loss_no_weight_decay: 0.6487
#
# Epoch 00023: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# Epoch 24/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.6521 - acc: 0.6646 - binary_accuracy: 0.6646 - mean_absolute_error: 0.4668 - loss_no_weight_decay: 0.6521 - val_loss: 0.6931 - val_acc: 0.5862 - val_binary_accuracy: 0.5862 - val_mean_absolute_error: 0.4936 - val_loss_no_weight_decay: 0.6931
#
# Epoch 00024: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# Epoch 25/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.6729 - acc: 0.6007 - binary_accuracy: 0.6007 - mean_absolute_error: 0.4905 - loss_no_weight_decay: 0.6729 - val_loss: 0.6659 - val_acc: 0.6724 - val_binary_accuracy: 0.6724 - val_mean_absolute_error: 0.4798 - val_loss_no_weight_decay: 0.6659
#
# Epoch 00025: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# Epoch 26/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.6470 - acc: 0.6066 - binary_accuracy: 0.6066 - mean_absolute_error: 0.4713 - loss_no_weight_decay: 0.6470 - val_loss: 0.6122 - val_acc: 0.6897 - val_binary_accuracy: 0.6897 - val_mean_absolute_error: 0.4489 - val_loss_no_weight_decay: 0.6122
#
# Epoch 00026: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# Epoch 27/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.6437 - acc: 0.6523 - binary_accuracy: 0.6523 - mean_absolute_error: 0.4579 - loss_no_weight_decay: 0.6437 - val_loss: 0.6210 - val_acc: 0.7069 - val_binary_accuracy: 0.7069 - val_mean_absolute_error: 0.4539 - val_loss_no_weight_decay: 0.6210
#
# Epoch 00027: val_acc did not improve from 0.74138
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Confusion matrix:
#  []
# Epoch 28/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.6862 - acc: 0.6502 - binary_accuracy: 0.6502 - mean_absolute_error: 0.4578 - loss_no_weight_decay: 0.6862 - val_loss: 0.6602 - val_acc: 0.6552 - val_binary_accuracy: 0.6552 - val_mean_absolute_error: 0.4745 - val_loss_no_weight_decay: 0.6602
#
# Epoch 00028: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# Epoch 29/35
# 4/4 [==============================] - 4s 921ms/step - loss: 0.6020 - acc: 0.6797 - binary_accuracy: 0.6797 - mean_absolute_error: 0.4616 - loss_no_weight_decay: 0.6020 - val_loss: 0.6059 - val_acc: 0.7241 - val_binary_accuracy: 0.7241 - val_mean_absolute_error: 0.4433 - val_loss_no_weight_decay: 0.6059
#
# Epoch 00029: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# Epoch 30/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.6645 - acc: 0.6445 - binary_accuracy: 0.6445 - mean_absolute_error: 0.4652 - loss_no_weight_decay: 0.6645 - val_loss: 0.6057 - val_acc: 0.7241 - val_binary_accuracy: 0.7241 - val_mean_absolute_error: 0.4426 - val_loss_no_weight_decay: 0.6057
#
# Epoch 00030: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# Epoch 31/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.6297 - acc: 0.6689 - binary_accuracy: 0.6689 - mean_absolute_error: 0.4369 - loss_no_weight_decay: 0.6297 - val_loss: 0.6148 - val_acc: 0.6724 - val_binary_accuracy: 0.6724 - val_mean_absolute_error: 0.4477 - val_loss_no_weight_decay: 0.6148
#
# Epoch 00031: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# Epoch 32/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.6283 - acc: 0.6484 - binary_accuracy: 0.6484 - mean_absolute_error: 0.4564 - loss_no_weight_decay: 0.6283 - val_loss: 0.6119 - val_acc: 0.6897 - val_binary_accuracy: 0.6897 - val_mean_absolute_error: 0.4450 - val_loss_no_weight_decay: 0.6119
#
# Epoch 00032: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# Epoch 33/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.6257 - acc: 0.6321 - binary_accuracy: 0.6321 - mean_absolute_error: 0.4452 - loss_no_weight_decay: 0.6257 - val_loss: 0.5530 - val_acc: 0.7241 - val_binary_accuracy: 0.7241 - val_mean_absolute_error: 0.4019 - val_loss_no_weight_decay: 0.5530
#
# Epoch 00033: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# Epoch 34/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.6765 - acc: 0.6484 - binary_accuracy: 0.6484 - mean_absolute_error: 0.4480 - loss_no_weight_decay: 0.6765 - val_loss: 0.7005 - val_acc: 0.5000 - val_binary_accuracy: 0.5000 - val_mean_absolute_error: 0.4872 - val_loss_no_weight_decay: 0.7005
#
# Epoch 00034: val_acc did not improve from 0.74138
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Confusion matrix:
#  []
# Epoch 35/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.6160 - acc: 0.6217 - binary_accuracy: 0.6217 - mean_absolute_error: 0.4659 - loss_no_weight_decay: 0.6160 - val_loss: 0.6365 - val_acc: 0.6207 - val_binary_accuracy: 0.6207 - val_mean_absolute_error: 0.4578 - val_loss_no_weight_decay: 0.6365
#
# Epoch 00035: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# 88/88 [==============================] - 1s 11ms/step
# 88/88 [==============================] - 1s 8ms/step
# Test loss: 0.643315614878454
# Test accuracy: 0.5909090909090909
# Confusion Matrix
# [[ 9 10]
#  [26 43]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.26      0.47      0.33        19
#            1       0.81      0.62      0.70        69
#
#     accuracy                           0.59        88
#    macro avg       0.53      0.55      0.52        88
# weighted avg       0.69      0.59      0.62        88

# %%
from Kappa_Skl import kappa
def kappa2(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    if len(y_true.shape) > 1 and y_true.shape[1] > 1:
        y_true = y_true.dot(range(y_true.shape[1]))
    if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
        y_pred = y_pred.dot(range(y_pred.shape[1]))
    try:
        return kappa(y_true, y_pred, weights='quadratic')
    except IndexError:
        return np.nan
    
print('Quadratic_wieghted_kappa')
print(kappa2(y_true, y_pred))
# Out:
# Quadratic_wieghted_kappa
# 0.07422559906487436

# %%
import numpy as np 
import matplotlib.pyplot as plt
import os
import wandb
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_acc', 'val_binary_accuracy', 'val_mean_absolute_error', 'val_loss_no_weight_decay', 'loss', 'acc', 'binary_accuracy', 'mean_absolute_error', 'loss_no_weight_decay', 'lr'])
