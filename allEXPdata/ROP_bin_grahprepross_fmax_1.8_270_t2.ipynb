# %%
import keras
from keras.models import Sequential, Input, Model
from keras.losses import mean_squared_error
from keras.layers import  *
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, InputLayer
from keras.regularizers import L1L2, l2, l1
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from custom_pooling import RMSPooling2D
from keras.optimizers import SGD, Adam
from keras.layers import LeakyReLU
#from data import BALANCE_WEIGHTS
from keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
#import os
from datetime import datetime as dt
from custom_loss import WeightedCategoricalCrossEntropy
from VCM import VCM
import keras.backend as K
from Fractional_MAXPOOL import FractionalPooling2D
from QWK import QWK
import tensorflow as tf
from Fractional_MAXPOOL import FractionalPooling2D

import numpy as np 
import matplotlib.pyplot as plt
import os
import wandb
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
def get_experiment_id():
    time_str = dt.now().strftime('%Y-%m-%d-%H-%M-%S')
    experiment_id = 'base_{}'.format(time_str)
    return experiment_id
p_ratio=[1.0, 1.44, 1.73, 1.0]

model = Sequential()


model.add(Conv2D(16, (5, 5), activation='tanh', input_shape=(270, 270, 3)))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(16, (3, 3), activation='tanh'))
model.add(Conv2D(16, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

#model.add(LeakyReLU(alpha=0.01))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))


model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))


model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))
model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))


#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))

model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
#model.add(MaxPooling2D(pool_size=1))


model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))




model.add(Flatten())


#chnaged from 10 to 5 because an error 
model.add(Dense(2, activation='softmax'))

sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.count_params()
#adam = Adam(lr=0.0005, decay=1e-6)
#rmsprop
#Mloss = WeightedCategoricalCrossEntropy({0: 0.4125861396437394, 1: 1.4918664786083686, 2: 0.690426457789382, 3: 3.9541433021806855, 4: 4.885604311008468})
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['acc','mae'])
model.summary()
loss_no_weight_decay = model.total_loss - sum(model.losses)
model.metrics_tensors.append(loss_no_weight_decay)
model.metrics_names.append('loss_no_weight_decay')
#############################################################################################
#############################################################################################
#############################################################################################
#############################################################################################
#Preparing Data Augmentation Configuration 
train_datagen = ImageDataGenerator(
        rescale=1./255,
#        featurewise_center=True,
 #       samplewise_center=True,
        shear_range=0,
        zoom_range=0.0,#[1 / 1.15, 1.15],
        horizontal_flip=False,#True,
        rotation_range=0)#90,
#        validation_split=0.2)
"""
For the test set only rescale should be made 
"""
test_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/grahprepross/bin_bal/train",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="training")
#    save_to_dir="D:/Separating Images into subfolders/train_augmented")


#print(train_generator.class_indices)

valid_generator = valid_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/grahprepross/bin_bal/vald",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="validation")
#    save_to_dir="D:/Separating Images into subfolders/val_augmented"


test_generator = test_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/grahprepross/bin_bal/test",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=1,
    class_mode="categorical",
    shuffle=False,
    seed=42)
#    save_to_dir="D:/Separating Images into subfolders/test_augmented")


# Fitting/Training the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
experiment_id = get_experiment_id()
callbacks = [
    EarlyStopping(monitor='val_acc', patience=10, min_delta=0.001, verbose=1),
    ModelCheckpoint(experiment_id + "-val_acc_checkpoint.hdf5", monitor='val_acc', verbose=1, save_best_only=True, mode='max'),
    ReduceLROnPlateau(monitor='val_acc', factor=0.5, patience=7, verbose=1, mode='auto', min_delta=0.001, cooldown=0, min_lr=1e-7),
    VCM(valid_generator,STEP_SIZE_VALID)
    
]

class_weight_list = class_weight.compute_class_weight('balanced', np.unique(train_generator.classes), train_generator.classes)
class_weights = dict(zip(np.unique(train_generator.classes), class_weight_list))

history=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    #class_weight=class_weights,
                    callbacks=callbacks,
                    epochs=35  
)


# Evaluating the model 
#predicting output
#reseting the test generator before calling predict_generator, in order not to get weird output
test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 266, 266, 16)      1216
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 262, 262, 16)      6416
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 260, 260, 16)      2320
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 258, 258, 16)      2320
# _________________________________________________________________
# fractional_pooling2d_1 (Frac (None, 143, 143, 16)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 139, 139, 16)      6416
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 135, 135, 16)      6416
# _________________________________________________________________
# fractional_pooling2d_2 (Frac (None, 75, 75, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 71, 71, 16)        6416
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 67, 67, 16)        6416
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 65, 65, 32)        4640
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 63, 63, 32)        9248
# _________________________________________________________________
# fractional_pooling2d_3 (Frac (None, 35, 35, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 33, 33, 64)        18496
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 31, 31, 64)        36928
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 29, 29, 64)        36928
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 27, 27, 64)        36928
# _________________________________________________________________
# fractional_pooling2d_4 (Frac (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 13, 13, 64)        36928
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 11, 11, 64)        36928
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 9, 9, 64)          36928
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 7, 7, 64)          36928
# _________________________________________________________________
# fractional_pooling2d_5 (Frac (None, 3, 3, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 576)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1154
# =================================================================
# Total params: 329,970
# Trainable params: 329,970
# Non-trainable params: 0
# _________________________________________________________________
# Found 462 images belonging to 2 classes.
# Found 154 images belonging to 2 classes.
# Found 66 images belonging to 2 classes.
# Epoch 1/35
# 7/7 [==============================] - 19s 3s/step - loss: 0.6941 - acc: 0.5183 - mean_absolute_error: 0.5002 - loss_no_weight_decay: 0.6941 - val_loss: 0.6916 - val_acc: 0.5156 - val_mean_absolute_error: 0.4991 - val_loss_no_weight_decay: 0.6916
#
# Epoch 00001: val_acc improved from -inf to 0.51562, saving model to base_2020-05-12-21-36-24-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[62  0]
#  [66  0]]
# Epoch 2/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.6940 - acc: 0.4704 - mean_absolute_error: 0.5003 - loss_no_weight_decay: 0.6940 - val_loss: 0.6907 - val_acc: 0.5000 - val_mean_absolute_error: 0.4987 - val_loss_no_weight_decay: 0.6907
#
# Epoch 00002: val_acc did not improve from 0.51562
# Confusion matrix:
#  [[38  1]
#  [46  5]]
# Epoch 3/35
# 7/7 [==============================] - 11s 2s/step - loss: 0.6941 - acc: 0.5141 - mean_absolute_error: 0.4999 - loss_no_weight_decay: 0.6941 - val_loss: 0.6936 - val_acc: 0.4778 - val_mean_absolute_error: 0.4995 - val_loss_no_weight_decay: 0.6936
#
# Epoch 00003: val_acc did not improve from 0.51562
# Confusion matrix:
#  [[36  0]
#  [54  0]]
# Epoch 4/35
# 7/7 [==============================] - 13s 2s/step - loss: 0.6914 - acc: 0.5134 - mean_absolute_error: 0.4988 - loss_no_weight_decay: 0.6914 - val_loss: 0.6888 - val_acc: 0.5469 - val_mean_absolute_error: 0.4978 - val_loss_no_weight_decay: 0.6888
#
# Epoch 00004: val_acc improved from 0.51562 to 0.54688, saving model to base_2020-05-12-21-36-24-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[67  0]
#  [57  4]]
# Epoch 5/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.6904 - acc: 0.5108 - mean_absolute_error: 0.4985 - loss_no_weight_decay: 0.6904 - val_loss: 0.6879 - val_acc: 0.5333 - val_mean_absolute_error: 0.4969 - val_loss_no_weight_decay: 0.6879
#
# Epoch 00005: val_acc did not improve from 0.54688
# Confusion matrix:
#  [[ 0 48]
#  [ 0 42]]
# Epoch 6/35
# 7/7 [==============================] - 11s 2s/step - loss: 0.6903 - acc: 0.5338 - mean_absolute_error: 0.4984 - loss_no_weight_decay: 0.6903 - val_loss: 0.6828 - val_acc: 0.5333 - val_mean_absolute_error: 0.4945 - val_loss_no_weight_decay: 0.6828
#
# Epoch 00006: val_acc did not improve from 0.54688
# Confusion matrix:
#  [[45  0]
#  [45  0]]
# Epoch 7/35
# 7/7 [==============================] - 10s 1s/step - loss: 0.6875 - acc: 0.5855 - mean_absolute_error: 0.4970 - loss_no_weight_decay: 0.6875 - val_loss: 0.6841 - val_acc: 0.6016 - val_mean_absolute_error: 0.4952 - val_loss_no_weight_decay: 0.6841
#
# Epoch 00007: val_acc improved from 0.54688 to 0.60156, saving model to base_2020-05-12-21-36-24-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[10 52]
#  [ 1 65]]
# Epoch 8/35
# 7/7 [==============================] - 13s 2s/step - loss: 0.6859 - acc: 0.6205 - mean_absolute_error: 0.4962 - loss_no_weight_decay: 0.6859 - val_loss: 0.6827 - val_acc: 0.6444 - val_mean_absolute_error: 0.4946 - val_loss_no_weight_decay: 0.6827
#
# Epoch 00008: val_acc improved from 0.60156 to 0.64444, saving model to base_2020-05-12-21-36-24-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[16 27]
#  [ 1 46]]
# Epoch 9/35
# 7/7 [==============================] - 11s 2s/step - loss: 0.6813 - acc: 0.5684 - mean_absolute_error: 0.4931 - loss_no_weight_decay: 0.6813 - val_loss: 0.6753 - val_acc: 0.6222 - val_mean_absolute_error: 0.4901 - val_loss_no_weight_decay: 0.6753
#
# Epoch 00009: val_acc did not improve from 0.64444
# Confusion matrix:
#  [[ 3 36]
#  [ 1 50]]
# Epoch 10/35
# 7/7 [==============================] - 11s 2s/step - loss: 0.6842 - acc: 0.5570 - mean_absolute_error: 0.4948 - loss_no_weight_decay: 0.6842 - val_loss: 0.6691 - val_acc: 0.6016 - val_mean_absolute_error: 0.4869 - val_loss_no_weight_decay: 0.6691
#
# Epoch 00010: val_acc did not improve from 0.64444
# Confusion matrix:
#  [[64  0]
#  [52 12]]
# Epoch 11/35
# 7/7 [==============================] - 13s 2s/step - loss: 0.6795 - acc: 0.5424 - mean_absolute_error: 0.4917 - loss_no_weight_decay: 0.6795 - val_loss: 0.6669 - val_acc: 0.7222 - val_mean_absolute_error: 0.4863 - val_loss_no_weight_decay: 0.6669
#
# Epoch 00011: val_acc improved from 0.64444 to 0.72222, saving model to base_2020-05-12-21-36-24-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[35 15]
#  [ 6 34]]
# Epoch 12/35
# 7/7 [==============================] - 10s 1s/step - loss: 0.6732 - acc: 0.5809 - mean_absolute_error: 0.4853 - loss_no_weight_decay: 0.6732 - val_loss: 0.6749 - val_acc: 0.5333 - val_mean_absolute_error: 0.4780 - val_loss_no_weight_decay: 0.6749
# Epoch 00012: val_acc did not improve from 0.72222
# Confusion matrix:
#  [[40  0]
#  [50  0]]
# Epoch 13/35
# 7/7 [==============================] - 13s 2s/step - loss: 0.6863 - acc: 0.5379 - mean_absolute_error: 0.4893 - loss_no_weight_decay: 0.6863 - val_loss: 0.6682 - val_acc: 0.6328 - val_mean_absolute_error: 0.4857 - val_loss_no_weight_decay: 0.6682
#
# Epoch 00013: val_acc did not improve from 0.72222
# Confusion matrix:
#  [[17 45]
#  [ 3 63]]
# Epoch 14/35
# 7/7 [==============================] - 11s 2s/step - loss: 0.6687 - acc: 0.6434 - mean_absolute_error: 0.4862 - loss_no_weight_decay: 0.6687 - val_loss: 0.6583 - val_acc: 0.7111 - val_mean_absolute_error: 0.4814 - val_loss_no_weight_decay: 0.6583
#
# Epoch 00014: val_acc did not improve from 0.72222
# Confusion matrix:
#  [[31 13]
#  [ 9 37]]
# Epoch 15/35
# 7/7 [==============================] - 11s 2s/step - loss: 0.6606 - acc: 0.6842 - mean_absolute_error: 0.4820 - loss_no_weight_decay: 0.6606 - val_loss: 0.6475 - val_acc: 0.7111 - val_mean_absolute_error: 0.4744 - val_loss_no_weight_decay: 0.6475
#
# Epoch 00015: val_acc did not improve from 0.72222
# Confusion matrix:
#  [[18 32]
#  [ 3 37]]
# Epoch 16/35
# 7/7 [==============================] - 11s 2s/step - loss: 0.6461 - acc: 0.6460 - mean_absolute_error: 0.4695 - loss_no_weight_decay: 0.6461 - val_loss: 0.6322 - val_acc: 0.6172 - val_mean_absolute_error: 0.4584 - val_loss_no_weight_decay: 0.6322
#
# Epoch 00016: val_acc did not improve from 0.72222
# Confusion matrix:
#  [[16 42]
#  [ 2 68]]
# Epoch 17/35
# 7/7 [==============================] - 11s 2s/step - loss: 0.6818 - acc: 0.6097 - mean_absolute_error: 0.4537 - loss_no_weight_decay: 0.6818 - val_loss: 0.7016 - val_acc: 0.5111 - val_mean_absolute_error: 0.4767 - val_loss_no_weight_decay: 0.7016
#
# Epoch 00017: val_acc did not improve from 0.72222
# Confusion matrix:
#  [[45  0]
#  [45  0]]
# Epoch 18/35
# 7/7 [==============================] - 11s 2s/step - loss: 0.6836 - acc: 0.5612 - mean_absolute_error: 0.4850 - loss_no_weight_decay: 0.6836 - val_loss: 0.6679 - val_acc: 0.6111 - val_mean_absolute_error: 0.4838 - val_loss_no_weight_decay: 0.6679
#
# Epoch 00018: val_acc did not improve from 0.72222
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Confusion matrix:
#  [[12 36]
#  [ 1 41]]
# Epoch 19/35
# 7/7 [==============================] - 13s 2s/step - loss: 0.6697 - acc: 0.6205 - mean_absolute_error: 0.4864 - loss_no_weight_decay: 0.6697 - val_loss: 0.6751 - val_acc: 0.5312 - val_mean_absolute_error: 0.4891 - val_loss_no_weight_decay: 0.6751
#
# Epoch 00019: val_acc did not improve from 0.72222
# Confusion matrix:
#  [[64  2]
#  [53  9]]
# Epoch 20/35
# 7/7 [==============================] - 10s 1s/step - loss: 0.6619 - acc: 0.5626 - mean_absolute_error: 0.4812 - loss_no_weight_decay: 0.6619 - val_loss: 0.6626 - val_acc: 0.5778 - val_mean_absolute_error: 0.4792 - val_loss_no_weight_decay: 0.6626
#
# Epoch 00020: val_acc did not improve from 0.72222
# Confusion matrix:
#  [[40  0]
#  [50  0]]
# Epoch 21/35
# 7/7 [==============================] - 13s 2s/step - loss: 0.6756 - acc: 0.5580 - mean_absolute_error: 0.4884 - loss_no_weight_decay: 0.6756 - val_loss: 0.6519 - val_acc: 0.7222 - val_mean_absolute_error: 0.4777 - val_loss_no_weight_decay: 0.6519
#
# Epoch 00021: val_acc improved from 0.72222 to 0.72222, saving model to base_2020-05-12-21-36-24-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[26 17]
#  [14 33]]
# Epoch 22/35
# 7/7 [==============================] - 10s 1s/step - loss: 0.6489 - acc: 0.6805 - mean_absolute_error: 0.4750 - loss_no_weight_decay: 0.6489 - val_loss: 0.6430 - val_acc: 0.6953 - val_mean_absolute_error: 0.4712 - val_loss_no_weight_decay: 0.6430
#
# Epoch 00022: val_acc did not improve from 0.72222
# Confusion matrix:
#  [[33 33]
#  [10 52]]
# Epoch 23/35
# 7/7 [==============================] - 13s 2s/step - loss: 0.6452 - acc: 0.6451 - mean_absolute_error: 0.4710 - loss_no_weight_decay: 0.6452 - val_loss: 0.6351 - val_acc: 0.6889 - val_mean_absolute_error: 0.4643 - val_loss_no_weight_decay: 0.6351
#
# Epoch 00023: val_acc did not improve from 0.72222
# Confusion matrix:
#  [[31 13]
#  [13 33]]
# Epoch 24/35
# 7/7 [==============================] - 11s 2s/step - loss: 0.6304 - acc: 0.6796 - mean_absolute_error: 0.4624 - loss_no_weight_decay: 0.6304 - val_loss: 0.6196 - val_acc: 0.7000 - val_mean_absolute_error: 0.4557 - val_loss_no_weight_decay: 0.6196
#
# Epoch 00024: val_acc did not improve from 0.72222
# Confusion matrix:
#  [[32 15]
#  [ 8 35]]
# Epoch 25/35
# 7/7 [==============================] - 11s 2s/step - loss: 0.6160 - acc: 0.6500 - mean_absolute_error: 0.4496 - loss_no_weight_decay: 0.6160 - val_loss: 0.6018 - val_acc: 0.7031 - val_mean_absolute_error: 0.4372 - val_loss_no_weight_decay: 0.6018
#
# Epoch 00025: val_acc did not improve from 0.72222
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Confusion matrix:
#  [[47 17]
#  [26 38]]
# Epoch 26/35
# 7/7 [==============================] - 11s 2s/step - loss: 0.6083 - acc: 0.6775 - mean_absolute_error: 0.4395 - loss_no_weight_decay: 0.6083 - val_loss: 0.5927 - val_acc: 0.7222 - val_mean_absolute_error: 0.4298 - val_loss_no_weight_decay: 0.5927
#
# Epoch 00026: val_acc did not improve from 0.72222
# Confusion matrix:
#  [[30 14]
#  [15 31]]
# Epoch 27/35
# 7/7 [==============================] - 11s 2s/step - loss: 0.6136 - acc: 0.6521 - mean_absolute_error: 0.4375 - loss_no_weight_decay: 0.6136 - val_loss: 0.5864 - val_acc: 0.7111 - val_mean_absolute_error: 0.4193 - val_loss_no_weight_decay: 0.5864
#
# Epoch 00027: val_acc did not improve from 0.72222
# Confusion matrix:
#  [[28 18]
#  [ 5 39]]
# Epoch 28/35
# 7/7 [==============================] - 11s 2s/step - loss: 0.5911 - acc: 0.6955 - mean_absolute_error: 0.4214 - loss_no_weight_decay: 0.5911 - val_loss: 0.5911 - val_acc: 0.6719 - val_mean_absolute_error: 0.4196 - val_loss_no_weight_decay: 0.5911
#
# Epoch 00028: val_acc did not improve from 0.72222
# Confusion matrix:
#  [[39 27]
#  [ 6 56]]
# Epoch 29/35
# 7/7 [==============================] - 13s 2s/step - loss: 0.5934 - acc: 0.6942 - mean_absolute_error: 0.4239 - loss_no_weight_decay: 0.5934 - val_loss: 0.5538 - val_acc: 0.7556 - val_mean_absolute_error: 0.4017 - val_loss_no_weight_decay: 0.5538
#
# Epoch 00029: val_acc improved from 0.72222 to 0.75556, saving model to base_2020-05-12-21-36-24-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[37 14]
#  [17 22]]
# Epoch 30/35
# 7/7 [==============================] - 10s 1s/step - loss: 0.5676 - acc: 0.7386 - mean_absolute_error: 0.4029 - loss_no_weight_decay: 0.5676 - val_loss: 0.6004 - val_acc: 0.7111 - val_mean_absolute_error: 0.4095 - val_loss_no_weight_decay: 0.6004
#
# Epoch 00030: val_acc did not improve from 0.75556
# Confusion matrix:
#  [[26 19]
#  [ 2 43]]
# Epoch 31/35
# 7/7 [==============================] - 13s 2s/step - loss: 0.5682 - acc: 0.7188 - mean_absolute_error: 0.4061 - loss_no_weight_decay: 0.5682 - val_loss: 0.5636 - val_acc: 0.7188 - val_mean_absolute_error: 0.4027 - val_loss_no_weight_decay: 0.5636
#
# Epoch 00031: val_acc did not improve from 0.75556
# Confusion matrix:
#  [[44 22]
#  [17 45]]
# Epoch 32/35
# 7/7 [==============================] - 11s 2s/step - loss: 0.5726 - acc: 0.7206 - mean_absolute_error: 0.4023 - loss_no_weight_decay: 0.5726 - val_loss: 0.5244 - val_acc: 0.7667 - val_mean_absolute_error: 0.3754 - val_loss_no_weight_decay: 0.5244
#
# Epoch 00032: val_acc improved from 0.75556 to 0.76667, saving model to base_2020-05-12-21-36-24-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[30 20]
#  [10 30]]
# Epoch 33/35
# 7/7 [==============================] - 11s 2s/step - loss: 0.5863 - acc: 0.6882 - mean_absolute_error: 0.4091 - loss_no_weight_decay: 0.5863 - val_loss: 0.5621 - val_acc: 0.6556 - val_mean_absolute_error: 0.3987 - val_loss_no_weight_decay: 0.5621
#
# Epoch 00033: val_acc did not improve from 0.76667
# Confusion matrix:
#  [[33 10]
#  [23 24]]
# Epoch 34/35
# 7/7 [==============================] - 11s 2s/step - loss: 0.5569 - acc: 0.7250 - mean_absolute_error: 0.3963 - loss_no_weight_decay: 0.5569 - val_loss: 0.5479 - val_acc: 0.7266 - val_mean_absolute_error: 0.3832 - val_loss_no_weight_decay: 0.5479
#
# Epoch 00034: val_acc did not improve from 0.76667
# Confusion matrix:
#  [[53 12]
#  [27 36]]
# Epoch 35/35
# 7/7 [==============================] - 13s 2s/step - loss: 0.5714 - acc: 0.7121 - mean_absolute_error: 0.4016 - loss_no_weight_decay: 0.5714 - val_loss: 0.5331 - val_acc: 0.7111 - val_mean_absolute_error: 0.3855 - val_loss_no_weight_decay: 0.5331
#
# Epoch 00035: val_acc did not improve from 0.76667
# Confusion matrix:
#  [[35 10]
#  [12 33]]
# Epoch 00028: early stopping
# 66/66 [==============================] - 1s 9ms/step
# 66/66 [==============================] - 1s 8ms/step
# Test loss: 0.6022801812399518
# Test accuracy: 0.696969696969697
# Confusion Matrix
# [[24  9]
#  [12 21]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.67      0.73      0.70        33
#            1       0.70      0.64      0.67        33
#
#     accuracy                           0.68        66
#    macro avg       0.68      0.68      0.68        66
# weighted avg       0.68      0.68      0.68        66

# %%
from Kappa_Skl import kappa
def kappa2(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    if len(y_true.shape) > 1 and y_true.shape[1] > 1:
        y_true = y_true.dot(range(y_true.shape[1]))
    if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
        y_pred = y_pred.dot(range(y_pred.shape[1]))
    try:
        return kappa(y_true, y_pred, weights='quadratic')
    except IndexError:
        return np.nan
    
print('Quadratic_wieghted_kappa')
print(kappa2(y_true, y_pred))
# Out:
# Quadratic_wieghted_kappa
# 0.36363636363636365

# %%
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
