# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, InputLayer
from keras.regularizers import L1L2, l2, l1
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from custom_pooling import RMSPooling2D
from keras.optimizers import SGD, Adam
from keras.layers import LeakyReLU
#from data import BALANCE_WEIGHTS
from keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
#import os
from datetime import datetime as dt
from custom_loss import WeightedCategoricalCrossEntropy
from VCM import VCM
from QWK import QWK
import keras.backend as K
from Fractional_MAXPOOL import FractionalPooling2D
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
def get_experiment_id():
    time_str = dt.now().strftime('%Y-%m-%d-%H-%M-%S')
    experiment_id = 'base_{}'.format(time_str)
    return experiment_id
p_ratio=[1.0, 1.44, 1.73, 1.0]

model = Sequential()


model.add(Conv2D(16, (5, 5), activation='tanh', input_shape=(270, 270, 3)))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))
model.add(FractionalPooling2D(pool_ratio=(1, 1.6, 1.6, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(16, (3, 3), activation='tanh'))
model.add(Conv2D(16, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

#model.add(LeakyReLU(alpha=0.01))


model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))


model.add(FractionalPooling2D(pool_ratio=(1, 1.6, 1.6, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))          
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
model.add(FractionalPooling2D(pool_ratio=(1, 1.6, 1.6, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(FractionalPooling2D(pool_ratio=(1, 1.6, 1.6, 1),pseudo_random = True,overlap=True))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))


model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

#model.add(MaxPooling2D(pool_size=1))




model.add(FractionalPooling2D(pool_ratio=(1, 1.7, 1.7, 1),pseudo_random = True,overlap=True))

model.add(Flatten())


#chnaged from 10 to 5 because an error 
model.add(Dense(3, activation='softmax'))

sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.count_params()
#adam = Adam(lr=0.0005, decay=1e-6)
#rmsprop
#Mloss = WeightedCategoricalCrossEntropy({0: 0.4125861396437394, 1: 1.4918664786083686, 2: 0.690426457789382, 3: 3.9541433021806855, 4: 4.885604311008468})
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['acc','binary_accuracy','mae'])
model.summary()
loss_no_weight_decay = model.total_loss - sum(model.losses)
model.metrics_tensors.append(loss_no_weight_decay)
model.metrics_names.append('loss_no_weight_decay')
#############################################################################################
#############################################################################################
#############################################################################################
#############################################################################################
#Preparing Data Augmentation Configuration 
train_datagen = ImageDataGenerator(
        rescale=1./255,
#        featurewise_center=True,
 #       samplewise_center=True,
        shear_range=0,
        zoom_range=0.0,#[1 / 1.15, 1.15],
        horizontal_flip=False,#True,
        rotation_range=0)#90,
#        validation_split=0.2)
"""
For the test set only rescale should be made 
"""
test_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/three_class/train",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="training")
#    save_to_dir="D:/Separating Images into subfolders/train_augmented")


#print(train_generator.class_indices)

valid_generator = valid_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/three_class/vald",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="validation")
#    save_to_dir="D:/Separating Images into subfolders/val_augmented"


test_generator = test_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/three_class/test",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=1,
    class_mode="categorical",
    shuffle=False,
    seed=42)
#    save_to_dir="D:/Separating Images into subfolders/test_augmented")


# Fitting/Training the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
experiment_id = get_experiment_id()
callbacks = [
    QWK(valid_generator, STEP_SIZE_VALID),
    EarlyStopping(monitor='val_acc', patience=50, min_delta=0.001, verbose=1),
    ModelCheckpoint(experiment_id + "-val_kapa_checkpoint.hdf5", monitor='val_kappa', verbose=1, save_best_only=True, mode='max'),
    ReduceLROnPlateau(monitor='val_acc', factor=0.5, patience=7, verbose=1, mode='auto', min_delta=0.001, cooldown=0, min_lr=1e-7),
    VCM(valid_generator,STEP_SIZE_VALID)
    
]

class_weight_list = class_weight.compute_class_weight('balanced', np.unique(train_generator.classes), train_generator.classes)
class_weights = dict(zip(np.unique(train_generator.classes), class_weight_list))

history=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    class_weight=class_weights,
                    callbacks=callbacks,
                    epochs=50  
)


# Evaluating the model 
#predicting output
#reseting the test generator before calling predict_generator, in order not to get weird output
test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1', '2']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 266, 266, 16)      1216
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 262, 262, 16)      6416
# _________________________________________________________________
# fractional_pooling2d_1 (Frac (None, 163, 163, 16)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 161, 161, 16)      2320
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 159, 159, 16)      2320
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 155, 155, 16)      6416
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 151, 151, 16)      6416
# _________________________________________________________________
# fractional_pooling2d_2 (Frac (None, 94, 94, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 90, 90, 16)        6416
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 86, 86, 16)        6416
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 84, 84, 32)        4640
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 82, 82, 32)        9248
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 80, 80, 32)        9248
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 78, 78, 32)        9248
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 76, 76, 32)        9248
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 74, 74, 32)        9248
# _________________________________________________________________
# fractional_pooling2d_3 (Frac (None, 46, 46, 32)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 44, 44, 32)        9248
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 42, 42, 32)        9248
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 40, 40, 64)        18496
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 38, 38, 64)        36928
# _________________________________________________________________
# fractional_pooling2d_4 (Frac (None, 23, 23, 64)        0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 21, 21, 64)        36928
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 19, 19, 64)        36928
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 17, 17, 64)        36928
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 15, 15, 64)        36928
# _________________________________________________________________
# fractional_pooling2d_5 (Frac (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 12291
# =================================================================
# Total params: 322,739
# Trainable params: 322,739
# Non-trainable params: 0
# _________________________________________________________________
# Found 588 images belonging to 3 classes.
# Found 116 images belonging to 3 classes.
# Found 176 images belonging to 3 classes.
# Epoch 1/50
# 9/9 [==============================] - 27s 3s/step - loss: 1.1024 - acc: 0.1784 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4458 - loss_no_weight_decay: 1.1024 - val_loss: 1.1022 - val_acc: 0.1562 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4452 - val_loss_no_weight_decay: 1.1022
# — val_kappa: 0.0
#
# Epoch 00001: val_kappa improved from -inf to 0.00000, saving model to base_2020-05-09-18-12-09-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[26  0  0]
#  [ 5  0  0]
#  [21  0  0]]
# Epoch 2/50
# 9/9 [==============================] - 19s 2s/step - loss: 1.0783 - acc: 0.3151 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4447 - loss_no_weight_decay: 1.0783 - val_loss: 1.0982 - val_acc: 0.4038 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4443 - val_loss_no_weight_decay: 1.0982
# — val_kappa: 0.0
#
# Epoch 00002: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[27  0  0]
#  [ 7  0  0]
#  [18  0  0]]
# Epoch 3/50
# 9/9 [==============================] - 20s 2s/step - loss: 1.0858 - acc: 0.5365 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4426 - loss_no_weight_decay: 1.0858 - val_loss: 1.0881 - val_acc: 0.5156 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4421 - val_loss_no_weight_decay: 1.0881
# — val_kappa: 0.0
#
# Epoch 00003: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[22  0  0]
#  [ 6  0  0]
#  [24  0  0]]
# Epoch 4/50
# 9/9 [==============================] - 17s 2s/step - loss: 1.1027 - acc: 0.4351 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4442 - loss_no_weight_decay: 1.1027 - val_loss: 1.1094 - val_acc: 0.3462 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4460 - val_loss_no_weight_decay: 1.1094
# — val_kappa: 0.0
#
# Epoch 00004: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[23  0  0]
#  [ 6  0  0]
#  [23  0  0]]
# Epoch 5/50
# 9/9 [==============================] - 18s 2s/step - loss: 1.1029 - acc: 0.3687 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4464 - loss_no_weight_decay: 1.1029 - val_loss: 1.1087 - val_acc: 0.4062 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4461 - val_loss_no_weight_decay: 1.1087
# — val_kappa: 0.0
#
# Epoch 00005: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[28  0  0]
#  [ 5  0  0]
#  [19  0  0]]
# Epoch 6/50
# 9/9 [==============================] - 18s 2s/step - loss: 1.0782 - acc: 0.4371 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4427 - loss_no_weight_decay: 1.0782 - val_loss: 1.0714 - val_acc: 0.6154 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4382 - val_loss_no_weight_decay: 1.0714
# — val_kappa: 0.0
#
# Epoch 00006: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[29  0  0]
#  [ 5  0  0]
#  [18  0  0]]
# Epoch 7/50
# 9/9 [==============================] - 18s 2s/step - loss: 1.0720 - acc: 0.6010 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4393 - loss_no_weight_decay: 1.0720 - val_loss: 1.0808 - val_acc: 0.4531 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4398 - val_loss_no_weight_decay: 1.0808
# — val_kappa: 0.0
#
# Epoch 00007: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[29  0  0]
#  [ 4  0  0]
#  [19  0  0]]
# Epoch 8/50
# 9/9 [==============================] - 20s 2s/step - loss: 1.0995 - acc: 0.4375 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4410 - loss_no_weight_decay: 1.0995 - val_loss: 1.0686 - val_acc: 0.5769 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4371 - val_loss_no_weight_decay: 1.0686
# — val_kappa: 0.0
#
# Epoch 00008: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[28  0  0]
#  [ 7  0  0]
#  [17  0  0]]
# Epoch 9/50
# 9/9 [==============================] - 18s 2s/step - loss: 1.0602 - acc: 0.5436 - binary_accuracy: 0.6667 - mean_absolute_error: 0.4360 - loss_no_weight_decay: 1.0602 - val_loss: 1.0470 - val_acc: 0.6250 - val_binary_accuracy: 0.6667 - val_mean_absolute_error: 0.4312 - val_loss_no_weight_decay: 1.0470
# — val_kappa: 0.0
#
# Epoch 00009: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[26  0  0]
#  [ 6  0  0]
#  [20  0  0]]
# Epoch 10/50
# 9/9 [==============================] - 18s 2s/step - loss: 1.0625 - acc: 0.5383 - binary_accuracy: 0.6684 - mean_absolute_error: 0.4306 - loss_no_weight_decay: 1.0625 - val_loss: 0.9826 - val_acc: 0.6154 - val_binary_accuracy: 0.6987 - val_mean_absolute_error: 0.4109 - val_loss_no_weight_decay: 0.9826
# — val_kappa: 0.10152284263959388
#
# Epoch 00010: val_kappa improved from 0.00000 to 0.10152, saving model to base_2020-05-09-18-12-09-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[29  0  0]
#  [ 4  0  0]
#  [19  0  0]]
# Epoch 11/50
# 9/9 [==============================] - 18s 2s/step - loss: 1.0168 - acc: 0.5563 - binary_accuracy: 0.6964 - mean_absolute_error: 0.4172 - loss_no_weight_decay: 1.0168 - val_loss: 1.0735 - val_acc: 0.4219 - val_binary_accuracy: 0.6823 - val_mean_absolute_error: 0.4117 - val_loss_no_weight_decay: 1.0735
# — val_kappa: 0.3433476394849786
#
# Epoch 00011: val_kappa improved from 0.10152 to 0.34335, saving model to base_2020-05-09-18-12-09-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[26  0  0]
#  [ 4  0  0]
#  [22  0  0]]
# Epoch 12/50
# 9/9 [==============================] - 18s 2s/step - loss: 1.0346 - acc: 0.4845 - binary_accuracy: 0.7051 - mean_absolute_error: 0.4124 - loss_no_weight_decay: 1.0346 - val_loss: 1.0615 - val_acc: 0.4038 - val_binary_accuracy: 0.6923 - val_mean_absolute_error: 0.4270 - val_loss_no_weight_decay: 1.0615
# — val_kappa: 0.13658536585365855
#
# Epoch 00012: val_kappa did not improve from 0.34335
# Confusion matrix:
#  [[31  0  0]
#  [ 2  2  0]
#  [15  2  0]]
# Epoch 13/50
# 9/9 [==============================] - 20s 2s/step - loss: 0.9536 - acc: 0.5312 - binary_accuracy: 0.7222 - mean_absolute_error: 0.3951 - loss_no_weight_decay: 0.9536 - val_loss: 0.9828 - val_acc: 0.5469 - val_binary_accuracy: 0.7188 - val_mean_absolute_error: 0.3915 - val_loss_no_weight_decay: 0.9828
# — val_kappa: 0.4260869565217391
#
# Epoch 00013: val_kappa improved from 0.34335 to 0.42609, saving model to base_2020-05-09-18-12-09-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[27  0  1]
#  [ 5  0  0]
#  [14  1  4]]
# Epoch 14/50
# 9/9 [==============================] - 20s 2s/step - loss: 0.9518 - acc: 0.5774 - binary_accuracy: 0.7327 - mean_absolute_error: 0.3800 - loss_no_weight_decay: 0.9518 - val_loss: 0.8248 - val_acc: 0.7308 - val_binary_accuracy: 0.7949 - val_mean_absolute_error: 0.3563 - val_loss_no_weight_decay: 0.8248
# — val_kappa: 0.3119266055045873
#
# Epoch 00014: val_kappa did not improve from 0.42609
# Confusion matrix:
#  [[27  0  0]
#  [ 5  1  0]
#  [16  1  2]]
# Epoch 15/50
# 9/9 [==============================] - 18s 2s/step - loss: 0.9537 - acc: 0.5416 - binary_accuracy: 0.7487 - mean_absolute_error: 0.3726 - loss_no_weight_decay: 0.9537 - val_loss: 0.9434 - val_acc: 0.5938 - val_binary_accuracy: 0.7031 - val_mean_absolute_error: 0.3888 - val_loss_no_weight_decay: 0.9434
# — val_kappa: 0.19999999999999996
#
# Epoch 00015: val_kappa did not improve from 0.42609
# Confusion matrix:
#  [[30  1  0]
#  [ 5  0  0]
#  [15  1  0]]
# Epoch 16/50
# 9/9 [==============================] - 16s 2s/step - loss: 0.8256 - acc: 0.6377 - binary_accuracy: 0.7479 - mean_absolute_error: 0.3599 - loss_no_weight_decay: 0.8256 - val_loss: 0.7720 - val_acc: 0.6731 - val_binary_accuracy: 0.7756 - val_mean_absolute_error: 0.3247 - val_loss_no_weight_decay: 0.7720
# — val_kappa: 0.46153846153846145
#
# Epoch 00016: val_kappa improved from 0.42609 to 0.46154, saving model to base_2020-05-09-18-12-09-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[24  0  0]
#  [ 9  0  0]
#  [18  1  0]]
# Epoch 17/50
# 9/9 [==============================] - 20s 2s/step - loss: 0.8968 - acc: 0.6476 - binary_accuracy: 0.7546 - mean_absolute_error: 0.3433 - loss_no_weight_decay: 0.8968 - val_loss: 0.9097 - val_acc: 0.5781 - val_binary_accuracy: 0.7500 - val_mean_absolute_error: 0.3703 - val_loss_no_weight_decay: 0.9097
# — val_kappa: 0.5374449339207048
#
# Epoch 00017: val_kappa improved from 0.46154 to 0.53744, saving model to base_2020-05-09-18-12-09-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[24  0  0]
#  [ 4  2  0]
#  [17  4  1]]
# Epoch 18/50
# 9/9 [==============================] - 18s 2s/step - loss: 0.8543 - acc: 0.6117 - binary_accuracy: 0.7489 - mean_absolute_error: 0.3430 - loss_no_weight_decay: 0.8543 - val_loss: 0.8447 - val_acc: 0.6346 - val_binary_accuracy: 0.7885 - val_mean_absolute_error: 0.3362 - val_loss_no_weight_decay: 0.8447
# — val_kappa: 0.3275862068965517
#
# Epoch 00018: val_kappa did not improve from 0.53744
# Confusion matrix:
#  [[29  1  2]
#  [ 1  2  0]
#  [13  1  3]]
# Epoch 19/50
# 9/9 [==============================] - 18s 2s/step - loss: 0.8907 - acc: 0.6157 - binary_accuracy: 0.7451 - mean_absolute_error: 0.3492 - loss_no_weight_decay: 0.8907 - val_loss: 0.7484 - val_acc: 0.7969 - val_binary_accuracy: 0.7604 - val_mean_absolute_error: 0.3308 - val_loss_no_weight_decay: 0.7484
# — val_kappa: 0.42152466367713004
#
# Epoch 00019: val_kappa did not improve from 0.53744
# Confusion matrix:
#  [[24  0  0]
#  [ 5  1  0]
#  [18  2  2]]
# Epoch 20/50
# 9/9 [==============================] - 18s 2s/step - loss: 0.7965 - acc: 0.6611 - binary_accuracy: 0.7804 - mean_absolute_error: 0.3243 - loss_no_weight_decay: 0.7965 - val_loss: 0.8090 - val_acc: 0.7308 - val_binary_accuracy: 0.8397 - val_mean_absolute_error: 0.3254 - val_loss_no_weight_decay: 0.8090
# — val_kappa: 0.39495798319327724
#
# Epoch 00020: val_kappa did not improve from 0.53744
# Confusion matrix:
#  [[22  0  2]
#  [ 2  3  1]
#  [10  2 10]]
# Epoch 21/50
# 9/9 [==============================] - 18s 2s/step - loss: 0.7879 - acc: 0.6661 - binary_accuracy: 0.7786 - mean_absolute_error: 0.3188 - loss_no_weight_decay: 0.7879 - val_loss: 0.7219 - val_acc: 0.7031 - val_binary_accuracy: 0.7812 - val_mean_absolute_error: 0.3055 - val_loss_no_weight_decay: 0.7219
# — val_kappa: 0.5432098765432098
#
# Epoch 00021: val_kappa improved from 0.53744 to 0.54321, saving model to base_2020-05-09-18-12-09-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[20  0  1]
#  [ 5  4  0]
#  [15  3  4]]
# Epoch 22/50
# 9/9 [==============================] - 18s 2s/step - loss: 0.7645 - acc: 0.6841 - binary_accuracy: 0.7933 - mean_absolute_error: 0.3056 - loss_no_weight_decay: 0.7645 - val_loss: 0.8062 - val_acc: 0.6154 - val_binary_accuracy: 0.8141 - val_mean_absolute_error: 0.3348 - val_loss_no_weight_decay: 0.8062
# — val_kappa: 0.3157894736842104
#
# Epoch 00022: val_kappa did not improve from 0.54321
# Confusion matrix:
#  [[26  1  0]
#  [ 5  4  0]
#  [12  1  3]]
# Epoch 23/50
# 9/9 [==============================] - 18s 2s/step - loss: 0.8201 - acc: 0.6518 - binary_accuracy: 0.7762 - mean_absolute_error: 0.3178 - loss_no_weight_decay: 0.8201 - val_loss: 0.6801 - val_acc: 0.7188 - val_binary_accuracy: 0.8125 - val_mean_absolute_error: 0.2993 - val_loss_no_weight_decay: 0.6801
# — val_kappa: 0.48275862068965514
#
# Epoch 00023: val_kappa did not improve from 0.54321
# Confusion matrix:
#  [[26  0  0]
#  [ 3  3  0]
#  [12  1  7]]
# Epoch 24/50
# 9/9 [==============================] - 18s 2s/step - loss: 0.7670 - acc: 0.6666 - binary_accuracy: 0.7836 - mean_absolute_error: 0.3081 - loss_no_weight_decay: 0.7670 - val_loss: 0.6490 - val_acc: 0.7692 - val_binary_accuracy: 0.8654 - val_mean_absolute_error: 0.2874 - val_loss_no_weight_decay: 0.6490
# — val_kappa: 0.510460251046025
#
# Epoch 00024: val_kappa did not improve from 0.54321
# Confusion matrix:
#  [[18  1  4]
#  [ 1  5  1]
#  [ 4  8 10]]
# Epoch 25/50
# 9/9 [==============================] - 18s 2s/step - loss: 0.7100 - acc: 0.7072 - binary_accuracy: 0.8049 - mean_absolute_error: 0.2883 - loss_no_weight_decay: 0.7100 - val_loss: 0.7313 - val_acc: 0.6875 - val_binary_accuracy: 0.7812 - val_mean_absolute_error: 0.3082 - val_loss_no_weight_decay: 0.7313
# — val_kappa: 0.5224489795918368
#
# Epoch 00025: val_kappa did not improve from 0.54321
# Confusion matrix:
#  [[18  3  4]
#  [ 3  2  1]
#  [ 7  6  8]]
# Epoch 26/50
# 9/9 [==============================] - 19s 2s/step - loss: 0.6799 - acc: 0.6997 - binary_accuracy: 0.8073 - mean_absolute_error: 0.2715 - loss_no_weight_decay: 0.6799 - val_loss: 0.5859 - val_acc: 0.7692 - val_binary_accuracy: 0.8333 - val_mean_absolute_error: 0.2640 - val_loss_no_weight_decay: 0.5859
# — val_kappa: 0.6887966804979253
#
# Epoch 00026: val_kappa improved from 0.54321 to 0.68880, saving model to base_2020-05-09-18-12-09-val_kapa_checkpoint.hdf5
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Confusion matrix:
#  [[24  0  2]
#  [ 1  3  2]
#  [10  2  8]]
# Epoch 27/50
# 9/9 [==============================] - 16s 2s/step - loss: 0.6210 - acc: 0.7529 - binary_accuracy: 0.8412 - mean_absolute_error: 0.2507 - loss_no_weight_decay: 0.6210 - val_loss: 0.6970 - val_acc: 0.6250 - val_binary_accuracy: 0.7708 - val_mean_absolute_error: 0.2595 - val_loss_no_weight_decay: 0.6970
# — val_kappa: 0.49795918367346936
#
# Epoch 00027: val_kappa did not improve from 0.68880
# Confusion matrix:
#  [[26  0  1]
#  [ 3  4  0]
#  [14  1  3]]
# Epoch 28/50
# 9/9 [==============================] - 19s 2s/step - loss: 0.6452 - acc: 0.7118 - binary_accuracy: 0.8212 - mean_absolute_error: 0.2606 - loss_no_weight_decay: 0.6452 - val_loss: 0.6074 - val_acc: 0.7692 - val_binary_accuracy: 0.8141 - val_mean_absolute_error: 0.2671 - val_loss_no_weight_decay: 0.6074
# — val_kappa: 0.5991902834008097
#
# Epoch 00028: val_kappa did not improve from 0.68880
# Confusion matrix:
#  [[20  1  4]
#  [ 3  4  1]
#  [ 5  2 12]]
# Epoch 29/50
# 9/9 [==============================] - 18s 2s/step - loss: 0.5782 - acc: 0.7635 - binary_accuracy: 0.8495 - mean_absolute_error: 0.2314 - loss_no_weight_decay: 0.5782 - val_loss: 0.7424 - val_acc: 0.6094 - val_binary_accuracy: 0.7865 - val_mean_absolute_error: 0.2917 - val_loss_no_weight_decay: 0.7424
# — val_kappa: 0.6419753086419753
#
# Epoch 00029: val_kappa did not improve from 0.68880
# Confusion matrix:
#  [[20  1  6]
#  [ 0  5  0]
#  [ 2  9  9]]
# Epoch 30/50
# 9/9 [==============================] - 18s 2s/step - loss: 0.5907 - acc: 0.7450 - binary_accuracy: 0.8347 - mean_absolute_error: 0.2411 - loss_no_weight_decay: 0.5907 - val_loss: 0.6909 - val_acc: 0.7885 - val_binary_accuracy: 0.8590 - val_mean_absolute_error: 0.2625 - val_loss_no_weight_decay: 0.6909
# — val_kappa: 0.5506072874493927
#
# Epoch 00030: val_kappa did not improve from 0.68880
# Confusion matrix:
#  [[18  1  4]
#  [ 1  4  0]
#  [ 4  3 17]]
# Epoch 31/50
# 9/9 [==============================] - 18s 2s/step - loss: 0.5540 - acc: 0.7568 - binary_accuracy: 0.8442 - mean_absolute_error: 0.2240 - loss_no_weight_decay: 0.5540 - val_loss: 0.5339 - val_acc: 0.7812 - val_binary_accuracy: 0.8490 - val_mean_absolute_error: 0.2289 - val_loss_no_weight_decay: 0.5339
# — val_kappa: 0.6294820717131475
#
# Epoch 00031: val_kappa did not improve from 0.68880
# Confusion matrix:
#  [[22  1  4]
#  [ 0  2  0]
#  [ 6  4 13]]
# Epoch 32/50
# 9/9 [==============================] - 18s 2s/step - loss: 0.5613 - acc: 0.7668 - binary_accuracy: 0.8545 - mean_absolute_error: 0.2251 - loss_no_weight_decay: 0.5613 - val_loss: 0.5839 - val_acc: 0.7308 - val_binary_accuracy: 0.8141 - val_mean_absolute_error: 0.2440 - val_loss_no_weight_decay: 0.5839
# — val_kappa: 0.6024096385542168
#
# Epoch 00032: val_kappa did not improve from 0.68880
# Confusion matrix:
#  [[22  1  1]
#  [ 0  5  2]
#  [ 7  3 11]]
# Epoch 33/50
# 9/9 [==============================] - 18s 2s/step - loss: 0.5478 - acc: 0.7933 - binary_accuracy: 0.8611 - mean_absolute_error: 0.2231 - loss_no_weight_decay: 0.5478 - val_loss: 0.6147 - val_acc: 0.7188 - val_binary_accuracy: 0.8177 - val_mean_absolute_error: 0.2386 - val_loss_no_weight_decay: 0.6147
# — val_kappa: 0.568
#
# Epoch 00033: val_kappa did not improve from 0.68880
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Confusion matrix:
#  [[22  0  5]
#  [ 1  3  3]
#  [ 1  2 15]]
# Epoch 34/50
# 9/9 [==============================] - 19s 2s/step - loss: 0.5287 - acc: 0.7656 - binary_accuracy: 0.8461 - mean_absolute_error: 0.2188 - loss_no_weight_decay: 0.5287 - val_loss: 0.5364 - val_acc: 0.7885 - val_binary_accuracy: 0.8590 - val_mean_absolute_error: 0.2261 - val_loss_no_weight_decay: 0.5364
# — val_kappa: 0.6533864541832669
#
# Epoch 00034: val_kappa did not improve from 0.68880
# Confusion matrix:
#  [[19  1  3]
#  [ 0  3  3]
#  [ 4  5 14]]
# Epoch 35/50
# 9/9 [==============================] - 16s 2s/step - loss: 0.5329 - acc: 0.7824 - binary_accuracy: 0.8644 - mean_absolute_error: 0.2132 - loss_no_weight_decay: 0.5329 - val_loss: 0.6087 - val_acc: 0.7969 - val_binary_accuracy: 0.8385 - val_mean_absolute_error: 0.2525 - val_loss_no_weight_decay: 0.6087
# — val_kappa: 0.5919999999999999
#
# Epoch 00035: val_kappa did not improve from 0.68880
# Confusion matrix:
#  [[22  1  8]
#  [ 0  3  0]
#  [ 1  4 13]]
# Epoch 36/50
# 9/9 [==============================] - 18s 2s/step - loss: 0.4852 - acc: 0.8159 - binary_accuracy: 0.8808 - mean_absolute_error: 0.1994 - loss_no_weight_decay: 0.4852 - val_loss: 0.5335 - val_acc: 0.7308 - val_binary_accuracy: 0.8269 - val_mean_absolute_error: 0.2308 - val_loss_no_weight_decay: 0.5335
# — val_kappa: 0.5952380952380953
#
# Epoch 00036: val_kappa did not improve from 0.68880
# Confusion matrix:
#  [[25  1  3]
#  [ 1  3  4]
#  [ 4  1 10]]
# Epoch 37/50
# 9/9 [==============================] - 19s 2s/step - loss: 0.5482 - acc: 0.7309 - binary_accuracy: 0.8299 - mean_absolute_error: 0.2190 - loss_no_weight_decay: 0.5482 - val_loss: 0.5112 - val_acc: 0.7812 - val_binary_accuracy: 0.8646 - val_mean_absolute_error: 0.2101 - val_loss_no_weight_decay: 0.5112
# — val_kappa: 0.6823529411764706
#
# Epoch 00037: val_kappa did not improve from 0.68880
# Confusion matrix:
#  [[18  0  5]
#  [ 0  2  4]
#  [ 5  2 16]]
# Epoch 38/50
# 9/9 [==============================] - 18s 2s/step - loss: 0.5212 - acc: 0.7831 - binary_accuracy: 0.8647 - mean_absolute_error: 0.2124 - loss_no_weight_decay: 0.5212 - val_loss: 0.7214 - val_acc: 0.7308 - val_binary_accuracy: 0.8013 - val_mean_absolute_error: 0.2448 - val_loss_no_weight_decay: 0.7214
# — val_kappa: 0.6456692913385826
#
# Epoch 00038: val_kappa did not improve from 0.68880
# Confusion matrix:
#  [[23  0  4]
#  [ 0  2  5]
#  [ 3  3 12]]
# Epoch 39/50
# 9/9 [==============================] - 18s 2s/step - loss: 0.5285 - acc: 0.7800 - binary_accuracy: 0.8649 - mean_absolute_error: 0.2016 - loss_no_weight_decay: 0.5285 - val_loss: 0.6521 - val_acc: 0.7031 - val_binary_accuracy: 0.8125 - val_mean_absolute_error: 0.2466 - val_loss_no_weight_decay: 0.6521
# — val_kappa: 0.5577689243027889
#
# Epoch 00039: val_kappa did not improve from 0.68880
# Confusion matrix:
#  [[27  0  2]
#  [ 0  5  2]
#  [ 2  5  9]]
# Epoch 40/50
# 9/9 [==============================] - 18s 2s/step - loss: 0.4735 - acc: 0.7931 - binary_accuracy: 0.8726 - mean_absolute_error: 0.1979 - loss_no_weight_decay: 0.4735 - val_loss: 0.5359 - val_acc: 0.6923 - val_binary_accuracy: 0.8013 - val_mean_absolute_error: 0.2202 - val_loss_no_weight_decay: 0.5359
# — val_kappa: 0.5375494071146245
#
# Epoch 00040: val_kappa did not improve from 0.68880
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Confusion matrix:
#  [[28  1  2]
#  [ 1  2  2]
#  [ 1  3 12]]
# Epoch 41/50
# 9/9 [==============================] - 18s 2s/step - loss: 0.4990 - acc: 0.7851 - binary_accuracy: 0.8672 - mean_absolute_error: 0.2060 - loss_no_weight_decay: 0.4990 - val_loss: 0.4682 - val_acc: 0.7500 - val_binary_accuracy: 0.8490 - val_mean_absolute_error: 0.2097 - val_loss_no_weight_decay: 0.4682
# — val_kappa: 0.5952380952380953
#
# Epoch 00041: val_kappa did not improve from 0.68880
# Confusion matrix:
#  [[26  0  2]
#  [ 0  2  2]
#  [ 5  3 12]]
# Epoch 42/50
# 9/9 [==============================] - 18s 2s/step - loss: 0.5542 - acc: 0.7575 - binary_accuracy: 0.8442 - mean_absolute_error: 0.2164 - loss_no_weight_decay: 0.5542 - val_loss: 0.5514 - val_acc: 0.8077 - val_binary_accuracy: 0.8590 - val_mean_absolute_error: 0.2034 - val_loss_no_weight_decay: 0.5514
# — val_kappa: 0.7058823529411765
#
# Epoch 00042: val_kappa improved from 0.68880 to 0.70588, saving model to base_2020-05-09-18-12-09-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[21  0  3]
#  [ 0  2  4]
#  [ 3  4 15]]
# Epoch 43/50
# 9/9 [==============================] - 18s 2s/step - loss: 0.5139 - acc: 0.7730 - binary_accuracy: 0.8573 - mean_absolute_error: 0.2066 - loss_no_weight_decay: 0.5139 - val_loss: 0.5866 - val_acc: 0.7656 - val_binary_accuracy: 0.8385 - val_mean_absolute_error: 0.2323 - val_loss_no_weight_decay: 0.5866
# — val_kappa: 0.6456692913385826
#
# Epoch 00043: val_kappa did not improve from 0.70588
# Confusion matrix:
#  [[25  0  4]
#  [ 1  1  1]
#  [ 2  4 14]]
# Epoch 44/50
# 9/9 [==============================] - 19s 2s/step - loss: 0.4449 - acc: 0.7986 - binary_accuracy: 0.8727 - mean_absolute_error: 0.1900 - loss_no_weight_decay: 0.4449 - val_loss: 0.5798 - val_acc: 0.7500 - val_binary_accuracy: 0.8397 - val_mean_absolute_error: 0.2318 - val_loss_no_weight_decay: 0.5798
# — val_kappa: 0.5919999999999999
#
# Epoch 00044: val_kappa did not improve from 0.70588
# Confusion matrix:
#  [[24  0  1]
#  [ 0  2  4]
#  [ 3  5 13]]
# Epoch 45/50
# 9/9 [==============================] - 18s 2s/step - loss: 0.4887 - acc: 0.8111 - binary_accuracy: 0.8828 - mean_absolute_error: 0.1968 - loss_no_weight_decay: 0.4887 - val_loss: 0.5674 - val_acc: 0.7031 - val_binary_accuracy: 0.8281 - val_mean_absolute_error: 0.2222 - val_loss_no_weight_decay: 0.5674
# — val_kappa: 0.6190476190476191
#
# Epoch 00045: val_kappa did not improve from 0.70588
# Confusion matrix:
#  [[18  1  2]
#  [ 0  3  3]
#  [ 3  4 18]]
# Epoch 46/50
# 9/9 [==============================] - 18s 2s/step - loss: 0.4963 - acc: 0.7901 - binary_accuracy: 0.8560 - mean_absolute_error: 0.2018 - loss_no_weight_decay: 0.4963 - val_loss: 0.5102 - val_acc: 0.7885 - val_binary_accuracy: 0.8590 - val_mean_absolute_error: 0.2046 - val_loss_no_weight_decay: 0.5102
# — val_kappa: 0.6588235294117646
#
# Epoch 00046: val_kappa did not improve from 0.70588
# Confusion matrix:
#  [[22  1  4]
#  [ 0  4  2]
#  [ 4  3 12]]
# Epoch 47/50
# 9/9 [==============================] - 16s 2s/step - loss: 0.4554 - acc: 0.8079 - binary_accuracy: 0.8784 - mean_absolute_error: 0.1925 - loss_no_weight_decay: 0.4554 - val_loss: 0.5778 - val_acc: 0.7344 - val_binary_accuracy: 0.8281 - val_mean_absolute_error: 0.2226 - val_loss_no_weight_decay: 0.5778
# — val_kappa: 0.5476190476190476
#
# Epoch 00047: val_kappa did not improve from 0.70588
# Confusion matrix:
#  [[22  1  2]
#  [ 0  3  1]
#  [ 5  5 13]]
# Epoch 48/50
# 9/9 [==============================] - 19s 2s/step - loss: 0.4954 - acc: 0.7969 - binary_accuracy: 0.8652 - mean_absolute_error: 0.1938 - loss_no_weight_decay: 0.4954 - val_loss: 0.6431 - val_acc: 0.7115 - val_binary_accuracy: 0.8269 - val_mean_absolute_error: 0.2265 - val_loss_no_weight_decay: 0.6431
# — val_kappa: 0.765625
#
# Epoch 00048: val_kappa improved from 0.70588 to 0.76562, saving model to base_2020-05-09-18-12-09-val_kapa_checkpoint.hdf5
# Confusion matrix:
#  [[22  1  7]
#  [ 0  2  2]
#  [ 2  4 12]]
# Epoch 49/50
# 9/9 [==============================] - 18s 2s/step - loss: 0.4595 - acc: 0.8146 - binary_accuracy: 0.8822 - mean_absolute_error: 0.1889 - loss_no_weight_decay: 0.4595 - val_loss: 0.4509 - val_acc: 0.8125 - val_binary_accuracy: 0.8646 - val_mean_absolute_error: 0.1975 - val_loss_no_weight_decay: 0.4509
# — val_kappa: 0.5577689243027889
#
# Epoch 00049: val_kappa did not improve from 0.76562
# Confusion matrix:
#  [[25  1  3]
#  [ 0  5  2]
#  [ 1  3 12]]
# Epoch 50/50
# 9/9 [==============================] - 18s 2s/step - loss: 0.5188 - acc: 0.7763 - binary_accuracy: 0.8550 - mean_absolute_error: 0.2137 - loss_no_weight_decay: 0.5188 - val_loss: 0.7043 - val_acc: 0.7115 - val_binary_accuracy: 0.8077 - val_mean_absolute_error: 0.2439 - val_loss_no_weight_decay: 0.7043
# — val_kappa: 0.6666666666666667
#
# Epoch 00050: val_kappa did not improve from 0.76562
# Confusion matrix:
#  [[23  1  4]
#  [ 0  6  1]
#  [ 2  5 10]]
# 176/176 [==============================] - 5s 26ms/step
# 176/176 [==============================] - 5s 27ms/step
# Test loss: 0.6035645572060275
# Test accuracy: 0.7215909090909091
# Confusion Matrix
# [[76  0 12]
#  [ 2 11  6]
#  [11 21 37]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.85      0.86      0.86        88
#            1       0.34      0.58      0.43        19
#            2       0.67      0.54      0.60        69
#
#     accuracy                           0.70       176
#    macro avg       0.62      0.66      0.63       176
# weighted avg       0.73      0.70      0.71       176

# %%
from Kappa_Skl import kappa
def kappa2(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    if len(y_true.shape) > 1 and y_true.shape[1] > 1:
        y_true = y_true.dot(range(y_true.shape[1]))
    if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
        y_pred = y_pred.dot(range(y_pred.shape[1]))
    try:
        return kappa(y_true, y_pred, weights='quadratic')
    except IndexError:
        return np.nan
    
print('Quadratic_wieghted_kappa')
print(kappa2(y_true, y_pred))
# Out:
# Quadratic_wieghted_kappa
# 0.5879575884219488

# %%
import numpy as np 
import matplotlib.pyplot as plt
import os
import wandb
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model loss.png')

# summarize history for val_kappa
plt.plot(history.history['val_kappa'])
plt.title('Validation_Kappa')
plt.ylabel('val_kappa')
plt.xlabel('epoch')
plt.legend([ 'validation'], loc='upper left')
plt.show()
#plt.savefig('model validation_kappa.png')

# summarize history for mean_absolute _error
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model mean_absolute_error')
plt.ylabel('mean_absolute_error')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model maey.png'
# Out:
# dict_keys(['val_loss', 'val_acc', 'val_binary_accuracy', 'val_mean_absolute_error', 'val_loss_no_weight_decay', 'loss', 'acc', 'binary_accuracy', 'mean_absolute_error', 'loss_no_weight_decay', 'val_kappa', 'lr'])
