# %%
import efficientnet.keras as efn
from keras.models import Model, model_from_json
from keras.regularizers import l1_l2
from keras.layers import Dense, Dropout
from keras.optimizers import SGD, Adam
import pandas as pd
from keras_preprocessing.image import ImageDataGenerator
from datetime import datetime as dt
from sklearn.utils import class_weight
from keras.callbacks import EarlyStopping, ModelCheckpoint,LearningRateScheduler, TensorBoard
import keras.backend as K
from VCM import VCM 
from keras.initializers import Constant,Orthogonal
from keras import regularizers
from Kappa_Skl import kappa
import keras.backend as K
import matplotlib.pyplot as plt
import itertools
from Homotopy import Homotopy 
from QWK import QWK
import tensorflow as tf
from Fractional_MAXPOOL import FractionalPooling2D

import numpy as np 
import matplotlib.pyplot as plt
import os
import wandb
#from wandb.keras import WandbCallback
#wandb.init(project="rop")


top_layers_checkpoint_path = 'cp.top.best.hdf5'
fine_tuned_checkpoint_path = 'cp.fine_tuned.best.hdf5'
new_extended_inception_weights = 'final_weights.hdf5'





def get_experiment_id():
    time_str = dt.now().strftime('%Y-%m-%d-%H-%M-%S')
    experiment_id = 'base_{}'.format(time_str)
    return experiment_id

#def scheduler(epoch):
#    if epoch == 150:
#        K.set_value(model.optimizer.lr, 0.00003)
#    return K.get_value(model.optimizer.lr)


def create_model():
    base_model = efn.EfficientNetB0(weights=None,
                        include_top=False,
                        input_shape=(128, 128, 3), pooling='avg')
#    base_model._layers.pop()
#    model2 = Model(base_model.input, base_model.layers[-1].output)
##    base_model = InceptionV3(weights=None , include_top=False, input_tensor=None, input_shape=(299, 299, 3), pooling='avg') 
    x = base_model.output
    x = Dense(2, activation="softmax")(x)
    model = Model(inputs = base_model.input, outputs = x)
    model.load_weights('base_2019-12-11-23-01-58-val_kappa_checkpoint.hdf5')
#    model._layers.pop()
#    x = Model(model.input, model.layers[-1].output)
#    model.save_weights("tmp.h5")
#    top_layers_checkpoint_path = 'cp.top.best.hdf5'

#    # first: train only the top layers (which were randomly initialized)
#    # i.e. freeze all convolutional InceptionV3 layers
    for layer in base_model.layers:
        layer.trainable = False
#    
#    
#
##    regularizer = l1_l2(l1=0.0005, l2=0.0005)
##    for layer in model.layers:
##        for attr in ['kernel_regularizer', 'bias_regularizer']:
##            if hasattr(layer, attr) and layer.trainable:
##                setattr(layer, attr, regularizer)
#
##
#    out = model_from_json(model.to_json())
#    out.load_weights("tmp.h5", by_name=True)
#
    return model


model = create_model()




radam = Adam(lr=0.0014339, beta_1=0.9, beta_2=0.999, epsilon=0.1, decay=1e-6, amsgrad=False)
model.compile(loss='categorical_crossentropy', optimizer=radam, metrics=['mae','acc'])

#sgd = SGD(lr=0.0003, decay=1e-6, momentum=0.9, nesterov=True)
#model.compile(loss='mse', optimizer=sgd, metrics=['mae', 'acc'])

experiment_id = get_experiment_id()


train_datagen = ImageDataGenerator(
        rescale=1./255,
#        featurewise_center=True,
 #       samplewise_center=True,
        shear_range=0,
        zoom_range=0.0,#[1 / 1.15, 1.15],
        horizontal_flip=False,#True,
        rotation_range=0)#90,
#        validation_split=0.2)
"""
For the test set only rescale should be made 
"""
test_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_class_treatment_noch/train",
    target_size=(128, 128),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="training")
#    save_to_dir="D:/Separating Images into subfolders/train_augmented")


#print(train_generator.class_indices)

valid_generator = valid_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_class_treatment_noch/vald",
    target_size=(128, 128),
    color_mode="rgb",
    batch_size=1,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="validation")
#    save_to_dir="D:/Separating Images into subfolders/val_augmented"


test_generator = test_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_class_treatment_noch/test",
    target_size=(128, 128),
    color_mode="rgb",
    batch_size=1,
    class_mode="categorical",
    shuffle=False,
    seed=42)
#    save_to_dir="D:/Separating Images into subfolders/test_augmented")


# Fitting/Training the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
experiment_id = get_experiment_id()


class_weight_list = class_weight.compute_class_weight('balanced', np.unique(train_generator.classes), train_generator.classes)
class_weights = dict(zip(np.unique(train_generator.classes), class_weight_list))

callbacks = [
#    Resample_Iterator(balance_weights),
   # QWK(valid_generator, STEP_SIZE_VALID),
    ModelCheckpoint(top_layers_checkpoint_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max'),
#    EarlyStopping(monitor='val_kappa', patience=10, min_delta=0.001, verbose=1, restore_best_weights=True, mode='max',baseline=None),
    VCM(valid_generator, STEP_SIZE_VALID),
#    LearningRateScheduler(scheduler, verbose=1),
 #   TensorBoard(log_dir='./Graph', histogram_freq=0, write_graph=True, write_images=True),        
]




# train the model on the new data for a few epochs

history1=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
#                    class_weight=[balance_weights],
                    callbacks=callbacks,
                    epochs=10  
)


 

callbacks1 = [
#    Resample_Iterator(balance_weights1),
    #QWK(valid_generator, STEP_SIZE_VALID),
    ModelCheckpoint(fine_tuned_checkpoint_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max'),
    EarlyStopping(monitor='val_acc', patience=7, min_delta=0.001, verbose=1, restore_best_weights=True, mode='max',baseline=None),
    VCM(valid_generator, STEP_SIZE_VALID),
#    LearningRateScheduler(scheduler, verbose=1),
#    TensorBoard(log_dir='./Graph', histogram_freq=0, write_graph=True, write_images=True),        
]



for layer in model.layers:
    layer.trainable = True
    
    
    
    
radam = Adam(lr=0.0014339, beta_1=0.9, beta_2=0.999, epsilon=0.1, decay=1e-6, amsgrad=False)
model.compile(loss='categorical_crossentropy', optimizer=radam, metrics=['mae','acc'])



# we train our model again (this time fine-tuning the top 2 inception blocks
# alongside the top Dense layers
history=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
#                    class_weight=[balance_weights1],
                    callbacks=callbacks1,
                    epochs=30) 




test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test mae:', score[1])
print('Test accuracy:', score[2])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1']
print(classification_report(y_true, y_pred, target_names=target_names))
                    
                    
# list all data in history
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model loss.png')

# summarize history for val_kappa
plt.plot(history.history['val_kappa'])
plt.title('Validation_Kappa')
plt.ylabel('val_kappa')
plt.xlabel('epoch')
plt.legend([ 'validation'], loc='upper left')
plt.show()
#plt.savefig('model validation_kappa.png')

# summarize history for mean_absolute _error
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model mean_absolute_error')
plt.ylabel('mean_absolute_error')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model maey.png')
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Found 285 images belonging to 2 classes.
# Found 23 images belonging to 2 classes.
# Found 33 images belonging to 2 classes.
# Epoch 1/10
# 4/4 [==============================] - 4s 931ms/step - loss: 1.6807 - mean_absolute_error: 0.6824 - acc: 0.2445 - val_loss: 1.0847 - val_mean_absolute_error: 0.5955 - val_acc: 0.3478
#
# Epoch 00001: val_acc improved from -inf to 0.34783, saving model to cp.top.best.hdf5
# Confusion matrix:
#  [[ 3  2]
#  [13  5]]
# Epoch 2/10
# 4/4 [==============================] - 1s 230ms/step - loss: 1.7007 - mean_absolute_error: 0.6841 - acc: 0.2578 - val_loss: 1.0385 - val_mean_absolute_error: 0.6076 - val_acc: 0.2609
#
# Epoch 00002: val_acc did not improve from 0.34783
# Confusion matrix:
#  [[ 3  3]
#  [12  5]]
# Epoch 3/10
# 4/4 [==============================] - 1s 178ms/step - loss: 1.5905 - mean_absolute_error: 0.6483 - acc: 0.3118 - val_loss: 1.0508 - val_mean_absolute_error: 0.5882 - val_acc: 0.3913
#
# Epoch 00003: val_acc improved from 0.34783 to 0.39130, saving model to cp.top.best.hdf5
# Confusion matrix:
#  [[ 3  2]
#  [12  6]]
# Epoch 4/10
# 4/4 [==============================] - 1s 160ms/step - loss: 1.5174 - mean_absolute_error: 0.6563 - acc: 0.2803 - val_loss: 1.0825 - val_mean_absolute_error: 0.5974 - val_acc: 0.3913
#
# Epoch 00004: val_acc did not improve from 0.39130
# Confusion matrix:
#  [[ 3  3]
#  [11  6]]
# Epoch 5/10
# 4/4 [==============================] - 0s 111ms/step - loss: 1.4098 - mean_absolute_error: 0.6350 - acc: 0.3357 - val_loss: 1.0094 - val_mean_absolute_error: 0.5779 - val_acc: 0.3913
#
# Epoch 00005: val_acc did not improve from 0.39130
# Confusion matrix:
#  [[ 3  2]
#  [12  6]]
# Epoch 6/10
# 4/4 [==============================] - 0s 108ms/step - loss: 1.3329 - mean_absolute_error: 0.6334 - acc: 0.3085 - val_loss: 0.9881 - val_mean_absolute_error: 0.5720 - val_acc: 0.3913
#
# Epoch 00006: val_acc did not improve from 0.39130
# Confusion matrix:
#  [[ 3  2]
#  [12  6]]
# Epoch 7/10
# 4/4 [==============================] - 1s 204ms/step - loss: 1.2170 - mean_absolute_error: 0.6017 - acc: 0.3599 - val_loss: 0.9678 - val_mean_absolute_error: 0.5658 - val_acc: 0.3913
#
# Epoch 00007: val_acc did not improve from 0.39130
# Confusion matrix:
#  [[ 2  3]
#  [10  8]]
# Epoch 8/10
# 4/4 [==============================] - 1s 185ms/step - loss: 1.0561 - mean_absolute_error: 0.5613 - acc: 0.4180 - val_loss: 0.9491 - val_mean_absolute_error: 0.5596 - val_acc: 0.4348
#
# Epoch 00008: val_acc improved from 0.39130 to 0.43478, saving model to cp.top.best.hdf5
# Confusion matrix:
#  [[ 2  3]
#  [10  8]]
# Epoch 9/10
# 4/4 [==============================] - 1s 173ms/step - loss: 1.0489 - mean_absolute_error: 0.5592 - acc: 0.4082 - val_loss: 1.0057 - val_mean_absolute_error: 0.5678 - val_acc: 0.4348
#
# Epoch 00009: val_acc did not improve from 0.43478
# Confusion matrix:
#  [[2 3]
#  [9 9]]
# Epoch 10/10
# 4/4 [==============================] - 0s 117ms/step - loss: 0.8944 - mean_absolute_error: 0.5197 - acc: 0.4319 - val_loss: 0.8749 - val_mean_absolute_error: 0.5322 - val_acc: 0.5217
#
# Epoch 00010: val_acc improved from 0.43478 to 0.52174, saving model to cp.top.best.hdf5
# Confusion matrix:
#  [[2 3]
#  [9 9]]
# Epoch 1/30
# 4/4 [==============================] - 12s 3s/step - loss: 0.8735 - mean_absolute_error: 0.5105 - acc: 0.4646 - val_loss: 0.9056 - val_mean_absolute_error: 0.5428 - val_acc: 0.3478
#
# Epoch 00001: val_acc improved from -inf to 0.34783, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  [[ 1  4]
#  [11  7]]
# Epoch 2/30
# 4/4 [==============================] - 1s 326ms/step - loss: 0.8470 - mean_absolute_error: 0.4976 - acc: 0.5233 - val_loss: 0.8509 - val_mean_absolute_error: 0.5236 - val_acc: 0.3478
#
# Epoch 00002: val_acc did not improve from 0.34783
# Confusion matrix:
#  [[1 5]
#  [9 8]]
# Epoch 3/30
# 4/4 [==============================] - 1s 360ms/step - loss: 0.7997 - mean_absolute_error: 0.4731 - acc: 0.5547 - val_loss: 0.7884 - val_mean_absolute_error: 0.5004 - val_acc: 0.3913
#
# Epoch 00003: val_acc improved from 0.34783 to 0.39130, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  [[ 1  4]
#  [10  8]]
# Epoch 4/30
# 4/4 [==============================] - 1s 324ms/step - loss: 0.7636 - mean_absolute_error: 0.4667 - acc: 0.5767 - val_loss: 0.7703 - val_mean_absolute_error: 0.4814 - val_acc: 0.3913
#
# Epoch 00004: val_acc did not improve from 0.39130
# Confusion matrix:
#  [[ 1  4]
#  [10  8]]
# Epoch 5/30
# 4/4 [==============================] - 1s 320ms/step - loss: 0.6982 - mean_absolute_error: 0.4412 - acc: 0.5875 - val_loss: 0.7258 - val_mean_absolute_error: 0.4763 - val_acc: 0.4783
#
# Epoch 00005: val_acc improved from 0.39130 to 0.47826, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  [[ 1  4]
#  [ 7 11]]
# Epoch 6/30
# 4/4 [==============================] - 1s 317ms/step - loss: 0.6444 - mean_absolute_error: 0.4203 - acc: 0.6359 - val_loss: 0.6836 - val_mean_absolute_error: 0.4613 - val_acc: 0.4783
#
# Epoch 00006: val_acc did not improve from 0.47826
# Confusion matrix:
#  [[ 1  4]
#  [ 7 11]]
# Epoch 7/30
# 4/4 [==============================] - 1s 365ms/step - loss: 0.6461 - mean_absolute_error: 0.4157 - acc: 0.6562 - val_loss: 0.6041 - val_mean_absolute_error: 0.4190 - val_acc: 0.6087
#
# Epoch 00007: val_acc improved from 0.47826 to 0.60870, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  [[ 2  3]
#  [ 6 12]]
# Epoch 8/30
# 4/4 [==============================] - 1s 333ms/step - loss: 0.5234 - mean_absolute_error: 0.3646 - acc: 0.7197 - val_loss: 0.4826 - val_mean_absolute_error: 0.3538 - val_acc: 0.6522
#
# Epoch 00008: val_acc improved from 0.60870 to 0.65217, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  [[ 2  3]
#  [ 6 12]]
# Epoch 9/30
# 4/4 [==============================] - 1s 352ms/step - loss: 0.5090 - mean_absolute_error: 0.3587 - acc: 0.7592 - val_loss: 0.6719 - val_mean_absolute_error: 0.4651 - val_acc: 0.5217
#
# Epoch 00009: val_acc did not improve from 0.65217
# Confusion matrix:
#  [[ 2  3]
#  [ 4 14]]
# Epoch 10/30
# 4/4 [==============================] - 1s 335ms/step - loss: 0.4959 - mean_absolute_error: 0.3508 - acc: 0.7683 - val_loss: 0.4547 - val_mean_absolute_error: 0.3382 - val_acc: 0.7826
#
# Epoch 00010: val_acc improved from 0.65217 to 0.78261, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  [[ 3  2]
#  [ 4 14]]
# Epoch 11/30
# 4/4 [==============================] - 2s 377ms/step - loss: 0.4405 - mean_absolute_error: 0.3202 - acc: 0.8008 - val_loss: 0.4128 - val_mean_absolute_error: 0.3068 - val_acc: 0.8261
#
# Epoch 00011: val_acc improved from 0.78261 to 0.82609, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  [[ 3  2]
#  [ 3 15]]
# Epoch 12/30
# 4/4 [==============================] - 1s 303ms/step - loss: 0.4159 - mean_absolute_error: 0.3038 - acc: 0.8484 - val_loss: 0.4344 - val_mean_absolute_error: 0.3251 - val_acc: 0.7826
#
# Epoch 00012: val_acc did not improve from 0.82609
# Confusion matrix:
#  [[ 3  2]
#  [ 3 15]]
# Epoch 13/30
# 4/4 [==============================] - 1s 364ms/step - loss: 0.3511 - mean_absolute_error: 0.2674 - acc: 0.8945 - val_loss: 0.4049 - val_mean_absolute_error: 0.3076 - val_acc: 0.7826
#
# Epoch 00013: val_acc did not improve from 0.82609
# Confusion matrix:
#  [[ 3  1]
#  [ 3 16]]
# Epoch 14/30
# 4/4 [==============================] - 1s 334ms/step - loss: 0.3687 - mean_absolute_error: 0.2748 - acc: 0.8721 - val_loss: 0.3798 - val_mean_absolute_error: 0.2920 - val_acc: 0.8696
#
# Epoch 00014: val_acc improved from 0.82609 to 0.86957, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  [[ 4  1]
#  [ 2 16]]
# Epoch 15/30
# 4/4 [==============================] - 1s 338ms/step - loss: 0.3378 - mean_absolute_error: 0.2595 - acc: 0.8605 - val_loss: 0.4321 - val_mean_absolute_error: 0.3261 - val_acc: 0.8261
#
# Epoch 00015: val_acc did not improve from 0.86957
# Confusion matrix:
#  [[ 4  1]
#  [ 1 17]]
# Epoch 16/30
# 4/4 [==============================] - 1s 335ms/step - loss: 0.3293 - mean_absolute_error: 0.2498 - acc: 0.8882 - val_loss: 0.3403 - val_mean_absolute_error: 0.2666 - val_acc: 0.9565
#
# Epoch 00016: val_acc improved from 0.86957 to 0.95652, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  [[ 4  1]
#  [ 0 18]]
# Epoch 17/30
# 4/4 [==============================] - 1s 371ms/step - loss: 0.2773 - mean_absolute_error: 0.2226 - acc: 0.9453 - val_loss: 0.3448 - val_mean_absolute_error: 0.2673 - val_acc: 0.9565
# Epoch 00017: val_acc did not improve from 0.95652
# Confusion matrix:
#  [[ 4  1]
#  [ 0 18]]
# Epoch 18/30
# 4/4 [==============================] - 1s 337ms/step - loss: 0.3016 - mean_absolute_error: 0.2311 - acc: 0.9003 - val_loss: 0.3113 - val_mean_absolute_error: 0.2470 - val_acc: 0.9565
#
# Epoch 00018: val_acc did not improve from 0.95652
# Confusion matrix:
#  [[ 4  1]
#  [ 0 18]]
# Epoch 19/30
# 4/4 [==============================] - 1s 320ms/step - loss: 0.2667 - mean_absolute_error: 0.2136 - acc: 0.9239 - val_loss: 0.2964 - val_mean_absolute_error: 0.2372 - val_acc: 0.9565
#
# Epoch 00019: val_acc did not improve from 0.95652
# Confusion matrix:
#  [[ 4  1]
#  [ 0 18]]
# Epoch 20/30
# 4/4 [==============================] - 1s 331ms/step - loss: 0.2422 - mean_absolute_error: 0.1986 - acc: 0.9557 - val_loss: 0.2892 - val_mean_absolute_error: 0.2331 - val_acc: 0.9565
#
# Epoch 00020: val_acc did not improve from 0.95652
# Confusion matrix:
#  [[ 4  1]
#  [ 0 18]]
# Epoch 21/30
# 4/4 [==============================] - 1s 364ms/step - loss: 0.2393 - mean_absolute_error: 0.1941 - acc: 0.9414 - val_loss: 0.2760 - val_mean_absolute_error: 0.2237 - val_acc: 0.9565
#
# Epoch 00021: val_acc did not improve from 0.95652
# Confusion matrix:
#  [[ 3  1]
#  [ 0 19]]
# Epoch 22/30
# 4/4 [==============================] - 1s 311ms/step - loss: 0.2149 - mean_absolute_error: 0.1787 - acc: 0.9673 - val_loss: 0.2641 - val_mean_absolute_error: 0.2157 - val_acc: 0.9565
#
# Epoch 00022: val_acc did not improve from 0.95652
# Confusion matrix:
#  [[ 4  1]
#  [ 0 18]]
# Epoch 23/30
# 4/4 [==============================] - 1s 361ms/step - loss: 0.2185 - mean_absolute_error: 0.1777 - acc: 0.9570 - val_loss: 0.2441 - val_mean_absolute_error: 0.2012 - val_acc: 0.9565
#
# Epoch 00023: val_acc did not improve from 0.95652
# Restoring model weights from the end of the best epoch
# Confusion matrix:
#  [[ 4  1]
#  [ 0 18]]
# Epoch 24/30
# 4/4 [==============================] - 1s 362ms/step - loss: 0.3306 - mean_absolute_error: 0.2444 - acc: 0.8761 - val_loss: 0.3082 - val_mean_absolute_error: 0.2469 - val_acc: 0.9565
#
# Epoch 00024: val_acc did not improve from 0.95652
# Restoring model weights from the end of the best epoch
# Confusion matrix:
#  [[ 3  1]
#  [ 0 19]]
# Epoch 25/30
# 4/4 [==============================] - 1s 338ms/step - loss: 0.2952 - mean_absolute_error: 0.2317 - acc: 0.9237 - val_loss: 0.3103 - val_mean_absolute_error: 0.2485 - val_acc: 0.9565
#
# Epoch 00025: val_acc did not improve from 0.95652
# Restoring model weights from the end of the best epoch
# Confusion matrix:
#  [[ 4  1]
#  [ 0 18]]
# Epoch 26/30
# 4/4 [==============================] - 1s 329ms/step - loss: 0.2996 - mean_absolute_error: 0.2340 - acc: 0.9081 - val_loss: 0.3241 - val_mean_absolute_error: 0.2596 - val_acc: 0.9565
#
# Epoch 00026: val_acc did not improve from 0.95652
# Restoring model weights from the end of the best epoch
# Confusion matrix:
#  [[ 4  1]
#  [ 0 18]]
# Epoch 27/30
# 4/4 [==============================] - 1s 324ms/step - loss: 0.2947 - mean_absolute_error: 0.2292 - acc: 0.9239 - val_loss: 0.3101 - val_mean_absolute_error: 0.2484 - val_acc: 0.9565
#
# Epoch 00027: val_acc did not improve from 0.95652
# Restoring model weights from the end of the best epoch
# Confusion matrix:
#  [[ 4  1]
#  [ 0 18]]
# Epoch 28/30
# 4/4 [==============================] - 1s 362ms/step - loss: 0.2901 - mean_absolute_error: 0.2285 - acc: 0.9219 - val_loss: 0.3489 - val_mean_absolute_error: 0.2747 - val_acc: 0.9565
#
# Epoch 00028: val_acc did not improve from 0.95652
# Restoring model weights from the end of the best epoch
# Confusion matrix:
#  [[ 4  1]
#  [ 0 18]]
# Epoch 29/30
# 4/4 [==============================] - 1s 318ms/step - loss: 0.3082 - mean_absolute_error: 0.2345 - acc: 0.8882 - val_loss: 0.2916 - val_mean_absolute_error: 0.2354 - val_acc: 0.9565
#
# Epoch 00029: val_acc did not improve from 0.95652
# Restoring model weights from the end of the best epoch
# Confusion matrix:
#  [[ 4  1]
#  [ 0 18]]
# Epoch 30/30
# 4/4 [==============================] - 1s 317ms/step - loss: 0.3054 - mean_absolute_error: 0.2337 - acc: 0.9038 - val_loss: 0.3315 - val_mean_absolute_error: 0.2649 - val_acc: 0.9565
#
# Epoch 00030: val_acc did not improve from 0.95652
# Restoring model weights from the end of the best epoch
# Confusion matrix:
#  [[ 4  1]
#  [ 0 18]]
# Epoch 00030: early stopping
# 33/33 [==============================] - 0s 11ms/step
# 33/33 [==============================] - 0s 11ms/step
# Test loss: 0.6809311221269044
# Test mae: 0.4289716267676065
# Test accuracy: 0.6363636363636364
# Confusion Matrix
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-54cc93ba0c67> in <module>
#     247 # generator.classes gives you the truth label y_true
#     248 print('Confusion Matrix')
# --> 249 cm = confusion_matrix(y_true, y_pred)
#     250
#     251 print(cm)
#
# NameError: name 'confusion_matrix' is not defined

# %%
from sklearn.metrics import confusion_matrix, classification_report

test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test mae:', score[1])
print('Test accuracy:', score[2])


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# 33/33 [==============================] - 0s 11ms/step
# 33/33 [==============================] - 0s 10ms/step
# Test loss: 0.6809311221269044
# Test mae: 0.4289716267676065
# Test accuracy: 0.6363636363636364
# Confusion Matrix
# [[ 3  9]
#  [ 3 18]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.50      0.25      0.33        12
#            1       0.67      0.86      0.75        21
#
#     accuracy                           0.64        33
#    macro avg       0.58      0.55      0.54        33
# weighted avg       0.61      0.64      0.60        33

# %%
def kappa2(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    if len(y_true.shape) > 1 and y_true.shape[1] > 1:
        y_true = y_true.dot(range(y_true.shape[1]))
    if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
        y_pred = y_pred.dot(range(y_pred.shape[1]))
    try:
        return kappa(y_true, y_pred, weights='quadratic')
    except IndexError:
        return np.nan
    
print('Quadratic_wieghted_kappa')
print(kappa2(y_true, y_pred))
# Out:
# Quadratic_wieghted_kappa
# 0.12

# %%
# list all data in history
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model loss.png')

# summarize history for val_kappa
plt.plot(history.history['val_kappa'])
plt.title('Validation_Kappa')
plt.ylabel('val_kappa')
plt.xlabel('epoch')
plt.legend([ 'validation'], loc='upper left')
plt.show()
#plt.savefig('model validation_kappa.png')

# summarize history for mean_absolute _error
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model mean_absolute_error')
plt.ylabel('mean_absolute_error')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model maey.png')
# Out:
# dict_keys(['val_loss', 'val_mean_absolute_error', 'val_acc', 'loss', 'mean_absolute_error', 'acc'])
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-b7c163781efd> in <module>
#      22
#      23 # summarize history for val_kappa
# ---> 24 plt.plot(history.history['val_kappa'])
#      25 plt.title('Validation_Kappa')
#      26 plt.ylabel('val_kappa')
#
# KeyError: 'val_kappa'
