# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, InputLayer
from keras.regularizers import L1L2, l2, l1
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from custom_pooling import RMSPooling2D
from keras.optimizers import SGD, Adam
from keras.layers import LeakyReLU
#from data import BALANCE_WEIGHTS
from keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
#import os
from datetime import datetime as dt
from custom_loss import WeightedCategoricalCrossEntropy
from VCM import VCM
from QWK import QWK
import keras.backend as K
from Fractional_MAXPOOL import FractionalPooling2D
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
def get_experiment_id():
    time_str = dt.now().strftime('%Y-%m-%d-%H-%M-%S')
    experiment_id = 'base_{}'.format(time_str)
    return experiment_id
p_ratio=[1.0, 1.44, 1.73, 1.0]

model = Sequential()


model.add(Conv2D(16, (5, 5), activation='tanh', input_shape=(300, 300, 3)))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(16, (3, 3), activation='tanh'))
model.add(Conv2D(16, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))

#model.add(LeakyReLU(alpha=0.01))


model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))



model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))          
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))
#model.add(MaxPooling2D(pool_size=1))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Flatten())


#chnaged from 10 to 5 because an error 
model.add(Dense(2, activation='softmax'))

sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.count_params()
#adam = Adam(lr=0.0005, decay=1e-6)
#rmsprop
#Mloss = WeightedCategoricalCrossEntropy({0: 0.4125861396437394, 1: 1.4918664786083686, 2: 0.690426457789382, 3: 3.9541433021806855, 4: 4.885604311008468})
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['mae','acc'])
model.summary()
loss_no_weight_decay = model.total_loss - sum(model.losses)
model.metrics_tensors.append(loss_no_weight_decay)
model.metrics_names.append('loss_no_weight_decay')
#############################################################################################
#############################################################################################
#############################################################################################
#############################################################################################
#Preparing Data Augmentation Configuration 
train_datagen = ImageDataGenerator(
        rescale=1./255,
#        featurewise_center=True,
 #       samplewise_center=True,
        shear_range=0,
        zoom_range=0.0,#[1 / 1.15, 1.15],
        horizontal_flip=False,#True,
        rotation_range=0)#90,
#        validation_split=0.2)
"""
For the test set only rescale should be made 
"""
test_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas_grah/train",
    target_size=(300, 300),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="training")
#    save_to_dir="D:/Separating Images into subfolders/train_augmented")


#print(train_generator.class_indices)

valid_generator = valid_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas_grah/vald",
    target_size=(300, 300),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="validation")
#    save_to_dir="D:/Separating Images into subfolders/val_augmented"


test_generator = test_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas_grah/test",
    target_size=(300, 300),
    color_mode="rgb",
    batch_size=1,
    class_mode="categorical",
    shuffle=False,
    seed=42)
#    save_to_dir="D:/Separating Images into subfolders/test_augmented")


# Fitting/Training the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
experiment_id = get_experiment_id()
callbacks = [
    QWK(valid_generator, STEP_SIZE_VALID),
    EarlyStopping(monitor='val_acc', patience=50, min_delta=0.001, verbose=1),
    ModelCheckpoint(experiment_id + "-val_acc_checkpoint.hdf5", monitor='val_kappa', verbose=1, save_best_only=True, mode='max'),
    ReduceLROnPlateau(monitor='val_acc', factor=0.5, patience=7, verbose=1, mode='auto', min_delta=0.001, cooldown=0, min_lr=1e-7),
    VCM(valid_generator,STEP_SIZE_VALID)
    
]

class_weight_list = class_weight.compute_class_weight('balanced', np.unique(train_generator.classes), train_generator.classes)
class_weights = dict(zip(np.unique(train_generator.classes), class_weight_list))

history=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    #class_weight=class_weights,
                    callbacks=callbacks,
                    epochs=20  
)


# Evaluating the model 
#predicting output
#reseting the test generator before calling predict_generator, in order not to get weird output
test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 296, 296, 16)      1216
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 292, 292, 16)      6416
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 290, 290, 16)      2320
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 288, 288, 16)      2320
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 284, 284, 16)      6416
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 280, 280, 16)      6416
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 276, 276, 16)      6416
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 272, 272, 16)      6416
# _________________________________________________________________
# fractional_pooling2d_1 (Frac (None, 151, 151, 16)      0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 149, 149, 32)      4640
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 147, 147, 32)      9248
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 145, 145, 32)      9248
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 143, 143, 32)      9248
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 141, 141, 32)      9248
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 139, 139, 32)      9248
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 137, 137, 32)      9248
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 135, 135, 32)      9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 67, 67, 32)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 65, 65, 64)        18496
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 63, 63, 64)        36928
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 61, 61, 64)        36928
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 59, 59, 64)        36928
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 57, 57, 64)        36928
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 55, 55, 64)        36928
# _________________________________________________________________
# fractional_pooling2d_2 (Frac (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 28, 28, 64)        36928
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 26, 26, 64)        36928
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 24, 24, 64)        36928
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 22, 22, 64)        36928
# _________________________________________________________________
# fractional_pooling2d_3 (Frac (None, 12, 12, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 9216)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 18434
# =================================================================
# Total params: 476,594
# Trainable params: 476,594
# Non-trainable params: 0
# _________________________________________________________________
# Found 588 images belonging to 2 classes.
# Found 116 images belonging to 2 classes.
# Found 176 images belonging to 2 classes.
# Epoch 1/20
# 9/9 [==============================] - 38s 4s/step - loss: 0.6936 - mean_absolute_error: 0.4993 - acc: 0.4794 - loss_no_weight_decay: 0.6936 - val_loss: 0.6792 - val_mean_absolute_error: 0.4919 - val_acc: 0.5781 - val_loss_no_weight_decay: 0.6792
# — val_kappa: 0.0
#
# Epoch 00001: val_kappa improved from -inf to 0.00000, saving model to base_2020-05-10-13-40-47-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[26  0]
#  [26  0]]
# Epoch 2/20
# 9/9 [==============================] - 26s 3s/step - loss: 0.6940 - mean_absolute_error: 0.4999 - acc: 0.4692 - loss_no_weight_decay: 0.6940 - val_loss: 0.6935 - val_mean_absolute_error: 0.4998 - val_acc: 0.4038 - val_loss_no_weight_decay: 0.6935
# — val_kappa: -0.125
#
# Epoch 00002: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[30  0]
#  [22  0]]
# Epoch 3/20
# 9/9 [==============================] - 23s 3s/step - loss: 0.6907 - mean_absolute_error: 0.4970 - acc: 0.5203 - loss_no_weight_decay: 0.6907 - val_loss: 0.6956 - val_mean_absolute_error: 0.4941 - val_acc: 0.5000 - val_loss_no_weight_decay: 0.6956
# — val_kappa: -0.125
#
# Epoch 00003: val_kappa did not improve from 0.00000
# Confusion matrix:
#  [[ 0 22]
#  [ 0 30]]
# Epoch 4/20
# 9/9 [==============================] - 23s 3s/step - loss: 0.6936 - mean_absolute_error: 0.4979 - acc: 0.5103 - loss_no_weight_decay: 0.6936 - val_loss: 0.6841 - val_mean_absolute_error: 0.4951 - val_acc: 0.5577 - val_loss_no_weight_decay: 0.6841
# — val_kappa: 0.25
#
# Epoch 00004: val_kappa improved from 0.00000 to 0.25000, saving model to base_2020-05-10-13-40-47-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[ 5 26]
#  [ 0 21]]
# Epoch 5/20
# 9/9 [==============================] - 23s 3s/step - loss: 0.6868 - mean_absolute_error: 0.4966 - acc: 0.6117 - loss_no_weight_decay: 0.6868 - val_loss: 0.6785 - val_mean_absolute_error: 0.4925 - val_acc: 0.7656 - val_loss_no_weight_decay: 0.6785
# — val_kappa: 0.625
#
# Epoch 00005: val_kappa improved from 0.25000 to 0.62500, saving model to base_2020-05-10-13-40-47-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[19  9]
#  [ 8 16]]
# Epoch 6/20
# 9/9 [==============================] - 25s 3s/step - loss: 0.6789 - mean_absolute_error: 0.4924 - acc: 0.6389 - loss_no_weight_decay: 0.6789 - val_loss: 0.6651 - val_mean_absolute_error: 0.4854 - val_acc: 0.8269 - val_loss_no_weight_decay: 0.6651
# — val_kappa: 0.5
#
# Epoch 00006: val_kappa did not improve from 0.62500
# Confusion matrix:
#  [[18  9]
#  [ 0 25]]
# Epoch 7/20
# 9/9 [==============================] - 23s 3s/step - loss: 0.6696 - mean_absolute_error: 0.4867 - acc: 0.6638 - loss_no_weight_decay: 0.6696 - val_loss: 0.6477 - val_mean_absolute_error: 0.4755 - val_acc: 0.8281 - val_loss_no_weight_decay: 0.6477
# — val_kappa: 0.5625
#
# Epoch 00007: val_kappa did not improve from 0.62500
# Confusion matrix:
#  [[15 14]
#  [ 2 21]]
# Epoch 8/20
# 9/9 [==============================] - 21s 2s/step - loss: 0.6463 - mean_absolute_error: 0.4720 - acc: 0.6640 - loss_no_weight_decay: 0.6463 - val_loss: 0.5920 - val_mean_absolute_error: 0.4415 - val_acc: 0.7500 - val_loss_no_weight_decay: 0.5920
# — val_kappa: 0.5
#
# Epoch 00008: val_kappa did not improve from 0.62500
# Confusion matrix:
#  [[14 11]
#  [ 3 24]]
# Epoch 9/20
# 9/9 [==============================] - 25s 3s/step - loss: 0.6045 - mean_absolute_error: 0.4356 - acc: 0.7031 - loss_no_weight_decay: 0.6045 - val_loss: 0.4988 - val_mean_absolute_error: 0.3680 - val_acc: 0.7344 - val_loss_no_weight_decay: 0.4988
# — val_kappa: 0.4375
#
# Epoch 00009: val_kappa did not improve from 0.62500
# Confusion matrix:
#  [[11 15]
#  [ 4 22]]
# Epoch 10/20
# 9/9 [==============================] - 23s 3s/step - loss: 0.7895 - mean_absolute_error: 0.4746 - acc: 0.6550 - loss_no_weight_decay: 0.7895 - val_loss: 0.6900 - val_mean_absolute_error: 0.4977 - val_acc: 0.5000 - val_loss_no_weight_decay: 0.6900
# — val_kappa: 0.375
#
# Epoch 00010: val_kappa did not improve from 0.62500
# Confusion matrix:
#  [[ 8 23]
#  [ 0 21]]
# Epoch 11/20
# 9/9 [==============================] - 23s 3s/step - loss: 0.7260 - mean_absolute_error: 0.5023 - acc: 0.5103 - loss_no_weight_decay: 0.7260 - val_loss: 0.7155 - val_mean_absolute_error: 0.5032 - val_acc: 0.4688 - val_loss_no_weight_decay: 0.7155
# — val_kappa: 0.0
#
# Epoch 00011: val_kappa did not improve from 0.62500
# Confusion matrix:
#  [[26  0]
#  [26  0]]
# Epoch 12/20
# 9/9 [==============================] - 23s 3s/step - loss: 0.6894 - mean_absolute_error: 0.4960 - acc: 0.5178 - loss_no_weight_decay: 0.6894 - val_loss: 0.6982 - val_mean_absolute_error: 0.4985 - val_acc: 0.4615 - val_loss_no_weight_decay: 0.6982
# — val_kappa: -0.09375
#
# Epoch 00012: val_kappa did not improve from 0.62500
# Confusion matrix:
#  [[ 0 23]
#  [ 0 29]]
# Epoch 13/20
# 9/9 [==============================] - 23s 3s/step - loss: 0.6855 - mean_absolute_error: 0.4941 - acc: 0.5443 - loss_no_weight_decay: 0.6855 - val_loss: 0.6721 - val_mean_absolute_error: 0.4892 - val_acc: 0.8594 - val_loss_no_weight_decay: 0.6721
# — val_kappa: 0.6875
#
# Epoch 00013: val_kappa improved from 0.62500 to 0.68750, saving model to base_2020-05-10-13-40-47-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[21  7]
#  [ 0 24]]
# Epoch 14/20
# 9/9 [==============================] - 25s 3s/step - loss: 0.6700 - mean_absolute_error: 0.4877 - acc: 0.7205 - loss_no_weight_decay: 0.6700 - val_loss: 0.6587 - val_mean_absolute_error: 0.4819 - val_acc: 0.8462 - val_loss_no_weight_decay: 0.6587
# — val_kappa: 0.8125
#
# Epoch 00014: val_kappa improved from 0.68750 to 0.81250, saving model to base_2020-05-10-13-40-47-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[15 12]
#  [ 2 23]]
# Epoch 15/20
# 9/9 [==============================] - 21s 2s/step - loss: 0.6589 - mean_absolute_error: 0.4809 - acc: 0.6626 - loss_no_weight_decay: 0.6589 - val_loss: 0.6434 - val_mean_absolute_error: 0.4725 - val_acc: 0.7812 - val_loss_no_weight_decay: 0.6434
# — val_kappa: 0.8125
#
# Epoch 00015: val_kappa did not improve from 0.81250
# Confusion matrix:
#  [[17 14]
#  [ 1 20]]
# Epoch 16/20
# 9/9 [==============================] - 25s 3s/step - loss: 0.6251 - mean_absolute_error: 0.4602 - acc: 0.7674 - loss_no_weight_decay: 0.6251 - val_loss: 0.5463 - val_mean_absolute_error: 0.4156 - val_acc: 0.9038 - val_loss_no_weight_decay: 0.5463
# — val_kappa: 0.625
#
# Epoch 00016: val_kappa did not improve from 0.81250
# Confusion matrix:
#  [[21  6]
#  [ 5 20]]
# Epoch 17/20
# 9/9 [==============================] - 21s 2s/step - loss: 0.5800 - mean_absolute_error: 0.4257 - acc: 0.7564 - loss_no_weight_decay: 0.5800 - val_loss: 0.4881 - val_mean_absolute_error: 0.3667 - val_acc: 0.8281 - val_loss_no_weight_decay: 0.4881
# — val_kappa: 0.65625
#
# Epoch 00017: val_kappa did not improve from 0.81250
# Confusion matrix:
#  [[14 10]
#  [ 1 27]]
# Epoch 18/20
# 9/9 [==============================] - 25s 3s/step - loss: 0.5441 - mean_absolute_error: 0.3831 - acc: 0.7465 - loss_no_weight_decay: 0.5441 - val_loss: 0.4554 - val_mean_absolute_error: 0.3295 - val_acc: 0.8077 - val_loss_no_weight_decay: 0.4554
# — val_kappa: 0.65625
#
# Epoch 00018: val_kappa did not improve from 0.81250
# Confusion matrix:
#  [[16  7]
#  [ 3 26]]
# Epoch 19/20
# 9/9 [==============================] - 23s 3s/step - loss: 0.5327 - mean_absolute_error: 0.3593 - acc: 0.7470 - loss_no_weight_decay: 0.5327 - val_loss: 0.5432 - val_mean_absolute_error: 0.3617 - val_acc: 0.7656 - val_loss_no_weight_decay: 0.5432
# — val_kappa: 0.59375
#
# Epoch 00019: val_kappa did not improve from 0.81250
# Confusion matrix:
#  [[14 10]
#  [ 0 28]]
# Epoch 20/20
# 9/9 [==============================] - 23s 3s/step - loss: 0.4853 - mean_absolute_error: 0.3176 - acc: 0.8001 - loss_no_weight_decay: 0.4853 - val_loss: 0.3213 - val_mean_absolute_error: 0.2529 - val_acc: 0.9231 - val_loss_no_weight_decay: 0.3213
# — val_kappa: 0.625
#
# Epoch 00020: val_kappa did not improve from 0.81250
# Confusion matrix:
#  [[22  4]
#  [ 1 25]]
# 176/176 [==============================] - 3s 15ms/step
# 176/176 [==============================] - 2s 13ms/step
# Test loss: 0.4771363200005991
# Test accuracy: 0.328850645667196
# Confusion Matrix
# [[66 22]
#  [19 69]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.78      0.75      0.76        88
#            1       0.76      0.78      0.77        88
#
#     accuracy                           0.77       176
#    macro avg       0.77      0.77      0.77       176
# weighted avg       0.77      0.77      0.77       176

# %%
from Kappa_Skl import kappa
def kappa2(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    if len(y_true.shape) > 1 and y_true.shape[1] > 1:
        y_true = y_true.dot(range(y_true.shape[1]))
    if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
        y_pred = y_pred.dot(range(y_pred.shape[1]))
    try:
        return kappa(y_true, y_pred, weights='quadratic')
    except IndexError:
        return np.nan
    
print('Quadratic_wieghted_kappa')
print(kappa2(y_true, y_pred))
# Out:
# Quadratic_wieghted_kappa
# 0.5340909090909091

# %%
import numpy as np 
import matplotlib.pyplot as plt
import os
import wandb
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model loss.png')

# summarize history for val_kappa
plt.plot(history.history['val_kappa'])
plt.title('Validation_Kappa')
plt.ylabel('val_kappa')
plt.xlabel('epoch')
plt.legend([ 'validation'], loc='upper left')
plt.show()
#plt.savefig('model validation_kappa.png')

# summarize history for mean_absolute _error
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model mean_absolute_error')
plt.ylabel('mean_absolute_error')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model maey.png'
# Out:
# dict_keys(['val_loss', 'val_mean_absolute_error', 'val_acc', 'val_loss_no_weight_decay', 'loss', 'mean_absolute_error', 'acc', 'loss_no_weight_decay', 'val_kappa', 'lr'])
