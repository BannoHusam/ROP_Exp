# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, InputLayer
from keras.regularizers import L1L2, l2, l1
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from custom_pooling import RMSPooling2D
from keras.optimizers import SGD, Adam
from keras.layers import LeakyReLU
#from data import BALANCE_WEIGHTS
from keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
#import os
from datetime import datetime as dt
from custom_loss import WeightedCategoricalCrossEntropy
from VCM import VCM
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
def get_experiment_id():
    time_str = dt.now().strftime('%Y-%m-%d-%H-%M-%S')
    experiment_id = 'base_{}'.format(time_str)
    return experiment_id
p_ratio=[1.0, 1.44, 1.73, 1.0]

model = Sequential()


model.add(Conv2D(16, (5, 5), activation='tanh', input_shape=(270, 270, 3)))
model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(16, (3, 3), activation='tanh'))
model.add(Conv2D(16, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))

#model.add(LeakyReLU(alpha=0.01))


model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))



model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))          
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(MaxPooling2D(pool_size=2))
#model.add(MaxPooling2D(pool_size=1))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
model.add(MaxPooling2D(pool_size=2))

model.add(Flatten())


#chnaged from 10 to 5 because an error 
model.add(Dense(2, activation='softmax'))

sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.count_params()
#adam = Adam(lr=0.0005, decay=1e-6)
#rmsprop
#Mloss = WeightedCategoricalCrossEntropy({0: 0.4125861396437394, 1: 1.4918664786083686, 2: 0.690426457789382, 3: 3.9541433021806855, 4: 4.885604311008468})
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['mae','acc'])
model.summary()
loss_no_weight_decay = model.total_loss - sum(model.losses)
model.metrics_tensors.append(loss_no_weight_decay)
model.metrics_names.append('loss_no_weight_decay')
#############################################################################################
#############################################################################################
#############################################################################################
#############################################################################################
#Preparing Data Augmentation Configuration 
train_datagen = ImageDataGenerator(
        rescale=1./255,
#        featurewise_center=True,
 #       samplewise_center=True,
        shear_range=0,
        zoom_range=0.0,#[1 / 1.15, 1.15],
        horizontal_flip=False,#True,
        rotation_range=0)#90,
#        validation_split=0.2)
"""
For the test set only rescale should be made 
"""
test_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_class_treatment/train",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="training")
#    save_to_dir="D:/Separating Images into subfolders/train_augmented")


#print(train_generator.class_indices)

valid_generator = valid_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_class_treatment/vald",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="validation")
#    save_to_dir="D:/Separating Images into subfolders/val_augmented"


test_generator = test_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_class_treatment/test",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=1,
    class_mode="categorical",
    shuffle=False,
    seed=42)
#    save_to_dir="D:/Separating Images into subfolders/test_augmented")


# Fitting/Training the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
experiment_id = get_experiment_id()
callbacks = [
    EarlyStopping(monitor='val_acc', patience=50, min_delta=0.001, verbose=1),
    ModelCheckpoint(experiment_id + "-val_acc_checkpoint.hdf5", monitor='val_acc', verbose=1, save_best_only=True, mode='auto'),
    ReduceLROnPlateau(monitor='val_acc', factor=0.5, patience=7, verbose=1, mode='auto', min_delta=0.001, cooldown=0, min_lr=1e-7),
    VCM(valid_generator,STEP_SIZE_VALID)
    
]

class_weight_list = class_weight.compute_class_weight('balanced', np.unique(train_generator.classes), train_generator.classes)
class_weights = dict(zip(np.unique(train_generator.classes), class_weight_list))

history=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    class_weight=class_weights,
                    callbacks=callbacks,
                    epochs=35  
)


# Evaluating the model 
#predicting output
#reseting the test generator before calling predict_generator, in order not to get weird output
test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 266, 266, 16)      1216
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 262, 262, 16)      6416
# _________________________________________________________________
# input_1 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 260, 260, 16)      2320
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 258, 258, 16)      2320
# _________________________________________________________________
# input_2 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 254, 254, 16)      6416
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 250, 250, 16)      6416
# _________________________________________________________________
# input_3 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 246, 246, 16)      6416
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 242, 242, 16)      6416
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 121, 121, 16)      0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 119, 119, 32)      4640
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 117, 117, 32)      9248
# _________________________________________________________________
# input_4 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 115, 115, 32)      9248
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 113, 113, 32)      9248
# _________________________________________________________________
# input_5 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 111, 111, 32)      9248
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 109, 109, 32)      9248
# _________________________________________________________________
# input_6 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 107, 107, 32)      9248
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 105, 105, 32)      9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 52, 52, 32)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 50, 50, 64)        18496
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 48, 48, 64)        36928
# _________________________________________________________________
# input_7 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 46, 46, 64)        36928
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 44, 44, 64)        36928
# _________________________________________________________________
# input_8 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 42, 42, 64)        36928
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 40, 40, 64)        36928
# _________________________________________________________________
# input_9 (InputLayer)         multiple                  0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 20, 20, 64)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 18, 18, 64)        36928
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# input_10 (InputLayer)        multiple                  0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 14, 14, 64)        36928
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 12, 12, 64)        36928
# _________________________________________________________________
# input_11 (InputLayer)        multiple                  0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 4610
# =================================================================
# Total params: 462,770
# Trainable params: 462,770
# Non-trainable params: 0
# _________________________________________________________________
# Found 294 images belonging to 2 classes.
# Found 58 images belonging to 2 classes.
# Found 88 images belonging to 2 classes.
# Epoch 1/35
# 4/4 [==============================] - 21s 5s/step - loss: 0.6947 - mean_absolute_error: 0.5127 - acc: 0.2629 - loss_no_weight_decay: 0.6947 - val_loss: 0.6996 - val_mean_absolute_error: 0.5032 - val_acc: 0.2241 - val_loss_no_weight_decay: 0.6996
#
# Epoch 00001: val_acc improved from -inf to 0.22414, saving model to base_2020-05-08-16-10-58-val_acc_checkpoint.hdf5
# Confusion matrix:
#  []
# Epoch 2/35
# 4/4 [==============================] - 5s 1s/step - loss: 0.6765 - mean_absolute_error: 0.4978 - acc: 0.4453 - loss_no_weight_decay: 0.6765 - val_loss: 0.6578 - val_mean_absolute_error: 0.4811 - val_acc: 0.7759 - val_loss_no_weight_decay: 0.6578
#
# Epoch 00002: val_acc improved from 0.22414 to 0.77586, saving model to base_2020-05-08-16-10-58-val_acc_checkpoint.hdf5
# Confusion matrix:
#  []
# Epoch 3/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.7425 - mean_absolute_error: 0.4941 - acc: 0.5503 - loss_no_weight_decay: 0.7425 - val_loss: 0.7181 - val_mean_absolute_error: 0.5120 - val_acc: 0.2241 - val_loss_no_weight_decay: 0.7181
#
# Epoch 00003: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 4/35
# 4/4 [==============================] - 5s 1s/step - loss: 0.6823 - mean_absolute_error: 0.5114 - acc: 0.2461 - loss_no_weight_decay: 0.6823 - val_loss: 0.7098 - val_mean_absolute_error: 0.5081 - val_acc: 0.2241 - val_loss_no_weight_decay: 0.7098
#
# Epoch 00004: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 5/35
# 4/4 [==============================] - 5s 1s/step - loss: 0.6925 - mean_absolute_error: 0.5025 - acc: 0.3489 - loss_no_weight_decay: 0.6925 - val_loss: 0.6906 - val_mean_absolute_error: 0.4987 - val_acc: 0.6897 - val_loss_no_weight_decay: 0.6906
#
# Epoch 00005: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 6/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.6971 - mean_absolute_error: 0.4996 - acc: 0.5096 - loss_no_weight_decay: 0.6971 - val_loss: 0.6911 - val_mean_absolute_error: 0.4990 - val_acc: 0.6897 - val_loss_no_weight_decay: 0.6911
# Epoch 00006: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 7/35
# 4/4 [==============================] - 5s 1s/step - loss: 0.6900 - mean_absolute_error: 0.4992 - acc: 0.5547 - loss_no_weight_decay: 0.6900 - val_loss: 0.6907 - val_mean_absolute_error: 0.4988 - val_acc: 0.6897 - val_loss_no_weight_decay: 0.6907
#
# Epoch 00007: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 8/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.6965 - mean_absolute_error: 0.4949 - acc: 0.7331 - loss_no_weight_decay: 0.6965 - val_loss: 0.6852 - val_mean_absolute_error: 0.4959 - val_acc: 0.7759 - val_loss_no_weight_decay: 0.6852
#
# Epoch 00008: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 9/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.6933 - mean_absolute_error: 0.4962 - acc: 0.7312 - loss_no_weight_decay: 0.6933 - val_loss: 0.6889 - val_mean_absolute_error: 0.4979 - val_acc: 0.7069 - val_loss_no_weight_decay: 0.6889
#
# Epoch 00009: val_acc did not improve from 0.77586
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Confusion matrix:
#  []
# Epoch 10/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.6803 - mean_absolute_error: 0.4973 - acc: 0.7389 - loss_no_weight_decay: 0.6803 - val_loss: 0.6894 - val_mean_absolute_error: 0.4981 - val_acc: 0.7069 - val_loss_no_weight_decay: 0.6894
#
# Epoch 00010: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 11/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.6893 - mean_absolute_error: 0.4957 - acc: 0.7475 - loss_no_weight_decay: 0.6893 - val_loss: 0.6855 - val_mean_absolute_error: 0.4961 - val_acc: 0.7586 - val_loss_no_weight_decay: 0.6855
#
# Epoch 00011: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 12/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.6542 - mean_absolute_error: 0.4925 - acc: 0.7712 - loss_no_weight_decay: 0.6542 - val_loss: 0.6693 - val_mean_absolute_error: 0.4875 - val_acc: 0.7759 - val_loss_no_weight_decay: 0.6693
#
# Epoch 00012: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 13/35
# 4/4 [==============================] - 5s 1s/step - loss: 0.7327 - mean_absolute_error: 0.4928 - acc: 0.7109 - loss_no_weight_decay: 0.7327 - val_loss: 0.6882 - val_mean_absolute_error: 0.4975 - val_acc: 0.7069 - val_loss_no_weight_decay: 0.6882
#
# Epoch 00013: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 14/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.6790 - mean_absolute_error: 0.4973 - acc: 0.7231 - loss_no_weight_decay: 0.6790 - val_loss: 0.6906 - val_mean_absolute_error: 0.4987 - val_acc: 0.6724 - val_loss_no_weight_decay: 0.6906
#
# Epoch 00014: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 15/35
# 4/4 [==============================] - 5s 1s/step - loss: 0.6888 - mean_absolute_error: 0.4983 - acc: 0.5820 - loss_no_weight_decay: 0.6888 - val_loss: 0.6931 - val_mean_absolute_error: 0.5000 - val_acc: 0.6207 - val_loss_no_weight_decay: 0.6931
#
# Epoch 00015: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 16/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.7030 - mean_absolute_error: 0.5010 - acc: 0.4161 - loss_no_weight_decay: 0.7030 - val_loss: 0.7016 - val_mean_absolute_error: 0.5042 - val_acc: 0.2241 - val_loss_no_weight_decay: 0.7016
#
# Epoch 00016: val_acc did not improve from 0.77586
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Confusion matrix:
#  []
# Epoch 17/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.7177 - mean_absolute_error: 0.5022 - acc: 0.3021 - loss_no_weight_decay: 0.7177 - val_loss: 0.7077 - val_mean_absolute_error: 0.5071 - val_acc: 0.2241 - val_loss_no_weight_decay: 0.7077
#
# Epoch 00017: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 18/35
# 4/4 [==============================] - 5s 1s/step - loss: 0.6630 - mean_absolute_error: 0.5060 - acc: 0.2344 - loss_no_weight_decay: 0.6630 - val_loss: 0.7049 - val_mean_absolute_error: 0.5057 - val_acc: 0.2241 - val_loss_no_weight_decay: 0.7049
#
# Epoch 00018: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 19/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.7051 - mean_absolute_error: 0.5038 - acc: 0.2832 - loss_no_weight_decay: 0.7051 - val_loss: 0.7044 - val_mean_absolute_error: 0.5055 - val_acc: 0.2241 - val_loss_no_weight_decay: 0.7044
#
# Epoch 00019: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 20/35
# 4/4 [==============================] - 5s 1s/step - loss: 0.6938 - mean_absolute_error: 0.5034 - acc: 0.2813 - loss_no_weight_decay: 0.6938 - val_loss: 0.7017 - val_mean_absolute_error: 0.5042 - val_acc: 0.2241 - val_loss_no_weight_decay: 0.7017
#
# Epoch 00020: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 21/35
# 4/4 [==============================] - 5s 1s/step - loss: 0.6790 - mean_absolute_error: 0.5026 - acc: 0.2964 - loss_no_weight_decay: 0.6790 - val_loss: 0.6945 - val_mean_absolute_error: 0.5007 - val_acc: 0.5517 - val_loss_no_weight_decay: 0.6945
#
# Epoch 00021: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 22/35
# 4/4 [==============================] - 5s 1s/step - loss: 0.6812 - mean_absolute_error: 0.4980 - acc: 0.6814 - loss_no_weight_decay: 0.6812 - val_loss: 0.6865 - val_mean_absolute_error: 0.4966 - val_acc: 0.7241 - val_loss_no_weight_decay: 0.6865
#
# Epoch 00022: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 23/35
# 4/4 [==============================] - 5s 1s/step - loss: 0.7162 - mean_absolute_error: 0.4966 - acc: 0.7046 - loss_no_weight_decay: 0.7162 - val_loss: 0.6873 - val_mean_absolute_error: 0.4970 - val_acc: 0.7241 - val_loss_no_weight_decay: 0.6873
#
# Epoch 00023: val_acc did not improve from 0.77586
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Confusion matrix:
#  []
# Epoch 24/35
# 4/4 [==============================] - 5s 1s/step - loss: 0.6846 - mean_absolute_error: 0.4965 - acc: 0.7208 - loss_no_weight_decay: 0.6846 - val_loss: 0.6892 - val_mean_absolute_error: 0.4980 - val_acc: 0.6724 - val_loss_no_weight_decay: 0.6892
#
# Epoch 00024: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 25/35
# 4/4 [==============================] - 5s 1s/step - loss: 0.6935 - mean_absolute_error: 0.4974 - acc: 0.7070 - loss_no_weight_decay: 0.6935 - val_loss: 0.6913 - val_mean_absolute_error: 0.4991 - val_acc: 0.6034 - val_loss_no_weight_decay: 0.6913
#
# Epoch 00025: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 26/35
# 4/4 [==============================] - 5s 1s/step - loss: 0.7081 - mean_absolute_error: 0.4989 - acc: 0.6057 - loss_no_weight_decay: 0.7081 - val_loss: 0.6957 - val_mean_absolute_error: 0.5012 - val_acc: 0.3966 - val_loss_no_weight_decay: 0.6957
#
# Epoch 00026: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 27/35
# 4/4 [==============================] - 5s 1s/step - loss: 0.6754 - mean_absolute_error: 0.4993 - acc: 0.5746 - loss_no_weight_decay: 0.6754 - val_loss: 0.6932 - val_mean_absolute_error: 0.5000 - val_acc: 0.5862 - val_loss_no_weight_decay: 0.6932
#
# Epoch 00027: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 28/35
# 4/4 [==============================] - 5s 1s/step - loss: 0.7066 - mean_absolute_error: 0.4992 - acc: 0.5898 - loss_no_weight_decay: 0.7066 - val_loss: 0.6959 - val_mean_absolute_error: 0.5013 - val_acc: 0.3621 - val_loss_no_weight_decay: 0.6959
#
# Epoch 00028: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 29/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.6704 - mean_absolute_error: 0.4996 - acc: 0.5059 - loss_no_weight_decay: 0.6704 - val_loss: 0.6937 - val_mean_absolute_error: 0.5002 - val_acc: 0.5690 - val_loss_no_weight_decay: 0.6937
#
# Epoch 00029: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 30/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.6894 - mean_absolute_error: 0.4992 - acc: 0.5829 - loss_no_weight_decay: 0.6894 - val_loss: 0.6926 - val_mean_absolute_error: 0.4997 - val_acc: 0.6034 - val_loss_no_weight_decay: 0.6926
# Epoch 00030: val_acc did not improve from 0.77586
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Confusion matrix:
#  []
# Epoch 31/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.6938 - mean_absolute_error: 0.4980 - acc: 0.6907 - loss_no_weight_decay: 0.6938 - val_loss: 0.6912 - val_mean_absolute_error: 0.4990 - val_acc: 0.6034 - val_loss_no_weight_decay: 0.6912
#
# Epoch 00031: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 32/35
# 4/4 [==============================] - 5s 1s/step - loss: 0.7001 - mean_absolute_error: 0.4978 - acc: 0.6914 - loss_no_weight_decay: 0.7001 - val_loss: 0.6910 - val_mean_absolute_error: 0.4989 - val_acc: 0.6207 - val_loss_no_weight_decay: 0.6910
#
# Epoch 00032: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 33/35
# 4/4 [==============================] - 4s 1s/step - loss: 0.6564 - mean_absolute_error: 0.4972 - acc: 0.7067 - loss_no_weight_decay: 0.6564 - val_loss: 0.6879 - val_mean_absolute_error: 0.4974 - val_acc: 0.6724 - val_loss_no_weight_decay: 0.6879
#
# Epoch 00033: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 34/35
# 4/4 [==============================] - 5s 1s/step - loss: 0.7058 - mean_absolute_error: 0.4966 - acc: 0.6969 - loss_no_weight_decay: 0.7058 - val_loss: 0.6870 - val_mean_absolute_error: 0.4969 - val_acc: 0.7241 - val_loss_no_weight_decay: 0.6870
#
# Epoch 00034: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# Epoch 35/35
# 4/4 [==============================] - 5s 1s/step - loss: 0.6774 - mean_absolute_error: 0.4950 - acc: 0.7478 - loss_no_weight_decay: 0.6774 - val_loss: 0.6851 - val_mean_absolute_error: 0.4959 - val_acc: 0.7241 - val_loss_no_weight_decay: 0.6851
#
# Epoch 00035: val_acc did not improve from 0.77586
# Confusion matrix:
#  []
# 88/88 [==============================] - 1s 11ms/step
# 88/88 [==============================] - 1s 9ms/step
# Test loss: 0.6834004284306006
# Test accuracy: 0.4950419908220118
# Confusion Matrix
# [[ 1 18]
#  [ 3 66]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.25      0.05      0.09        19
#            1       0.79      0.96      0.86        69
#
#     accuracy                           0.76        88
#    macro avg       0.52      0.50      0.47        88
# weighted avg       0.67      0.76      0.70        88

# %%
from Kappa_Skl import kappa
def kappa2(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    if len(y_true.shape) > 1 and y_true.shape[1] > 1:
        y_true = y_true.dot(range(y_true.shape[1]))
    if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
        y_pred = y_pred.dot(range(y_pred.shape[1]))
    try:
        return kappa(y_true, y_pred, weights='quadratic')
    except IndexError:
        return np.nan
    
print('Quadratic_wieghted_kappa')
print(kappa2(y_true, y_pred))
# Out:
# Quadratic_wieghted_kappa
# 0.012820512820512886

# %%
import numpy as np 
import matplotlib.pyplot as plt
import os
import wandb
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_mean_absolute_error', 'val_acc', 'val_loss_no_weight_decay', 'loss', 'mean_absolute_error', 'acc', 'loss_no_weight_decay', 'lr'])

# %%
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
