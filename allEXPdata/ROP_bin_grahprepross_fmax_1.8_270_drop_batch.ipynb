# %%
import keras
from keras.models import Sequential, Input, Model
from keras.losses import mean_squared_error
from keras.layers import  *
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, InputLayer
from keras.regularizers import L1L2, l2, l1
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from custom_pooling import RMSPooling2D
from keras.optimizers import SGD, Adam
from keras.layers import LeakyReLU
#from data import BALANCE_WEIGHTS
from keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
#import os
from datetime import datetime as dt
from custom_loss import WeightedCategoricalCrossEntropy
from VCM import VCM
import keras.backend as K
from Fractional_MAXPOOL import FractionalPooling2D
from QWK import QWK
import tensorflow as tf
from Fractional_MAXPOOL import FractionalPooling2D

import numpy as np 
import matplotlib.pyplot as plt
import os
import wandb
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
def get_experiment_id():
    time_str = dt.now().strftime('%Y-%m-%d-%H-%M-%S')
    experiment_id = 'base_{}'.format(time_str)
    return experiment_id
p_ratio=[1.0, 1.44, 1.73, 1.0]

model = Sequential()


model.add(Conv2D(16, (5, 5), activation='tanh', input_shape=(270, 270, 3)))
model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(BatchNormalization())
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(16, (3, 3), activation='tanh'))
model.add(Conv2D(16, (3, 3), activation='tanh'))
model.add(BatchNormalization())
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

#model.add(LeakyReLU(alpha=0.01))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))


model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(BatchNormalization())
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))


model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))
model.add(Dropout(0.5))
model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(BatchNormalization())
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))


#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(BatchNormalization())
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Dropout(0.5))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(BatchNormalization())

model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
#model.add(MaxPooling2D(pool_size=1))


model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))




model.add(Flatten())


#chnaged from 10 to 5 because an error 
model.add(Dense(2, activation='softmax'))

sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.count_params()
#adam = Adam(lr=0.0005, decay=1e-6)
#rmsprop
#Mloss = WeightedCategoricalCrossEntropy({0: 0.4125861396437394, 1: 1.4918664786083686, 2: 0.690426457789382, 3: 3.9541433021806855, 4: 4.885604311008468})
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['acc','mae'])
model.summary()
loss_no_weight_decay = model.total_loss - sum(model.losses)
model.metrics_tensors.append(loss_no_weight_decay)
model.metrics_names.append('loss_no_weight_decay')
#############################################################################################
#############################################################################################
#############################################################################################
#############################################################################################
#Preparing Data Augmentation Configuration 
train_datagen = ImageDataGenerator(
        rescale=1./255,
#        featurewise_center=True,
 #       samplewise_center=True,
        shear_range=0,
        zoom_range=0.0,#[1 / 1.15, 1.15],
        horizontal_flip=False,#True,
        rotation_range=0)#90,
#        validation_split=0.2)
"""
For the test set only rescale should be made 
"""
test_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/grahprepross/bin_bal/train",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="training")
#    save_to_dir="D:/Separating Images into subfolders/train_augmented")


#print(train_generator.class_indices)

valid_generator = valid_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/grahprepross/bin_bal/vald",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="validation")
#    save_to_dir="D:/Separating Images into subfolders/val_augmented"


test_generator = test_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/grahprepross/bin_bal/test",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=1,
    class_mode="categorical",
    shuffle=False,
    seed=42)
#    save_to_dir="D:/Separating Images into subfolders/test_augmented")


# Fitting/Training the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
experiment_id = get_experiment_id()
callbacks = [
    EarlyStopping(monitor='val_acc', patience=10, min_delta=0.001, verbose=1),
    ModelCheckpoint(experiment_id + "-val_acc_checkpoint.hdf5", monitor='val_acc', verbose=1, save_best_only=True, mode='max'),
    ReduceLROnPlateau(monitor='val_acc', factor=0.5, patience=7, verbose=1, mode='auto', min_delta=0.001, cooldown=0, min_lr=1e-7),
    VCM(valid_generator,STEP_SIZE_VALID)
    
]

class_weight_list = class_weight.compute_class_weight('balanced', np.unique(train_generator.classes), train_generator.classes)
class_weights = dict(zip(np.unique(train_generator.classes), class_weight_list))

history=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    #class_weight=class_weights,
                    callbacks=callbacks,
                    epochs=35  
)


# Evaluating the model 
#predicting output
#reseting the test generator before calling predict_generator, in order not to get weird output
test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 266, 266, 16)      1216
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 262, 262, 16)      6416
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 262, 262, 16)      64
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 260, 260, 16)      2320
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 258, 258, 16)      2320
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 258, 258, 16)      64
# _________________________________________________________________
# fractional_pooling2d_1 (Frac (None, 143, 143, 16)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 139, 139, 16)      6416
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 135, 135, 16)      6416
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 135, 135, 16)      64
# _________________________________________________________________
# fractional_pooling2d_2 (Frac (None, 75, 75, 16)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 75, 75, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 71, 71, 16)        6416
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 67, 67, 16)        6416
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 67, 67, 16)        64
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 65, 65, 32)        4640
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 63, 63, 32)        9248
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 63, 63, 32)        128
# _________________________________________________________________
# fractional_pooling2d_3 (Frac (None, 35, 35, 32)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 35, 35, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 33, 33, 64)        18496
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 31, 31, 64)        36928
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 31, 31, 64)        256
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 29, 29, 64)        36928
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 27, 27, 64)        36928
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 27, 27, 64)        256
# _________________________________________________________________
# fractional_pooling2d_4 (Frac (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 13, 13, 64)        36928
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 11, 11, 64)        36928
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 11, 11, 64)        256
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 9, 9, 64)          36928
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 7, 7, 64)          36928
# _________________________________________________________________
# fractional_pooling2d_5 (Frac (None, 3, 3, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 576)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1154
# =================================================================
# Total params: 331,122
# Trainable params: 330,546
# Non-trainable params: 576
# _________________________________________________________________
# Found 462 images belonging to 2 classes.
# Found 154 images belonging to 2 classes.
# Found 66 images belonging to 2 classes.
# Epoch 1/35
# 7/7 [==============================] - 19s 3s/step - loss: 0.7203 - acc: 0.5342 - mean_absolute_error: 0.4911 - loss_no_weight_decay: 0.7203 - val_loss: 0.8761 - val_acc: 0.3047 - val_mean_absolute_error: 0.5521 - val_loss_no_weight_decay: 0.8761
#
# Epoch 00001: val_acc improved from -inf to 0.30469, saving model to base_2020-05-12-20-58-25-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[26 36]
#  [51 15]]
# Epoch 2/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.5857 - acc: 0.7276 - mean_absolute_error: 0.4030 - loss_no_weight_decay: 0.5857 - val_loss: 0.7155 - val_acc: 0.5444 - val_mean_absolute_error: 0.4597 - val_loss_no_weight_decay: 0.7155
#
# Epoch 00002: val_acc improved from 0.30469 to 0.54444, saving model to base_2020-05-12-20-58-25-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[ 1 38]
#  [ 5 46]]
# Epoch 3/35
# 7/7 [==============================] - 13s 2s/step - loss: 0.4257 - acc: 0.7969 - mean_absolute_error: 0.2821 - loss_no_weight_decay: 0.4257 - val_loss: 0.8834 - val_acc: 0.5556 - val_mean_absolute_error: 0.4388 - val_loss_no_weight_decay: 0.8834
#
# Epoch 00003: val_acc improved from 0.54444 to 0.55556, saving model to base_2020-05-12-20-58-25-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[41  0]
#  [40  9]]
# Epoch 4/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.4170 - acc: 0.8136 - mean_absolute_error: 0.2678 - loss_no_weight_decay: 0.4170 - val_loss: 1.7947 - val_acc: 0.5234 - val_mean_absolute_error: 0.4778 - val_loss_no_weight_decay: 1.7947
#
# Epoch 00004: val_acc did not improve from 0.55556
# Confusion matrix:
#  [[67  0]
#  [61  0]]
# Epoch 5/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.4353 - acc: 0.7794 - mean_absolute_error: 0.2597 - loss_no_weight_decay: 0.4353 - val_loss: 0.9347 - val_acc: 0.5889 - val_mean_absolute_error: 0.4291 - val_loss_no_weight_decay: 0.9347
#
# Epoch 00005: val_acc improved from 0.55556 to 0.58889, saving model to base_2020-05-12-20-58-25-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[44  4]
#  [23 19]]
# Epoch 6/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.3071 - acc: 0.8819 - mean_absolute_error: 0.2082 - loss_no_weight_decay: 0.3071 - val_loss: 0.7410 - val_acc: 0.5333 - val_mean_absolute_error: 0.4901 - val_loss_no_weight_decay: 0.7410
#
# Epoch 00006: val_acc did not improve from 0.58889
# Confusion matrix:
#  [[ 5 41]
#  [ 1 43]]
# Epoch 7/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.2529 - acc: 0.9048 - mean_absolute_error: 0.1663 - loss_no_weight_decay: 0.2529 - val_loss: 0.6543 - val_acc: 0.6406 - val_mean_absolute_error: 0.4671 - val_loss_no_weight_decay: 0.6543
#
# Epoch 00007: val_acc improved from 0.58889 to 0.64062, saving model to base_2020-05-12-20-58-25-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[15 47]
#  [ 4 62]]
# Epoch 8/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.1933 - acc: 0.9250 - mean_absolute_error: 0.1304 - loss_no_weight_decay: 0.1933 - val_loss: 0.6212 - val_acc: 0.7222 - val_mean_absolute_error: 0.4383 - val_loss_no_weight_decay: 0.6212
#
# Epoch 00008: val_acc improved from 0.64062 to 0.72222, saving model to base_2020-05-12-20-58-25-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[20 23]
#  [ 8 39]]
# Epoch 9/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.1655 - acc: 0.9271 - mean_absolute_error: 0.1054 - loss_no_weight_decay: 0.1655 - val_loss: 0.6498 - val_acc: 0.5556 - val_mean_absolute_error: 0.4504 - val_loss_no_weight_decay: 0.6498
#
# Epoch 00009: val_acc did not improve from 0.72222
# Confusion matrix:
#  [[36  3]
#  [35 16]]
# Epoch 10/35
# 7/7 [==============================] - 13s 2s/step - loss: 0.0879 - acc: 0.9683 - mean_absolute_error: 0.0648 - loss_no_weight_decay: 0.0879 - val_loss: 1.4516 - val_acc: 0.5547 - val_mean_absolute_error: 0.3983 - val_loss_no_weight_decay: 1.4516
#
# Epoch 00010: val_acc did not improve from 0.72222
# Confusion matrix:
#  [[64  0]
#  [57  7]]
# Epoch 11/35
# 7/7 [==============================] - 13s 2s/step - loss: 0.0729 - acc: 0.9796 - mean_absolute_error: 0.0492 - loss_no_weight_decay: 0.0729 - val_loss: 3.9421 - val_acc: 0.4333 - val_mean_absolute_error: 0.5665 - val_loss_no_weight_decay: 3.9421
#
# Epoch 00011: val_acc did not improve from 0.72222
# Confusion matrix:
#  [[50  0]
#  [40  0]]
# Epoch 12/35
# 7/7 [==============================] - 14s 2s/step - loss: 0.0403 - acc: 0.9821 - mean_absolute_error: 0.0293 - loss_no_weight_decay: 0.0403 - val_loss: 3.4196 - val_acc: 0.5333 - val_mean_absolute_error: 0.4667 - val_loss_no_weight_decay: 3.4196
#
# Epoch 00012: val_acc did not improve from 0.72222
# Confusion matrix:
#  [[40  0]
#  [50  0]]
# Epoch 13/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.1031 - acc: 0.9590 - mean_absolute_error: 0.0517 - loss_no_weight_decay: 0.1031 - val_loss: 3.2564 - val_acc: 0.5156 - val_mean_absolute_error: 0.4828 - val_loss_no_weight_decay: 3.2564
#
# Epoch 00013: val_acc did not improve from 0.72222
# Confusion matrix:
#  [[62  0]
#  [66  0]]
# Epoch 14/35
# 7/7 [==============================] - 11s 2s/step - loss: 0.0767 - acc: 0.9768 - mean_absolute_error: 0.0487 - loss_no_weight_decay: 0.0767 - val_loss: 3.7773 - val_acc: 0.4667 - val_mean_absolute_error: 0.5331 - val_loss_no_weight_decay: 3.7773
#
# Epoch 00014: val_acc did not improve from 0.72222
# Confusion matrix:
#  [[44  0]
#  [46  0]]
# Epoch 15/35
# 7/7 [==============================] - 13s 2s/step - loss: 0.0432 - acc: 0.9866 - mean_absolute_error: 0.0323 - loss_no_weight_decay: 0.0432 - val_loss: 0.6343 - val_acc: 0.5111 - val_mean_absolute_error: 0.4319 - val_loss_no_weight_decay: 0.6343
#
# Epoch 00015: val_acc did not improve from 0.72222
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Confusion matrix:
#  [[49  1]
#  [40  0]]
# Epoch 16/35
# 7/7 [==============================] - 13s 2s/step - loss: 0.0573 - acc: 0.9796 - mean_absolute_error: 0.0336 - loss_no_weight_decay: 0.0573 - val_loss: 2.0323 - val_acc: 0.5000 - val_mean_absolute_error: 0.4446 - val_loss_no_weight_decay: 2.0323
#
# Epoch 00016: val_acc did not improve from 0.72222
# Confusion matrix:
#  [[58  0]
#  [67  3]]
# Epoch 17/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.0610 - acc: 0.9724 - mean_absolute_error: 0.0401 - loss_no_weight_decay: 0.0610 - val_loss: 3.6241 - val_acc: 0.5111 - val_mean_absolute_error: 0.4889 - val_loss_no_weight_decay: 3.6241
#
# Epoch 00017: val_acc did not improve from 0.72222
# Confusion matrix:
#  [[45  0]
#  [45  0]]
# Epoch 18/35
# 7/7 [==============================] - 13s 2s/step - loss: 0.0238 - acc: 0.9911 - mean_absolute_error: 0.0196 - loss_no_weight_decay: 0.0238 - val_loss: 3.6201 - val_acc: 0.5111 - val_mean_absolute_error: 0.4889 - val_loss_no_weight_decay: 3.6201
#
# Epoch 00018: val_acc did not improve from 0.72222
# Confusion matrix:
#  [[47  0]
#  [43  0]]
# Epoch 19/35
# 7/7 [==============================] - 11s 2s/step - loss: 0.0249 - acc: 0.9884 - mean_absolute_error: 0.0180 - loss_no_weight_decay: 0.0249 - val_loss: 3.6941 - val_acc: 0.5000 - val_mean_absolute_error: 0.5000 - val_loss_no_weight_decay: 3.6941
#
# Epoch 00019: val_acc did not improve from 0.72222
# Confusion matrix:
#  [[66  0]
#  [62  0]]
# Epoch 20/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.0306 - acc: 0.9794 - mean_absolute_error: 0.0213 - loss_no_weight_decay: 0.0306 - val_loss: 3.5736 - val_acc: 0.5222 - val_mean_absolute_error: 0.4778 - val_loss_no_weight_decay: 3.5736
#
# Epoch 00020: val_acc did not improve from 0.72222
# Confusion matrix:
#  [[40  0]
#  [50  0]]
# Epoch 21/35
# 7/7 [==============================] - 13s 2s/step - loss: 0.0100 - acc: 0.9978 - mean_absolute_error: 0.0088 - loss_no_weight_decay: 0.0100 - val_loss: 3.7789 - val_acc: 0.4778 - val_mean_absolute_error: 0.5216 - val_loss_no_weight_decay: 3.7789
#
# Epoch 00021: val_acc did not improve from 0.72222
# Confusion matrix:
#  [[43  0]
#  [47  0]]
# Epoch 22/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.0105 - acc: 0.9977 - mean_absolute_error: 0.0091 - loss_no_weight_decay: 0.0105 - val_loss: 3.2395 - val_acc: 0.4766 - val_mean_absolute_error: 0.5151 - val_loss_no_weight_decay: 3.2395
#
# Epoch 00022: val_acc did not improve from 0.72222
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Confusion matrix:
#  [[66  0]
#  [62  0]]
# Epoch 23/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.0189 - acc: 0.9955 - mean_absolute_error: 0.0125 - loss_no_weight_decay: 0.0189 - val_loss: 2.9254 - val_acc: 0.5111 - val_mean_absolute_error: 0.4776 - val_loss_no_weight_decay: 2.9254
#
# Epoch 00023: val_acc did not improve from 0.72222
# Confusion matrix:
#  [[44  0]
#  [46  0]]
# Epoch 24/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.0258 - acc: 0.9932 - mean_absolute_error: 0.0144 - loss_no_weight_decay: 0.0258 - val_loss: 1.8656 - val_acc: 0.5222 - val_mean_absolute_error: 0.4457 - val_loss_no_weight_decay: 1.8656
#
# Epoch 00024: val_acc did not improve from 0.72222
# Confusion matrix:
#  [[47  0]
#  [43  0]]
# Epoch 25/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.0214 - acc: 0.9955 - mean_absolute_error: 0.0170 - loss_no_weight_decay: 0.0214 - val_loss: 2.9901 - val_acc: 0.5312 - val_mean_absolute_error: 0.4614 - val_loss_no_weight_decay: 2.9901
#
# Epoch 00025: val_acc did not improve from 0.72222
# Confusion matrix:
#  [[64  0]
#  [64  0]]
# Epoch 26/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.0069 - acc: 0.9977 - mean_absolute_error: 0.0061 - loss_no_weight_decay: 0.0069 - val_loss: 3.3404 - val_acc: 0.5111 - val_mean_absolute_error: 0.4861 - val_loss_no_weight_decay: 3.3404
#
# Epoch 00026: val_acc did not improve from 0.72222
# Confusion matrix:
#  [[44  0]
#  [46  0]]
# Epoch 27/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.0231 - acc: 0.9885 - mean_absolute_error: 0.0147 - loss_no_weight_decay: 0.0231 - val_loss: 2.6742 - val_acc: 0.4444 - val_mean_absolute_error: 0.5241 - val_loss_no_weight_decay: 2.6742
#
# Epoch 00027: val_acc did not improve from 0.72222
# Confusion matrix:
#  [[46  0]
#  [44  0]]
# Epoch 28/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.0595 - acc: 0.9885 - mean_absolute_error: 0.0227 - loss_no_weight_decay: 0.0595 - val_loss: 1.0245 - val_acc: 0.5156 - val_mean_absolute_error: 0.4112 - val_loss_no_weight_decay: 1.0245
#
# Epoch 00028: val_acc did not improve from 0.72222
# Confusion matrix:
#  [[66  0]
#  [61  1]]
# Epoch 29/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.0156 - acc: 0.9977 - mean_absolute_error: 0.0126 - loss_no_weight_decay: 0.0156 - val_loss: 0.9421 - val_acc: 0.4889 - val_mean_absolute_error: 0.4233 - val_loss_no_weight_decay: 0.9421
#
# Epoch 00029: val_acc did not improve from 0.72222
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Confusion matrix:
#  [[51  0]
#  [39  0]]
# Epoch 30/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.0165 - acc: 0.9955 - mean_absolute_error: 0.0126 - loss_no_weight_decay: 0.0165 - val_loss: 1.3392 - val_acc: 0.5111 - val_mean_absolute_error: 0.4274 - val_loss_no_weight_decay: 1.3392
#
# Epoch 00030: val_acc did not improve from 0.72222
# Confusion matrix:
#  [[45  0]
#  [44  1]]
# Epoch 31/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.0114 - acc: 1.0000 - mean_absolute_error: 0.0103 - loss_no_weight_decay: 0.0114 - val_loss: 2.0361 - val_acc: 0.4844 - val_mean_absolute_error: 0.4780 - val_loss_no_weight_decay: 2.0361
# Epoch 00031: val_acc did not improve from 0.72222
# Confusion matrix:
#  [[66  0]
#  [60  2]]
# Epoch 32/35
# 7/7 [==============================] - 13s 2s/step - loss: 0.0130 - acc: 0.9933 - mean_absolute_error: 0.0103 - loss_no_weight_decay: 0.0130 - val_loss: 2.2723 - val_acc: 0.5333 - val_mean_absolute_error: 0.4512 - val_loss_no_weight_decay: 2.2723
#
# Epoch 00032: val_acc did not improve from 0.72222
# Confusion matrix:
#  [[50  0]
#  [40  0]]
# Epoch 33/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.0096 - acc: 1.0000 - mean_absolute_error: 0.0087 - loss_no_weight_decay: 0.0096 - val_loss: 2.8039 - val_acc: 0.5222 - val_mean_absolute_error: 0.4618 - val_loss_no_weight_decay: 2.8039
#
# Epoch 00033: val_acc did not improve from 0.72222
# Confusion matrix:
#  [[43  0]
#  [47  0]]
# Epoch 34/35
# 7/7 [==============================] - 12s 2s/step - loss: 0.0230 - acc: 0.9977 - mean_absolute_error: 0.0189 - loss_no_weight_decay: 0.0230 - val_loss: 2.4235 - val_acc: 0.5625 - val_mean_absolute_error: 0.4296 - val_loss_no_weight_decay: 2.4235
#
# Epoch 00034: val_acc did not improve from 0.72222
# Confusion matrix:
#  [[65  0]
#  [55  8]]
# Epoch 35/35
# 7/7 [==============================] - 14s 2s/step - loss: 0.0085 - acc: 0.9978 - mean_absolute_error: 0.0074 - loss_no_weight_decay: 0.0085 - val_loss: 2.2129 - val_acc: 0.5667 - val_mean_absolute_error: 0.4131 - val_loss_no_weight_decay: 2.2129
#
# Epoch 00035: val_acc did not improve from 0.72222
# Confusion matrix:
#  [[45  0]
#  [37  8]]
# Epoch 00035: early stopping
# 66/66 [==============================] - 1s 10ms/step
# 66/66 [==============================] - 1s 9ms/step
# Test loss: 3.1205150694954544
# Test accuracy: 0.5
# Confusion Matrix
# [[33  0]
#  [33  0]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67        33
#            1       0.00      0.00      0.00        33
#
#     accuracy                           0.50        66
#    macro avg       0.25      0.50      0.33        66
# weighted avg       0.25      0.50      0.33        66
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
from Kappa_Skl import kappa
def kappa2(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    if len(y_true.shape) > 1 and y_true.shape[1] > 1:
        y_true = y_true.dot(range(y_true.shape[1]))
    if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
        y_pred = y_pred.dot(range(y_pred.shape[1]))
    try:
        return kappa(y_true, y_pred, weights='quadratic')
    except IndexError:
        return np.nan
    
print('Quadratic_wieghted_kappa')
print(kappa2(y_true, y_pred))
# Out:
# Quadratic_wieghted_kappa
# 0.0

# %%
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
