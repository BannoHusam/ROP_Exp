# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, InputLayer
from keras.regularizers import L1L2, l2, l1
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from custom_pooling import RMSPooling2D
from keras.optimizers import SGD, Adam
from keras.layers import LeakyReLU
#from data import BALANCE_WEIGHTS
from keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
#import os
from datetime import datetime as dt
from custom_loss import WeightedCategoricalCrossEntropy
from VCM import VCM
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
def get_experiment_id():
    time_str = dt.now().strftime('%Y-%m-%d-%H-%M-%S')
    experiment_id = 'base_{}'.format(time_str)
    return experiment_id
p_ratio=[1.0, 1.44, 1.73, 1.0]

model = Sequential()


model.add(Conv2D(16, (5, 5), activation='tanh', input_shape=(270, 270, 3)))
model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(16, (3, 3), activation='tanh'))
model.add(Conv2D(16, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))

#model.add(LeakyReLU(alpha=0.01))


model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))



model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))          
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(MaxPooling2D(pool_size=2))
#model.add(MaxPooling2D(pool_size=1))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
model.add(MaxPooling2D(pool_size=2))

model.add(Flatten())


#chnaged from 10 to 5 because an error 
model.add(Dense(2, activation='softmax'))

sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.count_params()
#adam = Adam(lr=0.0005, decay=1e-6)
#rmsprop
#Mloss = WeightedCategoricalCrossEntropy({0: 0.4125861396437394, 1: 1.4918664786083686, 2: 0.690426457789382, 3: 3.9541433021806855, 4: 4.885604311008468})
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
model.summary()
loss_no_weight_decay = model.total_loss - sum(model.losses)
model.metrics_tensors.append(loss_no_weight_decay)
model.metrics_names.append('loss_no_weight_decay')
#############################################################################################
#############################################################################################
#############################################################################################
#############################################################################################
#Preparing Data Augmentation Configuration 
train_datagen = ImageDataGenerator(
        rescale=1./255,
#        featurewise_center=True,
 #       samplewise_center=True,
        shear_range=0,
        zoom_range=0.0,#[1 / 1.15, 1.15],
        horizontal_flip=False,#True,
        rotation_range=0)#90,
#        validation_split=0.2)
"""
For the test set only rescale should be made 
"""
test_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas_noch/train",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="training")
#    save_to_dir="D:/Separating Images into subfolders/train_augmented")


#print(train_generator.class_indices)

valid_generator = valid_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas_noch/vald",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="validation")
#    save_to_dir="D:/Separating Images into subfolders/val_augmented"


test_generator = test_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas_noch/test",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=1,
    class_mode="categorical",
    shuffle=False,
    seed=42)
#    save_to_dir="D:/Separating Images into subfolders/test_augmented")


# Fitting/Training the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
experiment_id = get_experiment_id()
callbacks = [
    EarlyStopping(monitor='val_acc', patience=50, min_delta=0.001, verbose=1),
    ModelCheckpoint(experiment_id + "-val_acc_checkpoint.hdf5", monitor='val_acc', verbose=1, save_best_only=True, mode='auto'),
    ReduceLROnPlateau(monitor='val_acc', factor=0.5, patience=7, verbose=1, mode='auto', min_delta=0.001, cooldown=0, min_lr=1e-7),
    VCM(valid_generator,STEP_SIZE_VALID)
    
]

class_weight_list = class_weight.compute_class_weight('balanced', np.unique(train_generator.classes), train_generator.classes)
class_weights = dict(zip(np.unique(train_generator.classes), class_weight_list))

history=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    class_weight=class_weights,
                    callbacks=callbacks,
                    epochs=35  
)


# Evaluating the model 
#predicting output
#reseting the test generator before calling predict_generator, in order not to get weird output
test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 266, 266, 16)      1216
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 262, 262, 16)      6416
# _________________________________________________________________
# input_1 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 260, 260, 16)      2320
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 258, 258, 16)      2320
# _________________________________________________________________
# input_2 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 254, 254, 16)      6416
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 250, 250, 16)      6416
# _________________________________________________________________
# input_3 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 246, 246, 16)      6416
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 242, 242, 16)      6416
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 121, 121, 16)      0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 119, 119, 32)      4640
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 117, 117, 32)      9248
# _________________________________________________________________
# input_4 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 115, 115, 32)      9248
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 113, 113, 32)      9248
# _________________________________________________________________
# input_5 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 111, 111, 32)      9248
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 109, 109, 32)      9248
# _________________________________________________________________
# input_6 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 107, 107, 32)      9248
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 105, 105, 32)      9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 52, 52, 32)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 50, 50, 64)        18496
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 48, 48, 64)        36928
# _________________________________________________________________
# input_7 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 46, 46, 64)        36928
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 44, 44, 64)        36928
# _________________________________________________________________
# input_8 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 42, 42, 64)        36928
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 40, 40, 64)        36928
# _________________________________________________________________
# input_9 (InputLayer)         multiple                  0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 20, 20, 64)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 18, 18, 64)        36928
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# input_10 (InputLayer)        multiple                  0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 14, 14, 64)        36928
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 12, 12, 64)        36928
# _________________________________________________________________
# input_11 (InputLayer)        multiple                  0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 4610
# =================================================================
# Total params: 462,770
# Trainable params: 462,770
# Non-trainable params: 0
# _________________________________________________________________
# Found 582 images belonging to 2 classes.
# Found 78 images belonging to 2 classes.
# Found 121 images belonging to 2 classes.
# Epoch 1/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.7095 - acc: 0.5337 - loss_no_weight_decay: 0.7095 - val_loss: 0.6949 - val_acc: 0.4219 - val_loss_no_weight_decay: 0.6949
#
# Epoch 00001: val_acc improved from -inf to 0.42188, saving model to base_2020-05-11-21-42-44-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[10 38]
#  [ 0 16]]
# Epoch 2/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.6917 - acc: 0.4849 - loss_no_weight_decay: 0.6917 - val_loss: 0.7079 - val_acc: 0.2857 - val_loss_no_weight_decay: 0.7079
#
# Epoch 00002: val_acc did not improve from 0.42188
# Confusion matrix:
#  [[ 0 11]
#  [ 0  3]]
# Epoch 3/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.6912 - acc: 0.5358 - loss_no_weight_decay: 0.6912 - val_loss: 0.6918 - val_acc: 0.5156 - val_loss_no_weight_decay: 0.6918
#
# Epoch 00003: val_acc improved from 0.42188 to 0.51562, saving model to base_2020-05-11-21-42-44-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[18 31]
#  [ 2 13]]
# Epoch 4/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.6890 - acc: 0.4786 - loss_no_weight_decay: 0.6890 - val_loss: 0.6909 - val_acc: 0.5714 - val_loss_no_weight_decay: 0.6909
#
# Epoch 00004: val_acc improved from 0.51562 to 0.57143, saving model to base_2020-05-11-21-42-44-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[6 6]
#  [0 2]]
# Epoch 5/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.6819 - acc: 0.6580 - loss_no_weight_decay: 0.6819 - val_loss: 0.6735 - val_acc: 0.7344 - val_loss_no_weight_decay: 0.6735
#
# Epoch 00005: val_acc improved from 0.57143 to 0.73438, saving model to base_2020-05-11-21-42-44-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[32 16]
#  [ 3 13]]
# Epoch 6/35
# 9/9 [==============================] - 11s 1s/step - loss: 0.6733 - acc: 0.6900 - loss_no_weight_decay: 0.6733 - val_loss: 0.6393 - val_acc: 0.7143 - val_loss_no_weight_decay: 0.6393
#
# Epoch 00006: val_acc did not improve from 0.73438
# Confusion matrix:
#  [[6 4]
#  [0 4]]
# Epoch 7/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.6709 - acc: 0.5913 - loss_no_weight_decay: 0.6709 - val_loss: 0.6088 - val_acc: 0.7812 - val_loss_no_weight_decay: 0.6088
#
# Epoch 00007: val_acc improved from 0.73438 to 0.78125, saving model to base_2020-05-11-21-42-44-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[38  8]
#  [ 7 11]]
# Epoch 8/35
# 9/9 [==============================] - 11s 1s/step - loss: 0.6321 - acc: 0.6882 - loss_no_weight_decay: 0.6321 - val_loss: 0.5430 - val_acc: 0.7143 - val_loss_no_weight_decay: 0.5430
#
# Epoch 00008: val_acc did not improve from 0.78125
# Confusion matrix:
#  [[8 1]
#  [3 2]]
# Epoch 9/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.6336 - acc: 0.6457 - loss_no_weight_decay: 0.6336 - val_loss: 0.6098 - val_acc: 0.5938 - val_loss_no_weight_decay: 0.6098
#
# Epoch 00009: val_acc did not improve from 0.78125
# Confusion matrix:
#  [[24 26]
#  [ 1 13]]
# Epoch 10/35
# 9/9 [==============================] - 10s 1s/step - loss: 0.6099 - acc: 0.6650 - loss_no_weight_decay: 0.6099 - val_loss: 0.5635 - val_acc: 0.7143 - val_loss_no_weight_decay: 0.5635
#
# Epoch 00010: val_acc did not improve from 0.78125
# Confusion matrix:
#  [[6 5]
#  [0 3]]
# Epoch 11/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.5949 - acc: 0.6731 - loss_no_weight_decay: 0.5949 - val_loss: 0.5180 - val_acc: 0.7344 - val_loss_no_weight_decay: 0.5180
#
# Epoch 00011: val_acc did not improve from 0.78125
# Confusion matrix:
#  [[38  8]
#  [ 9  9]]
# Epoch 12/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.5837 - acc: 0.7216 - loss_no_weight_decay: 0.5837 - val_loss: 0.6146 - val_acc: 0.5714 - val_loss_no_weight_decay: 0.6146
#
# Epoch 00012: val_acc did not improve from 0.78125
# Confusion matrix:
#  [[5 6]
#  [1 2]]
# Epoch 13/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.5510 - acc: 0.7135 - loss_no_weight_decay: 0.5510 - val_loss: 0.4649 - val_acc: 0.8125 - val_loss_no_weight_decay: 0.4649
#
# Epoch 00013: val_acc improved from 0.78125 to 0.81250, saving model to base_2020-05-11-21-42-44-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[39  8]
#  [ 5 12]]
# Epoch 14/35
# 9/9 [==============================] - 11s 1s/step - loss: 0.5460 - acc: 0.7189 - loss_no_weight_decay: 0.5460 - val_loss: 0.5332 - val_acc: 0.6429 - val_loss_no_weight_decay: 0.5332
#
# Epoch 00014: val_acc did not improve from 0.81250
# Confusion matrix:
#  [[11  2]
#  [ 0  1]]
# Epoch 15/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.5026 - acc: 0.7708 - loss_no_weight_decay: 0.5026 - val_loss: 0.4768 - val_acc: 0.7500 - val_loss_no_weight_decay: 0.4768
#
# Epoch 00015: val_acc did not improve from 0.81250
# Confusion matrix:
#  [[33 15]
#  [ 4 12]]
# Epoch 16/35
# 9/9 [==============================] - 11s 1s/step - loss: 0.5024 - acc: 0.7665 - loss_no_weight_decay: 0.5024 - val_loss: 0.3862 - val_acc: 0.8571 - val_loss_no_weight_decay: 0.3862
#
# Epoch 00016: val_acc improved from 0.81250 to 0.85714, saving model to base_2020-05-11-21-42-44-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[10  2]
#  [ 1  1]]
# Epoch 17/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.4930 - acc: 0.7574 - loss_no_weight_decay: 0.4930 - val_loss: 0.4391 - val_acc: 0.8125 - val_loss_no_weight_decay: 0.4391
#
# Epoch 00017: val_acc did not improve from 0.85714
# Confusion matrix:
#  [[33 14]
#  [ 2 15]]
# Epoch 18/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.5219 - acc: 0.7265 - loss_no_weight_decay: 0.5219 - val_loss: 0.6764 - val_acc: 0.5714 - val_loss_no_weight_decay: 0.6764
#
# Epoch 00018: val_acc did not improve from 0.85714
# Confusion matrix:
#  [[6 6]
#  [0 2]]
# Epoch 19/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.7137 - acc: 0.5449 - loss_no_weight_decay: 0.7137 - val_loss: 0.5910 - val_acc: 0.7344 - val_loss_no_weight_decay: 0.5910
#
# Epoch 00019: val_acc did not improve from 0.85714
# Confusion matrix:
#  [[32 14]
#  [ 3 15]]
# Epoch 20/35
# 9/9 [==============================] - 11s 1s/step - loss: 0.6085 - acc: 0.6801 - loss_no_weight_decay: 0.6085 - val_loss: 0.5724 - val_acc: 0.5000 - val_loss_no_weight_decay: 0.5724
#
# Epoch 00020: val_acc did not improve from 0.85714
# Confusion matrix:
#  [[7 4]
#  [2 1]]
# Epoch 21/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.5679 - acc: 0.7029 - loss_no_weight_decay: 0.5679 - val_loss: 0.4981 - val_acc: 0.7344 - val_loss_no_weight_decay: 0.4981
#
# Epoch 00021: val_acc did not improve from 0.85714
# Confusion matrix:
#  [[32 16]
#  [ 1 15]]
# Epoch 22/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.5513 - acc: 0.7118 - loss_no_weight_decay: 0.5513 - val_loss: 0.6400 - val_acc: 0.5000 - val_loss_no_weight_decay: 0.6400
#
# Epoch 00022: val_acc did not improve from 0.85714
# Confusion matrix:
#  [[3 6]
#  [0 5]]
# Epoch 23/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.5874 - acc: 0.6629 - loss_no_weight_decay: 0.5874 - val_loss: 0.4577 - val_acc: 0.7031 - val_loss_no_weight_decay: 0.4577
#
# Epoch 00023: val_acc did not improve from 0.85714
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Confusion matrix:
#  [[30 16]
#  [ 3 15]]
# Epoch 24/35
# 9/9 [==============================] - 11s 1s/step - loss: 0.6280 - acc: 0.6832 - loss_no_weight_decay: 0.6280 - val_loss: 0.6651 - val_acc: 0.5714 - val_loss_no_weight_decay: 0.6651
#
# Epoch 00024: val_acc did not improve from 0.85714
# Confusion matrix:
#  [[6 6]
#  [0 2]]
# Epoch 25/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.5350 - acc: 0.7413 - loss_no_weight_decay: 0.5350 - val_loss: 0.5672 - val_acc: 0.6406 - val_loss_no_weight_decay: 0.5672
#
# Epoch 00025: val_acc did not improve from 0.85714
# Confusion matrix:
#  [[26 23]
#  [ 0 15]]
# Epoch 26/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.5494 - acc: 0.7089 - loss_no_weight_decay: 0.5494 - val_loss: 0.5620 - val_acc: 0.5714 - val_loss_no_weight_decay: 0.5620
#
# Epoch 00026: val_acc did not improve from 0.85714
# Confusion matrix:
#  [[7 3]
#  [0 4]]
# Epoch 27/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.4965 - acc: 0.7577 - loss_no_weight_decay: 0.4965 - val_loss: 0.5384 - val_acc: 0.6094 - val_loss_no_weight_decay: 0.5384
#
# Epoch 00027: val_acc did not improve from 0.85714
# Confusion matrix:
#  [[27 23]
#  [ 2 12]]
# Epoch 28/35
# 9/9 [==============================] - 11s 1s/step - loss: 0.5295 - acc: 0.7223 - loss_no_weight_decay: 0.5295 - val_loss: 0.4095 - val_acc: 0.7857 - val_loss_no_weight_decay: 0.4095
#
# Epoch 00028: val_acc did not improve from 0.85714
# Confusion matrix:
#  [[8 5]
#  [0 1]]
# Epoch 29/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.5004 - acc: 0.7731 - loss_no_weight_decay: 0.5004 - val_loss: 0.5525 - val_acc: 0.6562 - val_loss_no_weight_decay: 0.5525
#
# Epoch 00029: val_acc did not improve from 0.85714
# Confusion matrix:
#  [[24 25]
#  [ 0 15]]
# Epoch 30/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.5145 - acc: 0.7361 - loss_no_weight_decay: 0.5145 - val_loss: 0.7731 - val_acc: 0.5000 - val_loss_no_weight_decay: 0.7731
#
# Epoch 00030: val_acc did not improve from 0.85714
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Confusion matrix:
#  [[4 5]
#  [0 5]]
# Epoch 31/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.5003 - acc: 0.7587 - loss_no_weight_decay: 0.5003 - val_loss: 0.4641 - val_acc: 0.7344 - val_loss_no_weight_decay: 0.4641
#
# Epoch 00031: val_acc did not improve from 0.85714
# Confusion matrix:
#  [[35 16]
#  [ 1 12]]
# Epoch 32/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.5445 - acc: 0.6673 - loss_no_weight_decay: 0.5445 - val_loss: 0.5602 - val_acc: 0.6429 - val_loss_no_weight_decay: 0.5602
#
# Epoch 00032: val_acc did not improve from 0.85714
# Confusion matrix:
#  [[5 5]
#  [0 4]]
# Epoch 33/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.5025 - acc: 0.7416 - loss_no_weight_decay: 0.5025 - val_loss: 0.4695 - val_acc: 0.6719 - val_loss_no_weight_decay: 0.4695
#
# Epoch 00033: val_acc did not improve from 0.85714
# Confusion matrix:
#  [[27 21]
#  [ 1 15]]
# Epoch 34/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.5034 - acc: 0.7448 - loss_no_weight_decay: 0.5034 - val_loss: 0.5789 - val_acc: 0.6429 - val_loss_no_weight_decay: 0.5789
# Epoch 00034: val_acc did not improve from 0.85714
# Confusion matrix:
#  [[4 7]
#  [0 3]]
# Epoch 35/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.4954 - acc: 0.7426 - loss_no_weight_decay: 0.4954 - val_loss: 0.4797 - val_acc: 0.7031 - val_loss_no_weight_decay: 0.4797
#
# Epoch 00035: val_acc did not improve from 0.85714
# Confusion matrix:
#  [[29 19]
#  [ 0 16]]
# 121/121 [==============================] - 4s 35ms/step
# 121/121 [==============================] - 4s 35ms/step
# Test loss: 0.5788212184186193
# Test accuracy: 0.6198347107438017
# Confusion Matrix
# [[48 40]
#  [ 6 27]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.89      0.55      0.68        88
#            1       0.40      0.82      0.54        33
#
#     accuracy                           0.62       121
#    macro avg       0.65      0.68      0.61       121
# weighted avg       0.76      0.62      0.64       121

# %%
import numpy as np 
import matplotlib.pyplot as plt
import os
import wandb
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_acc', 'val_loss_no_weight_decay', 'loss', 'acc', 'loss_no_weight_decay', 'lr'])

# %%
from Kappa_Skl import kappa
def kappa2(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    if len(y_true.shape) > 1 and y_true.shape[1] > 1:
        y_true = y_true.dot(range(y_true.shape[1]))
    if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
        y_pred = y_pred.dot(range(y_pred.shape[1]))
    try:
        return kappa(y_true, y_pred, weights='quadratic')
    except IndexError:
        return np.nan
    
print('Quadratic_wieghted_kappa')
print(kappa2(y_true, y_pred))
# Out:
# Quadratic_wieghted_kappa
# 0.27507163323782247
