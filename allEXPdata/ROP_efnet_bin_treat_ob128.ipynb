# %%
import efficientnet.keras as efn
from keras.models import Model, model_from_json
from keras.regularizers import l1_l2
from keras.layers import Dense, Dropout
from keras.optimizers import SGD, Adam
import pandas as pd
from keras_preprocessing.image import ImageDataGenerator
from datetime import datetime as dt
from sklearn.utils import class_weight
from keras.callbacks import EarlyStopping, ModelCheckpoint,LearningRateScheduler, TensorBoard
import keras.backend as K
from VCM import VCM 
from keras.initializers import Constant,Orthogonal
from keras import regularizers
from Kappa_Skl import kappa
import keras.backend as K
import matplotlib.pyplot as plt
import itertools
from Homotopy import Homotopy 
from QWK import QWK
import tensorflow as tf
from Fractional_MAXPOOL import FractionalPooling2D

import numpy as np 
import matplotlib.pyplot as plt
import os
import wandb
#from wandb.keras import WandbCallback
#wandb.init(project="rop")


top_layers_checkpoint_path = 'cp.top.best.hdf5'
fine_tuned_checkpoint_path = 'cp.fine_tuned.best.hdf5'
new_extended_inception_weights = 'final_weights.hdf5'





def get_experiment_id():
    time_str = dt.now().strftime('%Y-%m-%d-%H-%M-%S')
    experiment_id = 'base_{}'.format(time_str)
    return experiment_id

#def scheduler(epoch):
#    if epoch == 150:
#        K.set_value(model.optimizer.lr, 0.00003)
#    return K.get_value(model.optimizer.lr)


def create_model():
    base_model = efn.EfficientNetB0(weights=None,
                        include_top=False,
                        input_shape=(128, 128, 3), pooling='avg')
#    base_model._layers.pop()
#    model2 = Model(base_model.input, base_model.layers[-1].output)
##    base_model = InceptionV3(weights=None , include_top=False, input_tensor=None, input_shape=(299, 299, 3), pooling='avg') 
    x = base_model.output
    x = Dense(2, activation="softmax")(x)
    model = Model(inputs = base_model.input, outputs = x)
    model.load_weights('base_2019-12-11-23-01-58-val_kappa_checkpoint.hdf5')
#    model._layers.pop()
#    x = Model(model.input, model.layers[-1].output)
#    model.save_weights("tmp.h5")
#    top_layers_checkpoint_path = 'cp.top.best.hdf5'

#    # first: train only the top layers (which were randomly initialized)
#    # i.e. freeze all convolutional InceptionV3 layers
    for layer in base_model.layers:
        layer.trainable = False
#    
#    
#
##    regularizer = l1_l2(l1=0.0005, l2=0.0005)
##    for layer in model.layers:
##        for attr in ['kernel_regularizer', 'bias_regularizer']:
##            if hasattr(layer, attr) and layer.trainable:
##                setattr(layer, attr, regularizer)
#
##
#    out = model_from_json(model.to_json())
#    out.load_weights("tmp.h5", by_name=True)
#
    return model


model = create_model()




radam = Adam(lr=0.0014339, beta_1=0.9, beta_2=0.999, epsilon=0.1, decay=1e-6, amsgrad=False)
model.compile(loss='categorical_crossentropy', optimizer=radam, metrics=['mae','acc'])

#sgd = SGD(lr=0.0003, decay=1e-6, momentum=0.9, nesterov=True)
#model.compile(loss='mse', optimizer=sgd, metrics=['mae', 'acc'])

experiment_id = get_experiment_id()


train_datagen = ImageDataGenerator(
        rescale=1./255,
#        featurewise_center=True,
 #       samplewise_center=True,
        shear_range=0,
        zoom_range=0.0,#[1 / 1.15, 1.15],
        horizontal_flip=False,#True,
        rotation_range=0)#90,
#        validation_split=0.2)
"""
For the test set only rescale should be made 
"""
test_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_class_treatment/train",
    target_size=(128, 128),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="training")
#    save_to_dir="D:/Separating Images into subfolders/train_augmented")


#print(train_generator.class_indices)

valid_generator = valid_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_class_treatment/vald",
    target_size=(128, 128),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="validation")
#    save_to_dir="D:/Separating Images into subfolders/val_augmented"


test_generator = test_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_class_treatment/test",
    target_size=(128, 128),
    color_mode="rgb",
    batch_size=1,
    class_mode="categorical",
    shuffle=False,
    seed=42)
#    save_to_dir="D:/Separating Images into subfolders/test_augmented")


# Fitting/Training the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
experiment_id = get_experiment_id()


class_weight_list = class_weight.compute_class_weight('balanced', np.unique(train_generator.classes), train_generator.classes)
class_weights = dict(zip(np.unique(train_generator.classes), class_weight_list))

callbacks = [
#    Resample_Iterator(balance_weights),
    #QWK(valid_generator, STEP_SIZE_VALID),
    ModelCheckpoint(top_layers_checkpoint_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max'),
#    EarlyStopping(monitor='val_kappa', patience=10, min_delta=0.001, verbose=1, restore_best_weights=True, mode='max',baseline=None),
    VCM(valid_generator, STEP_SIZE_VALID),
#    LearningRateScheduler(scheduler, verbose=1),
 #   TensorBoard(log_dir='./Graph', histogram_freq=0, write_graph=True, write_images=True),        
]




# train the model on the new data for a few epochs

history1=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    class_weight=class_weight_list,
                    callbacks=callbacks,
                    epochs=10  
)


 

callbacks1 = [
#    Resample_Iterator(balance_weights1),
    #QWK(valid_generator, STEP_SIZE_VALID),
    ModelCheckpoint(fine_tuned_checkpoint_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max'),
#    EarlyStopping(monitor='val_kappa', patience=20, min_delta=0.001, verbose=1, restore_best_weights=True, mode='max',baseline=None),
    VCM(valid_generator, STEP_SIZE_VALID),
#    LearningRateScheduler(scheduler, verbose=1),
#    TensorBoard(log_dir='./Graph', histogram_freq=0, write_graph=True, write_images=True),        
]



for layer in model.layers:
    layer.trainable = True
    
    
    
    
radam = Adam(lr=0.0014339, beta_1=0.9, beta_2=0.999, epsilon=0.1, decay=1e-6, amsgrad=False)
model.compile(loss='categorical_crossentropy', optimizer=radam, metrics=['mae','acc'])



# we train our model again (this time fine-tuning the top 2 inception blocks
# alongside the top Dense layers
history=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    class_weight=class_weight_list,
                    callbacks=callbacks1,
                    epochs=30) 




test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1']
print(classification_report(y_true, y_pred, target_names=target_names))
                    
                    
# list all data in history
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model loss.png')

# summarize history for val_kappa
plt.plot(history.history['val_kappa'])
plt.title('Validation_Kappa')
plt.ylabel('val_kappa')
plt.xlabel('epoch')
plt.legend([ 'validation'], loc='upper left')
plt.show()
#plt.savefig('model validation_kappa.png')

# summarize history for mean_absolute _error
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model mean_absolute_error')
plt.ylabel('mean_absolute_error')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model maey.png')
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Found 294 images belonging to 2 classes.
# Found 58 images belonging to 2 classes.
# Found 88 images belonging to 2 classes.
# Epoch 1/10
# 4/4 [==============================] - 3s 864ms/step - loss: 1.4858 - mean_absolute_error: 0.6140 - acc: 0.3438 - val_loss: 1.0524 - val_mean_absolute_error: 0.5587 - val_acc: 0.4483
#
# Epoch 00001: val_acc improved from -inf to 0.44828, saving model to cp.top.best.hdf5
# Confusion matrix:
#  []
# Epoch 2/10
# 4/4 [==============================] - 1s 159ms/step - loss: 1.4197 - mean_absolute_error: 0.5864 - acc: 0.3815 - val_loss: 1.0290 - val_mean_absolute_error: 0.5544 - val_acc: 0.4483
#
# Epoch 00002: val_acc did not improve from 0.44828
# Confusion matrix:
#  []
# Epoch 3/10
# 4/4 [==============================] - 0s 125ms/step - loss: 1.4039 - mean_absolute_error: 0.5928 - acc: 0.3934 - val_loss: 0.9997 - val_mean_absolute_error: 0.5488 - val_acc: 0.4483
#
# Epoch 00003: val_acc did not improve from 0.44828
# Confusion matrix:
#  []
# Epoch 4/10
# 4/4 [==============================] - 1s 158ms/step - loss: 1.3470 - mean_absolute_error: 0.6005 - acc: 0.3672 - val_loss: 0.9672 - val_mean_absolute_error: 0.5421 - val_acc: 0.4655
#
# Epoch 00004: val_acc improved from 0.44828 to 0.46552, saving model to cp.top.best.hdf5
# Confusion matrix:
#  []
# Epoch 5/10
# 4/4 [==============================] - 0s 97ms/step - loss: 1.2890 - mean_absolute_error: 0.5773 - acc: 0.3860 - val_loss: 0.9330 - val_mean_absolute_error: 0.5345 - val_acc: 0.4828
#
# Epoch 00005: val_acc improved from 0.46552 to 0.48276, saving model to cp.top.best.hdf5
# Confusion matrix:
#  []
# Epoch 6/10
# 4/4 [==============================] - 0s 113ms/step - loss: 1.2323 - mean_absolute_error: 0.5771 - acc: 0.3984 - val_loss: 0.8978 - val_mean_absolute_error: 0.5261 - val_acc: 0.4828
#
# Epoch 00006: val_acc did not improve from 0.48276
# Confusion matrix:
#  []
# Epoch 7/10
# 4/4 [==============================] - 1s 157ms/step - loss: 1.1826 - mean_absolute_error: 0.5711 - acc: 0.4273 - val_loss: 0.8618 - val_mean_absolute_error: 0.5168 - val_acc: 0.5000
#
# Epoch 00007: val_acc improved from 0.48276 to 0.50000, saving model to cp.top.best.hdf5
# Confusion matrix:
#  []
# Epoch 8/10
# 4/4 [==============================] - 0s 110ms/step - loss: 1.0302 - mean_absolute_error: 0.5168 - acc: 0.5107 - val_loss: 0.8268 - val_mean_absolute_error: 0.5070 - val_acc: 0.5000
#
# Epoch 00008: val_acc did not improve from 0.50000
# Confusion matrix:
#  []
# Epoch 9/10
# 4/4 [==============================] - 1s 160ms/step - loss: 1.0566 - mean_absolute_error: 0.5491 - acc: 0.4062 - val_loss: 0.7934 - val_mean_absolute_error: 0.4968 - val_acc: 0.5000
#
# Epoch 00009: val_acc did not improve from 0.50000
# Confusion matrix:
#  []
# Epoch 10/10
# 4/4 [==============================] - 1s 131ms/step - loss: 1.0107 - mean_absolute_error: 0.5347 - acc: 0.4454 - val_loss: 0.7613 - val_mean_absolute_error: 0.4863 - val_acc: 0.5000
#
# Epoch 00010: val_acc did not improve from 0.50000
# Confusion matrix:
#  []
# Epoch 1/30
# 4/4 [==============================] - 11s 3s/step - loss: 0.9751 - mean_absolute_error: 0.5295 - acc: 0.4411 - val_loss: 0.8167 - val_mean_absolute_error: 0.4927 - val_acc: 0.4828
#
# Epoch 00001: val_acc improved from -inf to 0.48276, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  []
# Epoch 2/30
# 4/4 [==============================] - 1s 317ms/step - loss: 0.8855 - mean_absolute_error: 0.4952 - acc: 0.5078 - val_loss: 0.7881 - val_mean_absolute_error: 0.4841 - val_acc: 0.5000
#
# Epoch 00002: val_acc improved from 0.48276 to 0.50000, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  []
# Epoch 3/30
# 4/4 [==============================] - 1s 268ms/step - loss: 0.8567 - mean_absolute_error: 0.5003 - acc: 0.5192 - val_loss: 0.7631 - val_mean_absolute_error: 0.4738 - val_acc: 0.5000
#
# Epoch 00003: val_acc did not improve from 0.50000
# Confusion matrix:
#  []
# Epoch 4/30
# 4/4 [==============================] - 1s 330ms/step - loss: 0.8169 - mean_absolute_error: 0.4762 - acc: 0.5391 - val_loss: 0.7145 - val_mean_absolute_error: 0.4549 - val_acc: 0.5345
#
# Epoch 00004: val_acc improved from 0.50000 to 0.53448, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  []
# Epoch 5/30
# 4/4 [==============================] - 1s 289ms/step - loss: 0.7698 - mean_absolute_error: 0.4666 - acc: 0.5853 - val_loss: 0.6757 - val_mean_absolute_error: 0.4391 - val_acc: 0.6034
#
# Epoch 00005: val_acc improved from 0.53448 to 0.60345, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  []
# Epoch 6/30
# 4/4 [==============================] - 1s 306ms/step - loss: 0.7378 - mean_absolute_error: 0.4467 - acc: 0.5989 - val_loss: 0.6464 - val_mean_absolute_error: 0.4259 - val_acc: 0.6034
#
# Epoch 00006: val_acc did not improve from 0.60345
# Confusion matrix:
#  []
# Epoch 7/30
# 4/4 [==============================] - 1s 291ms/step - loss: 0.6606 - mean_absolute_error: 0.4297 - acc: 0.6542 - val_loss: 0.6127 - val_mean_absolute_error: 0.4109 - val_acc: 0.6034
#
# Epoch 00007: val_acc did not improve from 0.60345
# Confusion matrix:
#  []
# Epoch 8/30
# 4/4 [==============================] - 1s 320ms/step - loss: 0.6786 - mean_absolute_error: 0.4313 - acc: 0.6211 - val_loss: 0.5867 - val_mean_absolute_error: 0.3976 - val_acc: 0.6207
#
# Epoch 00008: val_acc improved from 0.60345 to 0.62069, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  []
# Epoch 9/30
# 4/4 [==============================] - 1s 260ms/step - loss: 0.5903 - mean_absolute_error: 0.3929 - acc: 0.7006 - val_loss: 0.5570 - val_mean_absolute_error: 0.3828 - val_acc: 0.6552
#
# Epoch 00009: val_acc improved from 0.62069 to 0.65517, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  []
# Epoch 10/30
# 4/4 [==============================] - 1s 317ms/step - loss: 0.5639 - mean_absolute_error: 0.3816 - acc: 0.7188 - val_loss: 0.5274 - val_mean_absolute_error: 0.3672 - val_acc: 0.7069
#
# Epoch 00010: val_acc improved from 0.65517 to 0.70690, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  []
# Epoch 11/30
# 4/4 [==============================] - 1s 291ms/step - loss: 0.5171 - mean_absolute_error: 0.3564 - acc: 0.7749 - val_loss: 0.5051 - val_mean_absolute_error: 0.3535 - val_acc: 0.7069
#
# Epoch 00011: val_acc did not improve from 0.70690
# Confusion matrix:
#  []
# Epoch 12/30
# 4/4 [==============================] - 1s 324ms/step - loss: 0.5562 - mean_absolute_error: 0.3668 - acc: 0.7383 - val_loss: 0.4833 - val_mean_absolute_error: 0.3407 - val_acc: 0.7931
#
# Epoch 00012: val_acc improved from 0.70690 to 0.79310, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  []
# Epoch 13/30
# 4/4 [==============================] - 1s 288ms/step - loss: 0.4573 - mean_absolute_error: 0.3293 - acc: 0.7997 - val_loss: 0.4617 - val_mean_absolute_error: 0.3270 - val_acc: 0.7931
#
# Epoch 00013: val_acc did not improve from 0.79310
# Confusion matrix:
#  []
# Epoch 14/30
# 4/4 [==============================] - 1s 294ms/step - loss: 0.4289 - mean_absolute_error: 0.3135 - acc: 0.7973 - val_loss: 0.4417 - val_mean_absolute_error: 0.3155 - val_acc: 0.7931
#
# Epoch 00014: val_acc did not improve from 0.79310
# Confusion matrix:
#  []
# Epoch 15/30
# 4/4 [==============================] - 1s 293ms/step - loss: 0.4107 - mean_absolute_error: 0.3006 - acc: 0.8633 - val_loss: 0.4224 - val_mean_absolute_error: 0.3036 - val_acc: 0.8276
#
# Epoch 00015: val_acc improved from 0.79310 to 0.82759, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  []
# Epoch 16/30
# 4/4 [==============================] - 1s 325ms/step - loss: 0.4097 - mean_absolute_error: 0.2942 - acc: 0.8477 - val_loss: 0.4041 - val_mean_absolute_error: 0.2931 - val_acc: 0.8276
#
# Epoch 00016: val_acc did not improve from 0.82759
# Confusion matrix:
#  []
# Epoch 17/30
# 4/4 [==============================] - 1s 293ms/step - loss: 0.4142 - mean_absolute_error: 0.2964 - acc: 0.8492 - val_loss: 0.3877 - val_mean_absolute_error: 0.2834 - val_acc: 0.8276
#
# Epoch 00017: val_acc did not improve from 0.82759
# Confusion matrix:
#  []
# Epoch 18/30
# 4/4 [==============================] - 1s 270ms/step - loss: 0.3579 - mean_absolute_error: 0.2745 - acc: 0.8760 - val_loss: 0.3705 - val_mean_absolute_error: 0.2739 - val_acc: 0.8276
#
# Epoch 00018: val_acc did not improve from 0.82759
# Confusion matrix:
#  []
# Epoch 19/30
# 4/4 [==============================] - 1s 327ms/step - loss: 0.3926 - mean_absolute_error: 0.2860 - acc: 0.8516 - val_loss: 0.3559 - val_mean_absolute_error: 0.2653 - val_acc: 0.8621
#
# Epoch 00019: val_acc improved from 0.82759 to 0.86207, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  []
# Epoch 20/30
# 4/4 [==============================] - 1s 288ms/step - loss: 0.3848 - mean_absolute_error: 0.2797 - acc: 0.8612 - val_loss: 0.3402 - val_mean_absolute_error: 0.2558 - val_acc: 0.8621
#
# Epoch 00020: val_acc did not improve from 0.86207
# Confusion matrix:
#  []
# Epoch 21/30
# 4/4 [==============================] - 1s 286ms/step - loss: 0.2943 - mean_absolute_error: 0.2376 - acc: 0.9198 - val_loss: 0.3273 - val_mean_absolute_error: 0.2478 - val_acc: 0.8966
#
# Epoch 00021: val_acc improved from 0.86207 to 0.89655, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  []
# Epoch 22/30
# 4/4 [==============================] - 1s 317ms/step - loss: 0.3473 - mean_absolute_error: 0.2602 - acc: 0.8750 - val_loss: 0.3159 - val_mean_absolute_error: 0.2404 - val_acc: 0.9138
#
# Epoch 00022: val_acc improved from 0.89655 to 0.91379, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  []
# Epoch 23/30
# 4/4 [==============================] - 1s 290ms/step - loss: 0.2905 - mean_absolute_error: 0.2273 - acc: 0.9214 - val_loss: 0.3063 - val_mean_absolute_error: 0.2334 - val_acc: 0.9138
#
# Epoch 00023: val_acc did not improve from 0.91379
# Confusion matrix:
#  []
# Epoch 24/30
# 4/4 [==============================] - 1s 292ms/step - loss: 0.3036 - mean_absolute_error: 0.2333 - acc: 0.8959 - val_loss: 0.2993 - val_mean_absolute_error: 0.2283 - val_acc: 0.9138
#
# Epoch 00024: val_acc did not improve from 0.91379
# Confusion matrix:
#  []
# Epoch 25/30
# 4/4 [==============================] - 1s 301ms/step - loss: 0.3003 - mean_absolute_error: 0.2349 - acc: 0.9054 - val_loss: 0.2927 - val_mean_absolute_error: 0.2232 - val_acc: 0.9138
#
# Epoch 00025: val_acc did not improve from 0.91379
# Confusion matrix:
#  []
# Epoch 26/30
# 4/4 [==============================] - 1s 291ms/step - loss: 0.2955 - mean_absolute_error: 0.2241 - acc: 0.9027 - val_loss: 0.2856 - val_mean_absolute_error: 0.2177 - val_acc: 0.9483
#
# Epoch 00026: val_acc improved from 0.91379 to 0.94828, saving model to cp.fine_tuned.best.hdf5
# Confusion matrix:
#  []
# Epoch 27/30
# 4/4 [==============================] - 1s 315ms/step - loss: 0.2363 - mean_absolute_error: 0.1948 - acc: 0.9570 - val_loss: 0.2796 - val_mean_absolute_error: 0.2128 - val_acc: 0.9483
#
# Epoch 00027: val_acc did not improve from 0.94828
# Confusion matrix:
#  []
# Epoch 28/30
# 4/4 [==============================] - 1s 281ms/step - loss: 0.2439 - mean_absolute_error: 0.1953 - acc: 0.9457 - val_loss: 0.2739 - val_mean_absolute_error: 0.2083 - val_acc: 0.9483
#
# Epoch 00028: val_acc did not improve from 0.94828
# Confusion matrix:
#  []
# Epoch 29/30
# 4/4 [==============================] - 1s 290ms/step - loss: 0.2344 - mean_absolute_error: 0.1913 - acc: 0.9518 - val_loss: 0.2671 - val_mean_absolute_error: 0.2031 - val_acc: 0.9483
#
# Epoch 00029: val_acc did not improve from 0.94828
# Confusion matrix:
#  []
# Epoch 30/30
# 4/4 [==============================] - 1s 300ms/step - loss: 0.2335 - mean_absolute_error: 0.1880 - acc: 0.9398 - val_loss: 0.2628 - val_mean_absolute_error: 0.1993 - val_acc: 0.9483
#
# Epoch 00030: val_acc did not improve from 0.94828
# Confusion matrix:
#  []
# 88/88 [==============================] - 2s 22ms/step
# 88/88 [==============================] - 1s 10ms/step
# Test loss: 0.3515767842129042
# Test accuracy: 0.2551283757625656
# Confusion Matrix
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-adec096d8157> in <module>
#     246 # generator.classes gives you the truth label y_true
#     247 print('Confusion Matrix')
# --> 248 cm = confusion_matrix(y_true, y_pred)
#     249
#     250 print(cm)
#
# NameError: name 'confusion_matrix' is not defined

# %%
from sklearn.metrics import confusion_matrix, classification_report

test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# 88/88 [==============================] - 1s 10ms/step
# 88/88 [==============================] - 1s 9ms/step
# Test loss: 0.3515767842129042
# Test accuracy: 0.2551283757625656
# Confusion Matrix
# [[10  9]
#  [ 7 62]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.59      0.53      0.56        19
#            1       0.87      0.90      0.89        69
#
#     accuracy                           0.82        88
#    macro avg       0.73      0.71      0.72        88
# weighted avg       0.81      0.82      0.81        88

# %%
def kappa2(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    if len(y_true.shape) > 1 and y_true.shape[1] > 1:
        y_true = y_true.dot(range(y_true.shape[1]))
    if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
        y_pred = y_pred.dot(range(y_pred.shape[1]))
    try:
        return kappa(y_true, y_pred, weights='quadratic')
    except IndexError:
        return np.nan
    
print('Quadratic_wieghted_kappa')
print(kappa2(y_true, y_pred))
# Out:
# Quadratic_wieghted_kappa
# 0.4417129262490087

# %%
# list all data in history
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model loss.png')

# summarize history for val_kappa
plt.plot(history.history['val_kappa'])
plt.title('Validation_Kappa')
plt.ylabel('val_kappa')
plt.xlabel('epoch')
plt.legend([ 'validation'], loc='upper left')
plt.show()
#plt.savefig('model validation_kappa.png')

# summarize history for mean_absolute _error
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model mean_absolute_error')
plt.ylabel('mean_absolute_error')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model maey.png')
# Out:
# dict_keys(['val_loss', 'val_mean_absolute_error', 'val_acc', 'loss', 'mean_absolute_error', 'acc'])
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-b7c163781efd> in <module>
#      22
#      23 # summarize history for val_kappa
# ---> 24 plt.plot(history.history['val_kappa'])
#      25 plt.title('Validation_Kappa')
#      26 plt.ylabel('val_kappa')
#
# KeyError: 'val_kappa'
