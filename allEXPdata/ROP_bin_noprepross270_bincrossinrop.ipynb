# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, InputLayer
from keras.regularizers import L1L2, l2, l1
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from custom_pooling import RMSPooling2D
from keras.optimizers import SGD, Adam
from keras.layers import LeakyReLU
#from data import BALANCE_WEIGHTS
from keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
#import os
from datetime import datetime as dt
from custom_loss import WeightedCategoricalCrossEntropy
from VCM import VCM
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
def get_experiment_id():
    time_str = dt.now().strftime('%Y-%m-%d-%H-%M-%S')
    experiment_id = 'base_{}'.format(time_str)
    return experiment_id
p_ratio=[1.0, 1.44, 1.73, 1.0]

model = Sequential()


model.add(Conv2D(16, (5, 5), activation='tanh', input_shape=(270, 270, 3)))
model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(16, (3, 3), activation='tanh'))
model.add(Conv2D(16, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))

#model.add(LeakyReLU(alpha=0.01))


model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))



model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))          
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(MaxPooling2D(pool_size=2))
#model.add(MaxPooling2D(pool_size=1))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
model.add(MaxPooling2D(pool_size=2))

model.add(Flatten())


#chnaged from 10 to 5 because an error 
model.add(Dense(2, activation='softmax'))

sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.count_params()
#adam = Adam(lr=0.0005, decay=1e-6)
#rmsprop
#Mloss = WeightedCategoricalCrossEntropy({0: 0.4125861396437394, 1: 1.4918664786083686, 2: 0.690426457789382, 3: 3.9541433021806855, 4: 4.885604311008468})
model.compile(loss='binary_crossentropy', optimizer=sgd, metrics=['acc','binary_accuracy','mae'])
model.summary()
loss_no_weight_decay = model.total_loss - sum(model.losses)
model.metrics_tensors.append(loss_no_weight_decay)
model.metrics_names.append('loss_no_weight_decay')
#############################################################################################
#############################################################################################
#############################################################################################
#############################################################################################
#Preparing Data Augmentation Configuration 
train_datagen = ImageDataGenerator(
        rescale=1./255,
#        featurewise_center=True,
 #       samplewise_center=True,
        shear_range=0,
        zoom_range=0.0,#[1 / 1.15, 1.15],
        horizontal_flip=False,#True,
        rotation_range=0)#90,
#        validation_split=0.2)
"""
For the test set only rescale should be made 
"""
test_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas/train",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="training")
#    save_to_dir="D:/Separating Images into subfolders/train_augmented")


#print(train_generator.class_indices)

valid_generator = valid_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas/vald",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="validation")
#    save_to_dir="D:/Separating Images into subfolders/val_augmented"


test_generator = test_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas/test",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=1,
    class_mode="categorical",
    shuffle=False,
    seed=42)
#    save_to_dir="D:/Separating Images into subfolders/test_augmented")


# Fitting/Training the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
experiment_id = get_experiment_id()
callbacks = [
    EarlyStopping(monitor='val_acc', patience=50, min_delta=0.001, verbose=1),
    ModelCheckpoint(experiment_id + "-val_acc_checkpoint.hdf5", monitor='val_acc', verbose=1, save_best_only=True, mode='auto'),
    ReduceLROnPlateau(monitor='val_acc', factor=0.5, patience=7, verbose=1, mode='auto', min_delta=0.001, cooldown=0, min_lr=1e-7),
    VCM(valid_generator,STEP_SIZE_VALID)
    
]

class_weight_list = class_weight.compute_class_weight('balanced', np.unique(train_generator.classes), train_generator.classes)
class_weights = dict(zip(np.unique(train_generator.classes), class_weight_list))

history=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    class_weight=class_weights,
                    callbacks=callbacks,
                    epochs=35  
)


# Evaluating the model 
#predicting output
#reseting the test generator before calling predict_generator, in order not to get weird output
test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 266, 266, 16)      1216
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 262, 262, 16)      6416
# _________________________________________________________________
# input_1 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 260, 260, 16)      2320
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 258, 258, 16)      2320
# _________________________________________________________________
# input_2 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 254, 254, 16)      6416
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 250, 250, 16)      6416
# _________________________________________________________________
# input_3 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 246, 246, 16)      6416
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 242, 242, 16)      6416
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 121, 121, 16)      0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 119, 119, 32)      4640
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 117, 117, 32)      9248
# _________________________________________________________________
# input_4 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 115, 115, 32)      9248
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 113, 113, 32)      9248
# _________________________________________________________________
# input_5 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 111, 111, 32)      9248
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 109, 109, 32)      9248
# _________________________________________________________________
# input_6 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 107, 107, 32)      9248
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 105, 105, 32)      9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 52, 52, 32)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 50, 50, 64)        18496
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 48, 48, 64)        36928
# _________________________________________________________________
# input_7 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 46, 46, 64)        36928
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 44, 44, 64)        36928
# _________________________________________________________________
# input_8 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 42, 42, 64)        36928
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 40, 40, 64)        36928
# _________________________________________________________________
# input_9 (InputLayer)         multiple                  0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 20, 20, 64)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 18, 18, 64)        36928
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# input_10 (InputLayer)        multiple                  0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 14, 14, 64)        36928
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 12, 12, 64)        36928
# _________________________________________________________________
# input_11 (InputLayer)        multiple                  0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 4610
# =================================================================
# Total params: 462,770
# Trainable params: 462,770
# Non-trainable params: 0
# _________________________________________________________________
# Found 588 images belonging to 2 classes.
# Found 116 images belonging to 2 classes.
# Found 176 images belonging to 2 classes.
# Epoch 1/35
# 9/9 [==============================] - 23s 3s/step - loss: 0.7139 - acc: 0.4707 - binary_accuracy: 0.4707 - mean_absolute_error: 0.5049 - loss_no_weight_decay: 0.7139 - val_loss: 0.6852 - val_acc: 0.5781 - val_binary_accuracy: 0.5781 - val_mean_absolute_error: 0.4946 - val_loss_no_weight_decay: 0.6852
#
# Epoch 00001: val_acc improved from -inf to 0.57812, saving model to base_2020-05-08-18-23-44-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[32  0]
#  [32  0]]
# Epoch 2/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.7004 - acc: 0.4479 - binary_accuracy: 0.4479 - mean_absolute_error: 0.5022 - loss_no_weight_decay: 0.7004 - val_loss: 0.6845 - val_acc: 0.5962 - val_binary_accuracy: 0.5962 - val_mean_absolute_error: 0.4953 - val_loss_no_weight_decay: 0.6845
#
# Epoch 00002: val_acc improved from 0.57812 to 0.59615, saving model to base_2020-05-08-18-23-44-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[ 0 29]
#  [ 0 23]]
# Epoch 3/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.6899 - acc: 0.5052 - binary_accuracy: 0.5052 - mean_absolute_error: 0.4979 - loss_no_weight_decay: 0.6899 - val_loss: 0.6853 - val_acc: 0.5469 - val_binary_accuracy: 0.5469 - val_mean_absolute_error: 0.4956 - val_loss_no_weight_decay: 0.6853
#
# Epoch 00003: val_acc did not improve from 0.59615
# Confusion matrix:
#  [[ 0 28]
#  [ 0 36]]
# Epoch 4/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.6910 - acc: 0.5077 - binary_accuracy: 0.5077 - mean_absolute_error: 0.4987 - loss_no_weight_decay: 0.6910 - val_loss: 0.6843 - val_acc: 0.5577 - val_binary_accuracy: 0.5577 - val_mean_absolute_error: 0.4953 - val_loss_no_weight_decay: 0.6843
#
# Epoch 00004: val_acc did not improve from 0.59615
# Confusion matrix:
#  [[23  0]
#  [29  0]]
# Epoch 5/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.6882 - acc: 0.5353 - binary_accuracy: 0.5353 - mean_absolute_error: 0.4973 - loss_no_weight_decay: 0.6882 - val_loss: 0.6852 - val_acc: 0.7969 - val_binary_accuracy: 0.7969 - val_mean_absolute_error: 0.4960 - val_loss_no_weight_decay: 0.6852
# Epoch 00005: val_acc improved from 0.59615 to 0.79688, saving model to base_2020-05-08-18-23-44-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[28  2]
#  [15 19]]
# Epoch 6/35
# 9/9 [==============================] - 11s 1s/step - loss: 0.6845 - acc: 0.6383 - binary_accuracy: 0.6383 - mean_absolute_error: 0.4955 - loss_no_weight_decay: 0.6845 - val_loss: 0.6780 - val_acc: 0.5962 - val_binary_accuracy: 0.5962 - val_mean_absolute_error: 0.4918 - val_loss_no_weight_decay: 0.6780
#
# Epoch 00006: val_acc did not improve from 0.79688
# Confusion matrix:
#  [[ 1 23]
#  [ 0 28]]
# Epoch 7/35
# 9/9 [==============================] - 11s 1s/step - loss: 0.6838 - acc: 0.5969 - binary_accuracy: 0.5969 - mean_absolute_error: 0.4949 - loss_no_weight_decay: 0.6838 - val_loss: 0.6798 - val_acc: 0.7344 - val_binary_accuracy: 0.7344 - val_mean_absolute_error: 0.4931 - val_loss_no_weight_decay: 0.6798
#
# Epoch 00007: val_acc did not improve from 0.79688
# Confusion matrix:
#  [[27  3]
#  [14 20]]
# Epoch 8/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.6800 - acc: 0.6840 - binary_accuracy: 0.6840 - mean_absolute_error: 0.4932 - loss_no_weight_decay: 0.6800 - val_loss: 0.6716 - val_acc: 0.7885 - val_binary_accuracy: 0.7885 - val_mean_absolute_error: 0.4889 - val_loss_no_weight_decay: 0.6716
#
# Epoch 00008: val_acc did not improve from 0.79688
# Confusion matrix:
#  [[15 11]
#  [ 1 25]]
# Epoch 9/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.6710 - acc: 0.6358 - binary_accuracy: 0.6358 - mean_absolute_error: 0.4880 - loss_no_weight_decay: 0.6710 - val_loss: 0.6638 - val_acc: 0.7188 - val_binary_accuracy: 0.7188 - val_mean_absolute_error: 0.4845 - val_loss_no_weight_decay: 0.6638
#
# Epoch 00009: val_acc did not improve from 0.79688
# Confusion matrix:
#  [[19 12]
#  [ 2 31]]
# Epoch 10/35
# 9/9 [==============================] - 10s 1s/step - loss: 0.6614 - acc: 0.7119 - binary_accuracy: 0.7119 - mean_absolute_error: 0.4829 - loss_no_weight_decay: 0.6614 - val_loss: 0.6380 - val_acc: 0.7692 - val_binary_accuracy: 0.7692 - val_mean_absolute_error: 0.4705 - val_loss_no_weight_decay: 0.6380
#
# Epoch 00010: val_acc did not improve from 0.79688
# Confusion matrix:
#  [[23  5]
#  [ 5 19]]
# Epoch 11/35
# 9/9 [==============================] - 11s 1s/step - loss: 0.6410 - acc: 0.7222 - binary_accuracy: 0.7222 - mean_absolute_error: 0.4705 - loss_no_weight_decay: 0.6410 - val_loss: 0.6169 - val_acc: 0.7031 - val_binary_accuracy: 0.7031 - val_mean_absolute_error: 0.4555 - val_loss_no_weight_decay: 0.6169
#
# Epoch 00011: val_acc did not improve from 0.79688
# Confusion matrix:
#  [[30  0]
#  [21 13]]
# Epoch 12/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.6090 - acc: 0.6806 - binary_accuracy: 0.6806 - mean_absolute_error: 0.4454 - loss_no_weight_decay: 0.6090 - val_loss: 0.5728 - val_acc: 0.7500 - val_binary_accuracy: 0.7500 - val_mean_absolute_error: 0.4180 - val_loss_no_weight_decay: 0.5728
#
# Epoch 00012: val_acc did not improve from 0.79688
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Confusion matrix:
#  [[25  0]
#  [13 14]]
# Epoch 13/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.6851 - acc: 0.5495 - binary_accuracy: 0.5495 - mean_absolute_error: 0.4837 - loss_no_weight_decay: 0.6851 - val_loss: 0.6843 - val_acc: 0.5156 - val_binary_accuracy: 0.5156 - val_mean_absolute_error: 0.4937 - val_loss_no_weight_decay: 0.6843
#
# Epoch 00013: val_acc did not improve from 0.79688
# Confusion matrix:
#  [[32  0]
#  [32  0]]
# Epoch 14/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.6914 - acc: 0.5104 - binary_accuracy: 0.5104 - mean_absolute_error: 0.4982 - loss_no_weight_decay: 0.6914 - val_loss: 0.6836 - val_acc: 0.5769 - val_binary_accuracy: 0.5769 - val_mean_absolute_error: 0.4947 - val_loss_no_weight_decay: 0.6836
#
# Epoch 00014: val_acc did not improve from 0.79688
# Confusion matrix:
#  [[ 3 18]
#  [ 0 31]]
# Epoch 15/35
# 9/9 [==============================] - 10s 1s/step - loss: 0.6928 - acc: 0.5028 - binary_accuracy: 0.5028 - mean_absolute_error: 0.4971 - loss_no_weight_decay: 0.6928 - val_loss: 0.7137 - val_acc: 0.4375 - val_binary_accuracy: 0.4375 - val_mean_absolute_error: 0.5051 - val_loss_no_weight_decay: 0.7137
#
# Epoch 00015: val_acc did not improve from 0.79688
# Confusion matrix:
#  [[ 1 26]
#  [ 0 37]]
# Epoch 16/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.6897 - acc: 0.5087 - binary_accuracy: 0.5087 - mean_absolute_error: 0.4935 - loss_no_weight_decay: 0.6897 - val_loss: 0.6609 - val_acc: 0.6923 - val_binary_accuracy: 0.6923 - val_mean_absolute_error: 0.4825 - val_loss_no_weight_decay: 0.6609
#
# Epoch 00016: val_acc did not improve from 0.79688
# Confusion matrix:
#  [[ 3 22]
#  [ 0 27]]
# Epoch 17/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.6769 - acc: 0.5243 - binary_accuracy: 0.5243 - mean_absolute_error: 0.4872 - loss_no_weight_decay: 0.6769 - val_loss: 0.6485 - val_acc: 0.5469 - val_binary_accuracy: 0.5469 - val_mean_absolute_error: 0.4728 - val_loss_no_weight_decay: 0.6485
#
# Epoch 00017: val_acc did not improve from 0.79688
# Confusion matrix:
#  [[32  0]
#  [32  0]]
# Epoch 18/35
# 9/9 [==============================] - 10s 1s/step - loss: 0.6570 - acc: 0.5777 - binary_accuracy: 0.5777 - mean_absolute_error: 0.4752 - loss_no_weight_decay: 0.6570 - val_loss: 0.6887 - val_acc: 0.5577 - val_binary_accuracy: 0.5577 - val_mean_absolute_error: 0.4286 - val_loss_no_weight_decay: 0.6887
#
# Epoch 00018: val_acc did not improve from 0.79688
# Confusion matrix:
#  [[28  0]
#  [21  3]]
# Epoch 19/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.6300 - acc: 0.6163 - binary_accuracy: 0.6163 - mean_absolute_error: 0.4327 - loss_no_weight_decay: 0.6300 - val_loss: 0.6327 - val_acc: 0.6562 - val_binary_accuracy: 0.6562 - val_mean_absolute_error: 0.4621 - val_loss_no_weight_decay: 0.6327
#
# Epoch 00019: val_acc did not improve from 0.79688
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Confusion matrix:
#  [[ 8 22]
#  [ 1 33]]
# Epoch 20/35
# 9/9 [==============================] - 11s 1s/step - loss: 0.6588 - acc: 0.5629 - binary_accuracy: 0.5629 - mean_absolute_error: 0.4783 - loss_no_weight_decay: 0.6588 - val_loss: 0.6607 - val_acc: 0.5385 - val_binary_accuracy: 0.5385 - val_mean_absolute_error: 0.4796 - val_loss_no_weight_decay: 0.6607
#
# Epoch 00020: val_acc did not improve from 0.79688
# Confusion matrix:
#  [[23  0]
#  [29  0]]
# Epoch 21/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.6508 - acc: 0.6591 - binary_accuracy: 0.6591 - mean_absolute_error: 0.4757 - loss_no_weight_decay: 0.6508 - val_loss: 0.6398 - val_acc: 0.6875 - val_binary_accuracy: 0.6875 - val_mean_absolute_error: 0.4681 - val_loss_no_weight_decay: 0.6398
#
# Epoch 00021: val_acc did not improve from 0.79688
# Confusion matrix:
#  [[17 14]
#  [ 1 32]]
# Epoch 22/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.6198 - acc: 0.6851 - binary_accuracy: 0.6851 - mean_absolute_error: 0.4521 - loss_no_weight_decay: 0.6198 - val_loss: 0.5474 - val_acc: 0.7885 - val_binary_accuracy: 0.7885 - val_mean_absolute_error: 0.4098 - val_loss_no_weight_decay: 0.5474
#
# Epoch 00022: val_acc did not improve from 0.79688
# Confusion matrix:
#  [[15 11]
#  [ 1 25]]
# Epoch 23/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.5303 - acc: 0.8166 - binary_accuracy: 0.8166 - mean_absolute_error: 0.3998 - loss_no_weight_decay: 0.5303 - val_loss: 0.5006 - val_acc: 0.8438 - val_binary_accuracy: 0.8438 - val_mean_absolute_error: 0.3843 - val_loss_no_weight_decay: 0.5006
#
# Epoch 00023: val_acc improved from 0.79688 to 0.84375, saving model to base_2020-05-08-18-23-44-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[27  4]
#  [ 6 27]]
# Epoch 24/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.5102 - acc: 0.7934 - binary_accuracy: 0.7934 - mean_absolute_error: 0.3825 - loss_no_weight_decay: 0.5102 - val_loss: 0.5401 - val_acc: 0.7115 - val_binary_accuracy: 0.7115 - val_mean_absolute_error: 0.3768 - val_loss_no_weight_decay: 0.5401
#
# Epoch 00024: val_acc did not improve from 0.84375
# Confusion matrix:
#  [[26  2]
#  [14 10]]
# Epoch 25/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.4665 - acc: 0.8063 - binary_accuracy: 0.8063 - mean_absolute_error: 0.3468 - loss_no_weight_decay: 0.4665 - val_loss: 0.4246 - val_acc: 0.8594 - val_binary_accuracy: 0.8594 - val_mean_absolute_error: 0.3157 - val_loss_no_weight_decay: 0.4246
#
# Epoch 00025: val_acc improved from 0.84375 to 0.85938, saving model to base_2020-05-08-18-23-44-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[28  6]
#  [ 8 22]]
# Epoch 26/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.4805 - acc: 0.7901 - binary_accuracy: 0.7901 - mean_absolute_error: 0.3514 - loss_no_weight_decay: 0.4805 - val_loss: 0.5165 - val_acc: 0.7308 - val_binary_accuracy: 0.7308 - val_mean_absolute_error: 0.3610 - val_loss_no_weight_decay: 0.5165
#
# Epoch 00026: val_acc did not improve from 0.85938
# Confusion matrix:
#  [[23  3]
#  [10 16]]
# Epoch 27/35
# 9/9 [==============================] - 11s 1s/step - loss: 0.4453 - acc: 0.8317 - binary_accuracy: 0.8317 - mean_absolute_error: 0.3291 - loss_no_weight_decay: 0.4453 - val_loss: 0.4225 - val_acc: 0.8438 - val_binary_accuracy: 0.8438 - val_mean_absolute_error: 0.3184 - val_loss_no_weight_decay: 0.4225
#
# Epoch 00027: val_acc did not improve from 0.85938
# Confusion matrix:
#  [[22 13]
#  [ 2 27]]
# Epoch 28/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.4678 - acc: 0.8021 - binary_accuracy: 0.8021 - mean_absolute_error: 0.3328 - loss_no_weight_decay: 0.4678 - val_loss: 0.4744 - val_acc: 0.7308 - val_binary_accuracy: 0.7308 - val_mean_absolute_error: 0.3307 - val_loss_no_weight_decay: 0.4744
#
# Epoch 00028: val_acc did not improve from 0.85938
# Confusion matrix:
#  [[23  6]
#  [ 3 20]]
# Epoch 29/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.4444 - acc: 0.7986 - binary_accuracy: 0.7986 - mean_absolute_error: 0.3253 - loss_no_weight_decay: 0.4444 - val_loss: 0.4641 - val_acc: 0.8438 - val_binary_accuracy: 0.8438 - val_mean_absolute_error: 0.3306 - val_loss_no_weight_decay: 0.4641
#
# Epoch 00029: val_acc did not improve from 0.85938
# Confusion matrix:
#  [[28  5]
#  [ 5 26]]
# Epoch 30/35
# 9/9 [==============================] - 11s 1s/step - loss: 0.4366 - acc: 0.8269 - binary_accuracy: 0.8269 - mean_absolute_error: 0.3221 - loss_no_weight_decay: 0.4366 - val_loss: 0.4153 - val_acc: 0.7885 - val_binary_accuracy: 0.7885 - val_mean_absolute_error: 0.3052 - val_loss_no_weight_decay: 0.4153
#
# Epoch 00030: val_acc did not improve from 0.85938
# Confusion matrix:
#  [[22  2]
#  [ 9 19]]
# Epoch 31/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.4251 - acc: 0.8319 - binary_accuracy: 0.8319 - mean_absolute_error: 0.3135 - loss_no_weight_decay: 0.4251 - val_loss: 0.3984 - val_acc: 0.8438 - val_binary_accuracy: 0.8438 - val_mean_absolute_error: 0.2968 - val_loss_no_weight_decay: 0.3984
#
# Epoch 00031: val_acc did not improve from 0.85938
# Confusion matrix:
#  [[33  4]
#  [ 7 20]]
# Epoch 32/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.4178 - acc: 0.8322 - binary_accuracy: 0.8322 - mean_absolute_error: 0.3009 - loss_no_weight_decay: 0.4178 - val_loss: 0.4650 - val_acc: 0.7885 - val_binary_accuracy: 0.7885 - val_mean_absolute_error: 0.3008 - val_loss_no_weight_decay: 0.4650
#
# Epoch 00032: val_acc did not improve from 0.85938
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Confusion matrix:
#  [[26  3]
#  [ 5 18]]
# Epoch 33/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.4223 - acc: 0.8076 - binary_accuracy: 0.8076 - mean_absolute_error: 0.2958 - loss_no_weight_decay: 0.4223 - val_loss: 0.4527 - val_acc: 0.7969 - val_binary_accuracy: 0.7969 - val_mean_absolute_error: 0.3025 - val_loss_no_weight_decay: 0.4527
#
# Epoch 00033: val_acc did not improve from 0.85938
# Confusion matrix:
#  [[29  6]
#  [ 6 23]]
# Epoch 34/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.4092 - acc: 0.8342 - binary_accuracy: 0.8342 - mean_absolute_error: 0.2977 - loss_no_weight_decay: 0.4092 - val_loss: 0.4013 - val_acc: 0.8269 - val_binary_accuracy: 0.8269 - val_mean_absolute_error: 0.3047 - val_loss_no_weight_decay: 0.4013
#
# Epoch 00034: val_acc did not improve from 0.85938
# Confusion matrix:
#  [[23  5]
#  [ 2 22]]
# Epoch 35/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.4061 - acc: 0.8368 - binary_accuracy: 0.8368 - mean_absolute_error: 0.2957 - loss_no_weight_decay: 0.4061 - val_loss: 0.5033 - val_acc: 0.7344 - val_binary_accuracy: 0.7344 - val_mean_absolute_error: 0.3332 - val_loss_no_weight_decay: 0.5033
#
# Epoch 00035: val_acc did not improve from 0.85938
# Confusion matrix:
#  [[26  4]
#  [10 24]]
# 176/176 [==============================] - 5s 28ms/step
# 176/176 [==============================] - 5s 29ms/step
# Test loss: 0.4510781915159896
# Test accuracy: 0.7840909090909091
# Confusion Matrix
# [[79  9]
#  [29 59]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.73      0.90      0.81        88
#            1       0.87      0.67      0.76        88
#
#     accuracy                           0.78       176
#    macro avg       0.80      0.78      0.78       176
# weighted avg       0.80      0.78      0.78       176

# %%
from Kappa_Skl import kappa
def kappa2(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    if len(y_true.shape) > 1 and y_true.shape[1] > 1:
        y_true = y_true.dot(range(y_true.shape[1]))
    if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
        y_pred = y_pred.dot(range(y_pred.shape[1]))
    try:
        return kappa(y_true, y_pred, weights='quadratic')
    except IndexError:
        return np.nan
    
print('Quadratic_wieghted_kappa')
print(kappa2(y_true, y_pred))
# Out:
# Quadratic_wieghted_kappa
# 0.5681818181818181

# %%
import numpy as np 
import matplotlib.pyplot as plt
import os
import wandb
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_acc', 'val_binary_accuracy', 'val_mean_absolute_error', 'val_loss_no_weight_decay', 'loss', 'acc', 'binary_accuracy', 'mean_absolute_error', 'loss_no_weight_decay', 'lr'])
