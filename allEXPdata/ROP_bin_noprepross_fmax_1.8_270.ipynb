# %%
import keras
from keras.models import Sequential, Input, Model
from keras.losses import mean_squared_error
from keras.layers import  *
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, InputLayer
from keras.regularizers import L1L2, l2, l1
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from custom_pooling import RMSPooling2D
from keras.optimizers import SGD, Adam
from keras.layers import LeakyReLU
#from data import BALANCE_WEIGHTS
from keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
#import os
from datetime import datetime as dt
from custom_loss import WeightedCategoricalCrossEntropy
from VCM import VCM
import keras.backend as K
from Fractional_MAXPOOL import FractionalPooling2D
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D,BatchNormalization,Dense, Dropout, Flatten, LeakyReLU, Lambda
from custom_pooling import RMSPooling2D
from keras.optimizers import SGD
from keras_preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from keras.callbacks import EarlyStopping, ModelCheckpoint,LearningRateScheduler, TensorBoard
from datetime import datetime as dt
from VCM import VCM 
from keras.initializers import Constant,Orthogonal
from keras import regularizers
from Kappa_Skl import kappa
import keras.backend as K
import matplotlib.pyplot as plt
import itertools
from Homotopy import Homotopy 
from QWK import QWK
import tensorflow as tf
from Fractional_MAXPOOL import FractionalPooling2D

# %%
def get_experiment_id():
    time_str = dt.now().strftime('%Y-%m-%d-%H-%M-%S')
    experiment_id = 'base_{}'.format(time_str)
    return experiment_id
p_ratio=[1.0, 1.44, 1.73, 1.0]

model = Sequential()


model.add(Conv2D(16, (5, 5), activation='tanh', input_shape=(270, 270, 3)))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(16, (3, 3), activation='tanh'))
model.add(Conv2D(16, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

#model.add(LeakyReLU(alpha=0.01))


model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))


model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))          
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))


model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

#model.add(MaxPooling2D(pool_size=1))




model.add(MaxPooling2D(pool_size=2))

model.add(Flatten())


#chnaged from 10 to 5 because an error 
model.add(Dense(2, activation='softmax'))

sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.count_params()
#adam = Adam(lr=0.0005, decay=1e-6)
#rmsprop
#Mloss = WeightedCategoricalCrossEntropy({0: 0.4125861396437394, 1: 1.4918664786083686, 2: 0.690426457789382, 3: 3.9541433021806855, 4: 4.885604311008468})
model.compile(loss='mse', optimizer=sgd, metrics=['mae','acc'])
model.summary()
loss_no_weight_decay = model.total_loss - sum(model.losses)
model.metrics_tensors.append(loss_no_weight_decay)
model.metrics_names.append('loss_no_weight_decay')
#############################################################################################
#############################################################################################
#############################################################################################
#############################################################################################
#Preparing Data Augmentation Configuration 
train_datagen = ImageDataGenerator(
        rescale=1./255,
#        featurewise_center=True,
 #       samplewise_center=True,
        shear_range=0,
        zoom_range=0.0,#[1 / 1.15, 1.15],
        horizontal_flip=False,#True,
        rotation_range=0)#90,
#        validation_split=0.2)
"""
For the test set only rescale should be made 
"""
test_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas/train",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="training")
#    save_to_dir="D:/Separating Images into subfolders/train_augmented")


#print(train_generator.class_indices)

valid_generator = valid_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas/vald",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="validation")
#    save_to_dir="D:/Separating Images into subfolders/val_augmented"


test_generator = test_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas/test",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=1,
    class_mode="categorical",
    shuffle=False,
    seed=42)
#    save_to_dir="D:/Separating Images into subfolders/test_augmented")


# Fitting/Training the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
experiment_id = get_experiment_id()
callbacks = [
    EarlyStopping(monitor='val_acc', patience=50, min_delta=0.001, verbose=1),
    ModelCheckpoint(experiment_id + "-val_acc_checkpoint.hdf5", monitor='val_acc', verbose=1, save_best_only=True, mode='auto'),
    ReduceLROnPlateau(monitor='val_acc', factor=0.5, patience=7, verbose=1, mode='auto', min_delta=0.001, cooldown=0, min_lr=1e-7),
    VCM(valid_generator,STEP_SIZE_VALID)
    
]

class_weight_list = class_weight.compute_class_weight('balanced', np.unique(train_generator.classes), train_generator.classes)
class_weights = dict(zip(np.unique(train_generator.classes), class_weight_list))

history=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    class_weight=class_weights,
                    callbacks=callbacks,
                    epochs=35  
)


# Evaluating the model 
#predicting output
#reseting the test generator before calling predict_generator, in order not to get weird output
test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 266, 266, 16)      1216
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 262, 262, 16)      6416
# _________________________________________________________________
# fractional_pooling2d_1 (Frac (None, 145, 145, 16)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 143, 143, 16)      2320
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 141, 141, 16)      2320
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 137, 137, 16)      6416
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 133, 133, 16)      6416
# _________________________________________________________________
# fractional_pooling2d_2 (Frac (None, 73, 73, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 69, 69, 16)        6416
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 65, 65, 16)        6416
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 63, 63, 32)        4640
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 61, 61, 32)        9248
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 59, 59, 32)        9248
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 57, 57, 32)        9248
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 55, 55, 32)        9248
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 53, 53, 32)        9248
# _________________________________________________________________
# fractional_pooling2d_3 (Frac (None, 29, 29, 32)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 27, 27, 32)        9248
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 25, 25, 32)        9248
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 23, 23, 64)        18496
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 21, 21, 64)        36928
# _________________________________________________________________
# fractional_pooling2d_4 (Frac (None, 11, 11, 64)        0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 9, 9, 64)          36928
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 7, 7, 64)          36928
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 5, 5, 64)          36928
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 3, 3, 64)          36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 1, 1, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 310,578
# Trainable params: 310,578
# Non-trainable params: 0
# _________________________________________________________________
# Found 588 images belonging to 2 classes.
# Found 116 images belonging to 2 classes.
# Found 176 images belonging to 2 classes.
# Epoch 1/35
# 9/9 [==============================] - 22s 2s/step - loss: 0.2510 - mean_absolute_error: 0.5010 - acc: 0.4549 - loss_no_weight_decay: 0.2510 - val_loss: 0.2511 - val_mean_absolute_error: 0.5011 - val_acc: 0.3594 - val_loss_no_weight_decay: 0.2511
#
# Epoch 00001: val_acc improved from -inf to 0.35938, saving model to base_2020-05-07-12-39-22-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[12 20]
#  [22 10]]
# Epoch 2/35
# 9/9 [==============================] - 16s 2s/step - loss: 0.2507 - mean_absolute_error: 0.5007 - acc: 0.4410 - loss_no_weight_decay: 0.2507 - val_loss: 0.2516 - val_mean_absolute_error: 0.5016 - val_acc: 0.3654 - val_loss_no_weight_decay: 0.2516
#
# Epoch 00002: val_acc improved from 0.35938 to 0.36538, saving model to base_2020-05-07-12-39-22-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[27  2]
#  [23  0]]
# Epoch 3/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.2504 - mean_absolute_error: 0.5003 - acc: 0.4790 - loss_no_weight_decay: 0.2504 - val_loss: 0.2511 - val_mean_absolute_error: 0.5010 - val_acc: 0.4531 - val_loss_no_weight_decay: 0.2511
#
# Epoch 00003: val_acc improved from 0.36538 to 0.45312, saving model to base_2020-05-07-12-39-22-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[28  0]
#  [36  0]]
# Epoch 4/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.2500 - mean_absolute_error: 0.5000 - acc: 0.4877 - loss_no_weight_decay: 0.2500 - val_loss: 0.2490 - val_mean_absolute_error: 0.4990 - val_acc: 0.5577 - val_loss_no_weight_decay: 0.2490
#
# Epoch 00004: val_acc improved from 0.45312 to 0.55769, saving model to base_2020-05-07-12-39-22-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[28  0]
#  [24  0]]
# Epoch 5/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.2491 - mean_absolute_error: 0.4990 - acc: 0.5436 - loss_no_weight_decay: 0.2491 - val_loss: 0.2493 - val_mean_absolute_error: 0.4993 - val_acc: 0.5469 - val_loss_no_weight_decay: 0.2493
#
# Epoch 00005: val_acc did not improve from 0.55769
# Confusion matrix:
#  [[28  2]
#  [27  7]]
# Epoch 6/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.2484 - mean_absolute_error: 0.4983 - acc: 0.6615 - loss_no_weight_decay: 0.2484 - val_loss: 0.2477 - val_mean_absolute_error: 0.4977 - val_acc: 0.6731 - val_loss_no_weight_decay: 0.2477
#
# Epoch 00006: val_acc improved from 0.55769 to 0.67308, saving model to base_2020-05-07-12-39-22-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[11 17]
#  [ 2 22]]
# Epoch 7/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.2472 - mean_absolute_error: 0.4971 - acc: 0.5774 - loss_no_weight_decay: 0.2472 - val_loss: 0.2460 - val_mean_absolute_error: 0.4958 - val_acc: 0.5625 - val_loss_no_weight_decay: 0.2460
#
# Epoch 00007: val_acc did not improve from 0.67308
# Confusion matrix:
#  [[ 3 27]
#  [ 1 33]]
# Epoch 8/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.2461 - mean_absolute_error: 0.4959 - acc: 0.5807 - loss_no_weight_decay: 0.2461 - val_loss: 0.2441 - val_mean_absolute_error: 0.4940 - val_acc: 0.7885 - val_loss_no_weight_decay: 0.2441
#
# Epoch 00008: val_acc improved from 0.67308 to 0.78846, saving model to base_2020-05-07-12-39-22-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[19  7]
#  [ 7 19]]
# Epoch 9/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.2439 - mean_absolute_error: 0.4936 - acc: 0.6240 - loss_no_weight_decay: 0.2439 - val_loss: 0.2403 - val_mean_absolute_error: 0.4898 - val_acc: 0.6562 - val_loss_no_weight_decay: 0.2403
#
# Epoch 00009: val_acc did not improve from 0.78846
# Confusion matrix:
#  [[12 19]
#  [ 4 29]]
# Epoch 10/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.2395 - mean_absolute_error: 0.4886 - acc: 0.6481 - loss_no_weight_decay: 0.2395 - val_loss: 0.2367 - val_mean_absolute_error: 0.4856 - val_acc: 0.7308 - val_loss_no_weight_decay: 0.2367
#
# Epoch 00010: val_acc did not improve from 0.78846
# Confusion matrix:
#  [[13 10]
#  [ 4 25]]
# Epoch 11/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.2366 - mean_absolute_error: 0.4833 - acc: 0.6661 - loss_no_weight_decay: 0.2366 - val_loss: 0.2329 - val_mean_absolute_error: 0.4771 - val_acc: 0.6094 - val_loss_no_weight_decay: 0.2329
#
# Epoch 00011: val_acc did not improve from 0.78846
# Confusion matrix:
#  [[14 16]
#  [ 2 32]]
# Epoch 12/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.2367 - mean_absolute_error: 0.4751 - acc: 0.6240 - loss_no_weight_decay: 0.2367 - val_loss: 0.2082 - val_mean_absolute_error: 0.4482 - val_acc: 0.7692 - val_loss_no_weight_decay: 0.2082
#
# Epoch 00012: val_acc did not improve from 0.78846
# Confusion matrix:
#  [[25  7]
#  [ 7 13]]
# Epoch 13/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.2302 - mean_absolute_error: 0.4587 - acc: 0.6278 - loss_no_weight_decay: 0.2302 - val_loss: 0.2084 - val_mean_absolute_error: 0.4441 - val_acc: 0.7031 - val_loss_no_weight_decay: 0.2084
#
# Epoch 00013: val_acc did not improve from 0.78846
# Confusion matrix:
#  [[16 16]
#  [ 8 24]]
# Epoch 14/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.2348 - mean_absolute_error: 0.4571 - acc: 0.6185 - loss_no_weight_decay: 0.2348 - val_loss: 0.2810 - val_mean_absolute_error: 0.4875 - val_acc: 0.5000 - val_loss_no_weight_decay: 0.2810
#
# Epoch 00014: val_acc did not improve from 0.78846
# Confusion matrix:
#  [[ 3 18]
#  [ 1 30]]
# Epoch 15/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.2251 - mean_absolute_error: 0.4569 - acc: 0.6593 - loss_no_weight_decay: 0.2251 - val_loss: 0.1996 - val_mean_absolute_error: 0.4378 - val_acc: 0.7656 - val_loss_no_weight_decay: 0.1996
#
# Epoch 00015: val_acc did not improve from 0.78846
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Confusion matrix:
#  [[18  9]
#  [12 25]]
# Epoch 16/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.2193 - mean_absolute_error: 0.4547 - acc: 0.6819 - loss_no_weight_decay: 0.2193 - val_loss: 0.2291 - val_mean_absolute_error: 0.4609 - val_acc: 0.6154 - val_loss_no_weight_decay: 0.2291
#
# Epoch 00016: val_acc did not improve from 0.78846
# Confusion matrix:
#  [[23  3]
#  [ 7 19]]
# Epoch 17/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.2073 - mean_absolute_error: 0.4367 - acc: 0.6892 - loss_no_weight_decay: 0.2073 - val_loss: 0.2169 - val_mean_absolute_error: 0.4398 - val_acc: 0.6406 - val_loss_no_weight_decay: 0.2169
#
# Epoch 00017: val_acc did not improve from 0.78846
# Confusion matrix:
#  [[27  5]
#  [19 13]]
# Epoch 18/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.2057 - mean_absolute_error: 0.4224 - acc: 0.6921 - loss_no_weight_decay: 0.2057 - val_loss: 0.1848 - val_mean_absolute_error: 0.3970 - val_acc: 0.7692 - val_loss_no_weight_decay: 0.1848
#
# Epoch 00018: val_acc did not improve from 0.78846
# Confusion matrix:
#  [[25  4]
#  [ 9 14]]
# Epoch 19/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.2011 - mean_absolute_error: 0.4111 - acc: 0.7117 - loss_no_weight_decay: 0.2011 - val_loss: 0.1974 - val_mean_absolute_error: 0.3966 - val_acc: 0.7188 - val_loss_no_weight_decay: 0.1974
#
# Epoch 00019: val_acc did not improve from 0.78846
# Confusion matrix:
#  [[26  4]
#  [13 21]]
# Epoch 20/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.1994 - mean_absolute_error: 0.4007 - acc: 0.7252 - loss_no_weight_decay: 0.1994 - val_loss: 0.2262 - val_mean_absolute_error: 0.4286 - val_acc: 0.6346 - val_loss_no_weight_decay: 0.2262
#
# Epoch 00020: val_acc did not improve from 0.78846
# Confusion matrix:
#  [[14 11]
#  [ 7 20]]
# Epoch 21/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.2034 - mean_absolute_error: 0.4025 - acc: 0.7082 - loss_no_weight_decay: 0.2034 - val_loss: 0.1718 - val_mean_absolute_error: 0.3733 - val_acc: 0.8125 - val_loss_no_weight_decay: 0.1718
#
# Epoch 00021: val_acc improved from 0.78846 to 0.81250, saving model to base_2020-05-07-12-39-22-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[27  4]
#  [ 9 24]]
# Epoch 22/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.2003 - mean_absolute_error: 0.3953 - acc: 0.7152 - loss_no_weight_decay: 0.2003 - val_loss: 0.2005 - val_mean_absolute_error: 0.3944 - val_acc: 0.7308 - val_loss_no_weight_decay: 0.2005
#
# Epoch 00022: val_acc did not improve from 0.81250
# Confusion matrix:
#  [[20  5]
#  [ 5 22]]
# Epoch 23/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.1976 - mean_absolute_error: 0.3925 - acc: 0.7083 - loss_no_weight_decay: 0.1976 - val_loss: 0.2240 - val_mean_absolute_error: 0.4057 - val_acc: 0.6250 - val_loss_no_weight_decay: 0.2240
#
# Epoch 00023: val_acc did not improve from 0.81250
# Confusion matrix:
#  [[30  1]
#  [26  7]]
# Epoch 24/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.1817 - mean_absolute_error: 0.3696 - acc: 0.7668 - loss_no_weight_decay: 0.1817 - val_loss: 0.1859 - val_mean_absolute_error: 0.3684 - val_acc: 0.7500 - val_loss_no_weight_decay: 0.1859
#
# Epoch 00024: val_acc did not improve from 0.81250
# Confusion matrix:
#  [[14 13]
#  [ 5 20]]
# Epoch 25/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.2077 - mean_absolute_error: 0.3867 - acc: 0.7202 - loss_no_weight_decay: 0.2077 - val_loss: 0.1865 - val_mean_absolute_error: 0.3795 - val_acc: 0.7344 - val_loss_no_weight_decay: 0.1865
#
# Epoch 00025: val_acc did not improve from 0.81250
# Confusion matrix:
#  [[24 10]
#  [ 8 22]]
# Epoch 26/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.2146 - mean_absolute_error: 0.3993 - acc: 0.6600 - loss_no_weight_decay: 0.2146 - val_loss: 0.1807 - val_mean_absolute_error: 0.3792 - val_acc: 0.7885 - val_loss_no_weight_decay: 0.1807
#
# Epoch 00026: val_acc did not improve from 0.81250
# Confusion matrix:
#  [[20  5]
#  [ 8 19]]
# Epoch 27/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.2125 - mean_absolute_error: 0.4130 - acc: 0.7042 - loss_no_weight_decay: 0.2125 - val_loss: 0.2239 - val_mean_absolute_error: 0.4261 - val_acc: 0.6250 - val_loss_no_weight_decay: 0.2239
#
# Epoch 00027: val_acc did not improve from 0.81250
# Confusion matrix:
#  [[17 18]
#  [ 7 22]]
# Epoch 28/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.1956 - mean_absolute_error: 0.4043 - acc: 0.7309 - loss_no_weight_decay: 0.1956 - val_loss: 0.1963 - val_mean_absolute_error: 0.4049 - val_acc: 0.7115 - val_loss_no_weight_decay: 0.1963
#
# Epoch 00028: val_acc did not improve from 0.81250
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Confusion matrix:
#  [[25  5]
#  [ 8 14]]
# Epoch 29/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.1834 - mean_absolute_error: 0.3857 - acc: 0.7670 - loss_no_weight_decay: 0.1834 - val_loss: 0.1880 - val_mean_absolute_error: 0.3893 - val_acc: 0.7188 - val_loss_no_weight_decay: 0.1880
#
# Epoch 00029: val_acc did not improve from 0.81250
# Confusion matrix:
#  [[29  4]
#  [11 20]]
# Epoch 30/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.1899 - mean_absolute_error: 0.3888 - acc: 0.7274 - loss_no_weight_decay: 0.1899 - val_loss: 0.1675 - val_mean_absolute_error: 0.3658 - val_acc: 0.8269 - val_loss_no_weight_decay: 0.1675
#
# Epoch 00030: val_acc improved from 0.81250 to 0.82692, saving model to base_2020-05-07-12-39-22-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[23  4]
#  [ 6 19]]
# Epoch 31/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.1728 - mean_absolute_error: 0.3675 - acc: 0.7651 - loss_no_weight_decay: 0.1728 - val_loss: 0.1924 - val_mean_absolute_error: 0.3812 - val_acc: 0.7031 - val_loss_no_weight_decay: 0.1924
#
# Epoch 00031: val_acc did not improve from 0.82692
# Confusion matrix:
#  [[32  5]
#  [10 17]]
# Epoch 32/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.1931 - mean_absolute_error: 0.3827 - acc: 0.7450 - loss_no_weight_decay: 0.1931 - val_loss: 0.1789 - val_mean_absolute_error: 0.3706 - val_acc: 0.7885 - val_loss_no_weight_decay: 0.1789
#
# Epoch 00032: val_acc did not improve from 0.82692
# Confusion matrix:
#  [[17  2]
#  [10 23]]
# Epoch 33/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.1733 - mean_absolute_error: 0.3574 - acc: 0.7741 - loss_no_weight_decay: 0.1733 - val_loss: 0.1732 - val_mean_absolute_error: 0.3555 - val_acc: 0.7500 - val_loss_no_weight_decay: 0.1732
# Epoch 00033: val_acc did not improve from 0.82692
# Confusion matrix:
#  [[30  5]
#  [13 16]]
# Epoch 34/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.1693 - mean_absolute_error: 0.3558 - acc: 0.7906 - loss_no_weight_decay: 0.1693 - val_loss: 0.1606 - val_mean_absolute_error: 0.3470 - val_acc: 0.7692 - val_loss_no_weight_decay: 0.1606
#
# Epoch 00034: val_acc did not improve from 0.82692
# Confusion matrix:
#  [[21  8]
#  [ 6 17]]
# Epoch 35/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.1980 - mean_absolute_error: 0.3812 - acc: 0.7157 - loss_no_weight_decay: 0.1980 - val_loss: 0.1759 - val_mean_absolute_error: 0.3594 - val_acc: 0.7969 - val_loss_no_weight_decay: 0.1759
#
# Epoch 00035: val_acc did not improve from 0.82692
# Confusion matrix:
#  [[28  2]
#  [11 23]]
# 176/176 [==============================] - 4s 25ms/step
# 176/176 [==============================] - 5s 26ms/step
# Test loss: 0.16500764717982913
# Test accuracy: 0.3422954501584172
# Confusion Matrix
# [[86  2]
#  [35 53]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.71      0.98      0.82        88
#            1       0.96      0.60      0.74        88
#
#     accuracy                           0.79       176
#    macro avg       0.84      0.79      0.78       176
# weighted avg       0.84      0.79      0.78       176

# %%
import numpy as np 
import matplotlib.pyplot as plt
import os
import wandb
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_mean_absolute_error', 'val_acc', 'val_loss_no_weight_decay', 'loss', 'mean_absolute_error', 'acc', 'loss_no_weight_decay', 'lr'])

# %%
from Kappa_Skl import kappa
def kappa2(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    if len(y_true.shape) > 1 and y_true.shape[1] > 1:
        y_true = y_true.dot(range(y_true.shape[1]))
    if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
        y_pred = y_pred.dot(range(y_pred.shape[1]))
    try:
        return kappa(y_true, y_pred, weights='quadratic')
    except IndexError:
        return np.nan
    
print('Quadratic_wieghted_kappa')
print(kappa2(y_true, y_pred))
# Out:
# Quadratic_wieghted_kappa
# 0.5795454545454546

# %%
# summarize history for mean_absolute _error
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model mean_absolute_error')
plt.ylabel('mean_absolute_error')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model maey.png')
