# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, InputLayer
from keras.regularizers import L1L2, l2, l1
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from custom_pooling import RMSPooling2D
from keras.optimizers import SGD, Adam
from keras.layers import LeakyReLU
#from data import BALANCE_WEIGHTS
from keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
#import os
from datetime import datetime as dt
from custom_loss import WeightedCategoricalCrossEntropy
from VCM import VCM
from QWK import QWK
import keras.backend as K
from Fractional_MAXPOOL import FractionalPooling2D
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
def get_experiment_id():
    time_str = dt.now().strftime('%Y-%m-%d-%H-%M-%S')
    experiment_id = 'base_{}'.format(time_str)
    return experiment_id
p_ratio=[1.0, 1.44, 1.73, 1.0]

model = Sequential()


model.add(Conv2D(16, (5, 5), activation='tanh', input_shape=(300, 300, 3)))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(16, (3, 3), activation='tanh'))
model.add(Conv2D(16, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))

#model.add(LeakyReLU(alpha=0.01))


model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))



model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))          
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))
#model.add(MaxPooling2D(pool_size=1))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Flatten())


#chnaged from 10 to 5 because an error 
model.add(Dense(2, activation='softmax'))

sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.count_params()
#adam = Adam(lr=0.0005, decay=1e-6)
#rmsprop
#Mloss = WeightedCategoricalCrossEntropy({0: 0.4125861396437394, 1: 1.4918664786083686, 2: 0.690426457789382, 3: 3.9541433021806855, 4: 4.885604311008468})
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['mae','acc'])
model.summary()
loss_no_weight_decay = model.total_loss - sum(model.losses)
model.metrics_tensors.append(loss_no_weight_decay)
model.metrics_names.append('loss_no_weight_decay')
#############################################################################################
#############################################################################################
#############################################################################################
#############################################################################################
#Preparing Data Augmentation Configuration 
train_datagen = ImageDataGenerator(
        rescale=1./255,
#        featurewise_center=True,
 #       samplewise_center=True,
        shear_range=0,
        zoom_range=0.0,#[1 / 1.15, 1.15],
        horizontal_flip=False,#True,
        rotation_range=0)#90,
#        validation_split=0.2)
"""
For the test set only rescale should be made 
"""
test_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_class_treatment_grah/train",
    target_size=(300, 300),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="training")
#    save_to_dir="D:/Separating Images into subfolders/train_augmented")


#print(train_generator.class_indices)

valid_generator = valid_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_class_treatment_grah/vald",
    target_size=(300, 300),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="validation")
#    save_to_dir="D:/Separating Images into subfolders/val_augmented"


test_generator = test_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_class_treatment_grah/test",
    target_size=(300, 300),
    color_mode="rgb",
    batch_size=1,
    class_mode="categorical",
    shuffle=False,
    seed=42)
#    save_to_dir="D:/Separating Images into subfolders/test_augmented")


# Fitting/Training the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
experiment_id = get_experiment_id()
callbacks = [
    #QWK(valid_generator, STEP_SIZE_VALID),
    EarlyStopping(monitor='val_acc', patience=50, min_delta=0.001, verbose=1),
    ModelCheckpoint(experiment_id + "-val_acc_checkpoint.hdf5", monitor='val_acc', verbose=1, save_best_only=True, mode='max'),
    ReduceLROnPlateau(monitor='val_acc', factor=0.5, patience=7, verbose=1, mode='auto', min_delta=0.001, cooldown=0, min_lr=1e-7),
    VCM(valid_generator,STEP_SIZE_VALID)
    
]

class_weight_list = class_weight.compute_class_weight('balanced', np.unique(train_generator.classes), train_generator.classes)
class_weights = dict(zip(np.unique(train_generator.classes), class_weight_list))

history=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    #class_weight=class_weights,
                    callbacks=callbacks,
                    epochs=35  
)


# Evaluating the model 
#predicting output
#reseting the test generator before calling predict_generator, in order not to get weird output
test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 296, 296, 16)      1216
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 292, 292, 16)      6416
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 290, 290, 16)      2320
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 288, 288, 16)      2320
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 284, 284, 16)      6416
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 280, 280, 16)      6416
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 276, 276, 16)      6416
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 272, 272, 16)      6416
# _________________________________________________________________
# fractional_pooling2d_1 (Frac (None, 151, 151, 16)      0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 149, 149, 32)      4640
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 147, 147, 32)      9248
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 145, 145, 32)      9248
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 143, 143, 32)      9248
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 141, 141, 32)      9248
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 139, 139, 32)      9248
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 137, 137, 32)      9248
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 135, 135, 32)      9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 67, 67, 32)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 65, 65, 64)        18496
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 63, 63, 64)        36928
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 61, 61, 64)        36928
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 59, 59, 64)        36928
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 57, 57, 64)        36928
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 55, 55, 64)        36928
# _________________________________________________________________
# fractional_pooling2d_2 (Frac (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 28, 28, 64)        36928
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 26, 26, 64)        36928
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 24, 24, 64)        36928
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 22, 22, 64)        36928
# _________________________________________________________________
# fractional_pooling2d_3 (Frac (None, 12, 12, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 9216)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 18434
# =================================================================
# Total params: 476,594
# Trainable params: 476,594
# Non-trainable params: 0
# _________________________________________________________________
# Found 294 images belonging to 2 classes.
# Found 58 images belonging to 2 classes.
# Found 88 images belonging to 2 classes.
# Epoch 1/35
# 4/4 [==============================] - 31s 8s/step - loss: 0.6159 - mean_absolute_error: 0.4537 - acc: 0.7952 - loss_no_weight_decay: 0.6159 - val_loss: 0.5715 - val_mean_absolute_error: 0.3795 - val_acc: 0.7414 - val_loss_no_weight_decay: 0.5715
#
# Epoch 00001: val_acc improved from -inf to 0.74138, saving model to base_2020-05-10-15-47-00-val_acc_checkpoint.hdf5
# Confusion matrix:
#  []
# Epoch 2/35
# 4/4 [==============================] - 12s 3s/step - loss: 0.4813 - mean_absolute_error: 0.2942 - acc: 0.8164 - loss_no_weight_decay: 0.4813 - val_loss: 0.6550 - val_mean_absolute_error: 0.3122 - val_acc: 0.7414 - val_loss_no_weight_decay: 0.6550
#
# Epoch 00002: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# Epoch 3/35
# 4/4 [==============================] - 11s 3s/step - loss: 0.5562 - mean_absolute_error: 0.3164 - acc: 0.7770 - loss_no_weight_decay: 0.5562 - val_loss: 0.5718 - val_mean_absolute_error: 0.3755 - val_acc: 0.7414 - val_loss_no_weight_decay: 0.5718
#
# Epoch 00003: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# Epoch 4/35
# 4/4 [==============================] - 11s 3s/step - loss: 0.5229 - mean_absolute_error: 0.3584 - acc: 0.7924 - loss_no_weight_decay: 0.5229 - val_loss: 0.5733 - val_mean_absolute_error: 0.3709 - val_acc: 0.7414 - val_loss_no_weight_decay: 0.5733
#
# Epoch 00004: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# Epoch 5/35
# 4/4 [==============================] - 11s 3s/step - loss: 0.5084 - mean_absolute_error: 0.3273 - acc: 0.7952 - loss_no_weight_decay: 0.5084 - val_loss: 0.5877 - val_mean_absolute_error: 0.3481 - val_acc: 0.7414 - val_loss_no_weight_decay: 0.5877
#
# Epoch 00005: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# Epoch 6/35
# 4/4 [==============================] - 11s 3s/step - loss: 0.5215 - mean_absolute_error: 0.3118 - acc: 0.7893 - loss_no_weight_decay: 0.5215 - val_loss: 0.5756 - val_mean_absolute_error: 0.3644 - val_acc: 0.7414 - val_loss_no_weight_decay: 0.5756
#
# Epoch 00006: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# Epoch 7/35
# 4/4 [==============================] - 12s 3s/step - loss: 0.4880 - mean_absolute_error: 0.3290 - acc: 0.8125 - loss_no_weight_decay: 0.4880 - val_loss: 0.5772 - val_mean_absolute_error: 0.3616 - val_acc: 0.7414 - val_loss_no_weight_decay: 0.5772
#
# Epoch 00007: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# Epoch 8/35
# 4/4 [==============================] - 11s 3s/step - loss: 0.5154 - mean_absolute_error: 0.3222 - acc: 0.7914 - loss_no_weight_decay: 0.5154 - val_loss: 0.5805 - val_mean_absolute_error: 0.3563 - val_acc: 0.7414 - val_loss_no_weight_decay: 0.5805
#
# Epoch 00008: val_acc did not improve from 0.74138
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Confusion matrix:
#  []
# Epoch 9/35
# 4/4 [==============================] - 10s 3s/step - loss: 0.4825 - mean_absolute_error: 0.3136 - acc: 0.8133 - loss_no_weight_decay: 0.4825 - val_loss: 0.5807 - val_mean_absolute_error: 0.3561 - val_acc: 0.7414 - val_loss_no_weight_decay: 0.5807
#
# Epoch 00009: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# Epoch 10/35
# 4/4 [==============================] - 11s 3s/step - loss: 0.5048 - mean_absolute_error: 0.3266 - acc: 0.7973 - loss_no_weight_decay: 0.5048 - val_loss: 0.5802 - val_mean_absolute_error: 0.3570 - val_acc: 0.7414 - val_loss_no_weight_decay: 0.5802
#
# Epoch 00010: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# Epoch 11/35
# 4/4 [==============================] - 12s 3s/step - loss: 0.5158 - mean_absolute_error: 0.3315 - acc: 0.7891 - loss_no_weight_decay: 0.5158 - val_loss: 0.5793 - val_mean_absolute_error: 0.3582 - val_acc: 0.7414 - val_loss_no_weight_decay: 0.5793
#
# Epoch 00011: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# Epoch 12/35
# 4/4 [==============================] - 10s 2s/step - loss: 0.4696 - mean_absolute_error: 0.3049 - acc: 0.8226 - loss_no_weight_decay: 0.4696 - val_loss: 0.5896 - val_mean_absolute_error: 0.3460 - val_acc: 0.7414 - val_loss_no_weight_decay: 0.5896
#
# Epoch 00012: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# Epoch 13/35
# 4/4 [==============================] - 11s 3s/step - loss: 0.4857 - mean_absolute_error: 0.2988 - acc: 0.8114 - loss_no_weight_decay: 0.4857 - val_loss: 0.5935 - val_mean_absolute_error: 0.3426 - val_acc: 0.7414 - val_loss_no_weight_decay: 0.5935
#
# Epoch 00013: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# Epoch 14/35
# 4/4 [==============================] - 12s 3s/step - loss: 0.4963 - mean_absolute_error: 0.3048 - acc: 0.8047 - loss_no_weight_decay: 0.4963 - val_loss: 0.5852 - val_mean_absolute_error: 0.3505 - val_acc: 0.7414 - val_loss_no_weight_decay: 0.5852
#
# Epoch 00014: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# Epoch 15/35
# 4/4 [==============================] - 11s 3s/step - loss: 0.5273 - mean_absolute_error: 0.3298 - acc: 0.7810 - loss_no_weight_decay: 0.5273 - val_loss: 0.5754 - val_mean_absolute_error: 0.3649 - val_acc: 0.7414 - val_loss_no_weight_decay: 0.5754
#
# Epoch 00015: val_acc did not improve from 0.74138
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Confusion matrix:
#  []
# Epoch 16/35
# 4/4 [==============================] - 12s 3s/step - loss: 0.4929 - mean_absolute_error: 0.3321 - acc: 0.8086 - loss_no_weight_decay: 0.4929 - val_loss: 0.5733 - val_mean_absolute_error: 0.3701 - val_acc: 0.7414 - val_loss_no_weight_decay: 0.5733
#
# Epoch 00016: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# Epoch 17/35
# 4/4 [==============================] - 11s 3s/step - loss: 0.4948 - mean_absolute_error: 0.3345 - acc: 0.8069 - loss_no_weight_decay: 0.4948 - val_loss: 0.5757 - val_mean_absolute_error: 0.3645 - val_acc: 0.7414 - val_loss_no_weight_decay: 0.5757
#
# Epoch 00017: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# Epoch 18/35
# 4/4 [==============================] - 10s 2s/step - loss: 0.5405 - mean_absolute_error: 0.3513 - acc: 0.7704 - loss_no_weight_decay: 0.5405 - val_loss: 0.5759 - val_mean_absolute_error: 0.3638 - val_acc: 0.7414 - val_loss_no_weight_decay: 0.5759
#
# Epoch 00018: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# Epoch 19/35
# 4/4 [==============================] - 12s 3s/step - loss: 0.5152 - mean_absolute_error: 0.3348 - acc: 0.7891 - loss_no_weight_decay: 0.5152 - val_loss: 0.5787 - val_mean_absolute_error: 0.3589 - val_acc: 0.7414 - val_loss_no_weight_decay: 0.5787
#
# Epoch 00019: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# Epoch 20/35
# 4/4 [==============================] - 11s 3s/step - loss: 0.4964 - mean_absolute_error: 0.3208 - acc: 0.8031 - loss_no_weight_decay: 0.4964 - val_loss: 0.5823 - val_mean_absolute_error: 0.3539 - val_acc: 0.7414 - val_loss_no_weight_decay: 0.5823
#
# Epoch 00020: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# Epoch 21/35
# 4/4 [==============================] - 11s 3s/step - loss: 0.4669 - mean_absolute_error: 0.3032 - acc: 0.8240 - loss_no_weight_decay: 0.4669 - val_loss: 0.5871 - val_mean_absolute_error: 0.3483 - val_acc: 0.7414 - val_loss_no_weight_decay: 0.5871
#
# Epoch 00021: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# Epoch 22/35
# 4/4 [==============================] - 12s 3s/step - loss: 0.5170 - mean_absolute_error: 0.3187 - acc: 0.7891 - loss_no_weight_decay: 0.5170 - val_loss: 0.5871 - val_mean_absolute_error: 0.3483 - val_acc: 0.7414 - val_loss_no_weight_decay: 0.5871
#
# Epoch 00022: val_acc did not improve from 0.74138
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Confusion matrix:
#  []
# Epoch 23/35
# 4/4 [==============================] - 10s 2s/step - loss: 0.5237 - mean_absolute_error: 0.3225 - acc: 0.7848 - loss_no_weight_decay: 0.5237 - val_loss: 0.5841 - val_mean_absolute_error: 0.3517 - val_acc: 0.7414 - val_loss_no_weight_decay: 0.5841
#
# Epoch 00023: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# Epoch 24/35
# 4/4 [==============================] - 12s 3s/step - loss: 0.4945 - mean_absolute_error: 0.3156 - acc: 0.8047 - loss_no_weight_decay: 0.4945 - val_loss: 0.5816 - val_mean_absolute_error: 0.3548 - val_acc: 0.7414 - val_loss_no_weight_decay: 0.5816
#
# Epoch 00024: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# Epoch 25/35
# 4/4 [==============================] - 11s 3s/step - loss: 0.5100 - mean_absolute_error: 0.3239 - acc: 0.7930 - loss_no_weight_decay: 0.5100 - val_loss: 0.5804 - val_mean_absolute_error: 0.3564 - val_acc: 0.7414 - val_loss_no_weight_decay: 0.5804
#
# Epoch 00025: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# Epoch 26/35
# 4/4 [==============================] - 11s 3s/step - loss: 0.5154 - mean_absolute_error: 0.3306 - acc: 0.7896 - loss_no_weight_decay: 0.5154 - val_loss: 0.5781 - val_mean_absolute_error: 0.3599 - val_acc: 0.7414 - val_loss_no_weight_decay: 0.5781
#
# Epoch 00026: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# Epoch 27/35
# 4/4 [==============================] - 12s 3s/step - loss: 0.4785 - mean_absolute_error: 0.3150 - acc: 0.8164 - loss_no_weight_decay: 0.4785 - val_loss: 0.5799 - val_mean_absolute_error: 0.3575 - val_acc: 0.7414 - val_loss_no_weight_decay: 0.5799
#
# Epoch 00027: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# Epoch 28/35
# 4/4 [==============================] - 10s 2s/step - loss: 0.5043 - mean_absolute_error: 0.3231 - acc: 0.7975 - loss_no_weight_decay: 0.5043 - val_loss: 0.5810 - val_mean_absolute_error: 0.3554 - val_acc: 0.7414 - val_loss_no_weight_decay: 0.5810
#
# Epoch 00028: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# Epoch 29/35
# 4/4 [==============================] - 12s 3s/step - loss: 0.4938 - mean_absolute_error: 0.3178 - acc: 0.8047 - loss_no_weight_decay: 0.4938 - val_loss: 0.5817 - val_mean_absolute_error: 0.3548 - val_acc: 0.7414 - val_loss_no_weight_decay: 0.5817
#
# Epoch 00029: val_acc did not improve from 0.74138
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Confusion matrix:
#  []
# Epoch 30/35
# 4/4 [==============================] - 11s 3s/step - loss: 0.5038 - mean_absolute_error: 0.3201 - acc: 0.7976 - loss_no_weight_decay: 0.5038 - val_loss: 0.5828 - val_mean_absolute_error: 0.3535 - val_acc: 0.7414 - val_loss_no_weight_decay: 0.5828
#
# Epoch 00030: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# Epoch 31/35
# 4/4 [==============================] - 11s 3s/step - loss: 0.5073 - mean_absolute_error: 0.3209 - acc: 0.7952 - loss_no_weight_decay: 0.5073 - val_loss: 0.5828 - val_mean_absolute_error: 0.3533 - val_acc: 0.7414 - val_loss_no_weight_decay: 0.5828
#
# Epoch 00031: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# Epoch 32/35
# 4/4 [==============================] - 12s 3s/step - loss: 0.5158 - mean_absolute_error: 0.3245 - acc: 0.7891 - loss_no_weight_decay: 0.5158 - val_loss: 0.5822 - val_mean_absolute_error: 0.3539 - val_acc: 0.7414 - val_loss_no_weight_decay: 0.5822
#
# Epoch 00032: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# Epoch 33/35
# 4/4 [==============================] - 10s 2s/step - loss: 0.4749 - mean_absolute_error: 0.3070 - acc: 0.8182 - loss_no_weight_decay: 0.4749 - val_loss: 0.5828 - val_mean_absolute_error: 0.3534 - val_acc: 0.7414 - val_loss_no_weight_decay: 0.5828
#
# Epoch 00033: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# Epoch 34/35
# 4/4 [==============================] - 12s 3s/step - loss: 0.4939 - mean_absolute_error: 0.3145 - acc: 0.8047 - loss_no_weight_decay: 0.4939 - val_loss: 0.5831 - val_mean_absolute_error: 0.3530 - val_acc: 0.7414 - val_loss_no_weight_decay: 0.5831
#
# Epoch 00034: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# Epoch 35/35
# 4/4 [==============================] - 11s 3s/step - loss: 0.5040 - mean_absolute_error: 0.3187 - acc: 0.7976 - loss_no_weight_decay: 0.5040 - val_loss: 0.5827 - val_mean_absolute_error: 0.3533 - val_acc: 0.7414 - val_loss_no_weight_decay: 0.5827
#
# Epoch 00035: val_acc did not improve from 0.74138
# Confusion matrix:
#  []
# 88/88 [==============================] - 2s 19ms/step
# 88/88 [==============================] - 1s 14ms/step
# Test loss: 0.5713496621359478
# Test accuracy: 0.3481948741457679
# Confusion Matrix
# [[ 0 22]
#  [ 0 66]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        22
#            1       0.75      1.00      0.86        66
#
#     accuracy                           0.75        88
#    macro avg       0.38      0.50      0.43        88
# weighted avg       0.56      0.75      0.64        88
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
from Kappa_Skl import kappa
def kappa2(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    if len(y_true.shape) > 1 and y_true.shape[1] > 1:
        y_true = y_true.dot(range(y_true.shape[1]))
    if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
        y_pred = y_pred.dot(range(y_pred.shape[1]))
    try:
        return kappa(y_true, y_pred, weights='quadratic')
    except IndexError:
        return np.nan
    
print('Quadratic_wieghted_kappa')
print(kappa2(y_true, y_pred))
# Out:
# Quadratic_wieghted_kappa
# 0.0

# %%
import numpy as np 
import matplotlib.pyplot as plt
import os
import wandb
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model loss.png')

# summarize history for val_kappa
plt.plot(history.history['val_kappa'])
plt.title('Validation_Kappa')
plt.ylabel('val_kappa')
plt.xlabel('epoch')
plt.legend([ 'validation'], loc='upper left')
plt.show()
#plt.savefig('model validation_kappa.png')

# summarize history for mean_absolute _error
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model mean_absolute_error')
plt.ylabel('mean_absolute_error')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model maey.png'
# Out:
# dict_keys(['val_loss', 'val_mean_absolute_error', 'val_acc', 'val_loss_no_weight_decay', 'loss', 'mean_absolute_error', 'acc', 'loss_no_weight_decay', 'lr'])
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-511ccd1e0b9e> in <module>
#      24
#      25 # summarize history for val_kappa
# ---> 26 plt.plot(history.history['val_kappa'])
#      27 plt.title('Validation_Kappa')
#      28 plt.ylabel('val_kappa')
#
# KeyError: 'val_kappa'
