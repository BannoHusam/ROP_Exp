# %%
import keras
from keras.models import Sequential, Input, Model
from keras.losses import mean_squared_error
from keras.layers import  *
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, InputLayer
from keras.regularizers import L1L2, l2, l1
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from custom_pooling import RMSPooling2D
from keras.optimizers import SGD, Adam
from keras.layers import LeakyReLU
#from data import BALANCE_WEIGHTS
from keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
#import os
from datetime import datetime as dt
from custom_loss import WeightedCategoricalCrossEntropy
from VCM import VCM
import keras.backend as K
from Fractional_MAXPOOL import FractionalPooling2D
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
def get_experiment_id():
    time_str = dt.now().strftime('%Y-%m-%d-%H-%M-%S')
    experiment_id = 'base_{}'.format(time_str)
    return experiment_id
p_ratio=[1.0, 1.44, 1.73, 1.0]

model = Sequential()


model.add(Conv2D(16, (5, 5), activation='tanh', input_shape=(270, 270, 3)))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(16, (3, 3), activation='tanh'))
model.add(Conv2D(16, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

#model.add(LeakyReLU(alpha=0.01))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))


model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))


model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))


#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))



#model.add(MaxPooling2D(pool_size=1))




model.add(MaxPooling2D(pool_size=2))

model.add(Flatten())


#chnaged from 10 to 5 because an error 
model.add(Dense(2, activation='softmax'))

sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.count_params()
#adam = Adam(lr=0.0005, decay=1e-6)
#rmsprop
#Mloss = WeightedCategoricalCrossEntropy({0: 0.4125861396437394, 1: 1.4918664786083686, 2: 0.690426457789382, 3: 3.9541433021806855, 4: 4.885604311008468})
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['mae','acc'])
model.summary()
loss_no_weight_decay = model.total_loss - sum(model.losses)
model.metrics_tensors.append(loss_no_weight_decay)
model.metrics_names.append('loss_no_weight_decay')
#############################################################################################
#############################################################################################
#############################################################################################
#############################################################################################
#Preparing Data Augmentation Configuration 
train_datagen = ImageDataGenerator(
        rescale=1./255,
#        featurewise_center=True,
 #       samplewise_center=True,
        shear_range=0,
        zoom_range=0.0,#[1 / 1.15, 1.15],
        horizontal_flip=False,#True,
        rotation_range=0)#90,
#        validation_split=0.2)
"""
For the test set only rescale should be made 
"""
test_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas_noch_bl/train",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="training")
#    save_to_dir="D:/Separating Images into subfolders/train_augmented")


#print(train_generator.class_indices)

valid_generator = valid_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas_noch_bl/vald",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="validation")
#    save_to_dir="D:/Separating Images into subfolders/val_augmented"


test_generator = test_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas_noch_bl/test",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=1,
    class_mode="categorical",
    shuffle=False,
    seed=42)
#    save_to_dir="D:/Separating Images into subfolders/test_augmented")


# Fitting/Training the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
experiment_id = get_experiment_id()
callbacks = [
    EarlyStopping(monitor='val_acc', patience=50, min_delta=0.001, verbose=1),
    ModelCheckpoint(experiment_id + "-val_acc_checkpoint.hdf5", monitor='val_acc', verbose=1, save_best_only=True, mode='auto'),
    ReduceLROnPlateau(monitor='val_acc', factor=0.5, patience=7, verbose=1, mode='auto', min_delta=0.001, cooldown=0, min_lr=1e-7),
    VCM(valid_generator,STEP_SIZE_VALID)
    
]

class_weight_list = class_weight.compute_class_weight('balanced', np.unique(train_generator.classes), train_generator.classes)
class_weights = dict(zip(np.unique(train_generator.classes), class_weight_list))

history=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    #class_weight=class_weights,
                    callbacks=callbacks,
                    epochs=35  
)


# Evaluating the model 
#predicting output
#reseting the test generator before calling predict_generator, in order not to get weird output
test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 266, 266, 16)      1216
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 262, 262, 16)      6416
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 260, 260, 16)      2320
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 258, 258, 16)      2320
# _________________________________________________________________
# fractional_pooling2d_1 (Frac (None, 143, 143, 16)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 139, 139, 16)      6416
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 135, 135, 16)      6416
# _________________________________________________________________
# fractional_pooling2d_2 (Frac (None, 75, 75, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 71, 71, 16)        6416
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 67, 67, 16)        6416
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 65, 65, 32)        4640
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 63, 63, 32)        9248
# _________________________________________________________________
# fractional_pooling2d_3 (Frac (None, 35, 35, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 33, 33, 32)        9248
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 31, 31, 32)        9248
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 29, 29, 64)        18496
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 27, 27, 64)        36928
# _________________________________________________________________
# fractional_pooling2d_4 (Frac (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 13, 13, 64)        36928
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 11, 11, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1600)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 3202
# =================================================================
# Total params: 202,802
# Trainable params: 202,802
# Non-trainable params: 0
# _________________________________________________________________
# Found 576 images belonging to 2 classes.
# Found 40 images belonging to 2 classes.
# Found 66 images belonging to 2 classes.
# Epoch 1/35
# 9/9 [==============================] - 24s 3s/step - loss: 0.6864 - mean_absolute_error: 0.4942 - acc: 0.5608 - loss_no_weight_decay: 0.6864 - val_loss: 0.6900 - val_mean_absolute_error: 0.4979 - val_acc: 0.5000 - val_loss_no_weight_decay: 0.6900
#
# Epoch 00001: val_acc improved from -inf to 0.50000, saving model to base_2020-05-12-13-02-42-val_acc_checkpoint.hdf5
# Confusion matrix:
#  []
# Epoch 2/35
# 9/9 [==============================] - 16s 2s/step - loss: 0.6829 - mean_absolute_error: 0.4938 - acc: 0.5521 - loss_no_weight_decay: 0.6829 - val_loss: 0.6785 - val_mean_absolute_error: 0.4903 - val_acc: 0.5250 - val_loss_no_weight_decay: 0.6785
#
# Epoch 00002: val_acc improved from 0.50000 to 0.52500, saving model to base_2020-05-12-13-02-42-val_acc_checkpoint.hdf5
# Confusion matrix:
#  []
# Epoch 3/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.6701 - mean_absolute_error: 0.4862 - acc: 0.6198 - loss_no_weight_decay: 0.6701 - val_loss: 0.6624 - val_mean_absolute_error: 0.4828 - val_acc: 0.6750 - val_loss_no_weight_decay: 0.6624
#
# Epoch 00003: val_acc improved from 0.52500 to 0.67500, saving model to base_2020-05-12-13-02-42-val_acc_checkpoint.hdf5
# Confusion matrix:
#  []
# Epoch 4/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.6531 - mean_absolute_error: 0.4733 - acc: 0.6441 - loss_no_weight_decay: 0.6531 - val_loss: 0.6418 - val_mean_absolute_error: 0.4680 - val_acc: 0.6000 - val_loss_no_weight_decay: 0.6418
#
# Epoch 00004: val_acc did not improve from 0.67500
# Confusion matrix:
#  []
# Epoch 5/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.6593 - mean_absolute_error: 0.4595 - acc: 0.6250 - loss_no_weight_decay: 0.6593 - val_loss: 0.6323 - val_mean_absolute_error: 0.4600 - val_acc: 0.7250 - val_loss_no_weight_decay: 0.6323
#
# Epoch 00005: val_acc improved from 0.67500 to 0.72500, saving model to base_2020-05-12-13-02-42-val_acc_checkpoint.hdf5
# Confusion matrix:
#  []
# Epoch 6/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.6260 - mean_absolute_error: 0.4520 - acc: 0.6875 - loss_no_weight_decay: 0.6260 - val_loss: 0.6131 - val_mean_absolute_error: 0.4493 - val_acc: 0.7500 - val_loss_no_weight_decay: 0.6131
#
# Epoch 00006: val_acc improved from 0.72500 to 0.75000, saving model to base_2020-05-12-13-02-42-val_acc_checkpoint.hdf5
# Confusion matrix:
#  []
# Epoch 7/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.5975 - mean_absolute_error: 0.4316 - acc: 0.7014 - loss_no_weight_decay: 0.5975 - val_loss: 0.5865 - val_mean_absolute_error: 0.4247 - val_acc: 0.6000 - val_loss_no_weight_decay: 0.5865
#
# Epoch 00007: val_acc did not improve from 0.75000
# Confusion matrix:
#  []
# Epoch 8/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.5835 - mean_absolute_error: 0.4111 - acc: 0.6875 - loss_no_weight_decay: 0.5835 - val_loss: 0.6108 - val_mean_absolute_error: 0.4227 - val_acc: 0.7000 - val_loss_no_weight_decay: 0.6108
#
# Epoch 00008: val_acc did not improve from 0.75000
# Confusion matrix:
#  []
# Epoch 9/35
# 9/9 [==============================] - 16s 2s/step - loss: 0.5847 - mean_absolute_error: 0.4155 - acc: 0.7066 - loss_no_weight_decay: 0.5847 - val_loss: 0.5555 - val_mean_absolute_error: 0.4150 - val_acc: 0.7500 - val_loss_no_weight_decay: 0.5555
#
# Epoch 00009: val_acc did not improve from 0.75000
# Confusion matrix:
#  []
# Epoch 10/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.5581 - mean_absolute_error: 0.3990 - acc: 0.7309 - loss_no_weight_decay: 0.5581 - val_loss: 0.6415 - val_mean_absolute_error: 0.4075 - val_acc: 0.6250 - val_loss_no_weight_decay: 0.6415
#
# Epoch 00010: val_acc did not improve from 0.75000
# Confusion matrix:
#  []
# Epoch 11/35
# 9/9 [==============================] - 18s 2s/step - loss: 0.5568 - mean_absolute_error: 0.3946 - acc: 0.7292 - loss_no_weight_decay: 0.5568 - val_loss: 0.5235 - val_mean_absolute_error: 0.3872 - val_acc: 0.8000 - val_loss_no_weight_decay: 0.5235
#
# Epoch 00011: val_acc improved from 0.75000 to 0.80000, saving model to base_2020-05-12-13-02-42-val_acc_checkpoint.hdf5
# Confusion matrix:
#  []
# Epoch 12/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.5231 - mean_absolute_error: 0.3718 - acc: 0.7535 - loss_no_weight_decay: 0.5231 - val_loss: 0.5171 - val_mean_absolute_error: 0.3773 - val_acc: 0.8000 - val_loss_no_weight_decay: 0.5171
#
# Epoch 00012: val_acc did not improve from 0.80000
# Confusion matrix:
#  []
# Epoch 13/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.5130 - mean_absolute_error: 0.3661 - acc: 0.7535 - loss_no_weight_decay: 0.5130 - val_loss: 0.5145 - val_mean_absolute_error: 0.3638 - val_acc: 0.8000 - val_loss_no_weight_decay: 0.5145
#
# Epoch 00013: val_acc did not improve from 0.80000
# Confusion matrix:
#  []
# Epoch 14/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.5060 - mean_absolute_error: 0.3563 - acc: 0.7500 - loss_no_weight_decay: 0.5060 - val_loss: 0.4967 - val_mean_absolute_error: 0.3576 - val_acc: 0.8000 - val_loss_no_weight_decay: 0.4967
#
# Epoch 00014: val_acc did not improve from 0.80000
# Confusion matrix:
#  []
# Epoch 15/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.5066 - mean_absolute_error: 0.3572 - acc: 0.7604 - loss_no_weight_decay: 0.5066 - val_loss: 0.4629 - val_mean_absolute_error: 0.3333 - val_acc: 0.8000 - val_loss_no_weight_decay: 0.4629
#
# Epoch 00015: val_acc did not improve from 0.80000
# Confusion matrix:
#  []
# Epoch 16/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.4840 - mean_absolute_error: 0.3469 - acc: 0.7639 - loss_no_weight_decay: 0.4840 - val_loss: 0.4465 - val_mean_absolute_error: 0.3348 - val_acc: 0.8000 - val_loss_no_weight_decay: 0.4465
#
# Epoch 00016: val_acc did not improve from 0.80000
# Confusion matrix:
#  []
# Epoch 17/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.4947 - mean_absolute_error: 0.3348 - acc: 0.7587 - loss_no_weight_decay: 0.4947 - val_loss: 0.5239 - val_mean_absolute_error: 0.3675 - val_acc: 0.7000 - val_loss_no_weight_decay: 0.5239
#
# Epoch 00017: val_acc did not improve from 0.80000
# Confusion matrix:
#  []
# Epoch 18/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.4673 - mean_absolute_error: 0.3353 - acc: 0.7622 - loss_no_weight_decay: 0.4673 - val_loss: 0.4305 - val_mean_absolute_error: 0.2986 - val_acc: 0.8000 - val_loss_no_weight_decay: 0.4305
#
# Epoch 00018: val_acc did not improve from 0.80000
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Confusion matrix:
#  []
# Epoch 19/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.4571 - mean_absolute_error: 0.3145 - acc: 0.7726 - loss_no_weight_decay: 0.4571 - val_loss: 0.3983 - val_mean_absolute_error: 0.2971 - val_acc: 0.8500 - val_loss_no_weight_decay: 0.3983
#
# Epoch 00019: val_acc improved from 0.80000 to 0.85000, saving model to base_2020-05-12-13-02-42-val_acc_checkpoint.hdf5
# Confusion matrix:
#  []
# Epoch 20/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.4295 - mean_absolute_error: 0.3066 - acc: 0.7899 - loss_no_weight_decay: 0.4295 - val_loss: 0.3869 - val_mean_absolute_error: 0.2830 - val_acc: 0.8000 - val_loss_no_weight_decay: 0.3869
#
# Epoch 00020: val_acc did not improve from 0.85000
# Confusion matrix:
#  []
# Epoch 21/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.4286 - mean_absolute_error: 0.3000 - acc: 0.7760 - loss_no_weight_decay: 0.4286 - val_loss: 0.4001 - val_mean_absolute_error: 0.2988 - val_acc: 0.8250 - val_loss_no_weight_decay: 0.4001
#
# Epoch 00021: val_acc did not improve from 0.85000
# Confusion matrix:
#  []
# Epoch 22/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.4244 - mean_absolute_error: 0.3007 - acc: 0.7969 - loss_no_weight_decay: 0.4244 - val_loss: 0.3819 - val_mean_absolute_error: 0.2842 - val_acc: 0.8500 - val_loss_no_weight_decay: 0.3819
#
# Epoch 00022: val_acc did not improve from 0.85000
# Confusion matrix:
#  []
# Epoch 23/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.3797 - mean_absolute_error: 0.2751 - acc: 0.8299 - loss_no_weight_decay: 0.3797 - val_loss: 0.3581 - val_mean_absolute_error: 0.2734 - val_acc: 0.8750 - val_loss_no_weight_decay: 0.3581
#
# Epoch 00023: val_acc improved from 0.85000 to 0.87500, saving model to base_2020-05-12-13-02-42-val_acc_checkpoint.hdf5
# Confusion matrix:
#  []
# Epoch 24/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.4665 - mean_absolute_error: 0.2919 - acc: 0.7795 - loss_no_weight_decay: 0.4665 - val_loss: 0.3919 - val_mean_absolute_error: 0.2959 - val_acc: 0.8250 - val_loss_no_weight_decay: 0.3919
#
# Epoch 00024: val_acc did not improve from 0.87500
# Confusion matrix:
#  []
# Epoch 25/35
# 9/9 [==============================] - 18s 2s/step - loss: 0.4127 - mean_absolute_error: 0.3022 - acc: 0.8177 - loss_no_weight_decay: 0.4127 - val_loss: 0.3763 - val_mean_absolute_error: 0.2700 - val_acc: 0.8000 - val_loss_no_weight_decay: 0.3763
#
# Epoch 00025: val_acc did not improve from 0.87500
# Confusion matrix:
#  []
# Epoch 26/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.3938 - mean_absolute_error: 0.2795 - acc: 0.8090 - loss_no_weight_decay: 0.3938 - val_loss: 0.3683 - val_mean_absolute_error: 0.2755 - val_acc: 0.8000 - val_loss_no_weight_decay: 0.3683
#
# Epoch 00026: val_acc did not improve from 0.87500
# Confusion matrix:
#  []
# Epoch 27/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.3742 - mean_absolute_error: 0.2736 - acc: 0.8229 - loss_no_weight_decay: 0.3742 - val_loss: 0.3108 - val_mean_absolute_error: 0.2389 - val_acc: 0.9250 - val_loss_no_weight_decay: 0.3108
#
# Epoch 00027: val_acc improved from 0.87500 to 0.92500, saving model to base_2020-05-12-13-02-42-val_acc_checkpoint.hdf5
# Confusion matrix:
#  []
# Epoch 28/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.3594 - mean_absolute_error: 0.2519 - acc: 0.8333 - loss_no_weight_decay: 0.3594 - val_loss: 0.3383 - val_mean_absolute_error: 0.2125 - val_acc: 0.8500 - val_loss_no_weight_decay: 0.3383
#
# Epoch 00028: val_acc did not improve from 0.92500
# Confusion matrix:
#  []
# Epoch 29/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.3822 - mean_absolute_error: 0.2607 - acc: 0.8142 - loss_no_weight_decay: 0.3822 - val_loss: 0.2936 - val_mean_absolute_error: 0.2260 - val_acc: 0.9500 - val_loss_no_weight_decay: 0.2936
#
# Epoch 00029: val_acc improved from 0.92500 to 0.95000, saving model to base_2020-05-12-13-02-42-val_acc_checkpoint.hdf5
# Confusion matrix:
#  []
# Epoch 30/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.3188 - mean_absolute_error: 0.2346 - acc: 0.8698 - loss_no_weight_decay: 0.3188 - val_loss: 0.2781 - val_mean_absolute_error: 0.2117 - val_acc: 0.9500 - val_loss_no_weight_decay: 0.2781
#
# Epoch 00030: val_acc did not improve from 0.95000
# Confusion matrix:
#  []
# Epoch 31/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.2788 - mean_absolute_error: 0.2118 - acc: 0.8958 - loss_no_weight_decay: 0.2788 - val_loss: 0.2331 - val_mean_absolute_error: 0.1706 - val_acc: 0.9500 - val_loss_no_weight_decay: 0.2331
#
# Epoch 00031: val_acc did not improve from 0.95000
# Confusion matrix:
#  []
# Epoch 32/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.3283 - mean_absolute_error: 0.2104 - acc: 0.8472 - loss_no_weight_decay: 0.3283 - val_loss: 0.2587 - val_mean_absolute_error: 0.1760 - val_acc: 0.9250 - val_loss_no_weight_decay: 0.2587
#
# Epoch 00032: val_acc did not improve from 0.95000
# Confusion matrix:
#  []
# Epoch 33/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.2529 - mean_absolute_error: 0.1892 - acc: 0.9062 - loss_no_weight_decay: 0.2529 - val_loss: 0.2506 - val_mean_absolute_error: 0.1692 - val_acc: 0.9250 - val_loss_no_weight_decay: 0.2506
#
# Epoch 00033: val_acc did not improve from 0.95000
# Confusion matrix:
#  []
# Epoch 34/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.2551 - mean_absolute_error: 0.1867 - acc: 0.9080 - loss_no_weight_decay: 0.2551 - val_loss: 0.2215 - val_mean_absolute_error: 0.1529 - val_acc: 0.9250 - val_loss_no_weight_decay: 0.2215
#
# Epoch 00034: val_acc did not improve from 0.95000
# Confusion matrix:
#  []
# Epoch 35/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.2137 - mean_absolute_error: 0.1576 - acc: 0.9271 - loss_no_weight_decay: 0.2137 - val_loss: 0.2119 - val_mean_absolute_error: 0.1542 - val_acc: 0.9500 - val_loss_no_weight_decay: 0.2119
#
# Epoch 00035: val_acc did not improve from 0.95000
# Confusion matrix:
#  []
# 66/66 [==============================] - 2s 37ms/step
# 66/66 [==============================] - 2s 26ms/step
# Test loss: 0.35722135505674296
# Test accuracy: 0.21103076838489593
# Confusion Matrix
# [[29  4]
#  [ 6 27]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.83      0.88      0.85        33
#            1       0.87      0.82      0.84        33
#
#     accuracy                           0.85        66
#    macro avg       0.85      0.85      0.85        66
# weighted avg       0.85      0.85      0.85        66

# %%
import numpy as np 
import matplotlib.pyplot as plt
import os
import wandb
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_mean_absolute_error', 'val_acc', 'val_loss_no_weight_decay', 'loss', 'mean_absolute_error', 'acc', 'loss_no_weight_decay', 'lr'])

# %%
from Kappa_Skl import kappa
def kappa2(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    if len(y_true.shape) > 1 and y_true.shape[1] > 1:
        y_true = y_true.dot(range(y_true.shape[1]))
    if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
        y_pred = y_pred.dot(range(y_pred.shape[1]))
    try:
        return kappa(y_true, y_pred, weights='quadratic')
    except IndexError:
        return np.nan
    
print('Quadratic_wieghted_kappa')
print(kappa2(y_true, y_pred))
# Out:
# Quadratic_wieghted_kappa
# 0.696969696969697
