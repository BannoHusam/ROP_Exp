# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, InputLayer
from keras.regularizers import L1L2, l2, l1
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from custom_pooling import RMSPooling2D
from keras.optimizers import SGD, Adam
from keras.layers import LeakyReLU
#from data import BALANCE_WEIGHTS
from keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
#import os
from datetime import datetime as dt
from custom_loss import WeightedCategoricalCrossEntropy
from VCM import VCM
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
def get_experiment_id():
    time_str = dt.now().strftime('%Y-%m-%d-%H-%M-%S')
    experiment_id = 'base_{}'.format(time_str)
    return experiment_id
p_ratio=[1.0, 1.44, 1.73, 1.0]

model = Sequential()


model.add(Conv2D(16, (5, 5), activation='tanh', input_shape=(300, 300, 3)))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(16, (3, 3), activation='tanh'))
model.add(Conv2D(16, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))

#model.add(LeakyReLU(alpha=0.01))


model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))



model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))          
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(MaxPooling2D(pool_size=2))
#model.add(MaxPooling2D(pool_size=1))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
model.add(MaxPooling2D(pool_size=2))

model.add(Flatten())


#chnaged from 10 to 5 because an error 
model.add(Dense(2, activation='softmax'))

sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.count_params()
#adam = Adam(lr=0.0005, decay=1e-6)
#rmsprop
#Mloss = WeightedCategoricalCrossEntropy({0: 0.4125861396437394, 1: 1.4918664786083686, 2: 0.690426457789382, 3: 3.9541433021806855, 4: 4.885604311008468})
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['mae','acc'])
model.summary()
loss_no_weight_decay = model.total_loss - sum(model.losses)
model.metrics_tensors.append(loss_no_weight_decay)
model.metrics_names.append('loss_no_weight_decay')
#############################################################################################
#############################################################################################
#############################################################################################
#############################################################################################
#Preparing Data Augmentation Configuration 
train_datagen = ImageDataGenerator(
        rescale=1./255,
#        featurewise_center=True,
 #       samplewise_center=True,
        shear_range=0,
        zoom_range=0.0,#[1 / 1.15, 1.15],
        horizontal_flip=False,#True,
        rotation_range=0)#90,
#        validation_split=0.2)
"""
For the test set only rescale should be made 
"""
test_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas/train",
    target_size=(300, 300),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="training")
#    save_to_dir="D:/Separating Images into subfolders/train_augmented")


#print(train_generator.class_indices)

valid_generator = valid_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas/vald",
    target_size=(300, 300),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="validation")
#    save_to_dir="D:/Separating Images into subfolders/val_augmented"


test_generator = test_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas/test",
    target_size=(300, 300),
    color_mode="rgb",
    batch_size=1,
    class_mode="categorical",
    shuffle=False,
    seed=42)
#    save_to_dir="D:/Separating Images into subfolders/test_augmented")


# Fitting/Training the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
experiment_id = get_experiment_id()
callbacks = [
    EarlyStopping(monitor='val_acc', patience=50, min_delta=0.001, verbose=1),
    ModelCheckpoint(experiment_id + "-val_acc_checkpoint.hdf5", monitor='val_acc', verbose=1, save_best_only=True, mode='auto'),
    ReduceLROnPlateau(monitor='val_acc', factor=0.5, patience=7, verbose=1, mode='auto', min_delta=0.001, cooldown=0, min_lr=1e-7),
    VCM(valid_generator,STEP_SIZE_VALID)
    
]

class_weight_list = class_weight.compute_class_weight('balanced', np.unique(train_generator.classes), train_generator.classes)
class_weights = dict(zip(np.unique(train_generator.classes), class_weight_list))

history=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    #class_weight=class_weights,
                    callbacks=callbacks,
                    epochs=35  
)


# Evaluating the model 
#predicting output
#reseting the test generator before calling predict_generator, in order not to get weird output
test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 296, 296, 16)      1216
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 292, 292, 16)      6416
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 290, 290, 16)      2320
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 288, 288, 16)      2320
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 284, 284, 16)      6416
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 280, 280, 16)      6416
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 276, 276, 16)      6416
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 272, 272, 16)      6416
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 136, 136, 16)      0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 134, 134, 32)      4640
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 132, 132, 32)      9248
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 130, 130, 32)      9248
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 128, 128, 32)      9248
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 126, 126, 32)      9248
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 124, 124, 32)      9248
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 122, 122, 32)      9248
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 120, 120, 32)      9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 60, 60, 32)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 58, 58, 64)        18496
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 56, 56, 64)        36928
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 54, 54, 64)        36928
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 52, 52, 64)        36928
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 50, 50, 64)        36928
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 48, 48, 64)        36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 22, 22, 64)        36928
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 20, 20, 64)        36928
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 18, 18, 64)        36928
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 8194
# =================================================================
# Total params: 466,354
# Trainable params: 466,354
# Non-trainable params: 0
# _________________________________________________________________
# Found 588 images belonging to 2 classes.
# Found 116 images belonging to 2 classes.
# Found 176 images belonging to 2 classes.
# Epoch 1/35
# 9/9 [==============================] - 28s 3s/step - loss: 0.6927 - mean_absolute_error: 0.4985 - acc: 0.5298 - loss_no_weight_decay: 0.6927 - val_loss: 0.7036 - val_mean_absolute_error: 0.5011 - val_acc: 0.4219 - val_loss_no_weight_decay: 0.7036
#
# Epoch 00001: val_acc improved from -inf to 0.42188, saving model to base_2020-05-08-01-50-45-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[ 0 32]
#  [ 0 32]]
# Epoch 2/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.6865 - mean_absolute_error: 0.4952 - acc: 0.5521 - loss_no_weight_decay: 0.6865 - val_loss: 0.6709 - val_mean_absolute_error: 0.4881 - val_acc: 0.6731 - val_loss_no_weight_decay: 0.6709
#
# Epoch 00002: val_acc improved from 0.42188 to 0.67308, saving model to base_2020-05-08-01-50-45-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[15  9]
#  [ 1 27]]
# Epoch 3/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.6479 - mean_absolute_error: 0.4709 - acc: 0.6849 - loss_no_weight_decay: 0.6479 - val_loss: 0.6268 - val_mean_absolute_error: 0.4440 - val_acc: 0.6562 - val_loss_no_weight_decay: 0.6268
#
# Epoch 00003: val_acc did not improve from 0.67308
# Confusion matrix:
#  [[25  3]
#  [20 16]]
# Epoch 4/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.7315 - mean_absolute_error: 0.4706 - acc: 0.5496 - loss_no_weight_decay: 0.7315 - val_loss: 0.7219 - val_mean_absolute_error: 0.4862 - val_acc: 0.5385 - val_loss_no_weight_decay: 0.7219
#
# Epoch 00004: val_acc did not improve from 0.67308
# Confusion matrix:
#  [[ 0 29]
#  [ 0 23]]
# Epoch 5/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.7065 - mean_absolute_error: 0.4998 - acc: 0.5052 - loss_no_weight_decay: 0.7065 - val_loss: 0.6957 - val_mean_absolute_error: 0.5011 - val_acc: 0.4531 - val_loss_no_weight_decay: 0.6957
#
# Epoch 00005: val_acc did not improve from 0.67308
# Confusion matrix:
#  [[30  0]
#  [34  0]]
# Epoch 6/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.7061 - mean_absolute_error: 0.5048 - acc: 0.4323 - loss_no_weight_decay: 0.7061 - val_loss: 0.7000 - val_mean_absolute_error: 0.5027 - val_acc: 0.4423 - val_loss_no_weight_decay: 0.7000
#
# Epoch 00006: val_acc did not improve from 0.67308
# Confusion matrix:
#  [[ 0 29]
#  [ 0 23]]
# Epoch 7/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.6960 - mean_absolute_error: 0.5004 - acc: 0.4907 - loss_no_weight_decay: 0.6960 - val_loss: 0.7050 - val_mean_absolute_error: 0.5037 - val_acc: 0.4531 - val_loss_no_weight_decay: 0.7050
#
# Epoch 00007: val_acc did not improve from 0.67308
# Confusion matrix:
#  [[30  0]
#  [34  0]]
# Epoch 8/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.6918 - mean_absolute_error: 0.4980 - acc: 0.5106 - loss_no_weight_decay: 0.6918 - val_loss: 0.7185 - val_mean_absolute_error: 0.5077 - val_acc: 0.4423 - val_loss_no_weight_decay: 0.7185
#
# Epoch 00008: val_acc did not improve from 0.67308
# Confusion matrix:
#  [[ 0 23]
#  [ 0 29]]
# Epoch 9/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.7009 - mean_absolute_error: 0.4992 - acc: 0.5017 - loss_no_weight_decay: 0.7009 - val_loss: 0.6945 - val_mean_absolute_error: 0.5004 - val_acc: 0.4531 - val_loss_no_weight_decay: 0.6945
#
# Epoch 00009: val_acc did not improve from 0.67308
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Confusion matrix:
#  [[ 0 31]
#  [ 0 33]]
# Epoch 10/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.6914 - mean_absolute_error: 0.4989 - acc: 0.5386 - loss_no_weight_decay: 0.6914 - val_loss: 0.6964 - val_mean_absolute_error: 0.5011 - val_acc: 0.4423 - val_loss_no_weight_decay: 0.6964
#
# Epoch 00010: val_acc did not improve from 0.67308
# Confusion matrix:
#  [[25  0]
#  [27  0]]
# Epoch 11/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.6921 - mean_absolute_error: 0.4986 - acc: 0.5103 - loss_no_weight_decay: 0.6921 - val_loss: 0.6898 - val_mean_absolute_error: 0.4975 - val_acc: 0.5156 - val_loss_no_weight_decay: 0.6898
#
# Epoch 00011: val_acc did not improve from 0.67308
# Confusion matrix:
#  [[30  0]
#  [34  0]]
# Epoch 12/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.6938 - mean_absolute_error: 0.5000 - acc: 0.5002 - loss_no_weight_decay: 0.6938 - val_loss: 0.6892 - val_mean_absolute_error: 0.4980 - val_acc: 0.6923 - val_loss_no_weight_decay: 0.6892
#
# Epoch 00012: val_acc improved from 0.67308 to 0.69231, saving model to base_2020-05-08-01-50-45-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[22  7]
#  [ 9 14]]
# Epoch 13/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.6898 - mean_absolute_error: 0.4983 - acc: 0.6528 - loss_no_weight_decay: 0.6898 - val_loss: 0.6890 - val_mean_absolute_error: 0.4979 - val_acc: 0.7344 - val_loss_no_weight_decay: 0.6890
#
# Epoch 00013: val_acc improved from 0.69231 to 0.73438, saving model to base_2020-05-08-01-50-45-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[20 12]
#  [ 7 25]]
# Epoch 14/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.6903 - mean_absolute_error: 0.4986 - acc: 0.5866 - loss_no_weight_decay: 0.6903 - val_loss: 0.6860 - val_mean_absolute_error: 0.4963 - val_acc: 0.6154 - val_loss_no_weight_decay: 0.6860
#
# Epoch 00014: val_acc did not improve from 0.73438
# Confusion matrix:
#  [[24  1]
#  [21  6]]
# Epoch 15/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.6890 - mean_absolute_error: 0.4979 - acc: 0.5469 - loss_no_weight_decay: 0.6890 - val_loss: 0.6869 - val_mean_absolute_error: 0.4968 - val_acc: 0.6094 - val_loss_no_weight_decay: 0.6869
#
# Epoch 00015: val_acc did not improve from 0.73438
# Confusion matrix:
#  [[25  2]
#  [24 13]]
# Epoch 16/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.6878 - mean_absolute_error: 0.4973 - acc: 0.6077 - loss_no_weight_decay: 0.6878 - val_loss: 0.6869 - val_mean_absolute_error: 0.4968 - val_acc: 0.5962 - val_loss_no_weight_decay: 0.6869
#
# Epoch 00016: val_acc did not improve from 0.73438
# Confusion matrix:
#  [[24  2]
#  [20  6]]
# Epoch 17/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.6882 - mean_absolute_error: 0.4974 - acc: 0.5208 - loss_no_weight_decay: 0.6882 - val_loss: 0.6849 - val_mean_absolute_error: 0.4958 - val_acc: 0.6562 - val_loss_no_weight_decay: 0.6849
#
# Epoch 00017: val_acc did not improve from 0.73438
# Confusion matrix:
#  [[28  4]
#  [19 13]]
# Epoch 18/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.6861 - mean_absolute_error: 0.4964 - acc: 0.6420 - loss_no_weight_decay: 0.6861 - val_loss: 0.6833 - val_mean_absolute_error: 0.4950 - val_acc: 0.6923 - val_loss_no_weight_decay: 0.6833
#
# Epoch 00018: val_acc did not improve from 0.73438
# Confusion matrix:
#  [[18 11]
#  [ 3 20]]
# Epoch 19/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.6852 - mean_absolute_error: 0.4959 - acc: 0.6315 - loss_no_weight_decay: 0.6852 - val_loss: 0.6787 - val_mean_absolute_error: 0.4926 - val_acc: 0.7031 - val_loss_no_weight_decay: 0.6787
#
# Epoch 00019: val_acc did not improve from 0.73438
# Confusion matrix:
#  [[11 19]
#  [ 1 33]]
# Epoch 20/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.6837 - mean_absolute_error: 0.4950 - acc: 0.6310 - loss_no_weight_decay: 0.6837 - val_loss: 0.6814 - val_mean_absolute_error: 0.4939 - val_acc: 0.7308 - val_loss_no_weight_decay: 0.6814
#
# Epoch 00020: val_acc did not improve from 0.73438
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Confusion matrix:
#  [[17 10]
#  [ 2 23]]
# Epoch 21/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.6801 - mean_absolute_error: 0.4932 - acc: 0.6784 - loss_no_weight_decay: 0.6801 - val_loss: 0.6766 - val_mean_absolute_error: 0.4914 - val_acc: 0.7656 - val_loss_no_weight_decay: 0.6766
#
# Epoch 00021: val_acc improved from 0.73438 to 0.76562, saving model to base_2020-05-08-01-50-45-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[23  8]
#  [12 21]]
# Epoch 22/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.6803 - mean_absolute_error: 0.4933 - acc: 0.6751 - loss_no_weight_decay: 0.6803 - val_loss: 0.6713 - val_mean_absolute_error: 0.4886 - val_acc: 0.6923 - val_loss_no_weight_decay: 0.6713
#
# Epoch 00022: val_acc did not improve from 0.76562
# Confusion matrix:
#  [[21  5]
#  [10 16]]
# Epoch 23/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.6760 - mean_absolute_error: 0.4910 - acc: 0.6696 - loss_no_weight_decay: 0.6760 - val_loss: 0.6689 - val_mean_absolute_error: 0.4873 - val_acc: 0.6875 - val_loss_no_weight_decay: 0.6689
#
# Epoch 00023: val_acc did not improve from 0.76562
# Confusion matrix:
#  [[23  8]
#  [ 9 24]]
# Epoch 24/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.6722 - mean_absolute_error: 0.4888 - acc: 0.6453 - loss_no_weight_decay: 0.6722 - val_loss: 0.6657 - val_mean_absolute_error: 0.4856 - val_acc: 0.7692 - val_loss_no_weight_decay: 0.6657
#
# Epoch 00024: val_acc improved from 0.76562 to 0.76923, saving model to base_2020-05-08-01-50-45-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[18  8]
#  [ 8 18]]
# Epoch 25/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.6688 - mean_absolute_error: 0.4870 - acc: 0.7014 - loss_no_weight_decay: 0.6688 - val_loss: 0.6556 - val_mean_absolute_error: 0.4800 - val_acc: 0.7188 - val_loss_no_weight_decay: 0.6556
#
# Epoch 00025: val_acc did not improve from 0.76923
# Confusion matrix:
#  [[23 11]
#  [ 5 25]]
# Epoch 26/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.6610 - mean_absolute_error: 0.4824 - acc: 0.6918 - loss_no_weight_decay: 0.6610 - val_loss: 0.6549 - val_mean_absolute_error: 0.4789 - val_acc: 0.7115 - val_loss_no_weight_decay: 0.6549
#
# Epoch 00026: val_acc did not improve from 0.76923
# Confusion matrix:
#  [[20  4]
#  [12 16]]
# Epoch 27/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.6562 - mean_absolute_error: 0.4786 - acc: 0.6788 - loss_no_weight_decay: 0.6562 - val_loss: 0.6332 - val_mean_absolute_error: 0.4663 - val_acc: 0.7188 - val_loss_no_weight_decay: 0.6332
#
# Epoch 00027: val_acc did not improve from 0.76923
# Confusion matrix:
#  [[28  7]
#  [10 19]]
# Epoch 28/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.6326 - mean_absolute_error: 0.4642 - acc: 0.6904 - loss_no_weight_decay: 0.6326 - val_loss: 0.6317 - val_mean_absolute_error: 0.4617 - val_acc: 0.6538 - val_loss_no_weight_decay: 0.6317
#
# Epoch 00028: val_acc did not improve from 0.76923
# Confusion matrix:
#  [[27  3]
#  [18  4]]
# Epoch 29/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.6259 - mean_absolute_error: 0.4550 - acc: 0.6563 - loss_no_weight_decay: 0.6259 - val_loss: 0.5928 - val_mean_absolute_error: 0.4374 - val_acc: 0.7500 - val_loss_no_weight_decay: 0.5928
#
# Epoch 00029: val_acc did not improve from 0.76923
# Confusion matrix:
#  [[28  5]
#  [15 16]]
# Epoch 30/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.6102 - mean_absolute_error: 0.4435 - acc: 0.6649 - loss_no_weight_decay: 0.6102 - val_loss: 0.6045 - val_mean_absolute_error: 0.4406 - val_acc: 0.6154 - val_loss_no_weight_decay: 0.6045
#
# Epoch 00030: val_acc did not improve from 0.76923
# Confusion matrix:
#  [[20  6]
#  [ 9 17]]
# Epoch 31/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.5924 - mean_absolute_error: 0.4299 - acc: 0.6892 - loss_no_weight_decay: 0.5924 - val_loss: 0.5800 - val_mean_absolute_error: 0.4222 - val_acc: 0.6406 - val_loss_no_weight_decay: 0.5800
#
# Epoch 00031: val_acc did not improve from 0.76923
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Confusion matrix:
#  [[30  7]
#  [ 9 18]]
# Epoch 32/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.5819 - mean_absolute_error: 0.4201 - acc: 0.6732 - loss_no_weight_decay: 0.5819 - val_loss: 0.5486 - val_mean_absolute_error: 0.4078 - val_acc: 0.7692 - val_loss_no_weight_decay: 0.5486
#
# Epoch 00032: val_acc did not improve from 0.76923
# Confusion matrix:
#  [[15  2]
#  [13 22]]
# Epoch 33/35
# 9/9 [==============================] - 13s 1s/step - loss: 0.5844 - mean_absolute_error: 0.4153 - acc: 0.7044 - loss_no_weight_decay: 0.5844 - val_loss: 0.5574 - val_mean_absolute_error: 0.4020 - val_acc: 0.7188 - val_loss_no_weight_decay: 0.5574
#
# Epoch 00033: val_acc did not improve from 0.76923
# Confusion matrix:
#  [[28  7]
#  [ 9 20]]
# Epoch 34/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.5476 - mean_absolute_error: 0.3980 - acc: 0.7235 - loss_no_weight_decay: 0.5476 - val_loss: 0.5465 - val_mean_absolute_error: 0.4032 - val_acc: 0.7500 - val_loss_no_weight_decay: 0.5465
#
# Epoch 00034: val_acc did not improve from 0.76923
# Confusion matrix:
#  [[20  7]
#  [10 15]]
# Epoch 35/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.5668 - mean_absolute_error: 0.4053 - acc: 0.7066 - loss_no_weight_decay: 0.5668 - val_loss: 0.5313 - val_mean_absolute_error: 0.3944 - val_acc: 0.7812 - val_loss_no_weight_decay: 0.5313
#
# Epoch 00035: val_acc improved from 0.76923 to 0.78125, saving model to base_2020-05-08-01-50-45-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[27  3]
#  [11 23]]
# 176/176 [==============================] - 5s 30ms/step
# 176/176 [==============================] - 5s 30ms/step
# Test loss: 0.5832029994873499
# Test accuracy: 0.4191358727402985
# Confusion Matrix
# [[67 21]
#  [37 51]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.64      0.76      0.70        88
#            1       0.71      0.58      0.64        88
#
#     accuracy                           0.67       176
#    macro avg       0.68      0.67      0.67       176
# weighted avg       0.68      0.67      0.67       176

# %%
import numpy as np 
import matplotlib.pyplot as plt
import os
import wandb
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_mean_absolute_error', 'val_acc', 'val_loss_no_weight_decay', 'loss', 'mean_absolute_error', 'acc', 'loss_no_weight_decay', 'lr'])

# %%
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
from Kappa_Skl import kappa
def kappa2(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    if len(y_true.shape) > 1 and y_true.shape[1] > 1:
        y_true = y_true.dot(range(y_true.shape[1]))
    if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
        y_pred = y_pred.dot(range(y_pred.shape[1]))
    try:
        return kappa(y_true, y_pred, weights='quadratic')
    except IndexError:
        return np.nan
    
print('Quadratic_wieghted_kappa')
print(kappa2(y_true, y_pred))
# Out:
# Quadratic_wieghted_kappa
# 0.34090909090909083

# %%
# summarize history for mean_absolute _error
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model mean_absolute_error')
plt.ylabel('mean_absolute_error')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model maey.png')
