# %%
import keras
from keras.models import Sequential, Input, Model
from keras.losses import mean_squared_error
from keras.layers import  *
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, InputLayer
from keras.regularizers import L1L2, l2, l1
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from custom_pooling import RMSPooling2D
from keras.optimizers import SGD, Adam
from keras.layers import LeakyReLU
#from data import BALANCE_WEIGHTS
from keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
#import os
from datetime import datetime as dt
from custom_loss import WeightedCategoricalCrossEntropy
from VCM import VCM
import keras.backend as K
from Fractional_MAXPOOL import FractionalPooling2D
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
def get_experiment_id():
    time_str = dt.now().strftime('%Y-%m-%d-%H-%M-%S')
    experiment_id = 'base_{}'.format(time_str)
    return experiment_id
p_ratio=[1.0, 1.44, 1.73, 1.0]

model = Sequential()


model.add(Conv2D(16, (5, 5), activation='tanh', input_shape=(270, 270, 3)))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(16, (3, 3), activation='tanh'))
model.add(Conv2D(16, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

#model.add(LeakyReLU(alpha=0.01))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))


model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))


model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))


#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(FractionalPooling2D(pool_ratio=(1, 1.8, 1.8, 1),pseudo_random = True,overlap=True))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))



#model.add(MaxPooling2D(pool_size=1))




model.add(MaxPooling2D(pool_size=2))

model.add(Flatten())


#chnaged from 10 to 5 because an error 
model.add(Dense(2, activation='softmax'))

sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.count_params()
#adam = Adam(lr=0.0005, decay=1e-6)
#rmsprop
#Mloss = WeightedCategoricalCrossEntropy({0: 0.4125861396437394, 1: 1.4918664786083686, 2: 0.690426457789382, 3: 3.9541433021806855, 4: 4.885604311008468})
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['mae','acc'])
model.summary()
loss_no_weight_decay = model.total_loss - sum(model.losses)
model.metrics_tensors.append(loss_no_weight_decay)
model.metrics_names.append('loss_no_weight_decay')
#############################################################################################
#############################################################################################
#############################################################################################
#############################################################################################
#Preparing Data Augmentation Configuration 
train_datagen = ImageDataGenerator(
        rescale=1./255,
#        featurewise_center=True,
 #       samplewise_center=True,
        shear_range=0,
        zoom_range=0.0,#[1 / 1.15, 1.15],
        horizontal_flip=False,#True,
        rotation_range=0)#90,
#        validation_split=0.2)
"""
For the test set only rescale should be made 
"""
test_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas/train",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="training")
#    save_to_dir="D:/Separating Images into subfolders/train_augmented")


#print(train_generator.class_indices)

valid_generator = valid_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas/vald",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="validation")
#    save_to_dir="D:/Separating Images into subfolders/val_augmented"


test_generator = test_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas/test",
    target_size=(270, 270),
    color_mode="rgb",
    batch_size=1,
    class_mode="categorical",
    shuffle=False,
    seed=42)
#    save_to_dir="D:/Separating Images into subfolders/test_augmented")


# Fitting/Training the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
experiment_id = get_experiment_id()
callbacks = [
    EarlyStopping(monitor='val_acc', patience=50, min_delta=0.001, verbose=1),
    ModelCheckpoint(experiment_id + "-val_acc_checkpoint.hdf5", monitor='val_acc', verbose=1, save_best_only=True, mode='auto'),
    ReduceLROnPlateau(monitor='val_acc', factor=0.5, patience=7, verbose=1, mode='auto', min_delta=0.001, cooldown=0, min_lr=1e-7),
    VCM(valid_generator,STEP_SIZE_VALID)
    
]

class_weight_list = class_weight.compute_class_weight('balanced', np.unique(train_generator.classes), train_generator.classes)
class_weights = dict(zip(np.unique(train_generator.classes), class_weight_list))

history=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    #class_weight=class_weights,
                    callbacks=callbacks,
                    epochs=35  
)


# Evaluating the model 
#predicting output
#reseting the test generator before calling predict_generator, in order not to get weird output
test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 266, 266, 16)      1216
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 262, 262, 16)      6416
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 260, 260, 16)      2320
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 258, 258, 16)      2320
# _________________________________________________________________
# fractional_pooling2d_1 (Frac (None, 143, 143, 16)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 139, 139, 16)      6416
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 135, 135, 16)      6416
# _________________________________________________________________
# fractional_pooling2d_2 (Frac (None, 75, 75, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 71, 71, 16)        6416
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 67, 67, 16)        6416
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 65, 65, 32)        4640
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 63, 63, 32)        9248
# _________________________________________________________________
# fractional_pooling2d_3 (Frac (None, 35, 35, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 33, 33, 32)        9248
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 31, 31, 32)        9248
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 29, 29, 64)        18496
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 27, 27, 64)        36928
# _________________________________________________________________
# fractional_pooling2d_4 (Frac (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 13, 13, 64)        36928
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 11, 11, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1600)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 3202
# =================================================================
# Total params: 202,802
# Trainable params: 202,802
# Non-trainable params: 0
# _________________________________________________________________
# Found 588 images belonging to 2 classes.
# Found 116 images belonging to 2 classes.
# Found 176 images belonging to 2 classes.
# Epoch 1/35
# 9/9 [==============================] - 22s 2s/step - loss: 0.6919 - mean_absolute_error: 0.4992 - acc: 0.5268 - loss_no_weight_decay: 0.6919 - val_loss: 0.6863 - val_mean_absolute_error: 0.4965 - val_acc: 0.6562 - val_loss_no_weight_decay: 0.6863
#
# Epoch 00001: val_acc improved from -inf to 0.65625, saving model to base_2020-05-07-23-38-37-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[17 15]
#  [12 20]]
# Epoch 2/35
# 9/9 [==============================] - 16s 2s/step - loss: 0.6796 - mean_absolute_error: 0.4926 - acc: 0.6012 - loss_no_weight_decay: 0.6796 - val_loss: 0.6662 - val_mean_absolute_error: 0.4837 - val_acc: 0.5769 - val_loss_no_weight_decay: 0.6662
#
# Epoch 00002: val_acc did not improve from 0.65625
# Confusion matrix:
#  [[ 5 21]
#  [ 0 26]]
# Epoch 3/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.6755 - mean_absolute_error: 0.4871 - acc: 0.5590 - loss_no_weight_decay: 0.6755 - val_loss: 0.6744 - val_mean_absolute_error: 0.4878 - val_acc: 0.6562 - val_loss_no_weight_decay: 0.6744
#
# Epoch 00003: val_acc did not improve from 0.65625
# Confusion matrix:
#  [[24  4]
#  [17 19]]
# Epoch 4/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.6828 - mean_absolute_error: 0.4793 - acc: 0.6090 - loss_no_weight_decay: 0.6828 - val_loss: 0.6663 - val_mean_absolute_error: 0.4710 - val_acc: 0.5769 - val_loss_no_weight_decay: 0.6663
#
# Epoch 00004: val_acc did not improve from 0.65625
# Confusion matrix:
#  [[ 4 22]
#  [ 1 25]]
# Epoch 5/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.6690 - mean_absolute_error: 0.4778 - acc: 0.5903 - loss_no_weight_decay: 0.6690 - val_loss: 0.6566 - val_mean_absolute_error: 0.4795 - val_acc: 0.6875 - val_loss_no_weight_decay: 0.6566
#
# Epoch 00005: val_acc improved from 0.65625 to 0.68750, saving model to base_2020-05-07-23-38-37-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[15 15]
#  [ 3 31]]
# Epoch 6/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.6576 - mean_absolute_error: 0.4801 - acc: 0.6729 - loss_no_weight_decay: 0.6576 - val_loss: 0.6467 - val_mean_absolute_error: 0.4732 - val_acc: 0.6923 - val_loss_no_weight_decay: 0.6467
#
# Epoch 00006: val_acc improved from 0.68750 to 0.69231, saving model to base_2020-05-07-23-38-37-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[18  7]
#  [11 16]]
# Epoch 7/35
# 9/9 [==============================] - 16s 2s/step - loss: 0.6279 - mean_absolute_error: 0.4598 - acc: 0.7097 - loss_no_weight_decay: 0.6279 - val_loss: 0.6033 - val_mean_absolute_error: 0.4396 - val_acc: 0.7500 - val_loss_no_weight_decay: 0.6033
#
# Epoch 00007: val_acc improved from 0.69231 to 0.75000, saving model to base_2020-05-07-23-38-37-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[17 13]
#  [14 20]]
# Epoch 8/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.6378 - mean_absolute_error: 0.4358 - acc: 0.6516 - loss_no_weight_decay: 0.6378 - val_loss: 0.6057 - val_mean_absolute_error: 0.4317 - val_acc: 0.6538 - val_loss_no_weight_decay: 0.6057
#
# Epoch 00008: val_acc did not improve from 0.75000
# Confusion matrix:
#  [[18  7]
#  [ 8 19]]
# Epoch 9/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.5995 - mean_absolute_error: 0.4315 - acc: 0.6858 - loss_no_weight_decay: 0.5995 - val_loss: 0.5988 - val_mean_absolute_error: 0.4275 - val_acc: 0.6719 - val_loss_no_weight_decay: 0.5988
#
# Epoch 00009: val_acc did not improve from 0.75000
# Confusion matrix:
#  [[14 17]
#  [ 5 28]]
# Epoch 10/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.5830 - mean_absolute_error: 0.4209 - acc: 0.7167 - loss_no_weight_decay: 0.5830 - val_loss: 0.5650 - val_mean_absolute_error: 0.4053 - val_acc: 0.7308 - val_loss_no_weight_decay: 0.5650
#
# Epoch 00010: val_acc did not improve from 0.75000
# Confusion matrix:
#  [[16  8]
#  [ 8 20]]
# Epoch 11/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.5676 - mean_absolute_error: 0.3964 - acc: 0.6962 - loss_no_weight_decay: 0.5676 - val_loss: 0.5747 - val_mean_absolute_error: 0.3901 - val_acc: 0.6719 - val_loss_no_weight_decay: 0.5747
#
# Epoch 00011: val_acc did not improve from 0.75000
# Confusion matrix:
#  [[18 12]
#  [ 4 30]]
# Epoch 12/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.5666 - mean_absolute_error: 0.3948 - acc: 0.7098 - loss_no_weight_decay: 0.5666 - val_loss: 0.5342 - val_mean_absolute_error: 0.3900 - val_acc: 0.7500 - val_loss_no_weight_decay: 0.5342
#
# Epoch 00012: val_acc did not improve from 0.75000
# Confusion matrix:
#  [[20 12]
#  [ 3 17]]
# Epoch 13/35
# 9/9 [==============================] - 16s 2s/step - loss: 0.5647 - mean_absolute_error: 0.4022 - acc: 0.7207 - loss_no_weight_decay: 0.5647 - val_loss: 0.5855 - val_mean_absolute_error: 0.4162 - val_acc: 0.6875 - val_loss_no_weight_decay: 0.5855
# Epoch 00013: val_acc did not improve from 0.75000
# Confusion matrix:
#  [[20 12]
#  [ 8 24]]
# Epoch 14/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.5365 - mean_absolute_error: 0.3801 - acc: 0.7344 - loss_no_weight_decay: 0.5365 - val_loss: 0.4728 - val_mean_absolute_error: 0.3427 - val_acc: 0.8269 - val_loss_no_weight_decay: 0.4728
#
# Epoch 00014: val_acc improved from 0.75000 to 0.82692, saving model to base_2020-05-07-23-38-37-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[20  7]
#  [ 4 21]]
# Epoch 15/35
# 9/9 [==============================] - 16s 2s/step - loss: 0.5458 - mean_absolute_error: 0.3807 - acc: 0.7360 - loss_no_weight_decay: 0.5458 - val_loss: 0.5415 - val_mean_absolute_error: 0.3873 - val_acc: 0.7500 - val_loss_no_weight_decay: 0.5415
#
# Epoch 00015: val_acc did not improve from 0.82692
# Confusion matrix:
#  [[21  6]
#  [ 9 28]]
# Epoch 16/35
# 9/9 [==============================] - 16s 2s/step - loss: 0.5080 - mean_absolute_error: 0.3549 - acc: 0.7493 - loss_no_weight_decay: 0.5080 - val_loss: 0.5111 - val_mean_absolute_error: 0.3490 - val_acc: 0.7308 - val_loss_no_weight_decay: 0.5111
#
# Epoch 00016: val_acc did not improve from 0.82692
# Confusion matrix:
#  [[20  5]
#  [14 13]]
# Epoch 17/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.5519 - mean_absolute_error: 0.3789 - acc: 0.7037 - loss_no_weight_decay: 0.5519 - val_loss: 0.5317 - val_mean_absolute_error: 0.3860 - val_acc: 0.7344 - val_loss_no_weight_decay: 0.5317
#
# Epoch 00017: val_acc did not improve from 0.82692
# Confusion matrix:
#  [[24  8]
#  [11 21]]
# Epoch 18/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.4998 - mean_absolute_error: 0.3632 - acc: 0.7708 - loss_no_weight_decay: 0.4998 - val_loss: 0.4694 - val_mean_absolute_error: 0.3257 - val_acc: 0.7692 - val_loss_no_weight_decay: 0.4694
#
# Epoch 00018: val_acc did not improve from 0.82692
# Confusion matrix:
#  [[13 14]
#  [ 3 22]]
# Epoch 19/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.5093 - mean_absolute_error: 0.3487 - acc: 0.7483 - loss_no_weight_decay: 0.5093 - val_loss: 0.4076 - val_mean_absolute_error: 0.2943 - val_acc: 0.8281 - val_loss_no_weight_decay: 0.4076
#
# Epoch 00019: val_acc improved from 0.82692 to 0.82812, saving model to base_2020-05-07-23-38-37-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[21  9]
#  [ 8 26]]
# Epoch 20/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.5058 - mean_absolute_error: 0.3521 - acc: 0.7467 - loss_no_weight_decay: 0.5058 - val_loss: 0.5424 - val_mean_absolute_error: 0.3780 - val_acc: 0.6538 - val_loss_no_weight_decay: 0.5424
#
# Epoch 00020: val_acc did not improve from 0.82812
# Confusion matrix:
#  [[16  4]
#  [ 8 24]]
# Epoch 21/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.5016 - mean_absolute_error: 0.3563 - acc: 0.7400 - loss_no_weight_decay: 0.5016 - val_loss: 0.4602 - val_mean_absolute_error: 0.3414 - val_acc: 0.7969 - val_loss_no_weight_decay: 0.4602
#
# Epoch 00021: val_acc did not improve from 0.82812
# Confusion matrix:
#  [[24  7]
#  [ 7 26]]
# Epoch 22/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.4995 - mean_absolute_error: 0.3437 - acc: 0.7482 - loss_no_weight_decay: 0.4995 - val_loss: 0.4410 - val_mean_absolute_error: 0.3180 - val_acc: 0.7885 - val_loss_no_weight_decay: 0.4410
#
# Epoch 00022: val_acc did not improve from 0.82812
# Confusion matrix:
#  [[18  7]
#  [ 4 23]]
# Epoch 23/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.4637 - mean_absolute_error: 0.3307 - acc: 0.7886 - loss_no_weight_decay: 0.4637 - val_loss: 0.4616 - val_mean_absolute_error: 0.3306 - val_acc: 0.7344 - val_loss_no_weight_decay: 0.4616
#
# Epoch 00023: val_acc did not improve from 0.82812
# Confusion matrix:
#  [[24  7]
#  [ 9 24]]
# Epoch 24/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.4590 - mean_absolute_error: 0.3153 - acc: 0.7640 - loss_no_weight_decay: 0.4590 - val_loss: 0.3865 - val_mean_absolute_error: 0.2768 - val_acc: 0.8462 - val_loss_no_weight_decay: 0.3865
#
# Epoch 00024: val_acc improved from 0.82812 to 0.84615, saving model to base_2020-05-07-23-38-37-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[22  5]
#  [ 5 20]]
# Epoch 25/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.4441 - mean_absolute_error: 0.3081 - acc: 0.7866 - loss_no_weight_decay: 0.4441 - val_loss: 0.4606 - val_mean_absolute_error: 0.3297 - val_acc: 0.7656 - val_loss_no_weight_decay: 0.4606
#
# Epoch 00025: val_acc did not improve from 0.84615
# Confusion matrix:
#  [[22 12]
#  [ 3 27]]
# Epoch 26/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.4245 - mean_absolute_error: 0.3093 - acc: 0.8036 - loss_no_weight_decay: 0.4245 - val_loss: 0.3996 - val_mean_absolute_error: 0.2789 - val_acc: 0.8077 - val_loss_no_weight_decay: 0.3996
#
# Epoch 00026: val_acc did not improve from 0.84615
# Confusion matrix:
#  [[20  4]
#  [ 6 22]]
# Epoch 27/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.4171 - mean_absolute_error: 0.2961 - acc: 0.8003 - loss_no_weight_decay: 0.4171 - val_loss: 0.4809 - val_mean_absolute_error: 0.3119 - val_acc: 0.7500 - val_loss_no_weight_decay: 0.4809
#
# Epoch 00027: val_acc did not improve from 0.84615
# Confusion matrix:
#  [[22 13]
#  [ 1 28]]
# Epoch 28/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.4265 - mean_absolute_error: 0.2972 - acc: 0.8019 - loss_no_weight_decay: 0.4265 - val_loss: 0.3987 - val_mean_absolute_error: 0.2896 - val_acc: 0.8077 - val_loss_no_weight_decay: 0.3987
#
# Epoch 00028: val_acc did not improve from 0.84615
# Confusion matrix:
#  [[21  1]
#  [ 7 23]]
# Epoch 29/35
# 9/9 [==============================] - 16s 2s/step - loss: 0.3909 - mean_absolute_error: 0.2831 - acc: 0.8149 - loss_no_weight_decay: 0.3909 - val_loss: 0.4351 - val_mean_absolute_error: 0.2880 - val_acc: 0.7812 - val_loss_no_weight_decay: 0.4351
#
# Epoch 00029: val_acc did not improve from 0.84615
# Confusion matrix:
#  [[30  3]
#  [ 3 28]]
# Epoch 30/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.4117 - mean_absolute_error: 0.2768 - acc: 0.7993 - loss_no_weight_decay: 0.4117 - val_loss: 0.3307 - val_mean_absolute_error: 0.2457 - val_acc: 0.8462 - val_loss_no_weight_decay: 0.3307
#
# Epoch 00030: val_acc did not improve from 0.84615
# Confusion matrix:
#  [[19  7]
#  [ 5 21]]
# Epoch 31/35
# 9/9 [==============================] - 16s 2s/step - loss: 0.3183 - mean_absolute_error: 0.2395 - acc: 0.8808 - loss_no_weight_decay: 0.3183 - val_loss: 0.2797 - val_mean_absolute_error: 0.2170 - val_acc: 0.8750 - val_loss_no_weight_decay: 0.2797
#
# Epoch 00031: val_acc improved from 0.84615 to 0.87500, saving model to base_2020-05-07-23-38-37-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[28  9]
#  [ 0 27]]
# Epoch 32/35
# 9/9 [==============================] - 16s 2s/step - loss: 0.3960 - mean_absolute_error: 0.2694 - acc: 0.7941 - loss_no_weight_decay: 0.3960 - val_loss: 0.4404 - val_mean_absolute_error: 0.2988 - val_acc: 0.7885 - val_loss_no_weight_decay: 0.4404
#
# Epoch 00032: val_acc did not improve from 0.87500
# Confusion matrix:
#  [[16  6]
#  [ 1 29]]
# Epoch 33/35
# 9/9 [==============================] - 17s 2s/step - loss: 0.3534 - mean_absolute_error: 0.2607 - acc: 0.8490 - loss_no_weight_decay: 0.3534 - val_loss: 0.3827 - val_mean_absolute_error: 0.2520 - val_acc: 0.8281 - val_loss_no_weight_decay: 0.3827
#
# Epoch 00033: val_acc did not improve from 0.87500
# Confusion matrix:
#  [[30  5]
#  [ 7 22]]
# Epoch 34/35
# 9/9 [==============================] - 15s 2s/step - loss: 0.3404 - mean_absolute_error: 0.2401 - acc: 0.8464 - loss_no_weight_decay: 0.3404 - val_loss: 0.3104 - val_mean_absolute_error: 0.2201 - val_acc: 0.8846 - val_loss_no_weight_decay: 0.3104
#
# Epoch 00034: val_acc improved from 0.87500 to 0.88462, saving model to base_2020-05-07-23-38-37-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[19  7]
#  [ 2 24]]
# Epoch 35/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.3041 - mean_absolute_error: 0.2209 - acc: 0.8824 - loss_no_weight_decay: 0.3041 - val_loss: 0.2816 - val_mean_absolute_error: 0.2011 - val_acc: 0.8750 - val_loss_no_weight_decay: 0.2816
#
# Epoch 00035: val_acc did not improve from 0.88462
# Confusion matrix:
#  [[27  3]
#  [ 2 32]]
# 176/176 [==============================] - 5s 29ms/step
# 176/176 [==============================] - 5s 28ms/step
# Test loss: 0.2454969423336231
# Test accuracy: 0.1847480315965103
# Confusion Matrix
# [[78 10]
#  [ 2 86]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.97      0.89      0.93        88
#            1       0.90      0.98      0.93        88
#
#     accuracy                           0.93       176
#    macro avg       0.94      0.93      0.93       176
# weighted avg       0.94      0.93      0.93       176

# %%
import numpy as np 
import matplotlib.pyplot as plt
import os
import wandb
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_mean_absolute_error', 'val_acc', 'val_loss_no_weight_decay', 'loss', 'mean_absolute_error', 'acc', 'loss_no_weight_decay', 'lr'])

# %%
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
from Kappa_Skl import kappa
def kappa2(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    if len(y_true.shape) > 1 and y_true.shape[1] > 1:
        y_true = y_true.dot(range(y_true.shape[1]))
    if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
        y_pred = y_pred.dot(range(y_pred.shape[1]))
    try:
        return kappa(y_true, y_pred, weights='quadratic')
    except IndexError:
        return np.nan
    
print('Quadratic_wieghted_kappa')
print(kappa2(y_true, y_pred))
# Out:
# Quadratic_wieghted_kappa
# 0.8636363636363636

# %%
# summarize history for mean_absolute _error
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model mean_absolute_error')
plt.ylabel('mean_absolute_error')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model maey.png')
