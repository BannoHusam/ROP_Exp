# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, InputLayer
from keras.regularizers import L1L2, l2, l1
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from custom_pooling import RMSPooling2D
from keras.optimizers import SGD, Adam
from keras.layers import LeakyReLU
#from data import BALANCE_WEIGHTS
from keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
#import os
from datetime import datetime as dt
from custom_loss import WeightedCategoricalCrossEntropy
from VCM import VCM
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
def get_experiment_id():
    time_str = dt.now().strftime('%Y-%m-%d-%H-%M-%S')
    experiment_id = 'base_{}'.format(time_str)
    return experiment_id
p_ratio=[1.0, 1.44, 1.73, 1.0]

model = Sequential()


model.add(Conv2D(16, (5, 5), activation='tanh', input_shape=(128, 128, 3)))
model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(16, (3, 3), activation='tanh'))
model.add(Conv2D(16, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))

#model.add(LeakyReLU(alpha=0.01))


model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))



model.add(Conv2D(16, (5, 5), activation='tanh'))
model.add(Conv2D(16, (5, 5), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))          
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))
#model.add(LeakyReLU(alpha=0.01))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
#model.add(Dense(8,activation='tanh', kernel_regularizer=regularizers.l2(0.0001)))

model.add(Conv2D(32, (3, 3), activation='tanh'))
model.add(Conv2D(32, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))

model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(Conv2D(64, (3, 3), activation='tanh'))
#model.add(InputLayer(input_tensor=tf.nn.fractional_max_pool(model.layers[1].output, p_ratio)[0]))


model.add(MaxPooling2D(pool_size=2))

model.add(Flatten())


#chnaged from 10 to 5 because an error 
model.add(Dense(2, activation='softmax'))

sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.count_params()
#adam = Adam(lr=0.0005, decay=1e-6)
#rmsprop
#Mloss = WeightedCategoricalCrossEntropy({0: 0.4125861396437394, 1: 1.4918664786083686, 2: 0.690426457789382, 3: 3.9541433021806855, 4: 4.885604311008468})
model.compile(loss='mse', optimizer=sgd, metrics=['mae','acc'])
model.summary()
loss_no_weight_decay = model.total_loss - sum(model.losses)
model.metrics_tensors.append(loss_no_weight_decay)
model.metrics_names.append('loss_no_weight_decay')
#############################################################################################
#############################################################################################
#############################################################################################
#############################################################################################
#Preparing Data Augmentation Configuration 
train_datagen = ImageDataGenerator(
        rescale=1./255,
#        featurewise_center=True,
 #       samplewise_center=True,
        shear_range=0,
        zoom_range=0.0,#[1 / 1.15, 1.15],
        horizontal_flip=False,#True,
        rotation_range=0)#90,
#        validation_split=0.2)
"""
For the test set only rescale should be made 
"""
test_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas/train",
    target_size=(128, 128),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="training")
#    save_to_dir="D:/Separating Images into subfolders/train_augmented")


#print(train_generator.class_indices)

valid_generator = valid_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas/vald",
    target_size=(128, 128),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42)
#    subset="validation")
#    save_to_dir="D:/Separating Images into subfolders/val_augmented"


test_generator = test_datagen.flow_from_directory(
    directory=r"/media/husam/Data/ROP_EXp/binary_clas/test",
    target_size=(128, 128),
    color_mode="rgb",
    batch_size=1,
    class_mode="categorical",
    shuffle=False,
    seed=42)
#    save_to_dir="D:/Separating Images into subfolders/test_augmented")


# Fitting/Training the model
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
experiment_id = get_experiment_id()
callbacks = [
    EarlyStopping(monitor='val_acc', patience=50, min_delta=0.001, verbose=1),
    ModelCheckpoint(experiment_id + "-val_acc_checkpoint.hdf5", monitor='val_acc', verbose=1, save_best_only=True, mode='auto'),
    ReduceLROnPlateau(monitor='val_acc', factor=0.5, patience=7, verbose=1, mode='auto', min_delta=0.001, cooldown=0, min_lr=1e-7),
    VCM(valid_generator,STEP_SIZE_VALID)
    
]

class_weight_list = class_weight.compute_class_weight('balanced', np.unique(train_generator.classes), train_generator.classes)
class_weights = dict(zip(np.unique(train_generator.classes), class_weight_list))

history=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    class_weight=class_weights,
                    callbacks=callbacks,
                    epochs=35  
)


# Evaluating the model 
#predicting output
#reseting the test generator before calling predict_generator, in order not to get weird output
test_generator.reset()
#test_imgs, test_labels = next(test_generator)

y_pred = model.predict_generator(test_generator, verbose=1,steps=len(test_generator))

score = model.evaluate_generator(generator=test_generator, verbose=1,steps=len(test_generator))
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#y_pred =


y_pred = np.argmax(y_pred, axis=1) #multiple categories
# mapping the labels to its classes 
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in y_pred]

y_true = (test_generator.classes)
#confusion Matrix and Classification Report
# generator.classes gives you the truth label y_true
print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

print(cm)

print('Classification Report')
target_names = ['0', '1']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 124, 124, 16)      1216
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 120, 120, 16)      6416
# _________________________________________________________________
# input_1 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 118, 118, 16)      2320
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 116, 116, 16)      2320
# _________________________________________________________________
# input_2 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 112, 112, 16)      6416
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 108, 108, 16)      6416
# _________________________________________________________________
# input_3 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 104, 104, 16)      6416
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 100, 100, 16)      6416
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 50, 50, 16)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 48, 48, 32)        4640
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 46, 46, 32)        9248
# _________________________________________________________________
# input_4 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 44, 44, 32)        9248
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 42, 42, 32)        9248
# _________________________________________________________________
# input_5 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 40, 40, 32)        9248
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 38, 38, 32)        9248
# _________________________________________________________________
# input_6 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 36, 36, 32)        9248
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 34, 34, 32)        9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 17, 17, 32)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 15, 15, 64)        18496
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 13, 13, 64)        36928
# _________________________________________________________________
# input_7 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 11, 11, 64)        36928
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 9, 9, 64)          36928
# _________________________________________________________________
# input_8 (InputLayer)         multiple                  0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 7, 7, 64)          36928
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 5, 5, 64)          36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 310,962
# Trainable params: 310,962
# Non-trainable params: 0
# _________________________________________________________________
# Found 588 images belonging to 2 classes.
# Found 116 images belonging to 2 classes.
# Found 176 images belonging to 2 classes.
# Epoch 1/35
# 9/9 [==============================] - 14s 2s/step - loss: 0.2516 - mean_absolute_error: 0.5014 - acc: 0.4464 - loss_no_weight_decay: 0.2516 - val_loss: 0.2478 - val_mean_absolute_error: 0.4975 - val_acc: 0.5625 - val_loss_no_weight_decay: 0.2478
#
# Epoch 00001: val_acc improved from -inf to 0.56250, saving model to base_2020-05-07-11-25-03-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[31  1]
#  [32  0]]
# Epoch 2/35
# 9/9 [==============================] - 10s 1s/step - loss: 0.2508 - mean_absolute_error: 0.5007 - acc: 0.4930 - loss_no_weight_decay: 0.2508 - val_loss: 0.2468 - val_mean_absolute_error: 0.4964 - val_acc: 0.6154 - val_loss_no_weight_decay: 0.2468
#
# Epoch 00002: val_acc improved from 0.56250 to 0.61538, saving model to base_2020-05-07-11-25-03-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[ 3 22]
#  [ 0 27]]
# Epoch 3/35
# 9/9 [==============================] - 10s 1s/step - loss: 0.2492 - mean_absolute_error: 0.4988 - acc: 0.5466 - loss_no_weight_decay: 0.2492 - val_loss: 0.2502 - val_mean_absolute_error: 0.4994 - val_acc: 0.4844 - val_loss_no_weight_decay: 0.2502
#
# Epoch 00003: val_acc did not improve from 0.61538
# Confusion matrix:
#  [[ 0 28]
#  [ 0 36]]
# Epoch 4/35
# 9/9 [==============================] - 10s 1s/step - loss: 0.2507 - mean_absolute_error: 0.4999 - acc: 0.4990 - loss_no_weight_decay: 0.2507 - val_loss: 0.2478 - val_mean_absolute_error: 0.4977 - val_acc: 0.6538 - val_loss_no_weight_decay: 0.2478
#
# Epoch 00004: val_acc improved from 0.61538 to 0.65385, saving model to base_2020-05-07-11-25-03-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[11 16]
#  [ 8 17]]
# Epoch 5/35
# 9/9 [==============================] - 11s 1s/step - loss: 0.2494 - mean_absolute_error: 0.4991 - acc: 0.5035 - loss_no_weight_decay: 0.2494 - val_loss: 0.2489 - val_mean_absolute_error: 0.4984 - val_acc: 0.4844 - val_loss_no_weight_decay: 0.2489
#
# Epoch 00005: val_acc did not improve from 0.65385
# Confusion matrix:
#  [[30  0]
#  [34  0]]
# Epoch 6/35
# 9/9 [==============================] - 9s 1s/step - loss: 0.2479 - mean_absolute_error: 0.4977 - acc: 0.5609 - loss_no_weight_decay: 0.2479 - val_loss: 0.2488 - val_mean_absolute_error: 0.4985 - val_acc: 0.5962 - val_loss_no_weight_decay: 0.2488
#
# Epoch 00006: val_acc did not improve from 0.65385
# Confusion matrix:
#  [[ 9 19]
#  [ 3 21]]
# Epoch 7/35
# 9/9 [==============================] - 9s 994ms/step - loss: 0.2472 - mean_absolute_error: 0.4969 - acc: 0.6008 - loss_no_weight_decay: 0.2472 - val_loss: 0.2449 - val_mean_absolute_error: 0.4947 - val_acc: 0.6562 - val_loss_no_weight_decay: 0.2449
#
# Epoch 00007: val_acc improved from 0.65385 to 0.65625, saving model to base_2020-05-07-11-25-03-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[18 12]
#  [16 18]]
# Epoch 8/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.2460 - mean_absolute_error: 0.4958 - acc: 0.6024 - loss_no_weight_decay: 0.2460 - val_loss: 0.2422 - val_mean_absolute_error: 0.4916 - val_acc: 0.6346 - val_loss_no_weight_decay: 0.2422
#
# Epoch 00008: val_acc did not improve from 0.65625
# Confusion matrix:
#  [[ 8 17]
#  [ 4 23]]
# Epoch 9/35
# 9/9 [==============================] - 10s 1s/step - loss: 0.2439 - mean_absolute_error: 0.4927 - acc: 0.5839 - loss_no_weight_decay: 0.2439 - val_loss: 0.2398 - val_mean_absolute_error: 0.4882 - val_acc: 0.6562 - val_loss_no_weight_decay: 0.2398
#
# Epoch 00009: val_acc did not improve from 0.65625
# Confusion matrix:
#  [[ 7 24]
#  [ 2 31]]
# Epoch 10/35
# 9/9 [==============================] - 10s 1s/step - loss: 0.2419 - mean_absolute_error: 0.4905 - acc: 0.6148 - loss_no_weight_decay: 0.2419 - val_loss: 0.2453 - val_mean_absolute_error: 0.4939 - val_acc: 0.6346 - val_loss_no_weight_decay: 0.2453
#
# Epoch 00010: val_acc did not improve from 0.65625
# Confusion matrix:
#  [[24  3]
#  [12 13]]
# Epoch 11/35
# 9/9 [==============================] - 10s 1s/step - loss: 0.2394 - mean_absolute_error: 0.4875 - acc: 0.6380 - loss_no_weight_decay: 0.2394 - val_loss: 0.2373 - val_mean_absolute_error: 0.4847 - val_acc: 0.6406 - val_loss_no_weight_decay: 0.2373
#
# Epoch 00011: val_acc did not improve from 0.65625
# Confusion matrix:
#  [[22  8]
#  [11 23]]
# Epoch 12/35
# 9/9 [==============================] - 11s 1s/step - loss: 0.2348 - mean_absolute_error: 0.4794 - acc: 0.6606 - loss_no_weight_decay: 0.2348 - val_loss: 0.2255 - val_mean_absolute_error: 0.4655 - val_acc: 0.7115 - val_loss_no_weight_decay: 0.2255
#
# Epoch 00012: val_acc improved from 0.65625 to 0.71154, saving model to base_2020-05-07-11-25-03-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[21  3]
#  [15 13]]
# Epoch 13/35
# 9/9 [==============================] - 10s 1s/step - loss: 0.2432 - mean_absolute_error: 0.4707 - acc: 0.6360 - loss_no_weight_decay: 0.2432 - val_loss: 0.2774 - val_mean_absolute_error: 0.4817 - val_acc: 0.5156 - val_loss_no_weight_decay: 0.2774
#
# Epoch 00013: val_acc did not improve from 0.71154
# Confusion matrix:
#  [[ 3 29]
#  [ 0 32]]
# Epoch 14/35
# 9/9 [==============================] - 10s 1s/step - loss: 0.2310 - mean_absolute_error: 0.4643 - acc: 0.6393 - loss_no_weight_decay: 0.2310 - val_loss: 0.2052 - val_mean_absolute_error: 0.4425 - val_acc: 0.6731 - val_loss_no_weight_decay: 0.2052
#
# Epoch 00014: val_acc did not improve from 0.71154
# Confusion matrix:
#  [[10 18]
#  [ 6 18]]
# Epoch 15/35
# 9/9 [==============================] - 11s 1s/step - loss: 0.2294 - mean_absolute_error: 0.4640 - acc: 0.6354 - loss_no_weight_decay: 0.2294 - val_loss: 0.2084 - val_mean_absolute_error: 0.4411 - val_acc: 0.7031 - val_loss_no_weight_decay: 0.2084
#
# Epoch 00015: val_acc did not improve from 0.71154
# Confusion matrix:
#  [[20  7]
#  [16 21]]
# Epoch 16/35
# 9/9 [==============================] - 8s 933ms/step - loss: 0.2281 - mean_absolute_error: 0.4601 - acc: 0.6144 - loss_no_weight_decay: 0.2281 - val_loss: 0.2513 - val_mean_absolute_error: 0.4756 - val_acc: 0.5577 - val_loss_no_weight_decay: 0.2513
#
# Epoch 00016: val_acc did not improve from 0.71154
# Confusion matrix:
#  [[ 9 19]
#  [ 2 22]]
# Epoch 17/35
# 9/9 [==============================] - 11s 1s/step - loss: 0.2220 - mean_absolute_error: 0.4501 - acc: 0.6372 - loss_no_weight_decay: 0.2220 - val_loss: 0.1996 - val_mean_absolute_error: 0.4262 - val_acc: 0.6562 - val_loss_no_weight_decay: 0.1996
#
# Epoch 00017: val_acc did not improve from 0.71154
# Confusion matrix:
#  [[18 14]
#  [ 9 23]]
# Epoch 18/35
# 9/9 [==============================] - 8s 933ms/step - loss: 0.2008 - mean_absolute_error: 0.4191 - acc: 0.7277 - loss_no_weight_decay: 0.2008 - val_loss: 0.2183 - val_mean_absolute_error: 0.4338 - val_acc: 0.6923 - val_loss_no_weight_decay: 0.2183
#
# Epoch 00018: val_acc did not improve from 0.71154
# Confusion matrix:
#  [[22  4]
#  [ 8 18]]
# Epoch 19/35
# 9/9 [==============================] - 11s 1s/step - loss: 0.2248 - mean_absolute_error: 0.4248 - acc: 0.6632 - loss_no_weight_decay: 0.2248 - val_loss: 0.1857 - val_mean_absolute_error: 0.3957 - val_acc: 0.7188 - val_loss_no_weight_decay: 0.1857
#
# Epoch 00019: val_acc improved from 0.71154 to 0.71875, saving model to base_2020-05-07-11-25-03-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[23  7]
#  [10 24]]
# Epoch 20/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.2081 - mean_absolute_error: 0.4149 - acc: 0.7079 - loss_no_weight_decay: 0.2081 - val_loss: 0.2267 - val_mean_absolute_error: 0.4372 - val_acc: 0.6538 - val_loss_no_weight_decay: 0.2267
#
# Epoch 00020: val_acc did not improve from 0.71875
# Confusion matrix:
#  [[16  9]
#  [ 6 21]]
# Epoch 21/35
# 9/9 [==============================] - 10s 1s/step - loss: 0.2095 - mean_absolute_error: 0.4177 - acc: 0.6974 - loss_no_weight_decay: 0.2095 - val_loss: 0.2207 - val_mean_absolute_error: 0.4306 - val_acc: 0.7031 - val_loss_no_weight_decay: 0.2207
#
# Epoch 00021: val_acc did not improve from 0.71875
# Confusion matrix:
#  [[22  9]
#  [ 8 25]]
# Epoch 22/35
# 9/9 [==============================] - 11s 1s/step - loss: 0.2035 - mean_absolute_error: 0.4088 - acc: 0.7117 - loss_no_weight_decay: 0.2035 - val_loss: 0.1785 - val_mean_absolute_error: 0.3872 - val_acc: 0.7115 - val_loss_no_weight_decay: 0.1785
#
# Epoch 00022: val_acc did not improve from 0.71875
# Confusion matrix:
#  [[15  9]
#  [ 9 19]]
# Epoch 23/35
# 9/9 [==============================] - 11s 1s/step - loss: 0.2110 - mean_absolute_error: 0.4122 - acc: 0.6886 - loss_no_weight_decay: 0.2110 - val_loss: 0.1775 - val_mean_absolute_error: 0.3859 - val_acc: 0.7969 - val_loss_no_weight_decay: 0.1775
#
# Epoch 00023: val_acc improved from 0.71875 to 0.79688, saving model to base_2020-05-07-11-25-03-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[27  4]
#  [18 15]]
# Epoch 24/35
# 9/9 [==============================] - 11s 1s/step - loss: 0.2008 - mean_absolute_error: 0.4064 - acc: 0.7101 - loss_no_weight_decay: 0.2008 - val_loss: 0.2346 - val_mean_absolute_error: 0.4473 - val_acc: 0.6154 - val_loss_no_weight_decay: 0.2346
#
# Epoch 00024: val_acc did not improve from 0.79688
# Confusion matrix:
#  [[21  1]
#  [11 19]]
# Epoch 25/35
# 9/9 [==============================] - 9s 1s/step - loss: 0.2084 - mean_absolute_error: 0.4218 - acc: 0.7077 - loss_no_weight_decay: 0.2084 - val_loss: 0.2120 - val_mean_absolute_error: 0.4279 - val_acc: 0.7031 - val_loss_no_weight_decay: 0.2120
#
# Epoch 00025: val_acc did not improve from 0.79688
# Confusion matrix:
#  [[25  9]
#  [10 20]]
# Epoch 26/35
# 9/9 [==============================] - 11s 1s/step - loss: 0.1876 - mean_absolute_error: 0.3997 - acc: 0.7448 - loss_no_weight_decay: 0.1876 - val_loss: 0.1746 - val_mean_absolute_error: 0.3791 - val_acc: 0.7885 - val_loss_no_weight_decay: 0.1746
#
# Epoch 00026: val_acc did not improve from 0.79688
# Confusion matrix:
#  [[20  4]
#  [ 6 22]]
# Epoch 27/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.1872 - mean_absolute_error: 0.3832 - acc: 0.7390 - loss_no_weight_decay: 0.1872 - val_loss: 0.2236 - val_mean_absolute_error: 0.4123 - val_acc: 0.6719 - val_loss_no_weight_decay: 0.2236
#
# Epoch 00027: val_acc did not improve from 0.79688
# Confusion matrix:
#  [[33  2]
#  [12 17]]
# Epoch 28/35
# 9/9 [==============================] - 8s 891ms/step - loss: 0.1901 - mean_absolute_error: 0.3783 - acc: 0.7219 - loss_no_weight_decay: 0.1901 - val_loss: 0.1717 - val_mean_absolute_error: 0.3691 - val_acc: 0.7500 - val_loss_no_weight_decay: 0.1717
#
# Epoch 00028: val_acc did not improve from 0.79688
# Confusion matrix:
#  [[17 10]
#  [ 4 21]]
# Epoch 29/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.1911 - mean_absolute_error: 0.3942 - acc: 0.7292 - loss_no_weight_decay: 0.1911 - val_loss: 0.2261 - val_mean_absolute_error: 0.4378 - val_acc: 0.6250 - val_loss_no_weight_decay: 0.2261
#
# Epoch 00029: val_acc did not improve from 0.79688
# Confusion matrix:
#  [[30  3]
#  [17 14]]
# Epoch 30/35
# 9/9 [==============================] - 9s 1s/step - loss: 0.1928 - mean_absolute_error: 0.4049 - acc: 0.7064 - loss_no_weight_decay: 0.1928 - val_loss: 0.1639 - val_mean_absolute_error: 0.3766 - val_acc: 0.8077 - val_loss_no_weight_decay: 0.1639
#
# Epoch 00030: val_acc improved from 0.79688 to 0.80769, saving model to base_2020-05-07-11-25-03-val_acc_checkpoint.hdf5
# Confusion matrix:
#  [[22  5]
#  [ 8 17]]
# Epoch 31/35
# 9/9 [==============================] - 11s 1s/step - loss: 0.1795 - mean_absolute_error: 0.3819 - acc: 0.7513 - loss_no_weight_decay: 0.1795 - val_loss: 0.1768 - val_mean_absolute_error: 0.3664 - val_acc: 0.7656 - val_loss_no_weight_decay: 0.1768
# Epoch 00031: val_acc did not improve from 0.80769
# Confusion matrix:
#  [[31  6]
#  [ 9 18]]
# Epoch 32/35
# 9/9 [==============================] - 11s 1s/step - loss: 0.1779 - mean_absolute_error: 0.3740 - acc: 0.7357 - loss_no_weight_decay: 0.1779 - val_loss: 0.1776 - val_mean_absolute_error: 0.3750 - val_acc: 0.7500 - val_loss_no_weight_decay: 0.1776
#
# Epoch 00032: val_acc did not improve from 0.80769
# Confusion matrix:
#  [[19  4]
#  [11 18]]
# Epoch 33/35
# 9/9 [==============================] - 12s 1s/step - loss: 0.1788 - mean_absolute_error: 0.3797 - acc: 0.7431 - loss_no_weight_decay: 0.1788 - val_loss: 0.1666 - val_mean_absolute_error: 0.3674 - val_acc: 0.7656 - val_loss_no_weight_decay: 0.1666
#
# Epoch 00033: val_acc did not improve from 0.80769
# Confusion matrix:
#  [[30  5]
#  [13 16]]
# Epoch 34/35
# 9/9 [==============================] - 9s 947ms/step - loss: 0.1683 - mean_absolute_error: 0.3679 - acc: 0.7627 - loss_no_weight_decay: 0.1683 - val_loss: 0.1793 - val_mean_absolute_error: 0.3684 - val_acc: 0.7115 - val_loss_no_weight_decay: 0.1793
#
# Epoch 00034: val_acc did not improve from 0.80769
# Confusion matrix:
#  [[19  6]
#  [ 7 20]]
# Epoch 35/35
# 9/9 [==============================] - 10s 1s/step - loss: 0.1806 - mean_absolute_error: 0.3836 - acc: 0.7259 - loss_no_weight_decay: 0.1806 - val_loss: 0.1870 - val_mean_absolute_error: 0.4015 - val_acc: 0.7344 - val_loss_no_weight_decay: 0.1870
#
# Epoch 00035: val_acc did not improve from 0.80769
# Confusion matrix:
#  [[25  5]
#  [ 7 27]]
# 176/176 [==============================] - 4s 23ms/step
# 176/176 [==============================] - 4s 23ms/step
# Test loss: 0.1573642543622885
# Test accuracy: 0.3722970776090568
# Confusion Matrix
# [[77 11]
#  [22 66]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.78      0.88      0.82        88
#            1       0.86      0.75      0.80        88
#
#     accuracy                           0.81       176
#    macro avg       0.82      0.81      0.81       176
# weighted avg       0.82      0.81      0.81       176

# %%
import numpy as np 
import matplotlib.pyplot as plt
import os
import wandb
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_mean_absolute_error', 'val_acc', 'val_loss_no_weight_decay', 'loss', 'mean_absolute_error', 'acc', 'loss_no_weight_decay', 'lr'])

# %%
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model accuracy.png')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
from Kappa_Skl import kappa
def kappa2(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    if len(y_true.shape) > 1 and y_true.shape[1] > 1:
        y_true = y_true.dot(range(y_true.shape[1]))
    if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
        y_pred = y_pred.dot(range(y_pred.shape[1]))
    try:
        return kappa(y_true, y_pred, weights='quadratic')
    except IndexError:
        return np.nan
    
print('Quadratic_wieghted_kappa')
print(kappa2(y_true, y_pred))
# Out:
# Quadratic_wieghted_kappa
# 0.625

# %%
# summarize history for mean_absolute _error
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model mean_absolute_error')
plt.ylabel('mean_absolute_error')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
#plt.savefig('model maey.png')
